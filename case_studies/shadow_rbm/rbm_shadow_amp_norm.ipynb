# %%
# %reload_ext autoreload
# %autoreload 2

from lib.data_loading import load_measurements, MixedDataLoader

####

from pathlib import Path
from typing import Optional, Tuple, Dict, Any, Sequence
from itertools import combinations

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import optax
from flax.training.train_state import TrainState
from flax import linen as nn

import matplotlib.pyplot as plt


data_dir = "data"
model_dir = Path("./models")
model_dir.mkdir(parents=True, exist_ok=True)

print(f"Data resides in        : {data_dir}")
print(f"Model will be saved to : {model_dir}")
# Out:
# Data resides in        : data
# Model will be saved to : models

# %%
class RBM(nn.Module):
    num_visible: int
    num_hidden: int
    k: int = 1
    T: float = 1.0

    def setup(self):
        self.W = self.param("W", nn.initializers.normal(0.01), (self.num_visible, self.num_hidden))
        self.b = self.param("b", nn.initializers.zeros, (self.num_visible,))
        self.c = self.param("c", nn.initializers.zeros, (self.num_hidden,))

    def __call__(self, data: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W, self.b, self.c, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (aux_vars["gibbs_chain"], aux_vars["key"]))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain)

        free_energy_data = self._free_energy(data)
        free_energy_model = self._free_energy(gibbs_chain)

        contrastive_divergence = jnp.mean(free_energy_data) - jnp.mean(free_energy_model)
        regularization = aux_vars["l2_strength"] * (jnp.sum(self.W**2) + jnp.sum(self.b**2) + jnp.sum(self.c**2))
        loss = contrastive_divergence + regularization

        aux_vars = {
            "gibbs_chain": gibbs_chain,
            "key": key,
            "free_energy_data": jnp.mean(free_energy_data),
            "free_energy_model": jnp.mean(free_energy_model),
        }

        return loss, aux_vars

    def _free_energy(self, v):
        return -(v @ self.b) - jnp.sum(jax.nn.softplus(v @ self.W + self.c), -1)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c)/T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b)/T)).astype(jnp.float32)
        return v, key

    @nn.nowrap
    def generate(self, num_samples: int, T_schedule: jnp.ndarray, key: PRNGKey) -> jnp.ndarray:
        key, key_init = jax.random.split(key, 2)
        v = jax.random.bernoulli(key_init, p=0.5, shape=(num_samples, self.num_visible)).astype(jnp.float32)

        anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, (v, key))
        return v_final

# %%
@jax.jit
def train_step(
        state: TrainState,
        batch: jnp.ndarray,
        gibbs_chain: jnp.ndarray,
        key: PRNGKey,
        chain_reset_frac: float,
        l2_strength) -> Tuple[TrainState, jnp.ndarray, jnp.ndarray, PRNGKey]:

    key, key_reset = jax.random.split(key)

    # reset gibbs_chain[i] with batch[i] given reset probability as chain_reset_frac
    reset_mask = jax.random.bernoulli(key_reset, p=chain_reset_frac, shape=(batch.shape[0], 1))
    gibbs_chain = jnp.where(reset_mask, batch, gibbs_chain)

    aux_vars = {"gibbs_chain": gibbs_chain, "key": key, "l2_strength": l2_strength}
    loss_fn = lambda params: state.apply_fn({'params': params}, batch, aux_vars)
    (loss, aux_vars), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    state = state.apply_gradients(grads=grads)

    return state, loss, aux_vars["gibbs_chain"], aux_vars["key"], aux_vars["free_energy_model"]


def count_modes(chain: jnp.ndarray) -> int:
    chain = chain.astype(jnp.uint32)
    powers = 2 ** jnp.arange(chain.shape[-1], dtype=jnp.uint32)
    ints = jnp.dot(chain, powers)

    hist = jnp.bincount(ints, length=1 << chain.shape[-1])
    return int(jnp.sum(hist > 0))


def train(
        state: TrainState,
        loader: MixedDataLoader,
        num_epochs: int,
        key: PRNGKey,
        chain_reset_frac: float,
        l2_strength: float) -> Tuple[TrainState, Dict[int, float]]:

    metrics: Dict[int, Any] = {}
    for epoch in range(num_epochs):
        gibbs_chain = None
        tot_loss = 0.0

        for i, batch in enumerate(loader):
            measurements = batch[:, :, 0].astype(jnp.float32) # we simply assume we are only dealing with Z-basis measurements here
            gibbs_chain = measurements if gibbs_chain is None else gibbs_chain

            key, key_batch = jax.random.split(key)
            state, loss, gibbs_chain, key, free_energy_model = train_step(state, measurements, gibbs_chain, key, chain_reset_frac, l2_strength)

            tot_loss += float(loss)

        avg_loss = tot_loss / len(loader)
        modes = count_modes(gibbs_chain)
        lr = float(lr_schedule(state.opt_state[0].count))

        metrics[epoch] = dict(loss=avg_loss, modes=modes, free_energy_model=free_energy_model, lr=lr)

        print(f"Epoch {epoch+1}/{num_epochs} │ "
              f"Loss: {avg_loss:+.4f} │ "
              f"Chain Modes: {modes} │ "
              f"Free Energy Model: {free_energy_model:.4f} │ "
              f"Learning Rate: {lr:.5f}")

    return state, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2

    curve_fn = lambda step: low + (high - low) / (1 + jnp.exp(falloff * (jnp.minimum(step, steps) - center_step)))
    return curve_fn

# %%
file_path = Path("data/w_aug_ZZZZZZZZ_10000.txt")
data = load_measurements(file_path)

measurements = data[:, :, 0]
empirical_freq = measurements.mean(axis=0)
empirical_freq
# Out:
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 26477.45it/s]
# Array([0.12529999, 0.1228    , 0.1222    , 0.1248    , 0.1337    ,
#        0.1295    , 0.1199    , 0.1218    ], dtype=float32)

# %%
batch_size   = 1024             # larger requires more epochs for the model to go down in its modes
num_visible  = 8
hidden_units = 8                # interesting, lower gives evener frequencies, although the modes go not down to 1
k_steps      = 50               # more steps required if small batch size
num_epochs   = 2000             # longer since large batch size
init_lr      = 1e-2             # large drives modes down fast but learns nothing, to small and we dont get any one hots
final_lr     = init_lr * 0.1
chain_reset_frac = 0.1
l2_strength  = 1e-4

# runs also very nicely if l2 norm is turned off completely


key_seed = PRNGKey(42)
key, key_params, key_dummy = jax.random.split(key_seed, 3)

model = RBM(num_visible=num_visible, num_hidden=hidden_units, k=k_steps)
batch_dummy = jnp.zeros((batch_size, num_visible), dtype=jnp.float32)
aux_vars_dummy = {"gibbs_chain": jnp.zeros((batch_size, num_visible), dtype=jnp.float32), "key": key_dummy, "l2_strength": l2_strength}
variables = model.init({"params": key_params}, batch_dummy, aux_vars_dummy)

loader = MixedDataLoader(data, batch_size=batch_size, drop_last=True) # we need the last batch to match the chain dimension

schedule_steps = num_epochs * len(loader)
lr_schedule = get_sigmoid_curve(high=init_lr, low=final_lr, steps=schedule_steps, falloff=0.0005)
optimizer = optax.adam(lr_schedule)

state = TrainState.create(apply_fn=model.apply, params=variables['params'], tx=optimizer)

state, metrics = train(state, loader, num_epochs, key, chain_reset_frac, l2_strength)
# Out:
# Epoch 1/2000 │ Loss: -0.4583 │ Chain Modes: 243 │ Free Energy Model: -4.5385 │ Learning Rate: 0.00990
# Epoch 2/2000 │ Loss: -1.0704 │ Chain Modes: 212 │ Free Energy Model: -4.1756 │ Learning Rate: 0.00990
# Epoch 3/2000 │ Loss: -1.1997 │ Chain Modes: 195 │ Free Energy Model: -4.2334 │ Learning Rate: 0.00990
# Epoch 4/2000 │ Loss: -1.0315 │ Chain Modes: 152 │ Free Energy Model: -4.6784 │ Learning Rate: 0.00990
# Epoch 5/2000 │ Loss: -0.7388 │ Chain Modes: 148 │ Free Energy Model: -5.0193 │ Learning Rate: 0.00990
# Epoch 6/2000 │ Loss: -0.4145 │ Chain Modes: 121 │ Free Energy Model: -5.6295 │ Learning Rate: 0.00990
# Epoch 7/2000 │ Loss: -0.1757 │ Chain Modes: 112 │ Free Energy Model: -5.8853 │ Learning Rate: 0.00990
# Epoch 8/2000 │ Loss: -0.0912 │ Chain Modes: 112 │ Free Energy Model: -6.1150 │ Learning Rate: 0.00990
# Epoch 9/2000 │ Loss: +0.0012 │ Chain Modes: 103 │ Free Energy Model: -6.2427 │ Learning Rate: 0.00990
# Epoch 10/2000 │ Loss: -0.0398 │ Chain Modes: 109 │ Free Energy Model: -6.3900 │ Learning Rate: 0.00990
# Epoch 11/2000 │ Loss: -0.0856 │ Chain Modes: 110 │ Free Energy Model: -6.4951 │ Learning Rate: 0.00990
# Epoch 12/2000 │ Loss: -0.0394 │ Chain Modes: 96 │ Free Energy Model: -6.8009 │ Learning Rate: 0.00990
# Epoch 13/2000 │ Loss: -0.1349 │ Chain Modes: 99 │ Free Energy Model: -6.7228 │ Learning Rate: 0.00990
# Epoch 14/2000 │ Loss: -0.1066 │ Chain Modes: 108 │ Free Energy Model: -6.8620 │ Learning Rate: 0.00989
# Epoch 15/2000 │ Loss: -0.1235 │ Chain Modes: 112 │ Free Energy Model: -6.9435 │ Learning Rate: 0.00989
# Epoch 16/2000 │ Loss: -0.1471 │ Chain Modes: 104 │ Free Energy Model: -7.1039 │ Learning Rate: 0.00989
# Epoch 17/2000 │ Loss: -0.0724 │ Chain Modes: 94 │ Free Energy Model: -7.4978 │ Learning Rate: 0.00989
# Epoch 18/2000 │ Loss: -0.0720 │ Chain Modes: 100 │ Free Energy Model: -7.5534 │ Learning Rate: 0.00989
# Epoch 19/2000 │ Loss: -0.1230 │ Chain Modes: 97 │ Free Energy Model: -7.6064 │ Learning Rate: 0.00989
# Epoch 20/2000 │ Loss: -0.0974 │ Chain Modes: 105 │ Free Energy Model: -7.7950 │ Learning Rate: 0.00989
# Epoch 21/2000 │ Loss: -0.0901 │ Chain Modes: 94 │ Free Energy Model: -8.0448 │ Learning Rate: 0.00989
# Epoch 22/2000 │ Loss: -0.0818 │ Chain Modes: 101 │ Free Energy Model: -8.0825 │ Learning Rate: 0.00989
# Epoch 23/2000 │ Loss: -0.1166 │ Chain Modes: 104 │ Free Energy Model: -8.2356 │ Learning Rate: 0.00989
# Epoch 24/2000 │ Loss: -0.1357 │ Chain Modes: 97 │ Free Energy Model: -8.4339 │ Learning Rate: 0.00989
# Epoch 25/2000 │ Loss: -0.0616 │ Chain Modes: 92 │ Free Energy Model: -8.6647 │ Learning Rate: 0.00989
# Epoch 26/2000 │ Loss: -0.0745 │ Chain Modes: 99 │ Free Energy Model: -8.6009 │ Learning Rate: 0.00989
# Epoch 27/2000 │ Loss: -0.0961 │ Chain Modes: 94 │ Free Energy Model: -8.7831 │ Learning Rate: 0.00989
# Epoch 28/2000 │ Loss: -0.0612 │ Chain Modes: 92 │ Free Energy Model: -8.9730 │ Learning Rate: 0.00989
# Epoch 29/2000 │ Loss: -0.0657 │ Chain Modes: 89 │ Free Energy Model: -9.2157 │ Learning Rate: 0.00989
# Epoch 30/2000 │ Loss: -0.0585 │ Chain Modes: 101 │ Free Energy Model: -9.1485 │ Learning Rate: 0.00989
# Epoch 31/2000 │ Loss: -0.0893 │ Chain Modes: 98 │ Free Energy Model: -9.2749 │ Learning Rate: 0.00989
# Epoch 32/2000 │ Loss: -0.0731 │ Chain Modes: 84 │ Free Energy Model: -9.5509 │ Learning Rate: 0.00989
# Epoch 33/2000 │ Loss: -0.0922 │ Chain Modes: 97 │ Free Energy Model: -9.5800 │ Learning Rate: 0.00989
# Epoch 34/2000 │ Loss: -0.0234 │ Chain Modes: 81 │ Free Energy Model: -9.9195 │ Learning Rate: 0.00988
# Epoch 35/2000 │ Loss: -0.0827 │ Chain Modes: 91 │ Free Energy Model: -9.8497 │ Learning Rate: 0.00988
# Epoch 36/2000 │ Loss: -0.0927 │ Chain Modes: 84 │ Free Energy Model: -9.9841 │ Learning Rate: 0.00988
# Epoch 37/2000 │ Loss: -0.0688 │ Chain Modes: 90 │ Free Energy Model: -10.1024 │ Learning Rate: 0.00988
# Epoch 38/2000 │ Loss: -0.0426 │ Chain Modes: 82 │ Free Energy Model: -10.2557 │ Learning Rate: 0.00988
# Epoch 39/2000 │ Loss: -0.0739 │ Chain Modes: 98 │ Free Energy Model: -10.1608 │ Learning Rate: 0.00988
# Epoch 40/2000 │ Loss: -0.0482 │ Chain Modes: 98 │ Free Energy Model: -10.3933 │ Learning Rate: 0.00988
# Epoch 41/2000 │ Loss: -0.0783 │ Chain Modes: 87 │ Free Energy Model: -10.5053 │ Learning Rate: 0.00988
# Epoch 42/2000 │ Loss: -0.0517 │ Chain Modes: 90 │ Free Energy Model: -10.5470 │ Learning Rate: 0.00988
# Epoch 43/2000 │ Loss: -0.0530 │ Chain Modes: 95 │ Free Energy Model: -10.6274 │ Learning Rate: 0.00988
# Epoch 44/2000 │ Loss: -0.0832 │ Chain Modes: 92 │ Free Energy Model: -10.6581 │ Learning Rate: 0.00988
# Epoch 45/2000 │ Loss: -0.0206 │ Chain Modes: 77 │ Free Energy Model: -10.9404 │ Learning Rate: 0.00988
# Epoch 46/2000 │ Loss: -0.0374 │ Chain Modes: 93 │ Free Energy Model: -10.9557 │ Learning Rate: 0.00988
# Epoch 47/2000 │ Loss: -0.1027 │ Chain Modes: 92 │ Free Energy Model: -11.0268 │ Learning Rate: 0.00988
# Epoch 48/2000 │ Loss: -0.0501 │ Chain Modes: 84 │ Free Energy Model: -11.1886 │ Learning Rate: 0.00988
# Epoch 49/2000 │ Loss: +0.0070 │ Chain Modes: 82 │ Free Energy Model: -11.2427 │ Learning Rate: 0.00988
# Epoch 50/2000 │ Loss: -0.0464 │ Chain Modes: 91 │ Free Energy Model: -11.2348 │ Learning Rate: 0.00988
# Epoch 51/2000 │ Loss: -0.0857 │ Chain Modes: 95 │ Free Energy Model: -11.3899 │ Learning Rate: 0.00988
# Epoch 52/2000 │ Loss: -0.0487 │ Chain Modes: 97 │ Free Energy Model: -11.4832 │ Learning Rate: 0.00988
# Epoch 53/2000 │ Loss: -0.0097 │ Chain Modes: 82 │ Free Energy Model: -11.6406 │ Learning Rate: 0.00987
# Epoch 54/2000 │ Loss: -0.0718 │ Chain Modes: 89 │ Free Energy Model: -11.7003 │ Learning Rate: 0.00987
# Epoch 55/2000 │ Loss: -0.0636 │ Chain Modes: 92 │ Free Energy Model: -11.8013 │ Learning Rate: 0.00987
# Epoch 56/2000 │ Loss: -0.0115 │ Chain Modes: 83 │ Free Energy Model: -11.9453 │ Learning Rate: 0.00987
# Epoch 57/2000 │ Loss: -0.0190 │ Chain Modes: 79 │ Free Energy Model: -11.9524 │ Learning Rate: 0.00987
# Epoch 58/2000 │ Loss: -0.0683 │ Chain Modes: 94 │ Free Energy Model: -12.0191 │ Learning Rate: 0.00987
# Epoch 59/2000 │ Loss: -0.0496 │ Chain Modes: 89 │ Free Energy Model: -12.0648 │ Learning Rate: 0.00987
# Epoch 60/2000 │ Loss: -0.0489 │ Chain Modes: 86 │ Free Energy Model: -12.0366 │ Learning Rate: 0.00987
# Epoch 61/2000 │ Loss: -0.0466 │ Chain Modes: 84 │ Free Energy Model: -12.2835 │ Learning Rate: 0.00987
# Epoch 62/2000 │ Loss: +0.0259 │ Chain Modes: 90 │ Free Energy Model: -12.2889 │ Learning Rate: 0.00987
# Epoch 63/2000 │ Loss: -0.0685 │ Chain Modes: 88 │ Free Energy Model: -12.3565 │ Learning Rate: 0.00987
# Epoch 64/2000 │ Loss: -0.0552 │ Chain Modes: 84 │ Free Energy Model: -12.4238 │ Learning Rate: 0.00987
# Epoch 65/2000 │ Loss: -0.0066 │ Chain Modes: 80 │ Free Energy Model: -12.5204 │ Learning Rate: 0.00987
# Epoch 66/2000 │ Loss: -0.0474 │ Chain Modes: 82 │ Free Energy Model: -12.5478 │ Learning Rate: 0.00987
# Epoch 67/2000 │ Loss: -0.0438 │ Chain Modes: 88 │ Free Energy Model: -12.6598 │ Learning Rate: 0.00987
# Epoch 68/2000 │ Loss: -0.0202 │ Chain Modes: 85 │ Free Energy Model: -12.7110 │ Learning Rate: 0.00987
# Epoch 69/2000 │ Loss: -0.0573 │ Chain Modes: 89 │ Free Energy Model: -12.7355 │ Learning Rate: 0.00987
# Epoch 70/2000 │ Loss: -0.0379 │ Chain Modes: 96 │ Free Energy Model: -12.7807 │ Learning Rate: 0.00987
# Epoch 71/2000 │ Loss: -0.0046 │ Chain Modes: 91 │ Free Energy Model: -12.8870 │ Learning Rate: 0.00986
# Epoch 72/2000 │ Loss: -0.0347 │ Chain Modes: 84 │ Free Energy Model: -12.9309 │ Learning Rate: 0.00986
# Epoch 73/2000 │ Loss: -0.0322 │ Chain Modes: 87 │ Free Energy Model: -13.0207 │ Learning Rate: 0.00986
# Epoch 74/2000 │ Loss: -0.0450 │ Chain Modes: 88 │ Free Energy Model: -13.0270 │ Learning Rate: 0.00986
# Epoch 75/2000 │ Loss: -0.0311 │ Chain Modes: 90 │ Free Energy Model: -13.0563 │ Learning Rate: 0.00986
# Epoch 76/2000 │ Loss: +0.0013 │ Chain Modes: 89 │ Free Energy Model: -13.2263 │ Learning Rate: 0.00986
# Epoch 77/2000 │ Loss: -0.0546 │ Chain Modes: 91 │ Free Energy Model: -13.2836 │ Learning Rate: 0.00986
# Epoch 78/2000 │ Loss: -0.0286 │ Chain Modes: 79 │ Free Energy Model: -13.2889 │ Learning Rate: 0.00986
# Epoch 79/2000 │ Loss: -0.0275 │ Chain Modes: 93 │ Free Energy Model: -13.2622 │ Learning Rate: 0.00986
# Epoch 80/2000 │ Loss: -0.0004 │ Chain Modes: 92 │ Free Energy Model: -13.2525 │ Learning Rate: 0.00986
# Epoch 81/2000 │ Loss: -0.0646 │ Chain Modes: 89 │ Free Energy Model: -13.4149 │ Learning Rate: 0.00986
# Epoch 82/2000 │ Loss: +0.0086 │ Chain Modes: 82 │ Free Energy Model: -13.5586 │ Learning Rate: 0.00986
# Epoch 83/2000 │ Loss: -0.0472 │ Chain Modes: 87 │ Free Energy Model: -13.5134 │ Learning Rate: 0.00986
# Epoch 84/2000 │ Loss: -0.0633 │ Chain Modes: 88 │ Free Energy Model: -13.5382 │ Learning Rate: 0.00986
# Epoch 85/2000 │ Loss: -0.0145 │ Chain Modes: 82 │ Free Energy Model: -13.6023 │ Learning Rate: 0.00986
# Epoch 86/2000 │ Loss: +0.0114 │ Chain Modes: 88 │ Free Energy Model: -13.5897 │ Learning Rate: 0.00986
# Epoch 134/2000 │ Loss: -0.0017 │ Chain Modes: 87 │ Free Energy Model: -15.0099 │ Learning Rate: 0.00982
# Epoch 135/2000 │ Loss: +0.0295 │ Chain Modes: 87 │ Free Energy Model: -15.0353 │ Learning Rate: 0.00982
# Epoch 136/2000 │ Loss: -0.0539 │ Chain Modes: 88 │ Free Energy Model: -14.9706 │ Learning Rate: 0.00982
# Epoch 137/2000 │ Loss: -0.0137 │ Chain Modes: 82 │ Free Energy Model: -15.0753 │ Learning Rate: 0.00982
# Epoch 138/2000 │ Loss: +0.0125 │ Chain Modes: 77 │ Free Energy Model: -15.1358 │ Learning Rate: 0.00982
# Epoch 139/2000 │ Loss: -0.0319 │ Chain Modes: 88 │ Free Energy Model: -14.9919 │ Learning Rate: 0.00982
# Epoch 140/2000 │ Loss: +0.0010 │ Chain Modes: 90 │ Free Energy Model: -14.9937 │ Learning Rate: 0.00982
# Epoch 141/2000 │ Loss: -0.0130 │ Chain Modes: 72 │ Free Energy Model: -15.1857 │ Learning Rate: 0.00982
# Epoch 142/2000 │ Loss: -0.0159 │ Chain Modes: 81 │ Free Energy Model: -15.1473 │ Learning Rate: 0.00981
# Epoch 143/2000 │ Loss: -0.0109 │ Chain Modes: 88 │ Free Energy Model: -15.0459 │ Learning Rate: 0.00981
# Epoch 144/2000 │ Loss: -0.0116 │ Chain Modes: 75 │ Free Energy Model: -15.1184 │ Learning Rate: 0.00981
# Epoch 145/2000 │ Loss: -0.0067 │ Chain Modes: 90 │ Free Energy Model: -15.0584 │ Learning Rate: 0.00981
# Epoch 146/2000 │ Loss: -0.0088 │ Chain Modes: 84 │ Free Energy Model: -15.1216 │ Learning Rate: 0.00981
# Epoch 147/2000 │ Loss: -0.0348 │ Chain Modes: 91 │ Free Energy Model: -15.0282 │ Learning Rate: 0.00981
# Epoch 148/2000 │ Loss: +0.0162 │ Chain Modes: 77 │ Free Energy Model: -15.0963 │ Learning Rate: 0.00981
# Epoch 149/2000 │ Loss: -0.0280 │ Chain Modes: 85 │ Free Energy Model: -15.0981 │ Learning Rate: 0.00981
# Epoch 150/2000 │ Loss: -0.0049 │ Chain Modes: 81 │ Free Energy Model: -15.1269 │ Learning Rate: 0.00981
# Epoch 151/2000 │ Loss: -0.0083 │ Chain Modes: 94 │ Free Energy Model: -15.1807 │ Learning Rate: 0.00981
# Epoch 152/2000 │ Loss: -0.0210 │ Chain Modes: 82 │ Free Energy Model: -15.0745 │ Learning Rate: 0.00981
# Epoch 153/2000 │ Loss: -0.0039 │ Chain Modes: 82 │ Free Energy Model: -15.1696 │ Learning Rate: 0.00981
# Epoch 154/2000 │ Loss: +0.0144 │ Chain Modes: 81 │ Free Energy Model: -15.1542 │ Learning Rate: 0.00980
# Epoch 155/2000 │ Loss: -0.0445 │ Chain Modes: 91 │ Free Energy Model: -15.0381 │ Learning Rate: 0.00980
# Epoch 156/2000 │ Loss: -0.0081 │ Chain Modes: 87 │ Free Energy Model: -15.0793 │ Learning Rate: 0.00980
# Epoch 157/2000 │ Loss: -0.0102 │ Chain Modes: 88 │ Free Energy Model: -15.0850 │ Learning Rate: 0.00980
# Epoch 158/2000 │ Loss: -0.0280 │ Chain Modes: 92 │ Free Energy Model: -15.0591 │ Learning Rate: 0.00980
# Epoch 159/2000 │ Loss: +0.0078 │ Chain Modes: 82 │ Free Energy Model: -15.1658 │ Learning Rate: 0.00980
# Epoch 160/2000 │ Loss: +0.0135 │ Chain Modes: 81 │ Free Energy Model: -15.1796 │ Learning Rate: 0.00980
# Epoch 161/2000 │ Loss: -0.0414 │ Chain Modes: 82 │ Free Energy Model: -15.2032 │ Learning Rate: 0.00980
# Epoch 162/2000 │ Loss: -0.0244 │ Chain Modes: 86 │ Free Energy Model: -15.1122 │ Learning Rate: 0.00980
# Epoch 163/2000 │ Loss: +0.0006 │ Chain Modes: 85 │ Free Energy Model: -15.1089 │ Learning Rate: 0.00980
# Epoch 164/2000 │ Loss: +0.0219 │ Chain Modes: 84 │ Free Energy Model: -15.0445 │ Learning Rate: 0.00980
# Epoch 165/2000 │ Loss: -0.0366 │ Chain Modes: 80 │ Free Energy Model: -15.1512 │ Learning Rate: 0.00979
# Epoch 166/2000 │ Loss: +0.0005 │ Chain Modes: 84 │ Free Energy Model: -15.2444 │ Learning Rate: 0.00979
# Epoch 167/2000 │ Loss: -0.0167 │ Chain Modes: 82 │ Free Energy Model: -15.1459 │ Learning Rate: 0.00979
# Epoch 168/2000 │ Loss: +0.0055 │ Chain Modes: 85 │ Free Energy Model: -15.1788 │ Learning Rate: 0.00979
# Epoch 169/2000 │ Loss: -0.0173 │ Chain Modes: 88 │ Free Energy Model: -15.1523 │ Learning Rate: 0.00979
# Epoch 170/2000 │ Loss: -0.0315 │ Chain Modes: 91 │ Free Energy Model: -15.0749 │ Learning Rate: 0.00979
# Epoch 171/2000 │ Loss: +0.0282 │ Chain Modes: 77 │ Free Energy Model: -15.1798 │ Learning Rate: 0.00979
# Epoch 172/2000 │ Loss: -0.0184 │ Chain Modes: 84 │ Free Energy Model: -15.1632 │ Learning Rate: 0.00979
# Epoch 173/2000 │ Loss: -0.0451 │ Chain Modes: 87 │ Free Energy Model: -15.0981 │ Learning Rate: 0.00979
# Epoch 174/2000 │ Loss: +0.0154 │ Chain Modes: 84 │ Free Energy Model: -15.0562 │ Learning Rate: 0.00979
# Epoch 175/2000 │ Loss: +0.0123 │ Chain Modes: 85 │ Free Energy Model: -15.0585 │ Learning Rate: 0.00979
# Epoch 176/2000 │ Loss: -0.0428 │ Chain Modes: 88 │ Free Energy Model: -15.0438 │ Learning Rate: 0.00978
# Epoch 177/2000 │ Loss: +0.0042 │ Chain Modes: 77 │ Free Energy Model: -15.1083 │ Learning Rate: 0.00978
# Epoch 178/2000 │ Loss: -0.0152 │ Chain Modes: 86 │ Free Energy Model: -14.9731 │ Learning Rate: 0.00978
# Epoch 179/2000 │ Loss: -0.0204 │ Chain Modes: 88 │ Free Energy Model: -15.0045 │ Learning Rate: 0.00978
# Epoch 180/2000 │ Loss: +0.0091 │ Chain Modes: 85 │ Free Energy Model: -15.0637 │ Learning Rate: 0.00978
# Epoch 181/2000 │ Loss: -0.0002 │ Chain Modes: 89 │ Free Energy Model: -15.0145 │ Learning Rate: 0.00978
# Epoch 182/2000 │ Loss: -0.0142 │ Chain Modes: 87 │ Free Energy Model: -15.1214 │ Learning Rate: 0.00978
# Epoch 183/2000 │ Loss: -0.0000 │ Chain Modes: 88 │ Free Energy Model: -15.0468 │ Learning Rate: 0.00978
# Epoch 184/2000 │ Loss: -0.0422 │ Chain Modes: 89 │ Free Energy Model: -14.9360 │ Learning Rate: 0.00978
# Epoch 185/2000 │ Loss: +0.0275 │ Chain Modes: 76 │ Free Energy Model: -15.0761 │ Learning Rate: 0.00978
# Epoch 186/2000 │ Loss: +0.0068 │ Chain Modes: 94 │ Free Energy Model: -14.8827 │ Learning Rate: 0.00977
# Epoch 187/2000 │ Loss: -0.0735 │ Chain Modes: 81 │ Free Energy Model: -14.9635 │ Learning Rate: 0.00977
# Epoch 188/2000 │ Loss: +0.0451 │ Chain Modes: 89 │ Free Energy Model: -14.9608 │ Learning Rate: 0.00977
# Epoch 189/2000 │ Loss: +0.0032 │ Chain Modes: 90 │ Free Energy Model: -14.9715 │ Learning Rate: 0.00977
# Epoch 190/2000 │ Loss: -0.0077 │ Chain Modes: 82 │ Free Energy Model: -14.9851 │ Learning Rate: 0.00977
# Epoch 191/2000 │ Loss: -0.0319 │ Chain Modes: 88 │ Free Energy Model: -14.8693 │ Learning Rate: 0.00977
# Epoch 192/2000 │ Loss: +0.0231 │ Chain Modes: 84 │ Free Energy Model: -14.9634 │ Learning Rate: 0.00977
# Epoch 193/2000 │ Loss: -0.0383 │ Chain Modes: 90 │ Free Energy Model: -14.7841 │ Learning Rate: 0.00977
# Epoch 194/2000 │ Loss: -0.0337 │ Chain Modes: 90 │ Free Energy Model: -14.9164 │ Learning Rate: 0.00977
# Epoch 195/2000 │ Loss: +0.0553 │ Chain Modes: 86 │ Free Energy Model: -14.8623 │ Learning Rate: 0.00977
# Epoch 196/2000 │ Loss: -0.0179 │ Chain Modes: 88 │ Free Energy Model: -14.8603 │ Learning Rate: 0.00976
# Epoch 197/2000 │ Loss: -0.0326 │ Chain Modes: 87 │ Free Energy Model: -14.9243 │ Learning Rate: 0.00976
# Epoch 198/2000 │ Loss: -0.0103 │ Chain Modes: 90 │ Free Energy Model: -14.8541 │ Learning Rate: 0.00976
# Epoch 199/2000 │ Loss: +0.0197 │ Chain Modes: 81 │ Free Energy Model: -14.8201 │ Learning Rate: 0.00976
# Epoch 200/2000 │ Loss: -0.0111 │ Chain Modes: 88 │ Free Energy Model: -14.8465 │ Learning Rate: 0.00976
# Epoch 201/2000 │ Loss: -0.0398 │ Chain Modes: 85 │ Free Energy Model: -14.6362 │ Learning Rate: 0.00976
# Epoch 202/2000 │ Loss: +0.0020 │ Chain Modes: 89 │ Free Energy Model: -14.7670 │ Learning Rate: 0.00976
# Epoch 203/2000 │ Loss: +0.0047 │ Chain Modes: 80 │ Free Energy Model: -14.7512 │ Learning Rate: 0.00976
# Epoch 204/2000 │ Loss: -0.0241 │ Chain Modes: 85 │ Free Energy Model: -14.6479 │ Learning Rate: 0.00976
# Epoch 205/2000 │ Loss: +0.0012 │ Chain Modes: 83 │ Free Energy Model: -14.7826 │ Learning Rate: 0.00976
# Epoch 206/2000 │ Loss: +0.0035 │ Chain Modes: 86 │ Free Energy Model: -14.6125 │ Learning Rate: 0.00975
# Epoch 207/2000 │ Loss: -0.0228 │ Chain Modes: 89 │ Free Energy Model: -14.6784 │ Learning Rate: 0.00975
# Epoch 208/2000 │ Loss: -0.0197 │ Chain Modes: 85 │ Free Energy Model: -14.6450 │ Learning Rate: 0.00975
# Epoch 209/2000 │ Loss: +0.0225 │ Chain Modes: 85 │ Free Energy Model: -14.6376 │ Learning Rate: 0.00975
# Epoch 210/2000 │ Loss: -0.0054 │ Chain Modes: 86 │ Free Energy Model: -14.6280 │ Learning Rate: 0.00975
# Epoch 211/2000 │ Loss: -0.0292 │ Chain Modes: 88 │ Free Energy Model: -14.6105 │ Learning Rate: 0.00975
# Epoch 212/2000 │ Loss: +0.0020 │ Chain Modes: 84 │ Free Energy Model: -14.6710 │ Learning Rate: 0.00975
# Epoch 213/2000 │ Loss: -0.0038 │ Chain Modes: 84 │ Free Energy Model: -14.4781 │ Learning Rate: 0.00975
# Epoch 214/2000 │ Loss: -0.0019 │ Chain Modes: 88 │ Free Energy Model: -14.5893 │ Learning Rate: 0.00975
# Epoch 215/2000 │ Loss: -0.0059 │ Chain Modes: 87 │ Free Energy Model: -14.6420 │ Learning Rate: 0.00974
# Epoch 216/2000 │ Loss: -0.0109 │ Chain Modes: 96 │ Free Energy Model: -14.4008 │ Learning Rate: 0.00974
# Epoch 217/2000 │ Loss: -0.0392 │ Chain Modes: 90 │ Free Energy Model: -14.4003 │ Learning Rate: 0.00974
# Epoch 218/2000 │ Loss: +0.0278 │ Chain Modes: 84 │ Free Energy Model: -14.4814 │ Learning Rate: 0.00974
# Epoch 219/2000 │ Loss: -0.0067 │ Chain Modes: 77 │ Free Energy Model: -14.4937 │ Learning Rate: 0.00974
# Epoch 220/2000 │ Loss: -0.0372 │ Chain Modes: 84 │ Free Energy Model: -14.3888 │ Learning Rate: 0.00974
# Epoch 221/2000 │ Loss: +0.0314 │ Chain Modes: 88 │ Free Energy Model: -14.3701 │ Learning Rate: 0.00974
# Epoch 222/2000 │ Loss: -0.0419 │ Chain Modes: 84 │ Free Energy Model: -14.3326 │ Learning Rate: 0.00974
# Epoch 223/2000 │ Loss: +0.0216 │ Chain Modes: 81 │ Free Energy Model: -14.3997 │ Learning Rate: 0.00974
# Epoch 224/2000 │ Loss: -0.0124 │ Chain Modes: 83 │ Free Energy Model: -14.2940 │ Learning Rate: 0.00973
# Epoch 225/2000 │ Loss: +0.0025 │ Chain Modes: 88 │ Free Energy Model: -14.2918 │ Learning Rate: 0.00973
# Epoch 226/2000 │ Loss: +0.0001 │ Chain Modes: 88 │ Free Energy Model: -14.2825 │ Learning Rate: 0.00973
# Epoch 227/2000 │ Loss: -0.0220 │ Chain Modes: 94 │ Free Energy Model: -14.1612 │ Learning Rate: 0.00973
# Epoch 228/2000 │ Loss: -0.0207 │ Chain Modes: 82 │ Free Energy Model: -14.2037 │ Learning Rate: 0.00973
# Epoch 229/2000 │ Loss: +0.0068 │ Chain Modes: 88 │ Free Energy Model: -14.2449 │ Learning Rate: 0.00973
# Epoch 230/2000 │ Loss: +0.0163 │ Chain Modes: 82 │ Free Energy Model: -14.1398 │ Learning Rate: 0.00973
# Epoch 231/2000 │ Loss: -0.0452 │ Chain Modes: 85 │ Free Energy Model: -14.1706 │ Learning Rate: 0.00973
# Epoch 232/2000 │ Loss: +0.0099 │ Chain Modes: 91 │ Free Energy Model: -14.1238 │ Learning Rate: 0.00972
# Epoch 233/2000 │ Loss: -0.0371 │ Chain Modes: 83 │ Free Energy Model: -14.1098 │ Learning Rate: 0.00972
# Epoch 234/2000 │ Loss: +0.0259 │ Chain Modes: 87 │ Free Energy Model: -14.0178 │ Learning Rate: 0.00972
# Epoch 235/2000 │ Loss: -0.0288 │ Chain Modes: 84 │ Free Energy Model: -14.0815 │ Learning Rate: 0.00972
# Epoch 236/2000 │ Loss: +0.0268 │ Chain Modes: 74 │ Free Energy Model: -14.1389 │ Learning Rate: 0.00972
# Epoch 237/2000 │ Loss: -0.0152 │ Chain Modes: 79 │ Free Energy Model: -14.0230 │ Learning Rate: 0.00972
# Epoch 238/2000 │ Loss: -0.0288 │ Chain Modes: 74 │ Free Energy Model: -14.0638 │ Learning Rate: 0.00972
# Epoch 239/2000 │ Loss: +0.0111 │ Chain Modes: 93 │ Free Energy Model: -13.9643 │ Learning Rate: 0.00972
# Epoch 240/2000 │ Loss: -0.0013 │ Chain Modes: 81 │ Free Energy Model: -13.9853 │ Learning Rate: 0.00971
# Epoch 241/2000 │ Loss: -0.0250 │ Chain Modes: 90 │ Free Energy Model: -13.8708 │ Learning Rate: 0.00971
# Epoch 242/2000 │ Loss: -0.0129 │ Chain Modes: 87 │ Free Energy Model: -13.8002 │ Learning Rate: 0.00971
# Epoch 243/2000 │ Loss: +0.0191 │ Chain Modes: 77 │ Free Energy Model: -13.8992 │ Learning Rate: 0.00971
# Epoch 244/2000 │ Loss: -0.0215 │ Chain Modes: 83 │ Free Energy Model: -13.8175 │ Learning Rate: 0.00971
# Epoch 245/2000 │ Loss: -0.0216 │ Chain Modes: 82 │ Free Energy Model: -13.7485 │ Learning Rate: 0.00971
# Epoch 246/2000 │ Loss: +0.0407 │ Chain Modes: 80 │ Free Energy Model: -13.8163 │ Learning Rate: 0.00971
# Epoch 247/2000 │ Loss: -0.0281 │ Chain Modes: 88 │ Free Energy Model: -13.7822 │ Learning Rate: 0.00971
# Epoch 248/2000 │ Loss: -0.0205 │ Chain Modes: 72 │ Free Energy Model: -13.7407 │ Learning Rate: 0.00970
# Epoch 249/2000 │ Loss: +0.0271 │ Chain Modes: 79 │ Free Energy Model: -13.7240 │ Learning Rate: 0.00970
# Epoch 273/2000 │ Loss: +0.0220 │ Chain Modes: 82 │ Free Energy Model: -12.7666 │ Learning Rate: 0.00967
# Epoch 274/2000 │ Loss: -0.0502 │ Chain Modes: 91 │ Free Energy Model: -12.6826 │ Learning Rate: 0.00967
# Epoch 275/2000 │ Loss: +0.0048 │ Chain Modes: 86 │ Free Energy Model: -12.7253 │ Learning Rate: 0.00967
# Epoch 276/2000 │ Loss: +0.0402 │ Chain Modes: 85 │ Free Energy Model: -12.7603 │ Learning Rate: 0.00967
# Epoch 277/2000 │ Loss: -0.0280 │ Chain Modes: 78 │ Free Energy Model: -12.7175 │ Learning Rate: 0.00967
# Epoch 278/2000 │ Loss: -0.0511 │ Chain Modes: 93 │ Free Energy Model: -12.7007 │ Learning Rate: 0.00966
# Epoch 279/2000 │ Loss: +0.0322 │ Chain Modes: 80 │ Free Energy Model: -12.5938 │ Learning Rate: 0.00966
# Epoch 280/2000 │ Loss: -0.0025 │ Chain Modes: 89 │ Free Energy Model: -12.5665 │ Learning Rate: 0.00966
# Epoch 281/2000 │ Loss: -0.0156 │ Chain Modes: 86 │ Free Energy Model: -12.5225 │ Learning Rate: 0.00966
# Epoch 282/2000 │ Loss: +0.0097 │ Chain Modes: 85 │ Free Energy Model: -12.4148 │ Learning Rate: 0.00966
# Epoch 283/2000 │ Loss: -0.0437 │ Chain Modes: 85 │ Free Energy Model: -12.4009 │ Learning Rate: 0.00966
# Epoch 284/2000 │ Loss: +0.0164 │ Chain Modes: 82 │ Free Energy Model: -12.3902 │ Learning Rate: 0.00965
# Epoch 285/2000 │ Loss: +0.0250 │ Chain Modes: 89 │ Free Energy Model: -12.3683 │ Learning Rate: 0.00965
# Epoch 286/2000 │ Loss: -0.0271 │ Chain Modes: 79 │ Free Energy Model: -12.3611 │ Learning Rate: 0.00965
# Epoch 287/2000 │ Loss: -0.0205 │ Chain Modes: 94 │ Free Energy Model: -12.1940 │ Learning Rate: 0.00965
# Epoch 288/2000 │ Loss: +0.0003 │ Chain Modes: 88 │ Free Energy Model: -12.3197 │ Learning Rate: 0.00965
# Epoch 289/2000 │ Loss: +0.0267 │ Chain Modes: 74 │ Free Energy Model: -12.2995 │ Learning Rate: 0.00965
# Epoch 290/2000 │ Loss: -0.0468 │ Chain Modes: 85 │ Free Energy Model: -12.1493 │ Learning Rate: 0.00965
# Epoch 291/2000 │ Loss: -0.0061 │ Chain Modes: 84 │ Free Energy Model: -12.1290 │ Learning Rate: 0.00964
# Epoch 292/2000 │ Loss: +0.0155 │ Chain Modes: 85 │ Free Energy Model: -12.0627 │ Learning Rate: 0.00964
# Epoch 293/2000 │ Loss: -0.0233 │ Chain Modes: 87 │ Free Energy Model: -11.9639 │ Learning Rate: 0.00964
# Epoch 294/2000 │ Loss: +0.0163 │ Chain Modes: 78 │ Free Energy Model: -12.0780 │ Learning Rate: 0.00964
# Epoch 295/2000 │ Loss: -0.0068 │ Chain Modes: 79 │ Free Energy Model: -12.0164 │ Learning Rate: 0.00964
# Epoch 296/2000 │ Loss: -0.0150 │ Chain Modes: 78 │ Free Energy Model: -11.9912 │ Learning Rate: 0.00964
# Epoch 297/2000 │ Loss: -0.0151 │ Chain Modes: 82 │ Free Energy Model: -11.8728 │ Learning Rate: 0.00963
# Epoch 298/2000 │ Loss: +0.0127 │ Chain Modes: 79 │ Free Energy Model: -11.8625 │ Learning Rate: 0.00963
# Epoch 299/2000 │ Loss: -0.0114 │ Chain Modes: 74 │ Free Energy Model: -11.8910 │ Learning Rate: 0.00963
# Epoch 300/2000 │ Loss: -0.0089 │ Chain Modes: 83 │ Free Energy Model: -11.6892 │ Learning Rate: 0.00963
# Epoch 301/2000 │ Loss: -0.0176 │ Chain Modes: 89 │ Free Energy Model: -11.6688 │ Learning Rate: 0.00963
# Epoch 302/2000 │ Loss: +0.0026 │ Chain Modes: 89 │ Free Energy Model: -11.6715 │ Learning Rate: 0.00963
# Epoch 303/2000 │ Loss: -0.0103 │ Chain Modes: 90 │ Free Energy Model: -11.5927 │ Learning Rate: 0.00963
# Epoch 304/2000 │ Loss: -0.0009 │ Chain Modes: 90 │ Free Energy Model: -11.4855 │ Learning Rate: 0.00962
# Epoch 305/2000 │ Loss: -0.0236 │ Chain Modes: 85 │ Free Energy Model: -11.5622 │ Learning Rate: 0.00962
# Epoch 306/2000 │ Loss: +0.0243 │ Chain Modes: 84 │ Free Energy Model: -11.4921 │ Learning Rate: 0.00962
# Epoch 307/2000 │ Loss: -0.0291 │ Chain Modes: 88 │ Free Energy Model: -11.4016 │ Learning Rate: 0.00962
# Epoch 308/2000 │ Loss: -0.0058 │ Chain Modes: 93 │ Free Energy Model: -11.4265 │ Learning Rate: 0.00962
# Epoch 309/2000 │ Loss: -0.0117 │ Chain Modes: 81 │ Free Energy Model: -11.3612 │ Learning Rate: 0.00962
# Epoch 310/2000 │ Loss: +0.0283 │ Chain Modes: 86 │ Free Energy Model: -11.4150 │ Learning Rate: 0.00961
# Epoch 311/2000 │ Loss: -0.0256 │ Chain Modes: 92 │ Free Energy Model: -11.2860 │ Learning Rate: 0.00961
# Epoch 312/2000 │ Loss: -0.0356 │ Chain Modes: 78 │ Free Energy Model: -11.2911 │ Learning Rate: 0.00961
# Epoch 313/2000 │ Loss: +0.0346 │ Chain Modes: 81 │ Free Energy Model: -11.2648 │ Learning Rate: 0.00961
# Epoch 314/2000 │ Loss: -0.0220 │ Chain Modes: 88 │ Free Energy Model: -11.1213 │ Learning Rate: 0.00961
# Epoch 315/2000 │ Loss: -0.0242 │ Chain Modes: 84 │ Free Energy Model: -11.1666 │ Learning Rate: 0.00961
# Epoch 316/2000 │ Loss: +0.0327 │ Chain Modes: 89 │ Free Energy Model: -11.0428 │ Learning Rate: 0.00960
# Epoch 317/2000 │ Loss: -0.0075 │ Chain Modes: 81 │ Free Energy Model: -11.1358 │ Learning Rate: 0.00960
# Epoch 318/2000 │ Loss: -0.0247 │ Chain Modes: 89 │ Free Energy Model: -10.9991 │ Learning Rate: 0.00960
# Epoch 319/2000 │ Loss: +0.0077 │ Chain Modes: 88 │ Free Energy Model: -11.0020 │ Learning Rate: 0.00960
# Epoch 320/2000 │ Loss: +0.0154 │ Chain Modes: 88 │ Free Energy Model: -10.9280 │ Learning Rate: 0.00960
# Epoch 321/2000 │ Loss: -0.0553 │ Chain Modes: 86 │ Free Energy Model: -10.7506 │ Learning Rate: 0.00960
# Epoch 322/2000 │ Loss: +0.0182 │ Chain Modes: 86 │ Free Energy Model: -10.8163 │ Learning Rate: 0.00959
# Epoch 323/2000 │ Loss: +0.0149 │ Chain Modes: 81 │ Free Energy Model: -10.7323 │ Learning Rate: 0.00959
# Epoch 324/2000 │ Loss: -0.0339 │ Chain Modes: 82 │ Free Energy Model: -10.7026 │ Learning Rate: 0.00959
# Epoch 325/2000 │ Loss: -0.0085 │ Chain Modes: 87 │ Free Energy Model: -10.6932 │ Learning Rate: 0.00959
# Epoch 326/2000 │ Loss: +0.0357 │ Chain Modes: 79 │ Free Energy Model: -10.6384 │ Learning Rate: 0.00959
# Epoch 327/2000 │ Loss: -0.0277 │ Chain Modes: 79 │ Free Energy Model: -10.5849 │ Learning Rate: 0.00958
# Epoch 328/2000 │ Loss: -0.0234 │ Chain Modes: 84 │ Free Energy Model: -10.5155 │ Learning Rate: 0.00958
# Epoch 329/2000 │ Loss: +0.0233 │ Chain Modes: 83 │ Free Energy Model: -10.4784 │ Learning Rate: 0.00958
# Epoch 330/2000 │ Loss: -0.0093 │ Chain Modes: 81 │ Free Energy Model: -10.4212 │ Learning Rate: 0.00958
# Epoch 331/2000 │ Loss: -0.0089 │ Chain Modes: 73 │ Free Energy Model: -10.5519 │ Learning Rate: 0.00958
# Epoch 332/2000 │ Loss: -0.0153 │ Chain Modes: 82 │ Free Energy Model: -10.3623 │ Learning Rate: 0.00958
# Epoch 333/2000 │ Loss: +0.0049 │ Chain Modes: 84 │ Free Energy Model: -10.3342 │ Learning Rate: 0.00957
# Epoch 334/2000 │ Loss: +0.0051 │ Chain Modes: 83 │ Free Energy Model: -10.2083 │ Learning Rate: 0.00957
# Epoch 335/2000 │ Loss: -0.0177 │ Chain Modes: 74 │ Free Energy Model: -10.2734 │ Learning Rate: 0.00957
# Epoch 336/2000 │ Loss: -0.0055 │ Chain Modes: 92 │ Free Energy Model: -10.0837 │ Learning Rate: 0.00957
# Epoch 337/2000 │ Loss: -0.0188 │ Chain Modes: 86 │ Free Energy Model: -10.0780 │ Learning Rate: 0.00957
# Epoch 338/2000 │ Loss: +0.0173 │ Chain Modes: 77 │ Free Energy Model: -10.1860 │ Learning Rate: 0.00956
# Epoch 339/2000 │ Loss: +0.0055 │ Chain Modes: 89 │ Free Energy Model: -9.9959 │ Learning Rate: 0.00956
# Epoch 340/2000 │ Loss: -0.0309 │ Chain Modes: 87 │ Free Energy Model: -9.9565 │ Learning Rate: 0.00956
# Epoch 341/2000 │ Loss: -0.0186 │ Chain Modes: 89 │ Free Energy Model: -9.8134 │ Learning Rate: 0.00956
# Epoch 342/2000 │ Loss: +0.0204 │ Chain Modes: 82 │ Free Energy Model: -9.9351 │ Learning Rate: 0.00956
# Epoch 343/2000 │ Loss: -0.0373 │ Chain Modes: 89 │ Free Energy Model: -9.7596 │ Learning Rate: 0.00956
# Epoch 344/2000 │ Loss: -0.0105 │ Chain Modes: 85 │ Free Energy Model: -9.6721 │ Learning Rate: 0.00955
# Epoch 345/2000 │ Loss: +0.0033 │ Chain Modes: 80 │ Free Energy Model: -9.6754 │ Learning Rate: 0.00955
# Epoch 346/2000 │ Loss: +0.0276 │ Chain Modes: 82 │ Free Energy Model: -9.6911 │ Learning Rate: 0.00955
# Epoch 347/2000 │ Loss: -0.0185 │ Chain Modes: 90 │ Free Energy Model: -9.5524 │ Learning Rate: 0.00955
# Epoch 348/2000 │ Loss: -0.0022 │ Chain Modes: 88 │ Free Energy Model: -9.6032 │ Learning Rate: 0.00955
# Epoch 349/2000 │ Loss: -0.0408 │ Chain Modes: 85 │ Free Energy Model: -9.5558 │ Learning Rate: 0.00954
# Epoch 350/2000 │ Loss: +0.0242 │ Chain Modes: 80 │ Free Energy Model: -9.5371 │ Learning Rate: 0.00954
# Epoch 351/2000 │ Loss: +0.0076 │ Chain Modes: 81 │ Free Energy Model: -9.4456 │ Learning Rate: 0.00954
# Epoch 352/2000 │ Loss: -0.0276 │ Chain Modes: 84 │ Free Energy Model: -9.3861 │ Learning Rate: 0.00954
# Epoch 353/2000 │ Loss: -0.0399 │ Chain Modes: 80 │ Free Energy Model: -9.3103 │ Learning Rate: 0.00954
# Epoch 354/2000 │ Loss: +0.0602 │ Chain Modes: 85 │ Free Energy Model: -9.3055 │ Learning Rate: 0.00953
# Epoch 355/2000 │ Loss: -0.0153 │ Chain Modes: 86 │ Free Energy Model: -9.2858 │ Learning Rate: 0.00953
# Epoch 356/2000 │ Loss: -0.0316 │ Chain Modes: 88 │ Free Energy Model: -9.2299 │ Learning Rate: 0.00953
# Epoch 357/2000 │ Loss: -0.0037 │ Chain Modes: 87 │ Free Energy Model: -9.1374 │ Learning Rate: 0.00953
# Epoch 358/2000 │ Loss: +0.0232 │ Chain Modes: 91 │ Free Energy Model: -9.0565 │ Learning Rate: 0.00953
# Epoch 359/2000 │ Loss: -0.0474 │ Chain Modes: 82 │ Free Energy Model: -9.0503 │ Learning Rate: 0.00952
# Epoch 360/2000 │ Loss: +0.0076 │ Chain Modes: 75 │ Free Energy Model: -9.0579 │ Learning Rate: 0.00952
# Epoch 361/2000 │ Loss: +0.0216 │ Chain Modes: 84 │ Free Energy Model: -8.9652 │ Learning Rate: 0.00952
# Epoch 362/2000 │ Loss: -0.0314 │ Chain Modes: 89 │ Free Energy Model: -8.8922 │ Learning Rate: 0.00952
# Epoch 363/2000 │ Loss: +0.0052 │ Chain Modes: 78 │ Free Energy Model: -8.7940 │ Learning Rate: 0.00952
# Epoch 364/2000 │ Loss: -0.0102 │ Chain Modes: 88 │ Free Energy Model: -8.9077 │ Learning Rate: 0.00951
# Epoch 365/2000 │ Loss: -0.0013 │ Chain Modes: 79 │ Free Energy Model: -8.8114 │ Learning Rate: 0.00951
# Epoch 366/2000 │ Loss: -0.0180 │ Chain Modes: 82 │ Free Energy Model: -8.6707 │ Learning Rate: 0.00951
# Epoch 367/2000 │ Loss: -0.0045 │ Chain Modes: 84 │ Free Energy Model: -8.6080 │ Learning Rate: 0.00951
# Epoch 368/2000 │ Loss: -0.0049 │ Chain Modes: 95 │ Free Energy Model: -8.4943 │ Learning Rate: 0.00951
# Epoch 369/2000 │ Loss: +0.0089 │ Chain Modes: 86 │ Free Energy Model: -8.5991 │ Learning Rate: 0.00950
# Epoch 370/2000 │ Loss: -0.0249 │ Chain Modes: 91 │ Free Energy Model: -8.4767 │ Learning Rate: 0.00950
# Epoch 371/2000 │ Loss: -0.0020 │ Chain Modes: 74 │ Free Energy Model: -8.4316 │ Learning Rate: 0.00950
# Epoch 372/2000 │ Loss: -0.0184 │ Chain Modes: 87 │ Free Energy Model: -8.4436 │ Learning Rate: 0.00950
# Epoch 373/2000 │ Loss: +0.0104 │ Chain Modes: 81 │ Free Energy Model: -8.3430 │ Learning Rate: 0.00949
# Epoch 374/2000 │ Loss: -0.0048 │ Chain Modes: 86 │ Free Energy Model: -8.3332 │ Learning Rate: 0.00949
# Epoch 375/2000 │ Loss: -0.0227 │ Chain Modes: 85 │ Free Energy Model: -8.3255 │ Learning Rate: 0.00949
# Epoch 376/2000 │ Loss: +0.0316 │ Chain Modes: 78 │ Free Energy Model: -8.2073 │ Learning Rate: 0.00949
# Epoch 377/2000 │ Loss: -0.0325 │ Chain Modes: 90 │ Free Energy Model: -8.0995 │ Learning Rate: 0.00949
# Epoch 378/2000 │ Loss: -0.0060 │ Chain Modes: 82 │ Free Energy Model: -8.1549 │ Learning Rate: 0.00948
# Epoch 379/2000 │ Loss: -0.0065 │ Chain Modes: 86 │ Free Energy Model: -7.9720 │ Learning Rate: 0.00948
# Epoch 380/2000 │ Loss: +0.0183 │ Chain Modes: 86 │ Free Energy Model: -7.9735 │ Learning Rate: 0.00948
# Epoch 381/2000 │ Loss: -0.0366 │ Chain Modes: 86 │ Free Energy Model: -7.9313 │ Learning Rate: 0.00948
# Epoch 382/2000 │ Loss: +0.0014 │ Chain Modes: 86 │ Free Energy Model: -7.8703 │ Learning Rate: 0.00947
# Epoch 383/2000 │ Loss: +0.0174 │ Chain Modes: 84 │ Free Energy Model: -7.7999 │ Learning Rate: 0.00947
# Epoch 384/2000 │ Loss: -0.0448 │ Chain Modes: 84 │ Free Energy Model: -7.7006 │ Learning Rate: 0.00947
# Epoch 385/2000 │ Loss: +0.0012 │ Chain Modes: 88 │ Free Energy Model: -7.7227 │ Learning Rate: 0.00947
# Epoch 386/2000 │ Loss: +0.0032 │ Chain Modes: 85 │ Free Energy Model: -7.6562 │ Learning Rate: 0.00947
# Epoch 387/2000 │ Loss: -0.0058 │ Chain Modes: 87 │ Free Energy Model: -7.5740 │ Learning Rate: 0.00946
# Epoch 388/2000 │ Loss: +0.0033 │ Chain Modes: 94 │ Free Energy Model: -7.4466 │ Learning Rate: 0.00946
# Epoch 389/2000 │ Loss: -0.0272 │ Chain Modes: 82 │ Free Energy Model: -7.4758 │ Learning Rate: 0.00946
# Epoch 390/2000 │ Loss: -0.0029 │ Chain Modes: 82 │ Free Energy Model: -7.4707 │ Learning Rate: 0.00946
# Epoch 391/2000 │ Loss: +0.0020 │ Chain Modes: 82 │ Free Energy Model: -7.3667 │ Learning Rate: 0.00945
# Epoch 392/2000 │ Loss: +0.0025 │ Chain Modes: 81 │ Free Energy Model: -7.3209 │ Learning Rate: 0.00945
# Epoch 393/2000 │ Loss: -0.0221 │ Chain Modes: 85 │ Free Energy Model: -7.2780 │ Learning Rate: 0.00945
# Epoch 394/2000 │ Loss: -0.0205 │ Chain Modes: 84 │ Free Energy Model: -7.2088 │ Learning Rate: 0.00945
# Epoch 395/2000 │ Loss: -0.0005 │ Chain Modes: 86 │ Free Energy Model: -7.2044 │ Learning Rate: 0.00945
# Epoch 396/2000 │ Loss: -0.0063 │ Chain Modes: 83 │ Free Energy Model: -7.0759 │ Learning Rate: 0.00944
# Epoch 397/2000 │ Loss: -0.0044 │ Chain Modes: 83 │ Free Energy Model: -6.9758 │ Learning Rate: 0.00944
# Epoch 398/2000 │ Loss: -0.0109 │ Chain Modes: 81 │ Free Energy Model: -7.0655 │ Learning Rate: 0.00944
# Epoch 399/2000 │ Loss: +0.0176 │ Chain Modes: 78 │ Free Energy Model: -7.0259 │ Learning Rate: 0.00944
# Epoch 400/2000 │ Loss: +0.0014 │ Chain Modes: 86 │ Free Energy Model: -6.9073 │ Learning Rate: 0.00943
# Epoch 401/2000 │ Loss: -0.0384 │ Chain Modes: 88 │ Free Energy Model: -6.8436 │ Learning Rate: 0.00943
# Epoch 402/2000 │ Loss: -0.0158 │ Chain Modes: 83 │ Free Energy Model: -6.8166 │ Learning Rate: 0.00943
# Epoch 403/2000 │ Loss: +0.0173 │ Chain Modes: 88 │ Free Energy Model: -6.7243 │ Learning Rate: 0.00943
# Epoch 404/2000 │ Loss: -0.0221 │ Chain Modes: 79 │ Free Energy Model: -6.7185 │ Learning Rate: 0.00942
# Epoch 405/2000 │ Loss: +0.0005 │ Chain Modes: 82 │ Free Energy Model: -6.6875 │ Learning Rate: 0.00942
# Epoch 406/2000 │ Loss: +0.0101 │ Chain Modes: 81 │ Free Energy Model: -6.5449 │ Learning Rate: 0.00942
# Epoch 407/2000 │ Loss: -0.0397 │ Chain Modes: 89 │ Free Energy Model: -6.5121 │ Learning Rate: 0.00942
# Epoch 408/2000 │ Loss: -0.0014 │ Chain Modes: 82 │ Free Energy Model: -6.3553 │ Learning Rate: 0.00941
# Epoch 409/2000 │ Loss: -0.0128 │ Chain Modes: 81 │ Free Energy Model: -6.3863 │ Learning Rate: 0.00941
# Epoch 410/2000 │ Loss: +0.0177 │ Chain Modes: 79 │ Free Energy Model: -6.3074 │ Learning Rate: 0.00941
# Epoch 411/2000 │ Loss: -0.0335 │ Chain Modes: 89 │ Free Energy Model: -6.2194 │ Learning Rate: 0.00941
# Epoch 412/2000 │ Loss: -0.0278 │ Chain Modes: 83 │ Free Energy Model: -6.1587 │ Learning Rate: 0.00940
# Epoch 413/2000 │ Loss: +0.0048 │ Chain Modes: 82 │ Free Energy Model: -6.1741 │ Learning Rate: 0.00940
# Epoch 414/2000 │ Loss: +0.0328 │ Chain Modes: 87 │ Free Energy Model: -6.0978 │ Learning Rate: 0.00940
# Epoch 415/2000 │ Loss: -0.0303 │ Chain Modes: 78 │ Free Energy Model: -6.0029 │ Learning Rate: 0.00940
# Epoch 416/2000 │ Loss: -0.0257 │ Chain Modes: 86 │ Free Energy Model: -5.9241 │ Learning Rate: 0.00939
# Epoch 417/2000 │ Loss: -0.0147 │ Chain Modes: 81 │ Free Energy Model: -5.8928 │ Learning Rate: 0.00939
# Epoch 418/2000 │ Loss: +0.0022 │ Chain Modes: 85 │ Free Energy Model: -5.7628 │ Learning Rate: 0.00939
# Epoch 419/2000 │ Loss: -0.0173 │ Chain Modes: 89 │ Free Energy Model: -5.7703 │ Learning Rate: 0.00939
# Epoch 420/2000 │ Loss: +0.0137 │ Chain Modes: 77 │ Free Energy Model: -5.7967 │ Learning Rate: 0.00938
# Epoch 421/2000 │ Loss: -0.0245 │ Chain Modes: 93 │ Free Energy Model: -5.6368 │ Learning Rate: 0.00938
# Epoch 422/2000 │ Loss: -0.0293 │ Chain Modes: 85 │ Free Energy Model: -5.6048 │ Learning Rate: 0.00938
# Epoch 423/2000 │ Loss: -0.0148 │ Chain Modes: 84 │ Free Energy Model: -5.4764 │ Learning Rate: 0.00938
# Epoch 424/2000 │ Loss: -0.0136 │ Chain Modes: 88 │ Free Energy Model: -5.4967 │ Learning Rate: 0.00937
# Epoch 425/2000 │ Loss: +0.0254 │ Chain Modes: 79 │ Free Energy Model: -5.4674 │ Learning Rate: 0.00937
# Epoch 426/2000 │ Loss: -0.0401 │ Chain Modes: 88 │ Free Energy Model: -5.3727 │ Learning Rate: 0.00937
# Epoch 427/2000 │ Loss: -0.0108 │ Chain Modes: 77 │ Free Energy Model: -5.4398 │ Learning Rate: 0.00937
# Epoch 428/2000 │ Loss: +0.0096 │ Chain Modes: 81 │ Free Energy Model: -5.2792 │ Learning Rate: 0.00936
# Epoch 429/2000 │ Loss: -0.0316 │ Chain Modes: 85 │ Free Energy Model: -5.1308 │ Learning Rate: 0.00936
# Epoch 430/2000 │ Loss: -0.0489 │ Chain Modes: 87 │ Free Energy Model: -5.0365 │ Learning Rate: 0.00936
# Epoch 431/2000 │ Loss: +0.0183 │ Chain Modes: 75 │ Free Energy Model: -5.1643 │ Learning Rate: 0.00935
# Epoch 432/2000 │ Loss: -0.0207 │ Chain Modes: 79 │ Free Energy Model: -5.0610 │ Learning Rate: 0.00935
# Epoch 433/2000 │ Loss: -0.0186 │ Chain Modes: 95 │ Free Energy Model: -4.8976 │ Learning Rate: 0.00935
# Epoch 434/2000 │ Loss: -0.0262 │ Chain Modes: 83 │ Free Energy Model: -4.9717 │ Learning Rate: 0.00935
# Epoch 435/2000 │ Loss: -0.0111 │ Chain Modes: 81 │ Free Energy Model: -4.9227 │ Learning Rate: 0.00934
# Epoch 436/2000 │ Loss: -0.0110 │ Chain Modes: 81 │ Free Energy Model: -4.8627 │ Learning Rate: 0.00934
# Epoch 437/2000 │ Loss: -0.0486 │ Chain Modes: 76 │ Free Energy Model: -4.8247 │ Learning Rate: 0.00934
# Epoch 438/2000 │ Loss: +0.0109 │ Chain Modes: 85 │ Free Energy Model: -4.7100 │ Learning Rate: 0.00934
# Epoch 439/2000 │ Loss: -0.0444 │ Chain Modes: 92 │ Free Energy Model: -4.6056 │ Learning Rate: 0.00933
# Epoch 440/2000 │ Loss: -0.0124 │ Chain Modes: 77 │ Free Energy Model: -4.7123 │ Learning Rate: 0.00933
# Epoch 441/2000 │ Loss: +0.0055 │ Chain Modes: 86 │ Free Energy Model: -4.5831 │ Learning Rate: 0.00933
# Epoch 442/2000 │ Loss: -0.0590 │ Chain Modes: 81 │ Free Energy Model: -4.5148 │ Learning Rate: 0.00932
# Epoch 443/2000 │ Loss: -0.0278 │ Chain Modes: 90 │ Free Energy Model: -4.4061 │ Learning Rate: 0.00932
# Epoch 444/2000 │ Loss: -0.0180 │ Chain Modes: 80 │ Free Energy Model: -4.4019 │ Learning Rate: 0.00932
# Epoch 445/2000 │ Loss: -0.0003 │ Chain Modes: 80 │ Free Energy Model: -4.5230 │ Learning Rate: 0.00932
# Epoch 446/2000 │ Loss: -0.0332 │ Chain Modes: 78 │ Free Energy Model: -4.4206 │ Learning Rate: 0.00931
# Epoch 447/2000 │ Loss: -0.0374 │ Chain Modes: 91 │ Free Energy Model: -4.3071 │ Learning Rate: 0.00931
# Epoch 448/2000 │ Loss: -0.0133 │ Chain Modes: 80 │ Free Energy Model: -4.3249 │ Learning Rate: 0.00931
# Epoch 449/2000 │ Loss: -0.0359 │ Chain Modes: 87 │ Free Energy Model: -4.1683 │ Learning Rate: 0.00930
# Epoch 450/2000 │ Loss: -0.0372 │ Chain Modes: 82 │ Free Energy Model: -4.2184 │ Learning Rate: 0.00930
# Epoch 451/2000 │ Loss: -0.0338 │ Chain Modes: 82 │ Free Energy Model: -4.1280 │ Learning Rate: 0.00930
# Epoch 452/2000 │ Loss: -0.0172 │ Chain Modes: 88 │ Free Energy Model: -4.1054 │ Learning Rate: 0.00930
# Epoch 453/2000 │ Loss: -0.0492 │ Chain Modes: 80 │ Free Energy Model: -4.0468 │ Learning Rate: 0.00929
# Epoch 454/2000 │ Loss: -0.0253 │ Chain Modes: 80 │ Free Energy Model: -4.1387 │ Learning Rate: 0.00929
# Epoch 455/2000 │ Loss: -0.0192 │ Chain Modes: 81 │ Free Energy Model: -4.0313 │ Learning Rate: 0.00929
# Epoch 456/2000 │ Loss: -0.0693 │ Chain Modes: 76 │ Free Energy Model: -4.0010 │ Learning Rate: 0.00928
# Epoch 457/2000 │ Loss: -0.0234 │ Chain Modes: 78 │ Free Energy Model: -4.0121 │ Learning Rate: 0.00928
# Epoch 458/2000 │ Loss: -0.0205 │ Chain Modes: 86 │ Free Energy Model: -3.9625 │ Learning Rate: 0.00928
# Epoch 1912/2000 │ Loss: -0.0159 │ Chain Modes: 23 │ Free Energy Model: -8.5646 │ Learning Rate: 0.00115
# Epoch 1913/2000 │ Loss: -0.0254 │ Chain Modes: 19 │ Free Energy Model: -8.5834 │ Learning Rate: 0.00115
# Epoch 1914/2000 │ Loss: -0.0147 │ Chain Modes: 23 │ Free Energy Model: -8.5363 │ Learning Rate: 0.00114
# Epoch 1915/2000 │ Loss: -0.0257 │ Chain Modes: 23 │ Free Energy Model: -8.5635 │ Learning Rate: 0.00114
# Epoch 1916/2000 │ Loss: -0.0204 │ Chain Modes: 19 │ Free Energy Model: -8.5819 │ Learning Rate: 0.00114
# Epoch 1917/2000 │ Loss: -0.0216 │ Chain Modes: 19 │ Free Energy Model: -8.5862 │ Learning Rate: 0.00114
# Epoch 1918/2000 │ Loss: -0.0213 │ Chain Modes: 21 │ Free Energy Model: -8.5851 │ Learning Rate: 0.00114
# Epoch 1919/2000 │ Loss: -0.0519 │ Chain Modes: 27 │ Free Energy Model: -8.5256 │ Learning Rate: 0.00114
# Epoch 1920/2000 │ Loss: -0.0280 │ Chain Modes: 23 │ Free Energy Model: -8.5753 │ Learning Rate: 0.00114
# Epoch 1921/2000 │ Loss: -0.0251 │ Chain Modes: 23 │ Free Energy Model: -8.5512 │ Learning Rate: 0.00114
# Epoch 1922/2000 │ Loss: -0.0334 │ Chain Modes: 24 │ Free Energy Model: -8.5392 │ Learning Rate: 0.00114
# Epoch 1923/2000 │ Loss: -0.0152 │ Chain Modes: 19 │ Free Energy Model: -8.5597 │ Learning Rate: 0.00114
# Epoch 1924/2000 │ Loss: -0.0165 │ Chain Modes: 20 │ Free Energy Model: -8.5605 │ Learning Rate: 0.00114
# Epoch 1925/2000 │ Loss: -0.0174 │ Chain Modes: 23 │ Free Energy Model: -8.5494 │ Learning Rate: 0.00114
# Epoch 1926/2000 │ Loss: -0.0220 │ Chain Modes: 19 │ Free Energy Model: -8.5640 │ Learning Rate: 0.00114
# Epoch 1927/2000 │ Loss: -0.0221 │ Chain Modes: 23 │ Free Energy Model: -8.5511 │ Learning Rate: 0.00114
# Epoch 1928/2000 │ Loss: -0.0225 │ Chain Modes: 20 │ Free Energy Model: -8.5685 │ Learning Rate: 0.00114
# Epoch 1929/2000 │ Loss: -0.0384 │ Chain Modes: 21 │ Free Energy Model: -8.5688 │ Learning Rate: 0.00114
# Epoch 1930/2000 │ Loss: -0.0253 │ Chain Modes: 25 │ Free Energy Model: -8.5424 │ Learning Rate: 0.00113
# Epoch 1931/2000 │ Loss: -0.0387 │ Chain Modes: 21 │ Free Energy Model: -8.5229 │ Learning Rate: 0.00113
# Epoch 1932/2000 │ Loss: -0.0127 │ Chain Modes: 19 │ Free Energy Model: -8.5849 │ Learning Rate: 0.00113
# Epoch 1933/2000 │ Loss: -0.0208 │ Chain Modes: 23 │ Free Energy Model: -8.5588 │ Learning Rate: 0.00113
# Epoch 1934/2000 │ Loss: -0.0323 │ Chain Modes: 25 │ Free Energy Model: -8.5393 │ Learning Rate: 0.00113
# Epoch 1981/2000 │ Loss: -0.0223 │ Chain Modes: 21 │ Free Energy Model: -8.5833 │ Learning Rate: 0.00111
# Epoch 1982/2000 │ Loss: -0.0192 │ Chain Modes: 21 │ Free Energy Model: -8.5465 │ Learning Rate: 0.00111
# Epoch 1983/2000 │ Loss: -0.0213 │ Chain Modes: 20 │ Free Energy Model: -8.5684 │ Learning Rate: 0.00111
# Epoch 1984/2000 │ Loss: -0.0293 │ Chain Modes: 22 │ Free Energy Model: -8.5599 │ Learning Rate: 0.00111
# Epoch 1985/2000 │ Loss: -0.0232 │ Chain Modes: 23 │ Free Energy Model: -8.5675 │ Learning Rate: 0.00111
# Epoch 1986/2000 │ Loss: -0.0207 │ Chain Modes: 23 │ Free Energy Model: -8.5804 │ Learning Rate: 0.00111
# Epoch 1987/2000 │ Loss: -0.0102 │ Chain Modes: 24 │ Free Energy Model: -8.5574 │ Learning Rate: 0.00110
# Epoch 1988/2000 │ Loss: -0.0274 │ Chain Modes: 25 │ Free Energy Model: -8.5533 │ Learning Rate: 0.00110
# Epoch 1989/2000 │ Loss: -0.0257 │ Chain Modes: 18 │ Free Energy Model: -8.5986 │ Learning Rate: 0.00110
# Epoch 1990/2000 │ Loss: -0.0313 │ Chain Modes: 24 │ Free Energy Model: -8.5665 │ Learning Rate: 0.00110
# Epoch 1991/2000 │ Loss: -0.0298 │ Chain Modes: 21 │ Free Energy Model: -8.5424 │ Learning Rate: 0.00110
# Epoch 1992/2000 │ Loss: -0.0227 │ Chain Modes: 18 │ Free Energy Model: -8.5955 │ Learning Rate: 0.00110
# Epoch 1993/2000 │ Loss: -0.0336 │ Chain Modes: 22 │ Free Energy Model: -8.5266 │ Learning Rate: 0.00110
# Epoch 1994/2000 │ Loss: -0.0278 │ Chain Modes: 23 │ Free Energy Model: -8.5544 │ Learning Rate: 0.00110
# Epoch 1995/2000 │ Loss: -0.0410 │ Chain Modes: 24 │ Free Energy Model: -8.5365 │ Learning Rate: 0.00110
# Epoch 1996/2000 │ Loss: -0.0220 │ Chain Modes: 22 │ Free Energy Model: -8.5731 │ Learning Rate: 0.00110
# Epoch 1997/2000 │ Loss: -0.0251 │ Chain Modes: 23 │ Free Energy Model: -8.5669 │ Learning Rate: 0.00110
# Epoch 1998/2000 │ Loss: -0.0278 │ Chain Modes: 21 │ Free Energy Model: -8.5538 │ Learning Rate: 0.00110
# Epoch 1999/2000 │ Loss: -0.0179 │ Chain Modes: 19 │ Free Energy Model: -8.5892 │ Learning Rate: 0.00110
# Epoch 2000/2000 │ Loss: -0.0341 │ Chain Modes: 27 │ Free Energy Model: -8.5259 │ Learning Rate: 0.00110

# %%
epochs = list(metrics.keys())

loss_vals = [metrics[e]['loss'] for e in epochs]
mode_vals = [metrics[e]['modes'] for e in epochs]
free_energy_model_vals = [metrics[e]['free_energy_model'] for e in epochs]
lr_vals = [metrics[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots()

ax1.set_xlabel("Epoch")

ax1.plot(epochs, loss_vals, label="Amplitude CD Loss", color="tab:blue")
ax1.set_ylabel("CD Loss", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

ax2 = ax1.twinx()
ax2.spines["right"].set_position(("axes", 1.05))
ax2.plot(epochs, free_energy_model_vals, label="Free Energy Model", color="tab:orange")
ax2.set_ylabel("Free Energy Model", color="tab:orange")
ax2.tick_params(axis="y", labelcolor="tab:orange")

ax3 = ax1.twinx()
ax3.spines["right"].set_position(("axes", 1.2))
ax3.plot(epochs, mode_vals, color="tab:green")
ax3.set_ylabel("Mode Count", color="tab:green")
ax3.tick_params(axis="y", labelcolor="tab:green")

ax4 = ax1.twinx()
ax4.spines["right"].set_position(("axes", 1.4))
ax4.plot(epochs, lr_vals,color="tab:red")
ax4.set_ylabel("Learning Rate", color="tab:red")
ax4.tick_params(axis="y", labelcolor="tab:red")

plt.title("Training curve for vanilla RBM")
plt.show()

# %%
# shifting the center step to 0 we can approximate an exponential schedule if we choose the high to be
T_high = 2.0
T_low = 0.01
sampling_steps = 5_000
sigmoid_schedule_fn = get_sigmoid_curve(high=T_high*2, low=T_low, steps=sampling_steps, falloff=0.0013, center_step=0)
sigmoid_schedule = jnp.array([sigmoid_schedule_fn(i) for i in range(sampling_steps)], dtype=jnp.float32)

key_sample = PRNGKey(1234)

samples = model.apply(
    {"params": state.params},
    num_samples=10_000,
    T_schedule=sigmoid_schedule,
    key=key_sample,
    method=RBM.generate
)

sampled_freq = samples.mean(0)
sampled_freq
# Out:
# Array([0.1286    , 0.1371    , 0.1169    , 0.1074    , 0.1397    ,
#        0.1319    , 0.11629999, 0.1221    ], dtype=float32)

# %%
spin_counts = samples.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(12), align='left', edgecolor='black')
plt.xticks(range(11))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
plt.figure(figsize=(10, 5))
x = jnp.arange(num_visible) + 1

width = 0.35

plt.bar(x - width/2, empirical_freq, width, label="Empirical", alpha=0.7)
plt.bar(x + width/2, sampled_freq, width, label="Sampled", alpha=0.7)

plt.axhline(1 / num_visible, linestyle='--', color='gray', label=f'1/{num_visible} reference')
plt.xlabel("Visible Unit Index")
plt.ylabel("Mean Activation Frequency")
plt.ylim(0, 0.15)
plt.title("Comparison: Empirical vs Sampled Frequencies")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# during phase training we will at most encounter k-hot vectors with k <= 3

def make_k_hot(n, k):
    return jnp.array([jnp.array([1 if i in idxs else 0 for i in range(n)]) for idxs in combinations(range(n), k)], dtype=jnp.float32)

k_hot_vectors = jnp.concatenate([make_k_hot(num_visible, k) for k in range(4)], axis=0)

fe_k_hot = model.apply({'params': state.params}, method=model._free_energy, v=k_hot_vectors)
fe_k_hot = jnp.squeeze(fe_k_hot)
min_fe_k_hot = jnp.min(fe_k_hot)
max_fe_k_hot = jnp.max(fe_k_hot)

print(f"min energy: {min_fe_k_hot:6f}, max energy: {max_fe_k_hot:6f}")
# Out:
# min energy: -8.730392, max energy: 3.766863
