# %%
import os
import numpy as np

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import flax.linen as nn
import optax
from flax.training import train_state

import functools

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches


data_dir = "./data"
device = jax.devices('cpu')[0]

print(f"Data resides in        : {data_dir}")
print(f"Training model on      : {str(device)}")
# Out:
# Data resides in        : ./data
# Training model on      : TFRT_CPU_0

# %%
def z_meas_to_binary(line: str) -> np.ndarray:
    binary_array = [c == "Z" for c in line.strip()]
    return np.array(binary_array, dtype=np.float32).reshape(-1)

data_file = os.path.join(data_dir, "w_vanilla_20_20000.txt")

with open(data_file) as f:
    data = np.stack([z_meas_to_binary(l) for l in f])

print(f"Loaded {len(data)} samples, each of length {data.shape[1]} into numpy array of type {data.dtype}.")

num_train_samples = 20_000
rng = PRNGKey(0)

data_subset = jax.random.choice(rng, data, (num_train_samples,), replace=False)

print(f"Subset shape: {data_subset.shape}")
# Out:
# Loaded 20000 samples, each of length 20 into numpy array of type float32.
# Subset shape: (20000, 20)

# %%
cols = 10
rows = data_subset.shape[0] // cols
panel_width = data_subset.shape[1]
spacer = 4
left_padding = 10
right_padding = 10

canvas_width = (left_padding + cols * panel_width + (cols - 1) * spacer + right_padding)

bright_red = "darkred"
dark_red = "#ffcccc"
flip_red_cmap = ListedColormap([bright_red, dark_red])
flip_red_cmap.set_bad("white")

canvas = np.full((rows, canvas_width), np.nan, dtype=np.float32)
for i in range(cols):
    start_x = left_padding + i * (panel_width + spacer)
    block = data_subset[i * rows:(i + 1) * rows, :]
    canvas[:, start_x:start_x + panel_width] = block

plt.figure(figsize=(12, 6))
img = plt.imshow(canvas, cmap=flip_red_cmap, interpolation='nearest', aspect='auto')
plt.axis('off')

dark_patch = mpatches.Patch(color=dark_red, label="1 (+Z)")
bright_patch = mpatches.Patch(color=bright_red, label="0 (−Z)")
plt.legend(
    handles=[dark_patch, bright_patch],
    loc="center right",
    bbox_to_anchor=(1.1, 0.5),
    frameon=False
)

plt.tight_layout()
plt.show()

# %%
# get rel frequency of up-spin on each site
rel_freq = data_subset.mean(0)
rel_freq
# Out:
# Array([0.04875, 0.0508 , 0.0493 , 0.0521 , 0.0491 , 0.04615, 0.04855,
#        0.0492 , 0.0504 , 0.0507 , 0.052  , 0.05445, 0.0466 , 0.0513 ,
#        0.0496 , 0.05005, 0.0507 , 0.0497 , 0.0495 , 0.05105],      dtype=float32)

# %%
class DataLoader:
    def __init__(self, dataset, batch_size=128, shuffle=True, drop_last=False):
        self.x         = dataset
        self.bs        = batch_size
        self.shuffle   = shuffle
        self.drop_last = drop_last

        n_samples = len(self.x)
        self.idx_slices = [
            (i, i + batch_size)
            for i in range(0, n_samples, batch_size)
            if not drop_last or i + batch_size <= n_samples
        ]

    def __iter__(self):
        order = np.arange(len(self.x))
        if self.shuffle:
            np.random.shuffle(order)
        for s, e in self.idx_slices:
            yield self.x[order[s:e]]

    def __len__(self):
        return len(self.idx_slices)

# %%
class RBM(nn.Module):
    n_visible: int
    n_hidden: int
    k: int = 1

    @nn.compact
    def __call__(self, data_batch: jnp.ndarray, v_persistent: jnp.ndarray, rng: PRNGKey) -> (jnp.ndarray, jnp.ndarray):
        # in flax, __call__ is the main computation to be differentiated.

        # initialize parameters in @nn.compact style:
        W = self.param("W", nn.initializers.normal(0.01), (self.n_visible, self.n_hidden))
        b = self.param("b", nn.initializers.zeros,        (self.n_visible,))
        c = self.param("c", nn.initializers.zeros,        (self.n_hidden,))
        params = {"W": W, "b": b, "c": c}

        # gibbs sampling only refines the fantasy particles, we are actually not interested in the gradients
        v_k, key = self._gibbs_sample(params, v_persistent, rng, k=self.k)
        v_k = jax.lax.stop_gradient(v_k)

        # we are interested in the gradients of the free energy w.r.t. the parameters
        free_energy_data  = self._free_energy(params, data_batch)
        free_energy_model = self._free_energy(params, v_k)

        pcd_loss = jnp.mean(free_energy_data) - jnp.mean(free_energy_model)
        # since this is a pcd loss function, we also return the updated fantasy particles. and we also pass through the key
        # since JAX’s tree utilities flatten nested tuples we need to wrap the auxiliary variables in a container
        aux_vars = {"v_persistent": v_k, "key": key}

        return pcd_loss, aux_vars

    @staticmethod
    def _free_energy(params, v):
        W, b, c = params["W"], params["b"], params["c"]

        visible_term = jnp.dot(v, b)
        hidden_term  = jnp.sum(jax.nn.softplus(v @ W + c), axis=-1)
        free_energy = -visible_term - hidden_term
        return free_energy

    @staticmethod
    def _gibbs_step(i, state, params, T=1.0):
        v, key = state
        W, b, c = params["W"], params["b"], params["c"]

        # splitting generates different random numbers for each step, one of them is passed on
        key, h_key, v_key = jax.random.split(key, 3)

        h_logits = (v @ W + c) / T
        h_probs = jax.nn.sigmoid(h_logits)
        h = jax.random.bernoulli(h_key, h_probs).astype(jnp.float32)

        v_logits = (h @ W.T + b) / T
        v_probs = jax.nn.sigmoid(v_logits)
        v = jax.random.bernoulli(v_key, v_probs).astype(jnp.float32)
        return v, key

    @staticmethod
    def _gibbs_sample(params, v_init, rng, k=1, T=1.0):
        # the fori_loop enables JIT compilation of loops. It basically unrolls the loop over the fixed length k.

        body_fun = lambda i, state: RBM._gibbs_step(i, state, params, T)
        v_final, key = jax.lax.fori_loop(0, k, body_fun, (v_init, rng))
        return v_final, key

    @staticmethod
    def _annealing_step(i, state, params, T_schedule):
        v, rng = state
        T = T_schedule[i]
        # Perform one Gibbs step using the current temperature T.
        # Note: _gibbs_sample already handles k=1 and T
        v_next, rng_next = RBM._gibbs_sample(params, v, rng, k=1, T=T)
        return (v_next, rng_next)

    # the nowrap attribute basically tells JAX to not do the magic wrapping, which injects the params argument
    @nn.nowrap
    def generate(self, params: dict, n_samples: int, T_schedule: jnp.ndarray, rng: PRNGKey) -> jnp.ndarray:

        # get the initial state and perform initial key splitting
        rng, init_key = jax.random.split(rng)
        v = jax.random.bernoulli(init_key, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)
        init_state = (v, rng)

        body_fun = lambda i, state: RBM._gibbs_step(i, state, params, T_schedule[i])

        # the fori_loop is still required, since this function will also be JIT-compiled
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), body_fun, init_state)
        return v_final

# %%
class RBMTrainState(train_state.TrainState):
    """
    A value object bundling parameters and optimizer state for training.
    It has a few pre-defined fields to be used in the training loop.
    Since it is immutable, the training function needs to return a new instance after each update step.
    """
    pass


@functools.partial(jax.jit)
def train_step(state: RBMTrainState, data_batch: jnp.ndarray, v_persistent: jnp.ndarray, key: PRNGKey):

    # only the 'params' argument remains a variable to be differentiated
    pcd_loss_fn = lambda params: state.apply_fn({'params': params}, data_batch, v_persistent, key)

    # since our pc_loss_fn also returns the updated fantasy particles, we need to use has_aux=True
    value_and_grad_fn = jax.value_and_grad(pcd_loss_fn, has_aux=True)
    (pcd_loss, aux_vars), pdc_loss_grads = value_and_grad_fn(state.params)

    # apply the gradients to the state, this actually updates the optimizer state
    new_state = state.apply_gradients(grads=pdc_loss_grads)
    v_persistent = aux_vars["v_persistent"]
    key = aux_vars["key"]

    return new_state, pcd_loss, v_persistent, key


def train_rbm(state: RBMTrainState, train_loader, num_epochs: int, rng: PRNGKey, pcd_reset: int = 5, scheduler=None):
    metrics = {}

    for epoch in range(num_epochs):
        total_loss = 0.0
        batch_count = 0

        for batch_idx, data in enumerate(train_loader):

            if batch_idx % pcd_reset == 0:
                rng, subkey = jax.random.split(rng)
                v_persistent = jax.random.bernoulli(subkey, p=0.5, shape=data.shape).astype(jnp.float32)

            state, loss, v_persistent, rng = train_step(state, data, v_persistent, rng)
            total_loss += loss
            batch_count += 1

        avg_loss = total_loss / len(train_loader)
        metrics[epoch] = {"free_energy_loss": float(avg_loss)}
        print(f"Epoch [{epoch+1}/{num_epochs}] - Free Energy Loss: {avg_loss:.4f}")

    return state, metrics, rng

# %%
# ACTUAL TRAINING
batch_size    = 128
visible_units = 20
hidden_units  = 20
k_steps       = 1
lr            = 1e-2
num_epochs    = 300
pcd_reset     = 100
lr_decay      = 0.95


rng = PRNGKey(42)

# instantiate the optimizer and the RBM
train_loader = DataLoader(data_subset, batch_size=batch_size, shuffle=True)

optimizer = optax.adam(learning_rate=lr)
rbm = RBM(n_visible=visible_units, n_hidden=hidden_units, k=k_steps)

# initialize RBM parameters and create the training state
dummy_batch = data_subset[:batch_size]
rng, subkey = jax.random.split(rng)
v_persistent = jax.random.bernoulli(subkey, p=0.5, shape=dummy_batch.shape).astype(jnp.float32)
params = rbm.init(rng, dummy_batch, v_persistent, rng)['params']

state = RBMTrainState.create(apply_fn=rbm.apply, params=params, tx=optimizer)

state, metrics, rng = train_rbm(state, train_loader, num_epochs, rng)
# Out:
# Epoch [1/300] - Free Energy Loss: -2.6024
# Epoch [2/300] - Free Energy Loss: -0.2437
# Epoch [3/300] - Free Energy Loss: -0.1721
# Epoch [4/300] - Free Energy Loss: -0.1146
# Epoch [5/300] - Free Energy Loss: -0.0748
# Epoch [6/300] - Free Energy Loss: -0.0497
# Epoch [7/300] - Free Energy Loss: -0.0413
# Epoch [8/300] - Free Energy Loss: -0.0226
# Epoch [9/300] - Free Energy Loss: -0.0178
# Epoch [10/300] - Free Energy Loss: -0.0306
# Epoch [11/300] - Free Energy Loss: 0.0004
# Epoch [12/300] - Free Energy Loss: -0.0074
# Epoch [13/300] - Free Energy Loss: 0.0040
# Epoch [14/300] - Free Energy Loss: 0.0037
# Epoch [15/300] - Free Energy Loss: 0.0167
# Epoch [16/300] - Free Energy Loss: -0.0026
# Epoch [17/300] - Free Energy Loss: 0.0074
# Epoch [18/300] - Free Energy Loss: 0.0280
# Epoch [19/300] - Free Energy Loss: -0.0009
# Epoch [20/300] - Free Energy Loss: 0.0318
# Epoch [21/300] - Free Energy Loss: 0.0118
# Epoch [22/300] - Free Energy Loss: 0.0176
# Epoch [23/300] - Free Energy Loss: 0.0275
# Epoch [24/300] - Free Energy Loss: 0.0166
# Epoch [25/300] - Free Energy Loss: 0.0212
# Epoch [26/300] - Free Energy Loss: 0.0233
# Epoch [27/300] - Free Energy Loss: 0.0232
# Epoch [28/300] - Free Energy Loss: 0.0294
# Epoch [29/300] - Free Energy Loss: 0.0245
# Epoch [30/300] - Free Energy Loss: 0.0081
# Epoch [31/300] - Free Energy Loss: 0.0286
# Epoch [32/300] - Free Energy Loss: 0.0324
# Epoch [33/300] - Free Energy Loss: 0.0205
# Epoch [34/300] - Free Energy Loss: 0.0254
# Epoch [35/300] - Free Energy Loss: 0.0285
# Epoch [36/300] - Free Energy Loss: 0.0184
# Epoch [37/300] - Free Energy Loss: 0.0390
# Epoch [38/300] - Free Energy Loss: 0.0275
# Epoch [39/300] - Free Energy Loss: 0.0087
# Epoch [40/300] - Free Energy Loss: 0.0339
# Epoch [41/300] - Free Energy Loss: 0.0148
# Epoch [42/300] - Free Energy Loss: 0.0243
# Epoch [43/300] - Free Energy Loss: 0.0073
# Epoch [44/300] - Free Energy Loss: 0.0102
# Epoch [45/300] - Free Energy Loss: 0.0164
# Epoch [46/300] - Free Energy Loss: -0.0022
# Epoch [47/300] - Free Energy Loss: -0.0018
# Epoch [48/300] - Free Energy Loss: -0.0033
# Epoch [49/300] - Free Energy Loss: -0.0195
# Epoch [50/300] - Free Energy Loss: -0.0006
# Epoch [51/300] - Free Energy Loss: -0.0152
# Epoch [52/300] - Free Energy Loss: -0.0162
# Epoch [53/300] - Free Energy Loss: -0.0305
# Epoch [54/300] - Free Energy Loss: -0.0169
# Epoch [55/300] - Free Energy Loss: -0.0174
# Epoch [56/300] - Free Energy Loss: -0.0392
# Epoch [57/300] - Free Energy Loss: -0.0144
# Epoch [58/300] - Free Energy Loss: -0.0267
# Epoch [59/300] - Free Energy Loss: -0.0227
# Epoch [60/300] - Free Energy Loss: 0.0008
# Epoch [61/300] - Free Energy Loss: -0.0002
# Epoch [62/300] - Free Energy Loss: -0.0043
# Epoch [63/300] - Free Energy Loss: 0.0003
# Epoch [64/300] - Free Energy Loss: -0.0047
# Epoch [65/300] - Free Energy Loss: 0.0040
# Epoch [66/300] - Free Energy Loss: 0.0004
# Epoch [67/300] - Free Energy Loss: 0.0038
# Epoch [68/300] - Free Energy Loss: 0.0137
# Epoch [69/300] - Free Energy Loss: 0.0113
# Epoch [70/300] - Free Energy Loss: -0.0208
# Epoch [71/300] - Free Energy Loss: 0.0229
# Epoch [72/300] - Free Energy Loss: 0.0188
# Epoch [73/300] - Free Energy Loss: -0.0254
# Epoch [74/300] - Free Energy Loss: 0.0214
# Epoch [75/300] - Free Energy Loss: 0.0002
# Epoch [76/300] - Free Energy Loss: 0.0082
# Epoch [77/300] - Free Energy Loss: 0.0051
# Epoch [78/300] - Free Energy Loss: 0.0055
# Epoch [79/300] - Free Energy Loss: 0.0003
# Epoch [80/300] - Free Energy Loss: 0.0121
# Epoch [81/300] - Free Energy Loss: -0.0021
# Epoch [82/300] - Free Energy Loss: 0.0096
# Epoch [83/300] - Free Energy Loss: 0.0015
# Epoch [84/300] - Free Energy Loss: 0.0130
# Epoch [85/300] - Free Energy Loss: -0.0091
# Epoch [86/300] - Free Energy Loss: 0.0162
# Epoch [87/300] - Free Energy Loss: 0.0097
# Epoch [88/300] - Free Energy Loss: -0.0016
# Epoch [89/300] - Free Energy Loss: 0.0046
# Epoch [90/300] - Free Energy Loss: 0.0126
# Epoch [91/300] - Free Energy Loss: -0.0061
# Epoch [92/300] - Free Energy Loss: 0.0036
# Epoch [93/300] - Free Energy Loss: 0.0166
# Epoch [94/300] - Free Energy Loss: 0.0062
# Epoch [95/300] - Free Energy Loss: -0.0141
# Epoch [96/300] - Free Energy Loss: 0.0165
# Epoch [97/300] - Free Energy Loss: 0.0006
# Epoch [98/300] - Free Energy Loss: 0.0122
# Epoch [99/300] - Free Energy Loss: 0.0172
# Epoch [100/300] - Free Energy Loss: -0.0103
# Epoch [101/300] - Free Energy Loss: 0.0113
# Epoch [102/300] - Free Energy Loss: 0.0051
# Epoch [103/300] - Free Energy Loss: -0.0138
# Epoch [104/300] - Free Energy Loss: 0.0107
# Epoch [105/300] - Free Energy Loss: 0.0186
# Epoch [106/300] - Free Energy Loss: 0.0116
# Epoch [107/300] - Free Energy Loss: 0.0029
# Epoch [108/300] - Free Energy Loss: 0.0032
# Epoch [109/300] - Free Energy Loss: 0.0004
# Epoch [110/300] - Free Energy Loss: 0.0185
# Epoch [111/300] - Free Energy Loss: 0.0044
# Epoch [112/300] - Free Energy Loss: 0.0008
# Epoch [113/300] - Free Energy Loss: -0.0020
# Epoch [114/300] - Free Energy Loss: 0.0023
# Epoch [115/300] - Free Energy Loss: 0.0132
# Epoch [116/300] - Free Energy Loss: -0.0048
# Epoch [117/300] - Free Energy Loss: -0.0017
# Epoch [118/300] - Free Energy Loss: 0.0069
# Epoch [119/300] - Free Energy Loss: 0.0113
# Epoch [120/300] - Free Energy Loss: 0.0032
# Epoch [121/300] - Free Energy Loss: -0.0061
# Epoch [122/300] - Free Energy Loss: -0.0095
# Epoch [123/300] - Free Energy Loss: -0.0242
# Epoch [124/300] - Free Energy Loss: -0.0257
# Epoch [125/300] - Free Energy Loss: -0.0284
# Epoch [126/300] - Free Energy Loss: -0.0317
# Epoch [127/300] - Free Energy Loss: -0.0305
# Epoch [128/300] - Free Energy Loss: -0.0440
# Epoch [129/300] - Free Energy Loss: -0.0355
# Epoch [130/300] - Free Energy Loss: -0.0461
# Epoch [131/300] - Free Energy Loss: -0.0382
# Epoch [132/300] - Free Energy Loss: -0.0521
# Epoch [133/300] - Free Energy Loss: -0.0726
# Epoch [134/300] - Free Energy Loss: -0.0063
# Epoch [135/300] - Free Energy Loss: -0.0817
# Epoch [136/300] - Free Energy Loss: -0.1205
# Epoch [137/300] - Free Energy Loss: -0.0995
# Epoch [138/300] - Free Energy Loss: -0.1669
# Epoch [139/300] - Free Energy Loss: -0.2018
# Epoch [140/300] - Free Energy Loss: -0.2150
# Epoch [141/300] - Free Energy Loss: -0.2503
# Epoch [142/300] - Free Energy Loss: -0.2893
# Epoch [143/300] - Free Energy Loss: -0.3335
# Epoch [144/300] - Free Energy Loss: -0.3427
# Epoch [145/300] - Free Energy Loss: -0.3397
# Epoch [146/300] - Free Energy Loss: -0.4372
# Epoch [147/300] - Free Energy Loss: -0.3273
# Epoch [148/300] - Free Energy Loss: -0.5262
# Epoch [149/300] - Free Energy Loss: -0.5438
# Epoch [150/300] - Free Energy Loss: -0.6132
# Epoch [151/300] - Free Energy Loss: -0.6329
# Epoch [152/300] - Free Energy Loss: -0.7634
# Epoch [153/300] - Free Energy Loss: -0.8008
# Epoch [154/300] - Free Energy Loss: -0.9169
# Epoch [155/300] - Free Energy Loss: -0.8598
# Epoch [156/300] - Free Energy Loss: -1.0155
# Epoch [157/300] - Free Energy Loss: -0.9726
# Epoch [158/300] - Free Energy Loss: -1.1304
# Epoch [159/300] - Free Energy Loss: -1.0882
# Epoch [160/300] - Free Energy Loss: -1.2589
# Epoch [161/300] - Free Energy Loss: -1.2503
# Epoch [162/300] - Free Energy Loss: -1.3788
# Epoch [163/300] - Free Energy Loss: -1.4570
# Epoch [164/300] - Free Energy Loss: -1.3857
# Epoch [165/300] - Free Energy Loss: -1.5732
# Epoch [166/300] - Free Energy Loss: -1.5235
# Epoch [167/300] - Free Energy Loss: -1.5524
# Epoch [168/300] - Free Energy Loss: -1.7488
# Epoch [169/300] - Free Energy Loss: -1.7855
# Epoch [170/300] - Free Energy Loss: -1.8181
# Epoch [171/300] - Free Energy Loss: -1.8392
# Epoch [172/300] - Free Energy Loss: -1.9768
# Epoch [173/300] - Free Energy Loss: -1.7937
# Epoch [174/300] - Free Energy Loss: -2.0569
# Epoch [175/300] - Free Energy Loss: -1.9966
# Epoch [176/300] - Free Energy Loss: -2.0850
# Epoch [177/300] - Free Energy Loss: -2.2765
# Epoch [178/300] - Free Energy Loss: -2.2244
# Epoch [179/300] - Free Energy Loss: -2.3839
# Epoch [180/300] - Free Energy Loss: -2.4737
# Epoch [181/300] - Free Energy Loss: -2.4328
# Epoch [182/300] - Free Energy Loss: -2.4707
# Epoch [183/300] - Free Energy Loss: -2.4404
# Epoch [184/300] - Free Energy Loss: -2.7017
# Epoch [185/300] - Free Energy Loss: -2.6831
# Epoch [186/300] - Free Energy Loss: -2.7661
# Epoch [187/300] - Free Energy Loss: -2.6827
# Epoch [188/300] - Free Energy Loss: -2.8723
# Epoch [189/300] - Free Energy Loss: -2.9504
# Epoch [190/300] - Free Energy Loss: -2.9470
# Epoch [191/300] - Free Energy Loss: -3.2597
# Epoch [192/300] - Free Energy Loss: -3.0562
# Epoch [193/300] - Free Energy Loss: -3.1431
# Epoch [194/300] - Free Energy Loss: -3.1547
# Epoch [195/300] - Free Energy Loss: -3.3422
# Epoch [196/300] - Free Energy Loss: -3.4650
# Epoch [197/300] - Free Energy Loss: -3.2739
# Epoch [198/300] - Free Energy Loss: -3.3161
# Epoch [199/300] - Free Energy Loss: -3.6469
# Epoch [200/300] - Free Energy Loss: -3.7307
# Epoch [201/300] - Free Energy Loss: -3.7219
# Epoch [202/300] - Free Energy Loss: -3.7701
# Epoch [203/300] - Free Energy Loss: -3.8807
# Epoch [204/300] - Free Energy Loss: -4.0947
# Epoch [205/300] - Free Energy Loss: -3.8174
# Epoch [206/300] - Free Energy Loss: -4.0792
# Epoch [207/300] - Free Energy Loss: -4.4532
# Epoch [208/300] - Free Energy Loss: -4.2150
# Epoch [209/300] - Free Energy Loss: -4.3930
# Epoch [210/300] - Free Energy Loss: -4.4102
# Epoch [211/300] - Free Energy Loss: -4.4285
# Epoch [212/300] - Free Energy Loss: -4.5149
# Epoch [213/300] - Free Energy Loss: -4.6494
# Epoch [214/300] - Free Energy Loss: -4.5910
# Epoch [215/300] - Free Energy Loss: -4.4667
# Epoch [216/300] - Free Energy Loss: -5.0512
# Epoch [217/300] - Free Energy Loss: -4.8183
# Epoch [218/300] - Free Energy Loss: -4.7035
# Epoch [219/300] - Free Energy Loss: -5.2674
# Epoch [220/300] - Free Energy Loss: -5.0224
# Epoch [221/300] - Free Energy Loss: -5.1292
# Epoch [222/300] - Free Energy Loss: -5.2678
# Epoch [223/300] - Free Energy Loss: -4.9401
# Epoch [224/300] - Free Energy Loss: -5.3954
# Epoch [225/300] - Free Energy Loss: -5.8072
# Epoch [226/300] - Free Energy Loss: -5.5776
# Epoch [227/300] - Free Energy Loss: -5.4764
# Epoch [228/300] - Free Energy Loss: -5.6793
# Epoch [229/300] - Free Energy Loss: -5.5961
# Epoch [230/300] - Free Energy Loss: -5.8132
# Epoch [231/300] - Free Energy Loss: -5.9724
# Epoch [232/300] - Free Energy Loss: -5.9808
# Epoch [233/300] - Free Energy Loss: -6.0654
# Epoch [234/300] - Free Energy Loss: -5.8467
# Epoch [235/300] - Free Energy Loss: -6.2093
# Epoch [236/300] - Free Energy Loss: -6.2106
# Epoch [237/300] - Free Energy Loss: -6.1061
# Epoch [238/300] - Free Energy Loss: -6.5702
# Epoch [239/300] - Free Energy Loss: -6.4478
# Epoch [240/300] - Free Energy Loss: -6.2481
# Epoch [241/300] - Free Energy Loss: -6.3515
# Epoch [242/300] - Free Energy Loss: -6.8822
# Epoch [243/300] - Free Energy Loss: -6.6711
# Epoch [244/300] - Free Energy Loss: -6.8121
# Epoch [245/300] - Free Energy Loss: -6.7231
# Epoch [246/300] - Free Energy Loss: -7.2845
# Epoch [247/300] - Free Energy Loss: -6.9048
# Epoch [248/300] - Free Energy Loss: -7.2606
# Epoch [249/300] - Free Energy Loss: -7.4047
# Epoch [250/300] - Free Energy Loss: -6.9957
# Epoch [251/300] - Free Energy Loss: -6.7584
# Epoch [252/300] - Free Energy Loss: -7.8834
# Epoch [253/300] - Free Energy Loss: -7.5979
# Epoch [254/300] - Free Energy Loss: -7.2229
# Epoch [255/300] - Free Energy Loss: -7.6190
# Epoch [256/300] - Free Energy Loss: -7.9516
# Epoch [257/300] - Free Energy Loss: -7.5829
# Epoch [258/300] - Free Energy Loss: -7.7591
# Epoch [259/300] - Free Energy Loss: -8.1821
# Epoch [260/300] - Free Energy Loss: -7.6163
# Epoch [261/300] - Free Energy Loss: -7.9838
# Epoch [262/300] - Free Energy Loss: -8.3170
# Epoch [263/300] - Free Energy Loss: -8.2631
# Epoch [264/300] - Free Energy Loss: -7.9203
# Epoch [265/300] - Free Energy Loss: -8.6628
# Epoch [266/300] - Free Energy Loss: -8.1980
# Epoch [267/300] - Free Energy Loss: -8.3626
# Epoch [268/300] - Free Energy Loss: -8.8956
# Epoch [269/300] - Free Energy Loss: -8.5458
# Epoch [270/300] - Free Energy Loss: -8.5819
# Epoch [271/300] - Free Energy Loss: -9.0848
# Epoch [272/300] - Free Energy Loss: -8.8158
# Epoch [273/300] - Free Energy Loss: -8.9009
# Epoch [274/300] - Free Energy Loss: -9.3404
# Epoch [275/300] - Free Energy Loss: -8.9778
# Epoch [276/300] - Free Energy Loss: -9.2246
# Epoch [277/300] - Free Energy Loss: -8.6754
# Epoch [278/300] - Free Energy Loss: -9.5094
# Epoch [279/300] - Free Energy Loss: -9.6969
# Epoch [280/300] - Free Energy Loss: -9.4634
# Epoch [281/300] - Free Energy Loss: -9.3089
# Epoch [282/300] - Free Energy Loss: -9.2851
# Epoch [283/300] - Free Energy Loss: -9.2856
# Epoch [284/300] - Free Energy Loss: -10.0894
# Epoch [285/300] - Free Energy Loss: -9.7102
# Epoch [286/300] - Free Energy Loss: -10.0236
# Epoch [287/300] - Free Energy Loss: -9.8325
# Epoch [288/300] - Free Energy Loss: -9.9540
# Epoch [289/300] - Free Energy Loss: -10.0909
# Epoch [290/300] - Free Energy Loss: -10.2112
# Epoch [291/300] - Free Energy Loss: -10.1876
# Epoch [292/300] - Free Energy Loss: -10.3741
# Epoch [293/300] - Free Energy Loss: -10.2071
# Epoch [294/300] - Free Energy Loss: -10.4428
# Epoch [295/300] - Free Energy Loss: -10.6184
# Epoch [296/300] - Free Energy Loss: -10.8333
# Epoch [297/300] - Free Energy Loss: -10.8126
# Epoch [298/300] - Free Energy Loss: -10.7906
# Epoch [299/300] - Free Energy Loss: -10.2414
# Epoch [300/300] - Free Energy Loss: -10.3020

# %%
plt.plot([metrics[epoch]['free_energy_loss'] for epoch in metrics])
plt.xlabel("Epoch")
plt.ylabel("Free Energy Loss")
# Out:
# Text(0, 0.5, 'Free Energy Loss')

# %%
samples = rbm.generate(state.params,
                       n_samples=10_000,
                       T_schedule=jnp.ones(200) * 1.2,
                       rng=rng)
rel_freq = samples.mean(0)
rel_freq
# Out:
# Array([0.        , 0.0762    , 0.        , 0.069     , 0.062     ,
#        0.        , 0.        , 0.        , 0.0743    , 0.063     ,
#        0.074     , 0.07889999, 0.        , 0.0792    , 0.07      ,
#        0.0629    , 0.0652    , 0.0815    , 0.07449999, 0.0693    ],      dtype=float32)

# %%
spin_counts = samples.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(22), align='left', edgecolor='black')
plt.xticks(range(21))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
sites = np.arange(1, visible_units+1)
ax.bar(sites, rel_freq, width=0.8, edgecolor='black', alpha=0.7)
ax.axhline(1/visible_units, color='red', linestyle='--', label=f'Expected = {1/visible_units:.3f}')

ax.set_xlabel('Spin‐site index')
ax.set_ylabel('Relative frequency of up‐spin')
ax.set_title('Training Data: Up‐Spin Occurrence per Site')
ax.set_xticks(sites)
ax.set_ylim(0, rel_freq.max()*1.2)

ax.legend(loc='upper right')
plt.tight_layout()
plt.show()
