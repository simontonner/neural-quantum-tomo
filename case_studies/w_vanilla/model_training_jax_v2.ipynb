# %%
import os
import numpy as np

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import flax.linen as nn
import optax
from flax.training import train_state

import functools

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches


data_dir = "./data"
device = jax.devices('cpu')[0]

print(f"Data resides in        : {data_dir}")
print(f"Training model on      : {str(device)}")
# Out:
# Data resides in        : ./data
# Training model on      : TFRT_CPU_0

# %%
def z_meas_to_binary(line: str) -> np.ndarray:
    binary_array = [c == "Z" for c in line.strip()]
    return np.array(binary_array, dtype=np.float32).reshape(-1)

data_file = os.path.join(data_dir, "w_vanilla_20_20000.txt")

with open(data_file) as f:
    data = np.stack([z_meas_to_binary(l) for l in f])

print(f"Loaded {len(data)} samples, each of length {data.shape[1]} into numpy array of type {data.dtype}.")

num_train_samples = 20_000
rng = PRNGKey(0)

data_subset = jax.random.choice(rng, data, (num_train_samples,), replace=False)

print(f"Subset shape: {data_subset.shape}")
# Out:
# Loaded 20000 samples, each of length 20 into numpy array of type float32.
# Subset shape: (20000, 20)

# %%
cols = 10
rows = data_subset.shape[0] // cols
panel_width = data_subset.shape[1]
spacer = 4
left_padding = 10
right_padding = 10

canvas_width = (left_padding + cols * panel_width + (cols - 1) * spacer + right_padding)

bright_red = "darkred"
dark_red = "#ffcccc"
flip_red_cmap = ListedColormap([bright_red, dark_red])
flip_red_cmap.set_bad("white")

canvas = np.full((rows, canvas_width), np.nan, dtype=np.float32)
for i in range(cols):
    start_x = left_padding + i * (panel_width + spacer)
    block = data_subset[i * rows:(i + 1) * rows, :]
    canvas[:, start_x:start_x + panel_width] = block

plt.figure(figsize=(12, 6))
img = plt.imshow(canvas, cmap=flip_red_cmap, interpolation='nearest', aspect='auto')
plt.axis('off')

dark_patch = mpatches.Patch(color=dark_red, label="1 (+Z)")
bright_patch = mpatches.Patch(color=bright_red, label="0 (−Z)")
plt.legend(
    handles=[dark_patch, bright_patch],
    loc="center right",
    bbox_to_anchor=(1.1, 0.5),
    frameon=False
)

plt.tight_layout()
plt.show()

# %%
# get rel frequency of up-spin on each site
rel_freq = data_subset.mean(0)
rel_freq
# Out:
# Array([0.04875, 0.0508 , 0.0493 , 0.0521 , 0.0491 , 0.04615, 0.04855,
#        0.0492 , 0.0504 , 0.0507 , 0.052  , 0.05445, 0.0466 , 0.0513 ,
#        0.0496 , 0.05005, 0.0507 , 0.0497 , 0.0495 , 0.05105],      dtype=float32)

# %%
class DataLoader:
    def __init__(self, dataset, batch_size=128, shuffle=True, drop_last=False):
        self.x         = dataset
        self.bs        = batch_size
        self.shuffle   = shuffle
        self.drop_last = drop_last

        n_samples = len(self.x)
        self.idx_slices = [
            (i, i + batch_size)
            for i in range(0, n_samples, batch_size)
            if not drop_last or i + batch_size <= n_samples
        ]

    def __iter__(self):
        order = np.arange(len(self.x))
        if self.shuffle:
            np.random.shuffle(order)
        for s, e in self.idx_slices:
            yield self.x[order[s:e]]

    def __len__(self):
        return len(self.idx_slices)

# %%
class RBM(nn.Module):
    n_visible: int
    n_hidden: int
    k: int = 1

    @nn.compact
    def __call__(self, data_batch: jnp.ndarray, v_persistent: jnp.ndarray, rng: PRNGKey) -> (jnp.ndarray, jnp.ndarray):
        # in flax, __call__ is the main computation to be differentiated.

        # initialize parameters in @nn.compact style:
        W = self.param("W", nn.initializers.normal(0.01), (self.n_visible, self.n_hidden))
        b = self.param("b", nn.initializers.zeros,        (self.n_visible,))
        c = self.param("c", nn.initializers.zeros,        (self.n_hidden,))
        params = {"W": W, "b": b, "c": c}

        # gibbs sampling only refines the fantasy particles, we are actually not interested in the gradients
        v_k, key = self._gibbs_sample(params, v_persistent, rng, k=self.k)
        v_k = jax.lax.stop_gradient(v_k)

        # we are interested in the gradients of the free energy w.r.t. the parameters
        free_energy_data  = self._free_energy(params, data_batch)
        free_energy_model = self._free_energy(params, v_k)

        pcd_loss = jnp.mean(free_energy_data) - jnp.mean(free_energy_model)
        # since this is a pcd loss function, we also return the updated fantasy particles. and we also pass through the key
        # since JAX’s tree utilities flatten nested tuples we need to wrap the auxiliary variables in a container
        aux_vars = {"v_persistent": v_k, "key": key}

        return pcd_loss, aux_vars

    @staticmethod
    def _free_energy(params, v):
        W, b, c = params["W"], params["b"], params["c"]

        visible_term = jnp.dot(v, b)
        hidden_term  = jnp.sum(jax.nn.softplus(v @ W + c), axis=-1)
        free_energy = -visible_term - hidden_term
        return free_energy

    @staticmethod
    def _gibbs_step(i, state, params, T=1.0):
        v, key = state
        W, b, c = params["W"], params["b"], params["c"]

        # splitting generates different random numbers for each step, one of them is passed on
        key, h_key, v_key = jax.random.split(key, 3)

        h_logits = (v @ W + c) / T
        h_probs = jax.nn.sigmoid(h_logits)
        h = jax.random.bernoulli(h_key, h_probs).astype(jnp.float32)

        v_logits = (h @ W.T + b) / T
        v_probs = jax.nn.sigmoid(v_logits)
        v = jax.random.bernoulli(v_key, v_probs).astype(jnp.float32)
        return v, key

    @staticmethod
    def _gibbs_sample(params, v_init, rng, k=1, T=1.0):
        # the fori_loop enables JIT compilation of loops. It basically unrolls the loop over the fixed length k.

        body_fun = lambda i, state: RBM._gibbs_step(i, state, params, T)
        v_final, key = jax.lax.fori_loop(0, k, body_fun, (v_init, rng))
        return v_final, key

    @staticmethod
    def _annealing_step(i, state, params, T_schedule):
        v, rng = state
        T = T_schedule[i]
        # Perform one Gibbs step using the current temperature T.
        # Note: _gibbs_sample already handles k=1 and T
        v_next, rng_next = RBM._gibbs_sample(params, v, rng, k=1, T=T)
        return (v_next, rng_next)

    # the nowrap attribute basically tells JAX to not do the magic wrapping, which injects the params argument
    @nn.nowrap
    def generate(self, params: dict, n_samples: int, T_schedule: jnp.ndarray, rng: PRNGKey) -> jnp.ndarray:

        # get the initial state and perform initial key splitting
        rng, init_key = jax.random.split(rng)
        v = jax.random.bernoulli(init_key, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)
        init_state = (v, rng)

        body_fun = lambda i, state: RBM._gibbs_step(i, state, params, T_schedule[i])

        # the fori_loop is still required, since this function will also be JIT-compiled
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), body_fun, init_state)
        return v_final

# %%
class RBMTrainState(train_state.TrainState):
    """
    A value object bundling parameters and optimizer state for training.
    It has a few pre-defined fields to be used in the training loop.
    Since it is immutable, the training function needs to return a new instance after each update step.
    """
    pass


@functools.partial(jax.jit)
def train_step(state: RBMTrainState, data_batch: jnp.ndarray, v_persistent: jnp.ndarray, key: PRNGKey):

    # only the 'params' argument remains a variable to be differentiated
    pcd_loss_fn = lambda params: state.apply_fn({'params': params}, data_batch, v_persistent, key)

    # since our pc_loss_fn also returns the updated fantasy particles, we need to use has_aux=True
    value_and_grad_fn = jax.value_and_grad(pcd_loss_fn, has_aux=True)
    (pcd_loss, aux_vars), pdc_loss_grads = value_and_grad_fn(state.params)

    # apply the gradients to the state, this actually updates the optimizer state
    new_state = state.apply_gradients(grads=pdc_loss_grads)
    v_persistent = aux_vars["v_persistent"]
    key = aux_vars["key"]

    return new_state, pcd_loss, v_persistent, key


def train_rbm(state: RBMTrainState, train_loader, num_epochs: int, rng: PRNGKey, pcd_reset: int = 5, scheduler=None):
    metrics = {}

    for epoch in range(num_epochs):
        total_loss = 0.0
        batch_count = 0

        for batch_idx, data in enumerate(train_loader):

            print(f"{type(batch_idx)}, {type(pcd_reset)}")
            if batch_idx % pcd_reset == 0:
                rng, subkey = jax.random.split(rng)
                v_persistent = jax.random.bernoulli(subkey, p=0.5, shape=data.shape).astype(jnp.float32)

            state, loss, v_persistent, rng = train_step(state, data, v_persistent, rng)
            total_loss += loss
            batch_count += 1

        avg_loss = total_loss / len(train_loader)
        metrics[epoch] = {"free_energy_loss": float(avg_loss)}
        print(f"Epoch [{epoch+1}/{num_epochs}] - Free Energy Loss: {avg_loss:.4f}")

    return state, metrics, rng

# %%
# ACTUAL TRAINING
batch_size    = 128
visible_units = 20
hidden_units  = 20
k_steps       = 100
lr            = 1e-2
num_epochs    = 300
pcd_reset     = 1
lr_decay      = 0.95


rng = PRNGKey(42)

# instantiate the optimizer and the RBM
train_loader = DataLoader(data_subset, batch_size=batch_size, shuffle=True)

optimizer = optax.adam(learning_rate=lr)
rbm = RBM(n_visible=visible_units, n_hidden=hidden_units, k=k_steps)

# initialize RBM parameters and create the training state
dummy_batch = data_subset[:batch_size]
rng, subkey = jax.random.split(rng)
v_persistent = jax.random.bernoulli(subkey, p=0.5, shape=dummy_batch.shape).astype(jnp.float32)
params = rbm.init(rng, dummy_batch, v_persistent, rng)['params']

state = RBMTrainState.create(apply_fn=rbm.apply, params=params, tx=optimizer)

state, metrics, rng = train_rbm(state, train_loader, num_epochs, rng, pcd_reset)
# Out:
# Epoch [1/300] - Free Energy Loss: -0.8517
# Epoch [2/300] - Free Energy Loss: -0.1372
# Epoch [3/300] - Free Energy Loss: -0.0630
# Epoch [4/300] - Free Energy Loss: -0.0559
# Epoch [5/300] - Free Energy Loss: -0.0424
# Epoch [6/300] - Free Energy Loss: -0.0192
# Epoch [7/300] - Free Energy Loss: 0.0014
# Epoch [8/300] - Free Energy Loss: 0.0046
# Epoch [9/300] - Free Energy Loss: -0.0085
# Epoch [10/300] - Free Energy Loss: 0.0269
# Epoch [11/300] - Free Energy Loss: 0.0062
# Epoch [12/300] - Free Energy Loss: 0.0238
# Epoch [13/300] - Free Energy Loss: 0.0199
# Epoch [14/300] - Free Energy Loss: 0.0169
# Epoch [15/300] - Free Energy Loss: 0.0319
# Epoch [16/300] - Free Energy Loss: 0.0321
# Epoch [17/300] - Free Energy Loss: 0.0371
# Epoch [18/300] - Free Energy Loss: 0.0328
# Epoch [19/300] - Free Energy Loss: 0.0346
# Epoch [20/300] - Free Energy Loss: 0.0352
# Epoch [21/300] - Free Energy Loss: 0.0473
# Epoch [22/300] - Free Energy Loss: 0.0426
# Epoch [23/300] - Free Energy Loss: 0.0290
# Epoch [24/300] - Free Energy Loss: 0.0369
# Epoch [25/300] - Free Energy Loss: 0.0436
# Epoch [26/300] - Free Energy Loss: 0.0387
# Epoch [27/300] - Free Energy Loss: 0.0423
# Epoch [28/300] - Free Energy Loss: 0.0404
# Epoch [29/300] - Free Energy Loss: 0.0418
# Epoch [30/300] - Free Energy Loss: 0.0436
# Epoch [31/300] - Free Energy Loss: 0.0448
# Epoch [32/300] - Free Energy Loss: 0.0431
# Epoch [33/300] - Free Energy Loss: 0.0455
# Epoch [34/300] - Free Energy Loss: 0.0444
# Epoch [35/300] - Free Energy Loss: 0.0310
# Epoch [36/300] - Free Energy Loss: 0.0414
# Epoch [37/300] - Free Energy Loss: 0.0557
# Epoch [38/300] - Free Energy Loss: 0.0317
# Epoch [39/300] - Free Energy Loss: 0.0493
# Epoch [40/300] - Free Energy Loss: 0.0387
# Epoch [41/300] - Free Energy Loss: 0.0378
# Epoch [42/300] - Free Energy Loss: 0.0489
# Epoch [43/300] - Free Energy Loss: 0.0508
# Epoch [44/300] - Free Energy Loss: 0.0459
# Epoch [45/300] - Free Energy Loss: 0.0542
# Epoch [46/300] - Free Energy Loss: 0.0378
# Epoch [47/300] - Free Energy Loss: 0.0448
# Epoch [48/300] - Free Energy Loss: 0.0451
# Epoch [49/300] - Free Energy Loss: 0.0290
# Epoch [50/300] - Free Energy Loss: 0.0362
# Epoch [51/300] - Free Energy Loss: 0.0425
# Epoch [52/300] - Free Energy Loss: 0.0290
# Epoch [53/300] - Free Energy Loss: 0.0411
# Epoch [54/300] - Free Energy Loss: 0.0343
# Epoch [55/300] - Free Energy Loss: 0.0200
# Epoch [56/300] - Free Energy Loss: 0.0481
# Epoch [57/300] - Free Energy Loss: 0.0127
# Epoch [58/300] - Free Energy Loss: 0.0436
# Epoch [59/300] - Free Energy Loss: 0.0215
# Epoch [60/300] - Free Energy Loss: 0.0486
# Epoch [61/300] - Free Energy Loss: 0.0452
# Epoch [62/300] - Free Energy Loss: 0.0268
# Epoch [63/300] - Free Energy Loss: 0.0263
# Epoch [64/300] - Free Energy Loss: 0.0270
# Epoch [65/300] - Free Energy Loss: 0.0327
# Epoch [66/300] - Free Energy Loss: 0.0242
# Epoch [67/300] - Free Energy Loss: 0.0442
# Epoch [68/300] - Free Energy Loss: 0.0280
# Epoch [69/300] - Free Energy Loss: 0.0285
# Epoch [70/300] - Free Energy Loss: 0.0353
# Epoch [71/300] - Free Energy Loss: 0.0300
# Epoch [72/300] - Free Energy Loss: 0.0375
# Epoch [73/300] - Free Energy Loss: 0.0262
# Epoch [74/300] - Free Energy Loss: 0.0233
# Epoch [75/300] - Free Energy Loss: 0.0327
# Epoch [76/300] - Free Energy Loss: 0.0455
# Epoch [77/300] - Free Energy Loss: 0.0232
# Epoch [78/300] - Free Energy Loss: 0.0288
# Epoch [79/300] - Free Energy Loss: 0.0319
# Epoch [80/300] - Free Energy Loss: 0.0362
# Epoch [81/300] - Free Energy Loss: 0.0385
# Epoch [82/300] - Free Energy Loss: 0.0155
# Epoch [83/300] - Free Energy Loss: 0.0408
# Epoch [84/300] - Free Energy Loss: 0.0222
# Epoch [85/300] - Free Energy Loss: 0.0244
# Epoch [86/300] - Free Energy Loss: 0.0296
# Epoch [87/300] - Free Energy Loss: 0.0361
# Epoch [88/300] - Free Energy Loss: 0.0284
# Epoch [89/300] - Free Energy Loss: 0.0311
# Epoch [90/300] - Free Energy Loss: 0.0242
# Epoch [91/300] - Free Energy Loss: 0.0274
# Epoch [92/300] - Free Energy Loss: 0.0389
# Epoch [93/300] - Free Energy Loss: 0.0380
# Epoch [94/300] - Free Energy Loss: 0.0201
# Epoch [95/300] - Free Energy Loss: 0.0332
# Epoch [96/300] - Free Energy Loss: 0.0232
# Epoch [97/300] - Free Energy Loss: 0.0306
# Epoch [98/300] - Free Energy Loss: 0.0290
# Epoch [99/300] - Free Energy Loss: 0.0300
# Epoch [100/300] - Free Energy Loss: 0.0388
# Epoch [101/300] - Free Energy Loss: 0.0139
# Epoch [102/300] - Free Energy Loss: 0.0415
# Epoch [103/300] - Free Energy Loss: 0.0231
# Epoch [104/300] - Free Energy Loss: 0.0326
# Epoch [105/300] - Free Energy Loss: 0.0491
# Epoch [106/300] - Free Energy Loss: 0.0256
# Epoch [107/300] - Free Energy Loss: 0.0169
# Epoch [108/300] - Free Energy Loss: 0.0419
# Epoch [109/300] - Free Energy Loss: 0.0359
# Epoch [110/300] - Free Energy Loss: 0.0276
# Epoch [111/300] - Free Energy Loss: 0.0338
# Epoch [112/300] - Free Energy Loss: 0.0232
# Epoch [113/300] - Free Energy Loss: 0.0354
# Epoch [114/300] - Free Energy Loss: 0.0306
# Epoch [115/300] - Free Energy Loss: 0.0298
# Epoch [116/300] - Free Energy Loss: 0.0244
# Epoch [117/300] - Free Energy Loss: 0.0348
# Epoch [118/300] - Free Energy Loss: 0.0251
# Epoch [119/300] - Free Energy Loss: 0.0254
# Epoch [120/300] - Free Energy Loss: 0.0283
# Epoch [121/300] - Free Energy Loss: 0.0235
# Epoch [122/300] - Free Energy Loss: 0.0284
# Epoch [123/300] - Free Energy Loss: 0.0326
# Epoch [124/300] - Free Energy Loss: 0.0215
# Epoch [125/300] - Free Energy Loss: 0.0348
# Epoch [126/300] - Free Energy Loss: 0.0285
# Epoch [127/300] - Free Energy Loss: 0.0222
# Epoch [128/300] - Free Energy Loss: 0.0418
# Epoch [129/300] - Free Energy Loss: 0.0224
# Epoch [130/300] - Free Energy Loss: 0.0300
# Epoch [131/300] - Free Energy Loss: 0.0246
# Epoch [132/300] - Free Energy Loss: 0.0382
# Epoch [133/300] - Free Energy Loss: 0.0044
# Epoch [134/300] - Free Energy Loss: 0.0466
# Epoch [135/300] - Free Energy Loss: 0.0288
# Epoch [136/300] - Free Energy Loss: 0.0296
# Epoch [137/300] - Free Energy Loss: 0.0435
# Epoch [138/300] - Free Energy Loss: 0.0297
# Epoch [139/300] - Free Energy Loss: 0.0090
# Epoch [140/300] - Free Energy Loss: 0.0540
# Epoch [141/300] - Free Energy Loss: 0.0171
# Epoch [142/300] - Free Energy Loss: 0.0278
# Epoch [143/300] - Free Energy Loss: 0.0241
# Epoch [144/300] - Free Energy Loss: 0.0318
# Epoch [145/300] - Free Energy Loss: 0.0373
# Epoch [146/300] - Free Energy Loss: 0.0254
# Epoch [147/300] - Free Energy Loss: 0.0225
# Epoch [148/300] - Free Energy Loss: 0.0226
# Epoch [149/300] - Free Energy Loss: 0.0393
# Epoch [150/300] - Free Energy Loss: 0.0239
# Epoch [151/300] - Free Energy Loss: 0.0180
# Epoch [152/300] - Free Energy Loss: 0.0394
# Epoch [153/300] - Free Energy Loss: 0.0301
# Epoch [154/300] - Free Energy Loss: 0.0109
# Epoch [155/300] - Free Energy Loss: 0.0385
# Epoch [156/300] - Free Energy Loss: 0.0322
# Epoch [157/300] - Free Energy Loss: 0.0265
# Epoch [158/300] - Free Energy Loss: 0.0224
# Epoch [159/300] - Free Energy Loss: 0.0334
# Epoch [160/300] - Free Energy Loss: 0.0387
# Epoch [161/300] - Free Energy Loss: 0.0132
# Epoch [162/300] - Free Energy Loss: 0.0270
# Epoch [163/300] - Free Energy Loss: 0.0293
# Epoch [164/300] - Free Energy Loss: 0.0400
# Epoch [165/300] - Free Energy Loss: 0.0372
# Epoch [166/300] - Free Energy Loss: 0.0259
# Epoch [167/300] - Free Energy Loss: 0.0271
# Epoch [168/300] - Free Energy Loss: 0.0329
# Epoch [169/300] - Free Energy Loss: 0.0186
# Epoch [170/300] - Free Energy Loss: 0.0260
# Epoch [171/300] - Free Energy Loss: 0.0358
# Epoch [172/300] - Free Energy Loss: 0.0196
# Epoch [173/300] - Free Energy Loss: 0.0318
# Epoch [174/300] - Free Energy Loss: 0.0290
# Epoch [175/300] - Free Energy Loss: 0.0381
# Epoch [176/300] - Free Energy Loss: 0.0199
# Epoch [177/300] - Free Energy Loss: 0.0328
# Epoch [178/300] - Free Energy Loss: 0.0257
# Epoch [179/300] - Free Energy Loss: 0.0340
# Epoch [180/300] - Free Energy Loss: 0.0257
# Epoch [181/300] - Free Energy Loss: 0.0356
# Epoch [182/300] - Free Energy Loss: 0.0225
# Epoch [183/300] - Free Energy Loss: 0.0005
# Epoch [184/300] - Free Energy Loss: 0.0251
# Epoch [185/300] - Free Energy Loss: 0.0148
# Epoch [186/300] - Free Energy Loss: 0.0218
# Epoch [187/300] - Free Energy Loss: 0.0181
# Epoch [188/300] - Free Energy Loss: 0.0144
# Epoch [189/300] - Free Energy Loss: 0.0323
# Epoch [190/300] - Free Energy Loss: 0.0190
# Epoch [191/300] - Free Energy Loss: 0.0236
# Epoch [192/300] - Free Energy Loss: 0.0237
# Epoch [193/300] - Free Energy Loss: 0.0283
# Epoch [194/300] - Free Energy Loss: 0.0209
# Epoch [195/300] - Free Energy Loss: 0.0329
# Epoch [196/300] - Free Energy Loss: 0.0108
# Epoch [197/300] - Free Energy Loss: 0.0258
# Epoch [198/300] - Free Energy Loss: 0.0150
# Epoch [199/300] - Free Energy Loss: 0.0021
# Epoch [200/300] - Free Energy Loss: 0.0211
# Epoch [201/300] - Free Energy Loss: 0.0111
# Epoch [202/300] - Free Energy Loss: 0.0141
# Epoch [203/300] - Free Energy Loss: 0.0235
# Epoch [204/300] - Free Energy Loss: 0.0212
# Epoch [205/300] - Free Energy Loss: -0.0006
# Epoch [206/300] - Free Energy Loss: 0.0136
# Epoch [207/300] - Free Energy Loss: 0.0084
# Epoch [208/300] - Free Energy Loss: 0.0199
# Epoch [209/300] - Free Energy Loss: 0.0123
# Epoch [210/300] - Free Energy Loss: 0.0142
# Epoch [211/300] - Free Energy Loss: 0.0188
# Epoch [212/300] - Free Energy Loss: 0.0187
# Epoch [213/300] - Free Energy Loss: 0.0068
# Epoch [214/300] - Free Energy Loss: 0.0149
# Epoch [215/300] - Free Energy Loss: -0.0083
# Epoch [216/300] - Free Energy Loss: -0.0076
# Epoch [217/300] - Free Energy Loss: 0.0102
# Epoch [218/300] - Free Energy Loss: -0.0165
# Epoch [219/300] - Free Energy Loss: -0.0109
# Epoch [220/300] - Free Energy Loss: -0.0142
# Epoch [221/300] - Free Energy Loss: -0.0026
# Epoch [222/300] - Free Energy Loss: 0.0041
# Epoch [223/300] - Free Energy Loss: 0.0110
# Epoch [224/300] - Free Energy Loss: 0.0106
# Epoch [225/300] - Free Energy Loss: 0.0075
# Epoch [226/300] - Free Energy Loss: 0.0109
# Epoch [227/300] - Free Energy Loss: 0.0040
# Epoch [228/300] - Free Energy Loss: -0.0049
# Epoch [229/300] - Free Energy Loss: 0.0050
# Epoch [230/300] - Free Energy Loss: 0.0094
# Epoch [231/300] - Free Energy Loss: -0.0055
# Epoch [232/300] - Free Energy Loss: 0.0015
# Epoch [233/300] - Free Energy Loss: 0.0019
# Epoch [234/300] - Free Energy Loss: 0.0047
# Epoch [235/300] - Free Energy Loss: 0.0073
# Epoch [236/300] - Free Energy Loss: 0.0044
# Epoch [237/300] - Free Energy Loss: 0.0179
# Epoch [238/300] - Free Energy Loss: -0.0257
# Epoch [239/300] - Free Energy Loss: -0.0140
# Epoch [240/300] - Free Energy Loss: -0.0164
# Epoch [241/300] - Free Energy Loss: 0.0016
# Epoch [242/300] - Free Energy Loss: -0.0074
# Epoch [243/300] - Free Energy Loss: -0.0008
# Epoch [244/300] - Free Energy Loss: -0.0028
# Epoch [245/300] - Free Energy Loss: 0.0060
# Epoch [246/300] - Free Energy Loss: 0.0027
# Epoch [247/300] - Free Energy Loss: 0.0247
# Epoch [248/300] - Free Energy Loss: -0.0021
# Epoch [249/300] - Free Energy Loss: 0.0043
# Epoch [250/300] - Free Energy Loss: 0.0065
# Epoch [251/300] - Free Energy Loss: 0.0097
# Epoch [252/300] - Free Energy Loss: -0.0013
# Epoch [253/300] - Free Energy Loss: 0.0053
# Epoch [254/300] - Free Energy Loss: 0.0066
# Epoch [255/300] - Free Energy Loss: 0.0096
# Epoch [256/300] - Free Energy Loss: 0.0120
# Epoch [257/300] - Free Energy Loss: -0.0021
# Epoch [258/300] - Free Energy Loss: 0.0196
# Epoch [259/300] - Free Energy Loss: 0.0077
# Epoch [260/300] - Free Energy Loss: 0.0060
# Epoch [261/300] - Free Energy Loss: 0.0085
# Epoch [262/300] - Free Energy Loss: 0.0026
# Epoch [263/300] - Free Energy Loss: 0.0245
# Epoch [264/300] - Free Energy Loss: 0.0025
# Epoch [265/300] - Free Energy Loss: 0.0084
# Epoch [266/300] - Free Energy Loss: 0.0189
# Epoch [267/300] - Free Energy Loss: 0.0107
# Epoch [268/300] - Free Energy Loss: 0.0112
# Epoch [269/300] - Free Energy Loss: 0.0023
# Epoch [270/300] - Free Energy Loss: -0.0026
# Epoch [271/300] - Free Energy Loss: 0.0011
# Epoch [272/300] - Free Energy Loss: 0.0085
# Epoch [273/300] - Free Energy Loss: 0.0020
# Epoch [274/300] - Free Energy Loss: 0.0121
# Epoch [275/300] - Free Energy Loss: -0.0062
# Epoch [276/300] - Free Energy Loss: 0.0120
# Epoch [277/300] - Free Energy Loss: -0.0063
# Epoch [278/300] - Free Energy Loss: 0.0150
# Epoch [279/300] - Free Energy Loss: 0.0071
# Epoch [280/300] - Free Energy Loss: 0.0118
# Epoch [281/300] - Free Energy Loss: 0.0075
# Epoch [282/300] - Free Energy Loss: 0.0180
# Epoch [283/300] - Free Energy Loss: 0.0108
# Epoch [284/300] - Free Energy Loss: 0.0022
# Epoch [285/300] - Free Energy Loss: 0.0141
# Epoch [286/300] - Free Energy Loss: 0.0066
# Epoch [287/300] - Free Energy Loss: 0.0128
# Epoch [288/300] - Free Energy Loss: -0.0045
# Epoch [289/300] - Free Energy Loss: 0.0177
# Epoch [290/300] - Free Energy Loss: 0.0026
# Epoch [291/300] - Free Energy Loss: 0.0236
# Epoch [292/300] - Free Energy Loss: 0.0024
# Epoch [293/300] - Free Energy Loss: 0.0178
# Epoch [294/300] - Free Energy Loss: 0.0159
# Epoch [295/300] - Free Energy Loss: 0.0071
# Epoch [296/300] - Free Energy Loss: 0.0105
# Epoch [297/300] - Free Energy Loss: 0.0063
# Epoch [298/300] - Free Energy Loss: 0.0145
# Epoch [299/300] - Free Energy Loss: 0.0123
# Epoch [300/300] - Free Energy Loss: 0.0130

# %%
plt.plot([metrics[epoch]['free_energy_loss'] for epoch in metrics])
plt.xlabel("Epoch")
plt.ylabel("Free Energy Loss")
# Out:
# Text(0, 0.5, 'Free Energy Loss')

# %%
samples = rbm.generate(state.params,
                       n_samples=10_000,
                       T_schedule=jnp.ones(200) * 1.2,
                       rng=rng)

rel_freq = samples.mean(0)
rel_freq
# Out:
# Array([0.0588    , 0.0563    , 0.0559    , 0.0567    , 0.0411    ,
#        0.0665    , 0.0709    , 0.0673    , 0.0424    , 0.06879999,
#        0.0678    , 0.0541    , 0.0614    , 0.0402    , 0.0714    ,
#        0.0751    , 0.0436    , 0.059     , 0.0674    , 0.0526    ],      dtype=float32)

# %%
spin_counts = samples.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(22), align='left', edgecolor='black')
plt.xticks(range(21))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
sites = np.arange(1, visible_units+1)
ax.bar(sites, rel_freq, width=0.8, edgecolor='black', alpha=0.7)
ax.axhline(1/visible_units, color='red', linestyle='--', label=f'Expected = {1/visible_units:.3f}')

ax.set_xlabel('Spin‐site index')
ax.set_ylabel('Relative frequency of up‐spin')
ax.set_title('Training Data: Up‐Spin Occurrence per Site')
ax.set_xticks(sites)
ax.set_ylim(0, rel_freq.max()*1.2)

ax.legend(loc='upper right')
plt.tight_layout()
plt.show()
