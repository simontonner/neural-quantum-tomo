# %%
# %reload_ext autoreload
# %autoreload 2

from lib.data_loading import load_measurements, MixedDataLoader

####

from pathlib import Path
from typing import Tuple, Dict, Any, Callable
from itertools import combinations
from datetime import datetime

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import optax
from flax.training.train_state import TrainState
from flax.training import checkpoints
from flax import linen as nn

import matplotlib.pyplot as plt


data_dir = "data"
model_dir = Path("./models")
model_dir.mkdir(parents=True, exist_ok=True)

print(f"Data resides in        : {data_dir}")
print(f"Model will be saved to : {model_dir}")
# Out:
# WARNING:absl:Tensorflow library not found, tensorflow.io.gfile operations will use native shim calls. GCS paths (i.e. 'gs://...') cannot be accessed.
# Data resides in        : data
# Model will be saved to : models

# %%
class RBM(nn.Module):
    num_visible: int
    num_hidden: int
    k: int = 1
    T: float = 1.0

    def setup(self):
        self.W = self.param("W", nn.initializers.normal(0.01), (self.num_visible, self.num_hidden))
        self.b = self.param("b", nn.initializers.zeros, (self.num_visible,))
        self.c = self.param("c", nn.initializers.zeros, (self.num_hidden,))

    def __call__(self, data: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W, self.b, self.c, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (aux_vars["gibbs_chain"], aux_vars["key"]))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain)

        free_energy_data = jnp.mean(self._free_energy(data))
        free_energy_model = jnp.mean(self._free_energy(gibbs_chain))

        regularization = aux_vars["l2_strength"] * (jnp.sum(self.W**2) + jnp.sum(self.b**2) + jnp.sum(self.c**2))
        loss = free_energy_data - free_energy_model + regularization

        aux_vars = {
            "gibbs_chain": gibbs_chain,
            "key": key,
            "free_energy_data": free_energy_data,
            "free_energy_model": free_energy_model,
        }

        return loss, aux_vars

    def _free_energy(self, v):
        return -(v @ self.b) - jnp.sum(jax.nn.softplus(v @ self.W + self.c), -1)

    @nn.nowrap
    def free_energy(self, v: jnp.ndarray) -> jnp.ndarray:
        return self._free_energy(v)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c)/T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b)/T)).astype(jnp.float32)
        return v, key

    @nn.nowrap
    def generate(self, num_samples: int, T_schedule: jnp.ndarray, key: PRNGKey) -> jnp.ndarray:
        key, key_init = jax.random.split(key, 2)
        v = jax.random.bernoulli(key_init, p=0.5, shape=(num_samples, self.num_visible)).astype(jnp.float32)

        anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, (v, key))
        return v_final

# %%
@jax.jit
def train_step(state: TrainState, batch: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[TrainState, jnp.ndarray, Dict[str, Any]]:

    key, key_reset = jax.random.split(aux_vars["key"])
    aux_vars["key"] = key

    # reset gibbs_chain[i] with batch[i] given reset probability as chain_reset_frac
    reset_mask = jax.random.bernoulli(key_reset, p=aux_vars["chain_reset_frac"], shape=(batch.shape[0], 1))
    aux_vars["gibbs_chain"] = jnp.where(reset_mask, batch, aux_vars["gibbs_chain"])

    loss_fn = lambda params: state.apply_fn({'params': params}, batch, aux_vars)
    (loss, aux_vars), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    state = state.apply_gradients(grads=grads)

    return state, loss, aux_vars


def count_modes(chain: jnp.ndarray) -> int:
    chain = chain.astype(jnp.uint32)
    powers = 2 ** jnp.arange(chain.shape[-1], dtype=jnp.uint32)
    ints = jnp.dot(chain, powers)

    hist = jnp.bincount(ints, length=1 << chain.shape[-1])
    return int(jnp.sum(hist > 0))


def train(
        state: TrainState,
        loader: MixedDataLoader,
        num_epochs: int,
        key: PRNGKey,
        chain_reset_frac: float,
        l2_strength: float,
        lr_schedule_fn: Callable[[int], float]) -> Tuple[TrainState, Dict[int, float]]:

    metrics: Dict[int, Any] = {}
    gibbs_chain = None

    for epoch in range(num_epochs):
        tot_loss = 0.0

        for i, batch in enumerate(loader):
            measurements = batch[:, :, 0].astype(jnp.float32)

            if gibbs_chain is None:
                gibbs_chain = measurements

            key, subkey = jax.random.split(key)
            aux_vars = {
                "gibbs_chain": gibbs_chain,
                "key": subkey,
                "chain_reset_frac": chain_reset_frac,
                "l2_strength": l2_strength,
            }

            state, loss, aux_vars = train_step(state, measurements, aux_vars)
            gibbs_chain = aux_vars["gibbs_chain"]
            key = aux_vars["key"]
            free_energy_model = aux_vars["free_energy_model"]
            free_energy_data  = aux_vars["free_energy_data"]

            tot_loss += float(loss)

        avg_loss = tot_loss / len(loader)
        modes = count_modes(gibbs_chain)
        lr = lr_schedule_fn(state.step)

        metrics[epoch] = dict(
            loss=avg_loss,
            modes=modes,
            free_energy_model=free_energy_model,
            free_energy_data=free_energy_data,
            lr=lr
        )

        print(f"Epoch {epoch+1}/{num_epochs} │ "
              f"Loss: {avg_loss:+.4f} │ "
              f"Modes: {modes} │ "
              f"Free En. Model: {free_energy_model:.4f} │ "
              f"Free En. Data: {free_energy_data:.4f} │ "
              f"Learning Rate: {lr:.5f}")

    return state, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2

    curve_fn = lambda step: low + (high - low) / (1 + jnp.exp(falloff * (jnp.minimum(step, steps) - center_step)))
    return curve_fn

# %%
file_path = Path("data/tfim_h7.00_3x3_10000.txt")
data = load_measurements(file_path)

measurements = data[:, :, 0]
empirical_freq = measurements.mean(axis=0)
empirical_freq
# Out:
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 21297.53it/s]
# Array([0.49679998, 0.5006    , 0.5075    , 0.5004    , 0.50119996,
#        0.49379998, 0.4992    , 0.5049    , 0.4872    ], dtype=float32)

# %%
batch_size   = 1024             # larger requires more epochs for the model to go down in its modes
num_visible  = 9
hidden_units = 9               # interesting, lower gives evener frequencies, although the modes go not down to 1
k_steps      = 50               # more steps required if small batch size
num_epochs   = 500             # longer since large batch size
init_lr      = 1e-2             # large drives modes down fast but learns nothing, to small and we dont get any one hots
final_lr     = init_lr * 0.1
chain_reset_frac = 0.1
l2_strength  = 1e-4

# we chose 16 in the hope that our conditioner has more to work with

# runs also very nicely if l2 norm is turned off completely but the free energies get large

key_seed = PRNGKey(42)
key, key_params, key_dummy = jax.random.split(key_seed, 3)

model = RBM(num_visible=num_visible, num_hidden=hidden_units, k=k_steps)
batch_dummy = jnp.zeros((batch_size, num_visible), dtype=jnp.float32)
aux_vars_dummy = {"gibbs_chain": jnp.zeros((batch_size, num_visible), dtype=jnp.float32), "key": key_dummy, "l2_strength": l2_strength}
variables = model.init({"params": key_params}, batch_dummy, aux_vars_dummy)

loader = MixedDataLoader(data, batch_size=batch_size, drop_last=True) # we need the last batch to match the chain dimension

schedule_steps = num_epochs * len(loader)
lr_schedule_fn = get_sigmoid_curve(high=init_lr, low=final_lr, steps=schedule_steps, falloff=0.0005)
optimizer = optax.adam(lr_schedule_fn)

state = TrainState.create(apply_fn=model.apply, params=variables['params'], tx=optimizer)

state, metrics = train(state, loader, num_epochs, key, chain_reset_frac, l2_strength, lr_schedule_fn)
# Out:
# Epoch 1/500 │ Loss: +0.0038 │ Modes: 443 │ Free En. Model: -5.9407 │ Free En. Data: -5.9415 │ Learning Rate: 0.00779
# Epoch 2/500 │ Loss: +0.0039 │ Modes: 445 │ Free En. Model: -5.9019 │ Free En. Data: -5.8945 │ Learning Rate: 0.00778
# Epoch 3/500 │ Loss: +0.0034 │ Modes: 428 │ Free En. Model: -5.7731 │ Free En. Data: -5.7742 │ Learning Rate: 0.00777
# Epoch 4/500 │ Loss: +0.0029 │ Modes: 449 │ Free En. Model: -5.5488 │ Free En. Data: -5.5445 │ Learning Rate: 0.00776
# Epoch 5/500 │ Loss: +0.0032 │ Modes: 438 │ Free En. Model: -5.4330 │ Free En. Data: -5.4333 │ Learning Rate: 0.00776
# Epoch 6/500 │ Loss: +0.0038 │ Modes: 439 │ Free En. Model: -5.3016 │ Free En. Data: -5.2975 │ Learning Rate: 0.00775
# Epoch 7/500 │ Loss: +0.0019 │ Modes: 445 │ Free En. Model: -5.1632 │ Free En. Data: -5.1606 │ Learning Rate: 0.00774
# Epoch 8/500 │ Loss: +0.0012 │ Modes: 429 │ Free En. Model: -5.0953 │ Free En. Data: -5.0946 │ Learning Rate: 0.00773
# Epoch 9/500 │ Loss: +0.0032 │ Modes: 447 │ Free En. Model: -5.0226 │ Free En. Data: -5.0213 │ Learning Rate: 0.00773
# Epoch 10/500 │ Loss: +0.0018 │ Modes: 433 │ Free En. Model: -4.9829 │ Free En. Data: -4.9835 │ Learning Rate: 0.00772
# Epoch 11/500 │ Loss: +0.0032 │ Modes: 439 │ Free En. Model: -4.9536 │ Free En. Data: -4.9518 │ Learning Rate: 0.00771
# Epoch 12/500 │ Loss: +0.0031 │ Modes: 423 │ Free En. Model: -4.8983 │ Free En. Data: -4.8951 │ Learning Rate: 0.00770
# Epoch 13/500 │ Loss: +0.0031 │ Modes: 443 │ Free En. Model: -4.7249 │ Free En. Data: -4.7258 │ Learning Rate: 0.00770
# Epoch 14/500 │ Loss: +0.0007 │ Modes: 438 │ Free En. Model: -4.7176 │ Free En. Data: -4.7199 │ Learning Rate: 0.00769
# Epoch 15/500 │ Loss: +0.0031 │ Modes: 446 │ Free En. Model: -4.7081 │ Free En. Data: -4.7088 │ Learning Rate: 0.00768
# Epoch 16/500 │ Loss: +0.0013 │ Modes: 455 │ Free En. Model: -4.7171 │ Free En. Data: -4.7158 │ Learning Rate: 0.00767
# Epoch 17/500 │ Loss: +0.0028 │ Modes: 452 │ Free En. Model: -4.6431 │ Free En. Data: -4.6401 │ Learning Rate: 0.00766
# Epoch 18/500 │ Loss: +0.0020 │ Modes: 437 │ Free En. Model: -4.5595 │ Free En. Data: -4.5582 │ Learning Rate: 0.00766
# Epoch 19/500 │ Loss: +0.0011 │ Modes: 439 │ Free En. Model: -4.5096 │ Free En. Data: -4.5126 │ Learning Rate: 0.00765
# Epoch 20/500 │ Loss: +0.0018 │ Modes: 452 │ Free En. Model: -4.5852 │ Free En. Data: -4.5849 │ Learning Rate: 0.00764
# Epoch 21/500 │ Loss: +0.0025 │ Modes: 441 │ Free En. Model: -4.5744 │ Free En. Data: -4.5729 │ Learning Rate: 0.00763
# Epoch 22/500 │ Loss: +0.0016 │ Modes: 444 │ Free En. Model: -4.5380 │ Free En. Data: -4.5355 │ Learning Rate: 0.00763
# Epoch 23/500 │ Loss: +0.0012 │ Modes: 441 │ Free En. Model: -4.5099 │ Free En. Data: -4.5048 │ Learning Rate: 0.00762
# Epoch 24/500 │ Loss: +0.0014 │ Modes: 443 │ Free En. Model: -4.5436 │ Free En. Data: -4.5397 │ Learning Rate: 0.00761
# Epoch 25/500 │ Loss: +0.0007 │ Modes: 434 │ Free En. Model: -4.5122 │ Free En. Data: -4.5116 │ Learning Rate: 0.00760
# Epoch 26/500 │ Loss: -0.0002 │ Modes: 440 │ Free En. Model: -4.5075 │ Free En. Data: -4.5069 │ Learning Rate: 0.00759
# Epoch 27/500 │ Loss: +0.0014 │ Modes: 448 │ Free En. Model: -4.5023 │ Free En. Data: -4.5044 │ Learning Rate: 0.00759
# Epoch 28/500 │ Loss: -0.0007 │ Modes: 440 │ Free En. Model: -4.5478 │ Free En. Data: -4.5450 │ Learning Rate: 0.00758
# Epoch 29/500 │ Loss: -0.0020 │ Modes: 440 │ Free En. Model: -4.5052 │ Free En. Data: -4.5060 │ Learning Rate: 0.00757
# Epoch 30/500 │ Loss: -0.0004 │ Modes: 428 │ Free En. Model: -4.5351 │ Free En. Data: -4.5377 │ Learning Rate: 0.00756
# Epoch 31/500 │ Loss: -0.0030 │ Modes: 439 │ Free En. Model: -4.5086 │ Free En. Data: -4.5110 │ Learning Rate: 0.00755
# Epoch 32/500 │ Loss: -0.0034 │ Modes: 435 │ Free En. Model: -4.5118 │ Free En. Data: -4.5160 │ Learning Rate: 0.00755
# Epoch 33/500 │ Loss: -0.0052 │ Modes: 444 │ Free En. Model: -4.5222 │ Free En. Data: -4.5338 │ Learning Rate: 0.00754
# Epoch 34/500 │ Loss: -0.0090 │ Modes: 453 │ Free En. Model: -4.6394 │ Free En. Data: -4.6485 │ Learning Rate: 0.00753
# Epoch 35/500 │ Loss: -0.0083 │ Modes: 440 │ Free En. Model: -4.6139 │ Free En. Data: -4.6215 │ Learning Rate: 0.00752
# Epoch 36/500 │ Loss: -0.0112 │ Modes: 447 │ Free En. Model: -4.5900 │ Free En. Data: -4.5941 │ Learning Rate: 0.00751
# Epoch 37/500 │ Loss: -0.0125 │ Modes: 442 │ Free En. Model: -4.6170 │ Free En. Data: -4.6250 │ Learning Rate: 0.00751
# Epoch 38/500 │ Loss: -0.0115 │ Modes: 441 │ Free En. Model: -4.6321 │ Free En. Data: -4.6439 │ Learning Rate: 0.00750
# Epoch 39/500 │ Loss: -0.0161 │ Modes: 435 │ Free En. Model: -4.6550 │ Free En. Data: -4.6633 │ Learning Rate: 0.00749
# Epoch 40/500 │ Loss: -0.0157 │ Modes: 431 │ Free En. Model: -4.6253 │ Free En. Data: -4.6464 │ Learning Rate: 0.00748
# Epoch 41/500 │ Loss: -0.0204 │ Modes: 449 │ Free En. Model: -4.7553 │ Free En. Data: -4.7758 │ Learning Rate: 0.00747
# Epoch 42/500 │ Loss: -0.0142 │ Modes: 430 │ Free En. Model: -4.6985 │ Free En. Data: -4.7142 │ Learning Rate: 0.00746
# Epoch 43/500 │ Loss: -0.0155 │ Modes: 439 │ Free En. Model: -4.7062 │ Free En. Data: -4.7234 │ Learning Rate: 0.00746
# Epoch 44/500 │ Loss: -0.0111 │ Modes: 438 │ Free En. Model: -4.8355 │ Free En. Data: -4.8451 │ Learning Rate: 0.00745
# Epoch 45/500 │ Loss: -0.0086 │ Modes: 435 │ Free En. Model: -4.7362 │ Free En. Data: -4.7483 │ Learning Rate: 0.00744
# Epoch 46/500 │ Loss: -0.0094 │ Modes: 440 │ Free En. Model: -4.8562 │ Free En. Data: -4.8564 │ Learning Rate: 0.00743
# Epoch 47/500 │ Loss: -0.0077 │ Modes: 434 │ Free En. Model: -4.7248 │ Free En. Data: -4.7382 │ Learning Rate: 0.00742
# Epoch 48/500 │ Loss: -0.0088 │ Modes: 429 │ Free En. Model: -4.7551 │ Free En. Data: -4.7639 │ Learning Rate: 0.00742
# Epoch 49/500 │ Loss: -0.0091 │ Modes: 432 │ Free En. Model: -4.7569 │ Free En. Data: -4.7591 │ Learning Rate: 0.00741
# Epoch 50/500 │ Loss: +0.0006 │ Modes: 441 │ Free En. Model: -4.7994 │ Free En. Data: -4.8009 │ Learning Rate: 0.00740
# Epoch 51/500 │ Loss: -0.0027 │ Modes: 433 │ Free En. Model: -4.7288 │ Free En. Data: -4.7206 │ Learning Rate: 0.00739
# Epoch 52/500 │ Loss: -0.0009 │ Modes: 437 │ Free En. Model: -4.8486 │ Free En. Data: -4.8574 │ Learning Rate: 0.00738
# Epoch 53/500 │ Loss: -0.0018 │ Modes: 435 │ Free En. Model: -4.7354 │ Free En. Data: -4.7375 │ Learning Rate: 0.00737
# Epoch 54/500 │ Loss: +0.0006 │ Modes: 440 │ Free En. Model: -4.8285 │ Free En. Data: -4.8272 │ Learning Rate: 0.00737
# Epoch 55/500 │ Loss: +0.0027 │ Modes: 437 │ Free En. Model: -4.7963 │ Free En. Data: -4.7754 │ Learning Rate: 0.00736
# Epoch 56/500 │ Loss: -0.0019 │ Modes: 426 │ Free En. Model: -4.7869 │ Free En. Data: -4.8004 │ Learning Rate: 0.00735
# Epoch 57/500 │ Loss: -0.0068 │ Modes: 448 │ Free En. Model: -4.7677 │ Free En. Data: -4.7601 │ Learning Rate: 0.00734
# Epoch 58/500 │ Loss: -0.0030 │ Modes: 431 │ Free En. Model: -4.7951 │ Free En. Data: -4.8017 │ Learning Rate: 0.00733
# Epoch 59/500 │ Loss: -0.0030 │ Modes: 437 │ Free En. Model: -4.8612 │ Free En. Data: -4.8475 │ Learning Rate: 0.00732
# Epoch 60/500 │ Loss: +0.0002 │ Modes: 427 │ Free En. Model: -4.8121 │ Free En. Data: -4.8432 │ Learning Rate: 0.00731
# Epoch 61/500 │ Loss: +0.0043 │ Modes: 421 │ Free En. Model: -4.8208 │ Free En. Data: -4.7903 │ Learning Rate: 0.00731
# Epoch 62/500 │ Loss: +0.0002 │ Modes: 429 │ Free En. Model: -4.8438 │ Free En. Data: -4.8428 │ Learning Rate: 0.00730
# Epoch 63/500 │ Loss: -0.0010 │ Modes: 436 │ Free En. Model: -4.8733 │ Free En. Data: -4.8781 │ Learning Rate: 0.00729
# Epoch 64/500 │ Loss: -0.0010 │ Modes: 445 │ Free En. Model: -4.8086 │ Free En. Data: -4.8065 │ Learning Rate: 0.00728
# Epoch 65/500 │ Loss: +0.0056 │ Modes: 433 │ Free En. Model: -4.7983 │ Free En. Data: -4.7941 │ Learning Rate: 0.00727
# Epoch 66/500 │ Loss: +0.0100 │ Modes: 431 │ Free En. Model: -4.8309 │ Free En. Data: -4.8275 │ Learning Rate: 0.00726
# Epoch 67/500 │ Loss: +0.0017 │ Modes: 433 │ Free En. Model: -4.8231 │ Free En. Data: -4.8255 │ Learning Rate: 0.00725
# Epoch 68/500 │ Loss: -0.0026 │ Modes: 448 │ Free En. Model: -4.8641 │ Free En. Data: -4.8399 │ Learning Rate: 0.00725
# Epoch 69/500 │ Loss: +0.0006 │ Modes: 448 │ Free En. Model: -4.8754 │ Free En. Data: -4.8875 │ Learning Rate: 0.00724
# Epoch 70/500 │ Loss: -0.0047 │ Modes: 438 │ Free En. Model: -4.8188 │ Free En. Data: -4.7981 │ Learning Rate: 0.00723
# Epoch 71/500 │ Loss: +0.0035 │ Modes: 425 │ Free En. Model: -4.9012 │ Free En. Data: -4.8945 │ Learning Rate: 0.00722
# Epoch 72/500 │ Loss: -0.0002 │ Modes: 436 │ Free En. Model: -4.8677 │ Free En. Data: -4.8715 │ Learning Rate: 0.00721
# Epoch 73/500 │ Loss: +0.0058 │ Modes: 430 │ Free En. Model: -4.8415 │ Free En. Data: -4.8219 │ Learning Rate: 0.00720
# Epoch 74/500 │ Loss: -0.0051 │ Modes: 440 │ Free En. Model: -4.8830 │ Free En. Data: -4.8808 │ Learning Rate: 0.00719
# Epoch 75/500 │ Loss: -0.0021 │ Modes: 427 │ Free En. Model: -4.8636 │ Free En. Data: -4.8597 │ Learning Rate: 0.00719
# Epoch 76/500 │ Loss: +0.0003 │ Modes: 441 │ Free En. Model: -4.8946 │ Free En. Data: -4.8913 │ Learning Rate: 0.00718
# Epoch 77/500 │ Loss: +0.0033 │ Modes: 423 │ Free En. Model: -4.8766 │ Free En. Data: -4.8629 │ Learning Rate: 0.00717
# Epoch 78/500 │ Loss: +0.0049 │ Modes: 432 │ Free En. Model: -4.8893 │ Free En. Data: -4.8904 │ Learning Rate: 0.00716
# Epoch 79/500 │ Loss: -0.0022 │ Modes: 432 │ Free En. Model: -4.8903 │ Free En. Data: -4.9034 │ Learning Rate: 0.00715
# Epoch 80/500 │ Loss: -0.0016 │ Modes: 433 │ Free En. Model: -4.9441 │ Free En. Data: -4.9239 │ Learning Rate: 0.00714
# Epoch 81/500 │ Loss: +0.0024 │ Modes: 441 │ Free En. Model: -4.8803 │ Free En. Data: -4.8843 │ Learning Rate: 0.00713
# Epoch 82/500 │ Loss: +0.0019 │ Modes: 437 │ Free En. Model: -4.9264 │ Free En. Data: -4.9188 │ Learning Rate: 0.00712
# Epoch 83/500 │ Loss: +0.0036 │ Modes: 428 │ Free En. Model: -4.9142 │ Free En. Data: -4.9107 │ Learning Rate: 0.00712
# Epoch 84/500 │ Loss: +0.0029 │ Modes: 424 │ Free En. Model: -4.9727 │ Free En. Data: -4.9671 │ Learning Rate: 0.00711
# Epoch 85/500 │ Loss: -0.0038 │ Modes: 440 │ Free En. Model: -4.9253 │ Free En. Data: -4.9343 │ Learning Rate: 0.00710
# Epoch 86/500 │ Loss: +0.0018 │ Modes: 436 │ Free En. Model: -4.9548 │ Free En. Data: -4.9540 │ Learning Rate: 0.00709
# Epoch 87/500 │ Loss: -0.0074 │ Modes: 433 │ Free En. Model: -4.8661 │ Free En. Data: -4.8786 │ Learning Rate: 0.00708
# Epoch 88/500 │ Loss: +0.0013 │ Modes: 436 │ Free En. Model: -4.9898 │ Free En. Data: -4.9792 │ Learning Rate: 0.00707
# Epoch 89/500 │ Loss: -0.0009 │ Modes: 436 │ Free En. Model: -4.9579 │ Free En. Data: -4.9630 │ Learning Rate: 0.00706
# Epoch 90/500 │ Loss: -0.0010 │ Modes: 440 │ Free En. Model: -4.9880 │ Free En. Data: -4.9832 │ Learning Rate: 0.00705
# Epoch 91/500 │ Loss: -0.0061 │ Modes: 439 │ Free En. Model: -4.9493 │ Free En. Data: -4.9537 │ Learning Rate: 0.00704
# Epoch 92/500 │ Loss: +0.0009 │ Modes: 439 │ Free En. Model: -4.9923 │ Free En. Data: -5.0058 │ Learning Rate: 0.00704
# Epoch 93/500 │ Loss: -0.0005 │ Modes: 439 │ Free En. Model: -4.9908 │ Free En. Data: -5.0142 │ Learning Rate: 0.00703
# Epoch 94/500 │ Loss: -0.0001 │ Modes: 441 │ Free En. Model: -4.9864 │ Free En. Data: -4.9981 │ Learning Rate: 0.00702
# Epoch 95/500 │ Loss: +0.0041 │ Modes: 424 │ Free En. Model: -5.0132 │ Free En. Data: -5.0203 │ Learning Rate: 0.00701
# Epoch 96/500 │ Loss: -0.0041 │ Modes: 428 │ Free En. Model: -5.0080 │ Free En. Data: -5.0104 │ Learning Rate: 0.00700
# Epoch 97/500 │ Loss: -0.0049 │ Modes: 437 │ Free En. Model: -5.0314 │ Free En. Data: -5.0356 │ Learning Rate: 0.00699
# Epoch 98/500 │ Loss: -0.0014 │ Modes: 430 │ Free En. Model: -4.9952 │ Free En. Data: -4.9900 │ Learning Rate: 0.00698
# Epoch 99/500 │ Loss: -0.0032 │ Modes: 431 │ Free En. Model: -5.0220 │ Free En. Data: -5.0481 │ Learning Rate: 0.00697
# Epoch 100/500 │ Loss: +0.0035 │ Modes: 442 │ Free En. Model: -5.0776 │ Free En. Data: -5.0945 │ Learning Rate: 0.00696
# Epoch 101/500 │ Loss: -0.0048 │ Modes: 443 │ Free En. Model: -5.1243 │ Free En. Data: -5.1241 │ Learning Rate: 0.00695
# Epoch 102/500 │ Loss: -0.0062 │ Modes: 446 │ Free En. Model: -5.0190 │ Free En. Data: -5.0393 │ Learning Rate: 0.00695
# Epoch 103/500 │ Loss: -0.0045 │ Modes: 435 │ Free En. Model: -5.1456 │ Free En. Data: -5.1402 │ Learning Rate: 0.00694
# Epoch 104/500 │ Loss: -0.0041 │ Modes: 434 │ Free En. Model: -5.1090 │ Free En. Data: -5.1007 │ Learning Rate: 0.00693
# Epoch 105/500 │ Loss: -0.0012 │ Modes: 423 │ Free En. Model: -5.0590 │ Free En. Data: -5.0529 │ Learning Rate: 0.00692
# Epoch 106/500 │ Loss: -0.0031 │ Modes: 427 │ Free En. Model: -5.1428 │ Free En. Data: -5.1293 │ Learning Rate: 0.00691
# Epoch 107/500 │ Loss: +0.0026 │ Modes: 423 │ Free En. Model: -5.0396 │ Free En. Data: -5.0573 │ Learning Rate: 0.00690
# Epoch 108/500 │ Loss: -0.0021 │ Modes: 434 │ Free En. Model: -5.2229 │ Free En. Data: -5.2448 │ Learning Rate: 0.00689
# Epoch 109/500 │ Loss: -0.0035 │ Modes: 430 │ Free En. Model: -5.1151 │ Free En. Data: -5.1086 │ Learning Rate: 0.00688
# Epoch 110/500 │ Loss: -0.0032 │ Modes: 426 │ Free En. Model: -5.0747 │ Free En. Data: -5.0860 │ Learning Rate: 0.00687
# Epoch 111/500 │ Loss: -0.0016 │ Modes: 433 │ Free En. Model: -5.1967 │ Free En. Data: -5.2058 │ Learning Rate: 0.00686
# Epoch 112/500 │ Loss: +0.0001 │ Modes: 434 │ Free En. Model: -5.2365 │ Free En. Data: -5.2394 │ Learning Rate: 0.00685
# Epoch 113/500 │ Loss: -0.0061 │ Modes: 439 │ Free En. Model: -5.1180 │ Free En. Data: -5.1110 │ Learning Rate: 0.00684
# Epoch 114/500 │ Loss: -0.0070 │ Modes: 435 │ Free En. Model: -5.0847 │ Free En. Data: -5.0990 │ Learning Rate: 0.00684
# Epoch 115/500 │ Loss: -0.0026 │ Modes: 438 │ Free En. Model: -5.2181 │ Free En. Data: -5.2225 │ Learning Rate: 0.00683
# Epoch 116/500 │ Loss: +0.0024 │ Modes: 438 │ Free En. Model: -5.1220 │ Free En. Data: -5.1393 │ Learning Rate: 0.00682
# Epoch 117/500 │ Loss: +0.0016 │ Modes: 428 │ Free En. Model: -5.1595 │ Free En. Data: -5.1542 │ Learning Rate: 0.00681
# Epoch 118/500 │ Loss: +0.0023 │ Modes: 433 │ Free En. Model: -5.2765 │ Free En. Data: -5.2452 │ Learning Rate: 0.00680
# Epoch 119/500 │ Loss: -0.0044 │ Modes: 430 │ Free En. Model: -5.1390 │ Free En. Data: -5.1293 │ Learning Rate: 0.00679
# Epoch 120/500 │ Loss: +0.0033 │ Modes: 433 │ Free En. Model: -5.2099 │ Free En. Data: -5.2252 │ Learning Rate: 0.00678
# Epoch 121/500 │ Loss: -0.0015 │ Modes: 436 │ Free En. Model: -5.2900 │ Free En. Data: -5.2723 │ Learning Rate: 0.00677
# Epoch 122/500 │ Loss: -0.0022 │ Modes: 442 │ Free En. Model: -5.2091 │ Free En. Data: -5.2101 │ Learning Rate: 0.00676
# Epoch 123/500 │ Loss: -0.0039 │ Modes: 441 │ Free En. Model: -5.1918 │ Free En. Data: -5.1822 │ Learning Rate: 0.00675
# Epoch 124/500 │ Loss: +0.0003 │ Modes: 439 │ Free En. Model: -5.3046 │ Free En. Data: -5.2914 │ Learning Rate: 0.00674
# Epoch 125/500 │ Loss: +0.0000 │ Modes: 438 │ Free En. Model: -5.2066 │ Free En. Data: -5.2107 │ Learning Rate: 0.00673
# Epoch 126/500 │ Loss: -0.0015 │ Modes: 442 │ Free En. Model: -5.2532 │ Free En. Data: -5.2512 │ Learning Rate: 0.00672
# Epoch 127/500 │ Loss: -0.0108 │ Modes: 440 │ Free En. Model: -5.2314 │ Free En. Data: -5.2440 │ Learning Rate: 0.00671
# Epoch 128/500 │ Loss: -0.0019 │ Modes: 432 │ Free En. Model: -5.1943 │ Free En. Data: -5.1933 │ Learning Rate: 0.00671
# Epoch 129/500 │ Loss: -0.0016 │ Modes: 438 │ Free En. Model: -5.2819 │ Free En. Data: -5.2752 │ Learning Rate: 0.00670
# Epoch 130/500 │ Loss: +0.0032 │ Modes: 433 │ Free En. Model: -5.2867 │ Free En. Data: -5.2650 │ Learning Rate: 0.00669
# Epoch 131/500 │ Loss: -0.0041 │ Modes: 435 │ Free En. Model: -5.2592 │ Free En. Data: -5.2522 │ Learning Rate: 0.00668
# Epoch 132/500 │ Loss: -0.0054 │ Modes: 433 │ Free En. Model: -5.2810 │ Free En. Data: -5.2815 │ Learning Rate: 0.00667
# Epoch 133/500 │ Loss: -0.0016 │ Modes: 434 │ Free En. Model: -5.3152 │ Free En. Data: -5.3124 │ Learning Rate: 0.00666
# Epoch 134/500 │ Loss: -0.0032 │ Modes: 423 │ Free En. Model: -5.2644 │ Free En. Data: -5.2733 │ Learning Rate: 0.00665
# Epoch 135/500 │ Loss: -0.0048 │ Modes: 434 │ Free En. Model: -5.3448 │ Free En. Data: -5.3662 │ Learning Rate: 0.00664
# Epoch 136/500 │ Loss: -0.0094 │ Modes: 444 │ Free En. Model: -5.3662 │ Free En. Data: -5.3865 │ Learning Rate: 0.00663
# Epoch 137/500 │ Loss: -0.0013 │ Modes: 435 │ Free En. Model: -5.3213 │ Free En. Data: -5.3404 │ Learning Rate: 0.00662
# Epoch 138/500 │ Loss: -0.0011 │ Modes: 433 │ Free En. Model: -5.3555 │ Free En. Data: -5.3441 │ Learning Rate: 0.00661
# Epoch 139/500 │ Loss: -0.0035 │ Modes: 430 │ Free En. Model: -5.3398 │ Free En. Data: -5.3313 │ Learning Rate: 0.00660
# Epoch 140/500 │ Loss: -0.0002 │ Modes: 434 │ Free En. Model: -5.4290 │ Free En. Data: -5.4312 │ Learning Rate: 0.00659
# Epoch 141/500 │ Loss: -0.0025 │ Modes: 441 │ Free En. Model: -5.3490 │ Free En. Data: -5.3460 │ Learning Rate: 0.00658
# Epoch 142/500 │ Loss: -0.0079 │ Modes: 438 │ Free En. Model: -5.4119 │ Free En. Data: -5.4192 │ Learning Rate: 0.00657
# Epoch 143/500 │ Loss: -0.0143 │ Modes: 431 │ Free En. Model: -5.4083 │ Free En. Data: -5.4256 │ Learning Rate: 0.00656
# Epoch 144/500 │ Loss: -0.0055 │ Modes: 449 │ Free En. Model: -5.3626 │ Free En. Data: -5.3743 │ Learning Rate: 0.00655
# Epoch 145/500 │ Loss: -0.0054 │ Modes: 440 │ Free En. Model: -5.4927 │ Free En. Data: -5.4976 │ Learning Rate: 0.00654
# Epoch 146/500 │ Loss: -0.0040 │ Modes: 434 │ Free En. Model: -5.4188 │ Free En. Data: -5.4173 │ Learning Rate: 0.00653
# Epoch 147/500 │ Loss: -0.0036 │ Modes: 430 │ Free En. Model: -5.4223 │ Free En. Data: -5.4267 │ Learning Rate: 0.00652
# Epoch 148/500 │ Loss: -0.0042 │ Modes: 437 │ Free En. Model: -5.4572 │ Free En. Data: -5.4563 │ Learning Rate: 0.00651
# Epoch 149/500 │ Loss: -0.0030 │ Modes: 441 │ Free En. Model: -5.5270 │ Free En. Data: -5.5290 │ Learning Rate: 0.00651
# Epoch 150/500 │ Loss: -0.0083 │ Modes: 434 │ Free En. Model: -5.4723 │ Free En. Data: -5.4649 │ Learning Rate: 0.00650
# Epoch 151/500 │ Loss: -0.0073 │ Modes: 437 │ Free En. Model: -5.4580 │ Free En. Data: -5.4664 │ Learning Rate: 0.00649
# Epoch 152/500 │ Loss: -0.0061 │ Modes: 430 │ Free En. Model: -5.4826 │ Free En. Data: -5.4887 │ Learning Rate: 0.00648
# Epoch 153/500 │ Loss: -0.0068 │ Modes: 439 │ Free En. Model: -5.5053 │ Free En. Data: -5.5240 │ Learning Rate: 0.00647
# Epoch 154/500 │ Loss: -0.0093 │ Modes: 437 │ Free En. Model: -5.5266 │ Free En. Data: -5.5424 │ Learning Rate: 0.00646
# Epoch 155/500 │ Loss: -0.0005 │ Modes: 433 │ Free En. Model: -5.4643 │ Free En. Data: -5.4826 │ Learning Rate: 0.00645
# Epoch 156/500 │ Loss: -0.0083 │ Modes: 438 │ Free En. Model: -5.6318 │ Free En. Data: -5.6427 │ Learning Rate: 0.00644
# Epoch 157/500 │ Loss: -0.0107 │ Modes: 442 │ Free En. Model: -5.5345 │ Free En. Data: -5.5648 │ Learning Rate: 0.00643
# Epoch 158/500 │ Loss: -0.0075 │ Modes: 435 │ Free En. Model: -5.5389 │ Free En. Data: -5.5619 │ Learning Rate: 0.00642
# Epoch 159/500 │ Loss: -0.0114 │ Modes: 434 │ Free En. Model: -5.5638 │ Free En. Data: -5.5658 │ Learning Rate: 0.00641
# Epoch 160/500 │ Loss: -0.0061 │ Modes: 434 │ Free En. Model: -5.5622 │ Free En. Data: -5.5623 │ Learning Rate: 0.00640
# Epoch 161/500 │ Loss: -0.0072 │ Modes: 450 │ Free En. Model: -5.5917 │ Free En. Data: -5.6149 │ Learning Rate: 0.00639
# Epoch 162/500 │ Loss: -0.0036 │ Modes: 427 │ Free En. Model: -5.6249 │ Free En. Data: -5.6348 │ Learning Rate: 0.00638
# Epoch 163/500 │ Loss: -0.0064 │ Modes: 432 │ Free En. Model: -5.6089 │ Free En. Data: -5.6177 │ Learning Rate: 0.00637
# Epoch 164/500 │ Loss: -0.0079 │ Modes: 436 │ Free En. Model: -5.6202 │ Free En. Data: -5.6380 │ Learning Rate: 0.00636
# Epoch 165/500 │ Loss: -0.0083 │ Modes: 444 │ Free En. Model: -5.7527 │ Free En. Data: -5.7656 │ Learning Rate: 0.00635
# Epoch 166/500 │ Loss: -0.0061 │ Modes: 430 │ Free En. Model: -5.6819 │ Free En. Data: -5.6983 │ Learning Rate: 0.00634
# Epoch 167/500 │ Loss: -0.0105 │ Modes: 437 │ Free En. Model: -5.6752 │ Free En. Data: -5.7074 │ Learning Rate: 0.00633
# Epoch 168/500 │ Loss: -0.0079 │ Modes: 444 │ Free En. Model: -5.7638 │ Free En. Data: -5.7702 │ Learning Rate: 0.00632
# Epoch 169/500 │ Loss: -0.0063 │ Modes: 423 │ Free En. Model: -5.6559 │ Free En. Data: -5.6603 │ Learning Rate: 0.00631
# Epoch 170/500 │ Loss: -0.0136 │ Modes: 439 │ Free En. Model: -5.7190 │ Free En. Data: -5.7326 │ Learning Rate: 0.00630
# Epoch 171/500 │ Loss: -0.0058 │ Modes: 438 │ Free En. Model: -5.7461 │ Free En. Data: -5.7647 │ Learning Rate: 0.00629
# Epoch 172/500 │ Loss: -0.0159 │ Modes: 440 │ Free En. Model: -5.6884 │ Free En. Data: -5.7107 │ Learning Rate: 0.00628
# Epoch 173/500 │ Loss: -0.0094 │ Modes: 429 │ Free En. Model: -5.7273 │ Free En. Data: -5.7379 │ Learning Rate: 0.00627
# Epoch 174/500 │ Loss: -0.0079 │ Modes: 427 │ Free En. Model: -5.7476 │ Free En. Data: -5.7461 │ Learning Rate: 0.00626
# Epoch 175/500 │ Loss: -0.0058 │ Modes: 436 │ Free En. Model: -5.7346 │ Free En. Data: -5.7351 │ Learning Rate: 0.00625
# Epoch 176/500 │ Loss: -0.0086 │ Modes: 445 │ Free En. Model: -5.7138 │ Free En. Data: -5.7609 │ Learning Rate: 0.00624
# Epoch 177/500 │ Loss: -0.0052 │ Modes: 432 │ Free En. Model: -5.7640 │ Free En. Data: -5.7744 │ Learning Rate: 0.00623
# Epoch 178/500 │ Loss: -0.0103 │ Modes: 436 │ Free En. Model: -5.7452 │ Free En. Data: -5.7768 │ Learning Rate: 0.00622
# Epoch 179/500 │ Loss: -0.0067 │ Modes: 437 │ Free En. Model: -5.7759 │ Free En. Data: -5.7994 │ Learning Rate: 0.00621
# Epoch 180/500 │ Loss: -0.0040 │ Modes: 433 │ Free En. Model: -5.8559 │ Free En. Data: -5.8555 │ Learning Rate: 0.00620
# Epoch 181/500 │ Loss: -0.0033 │ Modes: 428 │ Free En. Model: -5.7864 │ Free En. Data: -5.7947 │ Learning Rate: 0.00619
# Epoch 182/500 │ Loss: -0.0073 │ Modes: 430 │ Free En. Model: -5.8511 │ Free En. Data: -5.8822 │ Learning Rate: 0.00618
# Epoch 183/500 │ Loss: -0.0073 │ Modes: 431 │ Free En. Model: -5.8161 │ Free En. Data: -5.8547 │ Learning Rate: 0.00617
# Epoch 184/500 │ Loss: -0.0081 │ Modes: 432 │ Free En. Model: -5.8513 │ Free En. Data: -5.8489 │ Learning Rate: 0.00616
# Epoch 185/500 │ Loss: -0.0061 │ Modes: 427 │ Free En. Model: -5.9237 │ Free En. Data: -5.9442 │ Learning Rate: 0.00615
# Epoch 186/500 │ Loss: -0.0115 │ Modes: 436 │ Free En. Model: -5.8578 │ Free En. Data: -5.8484 │ Learning Rate: 0.00614
# Epoch 187/500 │ Loss: -0.0107 │ Modes: 429 │ Free En. Model: -5.7997 │ Free En. Data: -5.8157 │ Learning Rate: 0.00613
# Epoch 188/500 │ Loss: -0.0029 │ Modes: 436 │ Free En. Model: -5.8760 │ Free En. Data: -5.8736 │ Learning Rate: 0.00612
# Epoch 189/500 │ Loss: -0.0058 │ Modes: 432 │ Free En. Model: -5.9047 │ Free En. Data: -5.9276 │ Learning Rate: 0.00611
# Epoch 190/500 │ Loss: +0.0008 │ Modes: 436 │ Free En. Model: -5.9025 │ Free En. Data: -5.9075 │ Learning Rate: 0.00610
# Epoch 191/500 │ Loss: -0.0100 │ Modes: 436 │ Free En. Model: -5.9417 │ Free En. Data: -5.9331 │ Learning Rate: 0.00609
# Epoch 192/500 │ Loss: +0.0020 │ Modes: 424 │ Free En. Model: -5.9144 │ Free En. Data: -5.9064 │ Learning Rate: 0.00608
# Epoch 193/500 │ Loss: -0.0028 │ Modes: 430 │ Free En. Model: -5.8655 │ Free En. Data: -5.8972 │ Learning Rate: 0.00607
# Epoch 194/500 │ Loss: +0.0006 │ Modes: 423 │ Free En. Model: -5.9227 │ Free En. Data: -5.9342 │ Learning Rate: 0.00606
# Epoch 195/500 │ Loss: +0.0033 │ Modes: 438 │ Free En. Model: -5.9678 │ Free En. Data: -5.9395 │ Learning Rate: 0.00605
# Epoch 196/500 │ Loss: -0.0097 │ Modes: 440 │ Free En. Model: -5.9250 │ Free En. Data: -5.9456 │ Learning Rate: 0.00604
# Epoch 197/500 │ Loss: -0.0006 │ Modes: 428 │ Free En. Model: -5.9204 │ Free En. Data: -5.9280 │ Learning Rate: 0.00603
# Epoch 198/500 │ Loss: -0.0010 │ Modes: 453 │ Free En. Model: -5.9304 │ Free En. Data: -5.9601 │ Learning Rate: 0.00602
# Epoch 199/500 │ Loss: -0.0049 │ Modes: 437 │ Free En. Model: -5.9499 │ Free En. Data: -5.9542 │ Learning Rate: 0.00601
# Epoch 200/500 │ Loss: -0.0112 │ Modes: 434 │ Free En. Model: -5.8981 │ Free En. Data: -5.9018 │ Learning Rate: 0.00600
# Epoch 201/500 │ Loss: -0.0021 │ Modes: 421 │ Free En. Model: -5.9801 │ Free En. Data: -5.9878 │ Learning Rate: 0.00599
# Epoch 202/500 │ Loss: -0.0055 │ Modes: 435 │ Free En. Model: -5.9219 │ Free En. Data: -5.9554 │ Learning Rate: 0.00598
# Epoch 203/500 │ Loss: +0.0009 │ Modes: 423 │ Free En. Model: -5.9558 │ Free En. Data: -5.9363 │ Learning Rate: 0.00597
# Epoch 204/500 │ Loss: -0.0059 │ Modes: 438 │ Free En. Model: -5.9516 │ Free En. Data: -5.9546 │ Learning Rate: 0.00596
# Epoch 205/500 │ Loss: -0.0017 │ Modes: 425 │ Free En. Model: -5.8998 │ Free En. Data: -5.9030 │ Learning Rate: 0.00595
# Epoch 206/500 │ Loss: -0.0053 │ Modes: 441 │ Free En. Model: -5.9713 │ Free En. Data: -5.9789 │ Learning Rate: 0.00594
# Epoch 207/500 │ Loss: -0.0048 │ Modes: 428 │ Free En. Model: -5.9606 │ Free En. Data: -5.9753 │ Learning Rate: 0.00593
# Epoch 208/500 │ Loss: +0.0004 │ Modes: 428 │ Free En. Model: -5.9622 │ Free En. Data: -5.9747 │ Learning Rate: 0.00592
# Epoch 209/500 │ Loss: -0.0050 │ Modes: 429 │ Free En. Model: -5.9699 │ Free En. Data: -5.9805 │ Learning Rate: 0.00591
# Epoch 210/500 │ Loss: -0.0008 │ Modes: 429 │ Free En. Model: -5.8863 │ Free En. Data: -5.8939 │ Learning Rate: 0.00590
# Epoch 211/500 │ Loss: +0.0041 │ Modes: 430 │ Free En. Model: -6.0463 │ Free En. Data: -6.0346 │ Learning Rate: 0.00589
# Epoch 212/500 │ Loss: -0.0021 │ Modes: 433 │ Free En. Model: -5.9869 │ Free En. Data: -5.9708 │ Learning Rate: 0.00588
# Epoch 213/500 │ Loss: -0.0028 │ Modes: 440 │ Free En. Model: -6.0013 │ Free En. Data: -6.0148 │ Learning Rate: 0.00587
# Epoch 214/500 │ Loss: -0.0029 │ Modes: 419 │ Free En. Model: -6.0698 │ Free En. Data: -6.0790 │ Learning Rate: 0.00586
# Epoch 215/500 │ Loss: -0.0006 │ Modes: 434 │ Free En. Model: -5.8429 │ Free En. Data: -5.8489 │ Learning Rate: 0.00585
# Epoch 216/500 │ Loss: -0.0065 │ Modes: 423 │ Free En. Model: -6.0110 │ Free En. Data: -5.9929 │ Learning Rate: 0.00584
# Epoch 217/500 │ Loss: +0.0004 │ Modes: 431 │ Free En. Model: -5.9781 │ Free En. Data: -5.9800 │ Learning Rate: 0.00583
# Epoch 218/500 │ Loss: -0.0025 │ Modes: 427 │ Free En. Model: -5.9730 │ Free En. Data: -5.9863 │ Learning Rate: 0.00582
# Epoch 219/500 │ Loss: -0.0007 │ Modes: 434 │ Free En. Model: -5.9642 │ Free En. Data: -5.9675 │ Learning Rate: 0.00581
# Epoch 220/500 │ Loss: +0.0064 │ Modes: 441 │ Free En. Model: -6.0148 │ Free En. Data: -6.0249 │ Learning Rate: 0.00580
# Epoch 221/500 │ Loss: -0.0037 │ Modes: 430 │ Free En. Model: -5.9188 │ Free En. Data: -5.9177 │ Learning Rate: 0.00579
# Epoch 222/500 │ Loss: +0.0056 │ Modes: 434 │ Free En. Model: -5.9873 │ Free En. Data: -6.0141 │ Learning Rate: 0.00578
# Epoch 223/500 │ Loss: -0.0121 │ Modes: 436 │ Free En. Model: -5.9148 │ Free En. Data: -5.9379 │ Learning Rate: 0.00577
# Epoch 224/500 │ Loss: -0.0032 │ Modes: 433 │ Free En. Model: -5.9822 │ Free En. Data: -6.0020 │ Learning Rate: 0.00576
# Epoch 225/500 │ Loss: +0.0010 │ Modes: 430 │ Free En. Model: -5.9386 │ Free En. Data: -5.9502 │ Learning Rate: 0.00575
# Epoch 226/500 │ Loss: +0.0004 │ Modes: 442 │ Free En. Model: -5.9522 │ Free En. Data: -5.9467 │ Learning Rate: 0.00574
# Epoch 227/500 │ Loss: +0.0028 │ Modes: 437 │ Free En. Model: -5.9266 │ Free En. Data: -5.9594 │ Learning Rate: 0.00573
# Epoch 228/500 │ Loss: +0.0036 │ Modes: 434 │ Free En. Model: -5.9465 │ Free En. Data: -5.9398 │ Learning Rate: 0.00572
# Epoch 229/500 │ Loss: -0.0006 │ Modes: 436 │ Free En. Model: -5.9222 │ Free En. Data: -5.9612 │ Learning Rate: 0.00571
# Epoch 230/500 │ Loss: +0.0022 │ Modes: 433 │ Free En. Model: -6.0072 │ Free En. Data: -6.0170 │ Learning Rate: 0.00570
# Epoch 231/500 │ Loss: +0.0037 │ Modes: 423 │ Free En. Model: -6.0178 │ Free En. Data: -6.0107 │ Learning Rate: 0.00569
# Epoch 232/500 │ Loss: +0.0023 │ Modes: 435 │ Free En. Model: -5.9838 │ Free En. Data: -5.9735 │ Learning Rate: 0.00568
# Epoch 233/500 │ Loss: -0.0022 │ Modes: 426 │ Free En. Model: -6.0194 │ Free En. Data: -6.0225 │ Learning Rate: 0.00567
# Epoch 234/500 │ Loss: +0.0048 │ Modes: 419 │ Free En. Model: -5.9561 │ Free En. Data: -5.9298 │ Learning Rate: 0.00566
# Epoch 235/500 │ Loss: +0.0016 │ Modes: 440 │ Free En. Model: -6.0674 │ Free En. Data: -6.0843 │ Learning Rate: 0.00565
# Epoch 236/500 │ Loss: -0.0009 │ Modes: 417 │ Free En. Model: -6.0148 │ Free En. Data: -6.0031 │ Learning Rate: 0.00564
# Epoch 237/500 │ Loss: +0.0012 │ Modes: 434 │ Free En. Model: -5.9918 │ Free En. Data: -5.9826 │ Learning Rate: 0.00563
# Epoch 238/500 │ Loss: -0.0021 │ Modes: 422 │ Free En. Model: -5.9829 │ Free En. Data: -5.9900 │ Learning Rate: 0.00562
# Epoch 239/500 │ Loss: +0.0016 │ Modes: 423 │ Free En. Model: -6.0024 │ Free En. Data: -6.0046 │ Learning Rate: 0.00561
# Epoch 240/500 │ Loss: -0.0026 │ Modes: 434 │ Free En. Model: -5.9810 │ Free En. Data: -5.9633 │ Learning Rate: 0.00560
# Epoch 241/500 │ Loss: +0.0003 │ Modes: 431 │ Free En. Model: -5.9754 │ Free En. Data: -5.9801 │ Learning Rate: 0.00559
# Epoch 242/500 │ Loss: +0.0034 │ Modes: 431 │ Free En. Model: -5.9885 │ Free En. Data: -5.9961 │ Learning Rate: 0.00558
# Epoch 243/500 │ Loss: +0.0002 │ Modes: 440 │ Free En. Model: -5.9770 │ Free En. Data: -5.9925 │ Learning Rate: 0.00557
# Epoch 244/500 │ Loss: +0.0017 │ Modes: 444 │ Free En. Model: -5.9909 │ Free En. Data: -5.9931 │ Learning Rate: 0.00556
# Epoch 245/500 │ Loss: -0.0029 │ Modes: 428 │ Free En. Model: -5.9968 │ Free En. Data: -5.9995 │ Learning Rate: 0.00555
# Epoch 246/500 │ Loss: -0.0013 │ Modes: 434 │ Free En. Model: -5.9764 │ Free En. Data: -5.9827 │ Learning Rate: 0.00554
# Epoch 247/500 │ Loss: +0.0004 │ Modes: 440 │ Free En. Model: -5.9553 │ Free En. Data: -5.9810 │ Learning Rate: 0.00553
# Epoch 248/500 │ Loss: +0.0033 │ Modes: 412 │ Free En. Model: -6.0562 │ Free En. Data: -6.0393 │ Learning Rate: 0.00552
# Epoch 249/500 │ Loss: +0.0055 │ Modes: 433 │ Free En. Model: -6.0044 │ Free En. Data: -6.0004 │ Learning Rate: 0.00551
# Epoch 250/500 │ Loss: +0.0015 │ Modes: 431 │ Free En. Model: -5.9764 │ Free En. Data: -5.9792 │ Learning Rate: 0.00550
# Epoch 251/500 │ Loss: -0.0005 │ Modes: 424 │ Free En. Model: -6.0083 │ Free En. Data: -6.0074 │ Learning Rate: 0.00549
# Epoch 252/500 │ Loss: -0.0063 │ Modes: 415 │ Free En. Model: -6.0216 │ Free En. Data: -6.0125 │ Learning Rate: 0.00548
# Epoch 253/500 │ Loss: -0.0015 │ Modes: 431 │ Free En. Model: -5.9694 │ Free En. Data: -5.9728 │ Learning Rate: 0.00547
# Epoch 254/500 │ Loss: +0.0045 │ Modes: 423 │ Free En. Model: -5.9626 │ Free En. Data: -5.9818 │ Learning Rate: 0.00546
# Epoch 255/500 │ Loss: +0.0026 │ Modes: 421 │ Free En. Model: -5.9993 │ Free En. Data: -5.9816 │ Learning Rate: 0.00545
# Epoch 256/500 │ Loss: +0.0007 │ Modes: 420 │ Free En. Model: -5.9287 │ Free En. Data: -5.9317 │ Learning Rate: 0.00544
# Epoch 257/500 │ Loss: -0.0022 │ Modes: 422 │ Free En. Model: -5.9333 │ Free En. Data: -5.9166 │ Learning Rate: 0.00543
# Epoch 258/500 │ Loss: +0.0064 │ Modes: 433 │ Free En. Model: -5.9637 │ Free En. Data: -5.9811 │ Learning Rate: 0.00542
# Epoch 259/500 │ Loss: +0.0085 │ Modes: 438 │ Free En. Model: -5.9808 │ Free En. Data: -5.9755 │ Learning Rate: 0.00541
# Epoch 260/500 │ Loss: -0.0041 │ Modes: 429 │ Free En. Model: -5.9478 │ Free En. Data: -5.9603 │ Learning Rate: 0.00540
# Epoch 261/500 │ Loss: +0.0015 │ Modes: 431 │ Free En. Model: -5.9891 │ Free En. Data: -5.9960 │ Learning Rate: 0.00539
# Epoch 262/500 │ Loss: +0.0024 │ Modes: 435 │ Free En. Model: -5.9924 │ Free En. Data: -5.9705 │ Learning Rate: 0.00538
# Epoch 263/500 │ Loss: -0.0060 │ Modes: 449 │ Free En. Model: -5.9611 │ Free En. Data: -5.9809 │ Learning Rate: 0.00537
# Epoch 264/500 │ Loss: +0.0051 │ Modes: 424 │ Free En. Model: -5.9842 │ Free En. Data: -5.9748 │ Learning Rate: 0.00536
# Epoch 265/500 │ Loss: +0.0068 │ Modes: 428 │ Free En. Model: -5.9761 │ Free En. Data: -5.9728 │ Learning Rate: 0.00535
# Epoch 266/500 │ Loss: +0.0089 │ Modes: 436 │ Free En. Model: -5.9230 │ Free En. Data: -5.9017 │ Learning Rate: 0.00534
# Epoch 267/500 │ Loss: +0.0008 │ Modes: 431 │ Free En. Model: -6.0364 │ Free En. Data: -6.0390 │ Learning Rate: 0.00533
# Epoch 268/500 │ Loss: +0.0031 │ Modes: 421 │ Free En. Model: -5.9785 │ Free En. Data: -5.9719 │ Learning Rate: 0.00532
# Epoch 269/500 │ Loss: +0.0004 │ Modes: 434 │ Free En. Model: -5.9768 │ Free En. Data: -5.9717 │ Learning Rate: 0.00531
# Epoch 270/500 │ Loss: -0.0077 │ Modes: 427 │ Free En. Model: -5.9172 │ Free En. Data: -5.9323 │ Learning Rate: 0.00530
# Epoch 271/500 │ Loss: +0.0040 │ Modes: 431 │ Free En. Model: -6.0071 │ Free En. Data: -6.0115 │ Learning Rate: 0.00529
# Epoch 272/500 │ Loss: -0.0012 │ Modes: 431 │ Free En. Model: -6.0015 │ Free En. Data: -6.0161 │ Learning Rate: 0.00528
# Epoch 273/500 │ Loss: +0.0055 │ Modes: 436 │ Free En. Model: -5.8988 │ Free En. Data: -5.9056 │ Learning Rate: 0.00527
# Epoch 274/500 │ Loss: -0.0064 │ Modes: 429 │ Free En. Model: -5.9834 │ Free En. Data: -6.0038 │ Learning Rate: 0.00526
# Epoch 275/500 │ Loss: +0.0016 │ Modes: 430 │ Free En. Model: -5.9570 │ Free En. Data: -5.9639 │ Learning Rate: 0.00525
# Epoch 276/500 │ Loss: -0.0046 │ Modes: 433 │ Free En. Model: -5.9694 │ Free En. Data: -5.9819 │ Learning Rate: 0.00524
# Epoch 277/500 │ Loss: -0.0015 │ Modes: 423 │ Free En. Model: -5.9662 │ Free En. Data: -5.9632 │ Learning Rate: 0.00523
# Epoch 278/500 │ Loss: -0.0024 │ Modes: 438 │ Free En. Model: -5.9618 │ Free En. Data: -5.9759 │ Learning Rate: 0.00522
# Epoch 279/500 │ Loss: +0.0050 │ Modes: 434 │ Free En. Model: -5.9923 │ Free En. Data: -5.9818 │ Learning Rate: 0.00521
# Epoch 280/500 │ Loss: -0.0058 │ Modes: 433 │ Free En. Model: -6.0047 │ Free En. Data: -6.0229 │ Learning Rate: 0.00520
# Epoch 281/500 │ Loss: -0.0078 │ Modes: 432 │ Free En. Model: -5.9648 │ Free En. Data: -5.9669 │ Learning Rate: 0.00519
# Epoch 282/500 │ Loss: +0.0006 │ Modes: 446 │ Free En. Model: -5.9943 │ Free En. Data: -5.9826 │ Learning Rate: 0.00518
# Epoch 283/500 │ Loss: -0.0029 │ Modes: 431 │ Free En. Model: -5.9656 │ Free En. Data: -5.9842 │ Learning Rate: 0.00517
# Epoch 284/500 │ Loss: -0.0043 │ Modes: 432 │ Free En. Model: -6.0099 │ Free En. Data: -6.0381 │ Learning Rate: 0.00516
# Epoch 285/500 │ Loss: -0.0013 │ Modes: 429 │ Free En. Model: -6.0144 │ Free En. Data: -6.0045 │ Learning Rate: 0.00515
# Epoch 286/500 │ Loss: +0.0015 │ Modes: 425 │ Free En. Model: -6.0231 │ Free En. Data: -6.0027 │ Learning Rate: 0.00514
# Epoch 287/500 │ Loss: -0.0003 │ Modes: 429 │ Free En. Model: -5.9884 │ Free En. Data: -5.9941 │ Learning Rate: 0.00513
# Epoch 288/500 │ Loss: -0.0005 │ Modes: 423 │ Free En. Model: -6.0074 │ Free En. Data: -6.0280 │ Learning Rate: 0.00512
# Epoch 289/500 │ Loss: +0.0046 │ Modes: 431 │ Free En. Model: -5.9981 │ Free En. Data: -6.0060 │ Learning Rate: 0.00511
# Epoch 290/500 │ Loss: +0.0042 │ Modes: 437 │ Free En. Model: -5.9813 │ Free En. Data: -5.9982 │ Learning Rate: 0.00510
# Epoch 291/500 │ Loss: -0.0013 │ Modes: 443 │ Free En. Model: -5.9371 │ Free En. Data: -5.9287 │ Learning Rate: 0.00509
# Epoch 292/500 │ Loss: +0.0052 │ Modes: 427 │ Free En. Model: -6.0054 │ Free En. Data: -6.0109 │ Learning Rate: 0.00508
# Epoch 293/500 │ Loss: +0.0023 │ Modes: 436 │ Free En. Model: -6.0510 │ Free En. Data: -6.0695 │ Learning Rate: 0.00507
# Epoch 294/500 │ Loss: +0.0033 │ Modes: 432 │ Free En. Model: -5.9350 │ Free En. Data: -5.9518 │ Learning Rate: 0.00506
# Epoch 295/500 │ Loss: +0.0005 │ Modes: 433 │ Free En. Model: -6.0343 │ Free En. Data: -6.0363 │ Learning Rate: 0.00505
# Epoch 296/500 │ Loss: +0.0027 │ Modes: 420 │ Free En. Model: -6.0131 │ Free En. Data: -6.0142 │ Learning Rate: 0.00504
# Epoch 297/500 │ Loss: -0.0018 │ Modes: 426 │ Free En. Model: -5.9484 │ Free En. Data: -5.9462 │ Learning Rate: 0.00503
# Epoch 298/500 │ Loss: -0.0018 │ Modes: 427 │ Free En. Model: -5.9783 │ Free En. Data: -5.9903 │ Learning Rate: 0.00502
# Epoch 299/500 │ Loss: +0.0087 │ Modes: 425 │ Free En. Model: -6.0530 │ Free En. Data: -6.0663 │ Learning Rate: 0.00501
# Epoch 300/500 │ Loss: -0.0027 │ Modes: 447 │ Free En. Model: -5.9831 │ Free En. Data: -5.9894 │ Learning Rate: 0.00500
# Epoch 301/500 │ Loss: +0.0001 │ Modes: 422 │ Free En. Model: -6.0006 │ Free En. Data: -6.0186 │ Learning Rate: 0.00499
# Epoch 302/500 │ Loss: +0.0033 │ Modes: 432 │ Free En. Model: -6.0106 │ Free En. Data: -5.9977 │ Learning Rate: 0.00498
# Epoch 303/500 │ Loss: +0.0007 │ Modes: 425 │ Free En. Model: -5.9614 │ Free En. Data: -5.9513 │ Learning Rate: 0.00497
# Epoch 304/500 │ Loss: -0.0028 │ Modes: 427 │ Free En. Model: -6.0209 │ Free En. Data: -6.0428 │ Learning Rate: 0.00496
# Epoch 305/500 │ Loss: -0.0008 │ Modes: 428 │ Free En. Model: -5.9923 │ Free En. Data: -5.9811 │ Learning Rate: 0.00495
# Epoch 306/500 │ Loss: -0.0013 │ Modes: 439 │ Free En. Model: -5.9935 │ Free En. Data: -6.0043 │ Learning Rate: 0.00494
# Epoch 307/500 │ Loss: -0.0030 │ Modes: 427 │ Free En. Model: -6.0647 │ Free En. Data: -6.0522 │ Learning Rate: 0.00493
# Epoch 308/500 │ Loss: +0.0001 │ Modes: 428 │ Free En. Model: -5.9447 │ Free En. Data: -5.9486 │ Learning Rate: 0.00492
# Epoch 309/500 │ Loss: -0.0024 │ Modes: 421 │ Free En. Model: -5.9792 │ Free En. Data: -5.9912 │ Learning Rate: 0.00491
# Epoch 310/500 │ Loss: +0.0041 │ Modes: 437 │ Free En. Model: -6.0077 │ Free En. Data: -6.0260 │ Learning Rate: 0.00490
# Epoch 311/500 │ Loss: +0.0015 │ Modes: 422 │ Free En. Model: -5.9885 │ Free En. Data: -5.9901 │ Learning Rate: 0.00489
# Epoch 312/500 │ Loss: +0.0036 │ Modes: 434 │ Free En. Model: -5.9360 │ Free En. Data: -5.9259 │ Learning Rate: 0.00488
# Epoch 313/500 │ Loss: +0.0010 │ Modes: 431 │ Free En. Model: -5.9749 │ Free En. Data: -5.9962 │ Learning Rate: 0.00487
# Epoch 314/500 │ Loss: -0.0070 │ Modes: 441 │ Free En. Model: -5.9879 │ Free En. Data: -5.9893 │ Learning Rate: 0.00486
# Epoch 315/500 │ Loss: -0.0023 │ Modes: 441 │ Free En. Model: -5.9914 │ Free En. Data: -6.0118 │ Learning Rate: 0.00485
# Epoch 316/500 │ Loss: +0.0027 │ Modes: 432 │ Free En. Model: -6.0149 │ Free En. Data: -5.9845 │ Learning Rate: 0.00484
# Epoch 317/500 │ Loss: +0.0042 │ Modes: 418 │ Free En. Model: -5.9721 │ Free En. Data: -5.9502 │ Learning Rate: 0.00483
# Epoch 318/500 │ Loss: -0.0014 │ Modes: 431 │ Free En. Model: -5.9454 │ Free En. Data: -5.9451 │ Learning Rate: 0.00482
# Epoch 319/500 │ Loss: +0.0039 │ Modes: 432 │ Free En. Model: -5.9722 │ Free En. Data: -5.9656 │ Learning Rate: 0.00481
# Epoch 320/500 │ Loss: +0.0011 │ Modes: 422 │ Free En. Model: -5.9662 │ Free En. Data: -5.9547 │ Learning Rate: 0.00480
# Epoch 321/500 │ Loss: -0.0015 │ Modes: 428 │ Free En. Model: -6.0307 │ Free En. Data: -6.0401 │ Learning Rate: 0.00479
# Epoch 322/500 │ Loss: +0.0012 │ Modes: 433 │ Free En. Model: -5.9565 │ Free En. Data: -5.9780 │ Learning Rate: 0.00478
# Epoch 323/500 │ Loss: -0.0002 │ Modes: 427 │ Free En. Model: -5.9839 │ Free En. Data: -5.9924 │ Learning Rate: 0.00477
# Epoch 324/500 │ Loss: +0.0118 │ Modes: 429 │ Free En. Model: -6.0304 │ Free En. Data: -5.9978 │ Learning Rate: 0.00476
# Epoch 325/500 │ Loss: +0.0025 │ Modes: 419 │ Free En. Model: -5.9689 │ Free En. Data: -5.9709 │ Learning Rate: 0.00475
# Epoch 326/500 │ Loss: +0.0034 │ Modes: 420 │ Free En. Model: -5.9951 │ Free En. Data: -5.9722 │ Learning Rate: 0.00474
# Epoch 327/500 │ Loss: +0.0037 │ Modes: 431 │ Free En. Model: -6.0407 │ Free En. Data: -6.0353 │ Learning Rate: 0.00473
# Epoch 328/500 │ Loss: -0.0049 │ Modes: 426 │ Free En. Model: -6.0033 │ Free En. Data: -6.0067 │ Learning Rate: 0.00472
# Epoch 329/500 │ Loss: +0.0063 │ Modes: 419 │ Free En. Model: -6.0701 │ Free En. Data: -6.0569 │ Learning Rate: 0.00471
# Epoch 330/500 │ Loss: -0.0028 │ Modes: 431 │ Free En. Model: -5.9593 │ Free En. Data: -5.9498 │ Learning Rate: 0.00470
# Epoch 331/500 │ Loss: -0.0053 │ Modes: 435 │ Free En. Model: -5.9542 │ Free En. Data: -5.9714 │ Learning Rate: 0.00469
# Epoch 332/500 │ Loss: +0.0075 │ Modes: 430 │ Free En. Model: -5.9833 │ Free En. Data: -5.9943 │ Learning Rate: 0.00468
# Epoch 333/500 │ Loss: +0.0036 │ Modes: 428 │ Free En. Model: -6.0312 │ Free En. Data: -6.0295 │ Learning Rate: 0.00467
# Epoch 334/500 │ Loss: +0.0045 │ Modes: 422 │ Free En. Model: -5.9953 │ Free En. Data: -5.9705 │ Learning Rate: 0.00466
# Epoch 335/500 │ Loss: -0.0074 │ Modes: 435 │ Free En. Model: -5.9943 │ Free En. Data: -5.9797 │ Learning Rate: 0.00465
# Epoch 336/500 │ Loss: -0.0009 │ Modes: 433 │ Free En. Model: -5.9611 │ Free En. Data: -5.9549 │ Learning Rate: 0.00464
# Epoch 337/500 │ Loss: -0.0027 │ Modes: 435 │ Free En. Model: -5.9761 │ Free En. Data: -5.9980 │ Learning Rate: 0.00463
# Epoch 338/500 │ Loss: +0.0056 │ Modes: 433 │ Free En. Model: -6.0295 │ Free En. Data: -6.0236 │ Learning Rate: 0.00462
# Epoch 339/500 │ Loss: +0.0011 │ Modes: 433 │ Free En. Model: -6.0202 │ Free En. Data: -6.0665 │ Learning Rate: 0.00461
# Epoch 340/500 │ Loss: +0.0004 │ Modes: 429 │ Free En. Model: -6.0227 │ Free En. Data: -6.0173 │ Learning Rate: 0.00460
# Epoch 341/500 │ Loss: +0.0019 │ Modes: 429 │ Free En. Model: -5.9840 │ Free En. Data: -6.0002 │ Learning Rate: 0.00459
# Epoch 342/500 │ Loss: -0.0020 │ Modes: 419 │ Free En. Model: -6.0121 │ Free En. Data: -6.0082 │ Learning Rate: 0.00458
# Epoch 343/500 │ Loss: +0.0026 │ Modes: 420 │ Free En. Model: -5.9876 │ Free En. Data: -5.9833 │ Learning Rate: 0.00457
# Epoch 344/500 │ Loss: -0.0010 │ Modes: 421 │ Free En. Model: -5.9863 │ Free En. Data: -5.9826 │ Learning Rate: 0.00456
# Epoch 345/500 │ Loss: -0.0021 │ Modes: 444 │ Free En. Model: -5.9531 │ Free En. Data: -5.9915 │ Learning Rate: 0.00455
# Epoch 346/500 │ Loss: -0.0073 │ Modes: 436 │ Free En. Model: -6.0278 │ Free En. Data: -6.0539 │ Learning Rate: 0.00454
# Epoch 347/500 │ Loss: +0.0045 │ Modes: 426 │ Free En. Model: -6.0622 │ Free En. Data: -6.0611 │ Learning Rate: 0.00453
# Epoch 348/500 │ Loss: +0.0041 │ Modes: 432 │ Free En. Model: -5.9720 │ Free En. Data: -5.9774 │ Learning Rate: 0.00452
# Epoch 349/500 │ Loss: -0.0023 │ Modes: 436 │ Free En. Model: -5.9939 │ Free En. Data: -5.9717 │ Learning Rate: 0.00451
# Epoch 350/500 │ Loss: +0.0008 │ Modes: 433 │ Free En. Model: -6.0006 │ Free En. Data: -5.9946 │ Learning Rate: 0.00450
# Epoch 351/500 │ Loss: +0.0017 │ Modes: 432 │ Free En. Model: -6.0221 │ Free En. Data: -6.0547 │ Learning Rate: 0.00449
# Epoch 352/500 │ Loss: +0.0087 │ Modes: 422 │ Free En. Model: -6.0214 │ Free En. Data: -5.9907 │ Learning Rate: 0.00449
# Epoch 353/500 │ Loss: +0.0031 │ Modes: 430 │ Free En. Model: -6.0097 │ Free En. Data: -6.0035 │ Learning Rate: 0.00448
# Epoch 354/500 │ Loss: +0.0031 │ Modes: 432 │ Free En. Model: -5.9924 │ Free En. Data: -5.9709 │ Learning Rate: 0.00447
# Epoch 355/500 │ Loss: +0.0019 │ Modes: 426 │ Free En. Model: -6.0225 │ Free En. Data: -6.0225 │ Learning Rate: 0.00446
# Epoch 356/500 │ Loss: -0.0018 │ Modes: 426 │ Free En. Model: -6.0105 │ Free En. Data: -6.0185 │ Learning Rate: 0.00445
# Epoch 357/500 │ Loss: -0.0009 │ Modes: 429 │ Free En. Model: -6.0417 │ Free En. Data: -6.0274 │ Learning Rate: 0.00444
# Epoch 358/500 │ Loss: +0.0009 │ Modes: 438 │ Free En. Model: -6.0320 │ Free En. Data: -6.0345 │ Learning Rate: 0.00443
# Epoch 359/500 │ Loss: +0.0015 │ Modes: 413 │ Free En. Model: -6.0372 │ Free En. Data: -6.0330 │ Learning Rate: 0.00442
# Epoch 360/500 │ Loss: +0.0009 │ Modes: 424 │ Free En. Model: -5.9887 │ Free En. Data: -5.9852 │ Learning Rate: 0.00441
# Epoch 361/500 │ Loss: -0.0040 │ Modes: 422 │ Free En. Model: -6.0430 │ Free En. Data: -6.0460 │ Learning Rate: 0.00440
# Epoch 362/500 │ Loss: +0.0006 │ Modes: 423 │ Free En. Model: -6.0386 │ Free En. Data: -6.0431 │ Learning Rate: 0.00439
# Epoch 363/500 │ Loss: -0.0013 │ Modes: 429 │ Free En. Model: -6.0007 │ Free En. Data: -6.0290 │ Learning Rate: 0.00438
# Epoch 364/500 │ Loss: +0.0022 │ Modes: 415 │ Free En. Model: -5.9915 │ Free En. Data: -5.9695 │ Learning Rate: 0.00437
# Epoch 365/500 │ Loss: +0.0012 │ Modes: 417 │ Free En. Model: -5.9636 │ Free En. Data: -5.9708 │ Learning Rate: 0.00436
# Epoch 366/500 │ Loss: +0.0031 │ Modes: 438 │ Free En. Model: -6.0385 │ Free En. Data: -6.0401 │ Learning Rate: 0.00435
# Epoch 367/500 │ Loss: +0.0010 │ Modes: 427 │ Free En. Model: -6.0335 │ Free En. Data: -6.0383 │ Learning Rate: 0.00434
# Epoch 368/500 │ Loss: -0.0072 │ Modes: 428 │ Free En. Model: -5.9724 │ Free En. Data: -5.9665 │ Learning Rate: 0.00433
# Epoch 369/500 │ Loss: +0.0085 │ Modes: 422 │ Free En. Model: -6.0560 │ Free En. Data: -6.0544 │ Learning Rate: 0.00432
# Epoch 370/500 │ Loss: +0.0078 │ Modes: 424 │ Free En. Model: -6.0885 │ Free En. Data: -6.0987 │ Learning Rate: 0.00431
# Epoch 371/500 │ Loss: -0.0059 │ Modes: 425 │ Free En. Model: -6.0584 │ Free En. Data: -6.0694 │ Learning Rate: 0.00430
# Epoch 372/500 │ Loss: -0.0004 │ Modes: 428 │ Free En. Model: -5.9972 │ Free En. Data: -5.9758 │ Learning Rate: 0.00429
# Epoch 373/500 │ Loss: -0.0023 │ Modes: 425 │ Free En. Model: -5.9903 │ Free En. Data: -5.9814 │ Learning Rate: 0.00429
# Epoch 374/500 │ Loss: +0.0029 │ Modes: 427 │ Free En. Model: -6.0322 │ Free En. Data: -6.0272 │ Learning Rate: 0.00428
# Epoch 375/500 │ Loss: +0.0010 │ Modes: 420 │ Free En. Model: -5.9956 │ Free En. Data: -5.9653 │ Learning Rate: 0.00427
# Epoch 376/500 │ Loss: +0.0047 │ Modes: 419 │ Free En. Model: -6.0407 │ Free En. Data: -6.0304 │ Learning Rate: 0.00426
# Epoch 377/500 │ Loss: -0.0005 │ Modes: 423 │ Free En. Model: -6.0400 │ Free En. Data: -6.0359 │ Learning Rate: 0.00425
# Epoch 378/500 │ Loss: +0.0019 │ Modes: 435 │ Free En. Model: -6.0501 │ Free En. Data: -6.0370 │ Learning Rate: 0.00424
# Epoch 379/500 │ Loss: -0.0022 │ Modes: 436 │ Free En. Model: -6.0162 │ Free En. Data: -5.9990 │ Learning Rate: 0.00423
# Epoch 380/500 │ Loss: -0.0010 │ Modes: 437 │ Free En. Model: -6.0497 │ Free En. Data: -6.0472 │ Learning Rate: 0.00422
# Epoch 381/500 │ Loss: -0.0008 │ Modes: 429 │ Free En. Model: -6.0501 │ Free En. Data: -6.0688 │ Learning Rate: 0.00421
# Epoch 382/500 │ Loss: -0.0016 │ Modes: 437 │ Free En. Model: -5.9995 │ Free En. Data: -5.9928 │ Learning Rate: 0.00420
# Epoch 383/500 │ Loss: -0.0023 │ Modes: 439 │ Free En. Model: -6.0485 │ Free En. Data: -6.0734 │ Learning Rate: 0.00419
# Epoch 384/500 │ Loss: -0.0049 │ Modes: 427 │ Free En. Model: -6.0289 │ Free En. Data: -6.0178 │ Learning Rate: 0.00418
# Epoch 385/500 │ Loss: +0.0007 │ Modes: 427 │ Free En. Model: -6.0273 │ Free En. Data: -6.0344 │ Learning Rate: 0.00417
# Epoch 386/500 │ Loss: -0.0013 │ Modes: 429 │ Free En. Model: -5.9857 │ Free En. Data: -6.0025 │ Learning Rate: 0.00416
# Epoch 387/500 │ Loss: -0.0030 │ Modes: 421 │ Free En. Model: -6.0395 │ Free En. Data: -6.0379 │ Learning Rate: 0.00416
# Epoch 388/500 │ Loss: +0.0056 │ Modes: 435 │ Free En. Model: -6.0127 │ Free En. Data: -5.9979 │ Learning Rate: 0.00415
# Epoch 389/500 │ Loss: -0.0013 │ Modes: 434 │ Free En. Model: -6.0453 │ Free En. Data: -6.0257 │ Learning Rate: 0.00414
# Epoch 390/500 │ Loss: +0.0030 │ Modes: 420 │ Free En. Model: -6.0809 │ Free En. Data: -6.0527 │ Learning Rate: 0.00413
# Epoch 391/500 │ Loss: -0.0005 │ Modes: 432 │ Free En. Model: -6.0181 │ Free En. Data: -5.9944 │ Learning Rate: 0.00412
# Epoch 392/500 │ Loss: +0.0011 │ Modes: 423 │ Free En. Model: -6.0144 │ Free En. Data: -6.0088 │ Learning Rate: 0.00411
# Epoch 393/500 │ Loss: -0.0015 │ Modes: 426 │ Free En. Model: -6.0235 │ Free En. Data: -6.0480 │ Learning Rate: 0.00410
# Epoch 394/500 │ Loss: -0.0064 │ Modes: 427 │ Free En. Model: -6.0486 │ Free En. Data: -6.0852 │ Learning Rate: 0.00409
# Epoch 395/500 │ Loss: -0.0003 │ Modes: 435 │ Free En. Model: -6.0026 │ Free En. Data: -6.0027 │ Learning Rate: 0.00408
# Epoch 396/500 │ Loss: +0.0063 │ Modes: 429 │ Free En. Model: -6.0258 │ Free En. Data: -6.0127 │ Learning Rate: 0.00407
# Epoch 397/500 │ Loss: +0.0030 │ Modes: 437 │ Free En. Model: -6.0283 │ Free En. Data: -6.0428 │ Learning Rate: 0.00406
# Epoch 398/500 │ Loss: -0.0008 │ Modes: 432 │ Free En. Model: -6.0710 │ Free En. Data: -6.0632 │ Learning Rate: 0.00405
# Epoch 399/500 │ Loss: +0.0003 │ Modes: 432 │ Free En. Model: -6.0774 │ Free En. Data: -6.0856 │ Learning Rate: 0.00405
# Epoch 400/500 │ Loss: +0.0036 │ Modes: 426 │ Free En. Model: -6.1344 │ Free En. Data: -6.1427 │ Learning Rate: 0.00404
# Epoch 401/500 │ Loss: -0.0010 │ Modes: 428 │ Free En. Model: -6.0700 │ Free En. Data: -6.0852 │ Learning Rate: 0.00403
# Epoch 402/500 │ Loss: -0.0002 │ Modes: 436 │ Free En. Model: -6.0230 │ Free En. Data: -6.0401 │ Learning Rate: 0.00402
# Epoch 403/500 │ Loss: -0.0014 │ Modes: 437 │ Free En. Model: -6.0840 │ Free En. Data: -6.0781 │ Learning Rate: 0.00401
# Epoch 404/500 │ Loss: +0.0036 │ Modes: 431 │ Free En. Model: -6.0319 │ Free En. Data: -6.0330 │ Learning Rate: 0.00400
# Epoch 405/500 │ Loss: -0.0020 │ Modes: 419 │ Free En. Model: -6.0207 │ Free En. Data: -6.0257 │ Learning Rate: 0.00399
# Epoch 406/500 │ Loss: +0.0001 │ Modes: 423 │ Free En. Model: -5.9932 │ Free En. Data: -6.0080 │ Learning Rate: 0.00398
# Epoch 407/500 │ Loss: +0.0052 │ Modes: 430 │ Free En. Model: -6.0671 │ Free En. Data: -6.0449 │ Learning Rate: 0.00397
# Epoch 408/500 │ Loss: +0.0017 │ Modes: 440 │ Free En. Model: -6.0708 │ Free En. Data: -6.0989 │ Learning Rate: 0.00396
# Epoch 409/500 │ Loss: -0.0106 │ Modes: 433 │ Free En. Model: -6.0359 │ Free En. Data: -6.0424 │ Learning Rate: 0.00396
# Epoch 410/500 │ Loss: -0.0038 │ Modes: 432 │ Free En. Model: -6.0750 │ Free En. Data: -6.0625 │ Learning Rate: 0.00395
# Epoch 411/500 │ Loss: +0.0015 │ Modes: 427 │ Free En. Model: -6.0407 │ Free En. Data: -6.0265 │ Learning Rate: 0.00394
# Epoch 412/500 │ Loss: -0.0025 │ Modes: 421 │ Free En. Model: -6.0302 │ Free En. Data: -6.0050 │ Learning Rate: 0.00393
# Epoch 413/500 │ Loss: +0.0073 │ Modes: 430 │ Free En. Model: -6.0006 │ Free En. Data: -6.0221 │ Learning Rate: 0.00392
# Epoch 414/500 │ Loss: -0.0016 │ Modes: 433 │ Free En. Model: -6.0448 │ Free En. Data: -6.0472 │ Learning Rate: 0.00391
# Epoch 415/500 │ Loss: +0.0039 │ Modes: 420 │ Free En. Model: -6.0267 │ Free En. Data: -6.0150 │ Learning Rate: 0.00390
# Epoch 416/500 │ Loss: -0.0038 │ Modes: 422 │ Free En. Model: -6.0325 │ Free En. Data: -6.0242 │ Learning Rate: 0.00389
# Epoch 417/500 │ Loss: +0.0065 │ Modes: 432 │ Free En. Model: -6.0899 │ Free En. Data: -6.1241 │ Learning Rate: 0.00388
# Epoch 418/500 │ Loss: +0.0019 │ Modes: 444 │ Free En. Model: -6.0325 │ Free En. Data: -6.0457 │ Learning Rate: 0.00388
# Epoch 419/500 │ Loss: -0.0027 │ Modes: 431 │ Free En. Model: -5.9502 │ Free En. Data: -5.9707 │ Learning Rate: 0.00387
# Epoch 420/500 │ Loss: +0.0066 │ Modes: 428 │ Free En. Model: -6.0275 │ Free En. Data: -6.0233 │ Learning Rate: 0.00386
# Epoch 421/500 │ Loss: +0.0035 │ Modes: 436 │ Free En. Model: -6.0381 │ Free En. Data: -6.0477 │ Learning Rate: 0.00385
# Epoch 422/500 │ Loss: +0.0053 │ Modes: 422 │ Free En. Model: -6.0990 │ Free En. Data: -6.0985 │ Learning Rate: 0.00384
# Epoch 423/500 │ Loss: +0.0020 │ Modes: 436 │ Free En. Model: -6.0465 │ Free En. Data: -6.0571 │ Learning Rate: 0.00383
# Epoch 424/500 │ Loss: +0.0036 │ Modes: 429 │ Free En. Model: -5.9972 │ Free En. Data: -6.0058 │ Learning Rate: 0.00382
# Epoch 425/500 │ Loss: +0.0034 │ Modes: 430 │ Free En. Model: -6.0357 │ Free En. Data: -6.0290 │ Learning Rate: 0.00381
# Epoch 426/500 │ Loss: -0.0105 │ Modes: 435 │ Free En. Model: -6.0318 │ Free En. Data: -6.0296 │ Learning Rate: 0.00381
# Epoch 427/500 │ Loss: +0.0026 │ Modes: 428 │ Free En. Model: -6.0228 │ Free En. Data: -6.0317 │ Learning Rate: 0.00380
# Epoch 428/500 │ Loss: +0.0046 │ Modes: 438 │ Free En. Model: -6.0734 │ Free En. Data: -6.0638 │ Learning Rate: 0.00379
# Epoch 429/500 │ Loss: +0.0014 │ Modes: 433 │ Free En. Model: -6.0429 │ Free En. Data: -6.0686 │ Learning Rate: 0.00378
# Epoch 430/500 │ Loss: -0.0054 │ Modes: 426 │ Free En. Model: -6.0236 │ Free En. Data: -6.0379 │ Learning Rate: 0.00377
# Epoch 431/500 │ Loss: +0.0030 │ Modes: 434 │ Free En. Model: -6.0064 │ Free En. Data: -5.9991 │ Learning Rate: 0.00376
# Epoch 432/500 │ Loss: -0.0048 │ Modes: 432 │ Free En. Model: -5.9961 │ Free En. Data: -6.0268 │ Learning Rate: 0.00375
# Epoch 433/500 │ Loss: -0.0050 │ Modes: 427 │ Free En. Model: -6.0774 │ Free En. Data: -6.0647 │ Learning Rate: 0.00375
# Epoch 434/500 │ Loss: +0.0071 │ Modes: 415 │ Free En. Model: -6.0192 │ Free En. Data: -6.0049 │ Learning Rate: 0.00374
# Epoch 435/500 │ Loss: +0.0035 │ Modes: 434 │ Free En. Model: -6.0053 │ Free En. Data: -6.0040 │ Learning Rate: 0.00373
# Epoch 436/500 │ Loss: -0.0012 │ Modes: 428 │ Free En. Model: -6.0726 │ Free En. Data: -6.0625 │ Learning Rate: 0.00372
# Epoch 437/500 │ Loss: -0.0056 │ Modes: 428 │ Free En. Model: -6.0214 │ Free En. Data: -6.0338 │ Learning Rate: 0.00371
# Epoch 438/500 │ Loss: -0.0022 │ Modes: 440 │ Free En. Model: -5.9424 │ Free En. Data: -5.9684 │ Learning Rate: 0.00370
# Epoch 439/500 │ Loss: +0.0046 │ Modes: 435 │ Free En. Model: -5.9978 │ Free En. Data: -5.9952 │ Learning Rate: 0.00369
# Epoch 440/500 │ Loss: +0.0020 │ Modes: 425 │ Free En. Model: -6.0253 │ Free En. Data: -6.0315 │ Learning Rate: 0.00369
# Epoch 441/500 │ Loss: -0.0070 │ Modes: 433 │ Free En. Model: -6.0285 │ Free En. Data: -6.0680 │ Learning Rate: 0.00368
# Epoch 442/500 │ Loss: +0.0022 │ Modes: 439 │ Free En. Model: -6.0346 │ Free En. Data: -6.0331 │ Learning Rate: 0.00367
# Epoch 443/500 │ Loss: -0.0016 │ Modes: 423 │ Free En. Model: -6.0020 │ Free En. Data: -6.0135 │ Learning Rate: 0.00366
# Epoch 444/500 │ Loss: -0.0046 │ Modes: 433 │ Free En. Model: -6.0113 │ Free En. Data: -6.0196 │ Learning Rate: 0.00365
# Epoch 445/500 │ Loss: -0.0035 │ Modes: 438 │ Free En. Model: -6.0341 │ Free En. Data: -6.0267 │ Learning Rate: 0.00364
# Epoch 446/500 │ Loss: +0.0095 │ Modes: 434 │ Free En. Model: -6.0284 │ Free En. Data: -6.0278 │ Learning Rate: 0.00363
# Epoch 447/500 │ Loss: +0.0011 │ Modes: 427 │ Free En. Model: -6.0225 │ Free En. Data: -6.0213 │ Learning Rate: 0.00363
# Epoch 448/500 │ Loss: -0.0021 │ Modes: 438 │ Free En. Model: -6.0271 │ Free En. Data: -6.0285 │ Learning Rate: 0.00362
# Epoch 449/500 │ Loss: +0.0026 │ Modes: 427 │ Free En. Model: -6.0181 │ Free En. Data: -6.0250 │ Learning Rate: 0.00361
# Epoch 450/500 │ Loss: +0.0011 │ Modes: 430 │ Free En. Model: -6.0379 │ Free En. Data: -6.0591 │ Learning Rate: 0.00360
# Epoch 451/500 │ Loss: +0.0017 │ Modes: 441 │ Free En. Model: -6.0432 │ Free En. Data: -6.0349 │ Learning Rate: 0.00359
# Epoch 452/500 │ Loss: +0.0045 │ Modes: 424 │ Free En. Model: -6.0647 │ Free En. Data: -6.0621 │ Learning Rate: 0.00358
# Epoch 453/500 │ Loss: -0.0018 │ Modes: 431 │ Free En. Model: -6.0361 │ Free En. Data: -6.0398 │ Learning Rate: 0.00358
# Epoch 454/500 │ Loss: +0.0006 │ Modes: 428 │ Free En. Model: -6.0188 │ Free En. Data: -6.0183 │ Learning Rate: 0.00357
# Epoch 455/500 │ Loss: +0.0008 │ Modes: 425 │ Free En. Model: -6.0097 │ Free En. Data: -6.0129 │ Learning Rate: 0.00356
# Epoch 456/500 │ Loss: -0.0025 │ Modes: 431 │ Free En. Model: -6.0073 │ Free En. Data: -6.0179 │ Learning Rate: 0.00355
# Epoch 457/500 │ Loss: -0.0018 │ Modes: 430 │ Free En. Model: -6.0354 │ Free En. Data: -6.0398 │ Learning Rate: 0.00354
# Epoch 458/500 │ Loss: -0.0043 │ Modes: 433 │ Free En. Model: -6.0186 │ Free En. Data: -6.0291 │ Learning Rate: 0.00354
# Epoch 459/500 │ Loss: +0.0067 │ Modes: 426 │ Free En. Model: -5.9965 │ Free En. Data: -5.9784 │ Learning Rate: 0.00353
# Epoch 460/500 │ Loss: +0.0008 │ Modes: 429 │ Free En. Model: -6.0543 │ Free En. Data: -6.0572 │ Learning Rate: 0.00352
# Epoch 461/500 │ Loss: +0.0073 │ Modes: 427 │ Free En. Model: -6.0527 │ Free En. Data: -6.0478 │ Learning Rate: 0.00351
# Epoch 462/500 │ Loss: +0.0029 │ Modes: 426 │ Free En. Model: -6.0290 │ Free En. Data: -6.0315 │ Learning Rate: 0.00350
# Epoch 463/500 │ Loss: -0.0031 │ Modes: 428 │ Free En. Model: -5.9717 │ Free En. Data: -5.9723 │ Learning Rate: 0.00349
# Epoch 464/500 │ Loss: -0.0017 │ Modes: 430 │ Free En. Model: -5.9999 │ Free En. Data: -6.0176 │ Learning Rate: 0.00349
# Epoch 465/500 │ Loss: +0.0027 │ Modes: 420 │ Free En. Model: -6.0912 │ Free En. Data: -6.1025 │ Learning Rate: 0.00348
# Epoch 466/500 │ Loss: +0.0037 │ Modes: 434 │ Free En. Model: -6.0379 │ Free En. Data: -6.0438 │ Learning Rate: 0.00347
# Epoch 467/500 │ Loss: +0.0001 │ Modes: 437 │ Free En. Model: -5.9866 │ Free En. Data: -5.9815 │ Learning Rate: 0.00346
# Epoch 468/500 │ Loss: -0.0032 │ Modes: 435 │ Free En. Model: -6.0121 │ Free En. Data: -6.0070 │ Learning Rate: 0.00345
# Epoch 469/500 │ Loss: -0.0038 │ Modes: 418 │ Free En. Model: -6.0240 │ Free En. Data: -6.0262 │ Learning Rate: 0.00345
# Epoch 470/500 │ Loss: -0.0021 │ Modes: 436 │ Free En. Model: -5.9793 │ Free En. Data: -5.9923 │ Learning Rate: 0.00344
# Epoch 471/500 │ Loss: -0.0069 │ Modes: 442 │ Free En. Model: -5.9860 │ Free En. Data: -6.0070 │ Learning Rate: 0.00343
# Epoch 472/500 │ Loss: +0.0044 │ Modes: 432 │ Free En. Model: -6.0734 │ Free En. Data: -6.0572 │ Learning Rate: 0.00342
# Epoch 473/500 │ Loss: -0.0012 │ Modes: 439 │ Free En. Model: -6.0301 │ Free En. Data: -6.0513 │ Learning Rate: 0.00341
# Epoch 474/500 │ Loss: +0.0054 │ Modes: 429 │ Free En. Model: -6.0184 │ Free En. Data: -6.0026 │ Learning Rate: 0.00341
# Epoch 475/500 │ Loss: +0.0008 │ Modes: 433 │ Free En. Model: -5.9990 │ Free En. Data: -6.0069 │ Learning Rate: 0.00340
# Epoch 476/500 │ Loss: +0.0035 │ Modes: 435 │ Free En. Model: -6.0172 │ Free En. Data: -6.0407 │ Learning Rate: 0.00339
# Epoch 477/500 │ Loss: +0.0030 │ Modes: 425 │ Free En. Model: -6.0457 │ Free En. Data: -6.0472 │ Learning Rate: 0.00338
# Epoch 478/500 │ Loss: +0.0020 │ Modes: 420 │ Free En. Model: -6.0418 │ Free En. Data: -6.0379 │ Learning Rate: 0.00337
# Epoch 479/500 │ Loss: +0.0010 │ Modes: 426 │ Free En. Model: -6.0178 │ Free En. Data: -6.0264 │ Learning Rate: 0.00337
# Epoch 480/500 │ Loss: +0.0017 │ Modes: 423 │ Free En. Model: -6.0135 │ Free En. Data: -6.0114 │ Learning Rate: 0.00336
# Epoch 481/500 │ Loss: -0.0022 │ Modes: 436 │ Free En. Model: -6.0084 │ Free En. Data: -6.0185 │ Learning Rate: 0.00335
# Epoch 482/500 │ Loss: +0.0024 │ Modes: 421 │ Free En. Model: -6.0154 │ Free En. Data: -6.0092 │ Learning Rate: 0.00334
# Epoch 483/500 │ Loss: +0.0016 │ Modes: 432 │ Free En. Model: -6.0049 │ Free En. Data: -6.0133 │ Learning Rate: 0.00334
# Epoch 484/500 │ Loss: -0.0003 │ Modes: 431 │ Free En. Model: -5.9750 │ Free En. Data: -5.9910 │ Learning Rate: 0.00333
# Epoch 485/500 │ Loss: -0.0041 │ Modes: 439 │ Free En. Model: -5.9882 │ Free En. Data: -5.9751 │ Learning Rate: 0.00332
# Epoch 486/500 │ Loss: -0.0010 │ Modes: 427 │ Free En. Model: -5.9936 │ Free En. Data: -5.9533 │ Learning Rate: 0.00331
# Epoch 487/500 │ Loss: +0.0019 │ Modes: 428 │ Free En. Model: -5.9828 │ Free En. Data: -5.9936 │ Learning Rate: 0.00330
# Epoch 488/500 │ Loss: +0.0046 │ Modes: 431 │ Free En. Model: -6.0245 │ Free En. Data: -6.0205 │ Learning Rate: 0.00330
# Epoch 489/500 │ Loss: -0.0017 │ Modes: 426 │ Free En. Model: -6.0202 │ Free En. Data: -6.0264 │ Learning Rate: 0.00329
# Epoch 490/500 │ Loss: -0.0013 │ Modes: 442 │ Free En. Model: -6.0138 │ Free En. Data: -6.0123 │ Learning Rate: 0.00328
# Epoch 491/500 │ Loss: -0.0018 │ Modes: 435 │ Free En. Model: -6.0320 │ Free En. Data: -6.0320 │ Learning Rate: 0.00327
# Epoch 492/500 │ Loss: -0.0014 │ Modes: 429 │ Free En. Model: -6.0579 │ Free En. Data: -6.0728 │ Learning Rate: 0.00327
# Epoch 493/500 │ Loss: +0.0029 │ Modes: 426 │ Free En. Model: -5.9991 │ Free En. Data: -5.9993 │ Learning Rate: 0.00326
# Epoch 494/500 │ Loss: +0.0028 │ Modes: 433 │ Free En. Model: -5.9889 │ Free En. Data: -5.9809 │ Learning Rate: 0.00325
# Epoch 495/500 │ Loss: +0.0017 │ Modes: 425 │ Free En. Model: -6.0306 │ Free En. Data: -6.0290 │ Learning Rate: 0.00324
# Epoch 496/500 │ Loss: +0.0082 │ Modes: 422 │ Free En. Model: -6.0714 │ Free En. Data: -6.0616 │ Learning Rate: 0.00324
# Epoch 497/500 │ Loss: -0.0058 │ Modes: 437 │ Free En. Model: -6.0488 │ Free En. Data: -6.0474 │ Learning Rate: 0.00323
# Epoch 498/500 │ Loss: -0.0048 │ Modes: 428 │ Free En. Model: -6.0196 │ Free En. Data: -6.0363 │ Learning Rate: 0.00322
# Epoch 499/500 │ Loss: +0.0022 │ Modes: 428 │ Free En. Model: -6.0510 │ Free En. Data: -6.0565 │ Learning Rate: 0.00321
# Epoch 500/500 │ Loss: -0.0135 │ Modes: 436 │ Free En. Model: -6.0218 │ Free En. Data: -6.0493 │ Learning Rate: 0.00321

# %%
epochs = list(metrics.keys())

loss_vals = [metrics[e]['loss'] for e in epochs]
mode_vals = [metrics[e]['modes'] for e in epochs]
free_energy_model_vals = [metrics[e]['free_energy_model'] for e in epochs]
free_energy_data_vals = [metrics[e]['free_energy_data'] for e in epochs]
lr_vals = [metrics[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots(figsize=(11, 4))

ax1.set_xlabel("Epoch")

ax1.plot(epochs, lr_vals, color="tab:red")
ax1.set_ylabel("Learning Rate", color="tab:red")
ax1.tick_params(axis="y", labelcolor="tab:red")

ax2 = ax1.twinx()
ax2.plot(epochs, loss_vals, color="tab:blue")
ax2.set_ylabel("CD Loss", color="tab:blue")
ax2.tick_params(axis="y", labelcolor="tab:blue")
ax2.spines["right"].set_position(("axes", 1.0))

ax3 = ax1.twinx()
ax3.plot(epochs, free_energy_model_vals, color="tab:orange")
ax3.set_ylabel("Free Energy Model", color="tab:orange")
ax3.tick_params(axis="y", labelcolor="tab:orange")
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax1.twinx()
ax4.plot(epochs, mode_vals, color="tab:green")
ax4.set_ylabel("Mode Count", color="tab:green")
ax4.tick_params(axis="y", labelcolor="tab:green")
ax4.spines["right"].set_position(("axes", 1.2))

plt.title("Training curve for vanilla RBM")
plt.show()

# %%
# constant tempeature schedule is important for TFIM data
sampling_steps = 1000
constant_schedule = jnp.full((sampling_steps,), 1.0, dtype=jnp.float32)

T_high = 2.0
T_low = 0.01
sampling_steps = 5_000
sigmoid_schedule_fn = get_sigmoid_curve(high=T_high*2, low=T_low, steps=sampling_steps, falloff=0.0013, center_step=0)
sigmoid_schedule = jnp.array([sigmoid_schedule_fn(i) for i in range(sampling_steps)], dtype=jnp.float32)

key_sample = PRNGKey(1234)

samples = model.apply(
    {"params": state.params},
    num_samples=10_000,
    T_schedule=constant_schedule,
    key=key_sample,
    method=RBM.generate
)

sampled_freq = samples.mean(0)
sampled_freq
# Out:
# Array([1., 1., 1., 1., 1., 1., 1., 1., 1.], dtype=float32)

# %%
def magnetization_z(samples: jnp.ndarray) -> jnp.ndarray: # (num_samples, num_qubits)
    # making sure it is not unsigned when changing to -1 and +1 domain
    samples = samples.astype(jnp.float32)  # ensure float for division
    spins = 1 - 2 * samples  # map 0 -> +1, 1 -> -1
    sample_magnetisations = jnp.abs(spins.mean(axis=1)) # the .abs gives us the spontaneous magnetization
    total_magnetisation = sample_magnetisations.mean()
    return total_magnetisation  # mean over samples, gives us the global magnetization

mag_z = magnetization_z(measurements)
mag_z
# Out:
# Array(0.3239555, dtype=float32)

# %%
# now the same for the sampled data
mag_z_sampled = magnetization_z(samples)
mag_z_sampled
# Out:
# Array(0.32364437, dtype=float32)

# %%
import flax

def amplitude_ratio_flip(
        model: RBM,
        params: flax.core.FrozenDict,
        sample: jnp.ndarray,         # shape (batch_size, num_visible)
        flip_idx: int
) -> jnp.ndarray:
    # flip that one bit
    sample_flipped = sample.at[:, flip_idx].set(1 - sample[:, flip_idx])

    # compute F(v) and F(v') via apply+method
    F_ref  = model.apply({"params": params}, sample,        method=RBM.free_energy)
    F_flip = model.apply({"params": params}, sample_flipped, method=RBM.free_energy)

    # amplitude ratio = exp[(F(v) - F(v'))/2]
    return jnp.exp((F_ref - F_flip) / 2)


def magnetization_x(
        model: RBM,
        params: flax.core.FrozenDict,
        samples: jnp.ndarray          # shape (batch_size, num_visible)
) -> jnp.ndarray:
    # for each qubit index i, get a vector of ratios shape (batch,)
    flip_fn = lambda i: amplitude_ratio_flip(model, params, samples, i)
    # vmap over the spin index axis → (num_visible, batch_size)
    qubit_ratios = jax.vmap(flip_fn)(jnp.arange(samples.shape[1]))
    # average over qubits *and* batch:
    return qubit_ratios.mean()


mag_x = magnetization_x(model, state.params, measurements)
mag_x
# Out:
# Array(0.98764306, dtype=float32)

# %%
plt.show()
timestamp = datetime.now().strftime("%Y%m%d%H%M")
model_name = f"rbm_amp_{timestamp}"

checkpoints.save_checkpoint(
    ckpt_dir=str(model_dir.resolve()),
    target=state.params,
    step=0,
    prefix=model_name + "_",
    overwrite=True
)
# Out:
# '/Users/Tonni/Desktop/master-code/neural-quantum-tomo/case_studies/shadow_rbm_v2/models/rbm_amp_202506131953_0'
