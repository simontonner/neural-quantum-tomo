# %%
# %reload_ext autoreload
# %autoreload 2

from lib.data_loading import load_measurements, MixedDataLoader

####

from pathlib import Path
from typing import Tuple, Dict, Any, Callable
from itertools import combinations
from datetime import datetime

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import optax
from flax.training.train_state import TrainState
from flax.training import checkpoints
from flax import linen as nn

import matplotlib.pyplot as plt


data_dir = "data"
model_dir = Path("./models")
model_dir.mkdir(parents=True, exist_ok=True)

print(f"Data resides in        : {data_dir}")
print(f"Model will be saved to : {model_dir}")
# Out:
# WARNING:absl:Tensorflow library not found, tensorflow.io.gfile operations will use native shim calls. GCS paths (i.e. 'gs://...') cannot be accessed.
# Data resides in        : data
# Model will be saved to : models

# %%
class RBM(nn.Module):
    num_visible: int
    num_hidden: int
    k: int = 1
    T: float = 1.0

    def setup(self):
        self.W = self.param("W", nn.initializers.normal(0.01), (self.num_visible, self.num_hidden))
        self.b = self.param("b", nn.initializers.zeros, (self.num_visible,))
        self.c = self.param("c", nn.initializers.zeros, (self.num_hidden,))

    def __call__(self, data: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W, self.b, self.c, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (aux_vars["gibbs_chain"], aux_vars["key"]))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain)

        free_energy_data = jnp.mean(self._free_energy(data))
        free_energy_model = jnp.mean(self._free_energy(gibbs_chain))

        regularization = aux_vars["l2_strength"] * (jnp.sum(self.W**2) + jnp.sum(self.b**2) + jnp.sum(self.c**2))
        loss = free_energy_data - free_energy_model + regularization

        aux_vars = {
            "gibbs_chain": gibbs_chain,
            "key": key,
            "free_energy_data": free_energy_data,
            "free_energy_model": free_energy_model,
        }

        return loss, aux_vars

    def _free_energy(self, v):
        return -(v @ self.b) - jnp.sum(jax.nn.softplus(v @ self.W + self.c), -1)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c)/T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b)/T)).astype(jnp.float32)
        return v, key

    @nn.nowrap
    def generate(self, num_samples: int, T_schedule: jnp.ndarray, key: PRNGKey) -> jnp.ndarray:
        key, key_init = jax.random.split(key, 2)
        v = jax.random.bernoulli(key_init, p=0.5, shape=(num_samples, self.num_visible)).astype(jnp.float32)

        anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, (v, key))
        return v_final

# %%
@jax.jit
def train_step(state: TrainState, batch: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[TrainState, jnp.ndarray, Dict[str, Any]]:

    key, key_reset = jax.random.split(aux_vars["key"])
    aux_vars["key"] = key

    # reset gibbs_chain[i] with batch[i] given reset probability as chain_reset_frac
    reset_mask = jax.random.bernoulli(key_reset, p=aux_vars["chain_reset_frac"], shape=(batch.shape[0], 1))
    aux_vars["gibbs_chain"] = jnp.where(reset_mask, batch, aux_vars["gibbs_chain"])

    loss_fn = lambda params: state.apply_fn({'params': params}, batch, aux_vars)
    (loss, aux_vars), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    state = state.apply_gradients(grads=grads)

    return state, loss, aux_vars


def count_modes(chain: jnp.ndarray) -> int:
    chain = chain.astype(jnp.uint32)
    powers = 2 ** jnp.arange(chain.shape[-1], dtype=jnp.uint32)
    ints = jnp.dot(chain, powers)

    hist = jnp.bincount(ints, length=1 << chain.shape[-1])
    return int(jnp.sum(hist > 0))


def train(
        state: TrainState,
        loader: MixedDataLoader,
        num_epochs: int,
        key: PRNGKey,
        chain_reset_frac: float,
        l2_strength: float,
        lr_schedule_fn: Callable[[int], float]) -> Tuple[TrainState, Dict[int, float]]:

    metrics: Dict[int, Any] = {}
    gibbs_chain = None

    for epoch in range(num_epochs):
        tot_loss = 0.0

        for i, batch in enumerate(loader):
            measurements = batch[:, :, 0].astype(jnp.float32)

            if gibbs_chain is None:
                gibbs_chain = measurements

            key, subkey = jax.random.split(key)
            aux_vars = {
                "gibbs_chain": gibbs_chain,
                "key": subkey,
                "chain_reset_frac": chain_reset_frac,
                "l2_strength": l2_strength,
            }

            state, loss, aux_vars = train_step(state, measurements, aux_vars)
            gibbs_chain = aux_vars["gibbs_chain"]
            key = aux_vars["key"]
            free_energy_model = aux_vars["free_energy_model"]
            free_energy_data  = aux_vars["free_energy_data"]

            tot_loss += float(loss)

        avg_loss = tot_loss / len(loader)
        modes = count_modes(gibbs_chain)
        lr = lr_schedule_fn(state.step)

        metrics[epoch] = dict(
            loss=avg_loss,
            modes=modes,
            free_energy_model=free_energy_model,
            free_energy_data=free_energy_data,
            lr=lr
        )

        print(f"Epoch {epoch+1}/{num_epochs} │ "
              f"Loss: {avg_loss:+.4f} │ "
              f"Modes: {modes} │ "
              f"Free En. Model: {free_energy_model:.4f} │ "
              f"Free En. Data: {free_energy_data:.4f} │ "
              f"Learning Rate: {lr:.5f}")

    return state, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2

    curve_fn = lambda step: low + (high - low) / (1 + jnp.exp(falloff * (jnp.minimum(step, steps) - center_step)))
    return curve_fn

# %%
file_path = Path("data/w_aug_ZZZZZZZZ_6400.txt")
data = load_measurements(file_path)

measurements = data[:, :, 0]
empirical_freq = measurements.mean(axis=0)
empirical_freq
# Out:
# Parsing measurements: 100%|██████████| 6400/6400 [00:00<00:00, 22554.66it/s]
# Array([0.12656249, 0.1221875 , 0.1275    , 0.12374999, 0.13      ,
#        0.12859374, 0.11953124, 0.121875  ], dtype=float32)

# %%
batch_size   = 1024             # larger requires more epochs for the model to go down in its modes
num_visible  = 8
hidden_units = 8               # interesting, lower gives evener frequencies, although the modes go not down to 1
k_steps      = 50               # more steps required if small batch size
num_epochs   = 2000             # longer since large batch size
init_lr      = 1e-2             # large drives modes down fast but learns nothing, to small and we dont get any one hots
final_lr     = init_lr * 0.1
chain_reset_frac = 0.1
l2_strength  = 1e-4

# runs also very nicely if l2 norm is turned off completely but the free energies get large

key_seed = PRNGKey(42)
key, key_params, key_dummy = jax.random.split(key_seed, 3)

model = RBM(num_visible=num_visible, num_hidden=hidden_units, k=k_steps)
batch_dummy = jnp.zeros((batch_size, num_visible), dtype=jnp.float32)
aux_vars_dummy = {"gibbs_chain": jnp.zeros((batch_size, num_visible), dtype=jnp.float32), "key": key_dummy, "l2_strength": l2_strength}
variables = model.init({"params": key_params}, batch_dummy, aux_vars_dummy)

loader = MixedDataLoader(data, batch_size=batch_size, drop_last=True) # we need the last batch to match the chain dimension

schedule_steps = num_epochs * len(loader)
lr_schedule_fn = get_sigmoid_curve(high=init_lr, low=final_lr, steps=schedule_steps, falloff=0.0005)
optimizer = optax.adam(lr_schedule_fn)

state = TrainState.create(apply_fn=model.apply, params=variables['params'], tx=optimizer)

state, metrics = train(state, loader, num_epochs, key, chain_reset_frac, l2_strength, lr_schedule_fn)
# Out:
# Epoch 1/2000 │ Loss: -0.3017 │ Modes: 248 │ Free En. Model: -4.8600 │ Free En. Data: -5.4235 │ Learning Rate: 0.00957
# Epoch 2/2000 │ Loss: -0.8318 │ Modes: 236 │ Free En. Model: -4.3924 │ Free En. Data: -5.3729 │ Learning Rate: 0.00957
# Epoch 3/2000 │ Loss: -1.1164 │ Modes: 222 │ Free En. Model: -4.1760 │ Free En. Data: -5.3637 │ Learning Rate: 0.00957
# Epoch 4/2000 │ Loss: -1.2256 │ Modes: 192 │ Free En. Model: -4.1521 │ Free En. Data: -5.3916 │ Learning Rate: 0.00957
# Epoch 5/2000 │ Loss: -1.1286 │ Modes: 189 │ Free En. Model: -4.3077 │ Free En. Data: -5.4518 │ Learning Rate: 0.00957
# Epoch 6/2000 │ Loss: -1.0128 │ Modes: 167 │ Free En. Model: -4.5720 │ Free En. Data: -5.5394 │ Learning Rate: 0.00957
# Epoch 7/2000 │ Loss: -0.7965 │ Modes: 151 │ Free En. Model: -4.9208 │ Free En. Data: -5.6457 │ Learning Rate: 0.00956
# Epoch 8/2000 │ Loss: -0.6320 │ Modes: 136 │ Free En. Model: -5.2760 │ Free En. Data: -5.7624 │ Learning Rate: 0.00956
# Epoch 9/2000 │ Loss: -0.4696 │ Modes: 118 │ Free En. Model: -5.5045 │ Free En. Data: -5.8834 │ Learning Rate: 0.00956
# Epoch 10/2000 │ Loss: -0.2757 │ Modes: 111 │ Free En. Model: -5.8775 │ Free En. Data: -6.0002 │ Learning Rate: 0.00956
# Epoch 11/2000 │ Loss: -0.2034 │ Modes: 117 │ Free En. Model: -5.9024 │ Free En. Data: -6.1089 │ Learning Rate: 0.00956
# Epoch 12/2000 │ Loss: -0.0707 │ Modes: 100 │ Free En. Model: -6.1879 │ Free En. Data: -6.2111 │ Learning Rate: 0.00956
# Epoch 13/2000 │ Loss: -0.0626 │ Modes: 102 │ Free En. Model: -6.3236 │ Free En. Data: -6.3028 │ Learning Rate: 0.00956
# Epoch 14/2000 │ Loss: -0.0597 │ Modes: 104 │ Free En. Model: -6.3002 │ Free En. Data: -6.3908 │ Learning Rate: 0.00956
# Epoch 15/2000 │ Loss: -0.0681 │ Modes: 104 │ Free En. Model: -6.4498 │ Free En. Data: -6.4796 │ Learning Rate: 0.00955
# Epoch 16/2000 │ Loss: -0.0636 │ Modes: 110 │ Free En. Model: -6.4878 │ Free En. Data: -6.5667 │ Learning Rate: 0.00955
# Epoch 17/2000 │ Loss: -0.0695 │ Modes: 98 │ Free En. Model: -6.6699 │ Free En. Data: -6.6580 │ Learning Rate: 0.00955
# Epoch 18/2000 │ Loss: -0.0449 │ Modes: 97 │ Free En. Model: -6.6503 │ Free En. Data: -6.7455 │ Learning Rate: 0.00955
# Epoch 19/2000 │ Loss: -0.1081 │ Modes: 105 │ Free En. Model: -6.7296 │ Free En. Data: -6.8368 │ Learning Rate: 0.00955
# Epoch 20/2000 │ Loss: -0.1239 │ Modes: 95 │ Free En. Model: -6.8833 │ Free En. Data: -6.9304 │ Learning Rate: 0.00955
# Epoch 21/2000 │ Loss: -0.0549 │ Modes: 100 │ Free En. Model: -7.0252 │ Free En. Data: -7.0236 │ Learning Rate: 0.00955
# Epoch 22/2000 │ Loss: -0.0761 │ Modes: 102 │ Free En. Model: -7.0429 │ Free En. Data: -7.1157 │ Learning Rate: 0.00955
# Epoch 23/2000 │ Loss: -0.1308 │ Modes: 110 │ Free En. Model: -7.0065 │ Free En. Data: -7.2128 │ Learning Rate: 0.00954
# Epoch 24/2000 │ Loss: -0.1107 │ Modes: 97 │ Free En. Model: -7.2588 │ Free En. Data: -7.3089 │ Learning Rate: 0.00954
# Epoch 25/2000 │ Loss: -0.1352 │ Modes: 102 │ Free En. Model: -7.2637 │ Free En. Data: -7.4034 │ Learning Rate: 0.00954
# Epoch 26/2000 │ Loss: -0.0873 │ Modes: 97 │ Free En. Model: -7.4361 │ Free En. Data: -7.4970 │ Learning Rate: 0.00954
# Epoch 27/2000 │ Loss: -0.0647 │ Modes: 100 │ Free En. Model: -7.5375 │ Free En. Data: -7.5925 │ Learning Rate: 0.00954
# Epoch 28/2000 │ Loss: -0.0943 │ Modes: 97 │ Free En. Model: -7.5453 │ Free En. Data: -7.6857 │ Learning Rate: 0.00954
# Epoch 29/2000 │ Loss: -0.1337 │ Modes: 107 │ Free En. Model: -7.5533 │ Free En. Data: -7.7786 │ Learning Rate: 0.00954
# Epoch 30/2000 │ Loss: -0.1407 │ Modes: 103 │ Free En. Model: -7.7520 │ Free En. Data: -7.8755 │ Learning Rate: 0.00954
# Epoch 31/2000 │ Loss: -0.0789 │ Modes: 104 │ Free En. Model: -7.8766 │ Free En. Data: -7.9728 │ Learning Rate: 0.00953
# Epoch 32/2000 │ Loss: -0.0896 │ Modes: 106 │ Free En. Model: -7.8341 │ Free En. Data: -8.0637 │ Learning Rate: 0.00953
# Epoch 33/2000 │ Loss: -0.0788 │ Modes: 97 │ Free En. Model: -8.1316 │ Free En. Data: -8.1596 │ Learning Rate: 0.00953
# Epoch 34/2000 │ Loss: -0.0880 │ Modes: 98 │ Free En. Model: -8.1529 │ Free En. Data: -8.2517 │ Learning Rate: 0.00953
# Epoch 35/2000 │ Loss: -0.1177 │ Modes: 100 │ Free En. Model: -8.2327 │ Free En. Data: -8.3406 │ Learning Rate: 0.00953
# Epoch 36/2000 │ Loss: -0.0988 │ Modes: 95 │ Free En. Model: -8.3394 │ Free En. Data: -8.4338 │ Learning Rate: 0.00953
# Epoch 37/2000 │ Loss: -0.0999 │ Modes: 95 │ Free En. Model: -8.5259 │ Free En. Data: -8.5241 │ Learning Rate: 0.00953
# Epoch 38/2000 │ Loss: -0.0320 │ Modes: 97 │ Free En. Model: -8.5936 │ Free En. Data: -8.6141 │ Learning Rate: 0.00952
# Epoch 39/2000 │ Loss: -0.1156 │ Modes: 98 │ Free En. Model: -8.5837 │ Free En. Data: -8.7009 │ Learning Rate: 0.00952
# Epoch 40/2000 │ Loss: -0.0576 │ Modes: 106 │ Free En. Model: -8.6163 │ Free En. Data: -8.7910 │ Learning Rate: 0.00952
# Epoch 41/2000 │ Loss: -0.0968 │ Modes: 96 │ Free En. Model: -8.8039 │ Free En. Data: -8.8751 │ Learning Rate: 0.00952
# Epoch 42/2000 │ Loss: -0.0784 │ Modes: 97 │ Free En. Model: -8.8887 │ Free En. Data: -8.9609 │ Learning Rate: 0.00952
# Epoch 43/2000 │ Loss: -0.0937 │ Modes: 88 │ Free En. Model: -8.9617 │ Free En. Data: -9.0454 │ Learning Rate: 0.00952
# Epoch 44/2000 │ Loss: -0.0925 │ Modes: 95 │ Free En. Model: -8.9957 │ Free En. Data: -9.1277 │ Learning Rate: 0.00952
# Epoch 45/2000 │ Loss: -0.0837 │ Modes: 98 │ Free En. Model: -9.1588 │ Free En. Data: -9.2108 │ Learning Rate: 0.00951
# Epoch 46/2000 │ Loss: -0.0835 │ Modes: 92 │ Free En. Model: -9.2559 │ Free En. Data: -9.2950 │ Learning Rate: 0.00951
# Epoch 47/2000 │ Loss: -0.0832 │ Modes: 94 │ Free En. Model: -9.2976 │ Free En. Data: -9.3765 │ Learning Rate: 0.00951
# Epoch 48/2000 │ Loss: -0.0392 │ Modes: 93 │ Free En. Model: -9.3780 │ Free En. Data: -9.4584 │ Learning Rate: 0.00951
# Epoch 49/2000 │ Loss: -0.0373 │ Modes: 84 │ Free En. Model: -9.4926 │ Free En. Data: -9.5371 │ Learning Rate: 0.00951
# Epoch 50/2000 │ Loss: -0.0952 │ Modes: 104 │ Free En. Model: -9.4316 │ Free En. Data: -9.6158 │ Learning Rate: 0.00951
# Epoch 51/2000 │ Loss: -0.0913 │ Modes: 98 │ Free En. Model: -9.6301 │ Free En. Data: -9.6936 │ Learning Rate: 0.00951
# Epoch 52/2000 │ Loss: -0.0893 │ Modes: 94 │ Free En. Model: -9.6947 │ Free En. Data: -9.7714 │ Learning Rate: 0.00951
# Epoch 53/2000 │ Loss: -0.0915 │ Modes: 99 │ Free En. Model: -9.6934 │ Free En. Data: -9.8463 │ Learning Rate: 0.00950
# Epoch 54/2000 │ Loss: -0.0506 │ Modes: 99 │ Free En. Model: -9.8705 │ Free En. Data: -9.9263 │ Learning Rate: 0.00950
# Epoch 55/2000 │ Loss: -0.0551 │ Modes: 89 │ Free En. Model: -9.8992 │ Free En. Data: -10.0021 │ Learning Rate: 0.00950
# Epoch 56/2000 │ Loss: -0.0478 │ Modes: 95 │ Free En. Model: -10.0760 │ Free En. Data: -10.0757 │ Learning Rate: 0.00950
# Epoch 57/2000 │ Loss: -0.0519 │ Modes: 98 │ Free En. Model: -10.1085 │ Free En. Data: -10.1484 │ Learning Rate: 0.00950
# Epoch 58/2000 │ Loss: -0.0881 │ Modes: 101 │ Free En. Model: -10.1554 │ Free En. Data: -10.2224 │ Learning Rate: 0.00950
# Epoch 59/2000 │ Loss: -0.0917 │ Modes: 95 │ Free En. Model: -10.2206 │ Free En. Data: -10.2925 │ Learning Rate: 0.00950
# Epoch 60/2000 │ Loss: -0.0724 │ Modes: 95 │ Free En. Model: -10.2196 │ Free En. Data: -10.3634 │ Learning Rate: 0.00949
# Epoch 61/2000 │ Loss: -0.0016 │ Modes: 84 │ Free En. Model: -10.4313 │ Free En. Data: -10.4325 │ Learning Rate: 0.00949
# Epoch 62/2000 │ Loss: -0.0551 │ Modes: 99 │ Free En. Model: -10.4162 │ Free En. Data: -10.5053 │ Learning Rate: 0.00949
# Epoch 63/2000 │ Loss: -0.0498 │ Modes: 96 │ Free En. Model: -10.4732 │ Free En. Data: -10.5787 │ Learning Rate: 0.00949
# Epoch 64/2000 │ Loss: -0.0510 │ Modes: 97 │ Free En. Model: -10.5001 │ Free En. Data: -10.6474 │ Learning Rate: 0.00949
# Epoch 65/2000 │ Loss: -0.0637 │ Modes: 100 │ Free En. Model: -10.6162 │ Free En. Data: -10.7113 │ Learning Rate: 0.00949
# Epoch 66/2000 │ Loss: -0.1025 │ Modes: 98 │ Free En. Model: -10.6449 │ Free En. Data: -10.7714 │ Learning Rate: 0.00949
# Epoch 67/2000 │ Loss: -0.0623 │ Modes: 95 │ Free En. Model: -10.7393 │ Free En. Data: -10.8278 │ Learning Rate: 0.00948
# Epoch 68/2000 │ Loss: -0.0099 │ Modes: 85 │ Free En. Model: -10.8916 │ Free En. Data: -10.8939 │ Learning Rate: 0.00948
# Epoch 69/2000 │ Loss: -0.0543 │ Modes: 90 │ Free En. Model: -10.9969 │ Free En. Data: -10.9552 │ Learning Rate: 0.00948
# Epoch 70/2000 │ Loss: -0.0226 │ Modes: 94 │ Free En. Model: -11.0132 │ Free En. Data: -11.0218 │ Learning Rate: 0.00948
# Epoch 71/2000 │ Loss: -0.0725 │ Modes: 92 │ Free En. Model: -10.9595 │ Free En. Data: -11.0859 │ Learning Rate: 0.00948
# Epoch 72/2000 │ Loss: -0.0962 │ Modes: 96 │ Free En. Model: -10.9534 │ Free En. Data: -11.1436 │ Learning Rate: 0.00948
# Epoch 73/2000 │ Loss: -0.0557 │ Modes: 90 │ Free En. Model: -11.0931 │ Free En. Data: -11.2005 │ Learning Rate: 0.00947
# Epoch 74/2000 │ Loss: -0.0226 │ Modes: 91 │ Free En. Model: -11.2667 │ Free En. Data: -11.2565 │ Learning Rate: 0.00947
# Epoch 75/2000 │ Loss: -0.0369 │ Modes: 92 │ Free En. Model: -11.1943 │ Free En. Data: -11.3201 │ Learning Rate: 0.00947
# Epoch 76/2000 │ Loss: -0.0191 │ Modes: 89 │ Free En. Model: -11.2913 │ Free En. Data: -11.3775 │ Learning Rate: 0.00947
# Epoch 77/2000 │ Loss: -0.0445 │ Modes: 85 │ Free En. Model: -11.3651 │ Free En. Data: -11.4394 │ Learning Rate: 0.00947
# Epoch 78/2000 │ Loss: -0.0971 │ Modes: 88 │ Free En. Model: -11.4616 │ Free En. Data: -11.4957 │ Learning Rate: 0.00947
# Epoch 79/2000 │ Loss: -0.0602 │ Modes: 81 │ Free En. Model: -11.6497 │ Free En. Data: -11.5401 │ Learning Rate: 0.00947
# Epoch 80/2000 │ Loss: -0.0490 │ Modes: 87 │ Free En. Model: -11.5465 │ Free En. Data: -11.5930 │ Learning Rate: 0.00946
# Epoch 81/2000 │ Loss: -0.0142 │ Modes: 90 │ Free En. Model: -11.6717 │ Free En. Data: -11.6474 │ Learning Rate: 0.00946
# Epoch 82/2000 │ Loss: -0.0569 │ Modes: 90 │ Free En. Model: -11.6017 │ Free En. Data: -11.7041 │ Learning Rate: 0.00946
# Epoch 83/2000 │ Loss: -0.0618 │ Modes: 87 │ Free En. Model: -11.6073 │ Free En. Data: -11.7549 │ Learning Rate: 0.00946
# Epoch 84/2000 │ Loss: -0.0332 │ Modes: 90 │ Free En. Model: -11.8027 │ Free En. Data: -11.8038 │ Learning Rate: 0.00946
# Epoch 85/2000 │ Loss: -0.0913 │ Modes: 89 │ Free En. Model: -11.7436 │ Free En. Data: -11.8525 │ Learning Rate: 0.00946
# Epoch 86/2000 │ Loss: +0.0089 │ Modes: 90 │ Free En. Model: -11.8112 │ Free En. Data: -11.9073 │ Learning Rate: 0.00946
# Epoch 87/2000 │ Loss: -0.0436 │ Modes: 92 │ Free En. Model: -11.8514 │ Free En. Data: -11.9635 │ Learning Rate: 0.00945
# Epoch 88/2000 │ Loss: -0.0416 │ Modes: 87 │ Free En. Model: -11.9838 │ Free En. Data: -12.0146 │ Learning Rate: 0.00945
# Epoch 89/2000 │ Loss: -0.0437 │ Modes: 91 │ Free En. Model: -12.0023 │ Free En. Data: -12.0669 │ Learning Rate: 0.00945
# Epoch 90/2000 │ Loss: -0.0385 │ Modes: 89 │ Free En. Model: -12.0374 │ Free En. Data: -12.1193 │ Learning Rate: 0.00945
# Epoch 91/2000 │ Loss: -0.0770 │ Modes: 87 │ Free En. Model: -12.1461 │ Free En. Data: -12.1666 │ Learning Rate: 0.00945
# Epoch 92/2000 │ Loss: +0.0017 │ Modes: 86 │ Free En. Model: -12.1931 │ Free En. Data: -12.2136 │ Learning Rate: 0.00945
# Epoch 93/2000 │ Loss: -0.0539 │ Modes: 89 │ Free En. Model: -12.2167 │ Free En. Data: -12.2658 │ Learning Rate: 0.00944
# Epoch 94/2000 │ Loss: -0.0693 │ Modes: 86 │ Free En. Model: -12.2017 │ Free En. Data: -12.3054 │ Learning Rate: 0.00944
# Epoch 95/2000 │ Loss: -0.0178 │ Modes: 86 │ Free En. Model: -12.4119 │ Free En. Data: -12.3477 │ Learning Rate: 0.00944
# Epoch 96/2000 │ Loss: -0.0131 │ Modes: 89 │ Free En. Model: -12.3630 │ Free En. Data: -12.3954 │ Learning Rate: 0.00944
# Epoch 97/2000 │ Loss: -0.0529 │ Modes: 87 │ Free En. Model: -12.4641 │ Free En. Data: -12.4470 │ Learning Rate: 0.00944
# Epoch 98/2000 │ Loss: -0.0400 │ Modes: 91 │ Free En. Model: -12.5501 │ Free En. Data: -12.4898 │ Learning Rate: 0.00944
# Epoch 99/2000 │ Loss: -0.0044 │ Modes: 88 │ Free En. Model: -12.5066 │ Free En. Data: -12.5388 │ Learning Rate: 0.00943
# Epoch 100/2000 │ Loss: -0.0858 │ Modes: 93 │ Free En. Model: -12.5072 │ Free En. Data: -12.5860 │ Learning Rate: 0.00943
# Epoch 101/2000 │ Loss: -0.0178 │ Modes: 86 │ Free En. Model: -12.6696 │ Free En. Data: -12.6232 │ Learning Rate: 0.00943
# Epoch 102/2000 │ Loss: -0.0158 │ Modes: 90 │ Free En. Model: -12.5955 │ Free En. Data: -12.6713 │ Learning Rate: 0.00943
# Epoch 103/2000 │ Loss: -0.0323 │ Modes: 83 │ Free En. Model: -12.6536 │ Free En. Data: -12.7172 │ Learning Rate: 0.00943
# Epoch 104/2000 │ Loss: -0.0469 │ Modes: 81 │ Free En. Model: -12.7633 │ Free En. Data: -12.7592 │ Learning Rate: 0.00943
# Epoch 105/2000 │ Loss: -0.0739 │ Modes: 90 │ Free En. Model: -12.7272 │ Free En. Data: -12.7947 │ Learning Rate: 0.00943
# Epoch 106/2000 │ Loss: -0.0531 │ Modes: 81 │ Free En. Model: -12.7514 │ Free En. Data: -12.8221 │ Learning Rate: 0.00942
# Epoch 107/2000 │ Loss: +0.0015 │ Modes: 82 │ Free En. Model: -12.8910 │ Free En. Data: -12.8571 │ Learning Rate: 0.00942
# Epoch 108/2000 │ Loss: -0.0223 │ Modes: 99 │ Free En. Model: -12.7943 │ Free En. Data: -12.9030 │ Learning Rate: 0.00942
# Epoch 109/2000 │ Loss: -0.0433 │ Modes: 89 │ Free En. Model: -12.8305 │ Free En. Data: -12.9474 │ Learning Rate: 0.00942
# Epoch 110/2000 │ Loss: +0.0217 │ Modes: 85 │ Free En. Model: -12.9875 │ Free En. Data: -12.9937 │ Learning Rate: 0.00942
# Epoch 111/2000 │ Loss: -0.0431 │ Modes: 91 │ Free En. Model: -12.8917 │ Free En. Data: -13.0450 │ Learning Rate: 0.00942
# Epoch 112/2000 │ Loss: -0.0919 │ Modes: 91 │ Free En. Model: -12.9218 │ Free En. Data: -13.0814 │ Learning Rate: 0.00941
# Epoch 113/2000 │ Loss: -0.0119 │ Modes: 90 │ Free En. Model: -13.1362 │ Free En. Data: -13.1082 │ Learning Rate: 0.00941
# Epoch 114/2000 │ Loss: -0.0256 │ Modes: 90 │ Free En. Model: -13.0382 │ Free En. Data: -13.1424 │ Learning Rate: 0.00941
# Epoch 115/2000 │ Loss: -0.0571 │ Modes: 93 │ Free En. Model: -13.2253 │ Free En. Data: -13.1740 │ Learning Rate: 0.00941
# Epoch 116/2000 │ Loss: +0.0047 │ Modes: 91 │ Free En. Model: -13.1163 │ Free En. Data: -13.2157 │ Learning Rate: 0.00941
# Epoch 117/2000 │ Loss: -0.0203 │ Modes: 85 │ Free En. Model: -13.2079 │ Free En. Data: -13.2611 │ Learning Rate: 0.00941
# Epoch 118/2000 │ Loss: -0.0377 │ Modes: 83 │ Free En. Model: -13.2809 │ Free En. Data: -13.2972 │ Learning Rate: 0.00940
# Epoch 119/2000 │ Loss: -0.0653 │ Modes: 86 │ Free En. Model: -13.2451 │ Free En. Data: -13.3255 │ Learning Rate: 0.00940
# Epoch 120/2000 │ Loss: -0.0518 │ Modes: 89 │ Free En. Model: -13.3677 │ Free En. Data: -13.3470 │ Learning Rate: 0.00940
# Epoch 121/2000 │ Loss: +0.0069 │ Modes: 86 │ Free En. Model: -13.3435 │ Free En. Data: -13.3819 │ Learning Rate: 0.00940
# Epoch 122/2000 │ Loss: +0.0012 │ Modes: 88 │ Free En. Model: -13.3274 │ Free En. Data: -13.4231 │ Learning Rate: 0.00940
# Epoch 123/2000 │ Loss: -0.0025 │ Modes: 80 │ Free En. Model: -13.5235 │ Free En. Data: -13.4672 │ Learning Rate: 0.00940
# Epoch 124/2000 │ Loss: -0.0816 │ Modes: 85 │ Free En. Model: -13.4293 │ Free En. Data: -13.5032 │ Learning Rate: 0.00939
# Epoch 125/2000 │ Loss: -0.0049 │ Modes: 86 │ Free En. Model: -13.4394 │ Free En. Data: -13.5333 │ Learning Rate: 0.00939
# Epoch 126/2000 │ Loss: -0.0229 │ Modes: 79 │ Free En. Model: -13.6063 │ Free En. Data: -13.5658 │ Learning Rate: 0.00939
# Epoch 127/2000 │ Loss: -0.0252 │ Modes: 85 │ Free En. Model: -13.5288 │ Free En. Data: -13.6042 │ Learning Rate: 0.00939
# Epoch 128/2000 │ Loss: -0.0518 │ Modes: 82 │ Free En. Model: -13.5700 │ Free En. Data: -13.6293 │ Learning Rate: 0.00939
# Epoch 129/2000 │ Loss: -0.0114 │ Modes: 84 │ Free En. Model: -13.6687 │ Free En. Data: -13.6468 │ Learning Rate: 0.00939
# Epoch 130/2000 │ Loss: -0.0202 │ Modes: 96 │ Free En. Model: -13.6582 │ Free En. Data: -13.6797 │ Learning Rate: 0.00938
# Epoch 131/2000 │ Loss: -0.0266 │ Modes: 82 │ Free En. Model: -13.7150 │ Free En. Data: -13.7127 │ Learning Rate: 0.00938
# Epoch 132/2000 │ Loss: -0.0264 │ Modes: 89 │ Free En. Model: -13.7074 │ Free En. Data: -13.7414 │ Learning Rate: 0.00938
# Epoch 133/2000 │ Loss: +0.0071 │ Modes: 88 │ Free En. Model: -13.6865 │ Free En. Data: -13.7809 │ Learning Rate: 0.00938
# Epoch 134/2000 │ Loss: -0.0307 │ Modes: 79 │ Free En. Model: -13.8304 │ Free En. Data: -13.8176 │ Learning Rate: 0.00938
# Epoch 135/2000 │ Loss: -0.0793 │ Modes: 84 │ Free En. Model: -13.6811 │ Free En. Data: -13.8420 │ Learning Rate: 0.00937
# Epoch 136/2000 │ Loss: -0.0563 │ Modes: 86 │ Free En. Model: -13.7826 │ Free En. Data: -13.8468 │ Learning Rate: 0.00937
# Epoch 137/2000 │ Loss: -0.0003 │ Modes: 83 │ Free En. Model: -13.8055 │ Free En. Data: -13.8615 │ Learning Rate: 0.00937
# Epoch 138/2000 │ Loss: +0.0309 │ Modes: 87 │ Free En. Model: -13.9490 │ Free En. Data: -13.8959 │ Learning Rate: 0.00937
# Epoch 139/2000 │ Loss: -0.0497 │ Modes: 93 │ Free En. Model: -13.8338 │ Free En. Data: -13.9344 │ Learning Rate: 0.00937
# Epoch 140/2000 │ Loss: -0.0190 │ Modes: 102 │ Free En. Model: -13.8709 │ Free En. Data: -13.9663 │ Learning Rate: 0.00937
# Epoch 141/2000 │ Loss: -0.0248 │ Modes: 94 │ Free En. Model: -13.8510 │ Free En. Data: -13.9948 │ Learning Rate: 0.00936
# Epoch 142/2000 │ Loss: +0.0129 │ Modes: 96 │ Free En. Model: -14.0371 │ Free En. Data: -14.0311 │ Learning Rate: 0.00936
# Epoch 143/2000 │ Loss: -0.0408 │ Modes: 86 │ Free En. Model: -14.0089 │ Free En. Data: -14.0641 │ Learning Rate: 0.00936
# Epoch 144/2000 │ Loss: -0.0323 │ Modes: 84 │ Free En. Model: -14.0253 │ Free En. Data: -14.0871 │ Learning Rate: 0.00936
# Epoch 145/2000 │ Loss: -0.0097 │ Modes: 73 │ Free En. Model: -14.1646 │ Free En. Data: -14.1060 │ Learning Rate: 0.00936
# Epoch 146/2000 │ Loss: -0.0494 │ Modes: 94 │ Free En. Model: -14.0400 │ Free En. Data: -14.1274 │ Learning Rate: 0.00936
# Epoch 147/2000 │ Loss: +0.0015 │ Modes: 86 │ Free En. Model: -14.1895 │ Free En. Data: -14.1498 │ Learning Rate: 0.00935
# Epoch 148/2000 │ Loss: -0.0717 │ Modes: 90 │ Free En. Model: -14.0398 │ Free En. Data: -14.1677 │ Learning Rate: 0.00935
# Epoch 149/2000 │ Loss: -0.0033 │ Modes: 92 │ Free En. Model: -14.0974 │ Free En. Data: -14.1875 │ Learning Rate: 0.00935
# Epoch 150/2000 │ Loss: -0.0381 │ Modes: 90 │ Free En. Model: -14.0891 │ Free En. Data: -14.2043 │ Learning Rate: 0.00935
# Epoch 151/2000 │ Loss: -0.0260 │ Modes: 93 │ Free En. Model: -14.0663 │ Free En. Data: -14.2265 │ Learning Rate: 0.00935
# Epoch 152/2000 │ Loss: -0.0160 │ Modes: 91 │ Free En. Model: -14.1813 │ Free En. Data: -14.2477 │ Learning Rate: 0.00934
# Epoch 153/2000 │ Loss: +0.0068 │ Modes: 76 │ Free En. Model: -14.2892 │ Free En. Data: -14.2742 │ Learning Rate: 0.00934
# Epoch 154/2000 │ Loss: -0.0125 │ Modes: 84 │ Free En. Model: -14.2697 │ Free En. Data: -14.3065 │ Learning Rate: 0.00934
# Epoch 155/2000 │ Loss: -0.0182 │ Modes: 87 │ Free En. Model: -14.2864 │ Free En. Data: -14.3409 │ Learning Rate: 0.00934
# Epoch 156/2000 │ Loss: -0.0240 │ Modes: 83 │ Free En. Model: -14.3574 │ Free En. Data: -14.3686 │ Learning Rate: 0.00934
# Epoch 157/2000 │ Loss: -0.0316 │ Modes: 89 │ Free En. Model: -14.3428 │ Free En. Data: -14.3877 │ Learning Rate: 0.00934
# Epoch 158/2000 │ Loss: -0.0200 │ Modes: 80 │ Free En. Model: -14.3802 │ Free En. Data: -14.4090 │ Learning Rate: 0.00933
# Epoch 159/2000 │ Loss: +0.0018 │ Modes: 87 │ Free En. Model: -14.3856 │ Free En. Data: -14.4343 │ Learning Rate: 0.00933
# Epoch 160/2000 │ Loss: -0.0741 │ Modes: 82 │ Free En. Model: -14.4760 │ Free En. Data: -14.4447 │ Learning Rate: 0.00933
# Epoch 161/2000 │ Loss: +0.0147 │ Modes: 88 │ Free En. Model: -14.5183 │ Free En. Data: -14.4562 │ Learning Rate: 0.00933
# Epoch 162/2000 │ Loss: +0.0399 │ Modes: 87 │ Free En. Model: -14.5177 │ Free En. Data: -14.4964 │ Learning Rate: 0.00933
# Epoch 163/2000 │ Loss: -0.0775 │ Modes: 84 │ Free En. Model: -14.5095 │ Free En. Data: -14.5274 │ Learning Rate: 0.00932
# Epoch 164/2000 │ Loss: -0.0631 │ Modes: 78 │ Free En. Model: -14.5126 │ Free En. Data: -14.5284 │ Learning Rate: 0.00932
# Epoch 165/2000 │ Loss: +0.0172 │ Modes: 88 │ Free En. Model: -14.5284 │ Free En. Data: -14.5362 │ Learning Rate: 0.00932
# Epoch 166/2000 │ Loss: -0.0035 │ Modes: 83 │ Free En. Model: -14.4960 │ Free En. Data: -14.5676 │ Learning Rate: 0.00932
# Epoch 167/2000 │ Loss: -0.0010 │ Modes: 84 │ Free En. Model: -14.6892 │ Free En. Data: -14.5940 │ Learning Rate: 0.00932
# Epoch 168/2000 │ Loss: -0.0293 │ Modes: 87 │ Free En. Model: -14.6136 │ Free En. Data: -14.6142 │ Learning Rate: 0.00931
# Epoch 169/2000 │ Loss: -0.0454 │ Modes: 79 │ Free En. Model: -14.6726 │ Free En. Data: -14.6233 │ Learning Rate: 0.00931
# Epoch 170/2000 │ Loss: +0.0124 │ Modes: 83 │ Free En. Model: -14.6333 │ Free En. Data: -14.6375 │ Learning Rate: 0.00931
# Epoch 171/2000 │ Loss: -0.0173 │ Modes: 82 │ Free En. Model: -14.7117 │ Free En. Data: -14.6584 │ Learning Rate: 0.00931
# Epoch 172/2000 │ Loss: -0.0300 │ Modes: 86 │ Free En. Model: -14.7180 │ Free En. Data: -14.6817 │ Learning Rate: 0.00931
# Epoch 173/2000 │ Loss: -0.0765 │ Modes: 86 │ Free En. Model: -14.6054 │ Free En. Data: -14.6870 │ Learning Rate: 0.00931
# Epoch 174/2000 │ Loss: +0.0363 │ Modes: 87 │ Free En. Model: -14.6845 │ Free En. Data: -14.6957 │ Learning Rate: 0.00930
# Epoch 175/2000 │ Loss: +0.0064 │ Modes: 85 │ Free En. Model: -14.7260 │ Free En. Data: -14.7256 │ Learning Rate: 0.00930
# Epoch 176/2000 │ Loss: -0.0545 │ Modes: 83 │ Free En. Model: -14.6703 │ Free En. Data: -14.7473 │ Learning Rate: 0.00930
# Epoch 177/2000 │ Loss: -0.0392 │ Modes: 90 │ Free En. Model: -14.6490 │ Free En. Data: -14.7543 │ Learning Rate: 0.00930
# Epoch 178/2000 │ Loss: -0.0021 │ Modes: 92 │ Free En. Model: -14.7155 │ Free En. Data: -14.7606 │ Learning Rate: 0.00930
# Epoch 179/2000 │ Loss: +0.0170 │ Modes: 93 │ Free En. Model: -14.6793 │ Free En. Data: -14.7912 │ Learning Rate: 0.00929
# Epoch 180/2000 │ Loss: -0.0325 │ Modes: 99 │ Free En. Model: -14.6727 │ Free En. Data: -14.8161 │ Learning Rate: 0.00929
# Epoch 181/2000 │ Loss: -0.0653 │ Modes: 92 │ Free En. Model: -14.7861 │ Free En. Data: -14.8068 │ Learning Rate: 0.00929
# Epoch 182/2000 │ Loss: +0.0175 │ Modes: 85 │ Free En. Model: -14.8265 │ Free En. Data: -14.8125 │ Learning Rate: 0.00929
# Epoch 183/2000 │ Loss: +0.0443 │ Modes: 79 │ Free En. Model: -14.9927 │ Free En. Data: -14.8431 │ Learning Rate: 0.00929
# Epoch 184/2000 │ Loss: -0.0024 │ Modes: 81 │ Free En. Model: -14.9511 │ Free En. Data: -14.8843 │ Learning Rate: 0.00928
# Epoch 185/2000 │ Loss: -0.0753 │ Modes: 88 │ Free En. Model: -14.8087 │ Free En. Data: -14.9051 │ Learning Rate: 0.00928
# Epoch 186/2000 │ Loss: -0.0766 │ Modes: 91 │ Free En. Model: -14.7577 │ Free En. Data: -14.8864 │ Learning Rate: 0.00928
# Epoch 187/2000 │ Loss: +0.0407 │ Modes: 80 │ Free En. Model: -14.9371 │ Free En. Data: -14.8931 │ Learning Rate: 0.00928
# Epoch 188/2000 │ Loss: +0.0150 │ Modes: 80 │ Free En. Model: -14.9640 │ Free En. Data: -14.9135 │ Learning Rate: 0.00928
# Epoch 189/2000 │ Loss: -0.0539 │ Modes: 86 │ Free En. Model: -14.8173 │ Free En. Data: -14.9335 │ Learning Rate: 0.00927
# Epoch 190/2000 │ Loss: -0.0399 │ Modes: 85 │ Free En. Model: -14.9349 │ Free En. Data: -14.9342 │ Learning Rate: 0.00927
# Epoch 191/2000 │ Loss: -0.0385 │ Modes: 85 │ Free En. Model: -14.8966 │ Free En. Data: -14.9276 │ Learning Rate: 0.00927
# Epoch 192/2000 │ Loss: +0.0428 │ Modes: 92 │ Free En. Model: -14.8993 │ Free En. Data: -14.9428 │ Learning Rate: 0.00927
# Epoch 193/2000 │ Loss: -0.0317 │ Modes: 92 │ Free En. Model: -14.8191 │ Free En. Data: -14.9698 │ Learning Rate: 0.00927
# Epoch 194/2000 │ Loss: -0.0243 │ Modes: 92 │ Free En. Model: -14.8841 │ Free En. Data: -14.9881 │ Learning Rate: 0.00926
# Epoch 195/2000 │ Loss: +0.0273 │ Modes: 76 │ Free En. Model: -15.0024 │ Free En. Data: -15.0071 │ Learning Rate: 0.00926
# Epoch 196/2000 │ Loss: -0.0278 │ Modes: 84 │ Free En. Model: -14.9607 │ Free En. Data: -15.0315 │ Learning Rate: 0.00926
# Epoch 197/2000 │ Loss: -0.0437 │ Modes: 93 │ Free En. Model: -14.9208 │ Free En. Data: -15.0402 │ Learning Rate: 0.00926
# Epoch 198/2000 │ Loss: -0.0489 │ Modes: 93 │ Free En. Model: -14.9443 │ Free En. Data: -15.0360 │ Learning Rate: 0.00926
# Epoch 199/2000 │ Loss: +0.0155 │ Modes: 83 │ Free En. Model: -15.0329 │ Free En. Data: -15.0338 │ Learning Rate: 0.00925
# Epoch 200/2000 │ Loss: +0.0292 │ Modes: 89 │ Free En. Model: -15.0567 │ Free En. Data: -15.0510 │ Learning Rate: 0.00925
# Epoch 201/2000 │ Loss: -0.0063 │ Modes: 78 │ Free En. Model: -15.0468 │ Free En. Data: -15.0824 │ Learning Rate: 0.00925
# Epoch 202/2000 │ Loss: -0.0480 │ Modes: 85 │ Free En. Model: -15.0645 │ Free En. Data: -15.0953 │ Learning Rate: 0.00925
# Epoch 203/2000 │ Loss: -0.0085 │ Modes: 87 │ Free En. Model: -15.0169 │ Free En. Data: -15.1040 │ Learning Rate: 0.00925
# Epoch 204/2000 │ Loss: -0.0124 │ Modes: 87 │ Free En. Model: -15.2274 │ Free En. Data: -15.0979 │ Learning Rate: 0.00924
# Epoch 205/2000 │ Loss: -0.0242 │ Modes: 86 │ Free En. Model: -15.1840 │ Free En. Data: -15.1052 │ Learning Rate: 0.00924
# Epoch 206/2000 │ Loss: -0.0265 │ Modes: 87 │ Free En. Model: -15.1589 │ Free En. Data: -15.1112 │ Learning Rate: 0.00924
# Epoch 207/2000 │ Loss: +0.0489 │ Modes: 85 │ Free En. Model: -15.1219 │ Free En. Data: -15.1304 │ Learning Rate: 0.00924
# Epoch 208/2000 │ Loss: -0.0692 │ Modes: 83 │ Free En. Model: -15.0904 │ Free En. Data: -15.1551 │ Learning Rate: 0.00923
# Epoch 209/2000 │ Loss: -0.0211 │ Modes: 84 │ Free En. Model: -15.1160 │ Free En. Data: -15.1528 │ Learning Rate: 0.00923
# Epoch 210/2000 │ Loss: -0.0250 │ Modes: 85 │ Free En. Model: -15.1604 │ Free En. Data: -15.1416 │ Learning Rate: 0.00923
# Epoch 211/2000 │ Loss: +0.0453 │ Modes: 82 │ Free En. Model: -15.1763 │ Free En. Data: -15.1616 │ Learning Rate: 0.00923
# Epoch 212/2000 │ Loss: -0.0291 │ Modes: 92 │ Free En. Model: -15.1884 │ Free En. Data: -15.1888 │ Learning Rate: 0.00923
# Epoch 213/2000 │ Loss: -0.0003 │ Modes: 85 │ Free En. Model: -15.2325 │ Free En. Data: -15.2024 │ Learning Rate: 0.00922
# Epoch 214/2000 │ Loss: -0.0510 │ Modes: 86 │ Free En. Model: -15.1382 │ Free En. Data: -15.2063 │ Learning Rate: 0.00922
# Epoch 215/2000 │ Loss: -0.0213 │ Modes: 78 │ Free En. Model: -15.2270 │ Free En. Data: -15.1924 │ Learning Rate: 0.00922
# Epoch 216/2000 │ Loss: +0.0046 │ Modes: 94 │ Free En. Model: -15.1492 │ Free En. Data: -15.2027 │ Learning Rate: 0.00922
# Epoch 217/2000 │ Loss: -0.0059 │ Modes: 81 │ Free En. Model: -15.2304 │ Free En. Data: -15.2117 │ Learning Rate: 0.00922
# Epoch 218/2000 │ Loss: -0.0221 │ Modes: 83 │ Free En. Model: -15.1854 │ Free En. Data: -15.2234 │ Learning Rate: 0.00921
# Epoch 219/2000 │ Loss: -0.0138 │ Modes: 88 │ Free En. Model: -15.1607 │ Free En. Data: -15.2288 │ Learning Rate: 0.00921
# Epoch 220/2000 │ Loss: +0.0129 │ Modes: 89 │ Free En. Model: -15.2375 │ Free En. Data: -15.2281 │ Learning Rate: 0.00921
# Epoch 221/2000 │ Loss: -0.0385 │ Modes: 83 │ Free En. Model: -15.2416 │ Free En. Data: -15.2369 │ Learning Rate: 0.00921
# Epoch 222/2000 │ Loss: +0.0153 │ Modes: 80 │ Free En. Model: -15.2520 │ Free En. Data: -15.2416 │ Learning Rate: 0.00920
# Epoch 223/2000 │ Loss: -0.0665 │ Modes: 85 │ Free En. Model: -15.2261 │ Free En. Data: -15.2443 │ Learning Rate: 0.00920
# Epoch 224/2000 │ Loss: +0.0068 │ Modes: 86 │ Free En. Model: -15.2051 │ Free En. Data: -15.2421 │ Learning Rate: 0.00920
# Epoch 225/2000 │ Loss: -0.0092 │ Modes: 86 │ Free En. Model: -15.2506 │ Free En. Data: -15.2442 │ Learning Rate: 0.00920
# Epoch 226/2000 │ Loss: -0.0378 │ Modes: 88 │ Free En. Model: -15.1644 │ Free En. Data: -15.2531 │ Learning Rate: 0.00920
# Epoch 227/2000 │ Loss: +0.0138 │ Modes: 85 │ Free En. Model: -15.2033 │ Free En. Data: -15.2521 │ Learning Rate: 0.00919
# Epoch 228/2000 │ Loss: +0.0049 │ Modes: 76 │ Free En. Model: -15.3438 │ Free En. Data: -15.2637 │ Learning Rate: 0.00919
# Epoch 229/2000 │ Loss: -0.0394 │ Modes: 76 │ Free En. Model: -15.2802 │ Free En. Data: -15.2685 │ Learning Rate: 0.00919
# Epoch 230/2000 │ Loss: +0.0187 │ Modes: 84 │ Free En. Model: -15.3469 │ Free En. Data: -15.2735 │ Learning Rate: 0.00919
# Epoch 231/2000 │ Loss: -0.0076 │ Modes: 90 │ Free En. Model: -15.2987 │ Free En. Data: -15.2909 │ Learning Rate: 0.00919
# Epoch 232/2000 │ Loss: -0.0076 │ Modes: 84 │ Free En. Model: -15.3182 │ Free En. Data: -15.3034 │ Learning Rate: 0.00918
# Epoch 233/2000 │ Loss: -0.0280 │ Modes: 86 │ Free En. Model: -15.3260 │ Free En. Data: -15.3045 │ Learning Rate: 0.00918
# Epoch 234/2000 │ Loss: -0.0296 │ Modes: 83 │ Free En. Model: -15.2649 │ Free En. Data: -15.3048 │ Learning Rate: 0.00918
# Epoch 235/2000 │ Loss: -0.0294 │ Modes: 82 │ Free En. Model: -15.2513 │ Free En. Data: -15.2842 │ Learning Rate: 0.00918
# Epoch 236/2000 │ Loss: +0.0005 │ Modes: 97 │ Free En. Model: -15.1522 │ Free En. Data: -15.2826 │ Learning Rate: 0.00917
# Epoch 237/2000 │ Loss: +0.0193 │ Modes: 87 │ Free En. Model: -15.2481 │ Free En. Data: -15.2845 │ Learning Rate: 0.00917
# Epoch 238/2000 │ Loss: +0.0038 │ Modes: 76 │ Free En. Model: -15.2851 │ Free En. Data: -15.3027 │ Learning Rate: 0.00917
# Epoch 239/2000 │ Loss: -0.0324 │ Modes: 80 │ Free En. Model: -15.2634 │ Free En. Data: -15.3141 │ Learning Rate: 0.00917
# Epoch 240/2000 │ Loss: -0.0229 │ Modes: 76 │ Free En. Model: -15.4459 │ Free En. Data: -15.2970 │ Learning Rate: 0.00916
# Epoch 241/2000 │ Loss: +0.0191 │ Modes: 80 │ Free En. Model: -15.3172 │ Free En. Data: -15.3084 │ Learning Rate: 0.00916
# Epoch 242/2000 │ Loss: -0.0184 │ Modes: 88 │ Free En. Model: -15.2285 │ Free En. Data: -15.3248 │ Learning Rate: 0.00916
# Epoch 243/2000 │ Loss: -0.0314 │ Modes: 93 │ Free En. Model: -15.2225 │ Free En. Data: -15.3257 │ Learning Rate: 0.00916
# Epoch 244/2000 │ Loss: +0.0050 │ Modes: 80 │ Free En. Model: -15.3672 │ Free En. Data: -15.3196 │ Learning Rate: 0.00916
# Epoch 245/2000 │ Loss: -0.0549 │ Modes: 86 │ Free En. Model: -15.2894 │ Free En. Data: -15.3080 │ Learning Rate: 0.00915
# Epoch 246/2000 │ Loss: +0.0230 │ Modes: 86 │ Free En. Model: -15.3083 │ Free En. Data: -15.2960 │ Learning Rate: 0.00915
# Epoch 247/2000 │ Loss: -0.0115 │ Modes: 80 │ Free En. Model: -15.3667 │ Free En. Data: -15.3018 │ Learning Rate: 0.00915
# Epoch 248/2000 │ Loss: +0.0518 │ Modes: 85 │ Free En. Model: -15.3667 │ Free En. Data: -15.3303 │ Learning Rate: 0.00915
# Epoch 249/2000 │ Loss: -0.0449 │ Modes: 88 │ Free En. Model: -15.3208 │ Free En. Data: -15.3552 │ Learning Rate: 0.00914
# Epoch 250/2000 │ Loss: -0.0688 │ Modes: 84 │ Free En. Model: -15.3498 │ Free En. Data: -15.3348 │ Learning Rate: 0.00914
# Epoch 251/2000 │ Loss: -0.0174 │ Modes: 81 │ Free En. Model: -15.3000 │ Free En. Data: -15.3014 │ Learning Rate: 0.00914
# Epoch 252/2000 │ Loss: +0.0516 │ Modes: 82 │ Free En. Model: -15.4074 │ Free En. Data: -15.2992 │ Learning Rate: 0.00914
# Epoch 253/2000 │ Loss: +0.0008 │ Modes: 77 │ Free En. Model: -15.3492 │ Free En. Data: -15.3246 │ Learning Rate: 0.00913
# Epoch 254/2000 │ Loss: -0.0357 │ Modes: 77 │ Free En. Model: -15.3239 │ Free En. Data: -15.3334 │ Learning Rate: 0.00913
# Epoch 255/2000 │ Loss: -0.0357 │ Modes: 88 │ Free En. Model: -15.2774 │ Free En. Data: -15.3245 │ Learning Rate: 0.00913
# Epoch 256/2000 │ Loss: -0.0003 │ Modes: 88 │ Free En. Model: -15.2331 │ Free En. Data: -15.3156 │ Learning Rate: 0.00913
# Epoch 257/2000 │ Loss: -0.0243 │ Modes: 89 │ Free En. Model: -15.2816 │ Free En. Data: -15.3081 │ Learning Rate: 0.00913
# Epoch 258/2000 │ Loss: +0.0154 │ Modes: 90 │ Free En. Model: -15.2550 │ Free En. Data: -15.3060 │ Learning Rate: 0.00912
# Epoch 259/2000 │ Loss: +0.0196 │ Modes: 88 │ Free En. Model: -15.3099 │ Free En. Data: -15.3238 │ Learning Rate: 0.00912
# Epoch 260/2000 │ Loss: -0.0510 │ Modes: 75 │ Free En. Model: -15.3485 │ Free En. Data: -15.3167 │ Learning Rate: 0.00912
# Epoch 261/2000 │ Loss: -0.0037 │ Modes: 80 │ Free En. Model: -15.3517 │ Free En. Data: -15.3086 │ Learning Rate: 0.00912
# Epoch 262/2000 │ Loss: -0.0193 │ Modes: 90 │ Free En. Model: -15.3440 │ Free En. Data: -15.2979 │ Learning Rate: 0.00911
# Epoch 263/2000 │ Loss: +0.0037 │ Modes: 86 │ Free En. Model: -15.2300 │ Free En. Data: -15.2978 │ Learning Rate: 0.00911
# Epoch 264/2000 │ Loss: -0.0071 │ Modes: 82 │ Free En. Model: -15.2987 │ Free En. Data: -15.2994 │ Learning Rate: 0.00911
# Epoch 265/2000 │ Loss: -0.0232 │ Modes: 79 │ Free En. Model: -15.2927 │ Free En. Data: -15.2888 │ Learning Rate: 0.00911
# Epoch 266/2000 │ Loss: +0.0133 │ Modes: 83 │ Free En. Model: -15.2772 │ Free En. Data: -15.2886 │ Learning Rate: 0.00910
# Epoch 267/2000 │ Loss: -0.0100 │ Modes: 83 │ Free En. Model: -15.2940 │ Free En. Data: -15.2986 │ Learning Rate: 0.00910
# Epoch 268/2000 │ Loss: -0.0479 │ Modes: 81 │ Free En. Model: -15.2571 │ Free En. Data: -15.2899 │ Learning Rate: 0.00910
# Epoch 269/2000 │ Loss: +0.0109 │ Modes: 83 │ Free En. Model: -15.3359 │ Free En. Data: -15.2670 │ Learning Rate: 0.00910
# Epoch 270/2000 │ Loss: +0.0192 │ Modes: 83 │ Free En. Model: -15.2369 │ Free En. Data: -15.2739 │ Learning Rate: 0.00909
# Epoch 271/2000 │ Loss: -0.0175 │ Modes: 83 │ Free En. Model: -15.2950 │ Free En. Data: -15.2803 │ Learning Rate: 0.00909
# Epoch 272/2000 │ Loss: -0.0562 │ Modes: 103 │ Free En. Model: -15.0766 │ Free En. Data: -15.2735 │ Learning Rate: 0.00909
# Epoch 273/2000 │ Loss: -0.0147 │ Modes: 82 │ Free En. Model: -15.2616 │ Free En. Data: -15.2519 │ Learning Rate: 0.00909
# Epoch 274/2000 │ Loss: +0.0508 │ Modes: 91 │ Free En. Model: -15.1629 │ Free En. Data: -15.2555 │ Learning Rate: 0.00908
# Epoch 275/2000 │ Loss: -0.0036 │ Modes: 79 │ Free En. Model: -15.2494 │ Free En. Data: -15.2716 │ Learning Rate: 0.00908
# Epoch 276/2000 │ Loss: -0.0229 │ Modes: 90 │ Free En. Model: -15.2438 │ Free En. Data: -15.2660 │ Learning Rate: 0.00908
# Epoch 277/2000 │ Loss: -0.0309 │ Modes: 91 │ Free En. Model: -15.2211 │ Free En. Data: -15.2510 │ Learning Rate: 0.00908
# Epoch 278/2000 │ Loss: +0.0105 │ Modes: 86 │ Free En. Model: -15.2725 │ Free En. Data: -15.2375 │ Learning Rate: 0.00907
# Epoch 279/2000 │ Loss: -0.0068 │ Modes: 90 │ Free En. Model: -15.1553 │ Free En. Data: -15.2439 │ Learning Rate: 0.00907
# Epoch 280/2000 │ Loss: -0.0021 │ Modes: 89 │ Free En. Model: -15.2477 │ Free En. Data: -15.2369 │ Learning Rate: 0.00907
# Epoch 281/2000 │ Loss: -0.0030 │ Modes: 89 │ Free En. Model: -15.1762 │ Free En. Data: -15.2390 │ Learning Rate: 0.00907
# Epoch 282/2000 │ Loss: -0.0333 │ Modes: 85 │ Free En. Model: -15.2019 │ Free En. Data: -15.2303 │ Learning Rate: 0.00906
# Epoch 283/2000 │ Loss: +0.0073 │ Modes: 80 │ Free En. Model: -15.2475 │ Free En. Data: -15.2168 │ Learning Rate: 0.00906
# Epoch 284/2000 │ Loss: -0.0014 │ Modes: 89 │ Free En. Model: -15.2112 │ Free En. Data: -15.2082 │ Learning Rate: 0.00906
# Epoch 285/2000 │ Loss: +0.0127 │ Modes: 89 │ Free En. Model: -15.1420 │ Free En. Data: -15.2219 │ Learning Rate: 0.00906
# Epoch 286/2000 │ Loss: -0.0461 │ Modes: 84 │ Free En. Model: -15.2333 │ Free En. Data: -15.2055 │ Learning Rate: 0.00905
# Epoch 287/2000 │ Loss: -0.0185 │ Modes: 89 │ Free En. Model: -15.1416 │ Free En. Data: -15.1839 │ Learning Rate: 0.00905
# Epoch 288/2000 │ Loss: -0.0132 │ Modes: 83 │ Free En. Model: -15.1903 │ Free En. Data: -15.1649 │ Learning Rate: 0.00905
# Epoch 289/2000 │ Loss: +0.0199 │ Modes: 91 │ Free En. Model: -15.1138 │ Free En. Data: -15.1703 │ Learning Rate: 0.00905
# Epoch 290/2000 │ Loss: +0.0296 │ Modes: 87 │ Free En. Model: -15.2195 │ Free En. Data: -15.1870 │ Learning Rate: 0.00904
# Epoch 291/2000 │ Loss: -0.0569 │ Modes: 80 │ Free En. Model: -15.1328 │ Free En. Data: -15.1833 │ Learning Rate: 0.00904
# Epoch 292/2000 │ Loss: -0.0299 │ Modes: 88 │ Free En. Model: -15.1090 │ Free En. Data: -15.1637 │ Learning Rate: 0.00904
# Epoch 293/2000 │ Loss: +0.0046 │ Modes: 85 │ Free En. Model: -15.1802 │ Free En. Data: -15.1498 │ Learning Rate: 0.00904
# Epoch 294/2000 │ Loss: +0.0091 │ Modes: 87 │ Free En. Model: -15.1159 │ Free En. Data: -15.1491 │ Learning Rate: 0.00903
# Epoch 295/2000 │ Loss: +0.0084 │ Modes: 90 │ Free En. Model: -15.0610 │ Free En. Data: -15.1584 │ Learning Rate: 0.00903
# Epoch 296/2000 │ Loss: -0.0314 │ Modes: 84 │ Free En. Model: -15.1267 │ Free En. Data: -15.1558 │ Learning Rate: 0.00903
# Epoch 297/2000 │ Loss: -0.0450 │ Modes: 80 │ Free En. Model: -15.1636 │ Free En. Data: -15.1201 │ Learning Rate: 0.00903
# Epoch 298/2000 │ Loss: +0.0380 │ Modes: 89 │ Free En. Model: -15.1432 │ Free En. Data: -15.1069 │ Learning Rate: 0.00902
# Epoch 299/2000 │ Loss: +0.0208 │ Modes: 92 │ Free En. Model: -15.0430 │ Free En. Data: -15.1206 │ Learning Rate: 0.00902
# Epoch 300/2000 │ Loss: -0.0476 │ Modes: 88 │ Free En. Model: -15.0925 │ Free En. Data: -15.1210 │ Learning Rate: 0.00902
# Epoch 301/2000 │ Loss: -0.0240 │ Modes: 80 │ Free En. Model: -15.1319 │ Free En. Data: -15.1010 │ Learning Rate: 0.00902
# Epoch 302/2000 │ Loss: +0.0176 │ Modes: 84 │ Free En. Model: -15.2049 │ Free En. Data: -15.0884 │ Learning Rate: 0.00901
# Epoch 303/2000 │ Loss: +0.0003 │ Modes: 88 │ Free En. Model: -15.1304 │ Free En. Data: -15.0837 │ Learning Rate: 0.00901
# Epoch 304/2000 │ Loss: -0.0243 │ Modes: 83 │ Free En. Model: -14.9995 │ Free En. Data: -15.0816 │ Learning Rate: 0.00901
# Epoch 305/2000 │ Loss: +0.0024 │ Modes: 82 │ Free En. Model: -15.0620 │ Free En. Data: -15.0693 │ Learning Rate: 0.00900
# Epoch 306/2000 │ Loss: -0.0138 │ Modes: 83 │ Free En. Model: -14.9663 │ Free En. Data: -15.0651 │ Learning Rate: 0.00900
# Epoch 307/2000 │ Loss: -0.0022 │ Modes: 86 │ Free En. Model: -15.0213 │ Free En. Data: -15.0625 │ Learning Rate: 0.00900
# Epoch 308/2000 │ Loss: -0.0021 │ Modes: 82 │ Free En. Model: -14.9909 │ Free En. Data: -15.0566 │ Learning Rate: 0.00900
# Epoch 309/2000 │ Loss: -0.0143 │ Modes: 81 │ Free En. Model: -15.0060 │ Free En. Data: -15.0455 │ Learning Rate: 0.00899
# Epoch 310/2000 │ Loss: -0.0465 │ Modes: 85 │ Free En. Model: -14.9577 │ Free En. Data: -15.0168 │ Learning Rate: 0.00899
# Epoch 311/2000 │ Loss: +0.0401 │ Modes: 87 │ Free En. Model: -14.9467 │ Free En. Data: -14.9972 │ Learning Rate: 0.00899
# Epoch 312/2000 │ Loss: -0.0335 │ Modes: 84 │ Free En. Model: -14.9619 │ Free En. Data: -15.0044 │ Learning Rate: 0.00899
# Epoch 313/2000 │ Loss: -0.0347 │ Modes: 81 │ Free En. Model: -15.0204 │ Free En. Data: -14.9787 │ Learning Rate: 0.00898
# Epoch 314/2000 │ Loss: +0.0620 │ Modes: 83 │ Free En. Model: -14.8971 │ Free En. Data: -14.9766 │ Learning Rate: 0.00898
# Epoch 315/2000 │ Loss: -0.0089 │ Modes: 81 │ Free En. Model: -15.0660 │ Free En. Data: -14.9872 │ Learning Rate: 0.00898
# Epoch 316/2000 │ Loss: -0.0662 │ Modes: 90 │ Free En. Model: -14.8445 │ Free En. Data: -14.9763 │ Learning Rate: 0.00898
# Epoch 317/2000 │ Loss: -0.0095 │ Modes: 83 │ Free En. Model: -14.9151 │ Free En. Data: -14.9476 │ Learning Rate: 0.00897
# Epoch 318/2000 │ Loss: -0.0044 │ Modes: 82 │ Free En. Model: -14.9271 │ Free En. Data: -14.9305 │ Learning Rate: 0.00897
# Epoch 319/2000 │ Loss: +0.0341 │ Modes: 82 │ Free En. Model: -15.0137 │ Free En. Data: -14.9274 │ Learning Rate: 0.00897
# Epoch 320/2000 │ Loss: -0.0043 │ Modes: 80 │ Free En. Model: -14.9971 │ Free En. Data: -14.9334 │ Learning Rate: 0.00896
# Epoch 321/2000 │ Loss: -0.0394 │ Modes: 82 │ Free En. Model: -14.8712 │ Free En. Data: -14.9364 │ Learning Rate: 0.00896
# Epoch 322/2000 │ Loss: -0.0281 │ Modes: 83 │ Free En. Model: -14.8814 │ Free En. Data: -14.9092 │ Learning Rate: 0.00896
# Epoch 323/2000 │ Loss: +0.0101 │ Modes: 86 │ Free En. Model: -14.8836 │ Free En. Data: -14.8882 │ Learning Rate: 0.00896
# Epoch 324/2000 │ Loss: +0.0331 │ Modes: 86 │ Free En. Model: -14.8467 │ Free En. Data: -14.9004 │ Learning Rate: 0.00895
# Epoch 325/2000 │ Loss: -0.0432 │ Modes: 79 │ Free En. Model: -14.8773 │ Free En. Data: -14.8954 │ Learning Rate: 0.00895
# Epoch 326/2000 │ Loss: -0.0014 │ Modes: 84 │ Free En. Model: -14.7978 │ Free En. Data: -14.8798 │ Learning Rate: 0.00895
# Epoch 327/2000 │ Loss: -0.0333 │ Modes: 86 │ Free En. Model: -14.8735 │ Free En. Data: -14.8545 │ Learning Rate: 0.00894
# Epoch 328/2000 │ Loss: +0.0155 │ Modes: 72 │ Free En. Model: -14.9470 │ Free En. Data: -14.8256 │ Learning Rate: 0.00894
# Epoch 329/2000 │ Loss: +0.0096 │ Modes: 83 │ Free En. Model: -14.8105 │ Free En. Data: -14.8208 │ Learning Rate: 0.00894
# Epoch 330/2000 │ Loss: -0.0464 │ Modes: 89 │ Free En. Model: -14.7248 │ Free En. Data: -14.8166 │ Learning Rate: 0.00894
# Epoch 331/2000 │ Loss: +0.0112 │ Modes: 84 │ Free En. Model: -14.8024 │ Free En. Data: -14.8008 │ Learning Rate: 0.00893
# Epoch 332/2000 │ Loss: -0.0206 │ Modes: 94 │ Free En. Model: -14.7224 │ Free En. Data: -14.7914 │ Learning Rate: 0.00893
# Epoch 333/2000 │ Loss: -0.0209 │ Modes: 85 │ Free En. Model: -14.7770 │ Free En. Data: -14.7703 │ Learning Rate: 0.00893
# Epoch 334/2000 │ Loss: +0.0080 │ Modes: 77 │ Free En. Model: -14.8119 │ Free En. Data: -14.7536 │ Learning Rate: 0.00893
# Epoch 335/2000 │ Loss: +0.0217 │ Modes: 83 │ Free En. Model: -14.7406 │ Free En. Data: -14.7520 │ Learning Rate: 0.00892
# Epoch 336/2000 │ Loss: -0.0161 │ Modes: 84 │ Free En. Model: -14.7203 │ Free En. Data: -14.7613 │ Learning Rate: 0.00892
# Epoch 337/2000 │ Loss: +0.0052 │ Modes: 87 │ Free En. Model: -14.7891 │ Free En. Data: -14.7536 │ Learning Rate: 0.00892
# Epoch 338/2000 │ Loss: -0.0045 │ Modes: 73 │ Free En. Model: -14.8165 │ Free En. Data: -14.7411 │ Learning Rate: 0.00891
# Epoch 339/2000 │ Loss: -0.0418 │ Modes: 87 │ Free En. Model: -14.6383 │ Free En. Data: -14.7259 │ Learning Rate: 0.00891
# Epoch 340/2000 │ Loss: -0.0229 │ Modes: 88 │ Free En. Model: -14.6295 │ Free En. Data: -14.7019 │ Learning Rate: 0.00891
# Epoch 341/2000 │ Loss: -0.0107 │ Modes: 79 │ Free En. Model: -14.6796 │ Free En. Data: -14.6723 │ Learning Rate: 0.00891
# Epoch 342/2000 │ Loss: +0.0534 │ Modes: 85 │ Free En. Model: -14.6621 │ Free En. Data: -14.6682 │ Learning Rate: 0.00890
# Epoch 343/2000 │ Loss: -0.0012 │ Modes: 76 │ Free En. Model: -14.7124 │ Free En. Data: -14.6877 │ Learning Rate: 0.00890
# Epoch 344/2000 │ Loss: -0.0240 │ Modes: 86 │ Free En. Model: -14.6536 │ Free En. Data: -14.6831 │ Learning Rate: 0.00890
# Epoch 345/2000 │ Loss: -0.0534 │ Modes: 89 │ Free En. Model: -14.5644 │ Free En. Data: -14.6544 │ Learning Rate: 0.00889
# Epoch 346/2000 │ Loss: +0.0217 │ Modes: 80 │ Free En. Model: -14.7016 │ Free En. Data: -14.6246 │ Learning Rate: 0.00889
# Epoch 347/2000 │ Loss: -0.0106 │ Modes: 81 │ Free En. Model: -14.5854 │ Free En. Data: -14.6190 │ Learning Rate: 0.00889
# Epoch 348/2000 │ Loss: -0.0204 │ Modes: 86 │ Free En. Model: -14.5803 │ Free En. Data: -14.6015 │ Learning Rate: 0.00888
# Epoch 349/2000 │ Loss: +0.0086 │ Modes: 89 │ Free En. Model: -14.5901 │ Free En. Data: -14.5870 │ Learning Rate: 0.00888
# Epoch 350/2000 │ Loss: -0.0141 │ Modes: 86 │ Free En. Model: -14.5977 │ Free En. Data: -14.5682 │ Learning Rate: 0.00888
# Epoch 351/2000 │ Loss: -0.0111 │ Modes: 84 │ Free En. Model: -14.5341 │ Free En. Data: -14.5570 │ Learning Rate: 0.00888
# Epoch 352/2000 │ Loss: +0.0082 │ Modes: 84 │ Free En. Model: -14.6116 │ Free En. Data: -14.5372 │ Learning Rate: 0.00887
# Epoch 353/2000 │ Loss: -0.0138 │ Modes: 89 │ Free En. Model: -14.3953 │ Free En. Data: -14.5311 │ Learning Rate: 0.00887
# Epoch 354/2000 │ Loss: -0.0265 │ Modes: 78 │ Free En. Model: -14.5442 │ Free En. Data: -14.5126 │ Learning Rate: 0.00887
# Epoch 355/2000 │ Loss: +0.0111 │ Modes: 85 │ Free En. Model: -14.4579 │ Free En. Data: -14.4948 │ Learning Rate: 0.00886
# Epoch 356/2000 │ Loss: -0.0029 │ Modes: 84 │ Free En. Model: -14.5281 │ Free En. Data: -14.4812 │ Learning Rate: 0.00886
# Epoch 357/2000 │ Loss: +0.0024 │ Modes: 94 │ Free En. Model: -14.2938 │ Free En. Data: -14.4818 │ Learning Rate: 0.00886
# Epoch 358/2000 │ Loss: -0.0396 │ Modes: 79 │ Free En. Model: -14.4875 │ Free En. Data: -14.4602 │ Learning Rate: 0.00886
# Epoch 359/2000 │ Loss: +0.0195 │ Modes: 91 │ Free En. Model: -14.4134 │ Free En. Data: -14.4510 │ Learning Rate: 0.00885
# Epoch 360/2000 │ Loss: -0.0038 │ Modes: 85 │ Free En. Model: -14.3970 │ Free En. Data: -14.4369 │ Learning Rate: 0.00885
# Epoch 361/2000 │ Loss: -0.0095 │ Modes: 86 │ Free En. Model: -14.4442 │ Free En. Data: -14.4226 │ Learning Rate: 0.00885
# Epoch 362/2000 │ Loss: -0.0338 │ Modes: 90 │ Free En. Model: -14.3982 │ Free En. Data: -14.4039 │ Learning Rate: 0.00884
# Epoch 363/2000 │ Loss: +0.0155 │ Modes: 89 │ Free En. Model: -14.4706 │ Free En. Data: -14.3877 │ Learning Rate: 0.00884
# Epoch 364/2000 │ Loss: -0.0210 │ Modes: 78 │ Free En. Model: -14.3526 │ Free En. Data: -14.3700 │ Learning Rate: 0.00884
# Epoch 365/2000 │ Loss: +0.0054 │ Modes: 85 │ Free En. Model: -14.3254 │ Free En. Data: -14.3605 │ Learning Rate: 0.00883
# Epoch 366/2000 │ Loss: -0.0231 │ Modes: 84 │ Free En. Model: -14.3368 │ Free En. Data: -14.3431 │ Learning Rate: 0.00883
# Epoch 367/2000 │ Loss: +0.0036 │ Modes: 78 │ Free En. Model: -14.2501 │ Free En. Data: -14.3229 │ Learning Rate: 0.00883
# Epoch 368/2000 │ Loss: +0.0080 │ Modes: 75 │ Free En. Model: -14.3639 │ Free En. Data: -14.3070 │ Learning Rate: 0.00882
# Epoch 369/2000 │ Loss: -0.0066 │ Modes: 85 │ Free En. Model: -14.2985 │ Free En. Data: -14.3095 │ Learning Rate: 0.00882
# Epoch 370/2000 │ Loss: -0.0289 │ Modes: 81 │ Free En. Model: -14.3049 │ Free En. Data: -14.2835 │ Learning Rate: 0.00882
# Epoch 371/2000 │ Loss: -0.0138 │ Modes: 73 │ Free En. Model: -14.2848 │ Free En. Data: -14.2577 │ Learning Rate: 0.00882
# Epoch 372/2000 │ Loss: +0.0054 │ Modes: 90 │ Free En. Model: -14.2246 │ Free En. Data: -14.2381 │ Learning Rate: 0.00881
# Epoch 373/2000 │ Loss: -0.0296 │ Modes: 91 │ Free En. Model: -14.1912 │ Free En. Data: -14.2184 │ Learning Rate: 0.00881
# Epoch 374/2000 │ Loss: +0.0445 │ Modes: 95 │ Free En. Model: -14.2082 │ Free En. Data: -14.2138 │ Learning Rate: 0.00881
# Epoch 375/2000 │ Loss: -0.0111 │ Modes: 84 │ Free En. Model: -14.2656 │ Free En. Data: -14.2085 │ Learning Rate: 0.00880
# Epoch 376/2000 │ Loss: -0.0489 │ Modes: 83 │ Free En. Model: -14.1755 │ Free En. Data: -14.1871 │ Learning Rate: 0.00880
# Epoch 377/2000 │ Loss: +0.0117 │ Modes: 83 │ Free En. Model: -14.1842 │ Free En. Data: -14.1525 │ Learning Rate: 0.00880
# Epoch 378/2000 │ Loss: +0.0091 │ Modes: 79 │ Free En. Model: -14.1336 │ Free En. Data: -14.1427 │ Learning Rate: 0.00879
# Epoch 379/2000 │ Loss: -0.0335 │ Modes: 91 │ Free En. Model: -14.0344 │ Free En. Data: -14.1278 │ Learning Rate: 0.00879
# Epoch 380/2000 │ Loss: +0.0098 │ Modes: 83 │ Free En. Model: -14.1382 │ Free En. Data: -14.0986 │ Learning Rate: 0.00879
# Epoch 381/2000 │ Loss: +0.0160 │ Modes: 82 │ Free En. Model: -14.1290 │ Free En. Data: -14.0903 │ Learning Rate: 0.00878
# Epoch 382/2000 │ Loss: -0.0599 │ Modes: 93 │ Free En. Model: -13.9546 │ Free En. Data: -14.0620 │ Learning Rate: 0.00878
# Epoch 383/2000 │ Loss: +0.0714 │ Modes: 78 │ Free En. Model: -14.1269 │ Free En. Data: -14.0454 │ Learning Rate: 0.00878
# Epoch 384/2000 │ Loss: -0.0232 │ Modes: 76 │ Free En. Model: -14.0683 │ Free En. Data: -14.0468 │ Learning Rate: 0.00878
# Epoch 385/2000 │ Loss: -0.0121 │ Modes: 85 │ Free En. Model: -13.9993 │ Free En. Data: -14.0305 │ Learning Rate: 0.00877
# Epoch 386/2000 │ Loss: -0.0204 │ Modes: 85 │ Free En. Model: -13.9545 │ Free En. Data: -14.0047 │ Learning Rate: 0.00877
# Epoch 387/2000 │ Loss: -0.0369 │ Modes: 88 │ Free En. Model: -13.9491 │ Free En. Data: -13.9684 │ Learning Rate: 0.00877
# Epoch 388/2000 │ Loss: +0.0096 │ Modes: 87 │ Free En. Model: -13.8998 │ Free En. Data: -13.9389 │ Learning Rate: 0.00876
# Epoch 389/2000 │ Loss: +0.0118 │ Modes: 92 │ Free En. Model: -13.8168 │ Free En. Data: -13.9293 │ Learning Rate: 0.00876
# Epoch 390/2000 │ Loss: -0.0430 │ Modes: 83 │ Free En. Model: -13.8868 │ Free En. Data: -13.9018 │ Learning Rate: 0.00876
# Epoch 391/2000 │ Loss: +0.0419 │ Modes: 77 │ Free En. Model: -14.0203 │ Free En. Data: -13.8791 │ Learning Rate: 0.00875
# Epoch 392/2000 │ Loss: -0.0081 │ Modes: 82 │ Free En. Model: -13.8947 │ Free En. Data: -13.8717 │ Learning Rate: 0.00875
# Epoch 393/2000 │ Loss: -0.0178 │ Modes: 72 │ Free En. Model: -13.9310 │ Free En. Data: -13.8607 │ Learning Rate: 0.00875
# Epoch 394/2000 │ Loss: -0.0068 │ Modes: 85 │ Free En. Model: -13.8505 │ Free En. Data: -13.8367 │ Learning Rate: 0.00874
# Epoch 395/2000 │ Loss: +0.0047 │ Modes: 94 │ Free En. Model: -13.7230 │ Free En. Data: -13.8259 │ Learning Rate: 0.00874
# Epoch 396/2000 │ Loss: -0.0289 │ Modes: 83 │ Free En. Model: -13.8809 │ Free En. Data: -13.7966 │ Learning Rate: 0.00874
# Epoch 397/2000 │ Loss: -0.0445 │ Modes: 82 │ Free En. Model: -13.7997 │ Free En. Data: -13.7561 │ Learning Rate: 0.00873
# Epoch 398/2000 │ Loss: +0.0497 │ Modes: 83 │ Free En. Model: -13.6711 │ Free En. Data: -13.7462 │ Learning Rate: 0.00873
# ...
# Epoch 1868/2000 │ Loss: -0.0389 │ Modes: 21 │ Free En. Model: -8.6005 │ Free En. Data: -8.7102 │ Learning Rate: 0.00162
# Epoch 1869/2000 │ Loss: -0.0505 │ Modes: 27 │ Free En. Model: -8.5243 │ Free En. Data: -8.7094 │ Learning Rate: 0.00162
# Epoch 1870/2000 │ Loss: -0.0341 │ Modes: 22 │ Free En. Model: -8.5672 │ Free En. Data: -8.7102 │ Learning Rate: 0.00162
# Epoch 1871/2000 │ Loss: -0.0388 │ Modes: 22 │ Free En. Model: -8.6042 │ Free En. Data: -8.7103 │ Learning Rate: 0.00161
# Epoch 1872/2000 │ Loss: -0.0310 │ Modes: 28 │ Free En. Model: -8.5592 │ Free En. Data: -8.7112 │ Learning Rate: 0.00161
# Epoch 1873/2000 │ Loss: -0.0287 │ Modes: 21 │ Free En. Model: -8.5790 │ Free En. Data: -8.7087 │ Learning Rate: 0.00161
# Epoch 1874/2000 │ Loss: -0.0314 │ Modes: 24 │ Free En. Model: -8.5578 │ Free En. Data: -8.7056 │ Learning Rate: 0.00161
# Epoch 1875/2000 │ Loss: -0.0427 │ Modes: 22 │ Free En. Model: -8.5696 │ Free En. Data: -8.7057 │ Learning Rate: 0.00161
# Epoch 1876/2000 │ Loss: -0.0170 │ Modes: 19 │ Free En. Model: -8.6169 │ Free En. Data: -8.7065 │ Learning Rate: 0.00161
# Epoch 1877/2000 │ Loss: -0.0405 │ Modes: 26 │ Free En. Model: -8.5453 │ Free En. Data: -8.7077 │ Learning Rate: 0.00160
# Epoch 1878/2000 │ Loss: -0.0578 │ Modes: 22 │ Free En. Model: -8.5217 │ Free En. Data: -8.7104 │ Learning Rate: 0.00160
# Epoch 1879/2000 │ Loss: -0.0310 │ Modes: 27 │ Free En. Model: -8.5474 │ Free En. Data: -8.7086 │ Learning Rate: 0.00160
# Epoch 1880/2000 │ Loss: -0.0328 │ Modes: 27 │ Free En. Model: -8.5201 │ Free En. Data: -8.7082 │ Learning Rate: 0.00160
# Epoch 1881/2000 │ Loss: -0.0369 │ Modes: 31 │ Free En. Model: -8.5140 │ Free En. Data: -8.7089 │ Learning Rate: 0.00160
# Epoch 1882/2000 │ Loss: -0.0236 │ Modes: 22 │ Free En. Model: -8.5861 │ Free En. Data: -8.7098 │ Learning Rate: 0.00160
# Epoch 1883/2000 │ Loss: -0.0285 │ Modes: 22 │ Free En. Model: -8.6125 │ Free En. Data: -8.7103 │ Learning Rate: 0.00159
# Epoch 1884/2000 │ Loss: -0.0382 │ Modes: 25 │ Free En. Model: -8.5498 │ Free En. Data: -8.7090 │ Learning Rate: 0.00159
# Epoch 1885/2000 │ Loss: -0.0431 │ Modes: 20 │ Free En. Model: -8.5803 │ Free En. Data: -8.7088 │ Learning Rate: 0.00159
# Epoch 1886/2000 │ Loss: -0.0537 │ Modes: 24 │ Free En. Model: -8.5663 │ Free En. Data: -8.7090 │ Learning Rate: 0.00159
# Epoch 1887/2000 │ Loss: -0.0263 │ Modes: 26 │ Free En. Model: -8.5454 │ Free En. Data: -8.7075 │ Learning Rate: 0.00159
# Epoch 1888/2000 │ Loss: -0.0211 │ Modes: 23 │ Free En. Model: -8.5707 │ Free En. Data: -8.7091 │ Learning Rate: 0.00159
# Epoch 1889/2000 │ Loss: -0.0311 │ Modes: 28 │ Free En. Model: -8.5396 │ Free En. Data: -8.7134 │ Learning Rate: 0.00158
# Epoch 1890/2000 │ Loss: -0.0384 │ Modes: 24 │ Free En. Model: -8.5449 │ Free En. Data: -8.7139 │ Learning Rate: 0.00158
# Epoch 1891/2000 │ Loss: -0.0239 │ Modes: 24 │ Free En. Model: -8.5824 │ Free En. Data: -8.7128 │ Learning Rate: 0.00158
# Epoch 1892/2000 │ Loss: -0.0281 │ Modes: 22 │ Free En. Model: -8.5812 │ Free En. Data: -8.7123 │ Learning Rate: 0.00158
# Epoch 1893/2000 │ Loss: -0.0358 │ Modes: 28 │ Free En. Model: -8.5490 │ Free En. Data: -8.7110 │ Learning Rate: 0.00158
# Epoch 1894/2000 │ Loss: -0.0303 │ Modes: 25 │ Free En. Model: -8.5562 │ Free En. Data: -8.7101 │ Learning Rate: 0.00158
# Epoch 1895/2000 │ Loss: -0.0491 │ Modes: 22 │ Free En. Model: -8.5279 │ Free En. Data: -8.7058 │ Learning Rate: 0.00157
# Epoch 1896/2000 │ Loss: -0.0267 │ Modes: 17 │ Free En. Model: -8.6218 │ Free En. Data: -8.7052 │ Learning Rate: 0.00157
# Epoch 1897/2000 │ Loss: -0.0283 │ Modes: 20 │ Free En. Model: -8.5760 │ Free En. Data: -8.7015 │ Learning Rate: 0.00157
# Epoch 1898/2000 │ Loss: -0.0249 │ Modes: 19 │ Free En. Model: -8.5844 │ Free En. Data: -8.6994 │ Learning Rate: 0.00157
# Epoch 1899/2000 │ Loss: -0.0249 │ Modes: 25 │ Free En. Model: -8.5502 │ Free En. Data: -8.6985 │ Learning Rate: 0.00157
# Epoch 1900/2000 │ Loss: -0.0210 │ Modes: 19 │ Free En. Model: -8.6088 │ Free En. Data: -8.6979 │ Learning Rate: 0.00157
# Epoch 1901/2000 │ Loss: -0.0274 │ Modes: 24 │ Free En. Model: -8.5605 │ Free En. Data: -8.7004 │ Learning Rate: 0.00157
# Epoch 1902/2000 │ Loss: -0.0485 │ Modes: 22 │ Free En. Model: -8.5625 │ Free En. Data: -8.7012 │ Learning Rate: 0.00156
# Epoch 1903/2000 │ Loss: -0.0243 │ Modes: 23 │ Free En. Model: -8.5607 │ Free En. Data: -8.7065 │ Learning Rate: 0.00156
# Epoch 1904/2000 │ Loss: -0.0374 │ Modes: 26 │ Free En. Model: -8.5315 │ Free En. Data: -8.7076 │ Learning Rate: 0.00156
# Epoch 1905/2000 │ Loss: -0.0293 │ Modes: 25 │ Free En. Model: -8.5730 │ Free En. Data: -8.7090 │ Learning Rate: 0.00156
# Epoch 1906/2000 │ Loss: -0.0233 │ Modes: 27 │ Free En. Model: -8.5339 │ Free En. Data: -8.7083 │ Learning Rate: 0.00156
# Epoch 1907/2000 │ Loss: -0.0368 │ Modes: 27 │ Free En. Model: -8.5444 │ Free En. Data: -8.7080 │ Learning Rate: 0.00156
# Epoch 1908/2000 │ Loss: -0.0466 │ Modes: 28 │ Free En. Model: -8.5194 │ Free En. Data: -8.7074 │ Learning Rate: 0.00155
# Epoch 1909/2000 │ Loss: -0.0265 │ Modes: 26 │ Free En. Model: -8.5345 │ Free En. Data: -8.7100 │ Learning Rate: 0.00155
# Epoch 1910/2000 │ Loss: -0.0215 │ Modes: 18 │ Free En. Model: -8.6061 │ Free En. Data: -8.7067 │ Learning Rate: 0.00155
# Epoch 1911/2000 │ Loss: -0.0334 │ Modes: 22 │ Free En. Model: -8.5670 │ Free En. Data: -8.7064 │ Learning Rate: 0.00155
# Epoch 1912/2000 │ Loss: -0.0270 │ Modes: 23 │ Free En. Model: -8.5536 │ Free En. Data: -8.7075 │ Learning Rate: 0.00155
# Epoch 1913/2000 │ Loss: -0.0133 │ Modes: 20 │ Free En. Model: -8.5829 │ Free En. Data: -8.7046 │ Learning Rate: 0.00155
# Epoch 1914/2000 │ Loss: -0.0392 │ Modes: 24 │ Free En. Model: -8.5483 │ Free En. Data: -8.7014 │ Learning Rate: 0.00154
# Epoch 1915/2000 │ Loss: -0.0303 │ Modes: 24 │ Free En. Model: -8.5577 │ Free En. Data: -8.7024 │ Learning Rate: 0.00154
# Epoch 1916/2000 │ Loss: -0.0222 │ Modes: 22 │ Free En. Model: -8.5784 │ Free En. Data: -8.7006 │ Learning Rate: 0.00154
# Epoch 1917/2000 │ Loss: -0.0313 │ Modes: 19 │ Free En. Model: -8.5834 │ Free En. Data: -8.7005 │ Learning Rate: 0.00154
# Epoch 1918/2000 │ Loss: -0.0555 │ Modes: 25 │ Free En. Model: -8.5405 │ Free En. Data: -8.7038 │ Learning Rate: 0.00154
# Epoch 1919/2000 │ Loss: -0.0461 │ Modes: 24 │ Free En. Model: -8.5307 │ Free En. Data: -8.7015 │ Learning Rate: 0.00154
# Epoch 1920/2000 │ Loss: -0.0281 │ Modes: 21 │ Free En. Model: -8.5661 │ Free En. Data: -8.7072 │ Learning Rate: 0.00154
# Epoch 1921/2000 │ Loss: -0.0281 │ Modes: 25 │ Free En. Model: -8.5685 │ Free En. Data: -8.7062 │ Learning Rate: 0.00153
# Epoch 1922/2000 │ Loss: -0.0158 │ Modes: 24 │ Free En. Model: -8.5654 │ Free En. Data: -8.7041 │ Learning Rate: 0.00153
# Epoch 1923/2000 │ Loss: -0.0310 │ Modes: 24 │ Free En. Model: -8.5740 │ Free En. Data: -8.7021 │ Learning Rate: 0.00153
# Epoch 1924/2000 │ Loss: -0.0295 │ Modes: 19 │ Free En. Model: -8.5994 │ Free En. Data: -8.7019 │ Learning Rate: 0.00153
# Epoch 1925/2000 │ Loss: -0.0435 │ Modes: 23 │ Free En. Model: -8.5297 │ Free En. Data: -8.7026 │ Learning Rate: 0.00153
# Epoch 1926/2000 │ Loss: -0.0395 │ Modes: 22 │ Free En. Model: -8.5809 │ Free En. Data: -8.6995 │ Learning Rate: 0.00153
# Epoch 1927/2000 │ Loss: -0.0318 │ Modes: 24 │ Free En. Model: -8.5327 │ Free En. Data: -8.7014 │ Learning Rate: 0.00153
# Epoch 1928/2000 │ Loss: -0.0271 │ Modes: 21 │ Free En. Model: -8.5753 │ Free En. Data: -8.7029 │ Learning Rate: 0.00152
# Epoch 1929/2000 │ Loss: -0.0292 │ Modes: 18 │ Free En. Model: -8.5835 │ Free En. Data: -8.7049 │ Learning Rate: 0.00152
# Epoch 1930/2000 │ Loss: -0.0273 │ Modes: 24 │ Free En. Model: -8.5658 │ Free En. Data: -8.7069 │ Learning Rate: 0.00152
# Epoch 1931/2000 │ Loss: -0.0410 │ Modes: 23 │ Free En. Model: -8.5937 │ Free En. Data: -8.7063 │ Learning Rate: 0.00152
# Epoch 1932/2000 │ Loss: -0.0557 │ Modes: 26 │ Free En. Model: -8.5384 │ Free En. Data: -8.7050 │ Learning Rate: 0.00152
# Epoch 1933/2000 │ Loss: -0.0501 │ Modes: 23 │ Free En. Model: -8.5572 │ Free En. Data: -8.7018 │ Learning Rate: 0.00152
# Epoch 1934/2000 │ Loss: -0.0479 │ Modes: 24 │ Free En. Model: -8.5441 │ Free En. Data: -8.7056 │ Learning Rate: 0.00151
# Epoch 1935/2000 │ Loss: -0.0211 │ Modes: 23 │ Free En. Model: -8.5571 │ Free En. Data: -8.7037 │ Learning Rate: 0.00151
# Epoch 1936/2000 │ Loss: -0.0293 │ Modes: 23 │ Free En. Model: -8.5679 │ Free En. Data: -8.7027 │ Learning Rate: 0.00151
# Epoch 1937/2000 │ Loss: -0.0252 │ Modes: 20 │ Free En. Model: -8.6023 │ Free En. Data: -8.7044 │ Learning Rate: 0.00151
# Epoch 1938/2000 │ Loss: -0.0188 │ Modes: 21 │ Free En. Model: -8.5952 │ Free En. Data: -8.7030 │ Learning Rate: 0.00151
# Epoch 1939/2000 │ Loss: -0.0504 │ Modes: 19 │ Free En. Model: -8.5646 │ Free En. Data: -8.7020 │ Learning Rate: 0.00151
# Epoch 1940/2000 │ Loss: -0.0262 │ Modes: 23 │ Free En. Model: -8.5673 │ Free En. Data: -8.6976 │ Learning Rate: 0.00151
# Epoch 1941/2000 │ Loss: -0.0286 │ Modes: 23 │ Free En. Model: -8.5901 │ Free En. Data: -8.6991 │ Learning Rate: 0.00150
# Epoch 1942/2000 │ Loss: -0.0161 │ Modes: 19 │ Free En. Model: -8.5920 │ Free En. Data: -8.7015 │ Learning Rate: 0.00150
# Epoch 1943/2000 │ Loss: -0.0514 │ Modes: 24 │ Free En. Model: -8.5583 │ Free En. Data: -8.7032 │ Learning Rate: 0.00150
# Epoch 1944/2000 │ Loss: -0.0400 │ Modes: 24 │ Free En. Model: -8.5494 │ Free En. Data: -8.7042 │ Learning Rate: 0.00150
# Epoch 1945/2000 │ Loss: -0.0333 │ Modes: 20 │ Free En. Model: -8.5799 │ Free En. Data: -8.7037 │ Learning Rate: 0.00150
# Epoch 1946/2000 │ Loss: -0.0373 │ Modes: 24 │ Free En. Model: -8.5456 │ Free En. Data: -8.7034 │ Learning Rate: 0.00150
# Epoch 1947/2000 │ Loss: -0.0279 │ Modes: 26 │ Free En. Model: -8.5470 │ Free En. Data: -8.7048 │ Learning Rate: 0.00150
# Epoch 1948/2000 │ Loss: -0.0464 │ Modes: 26 │ Free En. Model: -8.5297 │ Free En. Data: -8.7028 │ Learning Rate: 0.00149
# Epoch 1949/2000 │ Loss: -0.0222 │ Modes: 23 │ Free En. Model: -8.5608 │ Free En. Data: -8.7033 │ Learning Rate: 0.00149
# Epoch 1950/2000 │ Loss: -0.0250 │ Modes: 23 │ Free En. Model: -8.5778 │ Free En. Data: -8.7019 │ Learning Rate: 0.00149
# Epoch 1951/2000 │ Loss: -0.0416 │ Modes: 30 │ Free En. Model: -8.5099 │ Free En. Data: -8.7028 │ Learning Rate: 0.00149
# Epoch 1952/2000 │ Loss: -0.0196 │ Modes: 22 │ Free En. Model: -8.5859 │ Free En. Data: -8.7034 │ Learning Rate: 0.00149
# Epoch 1953/2000 │ Loss: -0.0423 │ Modes: 24 │ Free En. Model: -8.5183 │ Free En. Data: -8.6999 │ Learning Rate: 0.00149
# Epoch 1954/2000 │ Loss: -0.0346 │ Modes: 25 │ Free En. Model: -8.5120 │ Free En. Data: -8.6998 │ Learning Rate: 0.00149
# Epoch 1955/2000 │ Loss: -0.0340 │ Modes: 25 │ Free En. Model: -8.5240 │ Free En. Data: -8.6998 │ Learning Rate: 0.00149
# Epoch 1956/2000 │ Loss: -0.0482 │ Modes: 26 │ Free En. Model: -8.5452 │ Free En. Data: -8.6990 │ Learning Rate: 0.00148
# Epoch 1957/2000 │ Loss: -0.0162 │ Modes: 24 │ Free En. Model: -8.5697 │ Free En. Data: -8.6975 │ Learning Rate: 0.00148
# Epoch 1958/2000 │ Loss: -0.0379 │ Modes: 23 │ Free En. Model: -8.5659 │ Free En. Data: -8.6992 │ Learning Rate: 0.00148
# Epoch 1959/2000 │ Loss: -0.0524 │ Modes: 23 │ Free En. Model: -8.5398 │ Free En. Data: -8.7015 │ Learning Rate: 0.00148
# Epoch 1960/2000 │ Loss: -0.0308 │ Modes: 23 │ Free En. Model: -8.5730 │ Free En. Data: -8.7014 │ Learning Rate: 0.00148
# Epoch 1961/2000 │ Loss: -0.0286 │ Modes: 19 │ Free En. Model: -8.5894 │ Free En. Data: -8.7033 │ Learning Rate: 0.00148
# Epoch 1962/2000 │ Loss: -0.0350 │ Modes: 22 │ Free En. Model: -8.5557 │ Free En. Data: -8.7005 │ Learning Rate: 0.00148
# Epoch 1963/2000 │ Loss: -0.0253 │ Modes: 20 │ Free En. Model: -8.6018 │ Free En. Data: -8.6993 │ Learning Rate: 0.00147
# Epoch 1964/2000 │ Loss: -0.0202 │ Modes: 23 │ Free En. Model: -8.5776 │ Free En. Data: -8.6955 │ Learning Rate: 0.00147
# Epoch 1965/2000 │ Loss: -0.0294 │ Modes: 21 │ Free En. Model: -8.5502 │ Free En. Data: -8.6950 │ Learning Rate: 0.00147
# Epoch 1966/2000 │ Loss: -0.0247 │ Modes: 22 │ Free En. Model: -8.5740 │ Free En. Data: -8.6939 │ Learning Rate: 0.00147
# Epoch 1967/2000 │ Loss: -0.0194 │ Modes: 24 │ Free En. Model: -8.5395 │ Free En. Data: -8.6940 │ Learning Rate: 0.00147
# Epoch 1968/2000 │ Loss: -0.0369 │ Modes: 25 │ Free En. Model: -8.5474 │ Free En. Data: -8.7007 │ Learning Rate: 0.00147
# Epoch 1969/2000 │ Loss: -0.0348 │ Modes: 26 │ Free En. Model: -8.5428 │ Free En. Data: -8.7008 │ Learning Rate: 0.00147
# Epoch 1970/2000 │ Loss: -0.0438 │ Modes: 26 │ Free En. Model: -8.5464 │ Free En. Data: -8.6999 │ Learning Rate: 0.00146
# Epoch 1971/2000 │ Loss: -0.0333 │ Modes: 25 │ Free En. Model: -8.5432 │ Free En. Data: -8.7013 │ Learning Rate: 0.00146
# Epoch 1972/2000 │ Loss: -0.0284 │ Modes: 22 │ Free En. Model: -8.5710 │ Free En. Data: -8.7012 │ Learning Rate: 0.00146
# Epoch 1973/2000 │ Loss: -0.0403 │ Modes: 23 │ Free En. Model: -8.5657 │ Free En. Data: -8.6984 │ Learning Rate: 0.00146
# Epoch 1974/2000 │ Loss: -0.0421 │ Modes: 21 │ Free En. Model: -8.5676 │ Free En. Data: -8.6998 │ Learning Rate: 0.00146
# Epoch 1975/2000 │ Loss: -0.0506 │ Modes: 24 │ Free En. Model: -8.5437 │ Free En. Data: -8.6997 │ Learning Rate: 0.00146
# Epoch 1976/2000 │ Loss: -0.0339 │ Modes: 23 │ Free En. Model: -8.5472 │ Free En. Data: -8.7019 │ Learning Rate: 0.00146
# Epoch 1977/2000 │ Loss: -0.0440 │ Modes: 22 │ Free En. Model: -8.5547 │ Free En. Data: -8.7005 │ Learning Rate: 0.00146
# Epoch 1978/2000 │ Loss: -0.0265 │ Modes: 21 │ Free En. Model: -8.5580 │ Free En. Data: -8.7006 │ Learning Rate: 0.00145
# Epoch 1979/2000 │ Loss: -0.0321 │ Modes: 19 │ Free En. Model: -8.6013 │ Free En. Data: -8.7000 │ Learning Rate: 0.00145
# Epoch 1980/2000 │ Loss: -0.0311 │ Modes: 25 │ Free En. Model: -8.5247 │ Free En. Data: -8.7009 │ Learning Rate: 0.00145
# Epoch 1981/2000 │ Loss: -0.0338 │ Modes: 21 │ Free En. Model: -8.5510 │ Free En. Data: -8.7014 │ Learning Rate: 0.00145
# Epoch 1982/2000 │ Loss: -0.0375 │ Modes: 26 │ Free En. Model: -8.5416 │ Free En. Data: -8.7040 │ Learning Rate: 0.00145
# Epoch 1983/2000 │ Loss: -0.0346 │ Modes: 28 │ Free En. Model: -8.5110 │ Free En. Data: -8.7045 │ Learning Rate: 0.00145
# Epoch 1984/2000 │ Loss: -0.0253 │ Modes: 24 │ Free En. Model: -8.5641 │ Free En. Data: -8.7038 │ Learning Rate: 0.00145
# Epoch 1985/2000 │ Loss: -0.0400 │ Modes: 29 │ Free En. Model: -8.5064 │ Free En. Data: -8.7030 │ Learning Rate: 0.00145
# Epoch 1986/2000 │ Loss: -0.0213 │ Modes: 20 │ Free En. Model: -8.6007 │ Free En. Data: -8.7008 │ Learning Rate: 0.00144
# Epoch 1987/2000 │ Loss: -0.0286 │ Modes: 25 │ Free En. Model: -8.5164 │ Free En. Data: -8.7025 │ Learning Rate: 0.00144
# Epoch 1988/2000 │ Loss: -0.0485 │ Modes: 22 │ Free En. Model: -8.5678 │ Free En. Data: -8.7040 │ Learning Rate: 0.00144
# Epoch 1989/2000 │ Loss: -0.0446 │ Modes: 23 │ Free En. Model: -8.5582 │ Free En. Data: -8.7023 │ Learning Rate: 0.00144
# Epoch 1990/2000 │ Loss: -0.0478 │ Modes: 27 │ Free En. Model: -8.5151 │ Free En. Data: -8.7028 │ Learning Rate: 0.00144
# Epoch 1991/2000 │ Loss: -0.0391 │ Modes: 19 │ Free En. Model: -8.5933 │ Free En. Data: -8.7023 │ Learning Rate: 0.00144
# Epoch 1992/2000 │ Loss: -0.0132 │ Modes: 26 │ Free En. Model: -8.5256 │ Free En. Data: -8.7010 │ Learning Rate: 0.00144
# Epoch 1993/2000 │ Loss: -0.0288 │ Modes: 24 │ Free En. Model: -8.5332 │ Free En. Data: -8.6984 │ Learning Rate: 0.00144
# Epoch 1994/2000 │ Loss: -0.0501 │ Modes: 25 │ Free En. Model: -8.5520 │ Free En. Data: -8.6976 │ Learning Rate: 0.00143
# Epoch 1995/2000 │ Loss: -0.0358 │ Modes: 27 │ Free En. Model: -8.5086 │ Free En. Data: -8.6987 │ Learning Rate: 0.00143
# Epoch 1996/2000 │ Loss: -0.0273 │ Modes: 25 │ Free En. Model: -8.5562 │ Free En. Data: -8.6984 │ Learning Rate: 0.00143
# Epoch 1997/2000 │ Loss: -0.0353 │ Modes: 23 │ Free En. Model: -8.5447 │ Free En. Data: -8.6984 │ Learning Rate: 0.00143
# Epoch 1998/2000 │ Loss: -0.0339 │ Modes: 24 │ Free En. Model: -8.5557 │ Free En. Data: -8.7001 │ Learning Rate: 0.00143
# Epoch 1999/2000 │ Loss: -0.0418 │ Modes: 21 │ Free En. Model: -8.5843 │ Free En. Data: -8.6981 │ Learning Rate: 0.00143
# Epoch 2000/2000 │ Loss: -0.0371 │ Modes: 21 │ Free En. Model: -8.5620 │ Free En. Data: -8.6949 │ Learning Rate: 0.00143

# %%
epochs = list(metrics.keys())

loss_vals = [metrics[e]['loss'] for e in epochs]
mode_vals = [metrics[e]['modes'] for e in epochs]
free_energy_model_vals = [metrics[e]['free_energy_model'] for e in epochs]
free_energy_data_vals = [metrics[e]['free_energy_data'] for e in epochs]
lr_vals = [metrics[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots(figsize=(11, 4))

ax1.set_xlabel("Epoch")

ax1.plot(epochs, lr_vals, color="tab:red")
ax1.set_ylabel("Learning Rate", color="tab:red")
ax1.tick_params(axis="y", labelcolor="tab:red")

ax2 = ax1.twinx()
ax2.plot(epochs, loss_vals, color="tab:blue")
ax2.set_ylabel("CD Loss", color="tab:blue")
ax2.tick_params(axis="y", labelcolor="tab:blue")
ax2.spines["right"].set_position(("axes", 1.0))

ax3 = ax1.twinx()
ax3.plot(epochs, free_energy_model_vals, color="tab:orange")
ax3.set_ylabel("Free Energy Model", color="tab:orange")
ax3.tick_params(axis="y", labelcolor="tab:orange")
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax1.twinx()
ax4.plot(epochs, mode_vals, color="tab:green")
ax4.set_ylabel("Mode Count", color="tab:green")
ax4.tick_params(axis="y", labelcolor="tab:green")
ax4.spines["right"].set_position(("axes", 1.2))

plt.title("Training curve for vanilla RBM")
plt.show()

# %%
# shifting the center step to 0 we can approximate an exponential schedule if we choose the high to be double of T_high
T_high = 2.0
T_low = 0.01
sampling_steps = 5_000
sigmoid_schedule_fn = get_sigmoid_curve(high=T_high*2, low=T_low, steps=sampling_steps, falloff=0.0013, center_step=0)
sigmoid_schedule = jnp.array([sigmoid_schedule_fn(i) for i in range(sampling_steps)], dtype=jnp.float32)

key_sample = PRNGKey(1234)

samples = model.apply(
    {"params": state.params},
    num_samples=10_000,
    T_schedule=sigmoid_schedule,
    key=key_sample,
    method=RBM.generate
)

sampled_freq = samples.mean(0)
sampled_freq
# Out:
# Array([0.126     , 0.1293    , 0.1214    , 0.1151    , 0.1399    ,
#        0.1331    , 0.1089    , 0.12629999], dtype=float32)

# %%
spin_counts = samples.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(12), align='left', edgecolor='black')
plt.xticks(range(11))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
plt.figure(figsize=(10, 5))
x = jnp.arange(num_visible) + 1

width = 0.35

plt.bar(x - width/2, empirical_freq, width, label="Empirical", alpha=0.7)
plt.bar(x + width/2, sampled_freq, width, label="Sampled", alpha=0.7)

plt.axhline(1 / num_visible, linestyle='--', color='gray', label=f'1/{num_visible} reference')
plt.xlabel("Visible Unit Index")
plt.ylabel("Mean Activation Frequency")
plt.ylim(0, 0.15)
plt.title("Comparison: Empirical vs Sampled Frequencies")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# during phase training we will at most encounter k-hot vectors with k <= 3

def make_k_hot(n, k):
    return jnp.array([jnp.array([1 if i in idxs else 0 for i in range(n)]) for idxs in combinations(range(n), k)], dtype=jnp.float32)

k_hot_vectors = jnp.concatenate([make_k_hot(num_visible, k) for k in range(4)], axis=0)

fe_k_hot = model.apply({'params': state.params}, method=model._free_energy, v=k_hot_vectors)
fe_k_hot = jnp.squeeze(fe_k_hot)
min_fe_k_hot = jnp.min(fe_k_hot)
max_fe_k_hot = jnp.max(fe_k_hot)

print(f"min energy: {min_fe_k_hot:6f}, max energy: {max_fe_k_hot:6f}")
# Out:
# min energy: -8.759494, max energy: 3.960068

# %%
plt.show()
timestamp = datetime.now().strftime("%Y%m%d%H%M")
model_name = f"rbm_amp_{timestamp}"

checkpoints.save_checkpoint(
    ckpt_dir=str(model_dir.resolve()),
    target=state.params,
    step=0,
    prefix=model_name + "_",
    overwrite=True
)
# Out:
# '/Users/Tonni/Desktop/master-code/neural-quantum-tomo/case_studies/w_aug_v3/models/rbm_amp_202506150002_0'
