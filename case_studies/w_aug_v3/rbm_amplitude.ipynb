# %%
import re
from pathlib import Path
from typing import Optional, Tuple, Dict, Any, Sequence
from datetime import datetime

import numpy as np

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import optax
from flax.training.train_state import TrainState
from flax.training import checkpoints
from flax import linen as nn

import matplotlib.pyplot as plt


data_dir = "./data"
model_dir = Path("./models")
model_dir.mkdir(parents=True, exist_ok=True)

print(f"Data resides in        : {data_dir}")
print(f"Model will be saved to : {model_dir}")
# Out:
# Data resides in        : ./data
# Model will be saved to : models

# %%
class MultiBasisDataLoader:
    def __init__(self, data_dict: dict[str, jnp.ndarray],
                 batch_size: int = 128,
                 shuffle: bool = True,
                 drop_last: bool = False,
                 seed: int = 0):
        lengths = [len(v) for v in data_dict.values()]
        if len(set(lengths)) != 1:
            raise ValueError(f"All arrays must have the same length, got: {lengths}")

        self.data = data_dict
        self.n = lengths[0]
        self.bs = batch_size
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.rng = np.random.default_rng(seed)

        self.idx_slices = [
            (i, i + batch_size)
            for i in range(0, self.n, batch_size)
            if not drop_last or i + batch_size <= self.n
        ]

    def __iter__(self):
        self.order = np.arange(self.n)
        if self.shuffle:
            self.rng.shuffle(self.order)
        self.slice_idx = 0
        return self

    def __next__(self):
        if self.slice_idx >= len(self.idx_slices):
            raise StopIteration
        s, e = self.idx_slices[self.slice_idx]
        self.slice_idx += 1
        return {k: v[self.order[s:e]] for k, v in self.data.items()}

    def __len__(self):
        return len(self.idx_slices)


def load_measurements(folder: str, file_pattern: str = "w_*.txt") -> dict[str, jnp.ndarray]:
    out: dict[str, jnp.ndarray] = {}

    for fp in Path(folder).glob(file_pattern):
        basis = fp.stem.split("_")[2]

        bitstrings = []
        with fp.open() as f:
            for line in f:
                bitstring = np.fromiter((c.islower() for c in line.strip()), dtype=np.float32)
                bitstrings.append(bitstring)

        arr = jnp.asarray(np.stack(bitstrings))
        if basis in out:
            out[basis] = jnp.concatenate([out[basis], arr], axis=0)
        else:
            out[basis] = arr

    return out

# %%
data_dict = load_measurements(data_dir, "w_*.txt")

keys_amp = [k for k in data_dict if re.fullmatch(r"^Z+$", k)]
dict_amp = {k: data_dict[k] for k in keys_amp}

# %%
empirical_freq_amp = jnp.zeros(next(iter(dict_amp.values())).shape[1])
num_total = 0

for arr in dict_amp.values():
    empirical_freq_amp += jnp.sum(arr, axis=0)
    num_total += arr.shape[0]

empirical_freq_amp = empirical_freq_amp / num_total
empirical_freq_amp
# Out:
# Array([0.10140625, 0.09359375, 0.10640625, 0.10125   , 0.0996875 ,
#        0.105     , 0.09578125, 0.09671875, 0.09984375, 0.1003125 ],      dtype=float32)

# %%
class RBM(nn.Module):
    n_visible: int
    n_hidden: int
    k: int = 1          # bound to class instance to make whole gibbs chain compilable
    T: float = 1.0      # bound to class instance to make single gibbs step compilable

    def setup(self):
        self.W = self.param("W", nn.initializers.normal(0.01), (self.n_visible, self.n_hidden))
        self.b = self.param("b", nn.initializers.zeros, (self.n_visible,))
        self.c = self.param("c", nn.initializers.zeros, (self.n_hidden,))

    def __call__(self, data: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W, self.b, self.c, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (aux_vars["gibbs_chain"], aux_vars["key"]))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain) # cut off gradients after Gibbs sampling

        loss = jnp.mean(self._free_energy(data)) - jnp.mean(self._free_energy(gibbs_chain))
        return loss, {"gibbs_chain": gibbs_chain, "key": key}

    def _free_energy(self, v):
        return -(v @ self.b) - jnp.sum(jax.nn.softplus(v @ self.W + self.c), -1)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c)/T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b)/T)).astype(jnp.float32)
        return v, key

    @nn.nowrap
    def generate(self, n_samples: int, T_schedule: jnp.ndarray, key: PRNGKey) -> jnp.ndarray:
        key, key_init = jax.random.split(key, 2)
        v = jax.random.bernoulli(key_init, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)

        anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, (v, key))
        return v_final

# %%
@jax.jit
def train_step_amp(
        state: TrainState,
        batch_dict: Dict[str, jnp.ndarray],
        gibbs_chain: jnp.ndarray,
        key: PRNGKey,
        chain_reset_frac: float) -> Tuple[TrainState, jnp.ndarray, jnp.ndarray, PRNGKey]:

    if len(batch_dict) != 1:
        raise ValueError("Batch dictionary must contain exactly one entry.")

    (basis_key, batch), = batch_dict.items()
    if set(basis_key) != {'Z'}:
        raise ValueError(f"Batch key must consist only of 'Z', got: {basis_key}")

    key, key_reset = jax.random.split(key)

    reset_mask = jax.random.bernoulli(key_reset, p=chain_reset_frac, shape=(gibbs_chain.shape[0], 1))
    reset_chain = jnp.where(reset_mask, batch, gibbs_chain)

    aux_vars = {"gibbs_chain": reset_chain, "key": key}
    loss_fn = lambda params: state.apply_fn({'params': params}, batch, aux_vars)
    (loss, aux_vars), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    state = state.apply_gradients(grads=grads)

    return state, loss, aux_vars["gibbs_chain"], aux_vars["key"]


def entropy_modes(chain: jnp.ndarray) -> Tuple[float, int]:
    # translate each binary pattern to a unique integer
    chain = chain.astype(jnp.uint32)
    powers = 2 ** jnp.arange(chain.shape[-1], dtype=jnp.uint32)
    ints = jnp.dot(chain, powers)

    hist = jnp.bincount(ints, length=1 << chain.shape[-1]).astype(jnp.float32)
    probs = hist / jnp.sum(hist)
    entropy = -jnp.sum(jnp.where(probs > 0, probs * jnp.log(probs), 0.0)) # shannon entropy with guard against prob <=0
    mode_count = jnp.sum(hist > 0)
    return float(entropy), int(mode_count)


def train_amp_rbm(
        state: TrainState,
        loader: MultiBasisDataLoader,
        gibbs_chain: jnp.ndarray,
        num_epochs: int,
        key: PRNGKey,
        chain_reset_frac_min: float = 0.02,
        chain_reset_frac_max: float = 0.30,
        chain_reset_ema_alpha: float = 0.9) -> Tuple[TrainState, Dict[int, float]]:

    print("Precalculating target entropy from data.")
    all_data = []
    for batch_dict in loader:
        (_, batch), = batch_dict.items()
        all_data.append(batch)
    all_data = jnp.concatenate(all_data, axis=0)

    entropy_target, _ = entropy_modes(all_data)

    chain_reset_frac_ema = 0.0
    metrics = {}
    for epoch in range(num_epochs):
        tot_loss = tot_entropy_chain = tot_modes_chain = 0.0
        batches = 0

        for batch_dict in loader:

            entropy_chain, modes_chain = entropy_modes(gibbs_chain)
            chain_reset_frac_raw = jnp.abs(jnp.log(entropy_chain/entropy_target + 1e-12))  # tiny eps for stability
            chain_reset_frac_ema = chain_reset_frac_ema * chain_reset_ema_alpha + (1 - chain_reset_ema_alpha) * chain_reset_frac_raw
            chain_reset_frac = float(jnp.clip(chain_reset_frac_ema, chain_reset_frac_min, chain_reset_frac_max))

            state, loss, gibbs_chain, key = train_step_amp(state, batch_dict, gibbs_chain, key, chain_reset_frac)

            tot_loss += float(loss)
            tot_entropy_chain += float(entropy_chain)
            tot_modes_chain += float(modes_chain)
            batches += 1

        avg_loss = tot_loss / batches
        avg_entropy_chain = tot_entropy_chain / batches
        avg_modes_chain = tot_modes_chain / batches
        lr = float(lr_schedule(state.opt_state[0].count))

        metrics[epoch] = dict(
            loss=avg_loss,
            entropy_chain=avg_entropy_chain,
            modes_chain=avg_modes_chain,
            lr=lr
        )

        print(f"Epoch {epoch+1}/{num_epochs} │ "
              f"Loss: {avg_loss:+.4f} │ "
              f"Chain Entr.: {avg_entropy_chain:.3f} │ "
              f"Chain Modes: {avg_modes_chain:.0f} │ "
              f"Chain Reset Frac.: {chain_reset_frac:.3f} │ "
              f"Learning Rate: {lr:.5f}")

    return state, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2

    curve_fn = lambda step: low + (high - low) / (1 + jnp.exp(falloff * (jnp.minimum(step, steps) - center_step)))
    return curve_fn

# %%
batch_size      = 64        #                                               DONE
visible_units   = 10        #                                               DONE
hidden_units    = 16        # totally sufficient to capture all modes       DONE
k_steps         = 400       # higher is generally better                    GOOD FOR NOW
init_lr         = 1e-2      #                                               DONE
final_lr        = init_lr * 0.2 #                                           DONE
num_epochs      = 500
chains          = batch_size # makes chain replacement logic easier         DONE


key_seed = PRNGKey(42)
key, key_params, key_chains, key_dummy = jax.random.split(key_seed, 4)

model_amp = RBM(visible_units, hidden_units, k=k_steps)
batch_dummy = jnp.zeros((batch_size, visible_units), dtype=jnp.float32)
aux_vars_dummy = {"gibbs_chain": jnp.zeros((batch_size, visible_units), dtype=jnp.float32), "key": key_dummy}
variables_amp = model_amp.init({"params": key_params}, batch_dummy, aux_vars_dummy)

loader_amp = MultiBasisDataLoader(dict_amp, batch_size=batch_size)

schedule_steps = num_epochs * len(loader_amp)
lr_schedule = get_sigmoid_curve(high=init_lr, low=final_lr, steps=schedule_steps, falloff=0.001, center_step=schedule_steps * 0.5)
optimizer_amp = optax.adam(learning_rate=lr_schedule)

state_amp = TrainState.create(apply_fn=model_amp.apply, params=variables_amp["params"], tx=optimizer_amp)

# should come from data too but works for now
gibbs_chain = jax.random.bernoulli(key_chains, p=0.5, shape=(chains, visible_units)).astype(jnp.float32)

# %time state_amp, metrics_amp = train_amp_rbm(state_amp, loader_amp, gibbs_chain, num_epochs, key=key, chain_reset_frac_min=0.02, chain_reset_frac_max=0.30, chain_reset_ema_alpha=0.9)
# Out:
# Precalculating target entropy from data.
# Epoch 1/500 │ Loss: -0.3414 │ Chain Entr.: 2.938 │ Chain Modes: 34 │ Chain Reset Frac.: 0.133 │ Learning Rate: 0.01000
# Epoch 2/500 │ Loss: -0.0826 │ Chain Entr.: 2.664 │ Chain Modes: 27 │ Chain Reset Frac.: 0.148 │ Learning Rate: 0.01000
# Epoch 3/500 │ Loss: -0.0267 │ Chain Entr.: 2.639 │ Chain Modes: 27 │ Chain Reset Frac.: 0.135 │ Learning Rate: 0.01000
# Epoch 4/500 │ Loss: -0.0422 │ Chain Entr.: 2.646 │ Chain Modes: 26 │ Chain Reset Frac.: 0.149 │ Learning Rate: 0.01000
# Epoch 5/500 │ Loss: -0.0047 │ Chain Entr.: 2.640 │ Chain Modes: 26 │ Chain Reset Frac.: 0.137 │ Learning Rate: 0.01000
# Epoch 6/500 │ Loss: -0.0203 │ Chain Entr.: 2.618 │ Chain Modes: 26 │ Chain Reset Frac.: 0.136 │ Learning Rate: 0.01000
# Epoch 7/500 │ Loss: -0.0089 │ Chain Entr.: 2.619 │ Chain Modes: 26 │ Chain Reset Frac.: 0.138 │ Learning Rate: 0.01000
# Epoch 8/500 │ Loss: +0.0046 │ Chain Entr.: 2.612 │ Chain Modes: 26 │ Chain Reset Frac.: 0.129 │ Learning Rate: 0.01000
# Epoch 9/500 │ Loss: +0.0151 │ Chain Entr.: 2.609 │ Chain Modes: 26 │ Chain Reset Frac.: 0.117 │ Learning Rate: 0.01000
# Epoch 10/500 │ Loss: +0.0036 │ Chain Entr.: 2.620 │ Chain Modes: 26 │ Chain Reset Frac.: 0.147 │ Learning Rate: 0.01000
# Epoch 11/500 │ Loss: +0.0088 │ Chain Entr.: 2.614 │ Chain Modes: 26 │ Chain Reset Frac.: 0.154 │ Learning Rate: 0.01000
# Epoch 12/500 │ Loss: +0.0089 │ Chain Entr.: 2.600 │ Chain Modes: 26 │ Chain Reset Frac.: 0.144 │ Learning Rate: 0.01000
# Epoch 13/500 │ Loss: +0.0343 │ Chain Entr.: 2.609 │ Chain Modes: 26 │ Chain Reset Frac.: 0.120 │ Learning Rate: 0.01000
# Epoch 14/500 │ Loss: -0.0049 │ Chain Entr.: 2.619 │ Chain Modes: 26 │ Chain Reset Frac.: 0.160 │ Learning Rate: 0.01000
# Epoch 15/500 │ Loss: +0.0229 │ Chain Entr.: 2.590 │ Chain Modes: 25 │ Chain Reset Frac.: 0.139 │ Learning Rate: 0.01000
# Epoch 16/500 │ Loss: +0.0129 │ Chain Entr.: 2.600 │ Chain Modes: 25 │ Chain Reset Frac.: 0.142 │ Learning Rate: 0.01000
# Epoch 17/500 │ Loss: +0.0375 │ Chain Entr.: 2.595 │ Chain Modes: 25 │ Chain Reset Frac.: 0.119 │ Learning Rate: 0.01000
# Epoch 18/500 │ Loss: +0.0072 │ Chain Entr.: 2.604 │ Chain Modes: 26 │ Chain Reset Frac.: 0.148 │ Learning Rate: 0.01000
# Epoch 19/500 │ Loss: +0.0493 │ Chain Entr.: 2.594 │ Chain Modes: 26 │ Chain Reset Frac.: 0.102 │ Learning Rate: 0.01000
# Epoch 20/500 │ Loss: +0.0261 │ Chain Entr.: 2.600 │ Chain Modes: 25 │ Chain Reset Frac.: 0.108 │ Learning Rate: 0.01000
# Epoch 21/500 │ Loss: +0.0090 │ Chain Entr.: 2.603 │ Chain Modes: 26 │ Chain Reset Frac.: 0.129 │ Learning Rate: 0.01000
# Epoch 22/500 │ Loss: +0.0263 │ Chain Entr.: 2.594 │ Chain Modes: 25 │ Chain Reset Frac.: 0.114 │ Learning Rate: 0.01000
# Epoch 23/500 │ Loss: +0.0085 │ Chain Entr.: 2.599 │ Chain Modes: 26 │ Chain Reset Frac.: 0.147 │ Learning Rate: 0.01000
# Epoch 24/500 │ Loss: +0.0480 │ Chain Entr.: 2.592 │ Chain Modes: 25 │ Chain Reset Frac.: 0.113 │ Learning Rate: 0.01000
# Epoch 25/500 │ Loss: +0.0216 │ Chain Entr.: 2.612 │ Chain Modes: 25 │ Chain Reset Frac.: 0.133 │ Learning Rate: 0.01000
# Epoch 26/500 │ Loss: +0.0257 │ Chain Entr.: 2.589 │ Chain Modes: 25 │ Chain Reset Frac.: 0.128 │ Learning Rate: 0.01000
# Epoch 27/500 │ Loss: +0.0290 │ Chain Entr.: 2.591 │ Chain Modes: 25 │ Chain Reset Frac.: 0.103 │ Learning Rate: 0.01000
# Epoch 28/500 │ Loss: +0.0333 │ Chain Entr.: 2.599 │ Chain Modes: 25 │ Chain Reset Frac.: 0.125 │ Learning Rate: 0.01000
# Epoch 29/500 │ Loss: +0.0212 │ Chain Entr.: 2.616 │ Chain Modes: 26 │ Chain Reset Frac.: 0.137 │ Learning Rate: 0.01000
# Epoch 30/500 │ Loss: +0.0183 │ Chain Entr.: 2.598 │ Chain Modes: 25 │ Chain Reset Frac.: 0.146 │ Learning Rate: 0.01000
# Epoch 31/500 │ Loss: +0.0375 │ Chain Entr.: 2.594 │ Chain Modes: 26 │ Chain Reset Frac.: 0.105 │ Learning Rate: 0.01000
# Epoch 32/500 │ Loss: +0.0096 │ Chain Entr.: 2.610 │ Chain Modes: 26 │ Chain Reset Frac.: 0.136 │ Learning Rate: 0.01000
# Epoch 33/500 │ Loss: +0.0307 │ Chain Entr.: 2.597 │ Chain Modes: 26 │ Chain Reset Frac.: 0.130 │ Learning Rate: 0.01000
# Epoch 34/500 │ Loss: +0.0310 │ Chain Entr.: 2.586 │ Chain Modes: 25 │ Chain Reset Frac.: 0.122 │ Learning Rate: 0.01000
# Epoch 35/500 │ Loss: +0.0280 │ Chain Entr.: 2.589 │ Chain Modes: 26 │ Chain Reset Frac.: 0.118 │ Learning Rate: 0.01000
# Epoch 36/500 │ Loss: +0.0389 │ Chain Entr.: 2.575 │ Chain Modes: 25 │ Chain Reset Frac.: 0.080 │ Learning Rate: 0.01000
# Epoch 37/500 │ Loss: +0.0223 │ Chain Entr.: 2.596 │ Chain Modes: 25 │ Chain Reset Frac.: 0.119 │ Learning Rate: 0.01000
# Epoch 38/500 │ Loss: +0.0086 │ Chain Entr.: 2.603 │ Chain Modes: 26 │ Chain Reset Frac.: 0.120 │ Learning Rate: 0.01000
# Epoch 39/500 │ Loss: +0.0343 │ Chain Entr.: 2.592 │ Chain Modes: 25 │ Chain Reset Frac.: 0.131 │ Learning Rate: 0.01000
# Epoch 40/500 │ Loss: +0.0191 │ Chain Entr.: 2.611 │ Chain Modes: 26 │ Chain Reset Frac.: 0.148 │ Learning Rate: 0.01000
# Epoch 41/500 │ Loss: +0.0446 │ Chain Entr.: 2.599 │ Chain Modes: 26 │ Chain Reset Frac.: 0.097 │ Learning Rate: 0.01000
# Epoch 42/500 │ Loss: +0.0353 │ Chain Entr.: 2.606 │ Chain Modes: 25 │ Chain Reset Frac.: 0.092 │ Learning Rate: 0.01000
# Epoch 43/500 │ Loss: +0.0053 │ Chain Entr.: 2.595 │ Chain Modes: 26 │ Chain Reset Frac.: 0.113 │ Learning Rate: 0.01000
# Epoch 44/500 │ Loss: +0.0173 │ Chain Entr.: 2.603 │ Chain Modes: 25 │ Chain Reset Frac.: 0.122 │ Learning Rate: 0.01000
# Epoch 45/500 │ Loss: +0.0372 │ Chain Entr.: 2.600 │ Chain Modes: 25 │ Chain Reset Frac.: 0.117 │ Learning Rate: 0.01000
# Epoch 46/500 │ Loss: +0.0225 │ Chain Entr.: 2.606 │ Chain Modes: 25 │ Chain Reset Frac.: 0.093 │ Learning Rate: 0.01000
# Epoch 47/500 │ Loss: +0.0057 │ Chain Entr.: 2.614 │ Chain Modes: 26 │ Chain Reset Frac.: 0.149 │ Learning Rate: 0.01000
# Epoch 48/500 │ Loss: +0.0349 │ Chain Entr.: 2.602 │ Chain Modes: 25 │ Chain Reset Frac.: 0.129 │ Learning Rate: 0.01000
# Epoch 49/500 │ Loss: +0.0220 │ Chain Entr.: 2.594 │ Chain Modes: 26 │ Chain Reset Frac.: 0.131 │ Learning Rate: 0.01000
# Epoch 50/500 │ Loss: +0.0091 │ Chain Entr.: 2.609 │ Chain Modes: 25 │ Chain Reset Frac.: 0.131 │ Learning Rate: 0.01000
# Epoch 51/500 │ Loss: +0.0216 │ Chain Entr.: 2.614 │ Chain Modes: 26 │ Chain Reset Frac.: 0.113 │ Learning Rate: 0.01000
# Epoch 52/500 │ Loss: +0.0174 │ Chain Entr.: 2.595 │ Chain Modes: 25 │ Chain Reset Frac.: 0.114 │ Learning Rate: 0.01000
# Epoch 53/500 │ Loss: +0.0175 │ Chain Entr.: 2.587 │ Chain Modes: 25 │ Chain Reset Frac.: 0.131 │ Learning Rate: 0.01000
# Epoch 54/500 │ Loss: +0.0149 │ Chain Entr.: 2.599 │ Chain Modes: 26 │ Chain Reset Frac.: 0.166 │ Learning Rate: 0.01000
# Epoch 55/500 │ Loss: +0.0376 │ Chain Entr.: 2.594 │ Chain Modes: 25 │ Chain Reset Frac.: 0.116 │ Learning Rate: 0.01000
# Epoch 56/500 │ Loss: +0.0070 │ Chain Entr.: 2.597 │ Chain Modes: 25 │ Chain Reset Frac.: 0.122 │ Learning Rate: 0.01000
# Epoch 57/500 │ Loss: +0.0269 │ Chain Entr.: 2.582 │ Chain Modes: 25 │ Chain Reset Frac.: 0.109 │ Learning Rate: 0.01000
# Epoch 58/500 │ Loss: -0.0041 │ Chain Entr.: 2.595 │ Chain Modes: 26 │ Chain Reset Frac.: 0.130 │ Learning Rate: 0.01000
# Epoch 59/500 │ Loss: +0.0282 │ Chain Entr.: 2.589 │ Chain Modes: 25 │ Chain Reset Frac.: 0.111 │ Learning Rate: 0.01000
# Epoch 60/500 │ Loss: -0.0009 │ Chain Entr.: 2.617 │ Chain Modes: 25 │ Chain Reset Frac.: 0.139 │ Learning Rate: 0.01000
# Epoch 61/500 │ Loss: +0.0197 │ Chain Entr.: 2.609 │ Chain Modes: 25 │ Chain Reset Frac.: 0.136 │ Learning Rate: 0.01000
# Epoch 62/500 │ Loss: +0.0239 │ Chain Entr.: 2.586 │ Chain Modes: 25 │ Chain Reset Frac.: 0.122 │ Learning Rate: 0.01000
# Epoch 63/500 │ Loss: +0.0040 │ Chain Entr.: 2.599 │ Chain Modes: 26 │ Chain Reset Frac.: 0.150 │ Learning Rate: 0.01000
# Epoch 64/500 │ Loss: +0.0294 │ Chain Entr.: 2.591 │ Chain Modes: 25 │ Chain Reset Frac.: 0.148 │ Learning Rate: 0.01000
# Epoch 65/500 │ Loss: +0.0106 │ Chain Entr.: 2.591 │ Chain Modes: 25 │ Chain Reset Frac.: 0.123 │ Learning Rate: 0.01000
# Epoch 66/500 │ Loss: +0.0201 │ Chain Entr.: 2.582 │ Chain Modes: 25 │ Chain Reset Frac.: 0.116 │ Learning Rate: 0.01000
# Epoch 67/500 │ Loss: +0.0213 │ Chain Entr.: 2.590 │ Chain Modes: 25 │ Chain Reset Frac.: 0.124 │ Learning Rate: 0.01000
# Epoch 68/500 │ Loss: +0.0142 │ Chain Entr.: 2.603 │ Chain Modes: 25 │ Chain Reset Frac.: 0.117 │ Learning Rate: 0.01000
# Epoch 69/500 │ Loss: +0.0223 │ Chain Entr.: 2.587 │ Chain Modes: 25 │ Chain Reset Frac.: 0.128 │ Learning Rate: 0.01000
# Epoch 70/500 │ Loss: +0.0049 │ Chain Entr.: 2.603 │ Chain Modes: 26 │ Chain Reset Frac.: 0.136 │ Learning Rate: 0.01000
# Epoch 71/500 │ Loss: +0.0281 │ Chain Entr.: 2.579 │ Chain Modes: 25 │ Chain Reset Frac.: 0.134 │ Learning Rate: 0.01000
# Epoch 72/500 │ Loss: +0.0429 │ Chain Entr.: 2.580 │ Chain Modes: 25 │ Chain Reset Frac.: 0.101 │ Learning Rate: 0.01000
# Epoch 73/500 │ Loss: -0.0110 │ Chain Entr.: 2.604 │ Chain Modes: 26 │ Chain Reset Frac.: 0.133 │ Learning Rate: 0.01000
# Epoch 74/500 │ Loss: +0.0199 │ Chain Entr.: 2.597 │ Chain Modes: 25 │ Chain Reset Frac.: 0.107 │ Learning Rate: 0.01000
# Epoch 75/500 │ Loss: +0.0081 │ Chain Entr.: 2.608 │ Chain Modes: 25 │ Chain Reset Frac.: 0.136 │ Learning Rate: 0.01000
# Epoch 76/500 │ Loss: +0.0202 │ Chain Entr.: 2.588 │ Chain Modes: 25 │ Chain Reset Frac.: 0.128 │ Learning Rate: 0.01000
# Epoch 77/500 │ Loss: +0.0291 │ Chain Entr.: 2.592 │ Chain Modes: 25 │ Chain Reset Frac.: 0.122 │ Learning Rate: 0.01000
# Epoch 78/500 │ Loss: +0.0317 │ Chain Entr.: 2.585 │ Chain Modes: 25 │ Chain Reset Frac.: 0.132 │ Learning Rate: 0.01000
# Epoch 79/500 │ Loss: -0.0057 │ Chain Entr.: 2.602 │ Chain Modes: 25 │ Chain Reset Frac.: 0.116 │ Learning Rate: 0.01000
# Epoch 80/500 │ Loss: +0.0132 │ Chain Entr.: 2.604 │ Chain Modes: 26 │ Chain Reset Frac.: 0.139 │ Learning Rate: 0.01000
# Epoch 81/500 │ Loss: +0.0158 │ Chain Entr.: 2.596 │ Chain Modes: 25 │ Chain Reset Frac.: 0.122 │ Learning Rate: 0.01000
# Epoch 82/500 │ Loss: +0.0242 │ Chain Entr.: 2.598 │ Chain Modes: 25 │ Chain Reset Frac.: 0.104 │ Learning Rate: 0.01000
# Epoch 83/500 │ Loss: +0.0112 │ Chain Entr.: 2.618 │ Chain Modes: 26 │ Chain Reset Frac.: 0.113 │ Learning Rate: 0.01000
# Epoch 84/500 │ Loss: +0.0170 │ Chain Entr.: 2.592 │ Chain Modes: 26 │ Chain Reset Frac.: 0.116 │ Learning Rate: 0.01000
# Epoch 85/500 │ Loss: +0.0046 │ Chain Entr.: 2.589 │ Chain Modes: 25 │ Chain Reset Frac.: 0.114 │ Learning Rate: 0.01000
# Epoch 86/500 │ Loss: +0.0250 │ Chain Entr.: 2.579 │ Chain Modes: 25 │ Chain Reset Frac.: 0.120 │ Learning Rate: 0.01000
# Epoch 87/500 │ Loss: +0.0307 │ Chain Entr.: 2.572 │ Chain Modes: 25 │ Chain Reset Frac.: 0.109 │ Learning Rate: 0.01000
# Epoch 88/500 │ Loss: +0.0042 │ Chain Entr.: 2.596 │ Chain Modes: 26 │ Chain Reset Frac.: 0.136 │ Learning Rate: 0.01000
# Epoch 89/500 │ Loss: +0.0262 │ Chain Entr.: 2.594 │ Chain Modes: 25 │ Chain Reset Frac.: 0.116 │ Learning Rate: 0.01000
# Epoch 90/500 │ Loss: +0.0158 │ Chain Entr.: 2.610 │ Chain Modes: 25 │ Chain Reset Frac.: 0.118 │ Learning Rate: 0.01000
# Epoch 91/500 │ Loss: +0.0129 │ Chain Entr.: 2.596 │ Chain Modes: 26 │ Chain Reset Frac.: 0.132 │ Learning Rate: 0.01000
# Epoch 92/500 │ Loss: +0.0149 │ Chain Entr.: 2.598 │ Chain Modes: 25 │ Chain Reset Frac.: 0.139 │ Learning Rate: 0.01000
# Epoch 93/500 │ Loss: +0.0222 │ Chain Entr.: 2.602 │ Chain Modes: 25 │ Chain Reset Frac.: 0.134 │ Learning Rate: 0.01000
# Epoch 94/500 │ Loss: +0.0128 │ Chain Entr.: 2.598 │ Chain Modes: 25 │ Chain Reset Frac.: 0.145 │ Learning Rate: 0.01000
# Epoch 95/500 │ Loss: +0.0129 │ Chain Entr.: 2.586 │ Chain Modes: 25 │ Chain Reset Frac.: 0.128 │ Learning Rate: 0.01000
# Epoch 96/500 │ Loss: +0.0227 │ Chain Entr.: 2.584 │ Chain Modes: 25 │ Chain Reset Frac.: 0.092 │ Learning Rate: 0.01000
# Epoch 97/500 │ Loss: +0.0025 │ Chain Entr.: 2.599 │ Chain Modes: 25 │ Chain Reset Frac.: 0.125 │ Learning Rate: 0.01000
# Epoch 98/500 │ Loss: +0.0025 │ Chain Entr.: 2.604 │ Chain Modes: 26 │ Chain Reset Frac.: 0.139 │ Learning Rate: 0.01000
# Epoch 99/500 │ Loss: +0.0248 │ Chain Entr.: 2.594 │ Chain Modes: 25 │ Chain Reset Frac.: 0.124 │ Learning Rate: 0.01000
# Epoch 100/500 │ Loss: -0.0171 │ Chain Entr.: 2.620 │ Chain Modes: 25 │ Chain Reset Frac.: 0.143 │ Learning Rate: 0.01000
# Epoch 101/500 │ Loss: +0.0005 │ Chain Entr.: 2.611 │ Chain Modes: 25 │ Chain Reset Frac.: 0.136 │ Learning Rate: 0.01000
# Epoch 102/500 │ Loss: -0.0087 │ Chain Entr.: 2.594 │ Chain Modes: 25 │ Chain Reset Frac.: 0.118 │ Learning Rate: 0.01000
# Epoch 103/500 │ Loss: -0.0015 │ Chain Entr.: 2.618 │ Chain Modes: 25 │ Chain Reset Frac.: 0.144 │ Learning Rate: 0.01000
# Epoch 104/500 │ Loss: -0.0234 │ Chain Entr.: 2.605 │ Chain Modes: 24 │ Chain Reset Frac.: 0.115 │ Learning Rate: 0.01000
# Epoch 105/500 │ Loss: -0.0515 │ Chain Entr.: 2.608 │ Chain Modes: 25 │ Chain Reset Frac.: 0.138 │ Learning Rate: 0.01000
# Epoch 106/500 │ Loss: -0.0446 │ Chain Entr.: 2.618 │ Chain Modes: 24 │ Chain Reset Frac.: 0.108 │ Learning Rate: 0.01000
# Epoch 107/500 │ Loss: -0.0562 │ Chain Entr.: 2.621 │ Chain Modes: 24 │ Chain Reset Frac.: 0.101 │ Learning Rate: 0.01000
# Epoch 108/500 │ Loss: -0.0925 │ Chain Entr.: 2.635 │ Chain Modes: 23 │ Chain Reset Frac.: 0.141 │ Learning Rate: 0.01000
# Epoch 109/500 │ Loss: -0.0815 │ Chain Entr.: 2.630 │ Chain Modes: 23 │ Chain Reset Frac.: 0.120 │ Learning Rate: 0.01000
# Epoch 110/500 │ Loss: -0.1040 │ Chain Entr.: 2.611 │ Chain Modes: 22 │ Chain Reset Frac.: 0.121 │ Learning Rate: 0.01000
# Epoch 111/500 │ Loss: -0.1191 │ Chain Entr.: 2.623 │ Chain Modes: 22 │ Chain Reset Frac.: 0.112 │ Learning Rate: 0.01000
# Epoch 112/500 │ Loss: -0.1316 │ Chain Entr.: 2.610 │ Chain Modes: 21 │ Chain Reset Frac.: 0.117 │ Learning Rate: 0.01000
# Epoch 113/500 │ Loss: -0.1320 │ Chain Entr.: 2.608 │ Chain Modes: 21 │ Chain Reset Frac.: 0.136 │ Learning Rate: 0.01000
# Epoch 114/500 │ Loss: -0.1152 │ Chain Entr.: 2.583 │ Chain Modes: 20 │ Chain Reset Frac.: 0.097 │ Learning Rate: 0.01000
# Epoch 115/500 │ Loss: -0.1276 │ Chain Entr.: 2.592 │ Chain Modes: 20 │ Chain Reset Frac.: 0.134 │ Learning Rate: 0.01000
# Epoch 116/500 │ Loss: -0.1230 │ Chain Entr.: 2.584 │ Chain Modes: 20 │ Chain Reset Frac.: 0.122 │ Learning Rate: 0.01000
# Epoch 117/500 │ Loss: -0.1557 │ Chain Entr.: 2.578 │ Chain Modes: 19 │ Chain Reset Frac.: 0.109 │ Learning Rate: 0.01000
# Epoch 118/500 │ Loss: -0.1913 │ Chain Entr.: 2.580 │ Chain Modes: 19 │ Chain Reset Frac.: 0.101 │ Learning Rate: 0.01000
# Epoch 119/500 │ Loss: -0.1828 │ Chain Entr.: 2.555 │ Chain Modes: 18 │ Chain Reset Frac.: 0.100 │ Learning Rate: 0.01000
# Epoch 120/500 │ Loss: -0.1914 │ Chain Entr.: 2.557 │ Chain Modes: 18 │ Chain Reset Frac.: 0.103 │ Learning Rate: 0.01000
# Epoch 121/500 │ Loss: -0.1885 │ Chain Entr.: 2.552 │ Chain Modes: 17 │ Chain Reset Frac.: 0.111 │ Learning Rate: 0.01000
# Epoch 122/500 │ Loss: -0.1959 │ Chain Entr.: 2.521 │ Chain Modes: 16 │ Chain Reset Frac.: 0.094 │ Learning Rate: 0.01000
# Epoch 123/500 │ Loss: -0.1933 │ Chain Entr.: 2.513 │ Chain Modes: 16 │ Chain Reset Frac.: 0.080 │ Learning Rate: 0.01000
# Epoch 124/500 │ Loss: -0.1993 │ Chain Entr.: 2.496 │ Chain Modes: 16 │ Chain Reset Frac.: 0.084 │ Learning Rate: 0.01000
# Epoch 125/500 │ Loss: -0.2357 │ Chain Entr.: 2.490 │ Chain Modes: 15 │ Chain Reset Frac.: 0.070 │ Learning Rate: 0.01000
# Epoch 126/500 │ Loss: -0.2558 │ Chain Entr.: 2.488 │ Chain Modes: 15 │ Chain Reset Frac.: 0.074 │ Learning Rate: 0.01000
# Epoch 127/500 │ Loss: -0.2405 │ Chain Entr.: 2.467 │ Chain Modes: 15 │ Chain Reset Frac.: 0.068 │ Learning Rate: 0.01000
# Epoch 128/500 │ Loss: -0.2362 │ Chain Entr.: 2.461 │ Chain Modes: 15 │ Chain Reset Frac.: 0.062 │ Learning Rate: 0.01000
# Epoch 129/500 │ Loss: -0.2239 │ Chain Entr.: 2.444 │ Chain Modes: 14 │ Chain Reset Frac.: 0.054 │ Learning Rate: 0.01000
# Epoch 130/500 │ Loss: -0.2206 │ Chain Entr.: 2.440 │ Chain Modes: 14 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.01000
# Epoch 131/500 │ Loss: -0.2100 │ Chain Entr.: 2.431 │ Chain Modes: 14 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.01000
# Epoch 132/500 │ Loss: -0.2108 │ Chain Entr.: 2.421 │ Chain Modes: 14 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.01000
# Epoch 133/500 │ Loss: -0.1910 │ Chain Entr.: 2.411 │ Chain Modes: 14 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.01000
# Epoch 134/500 │ Loss: -0.1851 │ Chain Entr.: 2.395 │ Chain Modes: 13 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.01000
# Epoch 135/500 │ Loss: -0.1876 │ Chain Entr.: 2.404 │ Chain Modes: 14 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.01000
# Epoch 136/500 │ Loss: -0.1499 │ Chain Entr.: 2.377 │ Chain Modes: 13 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 137/500 │ Loss: -0.1663 │ Chain Entr.: 2.380 │ Chain Modes: 13 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.01000
# Epoch 138/500 │ Loss: -0.1650 │ Chain Entr.: 2.374 │ Chain Modes: 13 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 139/500 │ Loss: -0.1461 │ Chain Entr.: 2.357 │ Chain Modes: 13 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 140/500 │ Loss: -0.1539 │ Chain Entr.: 2.354 │ Chain Modes: 13 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 141/500 │ Loss: -0.1368 │ Chain Entr.: 2.342 │ Chain Modes: 12 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 142/500 │ Loss: -0.1252 │ Chain Entr.: 2.332 │ Chain Modes: 12 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 143/500 │ Loss: -0.1156 │ Chain Entr.: 2.321 │ Chain Modes: 12 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 144/500 │ Loss: -0.1235 │ Chain Entr.: 2.317 │ Chain Modes: 12 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 145/500 │ Loss: -0.1080 │ Chain Entr.: 2.312 │ Chain Modes: 12 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 146/500 │ Loss: -0.1100 │ Chain Entr.: 2.314 │ Chain Modes: 12 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 147/500 │ Loss: -0.0858 │ Chain Entr.: 2.295 │ Chain Modes: 12 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 148/500 │ Loss: -0.0911 │ Chain Entr.: 2.293 │ Chain Modes: 12 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 149/500 │ Loss: -0.0783 │ Chain Entr.: 2.284 │ Chain Modes: 11 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 150/500 │ Loss: -0.0665 │ Chain Entr.: 2.277 │ Chain Modes: 11 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 151/500 │ Loss: -0.0780 │ Chain Entr.: 2.281 │ Chain Modes: 11 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 152/500 │ Loss: -0.0856 │ Chain Entr.: 2.285 │ Chain Modes: 11 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 153/500 │ Loss: -0.0961 │ Chain Entr.: 2.299 │ Chain Modes: 12 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 154/500 │ Loss: -0.0609 │ Chain Entr.: 2.281 │ Chain Modes: 11 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 155/500 │ Loss: -0.0653 │ Chain Entr.: 2.274 │ Chain Modes: 11 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 156/500 │ Loss: -0.0679 │ Chain Entr.: 2.274 │ Chain Modes: 11 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 157/500 │ Loss: -0.0713 │ Chain Entr.: 2.274 │ Chain Modes: 11 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 158/500 │ Loss: -0.0619 │ Chain Entr.: 2.269 │ Chain Modes: 11 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.01000
# Epoch 159/500 │ Loss: -0.0644 │ Chain Entr.: 2.268 │ Chain Modes: 11 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 160/500 │ Loss: -0.0656 │ Chain Entr.: 2.271 │ Chain Modes: 11 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 161/500 │ Loss: -0.0634 │ Chain Entr.: 2.270 │ Chain Modes: 11 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 162/500 │ Loss: -0.0474 │ Chain Entr.: 2.261 │ Chain Modes: 11 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 163/500 │ Loss: -0.0424 │ Chain Entr.: 2.255 │ Chain Modes: 11 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 164/500 │ Loss: -0.0573 │ Chain Entr.: 2.270 │ Chain Modes: 11 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 165/500 │ Loss: -0.0453 │ Chain Entr.: 2.254 │ Chain Modes: 11 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 166/500 │ Loss: -0.0595 │ Chain Entr.: 2.261 │ Chain Modes: 11 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 167/500 │ Loss: -0.0564 │ Chain Entr.: 2.266 │ Chain Modes: 11 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 168/500 │ Loss: -0.0343 │ Chain Entr.: 2.254 │ Chain Modes: 11 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.01000
# Epoch 169/500 │ Loss: -0.0437 │ Chain Entr.: 2.257 │ Chain Modes: 11 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 170/500 │ Loss: -0.0496 │ Chain Entr.: 2.259 │ Chain Modes: 11 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 171/500 │ Loss: -0.0402 │ Chain Entr.: 2.255 │ Chain Modes: 11 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 172/500 │ Loss: -0.0458 │ Chain Entr.: 2.256 │ Chain Modes: 11 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 173/500 │ Loss: -0.0453 │ Chain Entr.: 2.260 │ Chain Modes: 11 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 174/500 │ Loss: -0.0361 │ Chain Entr.: 2.261 │ Chain Modes: 11 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 175/500 │ Loss: -0.0351 │ Chain Entr.: 2.250 │ Chain Modes: 11 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 176/500 │ Loss: -0.0316 │ Chain Entr.: 2.244 │ Chain Modes: 11 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 177/500 │ Loss: -0.0422 │ Chain Entr.: 2.257 │ Chain Modes: 11 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00999
# Epoch 178/500 │ Loss: -0.0415 │ Chain Entr.: 2.254 │ Chain Modes: 11 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00999
# Epoch 179/500 │ Loss: -0.0358 │ Chain Entr.: 2.257 │ Chain Modes: 11 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00999
# Epoch 180/500 │ Loss: -0.0370 │ Chain Entr.: 2.251 │ Chain Modes: 11 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00999
# Epoch 181/500 │ Loss: -0.0451 │ Chain Entr.: 2.256 │ Chain Modes: 11 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00999
# Epoch 182/500 │ Loss: -0.0215 │ Chain Entr.: 2.244 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00999
# Epoch 183/500 │ Loss: -0.0499 │ Chain Entr.: 2.257 │ Chain Modes: 11 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00999
# Epoch 184/500 │ Loss: -0.0203 │ Chain Entr.: 2.243 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00999
# Epoch 185/500 │ Loss: -0.0320 │ Chain Entr.: 2.255 │ Chain Modes: 11 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00999
# Epoch 186/500 │ Loss: -0.0562 │ Chain Entr.: 2.251 │ Chain Modes: 11 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00999
# Epoch 187/500 │ Loss: -0.0278 │ Chain Entr.: 2.248 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00999
# Epoch 188/500 │ Loss: -0.0189 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00998
# Epoch 189/500 │ Loss: -0.0314 │ Chain Entr.: 2.245 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00998
# Epoch 190/500 │ Loss: -0.0239 │ Chain Entr.: 2.248 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00998
# Epoch 191/500 │ Loss: -0.0202 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00998
# Epoch 192/500 │ Loss: -0.0424 │ Chain Entr.: 2.254 │ Chain Modes: 11 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00998
# Epoch 193/500 │ Loss: -0.0243 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00997
# Epoch 194/500 │ Loss: -0.0293 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00997
# Epoch 195/500 │ Loss: -0.0230 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00997
# Epoch 196/500 │ Loss: -0.0192 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00996
# Epoch 197/500 │ Loss: -0.0306 │ Chain Entr.: 2.247 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00996
# Epoch 198/500 │ Loss: -0.0282 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00996
# Epoch 199/500 │ Loss: -0.0206 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00995
# Epoch 200/500 │ Loss: -0.0225 │ Chain Entr.: 2.249 │ Chain Modes: 10 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00995
# Epoch 201/500 │ Loss: -0.0355 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00994
# Epoch 202/500 │ Loss: -0.0197 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00993
# Epoch 203/500 │ Loss: -0.0256 │ Chain Entr.: 2.245 │ Chain Modes: 10 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00993
# Epoch 204/500 │ Loss: -0.0259 │ Chain Entr.: 2.244 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00992
# Epoch 205/500 │ Loss: -0.0310 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00991
# Epoch 206/500 │ Loss: -0.0152 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00990
# Epoch 207/500 │ Loss: -0.0285 │ Chain Entr.: 2.244 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00989
# Epoch 208/500 │ Loss: -0.0238 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00988
# Epoch 209/500 │ Loss: -0.0173 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00987
# Epoch 210/500 │ Loss: -0.0249 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00986
# Epoch 211/500 │ Loss: -0.0232 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00984
# Epoch 212/500 │ Loss: -0.0252 │ Chain Entr.: 2.243 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00982
# Epoch 213/500 │ Loss: -0.0216 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00981
# Epoch 214/500 │ Loss: -0.0189 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00979
# Epoch 215/500 │ Loss: -0.0205 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00977
# Epoch 216/500 │ Loss: -0.0130 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00974
# Epoch 217/500 │ Loss: -0.0268 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00972
# Epoch 218/500 │ Loss: -0.0258 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00969
# Epoch 219/500 │ Loss: -0.0225 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00966
# Epoch 220/500 │ Loss: -0.0048 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00962
# Epoch 221/500 │ Loss: -0.0175 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00958
# Epoch 222/500 │ Loss: -0.0131 │ Chain Entr.: 2.227 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00954
# Epoch 223/500 │ Loss: -0.0105 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00950
# Epoch 224/500 │ Loss: -0.0143 │ Chain Entr.: 2.243 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00945
# Epoch 225/500 │ Loss: -0.0265 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00939
# Epoch 226/500 │ Loss: -0.0237 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00933
# Epoch 227/500 │ Loss: -0.0072 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00927
# Epoch 228/500 │ Loss: -0.0109 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00920
# Epoch 229/500 │ Loss: -0.0174 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00913
# Epoch 230/500 │ Loss: -0.0135 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00905
# Epoch 231/500 │ Loss: -0.0137 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00896
# Epoch 232/500 │ Loss: -0.0189 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00887
# Epoch 233/500 │ Loss: -0.0203 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00876
# Epoch 234/500 │ Loss: -0.0152 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00866
# Epoch 235/500 │ Loss: -0.0229 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00854
# Epoch 236/500 │ Loss: -0.0177 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00842
# Epoch 237/500 │ Loss: -0.0177 │ Chain Entr.: 2.243 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00829
# Epoch 238/500 │ Loss: -0.0257 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00815
# Epoch 239/500 │ Loss: -0.0242 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00800
# Epoch 240/500 │ Loss: -0.0145 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00785
# Epoch 241/500 │ Loss: -0.0127 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00769
# Epoch 242/500 │ Loss: -0.0165 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00752
# Epoch 243/500 │ Loss: -0.0080 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00735
# Epoch 244/500 │ Loss: -0.0104 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00717
# Epoch 245/500 │ Loss: -0.0116 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00698
# Epoch 246/500 │ Loss: -0.0172 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00679
# Epoch 247/500 │ Loss: -0.0144 │ Chain Entr.: 2.231 │ Chain Modes: 10 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00660
# Epoch 248/500 │ Loss: -0.0126 │ Chain Entr.: 2.226 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00640
# Epoch 249/500 │ Loss: -0.0150 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00620
# Epoch 250/500 │ Loss: -0.0229 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00600
# Epoch 251/500 │ Loss: -0.0154 │ Chain Entr.: 2.229 │ Chain Modes: 10 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.00580
# Epoch 252/500 │ Loss: -0.0163 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00560
# Epoch 253/500 │ Loss: -0.0186 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00540
# Epoch 254/500 │ Loss: -0.0093 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00521
# Epoch 255/500 │ Loss: -0.0154 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00502
# Epoch 256/500 │ Loss: -0.0108 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00483
# Epoch 257/500 │ Loss: -0.0213 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00465
# Epoch 258/500 │ Loss: -0.0148 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00448
# Epoch 259/500 │ Loss: -0.0155 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00431
# Epoch 260/500 │ Loss: -0.0161 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00415
# Epoch 261/500 │ Loss: -0.0288 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00400
# Epoch 262/500 │ Loss: -0.0155 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00385
# Epoch 263/500 │ Loss: -0.0180 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00371
# Epoch 264/500 │ Loss: -0.0258 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00358
# Epoch 265/500 │ Loss: -0.0166 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00346
# Epoch 266/500 │ Loss: -0.0181 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00334
# Epoch 267/500 │ Loss: -0.0217 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00324
# Epoch 268/500 │ Loss: -0.0243 │ Chain Entr.: 2.244 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00313
# Epoch 269/500 │ Loss: -0.0170 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00304
# Epoch 270/500 │ Loss: -0.0193 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00295
# Epoch 271/500 │ Loss: -0.0154 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00287
# Epoch 272/500 │ Loss: -0.0314 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00280
# Epoch 273/500 │ Loss: -0.0301 │ Chain Entr.: 2.247 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00273
# Epoch 274/500 │ Loss: -0.0173 │ Chain Entr.: 2.231 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00267
# Epoch 275/500 │ Loss: -0.0081 │ Chain Entr.: 2.231 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00261
# Epoch 276/500 │ Loss: -0.0085 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00255
# Epoch 277/500 │ Loss: -0.0263 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00250
# Epoch 278/500 │ Loss: -0.0084 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00246
# Epoch 279/500 │ Loss: -0.0254 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00242
# Epoch 280/500 │ Loss: -0.0147 │ Chain Entr.: 2.225 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00238
# Epoch 281/500 │ Loss: -0.0189 │ Chain Entr.: 2.227 │ Chain Modes: 10 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00234
# Epoch 282/500 │ Loss: -0.0215 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00231
# Epoch 283/500 │ Loss: -0.0207 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00228
# Epoch 284/500 │ Loss: -0.0084 │ Chain Entr.: 2.228 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00226
# Epoch 285/500 │ Loss: -0.0263 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00223
# Epoch 286/500 │ Loss: -0.0275 │ Chain Entr.: 2.253 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00221
# Epoch 287/500 │ Loss: -0.0167 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00219
# Epoch 288/500 │ Loss: -0.0150 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00218
# Epoch 289/500 │ Loss: -0.0141 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00216
# Epoch 290/500 │ Loss: -0.0162 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00214
# Epoch 291/500 │ Loss: -0.0216 │ Chain Entr.: 2.248 │ Chain Modes: 10 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00213
# Epoch 292/500 │ Loss: -0.0191 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00212
# Epoch 293/500 │ Loss: -0.0162 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00211
# Epoch 294/500 │ Loss: -0.0193 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.00210
# Epoch 295/500 │ Loss: -0.0175 │ Chain Entr.: 2.231 │ Chain Modes: 10 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00209
# Epoch 296/500 │ Loss: -0.0189 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00208
# Epoch 297/500 │ Loss: -0.0165 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00207
# Epoch 298/500 │ Loss: -0.0245 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00207
# Epoch 299/500 │ Loss: -0.0225 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00206
# Epoch 300/500 │ Loss: -0.0137 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00205
# Epoch 301/500 │ Loss: -0.0109 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00205
# Epoch 302/500 │ Loss: -0.0175 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00204
# Epoch 303/500 │ Loss: -0.0099 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00204
# Epoch 304/500 │ Loss: -0.0257 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00204
# Epoch 305/500 │ Loss: -0.0145 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00203
# Epoch 306/500 │ Loss: -0.0165 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00203
# Epoch 307/500 │ Loss: -0.0192 │ Chain Entr.: 2.229 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00203
# Epoch 308/500 │ Loss: -0.0120 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00202
# Epoch 309/500 │ Loss: -0.0296 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00202
# Epoch 310/500 │ Loss: -0.0198 │ Chain Entr.: 2.244 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00202
# Epoch 311/500 │ Loss: -0.0180 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00202
# Epoch 312/500 │ Loss: -0.0176 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00202
# Epoch 313/500 │ Loss: -0.0155 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00201
# Epoch 314/500 │ Loss: -0.0171 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00201
# Epoch 315/500 │ Loss: -0.0155 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00201
# Epoch 316/500 │ Loss: -0.0258 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00201
# Epoch 317/500 │ Loss: -0.0181 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00201
# Epoch 318/500 │ Loss: -0.0116 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00201
# Epoch 319/500 │ Loss: -0.0256 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00201
# Epoch 320/500 │ Loss: -0.0178 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00201
# Epoch 321/500 │ Loss: -0.0176 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00201
# Epoch 322/500 │ Loss: -0.0087 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00201
# Epoch 323/500 │ Loss: -0.0148 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00201
# Epoch 324/500 │ Loss: -0.0179 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 325/500 │ Loss: -0.0178 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00200
# Epoch 326/500 │ Loss: -0.0204 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00200
# Epoch 327/500 │ Loss: -0.0117 │ Chain Entr.: 2.243 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 328/500 │ Loss: -0.0148 │ Chain Entr.: 2.244 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 329/500 │ Loss: -0.0267 │ Chain Entr.: 2.244 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 330/500 │ Loss: -0.0183 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00200
# Epoch 331/500 │ Loss: -0.0105 │ Chain Entr.: 2.224 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00200
# Epoch 332/500 │ Loss: -0.0116 │ Chain Entr.: 2.225 │ Chain Modes: 10 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00200
# Epoch 333/500 │ Loss: -0.0079 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00200
# Epoch 334/500 │ Loss: -0.0201 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 335/500 │ Loss: -0.0240 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 336/500 │ Loss: -0.0204 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 337/500 │ Loss: -0.0204 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 338/500 │ Loss: -0.0085 │ Chain Entr.: 2.231 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00200
# Epoch 339/500 │ Loss: -0.0111 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 340/500 │ Loss: -0.0165 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 341/500 │ Loss: -0.0175 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 342/500 │ Loss: -0.0220 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 343/500 │ Loss: -0.0233 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 344/500 │ Loss: -0.0102 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 345/500 │ Loss: -0.0093 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 346/500 │ Loss: -0.0191 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 347/500 │ Loss: -0.0195 │ Chain Entr.: 2.223 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 348/500 │ Loss: -0.0163 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 349/500 │ Loss: -0.0207 │ Chain Entr.: 2.244 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 350/500 │ Loss: -0.0111 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 351/500 │ Loss: -0.0231 │ Chain Entr.: 2.244 │ Chain Modes: 10 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00200
# Epoch 352/500 │ Loss: -0.0151 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00200
# Epoch 353/500 │ Loss: -0.0098 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00200
# Epoch 354/500 │ Loss: -0.0109 │ Chain Entr.: 2.226 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 355/500 │ Loss: -0.0180 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00200
# Epoch 356/500 │ Loss: -0.0245 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 357/500 │ Loss: -0.0181 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 358/500 │ Loss: -0.0112 │ Chain Entr.: 2.226 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 359/500 │ Loss: -0.0198 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00200
# Epoch 360/500 │ Loss: -0.0079 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00200
# Epoch 361/500 │ Loss: -0.0204 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00200
# Epoch 362/500 │ Loss: -0.0101 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 363/500 │ Loss: -0.0100 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 364/500 │ Loss: -0.0132 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00200
# Epoch 365/500 │ Loss: -0.0171 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 366/500 │ Loss: -0.0186 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 367/500 │ Loss: -0.0196 │ Chain Entr.: 2.243 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 368/500 │ Loss: -0.0152 │ Chain Entr.: 2.228 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 369/500 │ Loss: -0.0101 │ Chain Entr.: 2.226 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00200
# Epoch 370/500 │ Loss: -0.0175 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 371/500 │ Loss: -0.0170 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 372/500 │ Loss: -0.0154 │ Chain Entr.: 2.229 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00200
# Epoch 373/500 │ Loss: -0.0180 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 374/500 │ Loss: -0.0144 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00200
# Epoch 375/500 │ Loss: -0.0157 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 376/500 │ Loss: -0.0099 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00200
# Epoch 377/500 │ Loss: -0.0107 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00200
# Epoch 378/500 │ Loss: -0.0100 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00200
# Epoch 379/500 │ Loss: -0.0073 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 380/500 │ Loss: -0.0117 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 381/500 │ Loss: -0.0203 │ Chain Entr.: 2.231 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 382/500 │ Loss: -0.0174 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 383/500 │ Loss: -0.0169 │ Chain Entr.: 2.244 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 384/500 │ Loss: -0.0132 │ Chain Entr.: 2.222 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 385/500 │ Loss: -0.0099 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 386/500 │ Loss: -0.0167 │ Chain Entr.: 2.231 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00200
# Epoch 387/500 │ Loss: -0.0146 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 388/500 │ Loss: -0.0129 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 389/500 │ Loss: -0.0080 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 390/500 │ Loss: -0.0066 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 391/500 │ Loss: -0.0218 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.00200
# Epoch 392/500 │ Loss: -0.0109 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00200
# Epoch 393/500 │ Loss: -0.0217 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 394/500 │ Loss: -0.0167 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 395/500 │ Loss: -0.0188 │ Chain Entr.: 2.243 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 396/500 │ Loss: -0.0139 │ Chain Entr.: 2.229 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 397/500 │ Loss: -0.0223 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 398/500 │ Loss: -0.0234 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 399/500 │ Loss: -0.0138 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00200
# Epoch 400/500 │ Loss: -0.0212 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00200
# Epoch 401/500 │ Loss: -0.0202 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 402/500 │ Loss: -0.0196 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00200
# Epoch 403/500 │ Loss: -0.0129 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 404/500 │ Loss: -0.0192 │ Chain Entr.: 2.227 │ Chain Modes: 10 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00200
# Epoch 405/500 │ Loss: -0.0185 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00200
# Epoch 406/500 │ Loss: -0.0208 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 407/500 │ Loss: -0.0186 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 408/500 │ Loss: -0.0114 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00200
# Epoch 409/500 │ Loss: -0.0185 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 410/500 │ Loss: -0.0085 │ Chain Entr.: 2.226 │ Chain Modes: 10 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00200
# Epoch 411/500 │ Loss: -0.0084 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 412/500 │ Loss: -0.0202 │ Chain Entr.: 2.227 │ Chain Modes: 10 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00200
# Epoch 413/500 │ Loss: -0.0151 │ Chain Entr.: 2.240 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 414/500 │ Loss: -0.0185 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 415/500 │ Loss: -0.0176 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 416/500 │ Loss: -0.0135 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 417/500 │ Loss: -0.0125 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 418/500 │ Loss: -0.0107 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00200
# Epoch 419/500 │ Loss: -0.0145 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00200
# Epoch 420/500 │ Loss: -0.0084 │ Chain Entr.: 2.229 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 421/500 │ Loss: -0.0145 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 422/500 │ Loss: -0.0092 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00200
# Epoch 423/500 │ Loss: -0.0155 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 424/500 │ Loss: -0.0147 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 425/500 │ Loss: -0.0191 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00200
# Epoch 426/500 │ Loss: -0.0203 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 427/500 │ Loss: -0.0107 │ Chain Entr.: 2.245 │ Chain Modes: 10 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00200
# Epoch 428/500 │ Loss: -0.0157 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00200
# Epoch 429/500 │ Loss: -0.0145 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00200
# Epoch 430/500 │ Loss: -0.0174 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00200
# Epoch 431/500 │ Loss: -0.0179 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 432/500 │ Loss: -0.0203 │ Chain Entr.: 2.243 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 433/500 │ Loss: -0.0210 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 434/500 │ Loss: -0.0083 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00200
# Epoch 435/500 │ Loss: -0.0168 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 436/500 │ Loss: -0.0216 │ Chain Entr.: 2.245 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 437/500 │ Loss: -0.0149 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 438/500 │ Loss: -0.0136 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 439/500 │ Loss: -0.0107 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 440/500 │ Loss: -0.0193 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 441/500 │ Loss: -0.0185 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00200
# Epoch 442/500 │ Loss: -0.0270 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 443/500 │ Loss: -0.0143 │ Chain Entr.: 2.245 │ Chain Modes: 10 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00200
# Epoch 444/500 │ Loss: -0.0111 │ Chain Entr.: 2.231 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 445/500 │ Loss: -0.0235 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 446/500 │ Loss: -0.0130 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 447/500 │ Loss: -0.0235 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 448/500 │ Loss: -0.0220 │ Chain Entr.: 2.242 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 449/500 │ Loss: -0.0023 │ Chain Entr.: 2.231 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 450/500 │ Loss: -0.0186 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.00200
# Epoch 451/500 │ Loss: -0.0129 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 452/500 │ Loss: -0.0123 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00200
# Epoch 453/500 │ Loss: -0.0086 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00200
# Epoch 454/500 │ Loss: -0.0157 │ Chain Entr.: 2.243 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 455/500 │ Loss: -0.0135 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 456/500 │ Loss: -0.0131 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 457/500 │ Loss: -0.0074 │ Chain Entr.: 2.223 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 458/500 │ Loss: -0.0144 │ Chain Entr.: 2.230 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 459/500 │ Loss: -0.0161 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 460/500 │ Loss: -0.0170 │ Chain Entr.: 2.245 │ Chain Modes: 10 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00200
# Epoch 461/500 │ Loss: -0.0119 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00200
# Epoch 462/500 │ Loss: -0.0160 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00200
# Epoch 463/500 │ Loss: -0.0110 │ Chain Entr.: 2.235 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 464/500 │ Loss: -0.0222 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 465/500 │ Loss: -0.0140 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00200
# Epoch 466/500 │ Loss: -0.0152 │ Chain Entr.: 2.226 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 467/500 │ Loss: -0.0149 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 468/500 │ Loss: -0.0118 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00200
# Epoch 469/500 │ Loss: -0.0143 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 470/500 │ Loss: -0.0100 │ Chain Entr.: 2.241 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 471/500 │ Loss: -0.0177 │ Chain Entr.: 2.224 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 472/500 │ Loss: -0.0166 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 473/500 │ Loss: -0.0127 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 474/500 │ Loss: -0.0152 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 475/500 │ Loss: -0.0120 │ Chain Entr.: 2.227 │ Chain Modes: 10 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00200
# Epoch 476/500 │ Loss: -0.0205 │ Chain Entr.: 2.246 │ Chain Modes: 10 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00200
# Epoch 477/500 │ Loss: -0.0141 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 478/500 │ Loss: -0.0070 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00200
# Epoch 479/500 │ Loss: -0.0078 │ Chain Entr.: 2.231 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 480/500 │ Loss: -0.0094 │ Chain Entr.: 2.226 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 481/500 │ Loss: -0.0095 │ Chain Entr.: 2.243 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00200
# Epoch 482/500 │ Loss: -0.0183 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 483/500 │ Loss: -0.0159 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00200
# Epoch 484/500 │ Loss: -0.0094 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 485/500 │ Loss: -0.0138 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 486/500 │ Loss: -0.0084 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00200
# Epoch 487/500 │ Loss: -0.0175 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00200
# Epoch 488/500 │ Loss: -0.0068 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 489/500 │ Loss: -0.0064 │ Chain Entr.: 2.226 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00200
# Epoch 490/500 │ Loss: -0.0131 │ Chain Entr.: 2.227 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 491/500 │ Loss: -0.0113 │ Chain Entr.: 2.234 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00200
# Epoch 492/500 │ Loss: -0.0217 │ Chain Entr.: 2.236 │ Chain Modes: 10 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00200
# Epoch 493/500 │ Loss: -0.0018 │ Chain Entr.: 2.233 │ Chain Modes: 10 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00200
# Epoch 494/500 │ Loss: -0.0129 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 495/500 │ Loss: -0.0158 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 496/500 │ Loss: -0.0157 │ Chain Entr.: 2.239 │ Chain Modes: 10 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00200
# Epoch 497/500 │ Loss: -0.0188 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# Epoch 498/500 │ Loss: -0.0134 │ Chain Entr.: 2.238 │ Chain Modes: 10 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00200
# Epoch 499/500 │ Loss: -0.0065 │ Chain Entr.: 2.232 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00200
# Epoch 500/500 │ Loss: -0.0051 │ Chain Entr.: 2.237 │ Chain Modes: 10 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00200
# CPU times: user 4min 44s, sys: 2.74 s, total: 4min 47s
# Wall time: 4min 49s

# %%
epochs = list(metrics_amp.keys())
loss_vals = [metrics_amp[e]['loss'] for e in epochs]
entropy_vals = [metrics_amp[e]['entropy_chain'] for e in epochs]
mode_vals = [metrics_amp[e]['modes_chain'] for e in epochs]
lr_vals = [metrics_amp[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots()

ax1.plot(epochs, loss_vals, label="Amplitude CD Loss", color="tab:blue")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Amplitude CD Loss", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

ax2 = ax1.twinx()
ax2.plot(epochs, entropy_vals, label="Chain Entropy", color="tab:orange")
ax2.set_ylabel("Chain Entropy", color="tab:orange")
ax2.tick_params(axis="y", labelcolor="tab:orange")

ax3 = ax1.twinx()
ax3.spines["right"].set_position(("axes", 1.2))
ax3.plot(epochs, mode_vals, label="Estimated Mode Count", color="tab:green")
ax3.set_ylabel("Mode Count", color="tab:green")
ax3.tick_params(axis="y", labelcolor="tab:green")

ax4 = ax1.twinx()
ax4.spines["right"].set_position(("axes", 1.4))
ax4.plot(epochs, lr_vals, label="Learning Rate", color="tab:red")
ax4.set_ylabel("Learning Rate", color="tab:red")
ax4.tick_params(axis="y", labelcolor="tab:red")

plt.title("CD Loss vs. Entropy vs. Mode Count vs. Learning Rate")
plt.show()

# %%
# shifting the center step to 0 we can approximate an exponential schedule if we choose the high to be
T_high = 2.0
T_low = 0.01
sampling_steps = 5000
sigmoid_schedule_fn = get_sigmoid_curve(high=T_high*2, low=0.01, steps=sampling_steps, falloff=0.0013, center_step=0)
sigmoid_schedule = jnp.array([sigmoid_schedule_fn(i) for i in range(sampling_steps)], dtype=jnp.float32)

key_sample = PRNGKey(1234)

samples_amp = model_amp.apply(
    {"params": state_amp.params},
    n_samples=20_000,
    T_schedule=sigmoid_schedule,
    key=key_sample,
    method=RBM.generate
)

sampled_freq_amp = samples_amp.mean(0)
sampled_freq_amp
# Out:
# Array([0.09175   , 0.10089999, 0.10495   , 0.1002    , 0.10205   ,
#        0.0977    , 0.10134999, 0.0968    , 0.10745   , 0.0968    ],      dtype=float32)

# %%
spin_counts = samples_amp.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(12), align='left', edgecolor='black')
plt.xticks(range(11))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
plt.figure(figsize=(10, 5))
x = np.arange(visible_units) + 1
width = 0.35

plt.bar(x - width/2, empirical_freq_amp, width, label="Empirical", alpha=0.7)
plt.bar(x + width/2, sampled_freq_amp, width, label="Sampled", alpha=0.7)

plt.axhline(1 / visible_units, linestyle='--', color='gray', label=f'1/{visible_units} reference')
plt.xlabel("Visible Unit Index")
plt.ylabel("Mean Activation Frequency")
plt.title("Comparison: Empirical vs Sampled Frequencies")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
timestamp = datetime.now().strftime("%Y%m%d%H%M")
model_name = f"rbm_amp_{timestamp}"

checkpoints.save_checkpoint(
    ckpt_dir=str(model_dir.resolve()),
    target=state_amp.params,
    step=0,
    prefix=model_name + "_",
    overwrite=True
)
# Out:
# WARNING:absl:The `aggregate` option is deprecated and will be ignored.
# '/Users/Tonni/Desktop/master-code/neural-quantum-tomo/case_studies/w_aug_v3/models/rbm_amp_202506032349_0'
