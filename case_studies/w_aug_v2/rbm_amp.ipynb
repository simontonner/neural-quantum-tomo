# %%
# %reload_ext autoreload
# %autoreload 2

from lib.data_loading import load_measurements, MultiBasisDataLoader

####

import re
from pathlib import Path
from typing import Optional, Tuple, Dict, Any, Sequence
from datetime import datetime

import numpy as np

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import optax
from flax.training.train_state import TrainState
from flax.training import checkpoints
from flax import linen as nn

import matplotlib.pyplot as plt


data_dir = "data"
model_dir = Path("./models")
model_dir.mkdir(parents=True, exist_ok=True)

print(f"Data resides in        : {data_dir}")
print(f"Model will be saved to : {model_dir}")
# Out:
# WARNING:absl:Tensorflow library not found, tensorflow.io.gfile operations will use native shim calls. GCS paths (i.e. 'gs://...') cannot be accessed.
# Data resides in        : data
# Model will be saved to : models

# %%
class RBM(nn.Module):
    n_visible: int
    n_hidden: int
    k: int = 1          # bound to class instance to make whole gibbs chain compilable
    T: float = 1.0      # bound to class instance to make single gibbs step compilable

    def setup(self):
        self.W = self.param("W", nn.initializers.normal(0.01), (self.n_visible, self.n_hidden))
        self.b = self.param("b", nn.initializers.zeros, (self.n_visible,))
        self.c = self.param("c", nn.initializers.zeros, (self.n_hidden,))

    def __call__(self, data: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W, self.b, self.c, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (aux_vars["gibbs_chain"], aux_vars["key"]))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain) # cut off gradients after Gibbs sampling

        loss = jnp.mean(self._free_energy(data)) - jnp.mean(self._free_energy(gibbs_chain))
        return loss, {"gibbs_chain": gibbs_chain, "key": key}

    def _free_energy(self, v):
        return -(v @ self.b) - jnp.sum(jax.nn.softplus(v @ self.W + self.c), -1)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c)/T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b)/T)).astype(jnp.float32)
        return v, key

    @nn.nowrap
    def generate(self, n_samples: int, T_schedule: jnp.ndarray, key: PRNGKey) -> jnp.ndarray:
        key, key_init = jax.random.split(key, 2)
        v = jax.random.bernoulli(key_init, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)

        anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, (v, key))
        return v_final

# %%
@jax.jit
def train_step_amp(
        state: TrainState,
        batch: jnp.ndarray,
        gibbs_chain: jnp.ndarray,
        key: PRNGKey,
        chain_reset_frac: float) -> Tuple[TrainState, jnp.ndarray, jnp.ndarray, PRNGKey]:

    key, key_reset, key_sample = jax.random.split(key, 3)

    # Reset mask: which chains to replace
    reset_mask = jax.random.bernoulli(key_reset, p=chain_reset_frac, shape=(batch_size, 1))

    # Sample from batch — shape (batch_size,)
    sample_idxs = jax.random.randint(key_sample, shape=(batch_size,), minval=0, maxval=batch.shape[0])
    sampled_onehots = batch[sample_idxs]  # shape (batch_size, n_visible)

    # Replace according to mask
    reset_chain = jnp.where(reset_mask, sampled_onehots, gibbs_chain)


    aux_vars = {"gibbs_chain": reset_chain, "key": key}
    loss_fn = lambda params: state.apply_fn({'params': params}, batch, aux_vars)
    (loss, aux_vars), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    state = state.apply_gradients(grads=grads)

    return state, loss, aux_vars["gibbs_chain"], aux_vars["key"]


def entropy_modes(chain: jnp.ndarray) -> Tuple[float, int]:
    # translate each binary pattern to a unique integer
    chain = chain.astype(jnp.uint32)
    powers = 2 ** jnp.arange(chain.shape[-1], dtype=jnp.uint32)
    ints = jnp.dot(chain, powers)

    hist = jnp.bincount(ints, length=1 << chain.shape[-1]).astype(jnp.float32)
    probs = hist / jnp.sum(hist)
    entropy = -jnp.sum(jnp.where(probs > 0, probs * jnp.log(probs), 0.0)) # shannon entropy with guard against prob <=0
    mode_count = jnp.sum(hist > 0)
    return float(entropy), int(mode_count)


def train_amp_rbm(
        state: TrainState,
        loader: MultiBasisDataLoader,
        gibbs_chain: jnp.ndarray,
        num_epochs: int,
        key: PRNGKey,
        chain_reset_frac_min: float = 0.02,
        chain_reset_frac_max: float = 0.30,
        chain_reset_ema_alpha: float = 0.9) -> Tuple[TrainState, Dict[int, float]]:

    print("Precalculating target entropy from data.")
    all_data = []

    for base_batches, _ in loader:
        all_data.append(base_batches[0])  # shape: (batch_size, n_visible)

    all_data = jnp.concatenate(all_data, axis=0)
    entropy_target, _ = entropy_modes(all_data)

    chain_reset_frac_ema = 0.0
    metrics = {}
    for epoch in range(num_epochs):
        tot_loss = tot_entropy_chain = tot_modes_chain = 0.0
        batches = 0

        for base_batches, bases in loader:
            if base_batches.shape[0] != 1 or bases.shape[0] != 1:
                raise ValueError(f"Expected exactly one basis, got: {base_batches.shape[0]} bases")

            if not jnp.all(bases[0] == 0):
                raise ValueError(f"Only Z basis supported for amplitude RBM")

            batch = base_batches[0]

            entropy_chain, modes_chain = entropy_modes(gibbs_chain)
            chain_reset_frac_raw = jnp.abs(jnp.log(entropy_chain/entropy_target + 1e-12))  # tiny eps for stability
            chain_reset_frac_ema = chain_reset_frac_ema * chain_reset_ema_alpha + (1 - chain_reset_ema_alpha) * chain_reset_frac_raw
            chain_reset_frac = float(jnp.clip(chain_reset_frac_ema, chain_reset_frac_min, chain_reset_frac_max))

            state, loss, gibbs_chain, key = train_step_amp(state, batch, gibbs_chain, key, chain_reset_frac)

            tot_loss += float(loss)
            tot_entropy_chain += float(entropy_chain)
            tot_modes_chain += float(modes_chain)
            batches += 1

        avg_loss = tot_loss / batches
        avg_entropy_chain = tot_entropy_chain / batches
        avg_modes_chain = tot_modes_chain / batches
        lr = float(lr_schedule(state.opt_state[0].count))

        metrics[epoch] = dict(
            loss=avg_loss,
            entropy_chain=avg_entropy_chain,
            modes_chain=avg_modes_chain,
            lr=lr
        )

        print(f"Epoch {epoch+1}/{num_epochs} │ "
              f"Loss: {avg_loss:+.4f} │ "
              f"Chain Entr.: {avg_entropy_chain:.3f} │ "
              f"Chain Modes: {avg_modes_chain:.0f} │ "
              f"Chain Reset Frac.: {chain_reset_frac:.3f} │ "
              f"Learning Rate: {lr:.5f}")

    return state, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2

    curve_fn = lambda step: low + (high - low) / (1 + jnp.exp(falloff * (jnp.minimum(step, steps) - center_step)))
    return curve_fn

# %%
#### LOADING DATA IN Z BASIS ####

data_dict_amp = load_measurements(data_dir, "w_*.txt")

keys_amp = [k for k in data_dict_amp if re.fullmatch(r"^Z+$", k)]
dict_amp = {k: data_dict_amp[k] for k in keys_amp}

empirical_freq_amp = jnp.zeros(next(iter(dict_amp.values())).shape[1])
num_total = 0

for arr in dict_amp.values():
    empirical_freq_amp += jnp.sum(arr, axis=0)
    num_total += arr.shape[0]

empirical_freq_amp /= num_total
empirical_freq_amp
# Out:
# Array([0.1265625 , 0.1221875 , 0.1275    , 0.12375   , 0.13      ,
#        0.12859374, 0.11953125, 0.121875  ], dtype=float32)

# %%
batch_size      = 64        #                                               DONE
visible_units   = 8         #                                               DONE
hidden_units    = 16        # totally sufficient to capture all modes       DONE
k_steps         = 400       # higher is generally better                    GOOD FOR NOW
init_lr         = 1e-2      #                                               DONE
final_lr        = init_lr * 0.05 #                                           DONE
num_epochs      = 2000      #                                               MORE EPOCHS EVEN OUT SAMPLING FREQUENCIES
chains          = batch_size # makes chain replacement logic easier         DONE
weight_decay = 1e-2    #


key_seed = PRNGKey(42)
key, key_params, key_chains, key_dummy = jax.random.split(key_seed, 4)

model_amp = RBM(visible_units, hidden_units, k=k_steps)
batch_dummy = jnp.zeros((batch_size, visible_units), dtype=jnp.float32)
aux_vars_dummy = {"gibbs_chain": jnp.zeros((batch_size, visible_units), dtype=jnp.float32), "key": key_dummy}
variables_amp = model_amp.init({"params": key_params}, batch_dummy, aux_vars_dummy)

loader_amp = MultiBasisDataLoader(dict_amp, batch_size=batch_size, basis_encoding={'Z': 0, 'X': 1, 'Y': 2})

schedule_steps = num_epochs * len(loader_amp)
lr_schedule = get_sigmoid_curve(high=init_lr, low=final_lr, steps=schedule_steps, falloff=0.0005, center_step=schedule_steps * 0.5)
optimizer_amp = optax.adam(learning_rate=lr_schedule)

state_amp = TrainState.create(apply_fn=model_amp.apply, params=variables_amp["params"], tx=optimizer_amp)

# should come from data too but works for now
gibbs_chain = jax.random.bernoulli(key_chains, p=0.5, shape=(chains, visible_units)).astype(jnp.float32)

# %time state_amp, metrics_amp = train_amp_rbm(state_amp, loader_amp, gibbs_chain, num_epochs, key=key, chain_reset_frac_min=0.02, chain_reset_frac_max=0.30, chain_reset_ema_alpha=0.9)
# Out:
# Precalculating target entropy from data.
# Epoch 1/500 │ Loss: -0.1971 │ Chain Entr.: 2.796 │ Chain Modes: 29 │ Chain Reset Frac.: 0.232 │ Learning Rate: 0.01000
# Epoch 2/500 │ Loss: -0.0306 │ Chain Entr.: 2.556 │ Chain Modes: 24 │ Chain Reset Frac.: 0.156 │ Learning Rate: 0.01000
# Epoch 3/500 │ Loss: -0.0387 │ Chain Entr.: 2.558 │ Chain Modes: 24 │ Chain Reset Frac.: 0.193 │ Learning Rate: 0.01000
# Epoch 4/500 │ Loss: -0.0169 │ Chain Entr.: 2.569 │ Chain Modes: 24 │ Chain Reset Frac.: 0.208 │ Learning Rate: 0.01000
# Epoch 5/500 │ Loss: -0.0121 │ Chain Entr.: 2.556 │ Chain Modes: 24 │ Chain Reset Frac.: 0.191 │ Learning Rate: 0.01000
# Epoch 6/500 │ Loss: -0.0025 │ Chain Entr.: 2.544 │ Chain Modes: 23 │ Chain Reset Frac.: 0.189 │ Learning Rate: 0.01000
# Epoch 7/500 │ Loss: -0.0124 │ Chain Entr.: 2.553 │ Chain Modes: 23 │ Chain Reset Frac.: 0.195 │ Learning Rate: 0.01000
# Epoch 8/500 │ Loss: +0.0152 │ Chain Entr.: 2.536 │ Chain Modes: 23 │ Chain Reset Frac.: 0.170 │ Learning Rate: 0.01000
# Epoch 9/500 │ Loss: +0.0009 │ Chain Entr.: 2.526 │ Chain Modes: 24 │ Chain Reset Frac.: 0.211 │ Learning Rate: 0.01000
# Epoch 10/500 │ Loss: +0.0061 │ Chain Entr.: 2.526 │ Chain Modes: 23 │ Chain Reset Frac.: 0.197 │ Learning Rate: 0.01000
# Epoch 11/500 │ Loss: +0.0125 │ Chain Entr.: 2.519 │ Chain Modes: 23 │ Chain Reset Frac.: 0.198 │ Learning Rate: 0.01000
# Epoch 12/500 │ Loss: +0.0219 │ Chain Entr.: 2.523 │ Chain Modes: 23 │ Chain Reset Frac.: 0.170 │ Learning Rate: 0.01000
# Epoch 13/500 │ Loss: -0.0078 │ Chain Entr.: 2.542 │ Chain Modes: 23 │ Chain Reset Frac.: 0.215 │ Learning Rate: 0.01000
# Epoch 14/500 │ Loss: +0.0392 │ Chain Entr.: 2.504 │ Chain Modes: 23 │ Chain Reset Frac.: 0.203 │ Learning Rate: 0.01000
# Epoch 15/500 │ Loss: +0.0218 │ Chain Entr.: 2.510 │ Chain Modes: 23 │ Chain Reset Frac.: 0.160 │ Learning Rate: 0.01000
# Epoch 16/500 │ Loss: +0.0166 │ Chain Entr.: 2.524 │ Chain Modes: 23 │ Chain Reset Frac.: 0.181 │ Learning Rate: 0.01000
# Epoch 17/500 │ Loss: +0.0126 │ Chain Entr.: 2.534 │ Chain Modes: 23 │ Chain Reset Frac.: 0.197 │ Learning Rate: 0.01000
# Epoch 18/500 │ Loss: +0.0292 │ Chain Entr.: 2.522 │ Chain Modes: 23 │ Chain Reset Frac.: 0.171 │ Learning Rate: 0.01000
# Epoch 19/500 │ Loss: +0.0068 │ Chain Entr.: 2.539 │ Chain Modes: 23 │ Chain Reset Frac.: 0.210 │ Learning Rate: 0.01000
# Epoch 20/500 │ Loss: +0.0306 │ Chain Entr.: 2.516 │ Chain Modes: 23 │ Chain Reset Frac.: 0.199 │ Learning Rate: 0.01000
# Epoch 21/500 │ Loss: +0.0158 │ Chain Entr.: 2.513 │ Chain Modes: 23 │ Chain Reset Frac.: 0.170 │ Learning Rate: 0.01000
# Epoch 22/500 │ Loss: +0.0063 │ Chain Entr.: 2.543 │ Chain Modes: 23 │ Chain Reset Frac.: 0.190 │ Learning Rate: 0.01000
# Epoch 23/500 │ Loss: +0.0126 │ Chain Entr.: 2.518 │ Chain Modes: 23 │ Chain Reset Frac.: 0.202 │ Learning Rate: 0.01000
# Epoch 24/500 │ Loss: +0.0240 │ Chain Entr.: 2.521 │ Chain Modes: 23 │ Chain Reset Frac.: 0.197 │ Learning Rate: 0.01000
# Epoch 25/500 │ Loss: +0.0230 │ Chain Entr.: 2.531 │ Chain Modes: 23 │ Chain Reset Frac.: 0.179 │ Learning Rate: 0.01000
# Epoch 26/500 │ Loss: +0.0151 │ Chain Entr.: 2.534 │ Chain Modes: 23 │ Chain Reset Frac.: 0.190 │ Learning Rate: 0.01000
# Epoch 27/500 │ Loss: +0.0083 │ Chain Entr.: 2.526 │ Chain Modes: 23 │ Chain Reset Frac.: 0.194 │ Learning Rate: 0.01000
# Epoch 28/500 │ Loss: +0.0068 │ Chain Entr.: 2.530 │ Chain Modes: 23 │ Chain Reset Frac.: 0.219 │ Learning Rate: 0.01000
# Epoch 29/500 │ Loss: +0.0131 │ Chain Entr.: 2.536 │ Chain Modes: 23 │ Chain Reset Frac.: 0.212 │ Learning Rate: 0.01000
# Epoch 30/500 │ Loss: +0.0371 │ Chain Entr.: 2.499 │ Chain Modes: 23 │ Chain Reset Frac.: 0.137 │ Learning Rate: 0.01000
# Epoch 31/500 │ Loss: -0.0030 │ Chain Entr.: 2.544 │ Chain Modes: 23 │ Chain Reset Frac.: 0.183 │ Learning Rate: 0.01000
# Epoch 32/500 │ Loss: +0.0199 │ Chain Entr.: 2.515 │ Chain Modes: 23 │ Chain Reset Frac.: 0.171 │ Learning Rate: 0.01000
# Epoch 33/500 │ Loss: +0.0012 │ Chain Entr.: 2.538 │ Chain Modes: 23 │ Chain Reset Frac.: 0.191 │ Learning Rate: 0.01000
# Epoch 34/500 │ Loss: +0.0090 │ Chain Entr.: 2.526 │ Chain Modes: 23 │ Chain Reset Frac.: 0.206 │ Learning Rate: 0.01000
# Epoch 35/500 │ Loss: +0.0256 │ Chain Entr.: 2.512 │ Chain Modes: 23 │ Chain Reset Frac.: 0.164 │ Learning Rate: 0.01000
# Epoch 36/500 │ Loss: +0.0043 │ Chain Entr.: 2.536 │ Chain Modes: 24 │ Chain Reset Frac.: 0.181 │ Learning Rate: 0.01000
# Epoch 37/500 │ Loss: +0.0064 │ Chain Entr.: 2.525 │ Chain Modes: 23 │ Chain Reset Frac.: 0.188 │ Learning Rate: 0.01000
# Epoch 38/500 │ Loss: +0.0152 │ Chain Entr.: 2.513 │ Chain Modes: 23 │ Chain Reset Frac.: 0.168 │ Learning Rate: 0.01000
# Epoch 39/500 │ Loss: -0.0077 │ Chain Entr.: 2.536 │ Chain Modes: 23 │ Chain Reset Frac.: 0.203 │ Learning Rate: 0.01000
# Epoch 40/500 │ Loss: +0.0051 │ Chain Entr.: 2.529 │ Chain Modes: 23 │ Chain Reset Frac.: 0.203 │ Learning Rate: 0.01000
# Epoch 41/500 │ Loss: -0.0006 │ Chain Entr.: 2.520 │ Chain Modes: 23 │ Chain Reset Frac.: 0.192 │ Learning Rate: 0.01000
# Epoch 42/500 │ Loss: +0.0108 │ Chain Entr.: 2.507 │ Chain Modes: 23 │ Chain Reset Frac.: 0.183 │ Learning Rate: 0.01000
# Epoch 43/500 │ Loss: +0.0041 │ Chain Entr.: 2.534 │ Chain Modes: 23 │ Chain Reset Frac.: 0.214 │ Learning Rate: 0.01000
# Epoch 44/500 │ Loss: -0.0019 │ Chain Entr.: 2.524 │ Chain Modes: 23 │ Chain Reset Frac.: 0.202 │ Learning Rate: 0.01000
# Epoch 45/500 │ Loss: +0.0163 │ Chain Entr.: 2.516 │ Chain Modes: 23 │ Chain Reset Frac.: 0.186 │ Learning Rate: 0.01000
# Epoch 46/500 │ Loss: +0.0099 │ Chain Entr.: 2.505 │ Chain Modes: 23 │ Chain Reset Frac.: 0.208 │ Learning Rate: 0.01000
# Epoch 47/500 │ Loss: +0.0117 │ Chain Entr.: 2.520 │ Chain Modes: 23 │ Chain Reset Frac.: 0.183 │ Learning Rate: 0.01000
# Epoch 48/500 │ Loss: +0.0055 │ Chain Entr.: 2.521 │ Chain Modes: 23 │ Chain Reset Frac.: 0.183 │ Learning Rate: 0.01000
# Epoch 49/500 │ Loss: +0.0050 │ Chain Entr.: 2.522 │ Chain Modes: 23 │ Chain Reset Frac.: 0.193 │ Learning Rate: 0.01000
# Epoch 50/500 │ Loss: -0.0056 │ Chain Entr.: 2.537 │ Chain Modes: 23 │ Chain Reset Frac.: 0.225 │ Learning Rate: 0.01000
# Epoch 51/500 │ Loss: +0.0138 │ Chain Entr.: 2.515 │ Chain Modes: 23 │ Chain Reset Frac.: 0.197 │ Learning Rate: 0.01000
# Epoch 52/500 │ Loss: -0.0127 │ Chain Entr.: 2.534 │ Chain Modes: 23 │ Chain Reset Frac.: 0.225 │ Learning Rate: 0.01000
# Epoch 53/500 │ Loss: +0.0271 │ Chain Entr.: 2.498 │ Chain Modes: 23 │ Chain Reset Frac.: 0.180 │ Learning Rate: 0.01000
# Epoch 54/500 │ Loss: +0.0116 │ Chain Entr.: 2.512 │ Chain Modes: 23 │ Chain Reset Frac.: 0.175 │ Learning Rate: 0.01000
# Epoch 55/500 │ Loss: -0.0038 │ Chain Entr.: 2.530 │ Chain Modes: 23 │ Chain Reset Frac.: 0.205 │ Learning Rate: 0.01000
# Epoch 56/500 │ Loss: +0.0239 │ Chain Entr.: 2.503 │ Chain Modes: 23 │ Chain Reset Frac.: 0.172 │ Learning Rate: 0.01000
# Epoch 57/500 │ Loss: -0.0048 │ Chain Entr.: 2.519 │ Chain Modes: 23 │ Chain Reset Frac.: 0.184 │ Learning Rate: 0.01000
# Epoch 58/500 │ Loss: -0.0016 │ Chain Entr.: 2.528 │ Chain Modes: 23 │ Chain Reset Frac.: 0.202 │ Learning Rate: 0.01000
# Epoch 59/500 │ Loss: -0.0038 │ Chain Entr.: 2.530 │ Chain Modes: 23 │ Chain Reset Frac.: 0.161 │ Learning Rate: 0.01000
# Epoch 60/500 │ Loss: +0.0031 │ Chain Entr.: 2.520 │ Chain Modes: 23 │ Chain Reset Frac.: 0.190 │ Learning Rate: 0.01000
# Epoch 61/500 │ Loss: -0.0152 │ Chain Entr.: 2.534 │ Chain Modes: 23 │ Chain Reset Frac.: 0.223 │ Learning Rate: 0.01000
# Epoch 62/500 │ Loss: -0.0116 │ Chain Entr.: 2.523 │ Chain Modes: 23 │ Chain Reset Frac.: 0.202 │ Learning Rate: 0.01000
# Epoch 63/500 │ Loss: -0.0014 │ Chain Entr.: 2.518 │ Chain Modes: 23 │ Chain Reset Frac.: 0.194 │ Learning Rate: 0.01000
# Epoch 64/500 │ Loss: -0.0382 │ Chain Entr.: 2.547 │ Chain Modes: 23 │ Chain Reset Frac.: 0.183 │ Learning Rate: 0.01000
# Epoch 65/500 │ Loss: -0.0417 │ Chain Entr.: 2.531 │ Chain Modes: 23 │ Chain Reset Frac.: 0.204 │ Learning Rate: 0.01000
# Epoch 66/500 │ Loss: -0.0463 │ Chain Entr.: 2.546 │ Chain Modes: 22 │ Chain Reset Frac.: 0.210 │ Learning Rate: 0.01000
# Epoch 67/500 │ Loss: -0.0789 │ Chain Entr.: 2.550 │ Chain Modes: 22 │ Chain Reset Frac.: 0.192 │ Learning Rate: 0.01000
# Epoch 68/500 │ Loss: -0.0982 │ Chain Entr.: 2.562 │ Chain Modes: 22 │ Chain Reset Frac.: 0.208 │ Learning Rate: 0.01000
# Epoch 69/500 │ Loss: -0.1212 │ Chain Entr.: 2.563 │ Chain Modes: 22 │ Chain Reset Frac.: 0.241 │ Learning Rate: 0.01000
# Epoch 70/500 │ Loss: -0.1509 │ Chain Entr.: 2.557 │ Chain Modes: 21 │ Chain Reset Frac.: 0.217 │ Learning Rate: 0.01000
# Epoch 71/500 │ Loss: -0.1975 │ Chain Entr.: 2.555 │ Chain Modes: 21 │ Chain Reset Frac.: 0.185 │ Learning Rate: 0.01000
# Epoch 72/500 │ Loss: -0.2389 │ Chain Entr.: 2.558 │ Chain Modes: 19 │ Chain Reset Frac.: 0.187 │ Learning Rate: 0.01000
# Epoch 73/500 │ Loss: -0.3153 │ Chain Entr.: 2.567 │ Chain Modes: 19 │ Chain Reset Frac.: 0.217 │ Learning Rate: 0.01000
# Epoch 74/500 │ Loss: -0.3104 │ Chain Entr.: 2.505 │ Chain Modes: 17 │ Chain Reset Frac.: 0.172 │ Learning Rate: 0.01000
# Epoch 75/500 │ Loss: -0.3150 │ Chain Entr.: 2.458 │ Chain Modes: 16 │ Chain Reset Frac.: 0.170 │ Learning Rate: 0.01000
# Epoch 76/500 │ Loss: -0.3272 │ Chain Entr.: 2.429 │ Chain Modes: 15 │ Chain Reset Frac.: 0.143 │ Learning Rate: 0.01000
# Epoch 77/500 │ Loss: -0.3075 │ Chain Entr.: 2.374 │ Chain Modes: 14 │ Chain Reset Frac.: 0.111 │ Learning Rate: 0.01000
# Epoch 78/500 │ Loss: -0.2941 │ Chain Entr.: 2.328 │ Chain Modes: 13 │ Chain Reset Frac.: 0.103 │ Learning Rate: 0.01000
# Epoch 79/500 │ Loss: -0.2596 │ Chain Entr.: 2.290 │ Chain Modes: 13 │ Chain Reset Frac.: 0.081 │ Learning Rate: 0.01000
# Epoch 80/500 │ Loss: -0.2543 │ Chain Entr.: 2.266 │ Chain Modes: 12 │ Chain Reset Frac.: 0.073 │ Learning Rate: 0.01000
# Epoch 81/500 │ Loss: -0.2343 │ Chain Entr.: 2.250 │ Chain Modes: 12 │ Chain Reset Frac.: 0.072 │ Learning Rate: 0.01000
# Epoch 82/500 │ Loss: -0.2232 │ Chain Entr.: 2.232 │ Chain Modes: 12 │ Chain Reset Frac.: 0.063 │ Learning Rate: 0.01000
# Epoch 83/500 │ Loss: -0.1840 │ Chain Entr.: 2.198 │ Chain Modes: 11 │ Chain Reset Frac.: 0.062 │ Learning Rate: 0.01000
# Epoch 84/500 │ Loss: -0.1929 │ Chain Entr.: 2.193 │ Chain Modes: 11 │ Chain Reset Frac.: 0.058 │ Learning Rate: 0.01000
# Epoch 85/500 │ Loss: -0.1615 │ Chain Entr.: 2.170 │ Chain Modes: 11 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.01000
# Epoch 86/500 │ Loss: -0.1614 │ Chain Entr.: 2.153 │ Chain Modes: 11 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.01000
# Epoch 87/500 │ Loss: -0.1211 │ Chain Entr.: 2.137 │ Chain Modes: 10 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.01000
# Epoch 88/500 │ Loss: -0.1383 │ Chain Entr.: 2.137 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 89/500 │ Loss: -0.1355 │ Chain Entr.: 2.137 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 90/500 │ Loss: -0.1020 │ Chain Entr.: 2.111 │ Chain Modes: 10 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.01000
# Epoch 91/500 │ Loss: -0.1221 │ Chain Entr.: 2.129 │ Chain Modes: 10 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 92/500 │ Loss: -0.0874 │ Chain Entr.: 2.101 │ Chain Modes: 10 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.01000
# Epoch 93/500 │ Loss: -0.1037 │ Chain Entr.: 2.109 │ Chain Modes: 10 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.01000
# Epoch 94/500 │ Loss: -0.0967 │ Chain Entr.: 2.100 │ Chain Modes: 10 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 95/500 │ Loss: -0.0902 │ Chain Entr.: 2.095 │ Chain Modes: 9 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 96/500 │ Loss: -0.0815 │ Chain Entr.: 2.088 │ Chain Modes: 9 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 97/500 │ Loss: -0.0947 │ Chain Entr.: 2.094 │ Chain Modes: 9 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 98/500 │ Loss: -0.0698 │ Chain Entr.: 2.080 │ Chain Modes: 9 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 99/500 │ Loss: -0.0745 │ Chain Entr.: 2.076 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 100/500 │ Loss: -0.0554 │ Chain Entr.: 2.067 │ Chain Modes: 9 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00999
# Epoch 101/500 │ Loss: -0.0731 │ Chain Entr.: 2.075 │ Chain Modes: 9 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00999
# Epoch 102/500 │ Loss: -0.0679 │ Chain Entr.: 2.073 │ Chain Modes: 9 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00999
# Epoch 103/500 │ Loss: -0.0527 │ Chain Entr.: 2.067 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00999
# Epoch 104/500 │ Loss: -0.0539 │ Chain Entr.: 2.063 │ Chain Modes: 9 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00999
# Epoch 105/500 │ Loss: -0.0467 │ Chain Entr.: 2.061 │ Chain Modes: 9 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00999
# Epoch 106/500 │ Loss: -0.0569 │ Chain Entr.: 2.066 │ Chain Modes: 9 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00999
# Epoch 107/500 │ Loss: -0.0379 │ Chain Entr.: 2.053 │ Chain Modes: 9 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00999
# Epoch 108/500 │ Loss: -0.0593 │ Chain Entr.: 2.070 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00999
# Epoch 109/500 │ Loss: -0.0498 │ Chain Entr.: 2.055 │ Chain Modes: 9 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00999
# Epoch 110/500 │ Loss: -0.0448 │ Chain Entr.: 2.061 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00999
# Epoch 111/500 │ Loss: -0.0356 │ Chain Entr.: 2.045 │ Chain Modes: 9 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00999
# Epoch 112/500 │ Loss: -0.0477 │ Chain Entr.: 2.055 │ Chain Modes: 9 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00999
# Epoch 113/500 │ Loss: -0.0292 │ Chain Entr.: 2.047 │ Chain Modes: 9 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00999
# Epoch 114/500 │ Loss: -0.0452 │ Chain Entr.: 2.053 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00999
# Epoch 115/500 │ Loss: -0.0372 │ Chain Entr.: 2.043 │ Chain Modes: 9 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00999
# Epoch 116/500 │ Loss: -0.0302 │ Chain Entr.: 2.052 │ Chain Modes: 9 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00999
# Epoch 117/500 │ Loss: -0.0371 │ Chain Entr.: 2.047 │ Chain Modes: 9 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00999
# Epoch 118/500 │ Loss: -0.0386 │ Chain Entr.: 2.050 │ Chain Modes: 9 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00999
# Epoch 119/500 │ Loss: -0.0227 │ Chain Entr.: 2.035 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00999
# Epoch 120/500 │ Loss: -0.0208 │ Chain Entr.: 2.039 │ Chain Modes: 9 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00999
# Epoch 121/500 │ Loss: -0.0304 │ Chain Entr.: 2.035 │ Chain Modes: 9 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00999
# Epoch 122/500 │ Loss: -0.0375 │ Chain Entr.: 2.049 │ Chain Modes: 9 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00998
# Epoch 123/500 │ Loss: -0.0342 │ Chain Entr.: 2.046 │ Chain Modes: 9 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00998
# Epoch 124/500 │ Loss: -0.0160 │ Chain Entr.: 2.037 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00998
# Epoch 125/500 │ Loss: -0.0107 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00998
# Epoch 126/500 │ Loss: -0.0286 │ Chain Entr.: 2.047 │ Chain Modes: 9 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00998
# Epoch 127/500 │ Loss: -0.0175 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00998
# Epoch 128/500 │ Loss: -0.0240 │ Chain Entr.: 2.044 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00998
# Epoch 129/500 │ Loss: -0.0225 │ Chain Entr.: 2.041 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00998
# Epoch 130/500 │ Loss: -0.0209 │ Chain Entr.: 2.039 │ Chain Modes: 9 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00998
# Epoch 131/500 │ Loss: -0.0215 │ Chain Entr.: 2.034 │ Chain Modes: 9 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00998
# Epoch 132/500 │ Loss: -0.0143 │ Chain Entr.: 2.027 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00997
# Epoch 133/500 │ Loss: -0.0193 │ Chain Entr.: 2.032 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00997
# Epoch 134/500 │ Loss: -0.0110 │ Chain Entr.: 2.034 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00997
# Epoch 135/500 │ Loss: -0.0170 │ Chain Entr.: 2.032 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00997
# Epoch 136/500 │ Loss: -0.0156 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00997
# Epoch 137/500 │ Loss: -0.0083 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00997
# Epoch 138/500 │ Loss: -0.0187 │ Chain Entr.: 2.032 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00996
# Epoch 139/500 │ Loss: -0.0126 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00996
# Epoch 140/500 │ Loss: -0.0145 │ Chain Entr.: 2.029 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00996
# Epoch 141/500 │ Loss: -0.0193 │ Chain Entr.: 2.031 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00996
# Epoch 142/500 │ Loss: -0.0184 │ Chain Entr.: 2.032 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00996
# Epoch 143/500 │ Loss: -0.0115 │ Chain Entr.: 2.034 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00996
# Epoch 144/500 │ Loss: -0.0106 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00995
# Epoch 145/500 │ Loss: -0.0053 │ Chain Entr.: 2.026 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00995
# Epoch 146/500 │ Loss: -0.0059 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00995
# Epoch 147/500 │ Loss: -0.0162 │ Chain Entr.: 2.030 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00995
# Epoch 148/500 │ Loss: -0.0009 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00994
# Epoch 149/500 │ Loss: -0.0126 │ Chain Entr.: 2.029 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00994
# Epoch 150/500 │ Loss: -0.0098 │ Chain Entr.: 2.027 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00994
# Epoch 151/500 │ Loss: -0.0100 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00993
# Epoch 152/500 │ Loss: -0.0169 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00993
# Epoch 153/500 │ Loss: -0.0188 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00993
# Epoch 154/500 │ Loss: -0.0195 │ Chain Entr.: 2.027 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00992
# Epoch 155/500 │ Loss: -0.0048 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00992
# Epoch 156/500 │ Loss: -0.0102 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00991
# Epoch 157/500 │ Loss: -0.0025 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00991
# Epoch 158/500 │ Loss: -0.0049 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00991
# Epoch 159/500 │ Loss: -0.0096 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00990
# Epoch 160/500 │ Loss: -0.0049 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00990
# Epoch 161/500 │ Loss: -0.0085 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00989
# Epoch 162/500 │ Loss: -0.0047 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00988
# Epoch 163/500 │ Loss: -0.0149 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00988
# Epoch 164/500 │ Loss: -0.0063 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00987
# Epoch 165/500 │ Loss: -0.0168 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00987
# Epoch 166/500 │ Loss: +0.0007 │ Chain Entr.: 2.013 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00986
# Epoch 167/500 │ Loss: -0.0062 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00985
# Epoch 168/500 │ Loss: -0.0095 │ Chain Entr.: 2.013 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00985
# Epoch 169/500 │ Loss: -0.0076 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00984
# Epoch 170/500 │ Loss: -0.0072 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00983
# Epoch 171/500 │ Loss: -0.0045 │ Chain Entr.: 2.012 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00982
# Epoch 172/500 │ Loss: -0.0053 │ Chain Entr.: 2.013 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00981
# Epoch 173/500 │ Loss: +0.0026 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00980
# Epoch 174/500 │ Loss: +0.0000 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00979
# Epoch 175/500 │ Loss: -0.0097 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00978
# Epoch 176/500 │ Loss: -0.0067 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00977
# Epoch 177/500 │ Loss: +0.0081 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00976
# Epoch 178/500 │ Loss: -0.0147 │ Chain Entr.: 2.012 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00975
# Epoch 179/500 │ Loss: -0.0013 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00973
# Epoch 180/500 │ Loss: -0.0034 │ Chain Entr.: 2.012 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00972
# Epoch 181/500 │ Loss: -0.0063 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00971
# Epoch 182/500 │ Loss: +0.0048 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00969
# Epoch 183/500 │ Loss: -0.0011 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00968
# Epoch 184/500 │ Loss: -0.0035 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00966
# Epoch 185/500 │ Loss: -0.0026 │ Chain Entr.: 2.001 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00965
# Epoch 186/500 │ Loss: +0.0035 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00963
# Epoch 187/500 │ Loss: +0.0038 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00961
# Epoch 188/500 │ Loss: +0.0041 │ Chain Entr.: 1.998 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00959
# Epoch 189/500 │ Loss: -0.0013 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00957
# Epoch 190/500 │ Loss: +0.0078 │ Chain Entr.: 2.001 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00955
# Epoch 191/500 │ Loss: -0.0020 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00953
# Epoch 192/500 │ Loss: -0.0049 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00950
# Epoch 193/500 │ Loss: -0.0010 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00948
# Epoch 194/500 │ Loss: -0.0039 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00946
# Epoch 195/500 │ Loss: -0.0085 │ Chain Entr.: 2.000 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00943
# Epoch 196/500 │ Loss: -0.0045 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00940
# Epoch 197/500 │ Loss: -0.0029 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00937
# Epoch 198/500 │ Loss: -0.0016 │ Chain Entr.: 2.001 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00934
# Epoch 199/500 │ Loss: -0.0017 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00931
# Epoch 200/500 │ Loss: -0.0034 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00928
# Epoch 201/500 │ Loss: -0.0016 │ Chain Entr.: 1.998 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00925
# Epoch 202/500 │ Loss: +0.0007 │ Chain Entr.: 1.997 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00921
# Epoch 203/500 │ Loss: -0.0053 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00917
# Epoch 204/500 │ Loss: +0.0004 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00913
# Epoch 205/500 │ Loss: -0.0063 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00909
# Epoch 206/500 │ Loss: +0.0077 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00905
# Epoch 207/500 │ Loss: -0.0030 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00901
# Epoch 208/500 │ Loss: -0.0039 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00896
# Epoch 209/500 │ Loss: +0.0030 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00892
# Epoch 210/500 │ Loss: -0.0017 │ Chain Entr.: 2.001 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00887
# Epoch 211/500 │ Loss: +0.0048 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00882
# Epoch 212/500 │ Loss: +0.0026 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00876
# Epoch 213/500 │ Loss: -0.0076 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00871
# Epoch 214/500 │ Loss: -0.0028 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00865
# Epoch 215/500 │ Loss: -0.0010 │ Chain Entr.: 1.997 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00859
# Epoch 216/500 │ Loss: -0.0028 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00853
# Epoch 217/500 │ Loss: -0.0051 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00847
# Epoch 218/500 │ Loss: -0.0029 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00840
# Epoch 219/500 │ Loss: -0.0043 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00834
# Epoch 220/500 │ Loss: -0.0005 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00827
# Epoch 221/500 │ Loss: -0.0043 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00819
# Epoch 222/500 │ Loss: +0.0036 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00812
# Epoch 223/500 │ Loss: -0.0052 │ Chain Entr.: 2.000 │ Chain Modes: 8 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.00804
# Epoch 224/500 │ Loss: +0.0071 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00797
# Epoch 225/500 │ Loss: -0.0016 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00788
# Epoch 226/500 │ Loss: -0.0071 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00780
# Epoch 227/500 │ Loss: +0.0045 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00772
# Epoch 228/500 │ Loss: -0.0036 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00763
# Epoch 229/500 │ Loss: +0.0024 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00754
# Epoch 230/500 │ Loss: -0.0063 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00745
# Epoch 231/500 │ Loss: -0.0039 │ Chain Entr.: 1.998 │ Chain Modes: 8 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.00735
# Epoch 232/500 │ Loss: +0.0051 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00725
# Epoch 233/500 │ Loss: -0.0029 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00716
# Epoch 234/500 │ Loss: -0.0043 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.057 │ Learning Rate: 0.00705
# Epoch 235/500 │ Loss: +0.0005 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00695
# Epoch 236/500 │ Loss: -0.0048 │ Chain Entr.: 1.997 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00685
# Epoch 237/500 │ Loss: -0.0052 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00674
# Epoch 238/500 │ Loss: -0.0020 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.00663
# Epoch 239/500 │ Loss: -0.0047 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00652
# Epoch 240/500 │ Loss: -0.0026 │ Chain Entr.: 1.977 │ Chain Modes: 8 │ Chain Reset Frac.: 0.062 │ Learning Rate: 0.00641
# Epoch 241/500 │ Loss: -0.0067 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00630
# Epoch 242/500 │ Loss: -0.0051 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00619
# Epoch 243/500 │ Loss: +0.0012 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00607
# Epoch 244/500 │ Loss: -0.0062 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00596
# Epoch 245/500 │ Loss: -0.0141 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00584
# Epoch 246/500 │ Loss: -0.0032 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00572
# Epoch 247/500 │ Loss: -0.0124 │ Chain Entr.: 2.001 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00561
# Epoch 248/500 │ Loss: -0.0115 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.00549
# Epoch 249/500 │ Loss: -0.0059 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00537
# Epoch 250/500 │ Loss: +0.0018 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00525
# Epoch 251/500 │ Loss: -0.0009 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00513
# Epoch 252/500 │ Loss: -0.0048 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00501
# Epoch 253/500 │ Loss: -0.0069 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00489
# Epoch 254/500 │ Loss: +0.0031 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00478
# Epoch 255/500 │ Loss: -0.0029 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00466
# Epoch 256/500 │ Loss: -0.0047 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00454
# Epoch 257/500 │ Loss: -0.0043 │ Chain Entr.: 1.976 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00443
# Epoch 258/500 │ Loss: -0.0063 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.058 │ Learning Rate: 0.00431
# Epoch 259/500 │ Loss: +0.0022 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00420
# Epoch 260/500 │ Loss: +0.0003 │ Chain Entr.: 1.976 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00409
# Epoch 261/500 │ Loss: -0.0022 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00398
# Epoch 262/500 │ Loss: -0.0098 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00387
# Epoch 263/500 │ Loss: -0.0071 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00376
# Epoch 264/500 │ Loss: -0.0069 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00365
# Epoch 265/500 │ Loss: -0.0048 │ Chain Entr.: 1.978 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00355
# Epoch 266/500 │ Loss: +0.0011 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00345
# Epoch 267/500 │ Loss: -0.0053 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00334
# Epoch 268/500 │ Loss: -0.0099 │ Chain Entr.: 1.997 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00325
# Epoch 269/500 │ Loss: -0.0118 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00315
# Epoch 270/500 │ Loss: -0.0076 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.060 │ Learning Rate: 0.00305
# Epoch 271/500 │ Loss: -0.0051 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00296
# Epoch 272/500 │ Loss: -0.0059 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00287
# Epoch 273/500 │ Loss: -0.0048 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00278
# Epoch 274/500 │ Loss: -0.0010 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00270
# Epoch 275/500 │ Loss: -0.0043 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00262
# Epoch 276/500 │ Loss: -0.0121 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00253
# Epoch 277/500 │ Loss: -0.0114 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00246
# Epoch 278/500 │ Loss: -0.0048 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00238
# Epoch 279/500 │ Loss: -0.0060 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00231
# Epoch 280/500 │ Loss: -0.0048 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.055 │ Learning Rate: 0.00223
# Epoch 281/500 │ Loss: -0.0013 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00216
# Epoch 282/500 │ Loss: -0.0133 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00210
# Epoch 283/500 │ Loss: -0.0068 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00203
# Epoch 284/500 │ Loss: -0.0108 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00197
# Epoch 285/500 │ Loss: +0.0064 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00191
# Epoch 286/500 │ Loss: -0.0039 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00185
# Epoch 287/500 │ Loss: -0.0068 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00179
# Epoch 288/500 │ Loss: -0.0091 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00174
# Epoch 289/500 │ Loss: -0.0097 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.00168
# Epoch 290/500 │ Loss: -0.0065 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00163
# Epoch 291/500 │ Loss: -0.0048 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00158
# Epoch 292/500 │ Loss: -0.0065 │ Chain Entr.: 1.978 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.00154
# Epoch 293/500 │ Loss: -0.0090 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00149
# Epoch 294/500 │ Loss: -0.0080 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00145
# Epoch 295/500 │ Loss: -0.0030 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00141
# Epoch 296/500 │ Loss: -0.0049 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00137
# Epoch 297/500 │ Loss: -0.0061 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00133
# Epoch 298/500 │ Loss: -0.0101 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00129
# Epoch 299/500 │ Loss: -0.0124 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00125
# Epoch 300/500 │ Loss: -0.0083 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.00122
# Epoch 301/500 │ Loss: -0.0084 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.055 │ Learning Rate: 0.00119
# Epoch 302/500 │ Loss: -0.0053 │ Chain Entr.: 1.976 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00116
# Epoch 303/500 │ Loss: -0.0074 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00113
# Epoch 304/500 │ Loss: -0.0126 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.00110
# Epoch 305/500 │ Loss: -0.0128 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00107
# Epoch 306/500 │ Loss: -0.0104 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00104
# Epoch 307/500 │ Loss: -0.0131 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.00102
# Epoch 308/500 │ Loss: -0.0088 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00100
# Epoch 309/500 │ Loss: -0.0102 │ Chain Entr.: 1.979 │ Chain Modes: 8 │ Chain Reset Frac.: 0.061 │ Learning Rate: 0.00097
# Epoch 310/500 │ Loss: -0.0065 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00095
# Epoch 311/500 │ Loss: -0.0135 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00093
# Epoch 312/500 │ Loss: -0.0058 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00091
# Epoch 313/500 │ Loss: -0.0142 │ Chain Entr.: 1.998 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00089
# Epoch 314/500 │ Loss: -0.0143 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00087
# Epoch 315/500 │ Loss: -0.0050 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00085
# Epoch 316/500 │ Loss: -0.0092 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00084
# Epoch 317/500 │ Loss: -0.0108 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00082
# Epoch 318/500 │ Loss: -0.0086 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00081
# Epoch 319/500 │ Loss: -0.0128 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00079
# Epoch 320/500 │ Loss: -0.0113 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00078
# Epoch 321/500 │ Loss: -0.0088 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00077
# Epoch 322/500 │ Loss: -0.0103 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00075
# Epoch 323/500 │ Loss: -0.0114 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.061 │ Learning Rate: 0.00074
# Epoch 324/500 │ Loss: -0.0143 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.058 │ Learning Rate: 0.00073
# Epoch 325/500 │ Loss: -0.0070 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00072
# Epoch 326/500 │ Loss: -0.0157 │ Chain Entr.: 1.998 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00071
# Epoch 327/500 │ Loss: -0.0047 │ Chain Entr.: 1.979 │ Chain Modes: 8 │ Chain Reset Frac.: 0.057 │ Learning Rate: 0.00070
# Epoch 328/500 │ Loss: -0.0096 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00069
# Epoch 329/500 │ Loss: -0.0035 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00068
# Epoch 330/500 │ Loss: -0.0061 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00067
# Epoch 331/500 │ Loss: -0.0090 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00066
# Epoch 332/500 │ Loss: -0.0145 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00065
# Epoch 333/500 │ Loss: -0.0045 │ Chain Entr.: 1.980 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00065
# Epoch 334/500 │ Loss: -0.0143 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00064
# Epoch 335/500 │ Loss: -0.0091 │ Chain Entr.: 1.980 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00063
# Epoch 336/500 │ Loss: -0.0093 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00063
# Epoch 337/500 │ Loss: -0.0077 │ Chain Entr.: 1.979 │ Chain Modes: 8 │ Chain Reset Frac.: 0.062 │ Learning Rate: 0.00062
# Epoch 338/500 │ Loss: -0.0113 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.055 │ Learning Rate: 0.00062
# Epoch 339/500 │ Loss: -0.0057 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00061
# Epoch 340/500 │ Loss: -0.0151 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00060
# Epoch 341/500 │ Loss: -0.0169 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00060
# Epoch 342/500 │ Loss: -0.0121 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00059
# Epoch 343/500 │ Loss: -0.0093 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00059
# Epoch 344/500 │ Loss: -0.0078 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.054 │ Learning Rate: 0.00059
# Epoch 345/500 │ Loss: -0.0105 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00058
# Epoch 346/500 │ Loss: -0.0032 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00058
# Epoch 347/500 │ Loss: -0.0139 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00057
# Epoch 348/500 │ Loss: -0.0055 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00057
# Epoch 349/500 │ Loss: -0.0092 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00057
# Epoch 350/500 │ Loss: -0.0118 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00056
# Epoch 351/500 │ Loss: -0.0054 │ Chain Entr.: 1.978 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00056
# Epoch 352/500 │ Loss: -0.0160 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00056
# Epoch 353/500 │ Loss: -0.0108 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.057 │ Learning Rate: 0.00055
# Epoch 354/500 │ Loss: -0.0104 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00055
# Epoch 355/500 │ Loss: -0.0068 │ Chain Entr.: 1.980 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00055
# Epoch 356/500 │ Loss: -0.0077 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.054 │ Learning Rate: 0.00055
# Epoch 357/500 │ Loss: -0.0121 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00054
# Epoch 358/500 │ Loss: -0.0128 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00054
# Epoch 359/500 │ Loss: -0.0102 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00054
# Epoch 360/500 │ Loss: -0.0046 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00054
# Epoch 361/500 │ Loss: -0.0113 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00054
# Epoch 362/500 │ Loss: -0.0056 │ Chain Entr.: 1.977 │ Chain Modes: 8 │ Chain Reset Frac.: 0.055 │ Learning Rate: 0.00054
# Epoch 363/500 │ Loss: -0.0112 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00053
# Epoch 364/500 │ Loss: -0.0110 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.054 │ Learning Rate: 0.00053
# Epoch 365/500 │ Loss: -0.0075 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00053
# Epoch 366/500 │ Loss: -0.0103 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00053
# Epoch 367/500 │ Loss: -0.0086 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00053
# Epoch 368/500 │ Loss: -0.0120 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00053
# Epoch 369/500 │ Loss: -0.0162 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00052
# Epoch 370/500 │ Loss: -0.0028 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00052
# Epoch 371/500 │ Loss: -0.0099 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00052
# Epoch 372/500 │ Loss: -0.0053 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00052
# Epoch 373/500 │ Loss: -0.0090 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00052
# Epoch 374/500 │ Loss: -0.0049 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00052
# Epoch 375/500 │ Loss: -0.0080 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.057 │ Learning Rate: 0.00052
# Epoch 376/500 │ Loss: -0.0092 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00052
# Epoch 377/500 │ Loss: -0.0127 │ Chain Entr.: 1.979 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00052
# Epoch 378/500 │ Loss: -0.0137 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00052
# Epoch 379/500 │ Loss: -0.0022 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00051
# Epoch 380/500 │ Loss: -0.0095 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00051
# Epoch 381/500 │ Loss: -0.0115 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00051
# Epoch 382/500 │ Loss: -0.0074 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00051
# Epoch 383/500 │ Loss: -0.0144 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00051
# Epoch 384/500 │ Loss: -0.0061 │ Chain Entr.: 1.978 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00051
# Epoch 385/500 │ Loss: -0.0053 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00051
# Epoch 386/500 │ Loss: -0.0024 │ Chain Entr.: 1.974 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.00051
# Epoch 387/500 │ Loss: -0.0149 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00051
# Epoch 388/500 │ Loss: -0.0133 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00051
# Epoch 389/500 │ Loss: -0.0072 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00051
# Epoch 390/500 │ Loss: -0.0081 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00051
# Epoch 391/500 │ Loss: -0.0067 │ Chain Entr.: 1.975 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00051
# Epoch 392/500 │ Loss: -0.0140 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.055 │ Learning Rate: 0.00051
# Epoch 393/500 │ Loss: -0.0119 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00051
# Epoch 394/500 │ Loss: -0.0083 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00051
# Epoch 395/500 │ Loss: -0.0129 │ Chain Entr.: 1.980 │ Chain Modes: 8 │ Chain Reset Frac.: 0.057 │ Learning Rate: 0.00051
# Epoch 396/500 │ Loss: -0.0076 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00051
# Epoch 397/500 │ Loss: -0.0149 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00051
# Epoch 398/500 │ Loss: -0.0084 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00051
# Epoch 399/500 │ Loss: -0.0047 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00051
# Epoch 400/500 │ Loss: -0.0050 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00051
# Epoch 401/500 │ Loss: -0.0106 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00050
# Epoch 402/500 │ Loss: -0.0023 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00050
# Epoch 403/500 │ Loss: -0.0056 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.00050
# Epoch 404/500 │ Loss: -0.0105 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00050
# Epoch 405/500 │ Loss: -0.0104 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00050
# Epoch 406/500 │ Loss: -0.0075 │ Chain Entr.: 1.976 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00050
# Epoch 407/500 │ Loss: -0.0119 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00050
# Epoch 408/500 │ Loss: -0.0066 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00050
# Epoch 409/500 │ Loss: -0.0086 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00050
# Epoch 410/500 │ Loss: -0.0125 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00050
# Epoch 411/500 │ Loss: -0.0136 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00050
# Epoch 412/500 │ Loss: -0.0082 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00050
# Epoch 413/500 │ Loss: -0.0079 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00050
# Epoch 414/500 │ Loss: -0.0116 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.00050
# Epoch 415/500 │ Loss: -0.0128 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00050
# Epoch 416/500 │ Loss: -0.0150 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00050
# Epoch 417/500 │ Loss: -0.0096 │ Chain Entr.: 1.980 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00050
# Epoch 418/500 │ Loss: -0.0119 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00050
# Epoch 419/500 │ Loss: -0.0094 │ Chain Entr.: 1.979 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00050
# Epoch 420/500 │ Loss: -0.0064 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00050
# Epoch 421/500 │ Loss: -0.0181 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00050
# Epoch 422/500 │ Loss: -0.0051 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00050
# Epoch 423/500 │ Loss: -0.0088 │ Chain Entr.: 1.977 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.00050
# Epoch 424/500 │ Loss: -0.0029 │ Chain Entr.: 1.978 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00050
# Epoch 425/500 │ Loss: -0.0104 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00050
# Epoch 426/500 │ Loss: -0.0087 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00050
# Epoch 427/500 │ Loss: -0.0112 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.066 │ Learning Rate: 0.00050
# Epoch 428/500 │ Loss: -0.0096 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00050
# Epoch 429/500 │ Loss: -0.0066 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00050
# Epoch 430/500 │ Loss: -0.0120 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00050
# Epoch 431/500 │ Loss: -0.0083 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00050
# Epoch 432/500 │ Loss: -0.0192 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00050
# Epoch 433/500 │ Loss: -0.0149 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00050
# Epoch 434/500 │ Loss: -0.0101 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00050
# Epoch 435/500 │ Loss: -0.0078 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00050
# Epoch 436/500 │ Loss: -0.0081 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00050
# Epoch 437/500 │ Loss: -0.0192 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00050
# Epoch 438/500 │ Loss: -0.0106 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.00050
# Epoch 439/500 │ Loss: -0.0086 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00050
# Epoch 440/500 │ Loss: -0.0134 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00050
# Epoch 441/500 │ Loss: -0.0129 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00050
# Epoch 442/500 │ Loss: -0.0054 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00050
# Epoch 443/500 │ Loss: -0.0094 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.055 │ Learning Rate: 0.00050
# Epoch 444/500 │ Loss: -0.0115 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00050
# Epoch 445/500 │ Loss: -0.0109 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00050
# Epoch 446/500 │ Loss: -0.0149 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00050
# Epoch 447/500 │ Loss: -0.0085 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00050
# Epoch 448/500 │ Loss: -0.0091 │ Chain Entr.: 1.979 │ Chain Modes: 8 │ Chain Reset Frac.: 0.055 │ Learning Rate: 0.00050
# Epoch 449/500 │ Loss: -0.0095 │ Chain Entr.: 1.980 │ Chain Modes: 8 │ Chain Reset Frac.: 0.071 │ Learning Rate: 0.00050
# Epoch 450/500 │ Loss: -0.0080 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.062 │ Learning Rate: 0.00050
# Epoch 451/500 │ Loss: -0.0117 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00050
# Epoch 452/500 │ Loss: -0.0104 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00050
# Epoch 453/500 │ Loss: -0.0043 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00050
# Epoch 454/500 │ Loss: -0.0107 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00050
# Epoch 455/500 │ Loss: -0.0115 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.00050
# Epoch 456/500 │ Loss: -0.0076 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00050
# Epoch 457/500 │ Loss: -0.0082 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00050
# Epoch 458/500 │ Loss: -0.0103 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.00050
# Epoch 459/500 │ Loss: -0.0097 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.059 │ Learning Rate: 0.00050
# Epoch 460/500 │ Loss: -0.0050 │ Chain Entr.: 1.976 │ Chain Modes: 8 │ Chain Reset Frac.: 0.055 │ Learning Rate: 0.00050
# Epoch 461/500 │ Loss: -0.0115 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00050
# Epoch 462/500 │ Loss: -0.0098 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00050
# Epoch 463/500 │ Loss: -0.0057 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.00050
# Epoch 464/500 │ Loss: -0.0183 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00050
# Epoch 465/500 │ Loss: -0.0026 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00050
# Epoch 466/500 │ Loss: -0.0104 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00050
# Epoch 467/500 │ Loss: -0.0115 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00050
# Epoch 468/500 │ Loss: -0.0041 │ Chain Entr.: 1.976 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.00050
# Epoch 469/500 │ Loss: -0.0133 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.00050
# Epoch 470/500 │ Loss: -0.0177 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00050
# Epoch 471/500 │ Loss: -0.0141 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00050
# Epoch 472/500 │ Loss: -0.0069 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00050
# Epoch 473/500 │ Loss: -0.0030 │ Chain Entr.: 1.980 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00050
# Epoch 474/500 │ Loss: -0.0125 │ Chain Entr.: 1.984 │ Chain Modes: 8 │ Chain Reset Frac.: 0.054 │ Learning Rate: 0.00050
# Epoch 475/500 │ Loss: -0.0100 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.00050
# Epoch 476/500 │ Loss: -0.0088 │ Chain Entr.: 1.976 │ Chain Modes: 8 │ Chain Reset Frac.: 0.057 │ Learning Rate: 0.00050
# Epoch 477/500 │ Loss: -0.0062 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.00050
# Epoch 478/500 │ Loss: -0.0083 │ Chain Entr.: 1.978 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00050
# Epoch 479/500 │ Loss: -0.0094 │ Chain Entr.: 1.979 │ Chain Modes: 8 │ Chain Reset Frac.: 0.059 │ Learning Rate: 0.00050
# Epoch 480/500 │ Loss: -0.0114 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00050
# Epoch 481/500 │ Loss: -0.0049 │ Chain Entr.: 1.986 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00050
# Epoch 482/500 │ Loss: -0.0092 │ Chain Entr.: 1.977 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00050
# Epoch 483/500 │ Loss: -0.0126 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00050
# Epoch 484/500 │ Loss: -0.0113 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.054 │ Learning Rate: 0.00050
# Epoch 485/500 │ Loss: -0.0136 │ Chain Entr.: 1.979 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00050
# Epoch 486/500 │ Loss: -0.0125 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.00050
# Epoch 487/500 │ Loss: -0.0071 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00050
# Epoch 488/500 │ Loss: -0.0054 │ Chain Entr.: 1.971 │ Chain Modes: 8 │ Chain Reset Frac.: 0.058 │ Learning Rate: 0.00050
# Epoch 489/500 │ Loss: -0.0057 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.00050
# Epoch 490/500 │ Loss: -0.0144 │ Chain Entr.: 1.982 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00050
# Epoch 491/500 │ Loss: -0.0059 │ Chain Entr.: 1.979 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.00050
# Epoch 492/500 │ Loss: -0.0176 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.00050
# Epoch 493/500 │ Loss: -0.0117 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00050
# Epoch 494/500 │ Loss: -0.0135 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.00050
# Epoch 495/500 │ Loss: -0.0114 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00050
# Epoch 496/500 │ Loss: -0.0112 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00050
# Epoch 497/500 │ Loss: -0.0120 │ Chain Entr.: 1.983 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.00050
# Epoch 498/500 │ Loss: -0.0085 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.00050
# Epoch 499/500 │ Loss: -0.0055 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.00050
# Epoch 500/500 │ Loss: -0.0140 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00050
# CPU times: user 3min 27s, sys: 1.85 s, total: 3min 29s
# Wall time: 3min 29s

# %%
epochs = list(metrics_amp.keys())
loss_vals = [metrics_amp[e]['loss'] for e in epochs]
entropy_vals = [metrics_amp[e]['entropy_chain'] for e in epochs]
mode_vals = [metrics_amp[e]['modes_chain'] for e in epochs]
lr_vals = [metrics_amp[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots()

ax1.plot(epochs, loss_vals, label="Amplitude CD Loss", color="tab:blue")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Amplitude CD Loss", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

ax2 = ax1.twinx()
ax2.plot(epochs, entropy_vals, label="Chain Entropy", color="tab:orange")
ax2.set_ylabel("Chain Entropy", color="tab:orange")
ax2.tick_params(axis="y", labelcolor="tab:orange")

ax3 = ax1.twinx()
ax3.spines["right"].set_position(("axes", 1.2))
ax3.plot(epochs, mode_vals, label="Estimated Mode Count", color="tab:green")
ax3.set_ylabel("Mode Count", color="tab:green")
ax3.tick_params(axis="y", labelcolor="tab:green")

ax4 = ax1.twinx()
ax4.spines["right"].set_position(("axes", 1.4))
ax4.plot(epochs, lr_vals, label="Learning Rate", color="tab:red")
ax4.set_ylabel("Learning Rate", color="tab:red")
ax4.tick_params(axis="y", labelcolor="tab:red")

plt.title("CD Loss vs. Entropy vs. Mode Count vs. Learning Rate")
plt.show()

# %%
# shifting the center step to 0 we can approximate an exponential schedule if we choose the high to be
T_high = 2.0
T_low = 0.01
sampling_steps = 10000
sigmoid_schedule_fn = get_sigmoid_curve(high=T_high*2, low=T_low, steps=sampling_steps, falloff=0.0013, center_step=0)
sigmoid_schedule = jnp.array([sigmoid_schedule_fn(i) for i in range(sampling_steps)], dtype=jnp.float32)

key_sample = PRNGKey(1234)

samples_amp = model_amp.apply(
    {"params": state_amp.params},
    n_samples=10_000,
    T_schedule=sigmoid_schedule,
    key=key_sample,
    method=RBM.generate
)

sampled_freq_amp = samples_amp.mean(0)
sampled_freq_amp
# Out:
# Array([0.1157    , 0.11809999, 0.1312    , 0.0982    , 0.1321    ,
#        0.11      , 0.1671    , 0.1276    ], dtype=float32)

# %%
spin_counts = samples_amp.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(12), align='left', edgecolor='black')
plt.xticks(range(11))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
plt.figure(figsize=(10, 5))
x = np.arange(visible_units) + 1
width = 0.35

plt.bar(x - width/2, empirical_freq_amp, width, label="Empirical", alpha=0.7)
plt.bar(x + width/2, sampled_freq_amp, width, label="Sampled", alpha=0.7)

plt.axhline(1 / visible_units, linestyle='--', color='gray', label=f'1/{visible_units} reference')
plt.xlabel("Visible Unit Index")
plt.ylabel("Mean Activation Frequency")
plt.title("Comparison: Empirical vs Sampled Frequencies")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
timestamp = datetime.now().strftime("%Y%m%d%H%M")
model_name = f"rbm_amp_{timestamp}"

checkpoints.save_checkpoint(
    ckpt_dir=str(model_dir.resolve()),
    target=state_amp.params,
    step=0,
    prefix=model_name + "_",
    overwrite=True
)
# Out:
# WARNING:absl:The `aggregate` option is deprecated and will be ignored.
# '/Users/Tonni/Desktop/master-code/neural-quantum-tomo/case_studies/w_aug_v2/models/rbm_amp_202506110124_0'
