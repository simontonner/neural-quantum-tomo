# %%
# %reload_ext autoreload
# %autoreload 2

from lib.data_loading import load_measurements, MultiBasisDataLoader

####

import re
from pathlib import Path
from typing import Optional, Tuple, Dict, Any, Sequence
from datetime import datetime

import numpy as np

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import optax
from flax.training.train_state import TrainState
from flax.training import checkpoints
from flax import linen as nn

import matplotlib.pyplot as plt


data_dir = "data"
model_dir = Path("./models")
model_dir.mkdir(parents=True, exist_ok=True)

print(f"Data resides in        : {data_dir}")
print(f"Model will be saved to : {model_dir}")
# Out:
# WARNING:absl:Tensorflow library not found, tensorflow.io.gfile operations will use native shim calls. GCS paths (i.e. 'gs://...') cannot be accessed.
# Data resides in        : data
# Model will be saved to : models

# %%
class RBM(nn.Module):
    n_visible: int
    n_hidden: int
    k: int = 1          # bound to class instance to make whole gibbs chain compilable
    T: float = 1.0      # bound to class instance to make single gibbs step compilable

    def setup(self):
        self.W = self.param("W", nn.initializers.normal(0.01), (self.n_visible, self.n_hidden))
        self.b = self.param("b", nn.initializers.zeros, (self.n_visible,))
        self.c = self.param("c", nn.initializers.zeros, (self.n_hidden,))

    def __call__(self, data: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W, self.b, self.c, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (aux_vars["gibbs_chain"], aux_vars["key"]))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain) # cut off gradients after Gibbs sampling

        loss = jnp.mean(self._free_energy(data)) - jnp.mean(self._free_energy(gibbs_chain))
        return loss, {"gibbs_chain": gibbs_chain, "key": key}

    def _free_energy(self, v):
        return -(v @ self.b) - jnp.sum(jax.nn.softplus(v @ self.W + self.c), -1)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c)/T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b)/T)).astype(jnp.float32)
        return v, key

    @nn.nowrap
    def generate(self, n_samples: int, T_schedule: jnp.ndarray, key: PRNGKey) -> jnp.ndarray:
        key, key_init = jax.random.split(key, 2)
        v = jax.random.bernoulli(key_init, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)

        anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, (v, key))
        return v_final

# %%
@jax.jit
def train_step_amp(
        state: TrainState,
        batch: jnp.ndarray,
        gibbs_chain: jnp.ndarray,
        key: PRNGKey,
        chain_reset_frac: float) -> Tuple[TrainState, jnp.ndarray, jnp.ndarray, PRNGKey]:

    key, key_reset, key_sample = jax.random.split(key, 3)

    # Reset mask: which chains to replace
    reset_mask = jax.random.bernoulli(key_reset, p=chain_reset_frac, shape=(batch_size, 1))

    # Sample from batch — shape (batch_size,)
    sample_idxs = jax.random.randint(key_sample, shape=(batch_size,), minval=0, maxval=batch.shape[0])
    sampled_onehots = batch[sample_idxs]  # shape (batch_size, n_visible)

    # Replace according to mask
    reset_chain = jnp.where(reset_mask, sampled_onehots, gibbs_chain)


    aux_vars = {"gibbs_chain": reset_chain, "key": key}
    loss_fn = lambda params: state.apply_fn({'params': params}, batch, aux_vars)
    (loss, aux_vars), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    state = state.apply_gradients(grads=grads)

    return state, loss, aux_vars["gibbs_chain"], aux_vars["key"]


def entropy_modes(chain: jnp.ndarray) -> Tuple[float, int]:
    # translate each binary pattern to a unique integer
    chain = chain.astype(jnp.uint32)
    powers = 2 ** jnp.arange(chain.shape[-1], dtype=jnp.uint32)
    ints = jnp.dot(chain, powers)

    hist = jnp.bincount(ints, length=1 << chain.shape[-1]).astype(jnp.float32)
    probs = hist / jnp.sum(hist)
    entropy = -jnp.sum(jnp.where(probs > 0, probs * jnp.log(probs), 0.0)) # shannon entropy with guard against prob <=0
    mode_count = jnp.sum(hist > 0)
    return float(entropy), int(mode_count)


def train_amp_rbm(
        state: TrainState,
        loader: MultiBasisDataLoader,
        gibbs_chain: jnp.ndarray,
        num_epochs: int,
        key: PRNGKey,
        chain_reset_frac_min: float = 0.02,
        chain_reset_frac_max: float = 0.30,
        chain_reset_ema_alpha: float = 0.9) -> Tuple[TrainState, Dict[int, float]]:

    print("Precalculating target entropy from data.")
    all_data = []

    for base_batches, _ in loader:
        all_data.append(base_batches[0])  # shape: (batch_size, n_visible)

    all_data = jnp.concatenate(all_data, axis=0)
    entropy_target, _ = entropy_modes(all_data)

    chain_reset_frac_ema = 0.0
    metrics = {}
    for epoch in range(num_epochs):
        tot_loss = tot_entropy_chain = tot_modes_chain = 0.0
        batches = 0

        for base_batches, bases in loader:
            if base_batches.shape[0] != 1 or bases.shape[0] != 1:
                raise ValueError(f"Expected exactly one basis, got: {base_batches.shape[0]} bases")

            if not jnp.all(bases[0] == 0):
                raise ValueError(f"Only Z basis supported for amplitude RBM")

            batch = base_batches[0]

            entropy_chain, modes_chain = entropy_modes(gibbs_chain)
            chain_reset_frac_raw = jnp.abs(jnp.log(entropy_chain/entropy_target + 1e-12))  # tiny eps for stability
            chain_reset_frac_ema = chain_reset_frac_ema * chain_reset_ema_alpha + (1 - chain_reset_ema_alpha) * chain_reset_frac_raw
            chain_reset_frac = float(jnp.clip(chain_reset_frac_ema, chain_reset_frac_min, chain_reset_frac_max))

            state, loss, gibbs_chain, key = train_step_amp(state, batch, gibbs_chain, key, chain_reset_frac)

            tot_loss += float(loss)
            tot_entropy_chain += float(entropy_chain)
            tot_modes_chain += float(modes_chain)
            batches += 1

        avg_loss = tot_loss / batches
        avg_entropy_chain = tot_entropy_chain / batches
        avg_modes_chain = tot_modes_chain / batches
        lr = float(lr_schedule(state.opt_state[0].count))

        metrics[epoch] = dict(
            loss=avg_loss,
            entropy_chain=avg_entropy_chain,
            modes_chain=avg_modes_chain,
            lr=lr
        )

        print(f"Epoch {epoch+1}/{num_epochs} │ "
              f"Loss: {avg_loss:+.4f} │ "
              f"Chain Entr.: {avg_entropy_chain:.3f} │ "
              f"Chain Modes: {avg_modes_chain:.0f} │ "
              f"Chain Reset Frac.: {chain_reset_frac:.3f} │ "
              f"Learning Rate: {lr:.5f}")

    return state, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2

    curve_fn = lambda step: low + (high - low) / (1 + jnp.exp(falloff * (jnp.minimum(step, steps) - center_step)))
    return curve_fn

# %%
#### LOADING DATA IN Z BASIS ####

data_dict_amp = load_measurements(data_dir, "w_*.txt")

keys_amp = [k for k in data_dict_amp if re.fullmatch(r"^Z+$", k)]
dict_amp = {k: data_dict_amp[k] for k in keys_amp}

empirical_freq_amp = jnp.zeros(next(iter(dict_amp.values())).shape[1])
num_total = 0

for arr in dict_amp.values():
    empirical_freq_amp += jnp.sum(arr, axis=0)
    num_total += arr.shape[0]

empirical_freq_amp /= num_total
empirical_freq_amp
# Out:
# Array([0.1265625 , 0.1221875 , 0.1275    , 0.12375   , 0.13      ,
#        0.12859374, 0.11953125, 0.121875  ], dtype=float32)

# %%
batch_size      = 64        #                                               DONE
visible_units   = 8         #                                               DONE
hidden_units    = 16        # totally sufficient to capture all modes       DONE
k_steps         = 400       # higher is generally better                    GOOD FOR NOW
init_lr         = 1e-2      #                                               DONE
final_lr        = init_lr * 0.05 #                                           DONE
num_epochs      = 2000      #                                               MORE EPOCHS EVEN OUT SAMPLING FREQUENCIES
chains          = batch_size # makes chain replacement logic easier         DONE
weight_decay = 1e-2    #


key_seed = PRNGKey(42)
key, key_params, key_chains, key_dummy = jax.random.split(key_seed, 4)

model_amp = RBM(visible_units, hidden_units, k=k_steps)
batch_dummy = jnp.zeros((batch_size, visible_units), dtype=jnp.float32)
aux_vars_dummy = {"gibbs_chain": jnp.zeros((batch_size, visible_units), dtype=jnp.float32), "key": key_dummy}
variables_amp = model_amp.init({"params": key_params}, batch_dummy, aux_vars_dummy)

loader_amp = MultiBasisDataLoader(dict_amp, batch_size=batch_size, basis_encoding={'Z': 0, 'X': 1, 'Y': 2})

schedule_steps = num_epochs * len(loader_amp)
lr_schedule = get_sigmoid_curve(high=init_lr, low=final_lr, steps=schedule_steps, falloff=0.0005, center_step=schedule_steps * 0.5)
optimizer_amp = optax.adam(learning_rate=lr_schedule)

state_amp = TrainState.create(apply_fn=model_amp.apply, params=variables_amp["params"], tx=optimizer_amp)

# should come from data too but works for now
gibbs_chain = jax.random.bernoulli(key_chains, p=0.5, shape=(chains, visible_units)).astype(jnp.float32)

# %time state_amp, metrics_amp = train_amp_rbm(state_amp, loader_amp, gibbs_chain, num_epochs, key=key, chain_reset_frac_min=0.02, chain_reset_frac_max=0.30, chain_reset_ema_alpha=0.9)
# Out:
# Precalculating target entropy from data.
# Epoch 1/2000 │ Loss: -0.1971 │ Chain Entr.: 2.796 │ Chain Modes: 29 │ Chain Reset Frac.: 0.232 │ Learning Rate: 0.01000
# Epoch 2/2000 │ Loss: -0.0306 │ Chain Entr.: 2.556 │ Chain Modes: 24 │ Chain Reset Frac.: 0.156 │ Learning Rate: 0.01000
# Epoch 3/2000 │ Loss: -0.0387 │ Chain Entr.: 2.558 │ Chain Modes: 24 │ Chain Reset Frac.: 0.193 │ Learning Rate: 0.01000
# Epoch 4/2000 │ Loss: -0.0169 │ Chain Entr.: 2.569 │ Chain Modes: 24 │ Chain Reset Frac.: 0.208 │ Learning Rate: 0.01000
# Epoch 5/2000 │ Loss: -0.0121 │ Chain Entr.: 2.556 │ Chain Modes: 24 │ Chain Reset Frac.: 0.191 │ Learning Rate: 0.01000
# Epoch 6/2000 │ Loss: -0.0025 │ Chain Entr.: 2.544 │ Chain Modes: 23 │ Chain Reset Frac.: 0.189 │ Learning Rate: 0.01000
# Epoch 7/2000 │ Loss: -0.0124 │ Chain Entr.: 2.553 │ Chain Modes: 23 │ Chain Reset Frac.: 0.195 │ Learning Rate: 0.01000
# Epoch 8/2000 │ Loss: +0.0152 │ Chain Entr.: 2.536 │ Chain Modes: 23 │ Chain Reset Frac.: 0.170 │ Learning Rate: 0.01000
# Epoch 9/2000 │ Loss: +0.0009 │ Chain Entr.: 2.526 │ Chain Modes: 24 │ Chain Reset Frac.: 0.211 │ Learning Rate: 0.01000
# Epoch 10/2000 │ Loss: +0.0061 │ Chain Entr.: 2.526 │ Chain Modes: 23 │ Chain Reset Frac.: 0.197 │ Learning Rate: 0.01000
# Epoch 11/2000 │ Loss: +0.0125 │ Chain Entr.: 2.519 │ Chain Modes: 23 │ Chain Reset Frac.: 0.198 │ Learning Rate: 0.01000
# Epoch 12/2000 │ Loss: +0.0219 │ Chain Entr.: 2.523 │ Chain Modes: 23 │ Chain Reset Frac.: 0.170 │ Learning Rate: 0.01000
# Epoch 13/2000 │ Loss: -0.0078 │ Chain Entr.: 2.542 │ Chain Modes: 23 │ Chain Reset Frac.: 0.215 │ Learning Rate: 0.01000
# Epoch 14/2000 │ Loss: +0.0392 │ Chain Entr.: 2.504 │ Chain Modes: 23 │ Chain Reset Frac.: 0.203 │ Learning Rate: 0.01000
# Epoch 15/2000 │ Loss: +0.0218 │ Chain Entr.: 2.510 │ Chain Modes: 23 │ Chain Reset Frac.: 0.160 │ Learning Rate: 0.01000
# Epoch 16/2000 │ Loss: +0.0166 │ Chain Entr.: 2.524 │ Chain Modes: 23 │ Chain Reset Frac.: 0.181 │ Learning Rate: 0.01000
# Epoch 17/2000 │ Loss: +0.0126 │ Chain Entr.: 2.534 │ Chain Modes: 23 │ Chain Reset Frac.: 0.197 │ Learning Rate: 0.01000
# Epoch 18/2000 │ Loss: +0.0292 │ Chain Entr.: 2.522 │ Chain Modes: 23 │ Chain Reset Frac.: 0.171 │ Learning Rate: 0.01000
# Epoch 19/2000 │ Loss: +0.0068 │ Chain Entr.: 2.539 │ Chain Modes: 23 │ Chain Reset Frac.: 0.210 │ Learning Rate: 0.01000
# Epoch 20/2000 │ Loss: +0.0306 │ Chain Entr.: 2.516 │ Chain Modes: 23 │ Chain Reset Frac.: 0.199 │ Learning Rate: 0.01000
# Epoch 21/2000 │ Loss: +0.0158 │ Chain Entr.: 2.513 │ Chain Modes: 23 │ Chain Reset Frac.: 0.170 │ Learning Rate: 0.01000
# Epoch 22/2000 │ Loss: +0.0063 │ Chain Entr.: 2.543 │ Chain Modes: 23 │ Chain Reset Frac.: 0.190 │ Learning Rate: 0.01000
# Epoch 23/2000 │ Loss: +0.0126 │ Chain Entr.: 2.518 │ Chain Modes: 23 │ Chain Reset Frac.: 0.202 │ Learning Rate: 0.01000
# Epoch 24/2000 │ Loss: +0.0240 │ Chain Entr.: 2.521 │ Chain Modes: 23 │ Chain Reset Frac.: 0.197 │ Learning Rate: 0.01000
# Epoch 25/2000 │ Loss: +0.0230 │ Chain Entr.: 2.531 │ Chain Modes: 23 │ Chain Reset Frac.: 0.179 │ Learning Rate: 0.01000
# Epoch 26/2000 │ Loss: +0.0151 │ Chain Entr.: 2.534 │ Chain Modes: 23 │ Chain Reset Frac.: 0.190 │ Learning Rate: 0.01000
# Epoch 27/2000 │ Loss: +0.0083 │ Chain Entr.: 2.526 │ Chain Modes: 23 │ Chain Reset Frac.: 0.194 │ Learning Rate: 0.01000
# Epoch 28/2000 │ Loss: +0.0068 │ Chain Entr.: 2.530 │ Chain Modes: 23 │ Chain Reset Frac.: 0.219 │ Learning Rate: 0.01000
# Epoch 29/2000 │ Loss: +0.0131 │ Chain Entr.: 2.536 │ Chain Modes: 23 │ Chain Reset Frac.: 0.212 │ Learning Rate: 0.01000
# Epoch 30/2000 │ Loss: +0.0371 │ Chain Entr.: 2.499 │ Chain Modes: 23 │ Chain Reset Frac.: 0.137 │ Learning Rate: 0.01000
# Epoch 31/2000 │ Loss: -0.0030 │ Chain Entr.: 2.544 │ Chain Modes: 23 │ Chain Reset Frac.: 0.183 │ Learning Rate: 0.01000
# Epoch 32/2000 │ Loss: +0.0199 │ Chain Entr.: 2.515 │ Chain Modes: 23 │ Chain Reset Frac.: 0.171 │ Learning Rate: 0.01000
# Epoch 33/2000 │ Loss: +0.0012 │ Chain Entr.: 2.538 │ Chain Modes: 23 │ Chain Reset Frac.: 0.191 │ Learning Rate: 0.01000
# Epoch 34/2000 │ Loss: +0.0090 │ Chain Entr.: 2.526 │ Chain Modes: 23 │ Chain Reset Frac.: 0.206 │ Learning Rate: 0.01000
# Epoch 35/2000 │ Loss: +0.0256 │ Chain Entr.: 2.512 │ Chain Modes: 23 │ Chain Reset Frac.: 0.164 │ Learning Rate: 0.01000
# Epoch 36/2000 │ Loss: +0.0043 │ Chain Entr.: 2.536 │ Chain Modes: 24 │ Chain Reset Frac.: 0.181 │ Learning Rate: 0.01000
# Epoch 37/2000 │ Loss: +0.0064 │ Chain Entr.: 2.525 │ Chain Modes: 23 │ Chain Reset Frac.: 0.188 │ Learning Rate: 0.01000
# Epoch 38/2000 │ Loss: +0.0146 │ Chain Entr.: 2.513 │ Chain Modes: 23 │ Chain Reset Frac.: 0.169 │ Learning Rate: 0.01000
# Epoch 39/2000 │ Loss: -0.0070 │ Chain Entr.: 2.536 │ Chain Modes: 23 │ Chain Reset Frac.: 0.203 │ Learning Rate: 0.01000
# Epoch 40/2000 │ Loss: +0.0047 │ Chain Entr.: 2.528 │ Chain Modes: 23 │ Chain Reset Frac.: 0.203 │ Learning Rate: 0.01000
# Epoch 41/2000 │ Loss: +0.0002 │ Chain Entr.: 2.520 │ Chain Modes: 23 │ Chain Reset Frac.: 0.191 │ Learning Rate: 0.01000
# Epoch 42/2000 │ Loss: +0.0101 │ Chain Entr.: 2.507 │ Chain Modes: 23 │ Chain Reset Frac.: 0.184 │ Learning Rate: 0.01000
# Epoch 43/2000 │ Loss: +0.0041 │ Chain Entr.: 2.534 │ Chain Modes: 23 │ Chain Reset Frac.: 0.214 │ Learning Rate: 0.01000
# Epoch 44/2000 │ Loss: -0.0023 │ Chain Entr.: 2.525 │ Chain Modes: 23 │ Chain Reset Frac.: 0.201 │ Learning Rate: 0.01000
# Epoch 45/2000 │ Loss: +0.0178 │ Chain Entr.: 2.515 │ Chain Modes: 23 │ Chain Reset Frac.: 0.187 │ Learning Rate: 0.01000
# Epoch 46/2000 │ Loss: +0.0096 │ Chain Entr.: 2.505 │ Chain Modes: 23 │ Chain Reset Frac.: 0.206 │ Learning Rate: 0.01000
# Epoch 47/2000 │ Loss: +0.0113 │ Chain Entr.: 2.521 │ Chain Modes: 23 │ Chain Reset Frac.: 0.182 │ Learning Rate: 0.01000
# Epoch 48/2000 │ Loss: +0.0057 │ Chain Entr.: 2.521 │ Chain Modes: 23 │ Chain Reset Frac.: 0.183 │ Learning Rate: 0.01000
# Epoch 49/2000 │ Loss: +0.0055 │ Chain Entr.: 2.522 │ Chain Modes: 23 │ Chain Reset Frac.: 0.192 │ Learning Rate: 0.01000
# Epoch 50/2000 │ Loss: -0.0059 │ Chain Entr.: 2.538 │ Chain Modes: 23 │ Chain Reset Frac.: 0.224 │ Learning Rate: 0.01000
# Epoch 51/2000 │ Loss: +0.0138 │ Chain Entr.: 2.513 │ Chain Modes: 23 │ Chain Reset Frac.: 0.196 │ Learning Rate: 0.01000
# Epoch 52/2000 │ Loss: -0.0134 │ Chain Entr.: 2.535 │ Chain Modes: 23 │ Chain Reset Frac.: 0.226 │ Learning Rate: 0.01000
# Epoch 53/2000 │ Loss: +0.0282 │ Chain Entr.: 2.497 │ Chain Modes: 23 │ Chain Reset Frac.: 0.181 │ Learning Rate: 0.01000
# Epoch 54/2000 │ Loss: +0.0110 │ Chain Entr.: 2.513 │ Chain Modes: 23 │ Chain Reset Frac.: 0.174 │ Learning Rate: 0.01000
# Epoch 55/2000 │ Loss: -0.0034 │ Chain Entr.: 2.531 │ Chain Modes: 23 │ Chain Reset Frac.: 0.203 │ Learning Rate: 0.01000
# Epoch 56/2000 │ Loss: +0.0235 │ Chain Entr.: 2.504 │ Chain Modes: 23 │ Chain Reset Frac.: 0.174 │ Learning Rate: 0.01000
# Epoch 57/2000 │ Loss: -0.0062 │ Chain Entr.: 2.519 │ Chain Modes: 23 │ Chain Reset Frac.: 0.183 │ Learning Rate: 0.01000
# Epoch 58/2000 │ Loss: +0.0001 │ Chain Entr.: 2.528 │ Chain Modes: 23 │ Chain Reset Frac.: 0.201 │ Learning Rate: 0.01000
# Epoch 59/2000 │ Loss: -0.0042 │ Chain Entr.: 2.531 │ Chain Modes: 23 │ Chain Reset Frac.: 0.164 │ Learning Rate: 0.01000
# Epoch 60/2000 │ Loss: +0.0041 │ Chain Entr.: 2.520 │ Chain Modes: 23 │ Chain Reset Frac.: 0.190 │ Learning Rate: 0.01000
# Epoch 61/2000 │ Loss: -0.0165 │ Chain Entr.: 2.536 │ Chain Modes: 23 │ Chain Reset Frac.: 0.225 │ Learning Rate: 0.01000
# Epoch 62/2000 │ Loss: -0.0093 │ Chain Entr.: 2.523 │ Chain Modes: 23 │ Chain Reset Frac.: 0.205 │ Learning Rate: 0.01000
# Epoch 63/2000 │ Loss: -0.0013 │ Chain Entr.: 2.519 │ Chain Modes: 23 │ Chain Reset Frac.: 0.189 │ Learning Rate: 0.01000
# Epoch 64/2000 │ Loss: -0.0398 │ Chain Entr.: 2.549 │ Chain Modes: 23 │ Chain Reset Frac.: 0.183 │ Learning Rate: 0.01000
# Epoch 65/2000 │ Loss: -0.0395 │ Chain Entr.: 2.533 │ Chain Modes: 23 │ Chain Reset Frac.: 0.207 │ Learning Rate: 0.01000
# Epoch 66/2000 │ Loss: -0.0530 │ Chain Entr.: 2.551 │ Chain Modes: 22 │ Chain Reset Frac.: 0.209 │ Learning Rate: 0.01000
# Epoch 67/2000 │ Loss: -0.0739 │ Chain Entr.: 2.548 │ Chain Modes: 22 │ Chain Reset Frac.: 0.193 │ Learning Rate: 0.01000
# Epoch 68/2000 │ Loss: -0.1015 │ Chain Entr.: 2.560 │ Chain Modes: 22 │ Chain Reset Frac.: 0.207 │ Learning Rate: 0.01000
# Epoch 69/2000 │ Loss: -0.1219 │ Chain Entr.: 2.561 │ Chain Modes: 22 │ Chain Reset Frac.: 0.235 │ Learning Rate: 0.01000
# Epoch 70/2000 │ Loss: -0.1508 │ Chain Entr.: 2.558 │ Chain Modes: 21 │ Chain Reset Frac.: 0.211 │ Learning Rate: 0.01000
# Epoch 71/2000 │ Loss: -0.2014 │ Chain Entr.: 2.557 │ Chain Modes: 21 │ Chain Reset Frac.: 0.183 │ Learning Rate: 0.01000
# Epoch 72/2000 │ Loss: -0.2431 │ Chain Entr.: 2.565 │ Chain Modes: 20 │ Chain Reset Frac.: 0.190 │ Learning Rate: 0.01000
# Epoch 73/2000 │ Loss: -0.3069 │ Chain Entr.: 2.557 │ Chain Modes: 19 │ Chain Reset Frac.: 0.222 │ Learning Rate: 0.01000
# Epoch 74/2000 │ Loss: -0.3073 │ Chain Entr.: 2.502 │ Chain Modes: 17 │ Chain Reset Frac.: 0.170 │ Learning Rate: 0.01000
# Epoch 75/2000 │ Loss: -0.3222 │ Chain Entr.: 2.467 │ Chain Modes: 16 │ Chain Reset Frac.: 0.161 │ Learning Rate: 0.01000
# Epoch 76/2000 │ Loss: -0.3239 │ Chain Entr.: 2.425 │ Chain Modes: 15 │ Chain Reset Frac.: 0.131 │ Learning Rate: 0.01000
# Epoch 77/2000 │ Loss: -0.2896 │ Chain Entr.: 2.367 │ Chain Modes: 14 │ Chain Reset Frac.: 0.115 │ Learning Rate: 0.01000
# Epoch 78/2000 │ Loss: -0.2957 │ Chain Entr.: 2.326 │ Chain Modes: 14 │ Chain Reset Frac.: 0.094 │ Learning Rate: 0.01000
# Epoch 79/2000 │ Loss: -0.2470 │ Chain Entr.: 2.292 │ Chain Modes: 13 │ Chain Reset Frac.: 0.086 │ Learning Rate: 0.01000
# Epoch 80/2000 │ Loss: -0.2579 │ Chain Entr.: 2.273 │ Chain Modes: 12 │ Chain Reset Frac.: 0.082 │ Learning Rate: 0.01000
# Epoch 81/2000 │ Loss: -0.2221 │ Chain Entr.: 2.239 │ Chain Modes: 12 │ Chain Reset Frac.: 0.062 │ Learning Rate: 0.01000
# Epoch 82/2000 │ Loss: -0.2196 │ Chain Entr.: 2.222 │ Chain Modes: 12 │ Chain Reset Frac.: 0.057 │ Learning Rate: 0.01000
# Epoch 83/2000 │ Loss: -0.1850 │ Chain Entr.: 2.191 │ Chain Modes: 11 │ Chain Reset Frac.: 0.061 │ Learning Rate: 0.01000
# Epoch 84/2000 │ Loss: -0.1814 │ Chain Entr.: 2.188 │ Chain Modes: 11 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.01000
# Epoch 85/2000 │ Loss: -0.1645 │ Chain Entr.: 2.176 │ Chain Modes: 11 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.01000
# Epoch 86/2000 │ Loss: -0.1578 │ Chain Entr.: 2.162 │ Chain Modes: 11 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.01000
# Epoch 87/2000 │ Loss: -0.1416 │ Chain Entr.: 2.148 │ Chain Modes: 10 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 88/2000 │ Loss: -0.1291 │ Chain Entr.: 2.136 │ Chain Modes: 10 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.01000
# Epoch 89/2000 │ Loss: -0.1390 │ Chain Entr.: 2.136 │ Chain Modes: 10 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.01000
# Epoch 90/2000 │ Loss: -0.1157 │ Chain Entr.: 2.117 │ Chain Modes: 10 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 91/2000 │ Loss: -0.1150 │ Chain Entr.: 2.114 │ Chain Modes: 10 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 92/2000 │ Loss: -0.0981 │ Chain Entr.: 2.100 │ Chain Modes: 10 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 93/2000 │ Loss: -0.0956 │ Chain Entr.: 2.100 │ Chain Modes: 10 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 94/2000 │ Loss: -0.0889 │ Chain Entr.: 2.095 │ Chain Modes: 10 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 95/2000 │ Loss: -0.0864 │ Chain Entr.: 2.093 │ Chain Modes: 9 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 96/2000 │ Loss: -0.0747 │ Chain Entr.: 2.085 │ Chain Modes: 9 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 97/2000 │ Loss: -0.0759 │ Chain Entr.: 2.080 │ Chain Modes: 9 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 98/2000 │ Loss: -0.0799 │ Chain Entr.: 2.084 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 99/2000 │ Loss: -0.0938 │ Chain Entr.: 2.091 │ Chain Modes: 10 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 100/2000 │ Loss: -0.0592 │ Chain Entr.: 2.070 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 101/2000 │ Loss: -0.0617 │ Chain Entr.: 2.067 │ Chain Modes: 9 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 102/2000 │ Loss: -0.0585 │ Chain Entr.: 2.061 │ Chain Modes: 9 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 103/2000 │ Loss: -0.0502 │ Chain Entr.: 2.060 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 104/2000 │ Loss: -0.0556 │ Chain Entr.: 2.065 │ Chain Modes: 9 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 105/2000 │ Loss: -0.0568 │ Chain Entr.: 2.068 │ Chain Modes: 9 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 106/2000 │ Loss: -0.0677 │ Chain Entr.: 2.071 │ Chain Modes: 9 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 107/2000 │ Loss: -0.0345 │ Chain Entr.: 2.055 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 108/2000 │ Loss: -0.0437 │ Chain Entr.: 2.059 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 109/2000 │ Loss: -0.0467 │ Chain Entr.: 2.061 │ Chain Modes: 9 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 110/2000 │ Loss: -0.0372 │ Chain Entr.: 2.047 │ Chain Modes: 9 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 111/2000 │ Loss: -0.0361 │ Chain Entr.: 2.046 │ Chain Modes: 9 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 112/2000 │ Loss: -0.0203 │ Chain Entr.: 2.042 │ Chain Modes: 9 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 113/2000 │ Loss: -0.0154 │ Chain Entr.: 2.042 │ Chain Modes: 9 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 114/2000 │ Loss: -0.0368 │ Chain Entr.: 2.053 │ Chain Modes: 9 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 115/2000 │ Loss: -0.0264 │ Chain Entr.: 2.048 │ Chain Modes: 9 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 116/2000 │ Loss: -0.0338 │ Chain Entr.: 2.046 │ Chain Modes: 9 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 117/2000 │ Loss: -0.0201 │ Chain Entr.: 2.040 │ Chain Modes: 9 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 118/2000 │ Loss: -0.0389 │ Chain Entr.: 2.047 │ Chain Modes: 9 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.01000
# Epoch 119/2000 │ Loss: -0.0330 │ Chain Entr.: 2.047 │ Chain Modes: 9 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 120/2000 │ Loss: -0.0191 │ Chain Entr.: 2.041 │ Chain Modes: 9 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 121/2000 │ Loss: -0.0267 │ Chain Entr.: 2.040 │ Chain Modes: 9 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 122/2000 │ Loss: -0.0274 │ Chain Entr.: 2.043 │ Chain Modes: 9 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.01000
# Epoch 123/2000 │ Loss: -0.0144 │ Chain Entr.: 2.039 │ Chain Modes: 9 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 124/2000 │ Loss: -0.0149 │ Chain Entr.: 2.031 │ Chain Modes: 9 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 125/2000 │ Loss: -0.0197 │ Chain Entr.: 2.041 │ Chain Modes: 9 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 126/2000 │ Loss: -0.0085 │ Chain Entr.: 2.026 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 127/2000 │ Loss: -0.0246 │ Chain Entr.: 2.041 │ Chain Modes: 9 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 128/2000 │ Loss: -0.0249 │ Chain Entr.: 2.042 │ Chain Modes: 9 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 129/2000 │ Loss: -0.0107 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 130/2000 │ Loss: -0.0123 │ Chain Entr.: 2.031 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.01000
# Epoch 131/2000 │ Loss: +0.0088 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 132/2000 │ Loss: -0.0153 │ Chain Entr.: 2.030 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 133/2000 │ Loss: -0.0105 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 134/2000 │ Loss: +0.0012 │ Chain Entr.: 2.028 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 135/2000 │ Loss: +0.0075 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 136/2000 │ Loss: -0.0045 │ Chain Entr.: 2.036 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.01000
# Epoch 137/2000 │ Loss: -0.0100 │ Chain Entr.: 2.036 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 138/2000 │ Loss: -0.0070 │ Chain Entr.: 2.026 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 139/2000 │ Loss: -0.0063 │ Chain Entr.: 2.034 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 140/2000 │ Loss: -0.0076 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 141/2000 │ Loss: -0.0166 │ Chain Entr.: 2.040 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 142/2000 │ Loss: +0.0051 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.01000
# Epoch 143/2000 │ Loss: +0.0018 │ Chain Entr.: 2.030 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 144/2000 │ Loss: +0.0010 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 145/2000 │ Loss: +0.0022 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 146/2000 │ Loss: -0.0004 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 147/2000 │ Loss: -0.0098 │ Chain Entr.: 2.032 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 148/2000 │ Loss: +0.0024 │ Chain Entr.: 2.028 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 149/2000 │ Loss: -0.0064 │ Chain Entr.: 2.038 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 150/2000 │ Loss: +0.0152 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 151/2000 │ Loss: +0.0087 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 152/2000 │ Loss: +0.0172 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.058 │ Learning Rate: 0.01000
# Epoch 153/2000 │ Loss: +0.0110 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.01000
# Epoch 154/2000 │ Loss: +0.0148 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.01000
# Epoch 155/2000 │ Loss: +0.0102 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 156/2000 │ Loss: +0.0294 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.01000
# Epoch 157/2000 │ Loss: +0.0105 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.01000
# Epoch 158/2000 │ Loss: +0.0148 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 159/2000 │ Loss: +0.0238 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 160/2000 │ Loss: +0.0309 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.01000
# Epoch 161/2000 │ Loss: +0.0151 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 162/2000 │ Loss: +0.0196 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 163/2000 │ Loss: +0.0111 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.01000
# Epoch 164/2000 │ Loss: +0.0017 │ Chain Entr.: 2.028 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 165/2000 │ Loss: +0.0152 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 166/2000 │ Loss: +0.0174 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 167/2000 │ Loss: +0.0236 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 168/2000 │ Loss: +0.0141 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 169/2000 │ Loss: +0.0221 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 170/2000 │ Loss: +0.0055 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 171/2000 │ Loss: +0.0181 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 172/2000 │ Loss: +0.0257 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 173/2000 │ Loss: +0.0170 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 174/2000 │ Loss: +0.0419 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 175/2000 │ Loss: +0.0148 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 176/2000 │ Loss: +0.0570 │ Chain Entr.: 1.990 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 177/2000 │ Loss: +0.0211 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 178/2000 │ Loss: +0.0338 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 179/2000 │ Loss: +0.0363 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 180/2000 │ Loss: +0.0350 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 181/2000 │ Loss: +0.0133 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 182/2000 │ Loss: +0.0142 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 183/2000 │ Loss: +0.0520 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.01000
# Epoch 184/2000 │ Loss: +0.0212 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 185/2000 │ Loss: +0.0193 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.01000
# Epoch 186/2000 │ Loss: +0.0179 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.01000
# Epoch 187/2000 │ Loss: +0.0350 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.01000
# Epoch 188/2000 │ Loss: +0.0458 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.052 │ Learning Rate: 0.01000
# Epoch 189/2000 │ Loss: +0.0273 │ Chain Entr.: 2.009 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 190/2000 │ Loss: +0.0346 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 191/2000 │ Loss: +0.0353 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.01000
# Epoch 192/2000 │ Loss: +0.0356 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 193/2000 │ Loss: +0.0274 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 194/2000 │ Loss: +0.0362 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 195/2000 │ Loss: +0.0106 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 196/2000 │ Loss: +0.0280 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 197/2000 │ Loss: +0.0480 │ Chain Entr.: 1.997 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 198/2000 │ Loss: +0.0357 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 199/2000 │ Loss: +0.0295 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.01000
# Epoch 200/2000 │ Loss: +0.0260 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 201/2000 │ Loss: +0.0541 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 202/2000 │ Loss: +0.0359 │ Chain Entr.: 2.013 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 203/2000 │ Loss: +0.0256 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 204/2000 │ Loss: +0.0168 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 205/2000 │ Loss: +0.0241 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 206/2000 │ Loss: +0.0440 │ Chain Entr.: 2.012 │ Chain Modes: 8 │ Chain Reset Frac.: 0.055 │ Learning Rate: 0.01000
# Epoch 207/2000 │ Loss: +0.0510 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 208/2000 │ Loss: +0.0449 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 209/2000 │ Loss: +0.0503 │ Chain Entr.: 2.013 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 210/2000 │ Loss: +0.0345 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.01000
# Epoch 211/2000 │ Loss: +0.0630 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 212/2000 │ Loss: +0.0182 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 213/2000 │ Loss: +0.0365 │ Chain Entr.: 2.012 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 214/2000 │ Loss: +0.0507 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.01000
# Epoch 215/2000 │ Loss: +0.0285 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.01000
# Epoch 216/2000 │ Loss: +0.0133 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.01000
# Epoch 217/2000 │ Loss: +0.0630 │ Chain Entr.: 1.997 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.01000
# Epoch 218/2000 │ Loss: +0.0651 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 219/2000 │ Loss: +0.0534 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 220/2000 │ Loss: +0.0510 │ Chain Entr.: 2.003 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 221/2000 │ Loss: +0.0525 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 222/2000 │ Loss: +0.0314 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.01000
# Epoch 223/2000 │ Loss: +0.0340 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 224/2000 │ Loss: +0.0218 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 225/2000 │ Loss: +0.0339 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.01000
# Epoch 226/2000 │ Loss: +0.0433 │ Chain Entr.: 2.009 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.01000
# Epoch 227/2000 │ Loss: +0.0636 │ Chain Entr.: 2.003 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.01000
# Epoch 228/2000 │ Loss: +0.0381 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 229/2000 │ Loss: +0.0288 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 230/2000 │ Loss: +0.0556 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.01000
# Epoch 231/2000 │ Loss: +0.0277 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 232/2000 │ Loss: +0.0642 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 233/2000 │ Loss: +0.0484 │ Chain Entr.: 2.000 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.01000
# Epoch 234/2000 │ Loss: +0.0344 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.01000
# Epoch 235/2000 │ Loss: +0.0572 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.01000
# Epoch 236/2000 │ Loss: +0.0433 │ Chain Entr.: 2.001 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 237/2000 │ Loss: +0.0675 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 238/2000 │ Loss: +0.0532 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.01000
# Epoch 239/2000 │ Loss: +0.0423 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.01000
# Epoch 240/2000 │ Loss: +0.0545 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.01000
# Epoch 241/2000 │ Loss: +0.0426 │ Chain Entr.: 2.001 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.01000
# Epoch 242/2000 │ Loss: +0.0370 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 243/2000 │ Loss: +0.0354 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.01000
# Epoch 244/2000 │ Loss: +0.0556 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.01000
# Epoch 245/2000 │ Loss: +0.0526 │ Chain Entr.: 1.998 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 246/2000 │ Loss: +0.0424 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 247/2000 │ Loss: +0.0422 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 248/2000 │ Loss: +0.0521 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 249/2000 │ Loss: +0.0376 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 250/2000 │ Loss: +0.0474 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 251/2000 │ Loss: +0.0517 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 252/2000 │ Loss: +0.0224 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.01000
# Epoch 253/2000 │ Loss: +0.0370 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 254/2000 │ Loss: +0.0613 │ Chain Entr.: 1.998 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.01000
# Epoch 255/2000 │ Loss: +0.0397 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 256/2000 │ Loss: +0.0438 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.01000
# Epoch 257/2000 │ Loss: +0.0682 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.01000
# Epoch 258/2000 │ Loss: +0.0692 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 259/2000 │ Loss: +0.0290 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 260/2000 │ Loss: +0.0315 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 261/2000 │ Loss: +0.0561 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.01000
# Epoch 262/2000 │ Loss: +0.0300 │ Chain Entr.: 2.012 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 263/2000 │ Loss: +0.0395 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 264/2000 │ Loss: +0.0532 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 265/2000 │ Loss: +0.0632 │ Chain Entr.: 1.989 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.01000
# Epoch 266/2000 │ Loss: +0.0565 │ Chain Entr.: 1.997 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.01000
# Epoch 267/2000 │ Loss: +0.0592 │ Chain Entr.: 2.000 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.01000
# Epoch 268/2000 │ Loss: +0.0164 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 269/2000 │ Loss: +0.0427 │ Chain Entr.: 1.998 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 270/2000 │ Loss: +0.0879 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 271/2000 │ Loss: +0.0337 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 272/2000 │ Loss: +0.0749 │ Chain Entr.: 2.003 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.01000
# Epoch 273/2000 │ Loss: +0.0435 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 274/2000 │ Loss: +0.0285 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.043 │ Learning Rate: 0.01000
# Epoch 275/2000 │ Loss: +0.0472 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 276/2000 │ Loss: +0.0492 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 277/2000 │ Loss: +0.0552 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 278/2000 │ Loss: +0.0393 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 279/2000 │ Loss: +0.0307 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 280/2000 │ Loss: +0.0405 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 281/2000 │ Loss: +0.0062 │ Chain Entr.: 2.031 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 282/2000 │ Loss: +0.0500 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.01000
# Epoch 283/2000 │ Loss: +0.0265 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 284/2000 │ Loss: +0.0611 │ Chain Entr.: 2.004 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.01000
# Epoch 285/2000 │ Loss: +0.0233 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 286/2000 │ Loss: +0.0493 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 287/2000 │ Loss: +0.0478 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 288/2000 │ Loss: +0.0697 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.01000
# Epoch 289/2000 │ Loss: +0.0720 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.01000
# Epoch 290/2000 │ Loss: +0.0242 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 291/2000 │ Loss: +0.0348 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.01000
# Epoch 292/2000 │ Loss: +0.0405 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 293/2000 │ Loss: +0.0517 │ Chain Entr.: 2.003 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 294/2000 │ Loss: +0.0664 │ Chain Entr.: 1.992 │ Chain Modes: 8 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.01000
# Epoch 295/2000 │ Loss: +0.0384 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 296/2000 │ Loss: +0.0410 │ Chain Entr.: 2.013 │ Chain Modes: 8 │ Chain Reset Frac.: 0.062 │ Learning Rate: 0.01000
# Epoch 297/2000 │ Loss: +0.0595 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.01000
# Epoch 298/2000 │ Loss: +0.0216 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 299/2000 │ Loss: +0.0544 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.01000
# Epoch 300/2000 │ Loss: +0.0426 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.01000
# Epoch 301/2000 │ Loss: +0.0346 │ Chain Entr.: 2.003 │ Chain Modes: 8 │ Chain Reset Frac.: 0.055 │ Learning Rate: 0.01000
# Epoch 302/2000 │ Loss: +0.0659 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.01000
# Epoch 303/2000 │ Loss: +0.0595 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 304/2000 │ Loss: +0.0340 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 305/2000 │ Loss: +0.0404 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 306/2000 │ Loss: +0.0285 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.01000
# Epoch 307/2000 │ Loss: +0.0410 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 308/2000 │ Loss: +0.0390 │ Chain Entr.: 2.013 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 309/2000 │ Loss: +0.0446 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.01000
# Epoch 310/2000 │ Loss: +0.0601 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 311/2000 │ Loss: +0.0376 │ Chain Entr.: 2.001 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 312/2000 │ Loss: +0.0381 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.01000
# Epoch 313/2000 │ Loss: +0.1127 │ Chain Entr.: 1.988 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.01000
# Epoch 314/2000 │ Loss: +0.0748 │ Chain Entr.: 1.997 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 315/2000 │ Loss: +0.0293 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.01000
# Epoch 316/2000 │ Loss: +0.0846 │ Chain Entr.: 1.993 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.01000
# Epoch 317/2000 │ Loss: +0.0808 │ Chain Entr.: 1.997 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.01000
# Epoch 318/2000 │ Loss: +0.0535 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 319/2000 │ Loss: +0.0450 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 320/2000 │ Loss: +0.0227 │ Chain Entr.: 2.028 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 321/2000 │ Loss: +0.0614 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.01000
# Epoch 322/2000 │ Loss: +0.0375 │ Chain Entr.: 2.003 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.01000
# Epoch 323/2000 │ Loss: +0.0447 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 324/2000 │ Loss: +0.0687 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.01000
# Epoch 325/2000 │ Loss: +0.0312 │ Chain Entr.: 2.030 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 326/2000 │ Loss: +0.0734 │ Chain Entr.: 1.995 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 327/2000 │ Loss: +0.0285 │ Chain Entr.: 2.031 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 328/2000 │ Loss: +0.0352 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# Epoch 329/2000 │ Loss: +0.0474 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.065 │ Learning Rate: 0.01000
# Epoch 330/2000 │ Loss: +0.0503 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 331/2000 │ Loss: +0.0413 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.01000
# Epoch 332/2000 │ Loss: +0.0650 │ Chain Entr.: 1.999 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 333/2000 │ Loss: +0.0609 │ Chain Entr.: 2.009 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 334/2000 │ Loss: +0.0801 │ Chain Entr.: 1.994 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 335/2000 │ Loss: +0.0862 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 336/2000 │ Loss: +0.0403 │ Chain Entr.: 2.012 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.01000
# Epoch 337/2000 │ Loss: +0.0434 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.01000
# Epoch 338/2000 │ Loss: +0.0373 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 339/2000 │ Loss: +0.0660 │ Chain Entr.: 2.012 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 340/2000 │ Loss: +0.0332 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.061 │ Learning Rate: 0.01000
# Epoch 341/2000 │ Loss: +0.0825 │ Chain Entr.: 1.991 │ Chain Modes: 8 │ Chain Reset Frac.: 0.051 │ Learning Rate: 0.01000
# Epoch 342/2000 │ Loss: +0.0305 │ Chain Entr.: 2.027 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 343/2000 │ Loss: +0.0324 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.01000
# Epoch 344/2000 │ Loss: +0.0671 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 345/2000 │ Loss: +0.0389 │ Chain Entr.: 2.028 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 346/2000 │ Loss: +0.0446 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.01000
# Epoch 347/2000 │ Loss: +0.0335 │ Chain Entr.: 2.036 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.01000
# Epoch 348/2000 │ Loss: +0.0498 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.038 │ Learning Rate: 0.01000
# Epoch 349/2000 │ Loss: +0.0690 │ Chain Entr.: 2.003 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.01000
# Epoch 350/2000 │ Loss: +0.0773 │ Chain Entr.: 1.987 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.01000
# Epoch 351/2000 │ Loss: +0.0283 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.01000
# Epoch 352/2000 │ Loss: +0.0564 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.01000
# Epoch 353/2000 │ Loss: +0.0533 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.01000
# Epoch 354/2000 │ Loss: +0.0536 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 355/2000 │ Loss: +0.0503 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.01000
# Epoch 356/2000 │ Loss: +0.0437 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.01000
# Epoch 357/2000 │ Loss: +0.0654 │ Chain Entr.: 2.009 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.01000
# Epoch 358/2000 │ Loss: +0.0327 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 359/2000 │ Loss: +0.1045 │ Chain Entr.: 1.980 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 360/2000 │ Loss: +0.0236 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 361/2000 │ Loss: +0.0550 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.01000
# Epoch 362/2000 │ Loss: +0.0764 │ Chain Entr.: 1.996 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.01000
# Epoch 363/2000 │ Loss: +0.0508 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.01000
# Epoch 364/2000 │ Loss: +0.0544 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.056 │ Learning Rate: 0.01000
# Epoch 365/2000 │ Loss: +0.0884 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 366/2000 │ Loss: +0.0437 │ Chain Entr.: 2.029 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 367/2000 │ Loss: +0.0470 │ Chain Entr.: 2.002 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 368/2000 │ Loss: +0.1321 │ Chain Entr.: 1.978 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 369/2000 │ Loss: +0.0129 │ Chain Entr.: 2.039 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 370/2000 │ Loss: +0.0442 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 371/2000 │ Loss: +0.0411 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.048 │ Learning Rate: 0.01000
# Epoch 372/2000 │ Loss: +0.0614 │ Chain Entr.: 2.013 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.01000
# Epoch 373/2000 │ Loss: +0.0666 │ Chain Entr.: 1.998 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.01000
# Epoch 374/2000 │ Loss: +0.0531 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.01000
# Epoch 375/2000 │ Loss: +0.0608 │ Chain Entr.: 2.015 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.01000
# Epoch 376/2000 │ Loss: +0.0608 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.01000
# Epoch 377/2000 │ Loss: +0.0614 │ Chain Entr.: 2.003 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.01000
# Epoch 378/2000 │ Loss: +0.0541 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 379/2000 │ Loss: +0.0463 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 380/2000 │ Loss: +0.0557 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.01000
# Epoch 381/2000 │ Loss: +0.0416 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.01000
# Epoch 382/2000 │ Loss: +0.0542 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.01000
# Epoch 383/2000 │ Loss: +0.0576 │ Chain Entr.: 2.009 │ Chain Modes: 8 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.01000
# Epoch 384/2000 │ Loss: +0.0916 │ Chain Entr.: 1.981 │ Chain Modes: 8 │ Chain Reset Frac.: 0.083 │ Learning Rate: 0.01000
# Epoch 385/2000 │ Loss: +0.0815 │ Chain Entr.: 1.985 │ Chain Modes: 8 │ Chain Reset Frac.: 0.047 │ Learning Rate: 0.01000
# Epoch 386/2000 │ Loss: +0.0560 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.01000
# Epoch 387/2000 │ Loss: +0.0462 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.01000
# Epoch 388/2000 │ Loss: +0.0638 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.041 │ Learning Rate: 0.01000
# Epoch 389/2000 │ Loss: +0.0450 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.01000
# Epoch 390/2000 │ Loss: +0.0628 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.01000
# Epoch 391/2000 │ Loss: +0.0539 │ Chain Entr.: 2.006 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.01000
# Epoch 392/2000 │ Loss: +0.0479 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.050 │ Learning Rate: 0.01000
# Epoch 393/2000 │ Loss: +0.0750 │ Chain Entr.: 1.997 │ Chain Modes: 8 │ Chain Reset Frac.: 0.049 │ Learning Rate: 0.01000
# Epoch 394/2000 │ Loss: +0.0701 │ Chain Entr.: 2.001 │ Chain Modes: 8 │ Chain Reset Frac.: 0.053 │ Learning Rate: 0.01000
# Epoch 395/2000 │ Loss: +0.0362 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.01000
# Epoch 396/2000 │ Loss: +0.0670 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.01000
# ...
# Epoch 1871/2000 │ Loss: -0.0138 │ Chain Entr.: 2.031 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00050
# Epoch 1872/2000 │ Loss: -0.0033 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1873/2000 │ Loss: +0.0091 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1874/2000 │ Loss: -0.0067 │ Chain Entr.: 2.011 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00050
# Epoch 1875/2000 │ Loss: -0.0008 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00050
# Epoch 1876/2000 │ Loss: +0.0025 │ Chain Entr.: 2.028 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00050
# Epoch 1877/2000 │ Loss: -0.0145 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00050
# Epoch 1878/2000 │ Loss: -0.0074 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00050
# Epoch 1879/2000 │ Loss: -0.0065 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00050
# Epoch 1880/2000 │ Loss: -0.0068 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00050
# Epoch 1881/2000 │ Loss: +0.0095 │ Chain Entr.: 2.029 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1882/2000 │ Loss: -0.0064 │ Chain Entr.: 2.029 │ Chain Modes: 8 │ Chain Reset Frac.: 0.036 │ Learning Rate: 0.00050
# Epoch 1883/2000 │ Loss: +0.0011 │ Chain Entr.: 2.010 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00050
# Epoch 1884/2000 │ Loss: +0.0086 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00050
# Epoch 1885/2000 │ Loss: -0.0290 │ Chain Entr.: 2.030 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00050
# Epoch 1886/2000 │ Loss: +0.0027 │ Chain Entr.: 2.034 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00050
# Epoch 1887/2000 │ Loss: -0.0068 │ Chain Entr.: 2.032 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1888/2000 │ Loss: +0.0046 │ Chain Entr.: 2.044 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00050
# Epoch 1889/2000 │ Loss: +0.0052 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00050
# Epoch 1890/2000 │ Loss: +0.0014 │ Chain Entr.: 2.007 │ Chain Modes: 8 │ Chain Reset Frac.: 0.045 │ Learning Rate: 0.00050
# Epoch 1891/2000 │ Loss: +0.0039 │ Chain Entr.: 2.034 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00050
# Epoch 1892/2000 │ Loss: -0.0002 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1893/2000 │ Loss: -0.0058 │ Chain Entr.: 2.031 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00050
# Epoch 1894/2000 │ Loss: -0.0104 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00050
# Epoch 1895/2000 │ Loss: +0.0003 │ Chain Entr.: 2.038 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00050
# Epoch 1896/2000 │ Loss: +0.0016 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1897/2000 │ Loss: -0.0040 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00050
# Epoch 1898/2000 │ Loss: -0.0072 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00050
# Epoch 1899/2000 │ Loss: +0.0073 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00050
# Epoch 1900/2000 │ Loss: -0.0114 │ Chain Entr.: 2.036 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00050
# Epoch 1901/2000 │ Loss: +0.0057 │ Chain Entr.: 2.029 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1902/2000 │ Loss: -0.0044 │ Chain Entr.: 2.038 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00050
# Epoch 1903/2000 │ Loss: -0.0056 │ Chain Entr.: 2.043 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00050
# Epoch 1904/2000 │ Loss: -0.0079 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00050
# Epoch 1905/2000 │ Loss: -0.0096 │ Chain Entr.: 2.034 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00050
# Epoch 1906/2000 │ Loss: -0.0014 │ Chain Entr.: 2.038 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1907/2000 │ Loss: -0.0049 │ Chain Entr.: 2.034 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1908/2000 │ Loss: -0.0035 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.042 │ Learning Rate: 0.00050
# Epoch 1909/2000 │ Loss: +0.0022 │ Chain Entr.: 2.033 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00050
# Epoch 1910/2000 │ Loss: -0.0014 │ Chain Entr.: 2.033 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00050
# Epoch 1911/2000 │ Loss: -0.0096 │ Chain Entr.: 2.028 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00050
# Epoch 1912/2000 │ Loss: +0.0026 │ Chain Entr.: 2.036 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00050
# Epoch 1913/2000 │ Loss: -0.0081 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00050
# Epoch 1914/2000 │ Loss: -0.0024 │ Chain Entr.: 2.029 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1915/2000 │ Loss: -0.0042 │ Chain Entr.: 2.028 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00050
# Epoch 1916/2000 │ Loss: +0.0052 │ Chain Entr.: 2.030 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1917/2000 │ Loss: +0.0008 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00050
# Epoch 1918/2000 │ Loss: -0.0071 │ Chain Entr.: 2.027 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00050
# Epoch 1919/2000 │ Loss: +0.0033 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00050
# Epoch 1920/2000 │ Loss: -0.0127 │ Chain Entr.: 2.030 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00050
# Epoch 1921/2000 │ Loss: -0.0001 │ Chain Entr.: 2.031 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00050
# Epoch 1922/2000 │ Loss: -0.0062 │ Chain Entr.: 2.037 │ Chain Modes: 8 │ Chain Reset Frac.: 0.044 │ Learning Rate: 0.00050
# Epoch 1923/2000 │ Loss: +0.0092 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.039 │ Learning Rate: 0.00050
# Epoch 1924/2000 │ Loss: +0.0045 │ Chain Entr.: 2.008 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00050
# Epoch 1925/2000 │ Loss: -0.0040 │ Chain Entr.: 2.041 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00050
# Epoch 1926/2000 │ Loss: -0.0067 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00050
# Epoch 1927/2000 │ Loss: -0.0161 │ Chain Entr.: 2.036 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1928/2000 │ Loss: -0.0032 │ Chain Entr.: 2.031 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00050
# Epoch 1929/2000 │ Loss: +0.0090 │ Chain Entr.: 2.030 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00050
# Epoch 1930/2000 │ Loss: -0.0005 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00050
# Epoch 1931/2000 │ Loss: -0.0050 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1932/2000 │ Loss: -0.0113 │ Chain Entr.: 2.027 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1933/2000 │ Loss: +0.0056 │ Chain Entr.: 2.034 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1934/2000 │ Loss: -0.0009 │ Chain Entr.: 2.012 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00050
# Epoch 1935/2000 │ Loss: -0.0015 │ Chain Entr.: 2.027 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00050
# Epoch 1936/2000 │ Loss: -0.0046 │ Chain Entr.: 2.036 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00050
# Epoch 1937/2000 │ Loss: -0.0026 │ Chain Entr.: 2.032 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00050
# Epoch 1938/2000 │ Loss: -0.0021 │ Chain Entr.: 2.014 │ Chain Modes: 8 │ Chain Reset Frac.: 0.040 │ Learning Rate: 0.00050
# Epoch 1939/2000 │ Loss: -0.0008 │ Chain Entr.: 2.027 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00050
# Epoch 1940/2000 │ Loss: +0.0013 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00050
# Epoch 1941/2000 │ Loss: -0.0029 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00050
# Epoch 1942/2000 │ Loss: -0.0023 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00050
# Epoch 1943/2000 │ Loss: -0.0082 │ Chain Entr.: 2.038 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00050
# Epoch 1944/2000 │ Loss: -0.0116 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1945/2000 │ Loss: +0.0004 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00050
# Epoch 1946/2000 │ Loss: -0.0036 │ Chain Entr.: 2.035 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1947/2000 │ Loss: -0.0043 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00050
# Epoch 1948/2000 │ Loss: -0.0039 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1949/2000 │ Loss: +0.0033 │ Chain Entr.: 2.018 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00050
# Epoch 1950/2000 │ Loss: -0.0018 │ Chain Entr.: 2.030 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00050
# Epoch 1951/2000 │ Loss: -0.0184 │ Chain Entr.: 2.043 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00050
# Epoch 1952/2000 │ Loss: +0.0100 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00050
# Epoch 1953/2000 │ Loss: -0.0072 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.037 │ Learning Rate: 0.00050
# Epoch 1954/2000 │ Loss: -0.0071 │ Chain Entr.: 2.019 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00050
# Epoch 1955/2000 │ Loss: -0.0153 │ Chain Entr.: 2.029 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1956/2000 │ Loss: +0.0075 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1957/2000 │ Loss: -0.0031 │ Chain Entr.: 2.050 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1958/2000 │ Loss: +0.0014 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.026 │ Learning Rate: 0.00050
# Epoch 1959/2000 │ Loss: -0.0071 │ Chain Entr.: 2.048 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1960/2000 │ Loss: +0.0006 │ Chain Entr.: 2.050 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1961/2000 │ Loss: -0.0081 │ Chain Entr.: 2.037 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1962/2000 │ Loss: -0.0074 │ Chain Entr.: 2.029 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00050
# Epoch 1963/2000 │ Loss: -0.0041 │ Chain Entr.: 2.026 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1964/2000 │ Loss: +0.0090 │ Chain Entr.: 2.013 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00050
# Epoch 1965/2000 │ Loss: -0.0085 │ Chain Entr.: 2.043 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1966/2000 │ Loss: -0.0039 │ Chain Entr.: 2.026 │ Chain Modes: 8 │ Chain Reset Frac.: 0.031 │ Learning Rate: 0.00050
# Epoch 1967/2000 │ Loss: +0.0062 │ Chain Entr.: 2.038 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00050
# Epoch 1968/2000 │ Loss: -0.0020 │ Chain Entr.: 2.037 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00050
# Epoch 1969/2000 │ Loss: -0.0042 │ Chain Entr.: 2.042 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1970/2000 │ Loss: -0.0040 │ Chain Entr.: 2.013 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00050
# Epoch 1971/2000 │ Loss: +0.0019 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00050
# Epoch 1972/2000 │ Loss: +0.0005 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.029 │ Learning Rate: 0.00050
# Epoch 1973/2000 │ Loss: -0.0067 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.028 │ Learning Rate: 0.00050
# Epoch 1974/2000 │ Loss: -0.0101 │ Chain Entr.: 2.043 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1975/2000 │ Loss: +0.0112 │ Chain Entr.: 2.021 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1976/2000 │ Loss: -0.0027 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1977/2000 │ Loss: -0.0016 │ Chain Entr.: 2.036 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00050
# Epoch 1978/2000 │ Loss: -0.0086 │ Chain Entr.: 2.046 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00050
# Epoch 1979/2000 │ Loss: -0.0007 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00050
# Epoch 1980/2000 │ Loss: -0.0023 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.021 │ Learning Rate: 0.00050
# Epoch 1981/2000 │ Loss: -0.0053 │ Chain Entr.: 2.022 │ Chain Modes: 8 │ Chain Reset Frac.: 0.035 │ Learning Rate: 0.00050
# Epoch 1982/2000 │ Loss: -0.0034 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.027 │ Learning Rate: 0.00050
# Epoch 1983/2000 │ Loss: -0.0228 │ Chain Entr.: 2.041 │ Chain Modes: 8 │ Chain Reset Frac.: 0.033 │ Learning Rate: 0.00050
# Epoch 1984/2000 │ Loss: -0.0061 │ Chain Entr.: 2.026 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00050
# Epoch 1985/2000 │ Loss: -0.0022 │ Chain Entr.: 2.005 │ Chain Modes: 8 │ Chain Reset Frac.: 0.034 │ Learning Rate: 0.00050
# Epoch 1986/2000 │ Loss: +0.0193 │ Chain Entr.: 2.017 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00050
# Epoch 1987/2000 │ Loss: +0.0022 │ Chain Entr.: 2.025 │ Chain Modes: 8 │ Chain Reset Frac.: 0.032 │ Learning Rate: 0.00050
# Epoch 1988/2000 │ Loss: -0.0125 │ Chain Entr.: 2.037 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1989/2000 │ Loss: +0.0080 │ Chain Entr.: 2.036 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00050
# Epoch 1990/2000 │ Loss: +0.0010 │ Chain Entr.: 2.024 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00050
# Epoch 1991/2000 │ Loss: -0.0034 │ Chain Entr.: 2.030 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1992/2000 │ Loss: +0.0073 │ Chain Entr.: 2.012 │ Chain Modes: 8 │ Chain Reset Frac.: 0.024 │ Learning Rate: 0.00050
# Epoch 1993/2000 │ Loss: -0.0054 │ Chain Entr.: 2.033 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1994/2000 │ Loss: -0.0199 │ Chain Entr.: 2.016 │ Chain Modes: 8 │ Chain Reset Frac.: 0.020 │ Learning Rate: 0.00050
# Epoch 1995/2000 │ Loss: -0.0028 │ Chain Entr.: 2.042 │ Chain Modes: 8 │ Chain Reset Frac.: 0.030 │ Learning Rate: 0.00050
# Epoch 1996/2000 │ Loss: -0.0040 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.025 │ Learning Rate: 0.00050
# Epoch 1997/2000 │ Loss: +0.0033 │ Chain Entr.: 2.023 │ Chain Modes: 8 │ Chain Reset Frac.: 0.046 │ Learning Rate: 0.00050
# Epoch 1998/2000 │ Loss: -0.0098 │ Chain Entr.: 2.020 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00050
# Epoch 1999/2000 │ Loss: -0.0045 │ Chain Entr.: 2.038 │ Chain Modes: 8 │ Chain Reset Frac.: 0.022 │ Learning Rate: 0.00050
# Epoch 2000/2000 │ Loss: -0.0082 │ Chain Entr.: 2.040 │ Chain Modes: 8 │ Chain Reset Frac.: 0.023 │ Learning Rate: 0.00050
# CPU times: user 14min 6s, sys: 7.56 s, total: 14min 13s
# Wall time: 14min 27s

# %%
epochs = list(metrics_amp.keys())
loss_vals = [metrics_amp[e]['loss'] for e in epochs]
entropy_vals = [metrics_amp[e]['entropy_chain'] for e in epochs]
mode_vals = [metrics_amp[e]['modes_chain'] for e in epochs]
lr_vals = [metrics_amp[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots()

ax1.plot(epochs, loss_vals, label="Amplitude CD Loss", color="tab:blue")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Amplitude CD Loss", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

ax2 = ax1.twinx()
ax2.plot(epochs, entropy_vals, label="Chain Entropy", color="tab:orange")
ax2.set_ylabel("Chain Entropy", color="tab:orange")
ax2.tick_params(axis="y", labelcolor="tab:orange")

ax3 = ax1.twinx()
ax3.spines["right"].set_position(("axes", 1.2))
ax3.plot(epochs, mode_vals, label="Estimated Mode Count", color="tab:green")
ax3.set_ylabel("Mode Count", color="tab:green")
ax3.tick_params(axis="y", labelcolor="tab:green")

ax4 = ax1.twinx()
ax4.spines["right"].set_position(("axes", 1.4))
ax4.plot(epochs, lr_vals, label="Learning Rate", color="tab:red")
ax4.set_ylabel("Learning Rate", color="tab:red")
ax4.tick_params(axis="y", labelcolor="tab:red")

plt.title("CD Loss vs. Entropy vs. Mode Count vs. Learning Rate")
plt.show()

# %%
# shifting the center step to 0 we can approximate an exponential schedule if we choose the high to be
T_high = 2.0
T_low = 0.01
sampling_steps = 10000
sigmoid_schedule_fn = get_sigmoid_curve(high=T_high*2, low=T_low, steps=sampling_steps, falloff=0.0013, center_step=0)
sigmoid_schedule = jnp.array([sigmoid_schedule_fn(i) for i in range(sampling_steps)], dtype=jnp.float32)

key_sample = PRNGKey(1234)

samples_amp = model_amp.apply(
    {"params": state_amp.params},
    n_samples=10_000,
    T_schedule=sigmoid_schedule,
    key=key_sample,
    method=RBM.generate
)

sampled_freq_amp = samples_amp.mean(0)
sampled_freq_amp
# Out:
# Array([0.1187    , 0.1275    , 0.1477    , 0.1248    , 0.1241    ,
#        0.1147    , 0.1236    , 0.11889999], dtype=float32)

# %%
spin_counts = samples_amp.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(12), align='left', edgecolor='black')
plt.xticks(range(11))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
plt.figure(figsize=(10, 5))
x = np.arange(visible_units) + 1
width = 0.35

plt.bar(x - width/2, empirical_freq_amp, width, label="Empirical", alpha=0.7)
plt.bar(x + width/2, sampled_freq_amp, width, label="Sampled", alpha=0.7)

plt.axhline(1 / visible_units, linestyle='--', color='gray', label=f'1/{visible_units} reference')
plt.xlabel("Visible Unit Index")
plt.ylabel("Mean Activation Frequency")
plt.title("Comparison: Empirical vs Sampled Frequencies")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
timestamp = datetime.now().strftime("%Y%m%d%H%M")
model_name = f"rbm_amp_{timestamp}"

checkpoints.save_checkpoint(
    ckpt_dir=str(model_dir.resolve()),
    target=state_amp.params,
    step=0,
    prefix=model_name + "_",
    overwrite=True
)
# Out:
# WARNING:absl:The `aggregate` option is deprecated and will be ignored.
# '/Users/Tonni/Desktop/master-code/neural-quantum-tomo/case_studies/w_aug_v2/models/rbm_amp_202506110124_0'
