# %%
# %reload_ext autoreload
# %autoreload 2

from lib.data_loading import load_measurements, MixedDataLoader

####

from pathlib import Path
from typing import Tuple, Dict, Any, Callable

import jax
import jax.lax
import jax.numpy as jnp
from jax.random import PRNGKey
import optax
from flax.training.train_state import TrainState
from flax.training import checkpoints
from flax import linen as nn

import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings(
    "ignore",
    message=(
        "Couldn't find sharding info under RestoreArgs.*"
    ),
    category=UserWarning,
    module="orbax.checkpoint.type_handlers"
)

data_dir = "data"
model_dir = "./models"
model_prefix = "rbm_amp_202506131953_0"

print(f"Data resides in                         : {data_dir}")
print(f"Amplitude RBM checkpoint to be loaded   : {model_dir}/{model_prefix}")
# Out:
# Data resides in                         : data
# Amplitude RBM checkpoint to be loaded   : ./models/rbm_amp_202506131953_0

# %%
class ConditionalRBM(nn.Module):
    num_visible: int
    num_hidden: int
    conditioner_width: int = 64
    k: int = 1
    T: float = 1.0

    def setup(self):
        # we use frozen RBM parameters
        zeros = lambda shape: jnp.zeros(shape, dtype=jnp.float32)
        self.W = self.variable("rbm", "W", zeros, (self.num_visible, self.num_hidden))
        self.b = self.variable("rbm", "b", zeros, (self.num_visible,))   # global init
        self.c = self.variable("rbm", "c", zeros, (self.num_hidden,))    # global init

    @nn.compact
    def conditioner(self, condition: jnp.ndarray) -> Tuple[jnp.ndarray, jnp.ndarray, jnp.ndarray, jnp.ndarray]:
        # takes in batch of conditions lenght D, in our case one-hot measurement encodings (B, N, 4)
        x = nn.Dense(self.conditioner_width)(condition)     # (B, N, D)
        x = nn.tanh(x)
        x = x.reshape(x.shape[0], -1)                        # (B, N * D)
        x = nn.Dense(2 * (self.num_visible + self.num_hidden))(x)
        split_indices = [self.num_visible, 2 * self.num_visible, 2 * self.num_visible + self.num_hidden]
        gamma_b, beta_b, gamma_c, beta_c = jnp.split(x, split_indices, axis=-1)
        return gamma_b, beta_b, gamma_c, beta_c              # correction parameters have batch dim again (B, N/H)

    @staticmethod
    def encode_one_hot(basis_bits: jnp.ndarray) -> jnp.ndarray:
        basis_int = basis_bits[:, :, 0] * 2 + basis_bits[:, :, 1] # split high and low bits
        return jax.nn.one_hot(basis_int, 4, dtype=jnp.float32)

    @staticmethod
    def prepare_batch(batch: jnp.ndarray) -> Tuple[jnp.ndarray, jnp.ndarray]:
        # split off actual measurements and from basis bits and encode the basis bits as one-hot vectors
        measurements = batch[:, :, 0].astype(jnp.float32)       # (B, N)
        basis_high_bits = batch[:, :, 1].astype(jnp.int32)      # (B, N, 1)
        basis_low_bits = batch[:, :, 2].astype(jnp.int32)

        basis_int = basis_high_bits * 2 + basis_low_bits        # (B, N, 1)
        basis_one_hot = jax.nn.one_hot(basis_int, 4, dtype=jnp.float32)

        return measurements, basis_one_hot

    @staticmethod
    def _free_energy(v, W, b, c) -> jnp.ndarray:
        return -(v @ b) - jnp.sum(jax.nn.softplus(v @ W + c), -1)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c)/T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b)/T)).astype(jnp.float32)
        return v, key

    def __call__(self, batch: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        measurement = batch[:, :, 0].astype(jnp.float32)  # (B, N)
        basis_bits = batch[:, :, 1:].astype(jnp.int32)  # (B, N, 2)
        basis_one_hot = self.encode_one_hot(basis_bits)

        # each measurement sample gets its own FiLM modulation
        gamma_b, beta_b, gamma_c, beta_c = self.conditioner(basis_one_hot)
        b_mod = (1 + gamma_b) * self.b.value + beta_b  # (B, N)
        c_mod = (1 + gamma_c) * self.c.value + beta_c  # (B, H)

        # run a Gibbs chain (k steps) initialized at the data for true CD-k
        key, key_init = jax.random.split(aux_vars["key"])
        gibbs_chain = measurement  # initialize at data
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W.value, b_mod, c_mod, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (gibbs_chain, key))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain)

        # compute per-sample free energies
        free_energy_data  = jax.vmap(self._free_energy, in_axes=(0, None, 0, 0))(measurement, self.W.value, b_mod, c_mod)
        free_energy_model = jax.vmap(self._free_energy, in_axes=(0, None, 0, 0))(gibbs_chain, self.W.value, b_mod, c_mod)

        # pair up the free energies and compute the gap
        free_energy_delta = free_energy_data - free_energy_model  # shape (B,)

        # mean and jitter of the gap
        free_energy_mean = jnp.mean(free_energy_delta)
        free_energy_std  = jnp.std(free_energy_delta)

        # penalize drift from original biases (we need to add a dummy batch dim for broadcasting)
        l2_regularization = (jnp.sum((self.b.value[None, :] - b_mod) ** 2) + jnp.sum((self.c.value[None, :] - c_mod) ** 2))

        loss = free_energy_mean + aux_vars["l2_strength"] * l2_regularization

        aux_vars_out = {
            "key": key,
            "free_energy_mean": free_energy_mean,
            "free_energy_std": free_energy_std,
        }

        return loss, aux_vars_out

    @nn.nowrap
    def generate(self, basis_bits: jnp.ndarray, T_schedule: jnp.ndarray, key: PRNGKey) -> Tuple[jnp.ndarray, PRNGKey]:
        basis_one_hot = self.encode_one_hot(basis_bits)

        gamma_b, beta_b, gamma_c, beta_c = self.conditioner(basis_one_hot)
        b_mod = (1 + gamma_b) * self.b.value + beta_b
        c_mod = (1 + gamma_c) * self.c.value + beta_c

        batch_size, num_visible, _ = basis_bits.shape
        key, key_init = jax.random.split(key, 2)

        gibbs_chain = jax.random.bernoulli(key_init, 0.5, shape=(batch_size, num_visible)).astype(jnp.float32)  # (B, N)
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W.value, b_mod, c_mod, T_schedule[i])
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (gibbs_chain, key))

        return gibbs_chain, key

# %%
@jax.jit
def train_step(
        state: TrainState,
        batch: jnp.ndarray,
        rbm_vars: Dict[str, jnp.ndarray],
        aux_vars: Dict[str, Any]) -> Tuple[TrainState, jnp.ndarray, Dict[str, Any]]:
    loss_fn = lambda params: state.apply_fn({'params': params, 'rbm': rbm_vars}, batch, aux_vars)

    (loss, aux_vars), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    state = state.apply_gradients(grads=grads)
    return state, loss, aux_vars


def train(
        state: TrainState,
        rbm_vars: Dict[str, jnp.ndarray],
        loader: MixedDataLoader,
        num_epochs: int,
        key: PRNGKey,
        l2_strength: float,
        lr_schedule_fn: Callable[[int], float]) -> Tuple[TrainState, Dict[int, float]]:

    metrics: Dict[int, Any] = {}
    gibbs_chain = None

    for epoch in range(num_epochs):
        tot_loss = 0.0

        for batch in loader:
            measurements = batch[:, :, 0].astype(jnp.float32)

            if gibbs_chain is None:
                gibbs_chain = measurements  # initial random init could be better

            key, subkey = jax.random.split(key)
            aux_vars = {
                "key": subkey,
                "l2_strength": l2_strength,
            }

            state, loss, aux_vars = train_step(state, batch, rbm_vars, aux_vars)
            key = aux_vars["key"]
            free_energy_mean = aux_vars["free_energy_mean"]
            free_energy_std = aux_vars["free_energy_std"]

            tot_loss += float(loss)

        avg_loss = tot_loss / len(loader)
        lr = lr_schedule_fn(state.step)

        metrics[epoch] = dict(
            loss=avg_loss,
            free_energy_mean=free_energy_mean,
            free_energy_var=free_energy_std,
            lr=lr
        )

        print(f"Epoch {epoch+1}/{num_epochs} │ "
              f"Loss: {avg_loss:+.4f} │ "
              f"Free En. Mean: {free_energy_mean:.4f} │ "
              f"Free En. STD: {free_energy_std:.4f} │ "
              f"Learning Rate: {lr:.5f}")

    return state, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2

    curve_fn = lambda step: low + (high - low) / (1 + jnp.exp(falloff * (jnp.minimum(step, steps) - center_step)))
    return curve_fn

# %%
# load the RBM parameters and parse the data
rbm_params = checkpoints.restore_checkpoint(ckpt_dir=str(Path(model_dir).resolve()), target=None, prefix=model_prefix)
rbm_vars = {"W": rbm_params["W"], "b": rbm_params["b"], "c": rbm_params["c"]}

file_path = Path("data/w_aug_8MIXED_30000.txt")
data = load_measurements(file_path)
# Out:
# Parsing measurements: 100%|██████████| 30000/30000 [00:01<00:00, 26373.76it/s]

# %%
batch_size      = 2048
num_visible     = 8
num_hidden      = 16
conditioner_width = 64
num_epochs      = 500
k_steps         = 50
init_lr         = 1e-2                      # lucky guess. a larger learning rate is actually better as it seems
final_lr        = init_lr * 0.1
l2_strength     = 0

key = jax.random.PRNGKey(0)

key, key_params, key_dummy = jax.random.split(key, 3)

model = ConditionalRBM(num_visible=num_visible, num_hidden=num_hidden, conditioner_width=conditioner_width, k=k_steps)

batch_dummy = jnp.zeros((batch_size, num_visible, 3), dtype=jnp.float32)
aux_vars_dummy = { "key": key_dummy, "l2_strength": l2_strength}
variables = model.init({"params": key_params}, batch_dummy, aux_vars_dummy)

loader = MixedDataLoader(data, batch_size=batch_size)

schedule_steps = num_epochs * len(loader)
lr_schedule_fn = get_sigmoid_curve(high=init_lr, low=final_lr, steps=schedule_steps, falloff=0.0005)
optim = optax.adam(lr_schedule_fn)

state = TrainState.create(apply_fn=model.apply, params=variables['params'], tx=optim)

state, metrics = train(state, rbm_vars, loader, num_epochs, key, l2_strength, lr_schedule_fn)
# Out:
# Epoch 1/500 │ Loss: +6.5021 │ Free En. Mean: 3.4688 │ Free En. Var: 2.9591 │ Learning Rate: 0.00880
# Epoch 2/500 │ Loss: +2.4913 │ Free En. Mean: 1.8109 │ Free En. Var: 2.4744 │ Learning Rate: 0.00879
# Epoch 3/500 │ Loss: +1.8316 │ Free En. Mean: 1.7404 │ Free En. Var: 2.5363 │ Learning Rate: 0.00878
# Epoch 4/500 │ Loss: +1.6698 │ Free En. Mean: 1.7018 │ Free En. Var: 2.4542 │ Learning Rate: 0.00877
# Epoch 5/500 │ Loss: +1.5856 │ Free En. Mean: 1.6923 │ Free En. Var: 2.4672 │ Learning Rate: 0.00876
# Epoch 6/500 │ Loss: +1.5798 │ Free En. Mean: 1.6962 │ Free En. Var: 2.3893 │ Learning Rate: 0.00876
# Epoch 7/500 │ Loss: +1.5825 │ Free En. Mean: 1.6445 │ Free En. Var: 2.4266 │ Learning Rate: 0.00875
# Epoch 8/500 │ Loss: +1.5578 │ Free En. Mean: 1.5974 │ Free En. Var: 2.3842 │ Learning Rate: 0.00874
# Epoch 9/500 │ Loss: +1.5589 │ Free En. Mean: 1.5627 │ Free En. Var: 2.4199 │ Learning Rate: 0.00873
# Epoch 10/500 │ Loss: +1.5643 │ Free En. Mean: 1.5291 │ Free En. Var: 2.3040 │ Learning Rate: 0.00872
# Epoch 11/500 │ Loss: +1.5535 │ Free En. Mean: 1.4513 │ Free En. Var: 2.3674 │ Learning Rate: 0.00872
# Epoch 12/500 │ Loss: +1.5476 │ Free En. Mean: 1.5638 │ Free En. Var: 2.3487 │ Learning Rate: 0.00871
# Epoch 13/500 │ Loss: +1.5494 │ Free En. Mean: 1.4510 │ Free En. Var: 2.3193 │ Learning Rate: 0.00870
# Epoch 14/500 │ Loss: +1.5124 │ Free En. Mean: 1.5652 │ Free En. Var: 2.3787 │ Learning Rate: 0.00869
# Epoch 15/500 │ Loss: +1.5093 │ Free En. Mean: 1.4044 │ Free En. Var: 2.2959 │ Learning Rate: 0.00868
# Epoch 16/500 │ Loss: +1.4825 │ Free En. Mean: 1.4956 │ Free En. Var: 2.2421 │ Learning Rate: 0.00867
# Epoch 17/500 │ Loss: +1.4391 │ Free En. Mean: 1.4696 │ Free En. Var: 2.2230 │ Learning Rate: 0.00866
# Epoch 18/500 │ Loss: +1.4160 │ Free En. Mean: 1.4039 │ Free En. Var: 2.1279 │ Learning Rate: 0.00866
# Epoch 19/500 │ Loss: +1.3813 │ Free En. Mean: 1.3043 │ Free En. Var: 2.0688 │ Learning Rate: 0.00865
# Epoch 20/500 │ Loss: +1.1885 │ Free En. Mean: 0.9649 │ Free En. Var: 1.8707 │ Learning Rate: 0.00864
# Epoch 21/500 │ Loss: +0.6991 │ Free En. Mean: 0.5846 │ Free En. Var: 1.5827 │ Learning Rate: 0.00863
# Epoch 22/500 │ Loss: +0.2245 │ Free En. Mean: 0.0252 │ Free En. Var: 1.1461 │ Learning Rate: 0.00862
# Epoch 23/500 │ Loss: +0.2319 │ Free En. Mean: 0.0461 │ Free En. Var: 1.0691 │ Learning Rate: 0.00861
# Epoch 24/500 │ Loss: +0.1648 │ Free En. Mean: 0.1552 │ Free En. Var: 1.2217 │ Learning Rate: 0.00860
# Epoch 25/500 │ Loss: +0.1321 │ Free En. Mean: 0.1318 │ Free En. Var: 1.2134 │ Learning Rate: 0.00860
# Epoch 26/500 │ Loss: +0.1499 │ Free En. Mean: 0.1184 │ Free En. Var: 1.2259 │ Learning Rate: 0.00859
# Epoch 27/500 │ Loss: +0.1291 │ Free En. Mean: 0.1457 │ Free En. Var: 1.3630 │ Learning Rate: 0.00858
# Epoch 28/500 │ Loss: +0.1319 │ Free En. Mean: 0.0425 │ Free En. Var: 1.1226 │ Learning Rate: 0.00857
# Epoch 29/500 │ Loss: +0.1106 │ Free En. Mean: 0.1213 │ Free En. Var: 1.2446 │ Learning Rate: 0.00856
# Epoch 30/500 │ Loss: +0.1061 │ Free En. Mean: 0.1428 │ Free En. Var: 1.2254 │ Learning Rate: 0.00855
# Epoch 31/500 │ Loss: +0.1249 │ Free En. Mean: 0.1810 │ Free En. Var: 1.4308 │ Learning Rate: 0.00854
# Epoch 32/500 │ Loss: +0.0987 │ Free En. Mean: 0.1703 │ Free En. Var: 1.3413 │ Learning Rate: 0.00853
# Epoch 33/500 │ Loss: +0.1243 │ Free En. Mean: 0.2615 │ Free En. Var: 1.4175 │ Learning Rate: 0.00852
# Epoch 34/500 │ Loss: +0.1245 │ Free En. Mean: 0.1397 │ Free En. Var: 1.2879 │ Learning Rate: 0.00851
# Epoch 35/500 │ Loss: +0.1049 │ Free En. Mean: 0.0085 │ Free En. Var: 1.1308 │ Learning Rate: 0.00850
# Epoch 36/500 │ Loss: +0.1020 │ Free En. Mean: 0.0467 │ Free En. Var: 1.2232 │ Learning Rate: 0.00849
# Epoch 37/500 │ Loss: +0.1346 │ Free En. Mean: 0.0671 │ Free En. Var: 1.2066 │ Learning Rate: 0.00849
# Epoch 38/500 │ Loss: +0.1097 │ Free En. Mean: 0.1485 │ Free En. Var: 1.3499 │ Learning Rate: 0.00848
# Epoch 39/500 │ Loss: +0.1226 │ Free En. Mean: 0.2993 │ Free En. Var: 1.3657 │ Learning Rate: 0.00847
# Epoch 40/500 │ Loss: +0.0986 │ Free En. Mean: 0.1159 │ Free En. Var: 1.3059 │ Learning Rate: 0.00846
# Epoch 41/500 │ Loss: +0.1034 │ Free En. Mean: 0.1322 │ Free En. Var: 1.2645 │ Learning Rate: 0.00845
# Epoch 42/500 │ Loss: +0.1249 │ Free En. Mean: 0.0818 │ Free En. Var: 1.2658 │ Learning Rate: 0.00844
# Epoch 43/500 │ Loss: +0.1621 │ Free En. Mean: 0.2642 │ Free En. Var: 1.4338 │ Learning Rate: 0.00843
# Epoch 44/500 │ Loss: +0.1252 │ Free En. Mean: 0.1966 │ Free En. Var: 1.2875 │ Learning Rate: 0.00842
# Epoch 45/500 │ Loss: +0.0797 │ Free En. Mean: 0.1153 │ Free En. Var: 1.3327 │ Learning Rate: 0.00841
# Epoch 46/500 │ Loss: +0.0689 │ Free En. Mean: 0.0983 │ Free En. Var: 1.2165 │ Learning Rate: 0.00840
# Epoch 47/500 │ Loss: +0.0714 │ Free En. Mean: 0.1225 │ Free En. Var: 1.2087 │ Learning Rate: 0.00839
# Epoch 48/500 │ Loss: +0.0602 │ Free En. Mean: -0.0469 │ Free En. Var: 1.1254 │ Learning Rate: 0.00838
# Epoch 49/500 │ Loss: +0.0470 │ Free En. Mean: 0.0253 │ Free En. Var: 1.1446 │ Learning Rate: 0.00837
# Epoch 50/500 │ Loss: +0.0650 │ Free En. Mean: 0.1789 │ Free En. Var: 1.3222 │ Learning Rate: 0.00836
# Epoch 51/500 │ Loss: +0.0801 │ Free En. Mean: 0.0499 │ Free En. Var: 1.2248 │ Learning Rate: 0.00835
# Epoch 52/500 │ Loss: +0.0587 │ Free En. Mean: 0.1762 │ Free En. Var: 1.2824 │ Learning Rate: 0.00834
# Epoch 53/500 │ Loss: +0.0713 │ Free En. Mean: 0.0208 │ Free En. Var: 1.2339 │ Learning Rate: 0.00833
# Epoch 54/500 │ Loss: +0.0744 │ Free En. Mean: 0.0358 │ Free En. Var: 1.2802 │ Learning Rate: 0.00832
# Epoch 55/500 │ Loss: +0.0977 │ Free En. Mean: 0.1609 │ Free En. Var: 1.3393 │ Learning Rate: 0.00831
# Epoch 56/500 │ Loss: +0.1149 │ Free En. Mean: 0.1146 │ Free En. Var: 1.3273 │ Learning Rate: 0.00830
# Epoch 57/500 │ Loss: +0.1088 │ Free En. Mean: 0.2082 │ Free En. Var: 1.3382 │ Learning Rate: 0.00829
# Epoch 58/500 │ Loss: +0.0670 │ Free En. Mean: 0.1069 │ Free En. Var: 1.2411 │ Learning Rate: 0.00828
# Epoch 59/500 │ Loss: +0.0813 │ Free En. Mean: 0.1070 │ Free En. Var: 1.2234 │ Learning Rate: 0.00827
# Epoch 60/500 │ Loss: +0.0591 │ Free En. Mean: -0.0100 │ Free En. Var: 1.1238 │ Learning Rate: 0.00826
# Epoch 61/500 │ Loss: +0.0483 │ Free En. Mean: 0.0233 │ Free En. Var: 1.2335 │ Learning Rate: 0.00824
# Epoch 62/500 │ Loss: +0.0634 │ Free En. Mean: 0.0524 │ Free En. Var: 1.2375 │ Learning Rate: 0.00823
# Epoch 63/500 │ Loss: +0.0663 │ Free En. Mean: 0.2440 │ Free En. Var: 1.4403 │ Learning Rate: 0.00822
# Epoch 64/500 │ Loss: +0.0579 │ Free En. Mean: 0.0414 │ Free En. Var: 1.2564 │ Learning Rate: 0.00821
# Epoch 65/500 │ Loss: +0.0434 │ Free En. Mean: -0.0564 │ Free En. Var: 1.1064 │ Learning Rate: 0.00820
# Epoch 66/500 │ Loss: +0.0753 │ Free En. Mean: -0.0338 │ Free En. Var: 1.0723 │ Learning Rate: 0.00819
# Epoch 67/500 │ Loss: +0.0707 │ Free En. Mean: 0.0348 │ Free En. Var: 1.1187 │ Learning Rate: 0.00818
# Epoch 68/500 │ Loss: +0.0671 │ Free En. Mean: 0.0183 │ Free En. Var: 1.1278 │ Learning Rate: 0.00817
# Epoch 69/500 │ Loss: +0.0995 │ Free En. Mean: 0.0509 │ Free En. Var: 1.1706 │ Learning Rate: 0.00816
# Epoch 70/500 │ Loss: +0.0815 │ Free En. Mean: 0.0314 │ Free En. Var: 1.1249 │ Learning Rate: 0.00815
# Epoch 71/500 │ Loss: +0.0718 │ Free En. Mean: 0.0331 │ Free En. Var: 1.1622 │ Learning Rate: 0.00814
# Epoch 72/500 │ Loss: +0.0873 │ Free En. Mean: 0.1131 │ Free En. Var: 1.2976 │ Learning Rate: 0.00812
# Epoch 73/500 │ Loss: +0.0555 │ Free En. Mean: 0.0797 │ Free En. Var: 1.1976 │ Learning Rate: 0.00811
# Epoch 74/500 │ Loss: +0.0531 │ Free En. Mean: 0.0733 │ Free En. Var: 1.1488 │ Learning Rate: 0.00810
# Epoch 75/500 │ Loss: +0.0473 │ Free En. Mean: 0.1253 │ Free En. Var: 1.3039 │ Learning Rate: 0.00809
# Epoch 76/500 │ Loss: +0.0402 │ Free En. Mean: 0.0656 │ Free En. Var: 1.1818 │ Learning Rate: 0.00808
# Epoch 77/500 │ Loss: +0.0586 │ Free En. Mean: 0.1533 │ Free En. Var: 1.3210 │ Learning Rate: 0.00807
# Epoch 78/500 │ Loss: +0.0535 │ Free En. Mean: 0.0277 │ Free En. Var: 1.1961 │ Learning Rate: 0.00806
# Epoch 79/500 │ Loss: +0.0351 │ Free En. Mean: -0.0320 │ Free En. Var: 1.0936 │ Learning Rate: 0.00805
# Epoch 80/500 │ Loss: +0.0779 │ Free En. Mean: 0.1093 │ Free En. Var: 1.1337 │ Learning Rate: 0.00803
# Epoch 81/500 │ Loss: +0.0390 │ Free En. Mean: -0.0586 │ Free En. Var: 1.1595 │ Learning Rate: 0.00802
# Epoch 82/500 │ Loss: +0.0501 │ Free En. Mean: 0.0183 │ Free En. Var: 1.1653 │ Learning Rate: 0.00801
# Epoch 83/500 │ Loss: +0.0552 │ Free En. Mean: 0.0954 │ Free En. Var: 1.2524 │ Learning Rate: 0.00800
# Epoch 84/500 │ Loss: +0.0791 │ Free En. Mean: 0.1992 │ Free En. Var: 1.3824 │ Learning Rate: 0.00799
# Epoch 85/500 │ Loss: +0.0726 │ Free En. Mean: 0.1702 │ Free En. Var: 1.4035 │ Learning Rate: 0.00798
# Epoch 86/500 │ Loss: +0.0455 │ Free En. Mean: 0.0942 │ Free En. Var: 1.2422 │ Learning Rate: 0.00796
# Epoch 87/500 │ Loss: +0.0746 │ Free En. Mean: 0.1954 │ Free En. Var: 1.3103 │ Learning Rate: 0.00795
# Epoch 88/500 │ Loss: +0.0700 │ Free En. Mean: 0.1642 │ Free En. Var: 1.3213 │ Learning Rate: 0.00794
# Epoch 89/500 │ Loss: +0.0457 │ Free En. Mean: -0.0007 │ Free En. Var: 1.1560 │ Learning Rate: 0.00793
# Epoch 90/500 │ Loss: +0.0294 │ Free En. Mean: -0.0322 │ Free En. Var: 1.1191 │ Learning Rate: 0.00792
# Epoch 91/500 │ Loss: +0.0387 │ Free En. Mean: -0.0071 │ Free En. Var: 1.1544 │ Learning Rate: 0.00790
# Epoch 92/500 │ Loss: +0.0593 │ Free En. Mean: 0.0749 │ Free En. Var: 1.1849 │ Learning Rate: 0.00789
# Epoch 93/500 │ Loss: +0.0659 │ Free En. Mean: -0.0171 │ Free En. Var: 1.1376 │ Learning Rate: 0.00788
# Epoch 94/500 │ Loss: +0.0517 │ Free En. Mean: -0.0103 │ Free En. Var: 1.1289 │ Learning Rate: 0.00787
# Epoch 95/500 │ Loss: +0.0430 │ Free En. Mean: -0.0432 │ Free En. Var: 1.0508 │ Learning Rate: 0.00786
# Epoch 96/500 │ Loss: +0.0662 │ Free En. Mean: 0.0136 │ Free En. Var: 1.1030 │ Learning Rate: 0.00784
# Epoch 97/500 │ Loss: +0.0803 │ Free En. Mean: 0.0848 │ Free En. Var: 1.1985 │ Learning Rate: 0.00783
# Epoch 98/500 │ Loss: +0.0484 │ Free En. Mean: 0.0789 │ Free En. Var: 1.2978 │ Learning Rate: 0.00782
# Epoch 99/500 │ Loss: +0.0597 │ Free En. Mean: 0.0932 │ Free En. Var: 1.2825 │ Learning Rate: 0.00781
# Epoch 100/500 │ Loss: +0.0737 │ Free En. Mean: 0.1172 │ Free En. Var: 1.2982 │ Learning Rate: 0.00779
# Epoch 101/500 │ Loss: +0.0730 │ Free En. Mean: 0.0207 │ Free En. Var: 1.0654 │ Learning Rate: 0.00778
# Epoch 102/500 │ Loss: +0.0642 │ Free En. Mean: 0.0606 │ Free En. Var: 1.2150 │ Learning Rate: 0.00777
# Epoch 103/500 │ Loss: +0.0344 │ Free En. Mean: 0.0460 │ Free En. Var: 1.2875 │ Learning Rate: 0.00776
# Epoch 104/500 │ Loss: +0.0416 │ Free En. Mean: 0.1299 │ Free En. Var: 1.3146 │ Learning Rate: 0.00774
# Epoch 105/500 │ Loss: +0.0290 │ Free En. Mean: 0.0660 │ Free En. Var: 1.1684 │ Learning Rate: 0.00773
# Epoch 106/500 │ Loss: +0.0315 │ Free En. Mean: 0.0155 │ Free En. Var: 1.1311 │ Learning Rate: 0.00772
# Epoch 107/500 │ Loss: +0.0282 │ Free En. Mean: 0.0078 │ Free En. Var: 1.1532 │ Learning Rate: 0.00771
# Epoch 108/500 │ Loss: +0.0549 │ Free En. Mean: 0.1169 │ Free En. Var: 1.2272 │ Learning Rate: 0.00769
# Epoch 109/500 │ Loss: +0.0621 │ Free En. Mean: 0.0292 │ Free En. Var: 1.1328 │ Learning Rate: 0.00768
# Epoch 110/500 │ Loss: +0.0662 │ Free En. Mean: -0.0084 │ Free En. Var: 1.1915 │ Learning Rate: 0.00767
# Epoch 111/500 │ Loss: +0.0358 │ Free En. Mean: 0.0452 │ Free En. Var: 1.2688 │ Learning Rate: 0.00765
# Epoch 112/500 │ Loss: +0.0483 │ Free En. Mean: -0.0320 │ Free En. Var: 1.1314 │ Learning Rate: 0.00764
# Epoch 113/500 │ Loss: +0.0331 │ Free En. Mean: -0.0113 │ Free En. Var: 1.1237 │ Learning Rate: 0.00763
# Epoch 114/500 │ Loss: +0.0425 │ Free En. Mean: 0.0380 │ Free En. Var: 1.1895 │ Learning Rate: 0.00761
# Epoch 115/500 │ Loss: +0.0369 │ Free En. Mean: 0.0029 │ Free En. Var: 1.1581 │ Learning Rate: 0.00760
# Epoch 116/500 │ Loss: +0.0444 │ Free En. Mean: 0.0700 │ Free En. Var: 1.2955 │ Learning Rate: 0.00759
# Epoch 117/500 │ Loss: +0.0435 │ Free En. Mean: 0.0705 │ Free En. Var: 1.2392 │ Learning Rate: 0.00758
# Epoch 118/500 │ Loss: +0.0391 │ Free En. Mean: 0.1802 │ Free En. Var: 1.2996 │ Learning Rate: 0.00756
# Epoch 119/500 │ Loss: +0.0232 │ Free En. Mean: -0.0475 │ Free En. Var: 1.0704 │ Learning Rate: 0.00755
# Epoch 120/500 │ Loss: +0.0319 │ Free En. Mean: 0.0012 │ Free En. Var: 1.0812 │ Learning Rate: 0.00754
# Epoch 121/500 │ Loss: +0.0261 │ Free En. Mean: -0.0605 │ Free En. Var: 1.1037 │ Learning Rate: 0.00752
# Epoch 122/500 │ Loss: +0.0581 │ Free En. Mean: 0.0029 │ Free En. Var: 1.0441 │ Learning Rate: 0.00751
# Epoch 123/500 │ Loss: +0.0449 │ Free En. Mean: 0.0430 │ Free En. Var: 1.2417 │ Learning Rate: 0.00749
# Epoch 124/500 │ Loss: +0.0436 │ Free En. Mean: 0.0912 │ Free En. Var: 1.2569 │ Learning Rate: 0.00748
# Epoch 125/500 │ Loss: +0.0528 │ Free En. Mean: 0.0996 │ Free En. Var: 1.1819 │ Learning Rate: 0.00747
# Epoch 126/500 │ Loss: +0.0379 │ Free En. Mean: 0.0984 │ Free En. Var: 1.1875 │ Learning Rate: 0.00745
# Epoch 127/500 │ Loss: +0.0613 │ Free En. Mean: 0.1123 │ Free En. Var: 1.3895 │ Learning Rate: 0.00744
# Epoch 128/500 │ Loss: +0.0553 │ Free En. Mean: 0.0502 │ Free En. Var: 1.1977 │ Learning Rate: 0.00743
# Epoch 129/500 │ Loss: +0.0559 │ Free En. Mean: 0.0021 │ Free En. Var: 1.1572 │ Learning Rate: 0.00741
# Epoch 130/500 │ Loss: +0.0524 │ Free En. Mean: 0.0286 │ Free En. Var: 1.1830 │ Learning Rate: 0.00740
# Epoch 131/500 │ Loss: +0.0454 │ Free En. Mean: 0.0896 │ Free En. Var: 1.1734 │ Learning Rate: 0.00738
# Epoch 132/500 │ Loss: +0.0687 │ Free En. Mean: 0.0056 │ Free En. Var: 1.1612 │ Learning Rate: 0.00737
# Epoch 133/500 │ Loss: +0.0421 │ Free En. Mean: -0.0220 │ Free En. Var: 1.1554 │ Learning Rate: 0.00736
# Epoch 134/500 │ Loss: +0.0393 │ Free En. Mean: 0.0826 │ Free En. Var: 1.2125 │ Learning Rate: 0.00734
# Epoch 135/500 │ Loss: +0.0300 │ Free En. Mean: 0.0735 │ Free En. Var: 1.2511 │ Learning Rate: 0.00733
# Epoch 136/500 │ Loss: +0.0227 │ Free En. Mean: 0.0423 │ Free En. Var: 1.2500 │ Learning Rate: 0.00731
# Epoch 137/500 │ Loss: +0.0580 │ Free En. Mean: 0.0840 │ Free En. Var: 1.2681 │ Learning Rate: 0.00730
# Epoch 138/500 │ Loss: +0.0349 │ Free En. Mean: 0.1027 │ Free En. Var: 1.2348 │ Learning Rate: 0.00729
# Epoch 139/500 │ Loss: +0.0130 │ Free En. Mean: 0.0330 │ Free En. Var: 1.2193 │ Learning Rate: 0.00727
# Epoch 140/500 │ Loss: +0.0264 │ Free En. Mean: -0.0213 │ Free En. Var: 1.1751 │ Learning Rate: 0.00726
# Epoch 141/500 │ Loss: +0.0534 │ Free En. Mean: 0.0854 │ Free En. Var: 1.2312 │ Learning Rate: 0.00724
# Epoch 142/500 │ Loss: +0.0319 │ Free En. Mean: 0.1057 │ Free En. Var: 1.2448 │ Learning Rate: 0.00723
# Epoch 143/500 │ Loss: +0.0475 │ Free En. Mean: 0.0101 │ Free En. Var: 1.1978 │ Learning Rate: 0.00721
# Epoch 144/500 │ Loss: +0.0347 │ Free En. Mean: 0.0765 │ Free En. Var: 1.2204 │ Learning Rate: 0.00720
# Epoch 145/500 │ Loss: +0.0352 │ Free En. Mean: 0.0155 │ Free En. Var: 1.1539 │ Learning Rate: 0.00719
# Epoch 146/500 │ Loss: +0.0347 │ Free En. Mean: -0.0483 │ Free En. Var: 1.1414 │ Learning Rate: 0.00717
# Epoch 147/500 │ Loss: +0.0421 │ Free En. Mean: -0.0542 │ Free En. Var: 1.0799 │ Learning Rate: 0.00716
# Epoch 148/500 │ Loss: +0.0322 │ Free En. Mean: 0.0049 │ Free En. Var: 1.2100 │ Learning Rate: 0.00714
# Epoch 149/500 │ Loss: +0.0434 │ Free En. Mean: 0.0396 │ Free En. Var: 1.2095 │ Learning Rate: 0.00713
# Epoch 150/500 │ Loss: +0.0431 │ Free En. Mean: 0.0197 │ Free En. Var: 1.1133 │ Learning Rate: 0.00711
# Epoch 151/500 │ Loss: +0.0532 │ Free En. Mean: 0.1271 │ Free En. Var: 1.3427 │ Learning Rate: 0.00710
# Epoch 152/500 │ Loss: +0.0482 │ Free En. Mean: 0.1306 │ Free En. Var: 1.2902 │ Learning Rate: 0.00708
# Epoch 153/500 │ Loss: +0.0209 │ Free En. Mean: 0.0454 │ Free En. Var: 1.2106 │ Learning Rate: 0.00707
# Epoch 154/500 │ Loss: +0.0478 │ Free En. Mean: 0.0247 │ Free En. Var: 1.1865 │ Learning Rate: 0.00705
# Epoch 155/500 │ Loss: +0.0490 │ Free En. Mean: 0.0799 │ Free En. Var: 1.2666 │ Learning Rate: 0.00704
# Epoch 156/500 │ Loss: +0.0395 │ Free En. Mean: 0.0683 │ Free En. Var: 1.2375 │ Learning Rate: 0.00702
# Epoch 157/500 │ Loss: +0.0472 │ Free En. Mean: 0.0921 │ Free En. Var: 1.2333 │ Learning Rate: 0.00701
# Epoch 158/500 │ Loss: +0.0435 │ Free En. Mean: 0.0324 │ Free En. Var: 1.2587 │ Learning Rate: 0.00699
# Epoch 159/500 │ Loss: +0.0283 │ Free En. Mean: -0.0147 │ Free En. Var: 1.1038 │ Learning Rate: 0.00698
# Epoch 160/500 │ Loss: +0.0446 │ Free En. Mean: 0.1187 │ Free En. Var: 1.2780 │ Learning Rate: 0.00696
# Epoch 161/500 │ Loss: +0.0533 │ Free En. Mean: 0.0320 │ Free En. Var: 1.1202 │ Learning Rate: 0.00695
# Epoch 162/500 │ Loss: +0.0463 │ Free En. Mean: 0.0407 │ Free En. Var: 1.2754 │ Learning Rate: 0.00693
# Epoch 163/500 │ Loss: +0.0342 │ Free En. Mean: 0.1014 │ Free En. Var: 1.3234 │ Learning Rate: 0.00692
# Epoch 164/500 │ Loss: +0.0653 │ Free En. Mean: 0.0656 │ Free En. Var: 1.1724 │ Learning Rate: 0.00690
# Epoch 165/500 │ Loss: +0.0425 │ Free En. Mean: 0.0494 │ Free En. Var: 1.2666 │ Learning Rate: 0.00689
# Epoch 166/500 │ Loss: +0.0167 │ Free En. Mean: 0.0212 │ Free En. Var: 1.1894 │ Learning Rate: 0.00687
# Epoch 167/500 │ Loss: +0.0455 │ Free En. Mean: 0.1605 │ Free En. Var: 1.2709 │ Learning Rate: 0.00686
# Epoch 168/500 │ Loss: +0.0417 │ Free En. Mean: -0.0312 │ Free En. Var: 1.0776 │ Learning Rate: 0.00684
# Epoch 169/500 │ Loss: +0.0406 │ Free En. Mean: 0.0813 │ Free En. Var: 1.2795 │ Learning Rate: 0.00683
# Epoch 170/500 │ Loss: +0.0390 │ Free En. Mean: 0.1304 │ Free En. Var: 1.2239 │ Learning Rate: 0.00681
# Epoch 171/500 │ Loss: +0.0146 │ Free En. Mean: 0.0264 │ Free En. Var: 1.2022 │ Learning Rate: 0.00680
# Epoch 172/500 │ Loss: +0.0526 │ Free En. Mean: 0.0170 │ Free En. Var: 1.1615 │ Learning Rate: 0.00678
# Epoch 173/500 │ Loss: +0.0501 │ Free En. Mean: 0.0558 │ Free En. Var: 1.2429 │ Learning Rate: 0.00676
# Epoch 174/500 │ Loss: +0.0348 │ Free En. Mean: 0.0424 │ Free En. Var: 1.3053 │ Learning Rate: 0.00675
# Epoch 175/500 │ Loss: +0.0489 │ Free En. Mean: 0.1210 │ Free En. Var: 1.3723 │ Learning Rate: 0.00673
# Epoch 176/500 │ Loss: +0.0516 │ Free En. Mean: 0.1042 │ Free En. Var: 1.2914 │ Learning Rate: 0.00672
# Epoch 177/500 │ Loss: +0.0343 │ Free En. Mean: 0.0427 │ Free En. Var: 1.1904 │ Learning Rate: 0.00670
# Epoch 178/500 │ Loss: +0.0420 │ Free En. Mean: 0.0357 │ Free En. Var: 1.1863 │ Learning Rate: 0.00669
# Epoch 179/500 │ Loss: +0.0315 │ Free En. Mean: 0.0598 │ Free En. Var: 1.2137 │ Learning Rate: 0.00667
# Epoch 180/500 │ Loss: +0.0301 │ Free En. Mean: -0.0104 │ Free En. Var: 1.1311 │ Learning Rate: 0.00665
# Epoch 181/500 │ Loss: +0.0317 │ Free En. Mean: 0.0082 │ Free En. Var: 1.2159 │ Learning Rate: 0.00664
# Epoch 182/500 │ Loss: +0.0300 │ Free En. Mean: 0.0814 │ Free En. Var: 1.2704 │ Learning Rate: 0.00662
# Epoch 183/500 │ Loss: +0.0622 │ Free En. Mean: 0.0541 │ Free En. Var: 1.1220 │ Learning Rate: 0.00661
# Epoch 184/500 │ Loss: +0.0468 │ Free En. Mean: 0.0749 │ Free En. Var: 1.1783 │ Learning Rate: 0.00659
# Epoch 185/500 │ Loss: +0.0413 │ Free En. Mean: 0.0783 │ Free En. Var: 1.2367 │ Learning Rate: 0.00658
# Epoch 186/500 │ Loss: +0.0269 │ Free En. Mean: -0.0013 │ Free En. Var: 1.1987 │ Learning Rate: 0.00656
# Epoch 187/500 │ Loss: +0.0234 │ Free En. Mean: 0.0463 │ Free En. Var: 1.1882 │ Learning Rate: 0.00654
# Epoch 188/500 │ Loss: +0.0264 │ Free En. Mean: 0.0687 │ Free En. Var: 1.1785 │ Learning Rate: 0.00653
# Epoch 189/500 │ Loss: +0.0260 │ Free En. Mean: 0.0653 │ Free En. Var: 1.2335 │ Learning Rate: 0.00651
# Epoch 190/500 │ Loss: +0.0229 │ Free En. Mean: 0.0902 │ Free En. Var: 1.2860 │ Learning Rate: 0.00650
# Epoch 191/500 │ Loss: +0.0267 │ Free En. Mean: 0.0072 │ Free En. Var: 1.1506 │ Learning Rate: 0.00648
# Epoch 192/500 │ Loss: +0.0402 │ Free En. Mean: 0.0880 │ Free En. Var: 1.1357 │ Learning Rate: 0.00646
# Epoch 193/500 │ Loss: +0.0282 │ Free En. Mean: -0.0259 │ Free En. Var: 1.1699 │ Learning Rate: 0.00645
# Epoch 194/500 │ Loss: +0.0259 │ Free En. Mean: -0.0955 │ Free En. Var: 1.1236 │ Learning Rate: 0.00643
# Epoch 195/500 │ Loss: +0.0781 │ Free En. Mean: 0.1795 │ Free En. Var: 1.3351 │ Learning Rate: 0.00642
# Epoch 196/500 │ Loss: +0.0359 │ Free En. Mean: 0.0741 │ Free En. Var: 1.1790 │ Learning Rate: 0.00640
# Epoch 197/500 │ Loss: +0.0448 │ Free En. Mean: 0.0570 │ Free En. Var: 1.2031 │ Learning Rate: 0.00638
# Epoch 198/500 │ Loss: +0.0463 │ Free En. Mean: -0.0123 │ Free En. Var: 1.1450 │ Learning Rate: 0.00637
# Epoch 199/500 │ Loss: +0.0237 │ Free En. Mean: 0.0731 │ Free En. Var: 1.1893 │ Learning Rate: 0.00635
# Epoch 200/500 │ Loss: +0.0249 │ Free En. Mean: 0.0357 │ Free En. Var: 1.1613 │ Learning Rate: 0.00633
# Epoch 201/500 │ Loss: +0.0300 │ Free En. Mean: 0.0029 │ Free En. Var: 1.1602 │ Learning Rate: 0.00632
# Epoch 202/500 │ Loss: +0.0292 │ Free En. Mean: -0.0021 │ Free En. Var: 1.2158 │ Learning Rate: 0.00630
# Epoch 203/500 │ Loss: +0.0302 │ Free En. Mean: -0.0234 │ Free En. Var: 1.2063 │ Learning Rate: 0.00629
# Epoch 204/500 │ Loss: +0.0406 │ Free En. Mean: 0.0943 │ Free En. Var: 1.2499 │ Learning Rate: 0.00627
# Epoch 205/500 │ Loss: +0.0383 │ Free En. Mean: 0.0501 │ Free En. Var: 1.2681 │ Learning Rate: 0.00625
# Epoch 206/500 │ Loss: +0.0289 │ Free En. Mean: 0.0341 │ Free En. Var: 1.2431 │ Learning Rate: 0.00624
# Epoch 207/500 │ Loss: +0.0329 │ Free En. Mean: 0.0075 │ Free En. Var: 1.1037 │ Learning Rate: 0.00622
# Epoch 208/500 │ Loss: +0.0342 │ Free En. Mean: 0.1099 │ Free En. Var: 1.2671 │ Learning Rate: 0.00620
# Epoch 209/500 │ Loss: +0.0274 │ Free En. Mean: -0.0063 │ Free En. Var: 1.1106 │ Learning Rate: 0.00619
# Epoch 210/500 │ Loss: +0.0369 │ Free En. Mean: 0.0114 │ Free En. Var: 1.1252 │ Learning Rate: 0.00617
# Epoch 211/500 │ Loss: +0.0308 │ Free En. Mean: 0.0182 │ Free En. Var: 1.2245 │ Learning Rate: 0.00615
# Epoch 212/500 │ Loss: +0.0359 │ Free En. Mean: 0.0541 │ Free En. Var: 1.1860 │ Learning Rate: 0.00614
# Epoch 213/500 │ Loss: +0.0411 │ Free En. Mean: 0.0982 │ Free En. Var: 1.1660 │ Learning Rate: 0.00612
# Epoch 214/500 │ Loss: +0.0359 │ Free En. Mean: 0.0951 │ Free En. Var: 1.2328 │ Learning Rate: 0.00610
# Epoch 215/500 │ Loss: +0.0294 │ Free En. Mean: 0.0957 │ Free En. Var: 1.3080 │ Learning Rate: 0.00609
# Epoch 216/500 │ Loss: +0.0261 │ Free En. Mean: -0.0318 │ Free En. Var: 1.1673 │ Learning Rate: 0.00607
# Epoch 217/500 │ Loss: +0.0433 │ Free En. Mean: 0.0005 │ Free En. Var: 1.2421 │ Learning Rate: 0.00605
# Epoch 218/500 │ Loss: +0.0386 │ Free En. Mean: 0.0344 │ Free En. Var: 1.1887 │ Learning Rate: 0.00604
# Epoch 219/500 │ Loss: +0.0296 │ Free En. Mean: 0.0159 │ Free En. Var: 1.2047 │ Learning Rate: 0.00602
# Epoch 220/500 │ Loss: +0.0471 │ Free En. Mean: 0.1257 │ Free En. Var: 1.2899 │ Learning Rate: 0.00600
# Epoch 221/500 │ Loss: +0.0332 │ Free En. Mean: 0.0338 │ Free En. Var: 1.1795 │ Learning Rate: 0.00599
# Epoch 222/500 │ Loss: +0.0711 │ Free En. Mean: 0.0392 │ Free En. Var: 1.1815 │ Learning Rate: 0.00597
# Epoch 223/500 │ Loss: +0.0215 │ Free En. Mean: 0.0604 │ Free En. Var: 1.2640 │ Learning Rate: 0.00595
# Epoch 224/500 │ Loss: +0.0279 │ Free En. Mean: -0.0911 │ Free En. Var: 1.0966 │ Learning Rate: 0.00594
# Epoch 225/500 │ Loss: +0.0319 │ Free En. Mean: 0.0353 │ Free En. Var: 1.2309 │ Learning Rate: 0.00592
# Epoch 226/500 │ Loss: +0.0134 │ Free En. Mean: 0.0785 │ Free En. Var: 1.2944 │ Learning Rate: 0.00590
# Epoch 227/500 │ Loss: +0.0331 │ Free En. Mean: 0.0367 │ Free En. Var: 1.2083 │ Learning Rate: 0.00589
# Epoch 228/500 │ Loss: +0.0324 │ Free En. Mean: 0.0163 │ Free En. Var: 1.2190 │ Learning Rate: 0.00587
# Epoch 229/500 │ Loss: +0.0294 │ Free En. Mean: 0.0433 │ Free En. Var: 1.1666 │ Learning Rate: 0.00585
# Epoch 230/500 │ Loss: +0.0339 │ Free En. Mean: 0.0540 │ Free En. Var: 1.2225 │ Learning Rate: 0.00584
# Epoch 231/500 │ Loss: +0.0301 │ Free En. Mean: 0.0800 │ Free En. Var: 1.2387 │ Learning Rate: 0.00582
# Epoch 232/500 │ Loss: +0.0369 │ Free En. Mean: -0.0005 │ Free En. Var: 1.1220 │ Learning Rate: 0.00580
# Epoch 233/500 │ Loss: +0.0293 │ Free En. Mean: 0.0061 │ Free En. Var: 1.1553 │ Learning Rate: 0.00579
# Epoch 234/500 │ Loss: +0.0336 │ Free En. Mean: -0.0742 │ Free En. Var: 1.0318 │ Learning Rate: 0.00577
# Epoch 235/500 │ Loss: +0.0371 │ Free En. Mean: 0.0022 │ Free En. Var: 1.1971 │ Learning Rate: 0.00575
# Epoch 236/500 │ Loss: +0.0299 │ Free En. Mean: 0.0977 │ Free En. Var: 1.2586 │ Learning Rate: 0.00574
# Epoch 237/500 │ Loss: +0.0179 │ Free En. Mean: -0.0345 │ Free En. Var: 1.2291 │ Learning Rate: 0.00572
# Epoch 238/500 │ Loss: +0.0555 │ Free En. Mean: 0.1386 │ Free En. Var: 1.2868 │ Learning Rate: 0.00570
# Epoch 239/500 │ Loss: +0.0364 │ Free En. Mean: 0.0359 │ Free En. Var: 1.0876 │ Learning Rate: 0.00569
# Epoch 240/500 │ Loss: +0.0355 │ Free En. Mean: 0.0784 │ Free En. Var: 1.2023 │ Learning Rate: 0.00567
# Epoch 241/500 │ Loss: +0.0263 │ Free En. Mean: -0.0475 │ Free En. Var: 1.2060 │ Learning Rate: 0.00565
# Epoch 242/500 │ Loss: +0.0432 │ Free En. Mean: 0.0618 │ Free En. Var: 1.2163 │ Learning Rate: 0.00563
# Epoch 243/500 │ Loss: +0.0492 │ Free En. Mean: 0.0663 │ Free En. Var: 1.2386 │ Learning Rate: 0.00562
# Epoch 244/500 │ Loss: +0.0187 │ Free En. Mean: 0.0095 │ Free En. Var: 1.1952 │ Learning Rate: 0.00560
# Epoch 245/500 │ Loss: +0.0228 │ Free En. Mean: 0.0181 │ Free En. Var: 1.1856 │ Learning Rate: 0.00558
# Epoch 246/500 │ Loss: +0.0224 │ Free En. Mean: 0.0107 │ Free En. Var: 1.1494 │ Learning Rate: 0.00557
# Epoch 247/500 │ Loss: +0.0290 │ Free En. Mean: 0.0503 │ Free En. Var: 1.2631 │ Learning Rate: 0.00555
# Epoch 248/500 │ Loss: +0.0336 │ Free En. Mean: -0.0280 │ Free En. Var: 1.0788 │ Learning Rate: 0.00553
# Epoch 249/500 │ Loss: +0.0333 │ Free En. Mean: 0.0340 │ Free En. Var: 1.1701 │ Learning Rate: 0.00552
# Epoch 250/500 │ Loss: +0.0393 │ Free En. Mean: 0.0211 │ Free En. Var: 1.1393 │ Learning Rate: 0.00550
# Epoch 251/500 │ Loss: +0.0215 │ Free En. Mean: 0.0085 │ Free En. Var: 1.1395 │ Learning Rate: 0.00548
# Epoch 252/500 │ Loss: +0.0179 │ Free En. Mean: 0.0055 │ Free En. Var: 1.1806 │ Learning Rate: 0.00547
# Epoch 253/500 │ Loss: +0.0363 │ Free En. Mean: 0.0270 │ Free En. Var: 1.2421 │ Learning Rate: 0.00545
# Epoch 254/500 │ Loss: +0.0394 │ Free En. Mean: 0.0484 │ Free En. Var: 1.1158 │ Learning Rate: 0.00543
# Epoch 255/500 │ Loss: +0.0236 │ Free En. Mean: -0.0135 │ Free En. Var: 1.1295 │ Learning Rate: 0.00542
# Epoch 256/500 │ Loss: +0.0224 │ Free En. Mean: 0.0439 │ Free En. Var: 1.2185 │ Learning Rate: 0.00540
# Epoch 257/500 │ Loss: +0.0296 │ Free En. Mean: 0.0399 │ Free En. Var: 1.1405 │ Learning Rate: 0.00538
# Epoch 258/500 │ Loss: +0.0315 │ Free En. Mean: 0.0008 │ Free En. Var: 1.1706 │ Learning Rate: 0.00537
# Epoch 259/500 │ Loss: +0.0229 │ Free En. Mean: -0.0511 │ Free En. Var: 1.1928 │ Learning Rate: 0.00535
# Epoch 260/500 │ Loss: +0.0399 │ Free En. Mean: 0.0736 │ Free En. Var: 1.2023 │ Learning Rate: 0.00533
# Epoch 261/500 │ Loss: +0.0260 │ Free En. Mean: -0.0002 │ Free En. Var: 1.2235 │ Learning Rate: 0.00531
# Epoch 262/500 │ Loss: +0.0162 │ Free En. Mean: 0.0463 │ Free En. Var: 1.1866 │ Learning Rate: 0.00530
# Epoch 263/500 │ Loss: +0.0143 │ Free En. Mean: -0.0385 │ Free En. Var: 1.1490 │ Learning Rate: 0.00528
# Epoch 264/500 │ Loss: +0.0476 │ Free En. Mean: 0.1688 │ Free En. Var: 1.3821 │ Learning Rate: 0.00526
# Epoch 265/500 │ Loss: +0.0369 │ Free En. Mean: 0.0416 │ Free En. Var: 1.1777 │ Learning Rate: 0.00525
# Epoch 266/500 │ Loss: +0.0242 │ Free En. Mean: 0.0792 │ Free En. Var: 1.2626 │ Learning Rate: 0.00523
# Epoch 267/500 │ Loss: +0.0218 │ Free En. Mean: 0.0079 │ Free En. Var: 1.1641 │ Learning Rate: 0.00521
# Epoch 268/500 │ Loss: +0.0180 │ Free En. Mean: -0.1037 │ Free En. Var: 1.0503 │ Learning Rate: 0.00520
# Epoch 269/500 │ Loss: +0.0467 │ Free En. Mean: 0.0275 │ Free En. Var: 1.1561 │ Learning Rate: 0.00518
# Epoch 270/500 │ Loss: +0.0201 │ Free En. Mean: 0.0302 │ Free En. Var: 1.2105 │ Learning Rate: 0.00516
# Epoch 271/500 │ Loss: +0.0349 │ Free En. Mean: 0.0412 │ Free En. Var: 1.2323 │ Learning Rate: 0.00515
# Epoch 272/500 │ Loss: +0.0312 │ Free En. Mean: -0.0212 │ Free En. Var: 1.1121 │ Learning Rate: 0.00513
# Epoch 273/500 │ Loss: +0.0291 │ Free En. Mean: 0.0075 │ Free En. Var: 1.1510 │ Learning Rate: 0.00511
# Epoch 274/500 │ Loss: +0.0357 │ Free En. Mean: -0.0205 │ Free En. Var: 1.0561 │ Learning Rate: 0.00510
# Epoch 275/500 │ Loss: +0.0227 │ Free En. Mean: 0.0621 │ Free En. Var: 1.2508 │ Learning Rate: 0.00508
# Epoch 276/500 │ Loss: +0.0295 │ Free En. Mean: -0.0406 │ Free En. Var: 1.0762 │ Learning Rate: 0.00506
# Epoch 277/500 │ Loss: +0.0282 │ Free En. Mean: 0.0735 │ Free En. Var: 1.2228 │ Learning Rate: 0.00505
# Epoch 278/500 │ Loss: +0.0142 │ Free En. Mean: -0.0266 │ Free En. Var: 1.1463 │ Learning Rate: 0.00503
# Epoch 279/500 │ Loss: +0.0341 │ Free En. Mean: 0.1083 │ Free En. Var: 1.2846 │ Learning Rate: 0.00501
# Epoch 280/500 │ Loss: +0.0243 │ Free En. Mean: 0.0251 │ Free En. Var: 1.1806 │ Learning Rate: 0.00500
# Epoch 281/500 │ Loss: +0.0305 │ Free En. Mean: 0.0353 │ Free En. Var: 1.1036 │ Learning Rate: 0.00498
# Epoch 282/500 │ Loss: +0.0204 │ Free En. Mean: -0.0090 │ Free En. Var: 1.1255 │ Learning Rate: 0.00496
# Epoch 283/500 │ Loss: +0.0407 │ Free En. Mean: 0.0461 │ Free En. Var: 1.2017 │ Learning Rate: 0.00495
# Epoch 284/500 │ Loss: +0.0184 │ Free En. Mean: 0.0743 │ Free En. Var: 1.1891 │ Learning Rate: 0.00493
# Epoch 285/500 │ Loss: +0.0254 │ Free En. Mean: -0.0533 │ Free En. Var: 1.0849 │ Learning Rate: 0.00491
# Epoch 286/500 │ Loss: +0.0246 │ Free En. Mean: 0.0364 │ Free En. Var: 1.1596 │ Learning Rate: 0.00490
# Epoch 287/500 │ Loss: +0.0334 │ Free En. Mean: 0.0159 │ Free En. Var: 1.1545 │ Learning Rate: 0.00488
# Epoch 288/500 │ Loss: +0.0197 │ Free En. Mean: 0.0582 │ Free En. Var: 1.2374 │ Learning Rate: 0.00486
# Epoch 289/500 │ Loss: +0.0123 │ Free En. Mean: 0.0472 │ Free En. Var: 1.2700 │ Learning Rate: 0.00485
# Epoch 290/500 │ Loss: +0.0291 │ Free En. Mean: 0.1079 │ Free En. Var: 1.2963 │ Learning Rate: 0.00483
# Epoch 291/500 │ Loss: +0.0243 │ Free En. Mean: -0.0048 │ Free En. Var: 1.1884 │ Learning Rate: 0.00481
# Epoch 292/500 │ Loss: +0.0247 │ Free En. Mean: 0.0447 │ Free En. Var: 1.2491 │ Learning Rate: 0.00480
# Epoch 293/500 │ Loss: +0.0323 │ Free En. Mean: 0.0410 │ Free En. Var: 1.2315 │ Learning Rate: 0.00478
# Epoch 294/500 │ Loss: +0.0290 │ Free En. Mean: 0.0676 │ Free En. Var: 1.2138 │ Learning Rate: 0.00476
# Epoch 295/500 │ Loss: +0.0245 │ Free En. Mean: 0.0395 │ Free En. Var: 1.1402 │ Learning Rate: 0.00475
# Epoch 296/500 │ Loss: +0.0282 │ Free En. Mean: -0.0759 │ Free En. Var: 1.1380 │ Learning Rate: 0.00473
# Epoch 297/500 │ Loss: +0.0282 │ Free En. Mean: 0.0816 │ Free En. Var: 1.2631 │ Learning Rate: 0.00471
# Epoch 298/500 │ Loss: +0.0208 │ Free En. Mean: 0.0746 │ Free En. Var: 1.2332 │ Learning Rate: 0.00470
# Epoch 299/500 │ Loss: +0.0292 │ Free En. Mean: 0.0428 │ Free En. Var: 1.2615 │ Learning Rate: 0.00468
# Epoch 300/500 │ Loss: +0.0607 │ Free En. Mean: 0.0944 │ Free En. Var: 1.2694 │ Learning Rate: 0.00467
# Epoch 301/500 │ Loss: +0.0156 │ Free En. Mean: -0.0130 │ Free En. Var: 1.2000 │ Learning Rate: 0.00465
# Epoch 302/500 │ Loss: +0.0116 │ Free En. Mean: -0.0593 │ Free En. Var: 1.0892 │ Learning Rate: 0.00463
# Epoch 303/500 │ Loss: +0.0228 │ Free En. Mean: -0.0013 │ Free En. Var: 1.0848 │ Learning Rate: 0.00462
# Epoch 304/500 │ Loss: +0.0274 │ Free En. Mean: 0.0237 │ Free En. Var: 1.1636 │ Learning Rate: 0.00460
# Epoch 305/500 │ Loss: +0.0197 │ Free En. Mean: 0.0157 │ Free En. Var: 1.2473 │ Learning Rate: 0.00458
# Epoch 306/500 │ Loss: +0.0209 │ Free En. Mean: -0.0282 │ Free En. Var: 1.1030 │ Learning Rate: 0.00457
# Epoch 307/500 │ Loss: +0.0269 │ Free En. Mean: 0.0294 │ Free En. Var: 1.2016 │ Learning Rate: 0.00455
# Epoch 308/500 │ Loss: +0.0306 │ Free En. Mean: 0.0933 │ Free En. Var: 1.2329 │ Learning Rate: 0.00454
# Epoch 309/500 │ Loss: +0.0269 │ Free En. Mean: 0.0131 │ Free En. Var: 1.1502 │ Learning Rate: 0.00452
# Epoch 310/500 │ Loss: +0.0223 │ Free En. Mean: 0.1047 │ Free En. Var: 1.2706 │ Learning Rate: 0.00450
# Epoch 311/500 │ Loss: +0.0093 │ Free En. Mean: -0.0034 │ Free En. Var: 1.1968 │ Learning Rate: 0.00449
# Epoch 312/500 │ Loss: +0.0283 │ Free En. Mean: -0.0055 │ Free En. Var: 1.1035 │ Learning Rate: 0.00447
# Epoch 313/500 │ Loss: +0.0061 │ Free En. Mean: 0.0258 │ Free En. Var: 1.2862 │ Learning Rate: 0.00446
# Epoch 314/500 │ Loss: +0.0450 │ Free En. Mean: 0.0466 │ Free En. Var: 1.2213 │ Learning Rate: 0.00444
# Epoch 315/500 │ Loss: +0.0246 │ Free En. Mean: 0.1049 │ Free En. Var: 1.2609 │ Learning Rate: 0.00442
# Epoch 316/500 │ Loss: +0.0331 │ Free En. Mean: 0.0116 │ Free En. Var: 1.2031 │ Learning Rate: 0.00441
# Epoch 317/500 │ Loss: +0.0051 │ Free En. Mean: -0.0657 │ Free En. Var: 1.1361 │ Learning Rate: 0.00439
# Epoch 318/500 │ Loss: +0.0316 │ Free En. Mean: 0.0405 │ Free En. Var: 1.2256 │ Learning Rate: 0.00438
# Epoch 319/500 │ Loss: +0.0266 │ Free En. Mean: 0.0574 │ Free En. Var: 1.1688 │ Learning Rate: 0.00436
# Epoch 320/500 │ Loss: +0.0195 │ Free En. Mean: 0.0025 │ Free En. Var: 1.1827 │ Learning Rate: 0.00435
# Epoch 321/500 │ Loss: +0.0193 │ Free En. Mean: 0.0129 │ Free En. Var: 1.1710 │ Learning Rate: 0.00433
# Epoch 322/500 │ Loss: +0.0336 │ Free En. Mean: 0.0414 │ Free En. Var: 1.2096 │ Learning Rate: 0.00431
# Epoch 323/500 │ Loss: +0.0219 │ Free En. Mean: 0.0642 │ Free En. Var: 1.1513 │ Learning Rate: 0.00430
# Epoch 324/500 │ Loss: +0.0196 │ Free En. Mean: 0.0066 │ Free En. Var: 1.1445 │ Learning Rate: 0.00428
# Epoch 325/500 │ Loss: +0.0185 │ Free En. Mean: -0.0381 │ Free En. Var: 1.2400 │ Learning Rate: 0.00427
# Epoch 326/500 │ Loss: +0.0280 │ Free En. Mean: -0.0535 │ Free En. Var: 1.1262 │ Learning Rate: 0.00425
# Epoch 327/500 │ Loss: +0.0329 │ Free En. Mean: 0.0158 │ Free En. Var: 1.2097 │ Learning Rate: 0.00424
# Epoch 328/500 │ Loss: +0.0308 │ Free En. Mean: -0.0651 │ Free En. Var: 1.0716 │ Learning Rate: 0.00422
# Epoch 329/500 │ Loss: +0.0286 │ Free En. Mean: 0.0282 │ Free En. Var: 1.1899 │ Learning Rate: 0.00420
# Epoch 330/500 │ Loss: +0.0340 │ Free En. Mean: 0.1004 │ Free En. Var: 1.2732 │ Learning Rate: 0.00419
# Epoch 331/500 │ Loss: +0.0208 │ Free En. Mean: 0.0187 │ Free En. Var: 1.1235 │ Learning Rate: 0.00417
# Epoch 332/500 │ Loss: +0.0231 │ Free En. Mean: 0.1347 │ Free En. Var: 1.3040 │ Learning Rate: 0.00416
# Epoch 333/500 │ Loss: +0.0086 │ Free En. Mean: -0.0540 │ Free En. Var: 1.1661 │ Learning Rate: 0.00414
# Epoch 334/500 │ Loss: +0.0207 │ Free En. Mean: 0.0860 │ Free En. Var: 1.1922 │ Learning Rate: 0.00413
# Epoch 335/500 │ Loss: +0.0186 │ Free En. Mean: 0.0424 │ Free En. Var: 1.1647 │ Learning Rate: 0.00411
# Epoch 336/500 │ Loss: +0.0197 │ Free En. Mean: 0.0172 │ Free En. Var: 1.1333 │ Learning Rate: 0.00410
# Epoch 337/500 │ Loss: +0.0434 │ Free En. Mean: 0.1041 │ Free En. Var: 1.2233 │ Learning Rate: 0.00408
# Epoch 338/500 │ Loss: +0.0307 │ Free En. Mean: -0.0059 │ Free En. Var: 1.1742 │ Learning Rate: 0.00407
# Epoch 339/500 │ Loss: +0.0235 │ Free En. Mean: 0.1270 │ Free En. Var: 1.3520 │ Learning Rate: 0.00405
# Epoch 340/500 │ Loss: +0.0377 │ Free En. Mean: 0.1274 │ Free En. Var: 1.2488 │ Learning Rate: 0.00404
# Epoch 341/500 │ Loss: +0.0237 │ Free En. Mean: 0.0475 │ Free En. Var: 1.1715 │ Learning Rate: 0.00402
# Epoch 342/500 │ Loss: +0.0125 │ Free En. Mean: 0.0065 │ Free En. Var: 1.1756 │ Learning Rate: 0.00401
# Epoch 343/500 │ Loss: +0.0277 │ Free En. Mean: 0.0832 │ Free En. Var: 1.1829 │ Learning Rate: 0.00399
# Epoch 344/500 │ Loss: +0.0223 │ Free En. Mean: 0.0799 │ Free En. Var: 1.2479 │ Learning Rate: 0.00398
# Epoch 345/500 │ Loss: +0.0032 │ Free En. Mean: -0.0012 │ Free En. Var: 1.2209 │ Learning Rate: 0.00396
# Epoch 346/500 │ Loss: +0.0390 │ Free En. Mean: 0.0512 │ Free En. Var: 1.2335 │ Learning Rate: 0.00395
# Epoch 347/500 │ Loss: +0.0252 │ Free En. Mean: 0.0254 │ Free En. Var: 1.1643 │ Learning Rate: 0.00393
# Epoch 348/500 │ Loss: +0.0232 │ Free En. Mean: -0.0161 │ Free En. Var: 1.1433 │ Learning Rate: 0.00392
# Epoch 349/500 │ Loss: +0.0118 │ Free En. Mean: -0.0240 │ Free En. Var: 1.1788 │ Learning Rate: 0.00390
# Epoch 350/500 │ Loss: +0.0184 │ Free En. Mean: 0.0238 │ Free En. Var: 1.2039 │ Learning Rate: 0.00389
# Epoch 351/500 │ Loss: +0.0237 │ Free En. Mean: 0.0158 │ Free En. Var: 1.1581 │ Learning Rate: 0.00387
# Epoch 352/500 │ Loss: +0.0194 │ Free En. Mean: 0.0462 │ Free En. Var: 1.1832 │ Learning Rate: 0.00386
# Epoch 353/500 │ Loss: +0.0198 │ Free En. Mean: 0.0576 │ Free En. Var: 1.1821 │ Learning Rate: 0.00384
# Epoch 354/500 │ Loss: +0.0256 │ Free En. Mean: 0.0931 │ Free En. Var: 1.2269 │ Learning Rate: 0.00383
# Epoch 355/500 │ Loss: +0.0236 │ Free En. Mean: -0.0164 │ Free En. Var: 1.0936 │ Learning Rate: 0.00381
# Epoch 356/500 │ Loss: +0.0302 │ Free En. Mean: 0.0510 │ Free En. Var: 1.2353 │ Learning Rate: 0.00380
# Epoch 357/500 │ Loss: +0.0236 │ Free En. Mean: 0.0699 │ Free En. Var: 1.2069 │ Learning Rate: 0.00379
# Epoch 358/500 │ Loss: +0.0253 │ Free En. Mean: 0.0488 │ Free En. Var: 1.2443 │ Learning Rate: 0.00377
# Epoch 359/500 │ Loss: +0.0115 │ Free En. Mean: 0.0613 │ Free En. Var: 1.2799 │ Learning Rate: 0.00376
# Epoch 360/500 │ Loss: +0.0295 │ Free En. Mean: 0.0627 │ Free En. Var: 1.2230 │ Learning Rate: 0.00374
# Epoch 361/500 │ Loss: +0.0229 │ Free En. Mean: 0.0285 │ Free En. Var: 1.1687 │ Learning Rate: 0.00373
# Epoch 362/500 │ Loss: +0.0103 │ Free En. Mean: 0.0242 │ Free En. Var: 1.1647 │ Learning Rate: 0.00371
# Epoch 363/500 │ Loss: +0.0275 │ Free En. Mean: -0.0526 │ Free En. Var: 1.1210 │ Learning Rate: 0.00370
# Epoch 364/500 │ Loss: +0.0169 │ Free En. Mean: -0.1169 │ Free En. Var: 1.1382 │ Learning Rate: 0.00369
# Epoch 365/500 │ Loss: +0.0284 │ Free En. Mean: 0.0633 │ Free En. Var: 1.1496 │ Learning Rate: 0.00367
# Epoch 366/500 │ Loss: +0.0209 │ Free En. Mean: 0.0096 │ Free En. Var: 1.1534 │ Learning Rate: 0.00366
# Epoch 367/500 │ Loss: +0.0116 │ Free En. Mean: 0.0377 │ Free En. Var: 1.1827 │ Learning Rate: 0.00364
# Epoch 368/500 │ Loss: +0.0174 │ Free En. Mean: -0.0054 │ Free En. Var: 1.1273 │ Learning Rate: 0.00363
# Epoch 369/500 │ Loss: +0.0190 │ Free En. Mean: 0.0339 │ Free En. Var: 1.1693 │ Learning Rate: 0.00362
# Epoch 370/500 │ Loss: +0.0122 │ Free En. Mean: 0.0097 │ Free En. Var: 1.1878 │ Learning Rate: 0.00360
# Epoch 371/500 │ Loss: +0.0159 │ Free En. Mean: -0.0484 │ Free En. Var: 1.1515 │ Learning Rate: 0.00359
# Epoch 372/500 │ Loss: +0.0152 │ Free En. Mean: -0.0063 │ Free En. Var: 1.2291 │ Learning Rate: 0.00357
# Epoch 373/500 │ Loss: +0.0165 │ Free En. Mean: -0.0482 │ Free En. Var: 1.1691 │ Learning Rate: 0.00356
# Epoch 374/500 │ Loss: +0.0191 │ Free En. Mean: -0.0059 │ Free En. Var: 1.1608 │ Learning Rate: 0.00355
# Epoch 375/500 │ Loss: +0.0214 │ Free En. Mean: 0.0351 │ Free En. Var: 1.2233 │ Learning Rate: 0.00353
# Epoch 376/500 │ Loss: +0.0205 │ Free En. Mean: 0.0149 │ Free En. Var: 1.1021 │ Learning Rate: 0.00352
# Epoch 377/500 │ Loss: +0.0219 │ Free En. Mean: 0.0850 │ Free En. Var: 1.2710 │ Learning Rate: 0.00351
# Epoch 378/500 │ Loss: +0.0358 │ Free En. Mean: 0.0964 │ Free En. Var: 1.2537 │ Learning Rate: 0.00349
# Epoch 379/500 │ Loss: +0.0150 │ Free En. Mean: 0.0273 │ Free En. Var: 1.2306 │ Learning Rate: 0.00348
# Epoch 380/500 │ Loss: +0.0164 │ Free En. Mean: -0.0130 │ Free En. Var: 1.2146 │ Learning Rate: 0.00346
# Epoch 381/500 │ Loss: +0.0258 │ Free En. Mean: 0.0306 │ Free En. Var: 1.2105 │ Learning Rate: 0.00345
# Epoch 382/500 │ Loss: +0.0163 │ Free En. Mean: 0.0173 │ Free En. Var: 1.1814 │ Learning Rate: 0.00344
# Epoch 383/500 │ Loss: +0.0301 │ Free En. Mean: -0.0377 │ Free En. Var: 1.0899 │ Learning Rate: 0.00342
# Epoch 384/500 │ Loss: +0.0316 │ Free En. Mean: 0.0251 │ Free En. Var: 1.1996 │ Learning Rate: 0.00341
# Epoch 385/500 │ Loss: +0.0204 │ Free En. Mean: 0.0952 │ Free En. Var: 1.2180 │ Learning Rate: 0.00340
# Epoch 386/500 │ Loss: +0.0283 │ Free En. Mean: 0.1257 │ Free En. Var: 1.2112 │ Learning Rate: 0.00339
# Epoch 387/500 │ Loss: +0.0049 │ Free En. Mean: -0.0277 │ Free En. Var: 1.0826 │ Learning Rate: 0.00337
# Epoch 388/500 │ Loss: +0.0243 │ Free En. Mean: 0.0630 │ Free En. Var: 1.1524 │ Learning Rate: 0.00336
# Epoch 389/500 │ Loss: +0.0203 │ Free En. Mean: 0.0822 │ Free En. Var: 1.2048 │ Learning Rate: 0.00335
# Epoch 390/500 │ Loss: +0.0291 │ Free En. Mean: 0.1064 │ Free En. Var: 1.2846 │ Learning Rate: 0.00333
# Epoch 391/500 │ Loss: +0.0271 │ Free En. Mean: 0.1518 │ Free En. Var: 1.2935 │ Learning Rate: 0.00332
# Epoch 392/500 │ Loss: +0.0201 │ Free En. Mean: -0.0258 │ Free En. Var: 1.2053 │ Learning Rate: 0.00331
# Epoch 393/500 │ Loss: +0.0142 │ Free En. Mean: -0.0138 │ Free En. Var: 1.1349 │ Learning Rate: 0.00329
# Epoch 394/500 │ Loss: +0.0234 │ Free En. Mean: -0.0011 │ Free En. Var: 1.1067 │ Learning Rate: 0.00328
# Epoch 395/500 │ Loss: +0.0227 │ Free En. Mean: -0.0467 │ Free En. Var: 1.1450 │ Learning Rate: 0.00327
# Epoch 396/500 │ Loss: +0.0248 │ Free En. Mean: 0.0459 │ Free En. Var: 1.1456 │ Learning Rate: 0.00326
# Epoch 397/500 │ Loss: +0.0154 │ Free En. Mean: 0.0377 │ Free En. Var: 1.1772 │ Learning Rate: 0.00324
# Epoch 398/500 │ Loss: +0.0158 │ Free En. Mean: 0.0517 │ Free En. Var: 1.2356 │ Learning Rate: 0.00323
# Epoch 399/500 │ Loss: +0.0173 │ Free En. Mean: -0.0254 │ Free En. Var: 1.1407 │ Learning Rate: 0.00322
# Epoch 400/500 │ Loss: +0.0247 │ Free En. Mean: -0.0257 │ Free En. Var: 1.1359 │ Learning Rate: 0.00321
# Epoch 401/500 │ Loss: +0.0183 │ Free En. Mean: 0.0889 │ Free En. Var: 1.1602 │ Learning Rate: 0.00319
# Epoch 402/500 │ Loss: +0.0107 │ Free En. Mean: 0.0395 │ Free En. Var: 1.1294 │ Learning Rate: 0.00318
# Epoch 403/500 │ Loss: +0.0204 │ Free En. Mean: -0.0111 │ Free En. Var: 1.1851 │ Learning Rate: 0.00317
# Epoch 404/500 │ Loss: +0.0267 │ Free En. Mean: -0.0102 │ Free En. Var: 1.1343 │ Learning Rate: 0.00316
# Epoch 405/500 │ Loss: +0.0137 │ Free En. Mean: 0.0397 │ Free En. Var: 1.1837 │ Learning Rate: 0.00314
# Epoch 406/500 │ Loss: +0.0186 │ Free En. Mean: 0.0077 │ Free En. Var: 1.1400 │ Learning Rate: 0.00313
# Epoch 407/500 │ Loss: +0.0133 │ Free En. Mean: -0.0133 │ Free En. Var: 1.1316 │ Learning Rate: 0.00312
# Epoch 408/500 │ Loss: +0.0179 │ Free En. Mean: -0.0103 │ Free En. Var: 1.1342 │ Learning Rate: 0.00311
# Epoch 409/500 │ Loss: +0.0253 │ Free En. Mean: 0.0031 │ Free En. Var: 1.1969 │ Learning Rate: 0.00310
# Epoch 410/500 │ Loss: +0.0176 │ Free En. Mean: 0.0689 │ Free En. Var: 1.2204 │ Learning Rate: 0.00308
# Epoch 411/500 │ Loss: +0.0199 │ Free En. Mean: 0.0684 │ Free En. Var: 1.2351 │ Learning Rate: 0.00307
# Epoch 412/500 │ Loss: +0.0149 │ Free En. Mean: -0.0306 │ Free En. Var: 1.1368 │ Learning Rate: 0.00306
# Epoch 413/500 │ Loss: +0.0064 │ Free En. Mean: -0.0405 │ Free En. Var: 1.1577 │ Learning Rate: 0.00305
# Epoch 414/500 │ Loss: +0.0266 │ Free En. Mean: 0.0546 │ Free En. Var: 1.1680 │ Learning Rate: 0.00304
# Epoch 415/500 │ Loss: +0.0191 │ Free En. Mean: 0.0841 │ Free En. Var: 1.2449 │ Learning Rate: 0.00302
# Epoch 416/500 │ Loss: +0.0106 │ Free En. Mean: 0.0146 │ Free En. Var: 1.1429 │ Learning Rate: 0.00301
# Epoch 417/500 │ Loss: +0.0170 │ Free En. Mean: -0.0005 │ Free En. Var: 1.1738 │ Learning Rate: 0.00300
# Epoch 418/500 │ Loss: +0.0226 │ Free En. Mean: 0.0042 │ Free En. Var: 1.0993 │ Learning Rate: 0.00299
# Epoch 419/500 │ Loss: +0.0236 │ Free En. Mean: 0.0379 │ Free En. Var: 1.2251 │ Learning Rate: 0.00298
# Epoch 420/500 │ Loss: +0.0142 │ Free En. Mean: -0.0242 │ Free En. Var: 1.1288 │ Learning Rate: 0.00297
# Epoch 421/500 │ Loss: +0.0171 │ Free En. Mean: 0.0717 │ Free En. Var: 1.2318 │ Learning Rate: 0.00295
# Epoch 422/500 │ Loss: +0.0223 │ Free En. Mean: 0.0188 │ Free En. Var: 1.0797 │ Learning Rate: 0.00294
# Epoch 423/500 │ Loss: +0.0212 │ Free En. Mean: 0.0226 │ Free En. Var: 1.2524 │ Learning Rate: 0.00293
# Epoch 424/500 │ Loss: +0.0128 │ Free En. Mean: 0.0455 │ Free En. Var: 1.1754 │ Learning Rate: 0.00292
# Epoch 425/500 │ Loss: +0.0153 │ Free En. Mean: 0.0047 │ Free En. Var: 1.1187 │ Learning Rate: 0.00291
# Epoch 426/500 │ Loss: +0.0093 │ Free En. Mean: -0.0127 │ Free En. Var: 1.2025 │ Learning Rate: 0.00290
# Epoch 427/500 │ Loss: +0.0142 │ Free En. Mean: -0.0202 │ Free En. Var: 1.2147 │ Learning Rate: 0.00289
# Epoch 428/500 │ Loss: +0.0114 │ Free En. Mean: -0.0530 │ Free En. Var: 1.1875 │ Learning Rate: 0.00288
# Epoch 429/500 │ Loss: +0.0187 │ Free En. Mean: -0.0075 │ Free En. Var: 1.1641 │ Learning Rate: 0.00286
# Epoch 430/500 │ Loss: +0.0276 │ Free En. Mean: 0.0443 │ Free En. Var: 1.1948 │ Learning Rate: 0.00285
# Epoch 431/500 │ Loss: +0.0131 │ Free En. Mean: -0.0727 │ Free En. Var: 1.1225 │ Learning Rate: 0.00284
# Epoch 432/500 │ Loss: +0.0242 │ Free En. Mean: 0.0515 │ Free En. Var: 1.1841 │ Learning Rate: 0.00283
# Epoch 433/500 │ Loss: +0.0180 │ Free En. Mean: -0.0455 │ Free En. Var: 1.0925 │ Learning Rate: 0.00282
# Epoch 434/500 │ Loss: +0.0017 │ Free En. Mean: -0.0508 │ Free En. Var: 1.1978 │ Learning Rate: 0.00281
# Epoch 435/500 │ Loss: +0.0221 │ Free En. Mean: 0.0535 │ Free En. Var: 1.1957 │ Learning Rate: 0.00280
# Epoch 436/500 │ Loss: +0.0063 │ Free En. Mean: -0.0457 │ Free En. Var: 1.1679 │ Learning Rate: 0.00279
# Epoch 437/500 │ Loss: +0.0296 │ Free En. Mean: 0.0141 │ Free En. Var: 1.1288 │ Learning Rate: 0.00278
# Epoch 438/500 │ Loss: +0.0102 │ Free En. Mean: 0.0105 │ Free En. Var: 1.1335 │ Learning Rate: 0.00277
# Epoch 439/500 │ Loss: +0.0118 │ Free En. Mean: -0.0140 │ Free En. Var: 1.1551 │ Learning Rate: 0.00276
# Epoch 440/500 │ Loss: +0.0246 │ Free En. Mean: -0.0048 │ Free En. Var: 1.1278 │ Learning Rate: 0.00274
# Epoch 441/500 │ Loss: +0.0059 │ Free En. Mean: 0.0339 │ Free En. Var: 1.2506 │ Learning Rate: 0.00273
# Epoch 442/500 │ Loss: +0.0268 │ Free En. Mean: 0.0138 │ Free En. Var: 1.1624 │ Learning Rate: 0.00272
# Epoch 443/500 │ Loss: +0.0046 │ Free En. Mean: 0.0078 │ Free En. Var: 1.1402 │ Learning Rate: 0.00271
# Epoch 444/500 │ Loss: +0.0246 │ Free En. Mean: 0.0839 │ Free En. Var: 1.2444 │ Learning Rate: 0.00270
# Epoch 445/500 │ Loss: +0.0092 │ Free En. Mean: 0.0111 │ Free En. Var: 1.2082 │ Learning Rate: 0.00269
# Epoch 446/500 │ Loss: +0.0209 │ Free En. Mean: 0.0346 │ Free En. Var: 1.2331 │ Learning Rate: 0.00268
# Epoch 447/500 │ Loss: +0.0034 │ Free En. Mean: 0.0388 │ Free En. Var: 1.2246 │ Learning Rate: 0.00267
# Epoch 448/500 │ Loss: +0.0225 │ Free En. Mean: -0.0773 │ Free En. Var: 1.1756 │ Learning Rate: 0.00266
# Epoch 449/500 │ Loss: +0.0179 │ Free En. Mean: 0.1065 │ Free En. Var: 1.2293 │ Learning Rate: 0.00265
# Epoch 450/500 │ Loss: +0.0153 │ Free En. Mean: -0.0597 │ Free En. Var: 1.0323 │ Learning Rate: 0.00264
# Epoch 451/500 │ Loss: +0.0179 │ Free En. Mean: 0.0068 │ Free En. Var: 1.1737 │ Learning Rate: 0.00263
# Epoch 452/500 │ Loss: +0.0137 │ Free En. Mean: 0.0069 │ Free En. Var: 1.1551 │ Learning Rate: 0.00262
# Epoch 453/500 │ Loss: +0.0293 │ Free En. Mean: 0.0612 │ Free En. Var: 1.2985 │ Learning Rate: 0.00261
# Epoch 454/500 │ Loss: +0.0031 │ Free En. Mean: 0.0070 │ Free En. Var: 1.1864 │ Learning Rate: 0.00260
# Epoch 455/500 │ Loss: +0.0234 │ Free En. Mean: -0.0062 │ Free En. Var: 1.1324 │ Learning Rate: 0.00259
# Epoch 456/500 │ Loss: +0.0043 │ Free En. Mean: 0.0021 │ Free En. Var: 1.1864 │ Learning Rate: 0.00258
# Epoch 457/500 │ Loss: +0.0200 │ Free En. Mean: 0.0302 │ Free En. Var: 1.1439 │ Learning Rate: 0.00257
# Epoch 458/500 │ Loss: +0.0130 │ Free En. Mean: 0.0174 │ Free En. Var: 1.1607 │ Learning Rate: 0.00256
# Epoch 459/500 │ Loss: +0.0222 │ Free En. Mean: 0.0216 │ Free En. Var: 1.0908 │ Learning Rate: 0.00255
# Epoch 460/500 │ Loss: +0.0144 │ Free En. Mean: 0.0487 │ Free En. Var: 1.2057 │ Learning Rate: 0.00254
# Epoch 461/500 │ Loss: +0.0128 │ Free En. Mean: 0.0506 │ Free En. Var: 1.1818 │ Learning Rate: 0.00253
# Epoch 462/500 │ Loss: +0.0262 │ Free En. Mean: -0.0375 │ Free En. Var: 1.1140 │ Learning Rate: 0.00252
# Epoch 463/500 │ Loss: +0.0227 │ Free En. Mean: 0.0772 │ Free En. Var: 1.2818 │ Learning Rate: 0.00251
# Epoch 464/500 │ Loss: +0.0099 │ Free En. Mean: -0.0580 │ Free En. Var: 1.1801 │ Learning Rate: 0.00251
# Epoch 465/500 │ Loss: +0.0278 │ Free En. Mean: 0.0517 │ Free En. Var: 1.2385 │ Learning Rate: 0.00250
# Epoch 466/500 │ Loss: +0.0046 │ Free En. Mean: -0.0038 │ Free En. Var: 1.1888 │ Learning Rate: 0.00249
# Epoch 467/500 │ Loss: +0.0228 │ Free En. Mean: -0.0343 │ Free En. Var: 1.1678 │ Learning Rate: 0.00248
# Epoch 468/500 │ Loss: +0.0022 │ Free En. Mean: -0.0604 │ Free En. Var: 1.1722 │ Learning Rate: 0.00247
# Epoch 469/500 │ Loss: +0.0238 │ Free En. Mean: 0.0362 │ Free En. Var: 1.1851 │ Learning Rate: 0.00246
# Epoch 470/500 │ Loss: +0.0113 │ Free En. Mean: -0.0063 │ Free En. Var: 1.1321 │ Learning Rate: 0.00245
# Epoch 471/500 │ Loss: +0.0106 │ Free En. Mean: -0.0497 │ Free En. Var: 1.1019 │ Learning Rate: 0.00244
# Epoch 472/500 │ Loss: +0.0280 │ Free En. Mean: 0.0849 │ Free En. Var: 1.2215 │ Learning Rate: 0.00243
# Epoch 473/500 │ Loss: +0.0083 │ Free En. Mean: 0.0323 │ Free En. Var: 1.1264 │ Learning Rate: 0.00242
# Epoch 474/500 │ Loss: +0.0235 │ Free En. Mean: 0.0055 │ Free En. Var: 1.1243 │ Learning Rate: 0.00241
# Epoch 475/500 │ Loss: +0.0169 │ Free En. Mean: 0.0535 │ Free En. Var: 1.2493 │ Learning Rate: 0.00240
# Epoch 476/500 │ Loss: +0.0114 │ Free En. Mean: -0.0086 │ Free En. Var: 1.1933 │ Learning Rate: 0.00240
# Epoch 477/500 │ Loss: +0.0201 │ Free En. Mean: 0.0511 │ Free En. Var: 1.2003 │ Learning Rate: 0.00239
# Epoch 478/500 │ Loss: +0.0189 │ Free En. Mean: -0.0059 │ Free En. Var: 1.1410 │ Learning Rate: 0.00238
# Epoch 479/500 │ Loss: +0.0149 │ Free En. Mean: 0.1010 │ Free En. Var: 1.2672 │ Learning Rate: 0.00237
# Epoch 480/500 │ Loss: +0.0172 │ Free En. Mean: 0.0365 │ Free En. Var: 1.1954 │ Learning Rate: 0.00236
# Epoch 481/500 │ Loss: +0.0179 │ Free En. Mean: 0.0474 │ Free En. Var: 1.2135 │ Learning Rate: 0.00235
# Epoch 482/500 │ Loss: +0.0149 │ Free En. Mean: -0.0400 │ Free En. Var: 1.1640 │ Learning Rate: 0.00234
# Epoch 483/500 │ Loss: +0.0136 │ Free En. Mean: -0.0228 │ Free En. Var: 1.1916 │ Learning Rate: 0.00234
# Epoch 484/500 │ Loss: +0.0136 │ Free En. Mean: 0.0059 │ Free En. Var: 1.2131 │ Learning Rate: 0.00233
# Epoch 485/500 │ Loss: +0.0129 │ Free En. Mean: 0.0369 │ Free En. Var: 1.2493 │ Learning Rate: 0.00232
# Epoch 486/500 │ Loss: +0.0227 │ Free En. Mean: 0.0643 │ Free En. Var: 1.2080 │ Learning Rate: 0.00231
# Epoch 487/500 │ Loss: +0.0141 │ Free En. Mean: 0.0045 │ Free En. Var: 1.2030 │ Learning Rate: 0.00230
# Epoch 488/500 │ Loss: +0.0080 │ Free En. Mean: -0.0420 │ Free En. Var: 1.1141 │ Learning Rate: 0.00229
# Epoch 489/500 │ Loss: +0.0125 │ Free En. Mean: 0.0572 │ Free En. Var: 1.2427 │ Learning Rate: 0.00228
# Epoch 490/500 │ Loss: +0.0177 │ Free En. Mean: 0.0403 │ Free En. Var: 1.2024 │ Learning Rate: 0.00228
# Epoch 491/500 │ Loss: +0.0214 │ Free En. Mean: 0.1109 │ Free En. Var: 1.1242 │ Learning Rate: 0.00227
# Epoch 492/500 │ Loss: +0.0109 │ Free En. Mean: 0.0792 │ Free En. Var: 1.2182 │ Learning Rate: 0.00226
# Epoch 493/500 │ Loss: +0.0156 │ Free En. Mean: 0.0208 │ Free En. Var: 1.1682 │ Learning Rate: 0.00225
# Epoch 494/500 │ Loss: +0.0099 │ Free En. Mean: -0.0020 │ Free En. Var: 1.2239 │ Learning Rate: 0.00224
# Epoch 495/500 │ Loss: +0.0116 │ Free En. Mean: -0.0264 │ Free En. Var: 1.0955 │ Learning Rate: 0.00224
# Epoch 496/500 │ Loss: +0.0165 │ Free En. Mean: -0.0016 │ Free En. Var: 1.1912 │ Learning Rate: 0.00223
# Epoch 497/500 │ Loss: +0.0180 │ Free En. Mean: 0.0087 │ Free En. Var: 1.1927 │ Learning Rate: 0.00222
# Epoch 498/500 │ Loss: +0.0006 │ Free En. Mean: -0.0814 │ Free En. Var: 1.1099 │ Learning Rate: 0.00221
# Epoch 499/500 │ Loss: +0.0211 │ Free En. Mean: 0.0300 │ Free En. Var: 1.2597 │ Learning Rate: 0.00220
# Epoch 500/500 │ Loss: +0.0138 │ Free En. Mean: -0.0395 │ Free En. Var: 1.1880 │ Learning Rate: 0.00220

# %%
epochs = list(metrics.keys())

loss_vals = [metrics[e]['loss'] for e in epochs]
free_model_mean_vals = [metrics[e]['free_energy_mean'] for e in epochs]
free_model_var_vals = [metrics[e]['free_energy_var'] for e in epochs]
lr_vals = [metrics[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots(figsize=(11, 4))

ax1.plot(epochs, lr_vals, label="Learning Rate", color="tab:red")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Learning Rate", color="tab:red")
ax1.tick_params(axis="y", labelcolor="tab:red")

ax2 = ax1.twinx()
ax2.spines["right"].set_position(("axes", 1.00))
ax2.plot(epochs, loss_vals, label="Amplitude CD Loss", color="tab:blue")
ax2.set_ylabel("Loss", color="tab:blue")
ax2.tick_params(axis="y", labelcolor="tab:blue")

ax3 = ax1.twinx()
ax3.spines["right"].set_position(("axes", 1.1))
ax3.plot(epochs, free_model_var_vals, label="Free Energy Model Var", color="tab:green")
ax3.set_ylabel("Free Energy Model Var", color="tab:green")
ax3.tick_params(axis="y", labelcolor="tab:green")

ax4 = ax1.twinx()
ax4.spines["right"].set_position(("axes", 1.2))
ax4.plot(epochs, free_model_mean_vals, label="Free Energy Model Mean", color="tab:orange")
ax4.set_ylabel("Free Energy Model Mean", color="tab:orange")
ax4.tick_params(axis="y", labelcolor="tab:orange")

plt.tight_layout()
plt.show()

# %%
# a quick test is to test whether the conditioner can condition on the Z basis

T_high = 2.0
T_low = 0.01
sampling_steps = 5_000
sigmoid_schedule_fn = get_sigmoid_curve(high=T_high*2, low=T_low, steps=sampling_steps, falloff=0.0013, center_step=0)
sigmoid_schedule = jnp.array([sigmoid_schedule_fn(i) for i in range(sampling_steps)], dtype=jnp.float32)

# construct a batch of basis bits in Z direction
num_samples = 1_000
basis_bits = jnp.ones((num_samples, num_visible, 2), dtype=jnp.float32)

all_vars = { "params": state.params, "rbm": rbm_vars }

key_sample = jax.random.PRNGKey(42)
samples, key_sample = model.apply(all_vars, basis_bits, sigmoid_schedule, key_sample, method=ConditionalRBM.generate)

sampled_freq = samples.mean(axis=0)
sampled_freq
# Out:
# Array([0.42200002, 0.349     , 0.395     , 0.446     , 0.41000003,
#        0.37      , 0.39800003, 0.38200003], dtype=float32)
