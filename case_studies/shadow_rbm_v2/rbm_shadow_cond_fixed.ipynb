# %%
# %reload_ext autoreload
# %autoreload 2

from lib.data_loading import load_measurements, MixedDataLoader

####

from pathlib import Path
from typing import Tuple, Dict, Any, Callable

import jax
import jax.lax
import jax.numpy as jnp
from jax.random import PRNGKey
import optax
from flax.training.train_state import TrainState
from flax.training import checkpoints
from flax import linen as nn

import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings(
    "ignore",
    message=(
        "Couldn't find sharding info under RestoreArgs.*"
    ),
    category=UserWarning,
    module="orbax.checkpoint.type_handlers"
)

data_dir = "data"
model_dir = "./models"
model_prefix = "rbm_amp_202506131953_0"

print(f"Data resides in                         : {data_dir}")
print(f"Amplitude RBM checkpoint to be loaded   : {model_dir}/{model_prefix}")
# Out:
# Data resides in                         : data
# Amplitude RBM checkpoint to be loaded   : ./models/rbm_amp_202506131953_0

# %%
class ConditionalRBM(nn.Module):
    num_visible: int
    num_hidden: int
    conditioner_width: int = 64
    k: int = 1
    T: float = 1.0

    def setup(self):
        # we use frozen RBM parameters
        zeros = lambda shape: jnp.zeros(shape, dtype=jnp.float32)
        self.W = self.variable("rbm", "W", zeros, (self.num_visible, self.num_hidden))
        self.b = self.variable("rbm", "b", zeros, (self.num_visible,))   # global init
        self.c = self.variable("rbm", "c", zeros, (self.num_hidden,))    # global init

    @nn.compact
    def conditioner(self, condition: jnp.ndarray) -> Tuple[jnp.ndarray, jnp.ndarray, jnp.ndarray, jnp.ndarray]:
        # takes in batch of conditions lenght D, in our case one-hot measurement encodings (B, N, 4)
        x = nn.Dense(self.conditioner_width)(condition)     # (B, N, D)
        x = nn.tanh(x)
        x = x.reshape(x.shape[0], -1)                        # (B, N * D)
        x = nn.Dense(2 * (self.num_visible + self.num_hidden))(x)
        split_indices = [self.num_visible, 2 * self.num_visible, 2 * self.num_visible + self.num_hidden]
        gamma_b, beta_b, gamma_c, beta_c = jnp.split(x, split_indices, axis=-1)
        return gamma_b, beta_b, gamma_c, beta_c              # correction parameters have batch dim again (B, N/H)

    @staticmethod
    def encode_one_hot(basis_bits: jnp.ndarray) -> jnp.ndarray:
        basis_int = basis_bits[:, :, 0] * 2 + basis_bits[:, :, 1] # split high and low bits
        return jax.nn.one_hot(basis_int, 4, dtype=jnp.float32)

    @staticmethod
    def prepare_batch(batch: jnp.ndarray) -> Tuple[jnp.ndarray, jnp.ndarray]:
        # split off actual measurements and from basis bits and encode the basis bits as one-hot vectors
        measurements = batch[:, :, 0].astype(jnp.float32)       # (B, N)
        basis_high_bits = batch[:, :, 1].astype(jnp.int32)      # (B, N, 1)
        basis_low_bits = batch[:, :, 2].astype(jnp.int32)

        basis_int = basis_high_bits * 2 + basis_low_bits        # (B, N, 1)
        basis_one_hot = jax.nn.one_hot(basis_int, 4, dtype=jnp.float32)

        return measurements, basis_one_hot

    @staticmethod
    def _free_energy(v, W, b, c) -> jnp.ndarray:
        return -(v @ b) - jnp.sum(jax.nn.softplus(v @ W + c), -1)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c)/T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b)/T)).astype(jnp.float32)
        return v, key

    def __call__(self, batch: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        measurement = batch[:, :, 0].astype(jnp.float32)  # (B, N)
        basis_bits = batch[:, :, 1:].astype(jnp.int32)  # (B, N, 2)
        basis_one_hot = self.encode_one_hot(basis_bits)

        # each measurement sample gets its own FiLM modulation
        gamma_b, beta_b, gamma_c, beta_c = self.conditioner(basis_one_hot)
        b_mod = (1 + gamma_b) * self.b.value + beta_b  # (B, N)
        c_mod = (1 + gamma_c) * self.c.value + beta_c  # (B, H)

        # run a Gibbs chain (k steps) initialized at the data for true CD-k
        key, key_init = jax.random.split(aux_vars["key"])
        gibbs_chain = measurement  # initialize at data
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W.value, b_mod, c_mod, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (gibbs_chain, key))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain)

        # compute per-sample free energies
        free_energy_data  = jax.vmap(self._free_energy, in_axes=(0, None, 0, 0))(measurement, self.W.value, b_mod, c_mod)
        free_energy_model = jax.vmap(self._free_energy, in_axes=(0, None, 0, 0))(gibbs_chain, self.W.value, b_mod, c_mod)

        # pair up the free energies and compute the gap
        free_energy_delta = free_energy_data - free_energy_model  # shape (B,)

        # mean and jitter of the gap
        free_energy_mean = jnp.mean(free_energy_delta)
        free_energy_std  = jnp.std(free_energy_delta)

        # penalize drift from original biases (we need to add a dummy batch dim for broadcasting)
        l2_regularization = (jnp.sum((self.b.value[None, :] - b_mod) ** 2) + jnp.sum((self.c.value[None, :] - c_mod) ** 2))

        loss = free_energy_mean + aux_vars["l2_strength"] * l2_regularization

        aux_vars_out = {
            "key": key,
            "mean_delta_F": free_energy_mean,
            "std_delta_F": free_energy_std,
        }

        return loss, aux_vars_out

    @nn.nowrap
    def generate(self, basis_bits: jnp.ndarray, T_schedule: jnp.ndarray, key: PRNGKey) -> Tuple[jnp.ndarray, PRNGKey]:
        basis_one_hot = self.encode_one_hot(basis_bits)

        gamma_b, beta_b, gamma_c, beta_c = self.conditioner(basis_one_hot)
        b_mod = (1 + gamma_b) * self.b.value + beta_b
        c_mod = (1 + gamma_c) * self.c.value + beta_c

        batch_size, num_visible, _ = basis_bits.shape
        key, key_init = jax.random.split(key, 2)

        gibbs_chain = jax.random.bernoulli(key_init, 0.5, shape=(batch_size, num_visible)).astype(jnp.float32)  # (B, N)
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W.value, b_mod, c_mod, T_schedule[i])
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (gibbs_chain, key))

        return gibbs_chain, key

# %%
@jax.jit
def train_step(
        state: TrainState,
        batch: jnp.ndarray,
        rbm_vars: Dict[str, jnp.ndarray],
        aux_vars: Dict[str, Any]) -> Tuple[TrainState, jnp.ndarray, Dict[str, Any]]:
    loss_fn = lambda params: state.apply_fn({'params': params, 'rbm': rbm_vars}, batch, aux_vars)

    (loss, aux_vars), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    state = state.apply_gradients(grads=grads)
    return state, loss, aux_vars


def train(
        state: TrainState,
        rbm_vars: Dict[str, jnp.ndarray],
        loader: MixedDataLoader,
        num_epochs: int,
        key: PRNGKey,
        l2_strength: float,
        lr_schedule_fn: Callable[[int], float]) -> Tuple[TrainState, Dict[int, float]]:

    metrics: Dict[int, Any] = {}
    gibbs_chain = None

    for epoch in range(num_epochs):
        tot_loss = 0.0

        for batch in loader:
            measurements = batch[:, :, 0].astype(jnp.float32)

            if gibbs_chain is None:
                gibbs_chain = measurements  # initial random init could be better

            key, subkey = jax.random.split(key)
            aux_vars = {
                "key": subkey,
                "l2_strength": l2_strength,
            }

            state, loss, aux_vars = train_step(state, batch, rbm_vars, aux_vars)
            key = aux_vars["key"]
            free_energy_mean = aux_vars["mean_delta_F"]
            free_energy_var = aux_vars["std_delta_F"]

            tot_loss += float(loss)

        avg_loss = tot_loss / len(loader)
        lr = lr_schedule_fn(state.step)

        metrics[epoch] = dict(
            loss=avg_loss,
            free_energy_mean=free_energy_mean,
            free_energy_var=free_energy_var,
            lr=lr
        )

        print(f"Epoch {epoch+1}/{num_epochs} │ "
              f"Loss: {avg_loss:+.4f} │ "
              f"Free En. Mean: {free_energy_mean:.4f} │ "
              f"Free En. Var: {free_energy_var:.4f} │ "
              f"Learning Rate: {lr:.5f}")

    return state, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2

    curve_fn = lambda step: low + (high - low) / (1 + jnp.exp(falloff * (jnp.minimum(step, steps) - center_step)))
    return curve_fn

# %%
# load the RBM parameters and parse the data
rbm_params = checkpoints.restore_checkpoint(ckpt_dir=str(Path(model_dir).resolve()), target=None, prefix=model_prefix)
rbm_vars = {"W": rbm_params["W"], "b": rbm_params["b"], "c": rbm_params["c"]}

file_path = Path("data/w_aug_8MIXED_30000.txt")
data = load_measurements(file_path)
# Out:
# Parsing measurements: 100%|██████████| 30000/30000 [00:01<00:00, 26710.78it/s]

# %%
batch_size      = 2048
num_visible     = 8
num_hidden      = 16
conditioner_width = 64
num_epochs      = 500
k_steps         = 50
init_lr         = 1e-3
final_lr        = init_lr * 0.1
l2_strength     = 0

key = jax.random.PRNGKey(0)

key, key_params, key_dummy = jax.random.split(key, 3)

model = ConditionalRBM(num_visible=num_visible, num_hidden=num_hidden, conditioner_width=conditioner_width, k=k_steps)

batch_dummy = jnp.zeros((batch_size, num_visible, 3), dtype=jnp.float32)
aux_vars_dummy = { "key": key_dummy, "l2_strength": l2_strength}
variables = model.init({"params": key_params}, batch_dummy, aux_vars_dummy)

loader = MixedDataLoader(data, batch_size=batch_size)

schedule_steps = num_epochs * len(loader)
lr_schedule_fn = get_sigmoid_curve(high=init_lr, low=final_lr, steps=schedule_steps, falloff=0.0005)
optim = optax.adam(lr_schedule_fn)

state = TrainState.create(apply_fn=model.apply, params=variables['params'], tx=optim)

state, metrics = train(state, rbm_vars, loader, num_epochs, key, l2_strength, lr_schedule_fn)
# Out:
# Epoch 1/500 │ Loss: +4.3086 │ Free En. Mean: 2.2925 │ Free En. Var: 2.6331 │ Learning Rate: 0.00088
# Epoch 2/500 │ Loss: +1.9045 │ Free En. Mean: 1.8115 │ Free En. Var: 2.6652 │ Learning Rate: 0.00088
# Epoch 3/500 │ Loss: +1.4728 │ Free En. Mean: 1.3791 │ Free En. Var: 2.2618 │ Learning Rate: 0.00088
# Epoch 4/500 │ Loss: +1.3467 │ Free En. Mean: 1.3309 │ Free En. Var: 2.2516 │ Learning Rate: 0.00088
# Epoch 5/500 │ Loss: +1.2505 │ Free En. Mean: 1.2986 │ Free En. Var: 2.2712 │ Learning Rate: 0.00088
# Epoch 6/500 │ Loss: +1.1801 │ Free En. Mean: 1.1252 │ Free En. Var: 2.1055 │ Learning Rate: 0.00088
# Epoch 7/500 │ Loss: +1.1140 │ Free En. Mean: 1.1255 │ Free En. Var: 2.1924 │ Learning Rate: 0.00087
# Epoch 8/500 │ Loss: +1.0962 │ Free En. Mean: 1.1092 │ Free En. Var: 2.0554 │ Learning Rate: 0.00087
# Epoch 9/500 │ Loss: +1.0669 │ Free En. Mean: 1.0978 │ Free En. Var: 2.1610 │ Learning Rate: 0.00087
# Epoch 10/500 │ Loss: +1.0649 │ Free En. Mean: 1.1193 │ Free En. Var: 2.0419 │ Learning Rate: 0.00087
# Epoch 11/500 │ Loss: +1.0594 │ Free En. Mean: 1.0114 │ Free En. Var: 2.0786 │ Learning Rate: 0.00087
# Epoch 12/500 │ Loss: +1.0639 │ Free En. Mean: 1.0189 │ Free En. Var: 2.0144 │ Learning Rate: 0.00087
# Epoch 13/500 │ Loss: +1.0715 │ Free En. Mean: 1.0092 │ Free En. Var: 2.0291 │ Learning Rate: 0.00087
# Epoch 14/500 │ Loss: +1.0753 │ Free En. Mean: 1.0884 │ Free En. Var: 2.0288 │ Learning Rate: 0.00087
# Epoch 15/500 │ Loss: +1.0659 │ Free En. Mean: 1.0428 │ Free En. Var: 2.0988 │ Learning Rate: 0.00087
# Epoch 16/500 │ Loss: +1.0721 │ Free En. Mean: 1.1506 │ Free En. Var: 2.1084 │ Learning Rate: 0.00087
# Epoch 17/500 │ Loss: +1.0740 │ Free En. Mean: 1.1391 │ Free En. Var: 2.1151 │ Learning Rate: 0.00087
# Epoch 18/500 │ Loss: +1.0579 │ Free En. Mean: 1.1100 │ Free En. Var: 2.0150 │ Learning Rate: 0.00087
# Epoch 19/500 │ Loss: +1.0622 │ Free En. Mean: 1.0177 │ Free En. Var: 2.1258 │ Learning Rate: 0.00086
# Epoch 20/500 │ Loss: +1.0709 │ Free En. Mean: 1.0566 │ Free En. Var: 1.9903 │ Learning Rate: 0.00086
# Epoch 21/500 │ Loss: +1.0611 │ Free En. Mean: 0.9766 │ Free En. Var: 2.0287 │ Learning Rate: 0.00086
# Epoch 22/500 │ Loss: +1.0520 │ Free En. Mean: 1.0293 │ Free En. Var: 1.9902 │ Learning Rate: 0.00086
# Epoch 23/500 │ Loss: +1.0465 │ Free En. Mean: 0.9925 │ Free En. Var: 2.1672 │ Learning Rate: 0.00086
# Epoch 24/500 │ Loss: +1.0666 │ Free En. Mean: 1.0275 │ Free En. Var: 1.9814 │ Learning Rate: 0.00086
# Epoch 25/500 │ Loss: +1.0599 │ Free En. Mean: 1.0764 │ Free En. Var: 1.9818 │ Learning Rate: 0.00086
# Epoch 26/500 │ Loss: +1.0527 │ Free En. Mean: 1.0992 │ Free En. Var: 2.1243 │ Learning Rate: 0.00086
# Epoch 27/500 │ Loss: +1.0514 │ Free En. Mean: 0.9641 │ Free En. Var: 1.9705 │ Learning Rate: 0.00086
# Epoch 28/500 │ Loss: +1.0591 │ Free En. Mean: 1.0723 │ Free En. Var: 2.0007 │ Learning Rate: 0.00086
# Epoch 29/500 │ Loss: +1.0656 │ Free En. Mean: 1.1366 │ Free En. Var: 2.1748 │ Learning Rate: 0.00086
# Epoch 30/500 │ Loss: +1.0559 │ Free En. Mean: 1.1379 │ Free En. Var: 2.1331 │ Learning Rate: 0.00086
# Epoch 31/500 │ Loss: +1.0507 │ Free En. Mean: 1.0444 │ Free En. Var: 2.0372 │ Learning Rate: 0.00085
# Epoch 32/500 │ Loss: +1.0433 │ Free En. Mean: 1.0084 │ Free En. Var: 2.1336 │ Learning Rate: 0.00085
# Epoch 33/500 │ Loss: +1.0784 │ Free En. Mean: 1.1238 │ Free En. Var: 2.1424 │ Learning Rate: 0.00085
# Epoch 34/500 │ Loss: +1.0759 │ Free En. Mean: 0.9446 │ Free En. Var: 1.8954 │ Learning Rate: 0.00085
# Epoch 35/500 │ Loss: +1.0660 │ Free En. Mean: 1.0435 │ Free En. Var: 2.1595 │ Learning Rate: 0.00085
# Epoch 36/500 │ Loss: +1.0529 │ Free En. Mean: 1.0331 │ Free En. Var: 2.0475 │ Learning Rate: 0.00085
# Epoch 37/500 │ Loss: +1.0716 │ Free En. Mean: 1.0389 │ Free En. Var: 1.9439 │ Learning Rate: 0.00085
# Epoch 38/500 │ Loss: +1.0675 │ Free En. Mean: 1.0456 │ Free En. Var: 2.1785 │ Learning Rate: 0.00085
# Epoch 39/500 │ Loss: +1.0609 │ Free En. Mean: 0.9671 │ Free En. Var: 1.9149 │ Learning Rate: 0.00085
# Epoch 40/500 │ Loss: +1.0631 │ Free En. Mean: 0.9992 │ Free En. Var: 2.0209 │ Learning Rate: 0.00085
# Epoch 41/500 │ Loss: +1.0555 │ Free En. Mean: 1.0883 │ Free En. Var: 2.0660 │ Learning Rate: 0.00084
# Epoch 42/500 │ Loss: +1.0674 │ Free En. Mean: 1.1251 │ Free En. Var: 2.1088 │ Learning Rate: 0.00084
# Epoch 43/500 │ Loss: +1.0618 │ Free En. Mean: 1.0226 │ Free En. Var: 2.0458 │ Learning Rate: 0.00084
# Epoch 44/500 │ Loss: +1.0645 │ Free En. Mean: 1.0725 │ Free En. Var: 2.0082 │ Learning Rate: 0.00084
# Epoch 45/500 │ Loss: +1.0608 │ Free En. Mean: 0.9783 │ Free En. Var: 2.0077 │ Learning Rate: 0.00084
# Epoch 46/500 │ Loss: +1.0747 │ Free En. Mean: 1.0758 │ Free En. Var: 2.0561 │ Learning Rate: 0.00084
# Epoch 47/500 │ Loss: +1.0645 │ Free En. Mean: 1.0685 │ Free En. Var: 1.9874 │ Learning Rate: 0.00084
# Epoch 48/500 │ Loss: +1.0517 │ Free En. Mean: 0.9084 │ Free En. Var: 1.9625 │ Learning Rate: 0.00084
# Epoch 49/500 │ Loss: +1.0464 │ Free En. Mean: 0.9815 │ Free En. Var: 2.0221 │ Learning Rate: 0.00084
# Epoch 50/500 │ Loss: +1.0588 │ Free En. Mean: 1.1233 │ Free En. Var: 2.1114 │ Learning Rate: 0.00084
# Epoch 51/500 │ Loss: +1.0471 │ Free En. Mean: 1.0505 │ Free En. Var: 1.9817 │ Learning Rate: 0.00083
# Epoch 52/500 │ Loss: +1.0433 │ Free En. Mean: 1.0564 │ Free En. Var: 2.0075 │ Learning Rate: 0.00083
# Epoch 53/500 │ Loss: +1.0678 │ Free En. Mean: 1.0231 │ Free En. Var: 2.0284 │ Learning Rate: 0.00083
# Epoch 54/500 │ Loss: +1.0592 │ Free En. Mean: 1.0275 │ Free En. Var: 1.9740 │ Learning Rate: 0.00083
# Epoch 55/500 │ Loss: +1.0393 │ Free En. Mean: 1.0027 │ Free En. Var: 2.0289 │ Learning Rate: 0.00083
# Epoch 56/500 │ Loss: +1.0647 │ Free En. Mean: 1.0840 │ Free En. Var: 2.1450 │ Learning Rate: 0.00083
# Epoch 57/500 │ Loss: +1.0637 │ Free En. Mean: 1.0699 │ Free En. Var: 2.0282 │ Learning Rate: 0.00083
# Epoch 58/500 │ Loss: +1.0693 │ Free En. Mean: 1.0365 │ Free En. Var: 2.0277 │ Learning Rate: 0.00083
# Epoch 59/500 │ Loss: +1.0673 │ Free En. Mean: 1.1443 │ Free En. Var: 2.1786 │ Learning Rate: 0.00083
# Epoch 60/500 │ Loss: +1.0582 │ Free En. Mean: 1.0611 │ Free En. Var: 1.9650 │ Learning Rate: 0.00083
# Epoch 61/500 │ Loss: +1.0550 │ Free En. Mean: 0.9226 │ Free En. Var: 1.9261 │ Learning Rate: 0.00082
# Epoch 62/500 │ Loss: +1.0656 │ Free En. Mean: 1.0292 │ Free En. Var: 2.0197 │ Learning Rate: 0.00082
# Epoch 63/500 │ Loss: +1.0683 │ Free En. Mean: 1.0070 │ Free En. Var: 2.0679 │ Learning Rate: 0.00082
# Epoch 64/500 │ Loss: +1.0609 │ Free En. Mean: 1.2117 │ Free En. Var: 2.1701 │ Learning Rate: 0.00082
# Epoch 65/500 │ Loss: +1.0517 │ Free En. Mean: 0.9930 │ Free En. Var: 1.9957 │ Learning Rate: 0.00082
# Epoch 66/500 │ Loss: +1.0614 │ Free En. Mean: 1.1437 │ Free En. Var: 2.0127 │ Learning Rate: 0.00082
# Epoch 67/500 │ Loss: +1.0435 │ Free En. Mean: 1.0099 │ Free En. Var: 2.0126 │ Learning Rate: 0.00082
# Epoch 68/500 │ Loss: +1.0519 │ Free En. Mean: 0.9932 │ Free En. Var: 1.9976 │ Learning Rate: 0.00082
# Epoch 69/500 │ Loss: +1.0637 │ Free En. Mean: 1.1170 │ Free En. Var: 2.0783 │ Learning Rate: 0.00082
# Epoch 70/500 │ Loss: +1.0676 │ Free En. Mean: 1.1579 │ Free En. Var: 2.0866 │ Learning Rate: 0.00081
# Epoch 71/500 │ Loss: +1.0509 │ Free En. Mean: 1.0300 │ Free En. Var: 2.0155 │ Learning Rate: 0.00081
# Epoch 72/500 │ Loss: +1.0583 │ Free En. Mean: 1.0626 │ Free En. Var: 2.0263 │ Learning Rate: 0.00081
# Epoch 73/500 │ Loss: +1.0538 │ Free En. Mean: 1.0361 │ Free En. Var: 1.9921 │ Learning Rate: 0.00081
# Epoch 74/500 │ Loss: +1.0615 │ Free En. Mean: 1.0457 │ Free En. Var: 1.9914 │ Learning Rate: 0.00081
# Epoch 75/500 │ Loss: +1.0387 │ Free En. Mean: 0.9152 │ Free En. Var: 2.0322 │ Learning Rate: 0.00081
# Epoch 76/500 │ Loss: +1.0486 │ Free En. Mean: 1.0185 │ Free En. Var: 2.0400 │ Learning Rate: 0.00081
# Epoch 77/500 │ Loss: +1.0547 │ Free En. Mean: 1.0744 │ Free En. Var: 2.0405 │ Learning Rate: 0.00081
# Epoch 78/500 │ Loss: +1.0576 │ Free En. Mean: 1.1441 │ Free En. Var: 2.0534 │ Learning Rate: 0.00081
# Epoch 79/500 │ Loss: +1.0671 │ Free En. Mean: 1.0744 │ Free En. Var: 2.0170 │ Learning Rate: 0.00080
# Epoch 80/500 │ Loss: +1.0608 │ Free En. Mean: 1.1528 │ Free En. Var: 2.0274 │ Learning Rate: 0.00080
# Epoch 81/500 │ Loss: +1.0624 │ Free En. Mean: 1.1095 │ Free En. Var: 2.1445 │ Learning Rate: 0.00080
# Epoch 82/500 │ Loss: +1.0639 │ Free En. Mean: 1.0219 │ Free En. Var: 1.9690 │ Learning Rate: 0.00080
# Epoch 83/500 │ Loss: +1.0521 │ Free En. Mean: 1.0332 │ Free En. Var: 1.9252 │ Learning Rate: 0.00080
# Epoch 84/500 │ Loss: +1.0627 │ Free En. Mean: 1.1327 │ Free En. Var: 2.0574 │ Learning Rate: 0.00080
# Epoch 85/500 │ Loss: +1.0556 │ Free En. Mean: 1.1351 │ Free En. Var: 2.0228 │ Learning Rate: 0.00080
# Epoch 86/500 │ Loss: +1.0473 │ Free En. Mean: 1.1447 │ Free En. Var: 2.0386 │ Learning Rate: 0.00080
# Epoch 87/500 │ Loss: +1.0514 │ Free En. Mean: 1.1123 │ Free En. Var: 2.0594 │ Learning Rate: 0.00080
# Epoch 88/500 │ Loss: +1.0670 │ Free En. Mean: 1.2176 │ Free En. Var: 2.0940 │ Learning Rate: 0.00079
# Epoch 89/500 │ Loss: +1.0668 │ Free En. Mean: 1.1219 │ Free En. Var: 2.1094 │ Learning Rate: 0.00079
# Epoch 90/500 │ Loss: +1.0565 │ Free En. Mean: 1.0258 │ Free En. Var: 1.9315 │ Learning Rate: 0.00079
# Epoch 91/500 │ Loss: +1.0460 │ Free En. Mean: 1.0409 │ Free En. Var: 2.0179 │ Learning Rate: 0.00079
# Epoch 92/500 │ Loss: +1.0633 │ Free En. Mean: 1.0068 │ Free En. Var: 2.0336 │ Learning Rate: 0.00079
# Epoch 93/500 │ Loss: +1.0655 │ Free En. Mean: 1.0353 │ Free En. Var: 2.0686 │ Learning Rate: 0.00079
# Epoch 94/500 │ Loss: +1.0682 │ Free En. Mean: 1.0346 │ Free En. Var: 2.0948 │ Learning Rate: 0.00079
# Epoch 95/500 │ Loss: +1.0505 │ Free En. Mean: 1.0005 │ Free En. Var: 1.9503 │ Learning Rate: 0.00079
# Epoch 96/500 │ Loss: +1.0616 │ Free En. Mean: 1.1204 │ Free En. Var: 2.0312 │ Learning Rate: 0.00078
# Epoch 97/500 │ Loss: +1.0775 │ Free En. Mean: 1.0905 │ Free En. Var: 2.0434 │ Learning Rate: 0.00078
# Epoch 98/500 │ Loss: +1.0537 │ Free En. Mean: 1.0576 │ Free En. Var: 2.0013 │ Learning Rate: 0.00078
# Epoch 99/500 │ Loss: +1.0731 │ Free En. Mean: 1.0835 │ Free En. Var: 2.0255 │ Learning Rate: 0.00078
# Epoch 100/500 │ Loss: +1.0781 │ Free En. Mean: 1.1301 │ Free En. Var: 2.1908 │ Learning Rate: 0.00078
# Epoch 101/500 │ Loss: +1.0436 │ Free En. Mean: 1.0653 │ Free En. Var: 2.0107 │ Learning Rate: 0.00078
# Epoch 102/500 │ Loss: +1.0508 │ Free En. Mean: 1.1456 │ Free En. Var: 2.0990 │ Learning Rate: 0.00078
# Epoch 103/500 │ Loss: +1.0426 │ Free En. Mean: 1.0194 │ Free En. Var: 1.9533 │ Learning Rate: 0.00078
# Epoch 104/500 │ Loss: +1.0631 │ Free En. Mean: 1.0210 │ Free En. Var: 1.9446 │ Learning Rate: 0.00077
# Epoch 105/500 │ Loss: +1.0480 │ Free En. Mean: 0.9603 │ Free En. Var: 1.8992 │ Learning Rate: 0.00077
# Epoch 106/500 │ Loss: +1.0536 │ Free En. Mean: 1.0617 │ Free En. Var: 2.0865 │ Learning Rate: 0.00077
# Epoch 107/500 │ Loss: +1.0410 │ Free En. Mean: 1.0723 │ Free En. Var: 2.1861 │ Learning Rate: 0.00077
# Epoch 108/500 │ Loss: +1.0514 │ Free En. Mean: 1.0791 │ Free En. Var: 2.0443 │ Learning Rate: 0.00077
# Epoch 109/500 │ Loss: +1.0541 │ Free En. Mean: 1.0380 │ Free En. Var: 2.0050 │ Learning Rate: 0.00077
# Epoch 110/500 │ Loss: +1.0639 │ Free En. Mean: 0.9499 │ Free En. Var: 1.9629 │ Learning Rate: 0.00077
# Epoch 111/500 │ Loss: +1.0533 │ Free En. Mean: 1.0520 │ Free En. Var: 2.0005 │ Learning Rate: 0.00077
# Epoch 112/500 │ Loss: +1.0594 │ Free En. Mean: 1.0466 │ Free En. Var: 1.9641 │ Learning Rate: 0.00076
# Epoch 113/500 │ Loss: +1.0553 │ Free En. Mean: 1.0441 │ Free En. Var: 1.9377 │ Learning Rate: 0.00076
# Epoch 114/500 │ Loss: +1.0855 │ Free En. Mean: 1.1237 │ Free En. Var: 2.1263 │ Learning Rate: 0.00076
# Epoch 115/500 │ Loss: +1.0549 │ Free En. Mean: 1.0636 │ Free En. Var: 2.0575 │ Learning Rate: 0.00076
# Epoch 116/500 │ Loss: +1.0717 │ Free En. Mean: 1.0127 │ Free En. Var: 1.9615 │ Learning Rate: 0.00076
# Epoch 117/500 │ Loss: +1.0498 │ Free En. Mean: 1.0661 │ Free En. Var: 2.1082 │ Learning Rate: 0.00076
# Epoch 118/500 │ Loss: +1.0529 │ Free En. Mean: 1.1231 │ Free En. Var: 2.0907 │ Learning Rate: 0.00076
# Epoch 119/500 │ Loss: +1.0632 │ Free En. Mean: 0.9621 │ Free En. Var: 1.9381 │ Learning Rate: 0.00075
# Epoch 120/500 │ Loss: +1.0589 │ Free En. Mean: 1.0095 │ Free En. Var: 1.9759 │ Learning Rate: 0.00075
# Epoch 121/500 │ Loss: +1.0422 │ Free En. Mean: 1.0287 │ Free En. Var: 1.9710 │ Learning Rate: 0.00075
# Epoch 122/500 │ Loss: +1.0737 │ Free En. Mean: 1.1615 │ Free En. Var: 2.0950 │ Learning Rate: 0.00075
# Epoch 123/500 │ Loss: +1.0595 │ Free En. Mean: 0.9822 │ Free En. Var: 2.0127 │ Learning Rate: 0.00075
# Epoch 124/500 │ Loss: +1.0604 │ Free En. Mean: 1.0585 │ Free En. Var: 2.0252 │ Learning Rate: 0.00075
# Epoch 125/500 │ Loss: +1.0544 │ Free En. Mean: 1.0113 │ Free En. Var: 2.0158 │ Learning Rate: 0.00075
# Epoch 126/500 │ Loss: +1.0505 │ Free En. Mean: 1.1031 │ Free En. Var: 2.0155 │ Learning Rate: 0.00075
# Epoch 127/500 │ Loss: +1.0573 │ Free En. Mean: 1.0490 │ Free En. Var: 2.0264 │ Learning Rate: 0.00074
# Epoch 128/500 │ Loss: +1.0609 │ Free En. Mean: 1.0595 │ Free En. Var: 1.9962 │ Learning Rate: 0.00074
# Epoch 129/500 │ Loss: +1.0609 │ Free En. Mean: 1.0903 │ Free En. Var: 1.9832 │ Learning Rate: 0.00074
# Epoch 130/500 │ Loss: +1.0528 │ Free En. Mean: 1.0464 │ Free En. Var: 2.0530 │ Learning Rate: 0.00074
# Epoch 131/500 │ Loss: +1.0604 │ Free En. Mean: 1.0990 │ Free En. Var: 2.0802 │ Learning Rate: 0.00074
# Epoch 132/500 │ Loss: +1.0618 │ Free En. Mean: 1.0523 │ Free En. Var: 2.0112 │ Learning Rate: 0.00074
# Epoch 133/500 │ Loss: +1.0768 │ Free En. Mean: 1.0138 │ Free En. Var: 1.9677 │ Learning Rate: 0.00074
# Epoch 134/500 │ Loss: +1.0619 │ Free En. Mean: 1.0728 │ Free En. Var: 1.9670 │ Learning Rate: 0.00073
# Epoch 135/500 │ Loss: +1.0667 │ Free En. Mean: 1.1315 │ Free En. Var: 2.1227 │ Learning Rate: 0.00073
# Epoch 136/500 │ Loss: +1.0600 │ Free En. Mean: 1.0475 │ Free En. Var: 2.0513 │ Learning Rate: 0.00073
# Epoch 137/500 │ Loss: +1.0573 │ Free En. Mean: 1.0065 │ Free En. Var: 2.0428 │ Learning Rate: 0.00073
# Epoch 138/500 │ Loss: +1.0506 │ Free En. Mean: 1.0101 │ Free En. Var: 1.9907 │ Learning Rate: 0.00073
# Epoch 139/500 │ Loss: +1.0408 │ Free En. Mean: 1.0503 │ Free En. Var: 2.0871 │ Learning Rate: 0.00073
# Epoch 140/500 │ Loss: +1.0496 │ Free En. Mean: 0.8789 │ Free En. Var: 1.8674 │ Learning Rate: 0.00073
# Epoch 141/500 │ Loss: +1.0542 │ Free En. Mean: 1.1083 │ Free En. Var: 2.0526 │ Learning Rate: 0.00072
# Epoch 142/500 │ Loss: +1.0584 │ Free En. Mean: 1.0787 │ Free En. Var: 2.0077 │ Learning Rate: 0.00072
# Epoch 143/500 │ Loss: +1.0547 │ Free En. Mean: 1.0471 │ Free En. Var: 2.0233 │ Learning Rate: 0.00072
# Epoch 144/500 │ Loss: +1.0651 │ Free En. Mean: 1.0876 │ Free En. Var: 2.0259 │ Learning Rate: 0.00072
# Epoch 145/500 │ Loss: +1.0497 │ Free En. Mean: 1.0594 │ Free En. Var: 2.0851 │ Learning Rate: 0.00072
# Epoch 146/500 │ Loss: +1.0629 │ Free En. Mean: 1.0832 │ Free En. Var: 1.9811 │ Learning Rate: 0.00072
# Epoch 147/500 │ Loss: +1.0543 │ Free En. Mean: 1.1354 │ Free En. Var: 2.0542 │ Learning Rate: 0.00072
# Epoch 148/500 │ Loss: +1.0539 │ Free En. Mean: 0.9453 │ Free En. Var: 1.9659 │ Learning Rate: 0.00071
# Epoch 149/500 │ Loss: +1.0562 │ Free En. Mean: 1.0803 │ Free En. Var: 2.0704 │ Learning Rate: 0.00071
# Epoch 150/500 │ Loss: +1.0549 │ Free En. Mean: 1.0704 │ Free En. Var: 1.9878 │ Learning Rate: 0.00071
# Epoch 151/500 │ Loss: +1.0606 │ Free En. Mean: 1.1370 │ Free En. Var: 2.0928 │ Learning Rate: 0.00071
# Epoch 152/500 │ Loss: +1.0553 │ Free En. Mean: 1.0365 │ Free En. Var: 2.0363 │ Learning Rate: 0.00071
# Epoch 153/500 │ Loss: +1.0585 │ Free En. Mean: 1.1404 │ Free En. Var: 2.0621 │ Learning Rate: 0.00071
# Epoch 154/500 │ Loss: +1.0603 │ Free En. Mean: 1.1296 │ Free En. Var: 2.1758 │ Learning Rate: 0.00071
# Epoch 155/500 │ Loss: +1.0603 │ Free En. Mean: 1.1085 │ Free En. Var: 2.1702 │ Learning Rate: 0.00070
# Epoch 156/500 │ Loss: +1.0449 │ Free En. Mean: 1.0320 │ Free En. Var: 2.0101 │ Learning Rate: 0.00070
# Epoch 157/500 │ Loss: +1.0653 │ Free En. Mean: 1.0368 │ Free En. Var: 1.9584 │ Learning Rate: 0.00070
# Epoch 158/500 │ Loss: +1.0454 │ Free En. Mean: 0.9490 │ Free En. Var: 2.0166 │ Learning Rate: 0.00070
# Epoch 159/500 │ Loss: +1.0555 │ Free En. Mean: 0.9424 │ Free En. Var: 1.8949 │ Learning Rate: 0.00070
# Epoch 160/500 │ Loss: +1.0641 │ Free En. Mean: 1.1213 │ Free En. Var: 1.9574 │ Learning Rate: 0.00070
# Epoch 161/500 │ Loss: +1.0588 │ Free En. Mean: 1.0054 │ Free En. Var: 1.9862 │ Learning Rate: 0.00069
# Epoch 162/500 │ Loss: +1.0517 │ Free En. Mean: 1.1223 │ Free En. Var: 2.0796 │ Learning Rate: 0.00069
# Epoch 163/500 │ Loss: +1.0639 │ Free En. Mean: 1.0029 │ Free En. Var: 1.9042 │ Learning Rate: 0.00069
# Epoch 164/500 │ Loss: +1.0671 │ Free En. Mean: 1.0910 │ Free En. Var: 2.0232 │ Learning Rate: 0.00069
# Epoch 165/500 │ Loss: +1.0518 │ Free En. Mean: 1.0826 │ Free En. Var: 2.0961 │ Learning Rate: 0.00069
# Epoch 166/500 │ Loss: +1.0536 │ Free En. Mean: 1.0432 │ Free En. Var: 1.9674 │ Learning Rate: 0.00069
# Epoch 167/500 │ Loss: +1.0576 │ Free En. Mean: 1.1306 │ Free En. Var: 2.0364 │ Learning Rate: 0.00069
# Epoch 168/500 │ Loss: +1.0443 │ Free En. Mean: 0.9958 │ Free En. Var: 2.0129 │ Learning Rate: 0.00068
# Epoch 169/500 │ Loss: +1.0509 │ Free En. Mean: 1.0815 │ Free En. Var: 2.0837 │ Learning Rate: 0.00068
# Epoch 170/500 │ Loss: +1.0684 │ Free En. Mean: 1.0672 │ Free En. Var: 2.0297 │ Learning Rate: 0.00068
# Epoch 171/500 │ Loss: +1.0520 │ Free En. Mean: 1.0733 │ Free En. Var: 2.0594 │ Learning Rate: 0.00068
# Epoch 172/500 │ Loss: +1.0633 │ Free En. Mean: 1.1555 │ Free En. Var: 1.9744 │ Learning Rate: 0.00068
# Epoch 173/500 │ Loss: +1.0497 │ Free En. Mean: 1.0488 │ Free En. Var: 2.1271 │ Learning Rate: 0.00068
# Epoch 174/500 │ Loss: +1.0562 │ Free En. Mean: 1.1157 │ Free En. Var: 2.0434 │ Learning Rate: 0.00067
# Epoch 175/500 │ Loss: +1.0435 │ Free En. Mean: 1.0222 │ Free En. Var: 1.9928 │ Learning Rate: 0.00067
# Epoch 176/500 │ Loss: +1.0474 │ Free En. Mean: 1.0146 │ Free En. Var: 2.0646 │ Learning Rate: 0.00067
# Epoch 177/500 │ Loss: +1.0557 │ Free En. Mean: 0.9951 │ Free En. Var: 1.9692 │ Learning Rate: 0.00067
# Epoch 178/500 │ Loss: +1.0445 │ Free En. Mean: 1.0422 │ Free En. Var: 2.0005 │ Learning Rate: 0.00067
# Epoch 179/500 │ Loss: +1.0523 │ Free En. Mean: 1.1161 │ Free En. Var: 2.0687 │ Learning Rate: 0.00067
# Epoch 180/500 │ Loss: +1.0631 │ Free En. Mean: 1.1148 │ Free En. Var: 2.0343 │ Learning Rate: 0.00067
# Epoch 181/500 │ Loss: +1.0540 │ Free En. Mean: 1.0195 │ Free En. Var: 1.9656 │ Learning Rate: 0.00066
# Epoch 182/500 │ Loss: +1.0506 │ Free En. Mean: 0.9919 │ Free En. Var: 1.9043 │ Learning Rate: 0.00066
# Epoch 183/500 │ Loss: +1.0710 │ Free En. Mean: 1.1505 │ Free En. Var: 1.9798 │ Learning Rate: 0.00066
# Epoch 184/500 │ Loss: +1.0564 │ Free En. Mean: 1.0112 │ Free En. Var: 2.0013 │ Learning Rate: 0.00066
# Epoch 185/500 │ Loss: +1.0520 │ Free En. Mean: 1.1291 │ Free En. Var: 2.1858 │ Learning Rate: 0.00066
# Epoch 186/500 │ Loss: +1.0360 │ Free En. Mean: 1.0095 │ Free En. Var: 2.0145 │ Learning Rate: 0.00066
# Epoch 187/500 │ Loss: +1.0461 │ Free En. Mean: 1.0286 │ Free En. Var: 2.0028 │ Learning Rate: 0.00065
# Epoch 188/500 │ Loss: +1.0427 │ Free En. Mean: 1.1591 │ Free En. Var: 2.0339 │ Learning Rate: 0.00065
# Epoch 189/500 │ Loss: +1.0421 │ Free En. Mean: 1.0494 │ Free En. Var: 2.0077 │ Learning Rate: 0.00065
# Epoch 190/500 │ Loss: +1.0330 │ Free En. Mean: 1.0351 │ Free En. Var: 1.9992 │ Learning Rate: 0.00065
# Epoch 191/500 │ Loss: +1.0399 │ Free En. Mean: 1.0196 │ Free En. Var: 1.9193 │ Learning Rate: 0.00065
# Epoch 192/500 │ Loss: +1.0342 │ Free En. Mean: 1.1426 │ Free En. Var: 2.0418 │ Learning Rate: 0.00065
# Epoch 193/500 │ Loss: +1.0261 │ Free En. Mean: 1.0140 │ Free En. Var: 1.9700 │ Learning Rate: 0.00064
# Epoch 194/500 │ Loss: +1.0331 │ Free En. Mean: 0.9834 │ Free En. Var: 1.9395 │ Learning Rate: 0.00064
# Epoch 195/500 │ Loss: +1.0298 │ Free En. Mean: 1.0062 │ Free En. Var: 1.8941 │ Learning Rate: 0.00064
# Epoch 196/500 │ Loss: +1.0287 │ Free En. Mean: 1.0404 │ Free En. Var: 1.9740 │ Learning Rate: 0.00064
# Epoch 197/500 │ Loss: +1.0323 │ Free En. Mean: 0.9977 │ Free En. Var: 1.9848 │ Learning Rate: 0.00064
# Epoch 198/500 │ Loss: +1.0270 │ Free En. Mean: 1.0848 │ Free En. Var: 2.0650 │ Learning Rate: 0.00064
# Epoch 199/500 │ Loss: +1.0168 │ Free En. Mean: 1.0416 │ Free En. Var: 2.0060 │ Learning Rate: 0.00064
# Epoch 200/500 │ Loss: +1.0174 │ Free En. Mean: 1.0054 │ Free En. Var: 1.9858 │ Learning Rate: 0.00063
# Epoch 201/500 │ Loss: +1.0214 │ Free En. Mean: 0.9490 │ Free En. Var: 1.8994 │ Learning Rate: 0.00063
# Epoch 202/500 │ Loss: +1.0145 │ Free En. Mean: 0.8677 │ Free En. Var: 1.8790 │ Learning Rate: 0.00063
# Epoch 203/500 │ Loss: +1.0146 │ Free En. Mean: 0.9588 │ Free En. Var: 1.9736 │ Learning Rate: 0.00063
# Epoch 204/500 │ Loss: +1.0053 │ Free En. Mean: 0.9798 │ Free En. Var: 1.8946 │ Learning Rate: 0.00063
# Epoch 205/500 │ Loss: +1.0106 │ Free En. Mean: 0.9299 │ Free En. Var: 1.9565 │ Learning Rate: 0.00063
# Epoch 206/500 │ Loss: +1.0028 │ Free En. Mean: 1.0237 │ Free En. Var: 1.9903 │ Learning Rate: 0.00062
# Epoch 207/500 │ Loss: +0.9960 │ Free En. Mean: 0.9452 │ Free En. Var: 1.9735 │ Learning Rate: 0.00062
# Epoch 208/500 │ Loss: +0.9753 │ Free En. Mean: 1.0104 │ Free En. Var: 1.9375 │ Learning Rate: 0.00062
# Epoch 209/500 │ Loss: +0.9842 │ Free En. Mean: 1.0152 │ Free En. Var: 1.9404 │ Learning Rate: 0.00062
# Epoch 210/500 │ Loss: +0.9915 │ Free En. Mean: 1.1157 │ Free En. Var: 2.0906 │ Learning Rate: 0.00062
# Epoch 211/500 │ Loss: +0.9836 │ Free En. Mean: 0.9878 │ Free En. Var: 1.9640 │ Learning Rate: 0.00062
# Epoch 212/500 │ Loss: +0.9726 │ Free En. Mean: 0.9638 │ Free En. Var: 1.9473 │ Learning Rate: 0.00061
# Epoch 213/500 │ Loss: +0.9776 │ Free En. Mean: 0.9726 │ Free En. Var: 1.8285 │ Learning Rate: 0.00061
# Epoch 214/500 │ Loss: +0.9669 │ Free En. Mean: 1.0566 │ Free En. Var: 2.0522 │ Learning Rate: 0.00061
# Epoch 215/500 │ Loss: +0.9540 │ Free En. Mean: 0.9866 │ Free En. Var: 1.9997 │ Learning Rate: 0.00061
# Epoch 216/500 │ Loss: +0.9524 │ Free En. Mean: 0.9601 │ Free En. Var: 1.9144 │ Learning Rate: 0.00061
# Epoch 217/500 │ Loss: +0.9331 │ Free En. Mean: 0.8715 │ Free En. Var: 1.9106 │ Learning Rate: 0.00061
# Epoch 218/500 │ Loss: +0.9353 │ Free En. Mean: 0.9332 │ Free En. Var: 1.9318 │ Learning Rate: 0.00060
# Epoch 219/500 │ Loss: +0.9264 │ Free En. Mean: 0.9996 │ Free En. Var: 1.7978 │ Learning Rate: 0.00060
# Epoch 220/500 │ Loss: +0.9232 │ Free En. Mean: 0.9512 │ Free En. Var: 1.8762 │ Learning Rate: 0.00060
# Epoch 221/500 │ Loss: +0.8908 │ Free En. Mean: 0.8746 │ Free En. Var: 1.8345 │ Learning Rate: 0.00060
# Epoch 222/500 │ Loss: +0.9188 │ Free En. Mean: 0.8515 │ Free En. Var: 1.8626 │ Learning Rate: 0.00060
# Epoch 223/500 │ Loss: +0.8880 │ Free En. Mean: 0.9004 │ Free En. Var: 1.9214 │ Learning Rate: 0.00060
# Epoch 224/500 │ Loss: +0.8973 │ Free En. Mean: 0.7897 │ Free En. Var: 1.8072 │ Learning Rate: 0.00059
# Epoch 225/500 │ Loss: +0.8672 │ Free En. Mean: 0.8832 │ Free En. Var: 1.8503 │ Learning Rate: 0.00059
# Epoch 226/500 │ Loss: +0.8539 │ Free En. Mean: 0.8356 │ Free En. Var: 1.9420 │ Learning Rate: 0.00059
# Epoch 227/500 │ Loss: +0.8647 │ Free En. Mean: 0.8775 │ Free En. Var: 1.9062 │ Learning Rate: 0.00059
# Epoch 228/500 │ Loss: +0.8420 │ Free En. Mean: 0.7235 │ Free En. Var: 1.9274 │ Learning Rate: 0.00059
# Epoch 229/500 │ Loss: +0.8493 │ Free En. Mean: 0.8784 │ Free En. Var: 1.8377 │ Learning Rate: 0.00059
# Epoch 230/500 │ Loss: +0.8434 │ Free En. Mean: 0.7913 │ Free En. Var: 1.9046 │ Learning Rate: 0.00058
# Epoch 231/500 │ Loss: +0.8205 │ Free En. Mean: 0.8389 │ Free En. Var: 1.8978 │ Learning Rate: 0.00058
# Epoch 232/500 │ Loss: +0.8190 │ Free En. Mean: 0.8036 │ Free En. Var: 1.9543 │ Learning Rate: 0.00058
# Epoch 233/500 │ Loss: +0.8077 │ Free En. Mean: 0.7895 │ Free En. Var: 1.8782 │ Learning Rate: 0.00058
# Epoch 234/500 │ Loss: +0.8177 │ Free En. Mean: 0.7229 │ Free En. Var: 1.7928 │ Learning Rate: 0.00058
# Epoch 235/500 │ Loss: +0.7976 │ Free En. Mean: 0.8203 │ Free En. Var: 1.9476 │ Learning Rate: 0.00058
# Epoch 236/500 │ Loss: +0.7887 │ Free En. Mean: 0.8166 │ Free En. Var: 1.8490 │ Learning Rate: 0.00057
# Epoch 237/500 │ Loss: +0.7659 │ Free En. Mean: 0.7506 │ Free En. Var: 1.8839 │ Learning Rate: 0.00057
# Epoch 238/500 │ Loss: +0.7751 │ Free En. Mean: 0.7910 │ Free En. Var: 2.0073 │ Learning Rate: 0.00057
# Epoch 239/500 │ Loss: +0.7667 │ Free En. Mean: 0.8453 │ Free En. Var: 1.9334 │ Learning Rate: 0.00057
# Epoch 240/500 │ Loss: +0.7530 │ Free En. Mean: 0.8409 │ Free En. Var: 1.8737 │ Learning Rate: 0.00057
# Epoch 241/500 │ Loss: +0.7540 │ Free En. Mean: 0.7092 │ Free En. Var: 1.8931 │ Learning Rate: 0.00057
# Epoch 242/500 │ Loss: +0.7590 │ Free En. Mean: 0.7649 │ Free En. Var: 1.7894 │ Learning Rate: 0.00056
# Epoch 243/500 │ Loss: +0.7476 │ Free En. Mean: 0.8116 │ Free En. Var: 1.8801 │ Learning Rate: 0.00056
# Epoch 244/500 │ Loss: +0.7257 │ Free En. Mean: 0.6707 │ Free En. Var: 1.7616 │ Learning Rate: 0.00056
# Epoch 245/500 │ Loss: +0.7395 │ Free En. Mean: 0.7773 │ Free En. Var: 1.8983 │ Learning Rate: 0.00056
# Epoch 246/500 │ Loss: +0.7339 │ Free En. Mean: 0.7685 │ Free En. Var: 1.8819 │ Learning Rate: 0.00056
# Epoch 247/500 │ Loss: +0.7299 │ Free En. Mean: 0.7145 │ Free En. Var: 1.8715 │ Learning Rate: 0.00056
# Epoch 248/500 │ Loss: +0.7184 │ Free En. Mean: 0.8257 │ Free En. Var: 1.9480 │ Learning Rate: 0.00055
# Epoch 249/500 │ Loss: +0.7197 │ Free En. Mean: 0.6876 │ Free En. Var: 1.8110 │ Learning Rate: 0.00055
# Epoch 250/500 │ Loss: +0.7227 │ Free En. Mean: 0.7157 │ Free En. Var: 1.8640 │ Learning Rate: 0.00055
# Epoch 251/500 │ Loss: +0.7118 │ Free En. Mean: 0.7217 │ Free En. Var: 1.7293 │ Learning Rate: 0.00055
# Epoch 252/500 │ Loss: +0.7115 │ Free En. Mean: 0.6873 │ Free En. Var: 1.8070 │ Learning Rate: 0.00055
# Epoch 253/500 │ Loss: +0.7136 │ Free En. Mean: 0.6676 │ Free En. Var: 1.7621 │ Learning Rate: 0.00054
# Epoch 254/500 │ Loss: +0.7227 │ Free En. Mean: 0.7333 │ Free En. Var: 1.8029 │ Learning Rate: 0.00054
# Epoch 255/500 │ Loss: +0.7127 │ Free En. Mean: 0.6852 │ Free En. Var: 1.8162 │ Learning Rate: 0.00054
# Epoch 256/500 │ Loss: +0.6995 │ Free En. Mean: 0.6879 │ Free En. Var: 1.9018 │ Learning Rate: 0.00054
# Epoch 257/500 │ Loss: +0.7210 │ Free En. Mean: 0.6934 │ Free En. Var: 1.8377 │ Learning Rate: 0.00054
# Epoch 258/500 │ Loss: +0.7105 │ Free En. Mean: 0.7212 │ Free En. Var: 1.8015 │ Learning Rate: 0.00054
# Epoch 259/500 │ Loss: +0.6995 │ Free En. Mean: 0.7355 │ Free En. Var: 1.8782 │ Learning Rate: 0.00053
# Epoch 260/500 │ Loss: +0.7136 │ Free En. Mean: 0.8444 │ Free En. Var: 1.9105 │ Learning Rate: 0.00053
# Epoch 261/500 │ Loss: +0.6990 │ Free En. Mean: 0.7322 │ Free En. Var: 1.9135 │ Learning Rate: 0.00053
# Epoch 262/500 │ Loss: +0.7207 │ Free En. Mean: 0.7308 │ Free En. Var: 1.8681 │ Learning Rate: 0.00053
# Epoch 263/500 │ Loss: +0.7139 │ Free En. Mean: 0.7289 │ Free En. Var: 1.8634 │ Learning Rate: 0.00053
# Epoch 264/500 │ Loss: +0.7069 │ Free En. Mean: 0.7535 │ Free En. Var: 1.8955 │ Learning Rate: 0.00053
# Epoch 265/500 │ Loss: +0.6948 │ Free En. Mean: 0.8061 │ Free En. Var: 1.9518 │ Learning Rate: 0.00052
# Epoch 266/500 │ Loss: +0.6947 │ Free En. Mean: 0.7950 │ Free En. Var: 1.9286 │ Learning Rate: 0.00052
# Epoch 267/500 │ Loss: +0.7085 │ Free En. Mean: 0.6772 │ Free En. Var: 1.8468 │ Learning Rate: 0.00052
# Epoch 268/500 │ Loss: +0.7018 │ Free En. Mean: 0.7372 │ Free En. Var: 1.8008 │ Learning Rate: 0.00052
# Epoch 269/500 │ Loss: +0.7122 │ Free En. Mean: 0.6630 │ Free En. Var: 1.7826 │ Learning Rate: 0.00052
# Epoch 270/500 │ Loss: +0.7067 │ Free En. Mean: 0.6571 │ Free En. Var: 1.8241 │ Learning Rate: 0.00052
# Epoch 271/500 │ Loss: +0.6998 │ Free En. Mean: 0.6435 │ Free En. Var: 1.7704 │ Learning Rate: 0.00051
# Epoch 272/500 │ Loss: +0.7133 │ Free En. Mean: 0.6116 │ Free En. Var: 1.7778 │ Learning Rate: 0.00051
# Epoch 273/500 │ Loss: +0.7036 │ Free En. Mean: 0.6820 │ Free En. Var: 1.8061 │ Learning Rate: 0.00051
# Epoch 274/500 │ Loss: +0.7104 │ Free En. Mean: 0.7583 │ Free En. Var: 1.8079 │ Learning Rate: 0.00051
# Epoch 275/500 │ Loss: +0.6934 │ Free En. Mean: 0.6737 │ Free En. Var: 1.7893 │ Learning Rate: 0.00051
# Epoch 276/500 │ Loss: +0.6994 │ Free En. Mean: 0.6732 │ Free En. Var: 1.8604 │ Learning Rate: 0.00051
# Epoch 277/500 │ Loss: +0.6994 │ Free En. Mean: 0.7582 │ Free En. Var: 1.8650 │ Learning Rate: 0.00050
# Epoch 278/500 │ Loss: +0.6931 │ Free En. Mean: 0.6839 │ Free En. Var: 1.7943 │ Learning Rate: 0.00050
# Epoch 279/500 │ Loss: +0.7019 │ Free En. Mean: 0.8019 │ Free En. Var: 1.8827 │ Learning Rate: 0.00050
# Epoch 280/500 │ Loss: +0.6849 │ Free En. Mean: 0.6603 │ Free En. Var: 1.7965 │ Learning Rate: 0.00050
# Epoch 281/500 │ Loss: +0.7068 │ Free En. Mean: 0.6992 │ Free En. Var: 1.8091 │ Learning Rate: 0.00050
# Epoch 282/500 │ Loss: +0.7017 │ Free En. Mean: 0.7374 │ Free En. Var: 1.8859 │ Learning Rate: 0.00050
# Epoch 283/500 │ Loss: +0.7054 │ Free En. Mean: 0.7415 │ Free En. Var: 1.8089 │ Learning Rate: 0.00049
# Epoch 284/500 │ Loss: +0.6912 │ Free En. Mean: 0.7690 │ Free En. Var: 1.8976 │ Learning Rate: 0.00049
# Epoch 285/500 │ Loss: +0.7012 │ Free En. Mean: 0.6671 │ Free En. Var: 1.7826 │ Learning Rate: 0.00049
# Epoch 286/500 │ Loss: +0.7010 │ Free En. Mean: 0.7211 │ Free En. Var: 1.8104 │ Learning Rate: 0.00049
# Epoch 287/500 │ Loss: +0.7004 │ Free En. Mean: 0.6631 │ Free En. Var: 1.7757 │ Learning Rate: 0.00049
# Epoch 288/500 │ Loss: +0.6978 │ Free En. Mean: 0.7797 │ Free En. Var: 1.9411 │ Learning Rate: 0.00049
# Epoch 289/500 │ Loss: +0.6831 │ Free En. Mean: 0.7416 │ Free En. Var: 1.9082 │ Learning Rate: 0.00048
# Epoch 290/500 │ Loss: +0.6885 │ Free En. Mean: 0.6771 │ Free En. Var: 1.8249 │ Learning Rate: 0.00048
# Epoch 291/500 │ Loss: +0.7030 │ Free En. Mean: 0.7375 │ Free En. Var: 1.8147 │ Learning Rate: 0.00048
# Epoch 292/500 │ Loss: +0.6920 │ Free En. Mean: 0.6394 │ Free En. Var: 1.7556 │ Learning Rate: 0.00048
# Epoch 293/500 │ Loss: +0.7051 │ Free En. Mean: 0.6377 │ Free En. Var: 1.8381 │ Learning Rate: 0.00048
# Epoch 294/500 │ Loss: +0.7032 │ Free En. Mean: 0.7554 │ Free En. Var: 1.9040 │ Learning Rate: 0.00048
# Epoch 295/500 │ Loss: +0.6881 │ Free En. Mean: 0.7067 │ Free En. Var: 1.8772 │ Learning Rate: 0.00047
# Epoch 296/500 │ Loss: +0.6875 │ Free En. Mean: 0.6733 │ Free En. Var: 1.8357 │ Learning Rate: 0.00047
# Epoch 297/500 │ Loss: +0.6865 │ Free En. Mean: 0.7762 │ Free En. Var: 1.9391 │ Learning Rate: 0.00047
# Epoch 298/500 │ Loss: +0.6904 │ Free En. Mean: 0.7260 │ Free En. Var: 1.8168 │ Learning Rate: 0.00047
# Epoch 299/500 │ Loss: +0.6912 │ Free En. Mean: 0.6043 │ Free En. Var: 1.8095 │ Learning Rate: 0.00047
# Epoch 300/500 │ Loss: +0.6967 │ Free En. Mean: 0.7303 │ Free En. Var: 1.8646 │ Learning Rate: 0.00047
# Epoch 301/500 │ Loss: +0.6964 │ Free En. Mean: 0.7862 │ Free En. Var: 1.9341 │ Learning Rate: 0.00046
# Epoch 302/500 │ Loss: +0.6866 │ Free En. Mean: 0.5759 │ Free En. Var: 1.7446 │ Learning Rate: 0.00046
# Epoch 303/500 │ Loss: +0.6994 │ Free En. Mean: 0.7128 │ Free En. Var: 1.7831 │ Learning Rate: 0.00046
# Epoch 304/500 │ Loss: +0.6913 │ Free En. Mean: 0.7164 │ Free En. Var: 1.8115 │ Learning Rate: 0.00046
# Epoch 305/500 │ Loss: +0.6889 │ Free En. Mean: 0.7565 │ Free En. Var: 1.8990 │ Learning Rate: 0.00046
# Epoch 306/500 │ Loss: +0.6849 │ Free En. Mean: 0.6866 │ Free En. Var: 1.9279 │ Learning Rate: 0.00046
# Epoch 307/500 │ Loss: +0.7046 │ Free En. Mean: 0.6621 │ Free En. Var: 1.8417 │ Learning Rate: 0.00046
# Epoch 308/500 │ Loss: +0.6921 │ Free En. Mean: 0.7871 │ Free En. Var: 1.9170 │ Learning Rate: 0.00045
# Epoch 309/500 │ Loss: +0.6996 │ Free En. Mean: 0.7098 │ Free En. Var: 1.9443 │ Learning Rate: 0.00045
# Epoch 310/500 │ Loss: +0.6873 │ Free En. Mean: 0.6473 │ Free En. Var: 1.8219 │ Learning Rate: 0.00045
# Epoch 311/500 │ Loss: +0.6851 │ Free En. Mean: 0.6612 │ Free En. Var: 1.7798 │ Learning Rate: 0.00045
# Epoch 312/500 │ Loss: +0.7007 │ Free En. Mean: 0.6302 │ Free En. Var: 1.8194 │ Learning Rate: 0.00045
# Epoch 313/500 │ Loss: +0.6789 │ Free En. Mean: 0.6905 │ Free En. Var: 1.8732 │ Learning Rate: 0.00045
# Epoch 314/500 │ Loss: +0.6987 │ Free En. Mean: 0.6437 │ Free En. Var: 1.7796 │ Learning Rate: 0.00044
# Epoch 315/500 │ Loss: +0.6735 │ Free En. Mean: 0.6752 │ Free En. Var: 1.7960 │ Learning Rate: 0.00044
# Epoch 316/500 │ Loss: +0.7007 │ Free En. Mean: 0.7303 │ Free En. Var: 1.8653 │ Learning Rate: 0.00044
# Epoch 317/500 │ Loss: +0.6820 │ Free En. Mean: 0.6858 │ Free En. Var: 1.8506 │ Learning Rate: 0.00044
# Epoch 318/500 │ Loss: +0.6879 │ Free En. Mean: 0.6191 │ Free En. Var: 1.8214 │ Learning Rate: 0.00044
# Epoch 319/500 │ Loss: +0.6969 │ Free En. Mean: 0.7719 │ Free En. Var: 1.8331 │ Learning Rate: 0.00044
# Epoch 320/500 │ Loss: +0.6831 │ Free En. Mean: 0.7652 │ Free En. Var: 1.9120 │ Learning Rate: 0.00043
# Epoch 321/500 │ Loss: +0.6897 │ Free En. Mean: 0.6982 │ Free En. Var: 1.7537 │ Learning Rate: 0.00043
# Epoch 322/500 │ Loss: +0.6797 │ Free En. Mean: 0.6807 │ Free En. Var: 1.8347 │ Learning Rate: 0.00043
# Epoch 323/500 │ Loss: +0.6913 │ Free En. Mean: 0.7151 │ Free En. Var: 1.7672 │ Learning Rate: 0.00043
# Epoch 324/500 │ Loss: +0.6925 │ Free En. Mean: 0.7077 │ Free En. Var: 1.8913 │ Learning Rate: 0.00043
# Epoch 325/500 │ Loss: +0.6780 │ Free En. Mean: 0.5851 │ Free En. Var: 1.8387 │ Learning Rate: 0.00043
# Epoch 326/500 │ Loss: +0.6982 │ Free En. Mean: 0.6480 │ Free En. Var: 1.8821 │ Learning Rate: 0.00043
# Epoch 327/500 │ Loss: +0.6975 │ Free En. Mean: 0.7239 │ Free En. Var: 1.8708 │ Learning Rate: 0.00042
# Epoch 328/500 │ Loss: +0.6890 │ Free En. Mean: 0.6456 │ Free En. Var: 1.8423 │ Learning Rate: 0.00042
# Epoch 329/500 │ Loss: +0.6904 │ Free En. Mean: 0.6480 │ Free En. Var: 1.7406 │ Learning Rate: 0.00042
# Epoch 330/500 │ Loss: +0.6966 │ Free En. Mean: 0.7558 │ Free En. Var: 1.8627 │ Learning Rate: 0.00042
# Epoch 331/500 │ Loss: +0.6886 │ Free En. Mean: 0.7816 │ Free En. Var: 1.9269 │ Learning Rate: 0.00042
# Epoch 332/500 │ Loss: +0.6833 │ Free En. Mean: 0.7483 │ Free En. Var: 1.9088 │ Learning Rate: 0.00042
# Epoch 333/500 │ Loss: +0.6906 │ Free En. Mean: 0.6754 │ Free En. Var: 1.8075 │ Learning Rate: 0.00041
# Epoch 334/500 │ Loss: +0.6932 │ Free En. Mean: 0.7966 │ Free En. Var: 1.8754 │ Learning Rate: 0.00041
# Epoch 335/500 │ Loss: +0.6886 │ Free En. Mean: 0.7028 │ Free En. Var: 1.7638 │ Learning Rate: 0.00041
# Epoch 336/500 │ Loss: +0.6834 │ Free En. Mean: 0.6584 │ Free En. Var: 1.8571 │ Learning Rate: 0.00041
# Epoch 337/500 │ Loss: +0.7026 │ Free En. Mean: 0.7024 │ Free En. Var: 1.8142 │ Learning Rate: 0.00041
# Epoch 338/500 │ Loss: +0.6817 │ Free En. Mean: 0.8100 │ Free En. Var: 1.9748 │ Learning Rate: 0.00041
# Epoch 339/500 │ Loss: +0.6829 │ Free En. Mean: 0.6780 │ Free En. Var: 1.9066 │ Learning Rate: 0.00041
# Epoch 340/500 │ Loss: +0.6850 │ Free En. Mean: 0.7279 │ Free En. Var: 1.9454 │ Learning Rate: 0.00040
# Epoch 341/500 │ Loss: +0.6843 │ Free En. Mean: 0.6780 │ Free En. Var: 1.8649 │ Learning Rate: 0.00040
# Epoch 342/500 │ Loss: +0.6779 │ Free En. Mean: 0.7536 │ Free En. Var: 1.8886 │ Learning Rate: 0.00040
# Epoch 343/500 │ Loss: +0.6895 │ Free En. Mean: 0.7394 │ Free En. Var: 1.8356 │ Learning Rate: 0.00040
# Epoch 344/500 │ Loss: +0.7006 │ Free En. Mean: 0.7900 │ Free En. Var: 1.8620 │ Learning Rate: 0.00040
# Epoch 345/500 │ Loss: +0.6830 │ Free En. Mean: 0.6949 │ Free En. Var: 1.9298 │ Learning Rate: 0.00040
# Epoch 346/500 │ Loss: +0.6930 │ Free En. Mean: 0.7452 │ Free En. Var: 1.8606 │ Learning Rate: 0.00039
# Epoch 347/500 │ Loss: +0.6792 │ Free En. Mean: 0.7204 │ Free En. Var: 1.8300 │ Learning Rate: 0.00039
# Epoch 348/500 │ Loss: +0.7069 │ Free En. Mean: 0.7257 │ Free En. Var: 1.8583 │ Learning Rate: 0.00039
# Epoch 349/500 │ Loss: +0.6880 │ Free En. Mean: 0.6905 │ Free En. Var: 1.8357 │ Learning Rate: 0.00039
# Epoch 350/500 │ Loss: +0.6876 │ Free En. Mean: 0.7671 │ Free En. Var: 1.8705 │ Learning Rate: 0.00039
# Epoch 351/500 │ Loss: +0.6863 │ Free En. Mean: 0.6761 │ Free En. Var: 1.8471 │ Learning Rate: 0.00039
# Epoch 352/500 │ Loss: +0.6777 │ Free En. Mean: 0.7200 │ Free En. Var: 1.8692 │ Learning Rate: 0.00039
# Epoch 353/500 │ Loss: +0.6893 │ Free En. Mean: 0.6980 │ Free En. Var: 1.8225 │ Learning Rate: 0.00038
# Epoch 354/500 │ Loss: +0.6847 │ Free En. Mean: 0.7521 │ Free En. Var: 1.9194 │ Learning Rate: 0.00038
# Epoch 355/500 │ Loss: +0.6916 │ Free En. Mean: 0.6920 │ Free En. Var: 1.8028 │ Learning Rate: 0.00038
# Epoch 356/500 │ Loss: +0.6861 │ Free En. Mean: 0.6890 │ Free En. Var: 1.8103 │ Learning Rate: 0.00038
# Epoch 357/500 │ Loss: +0.6939 │ Free En. Mean: 0.7178 │ Free En. Var: 1.9394 │ Learning Rate: 0.00038
# Epoch 358/500 │ Loss: +0.6886 │ Free En. Mean: 0.7171 │ Free En. Var: 1.8615 │ Learning Rate: 0.00038
# Epoch 359/500 │ Loss: +0.6753 │ Free En. Mean: 0.6379 │ Free En. Var: 1.7631 │ Learning Rate: 0.00038
# Epoch 360/500 │ Loss: +0.6874 │ Free En. Mean: 0.6128 │ Free En. Var: 1.8853 │ Learning Rate: 0.00037
# Epoch 361/500 │ Loss: +0.6965 │ Free En. Mean: 0.6847 │ Free En. Var: 1.8376 │ Learning Rate: 0.00037
# Epoch 362/500 │ Loss: +0.6866 │ Free En. Mean: 0.7516 │ Free En. Var: 1.9548 │ Learning Rate: 0.00037
# Epoch 363/500 │ Loss: +0.6814 │ Free En. Mean: 0.6530 │ Free En. Var: 1.8388 │ Learning Rate: 0.00037
# Epoch 364/500 │ Loss: +0.6854 │ Free En. Mean: 0.6096 │ Free En. Var: 1.8411 │ Learning Rate: 0.00037
# Epoch 365/500 │ Loss: +0.6897 │ Free En. Mean: 0.7228 │ Free En. Var: 1.8745 │ Learning Rate: 0.00037
# Epoch 366/500 │ Loss: +0.6838 │ Free En. Mean: 0.6656 │ Free En. Var: 1.8375 │ Learning Rate: 0.00037
# Epoch 367/500 │ Loss: +0.6958 │ Free En. Mean: 0.6671 │ Free En. Var: 1.7645 │ Learning Rate: 0.00036
# Epoch 368/500 │ Loss: +0.6829 │ Free En. Mean: 0.6797 │ Free En. Var: 1.8746 │ Learning Rate: 0.00036
# Epoch 369/500 │ Loss: +0.6854 │ Free En. Mean: 0.7127 │ Free En. Var: 1.9001 │ Learning Rate: 0.00036
# Epoch 370/500 │ Loss: +0.6745 │ Free En. Mean: 0.6559 │ Free En. Var: 1.7713 │ Learning Rate: 0.00036
# Epoch 371/500 │ Loss: +0.6869 │ Free En. Mean: 0.6888 │ Free En. Var: 1.9199 │ Learning Rate: 0.00036
# Epoch 372/500 │ Loss: +0.6886 │ Free En. Mean: 0.6960 │ Free En. Var: 1.9076 │ Learning Rate: 0.00036
# Epoch 373/500 │ Loss: +0.6741 │ Free En. Mean: 0.6148 │ Free En. Var: 1.7608 │ Learning Rate: 0.00036
# Epoch 374/500 │ Loss: +0.6884 │ Free En. Mean: 0.6292 │ Free En. Var: 1.8285 │ Learning Rate: 0.00035
# Epoch 375/500 │ Loss: +0.6781 │ Free En. Mean: 0.6532 │ Free En. Var: 1.9261 │ Learning Rate: 0.00035
# Epoch 376/500 │ Loss: +0.6860 │ Free En. Mean: 0.7186 │ Free En. Var: 1.7754 │ Learning Rate: 0.00035
# Epoch 377/500 │ Loss: +0.6854 │ Free En. Mean: 0.6623 │ Free En. Var: 1.7771 │ Learning Rate: 0.00035
# Epoch 378/500 │ Loss: +0.6912 │ Free En. Mean: 0.7022 │ Free En. Var: 1.8486 │ Learning Rate: 0.00035
# Epoch 379/500 │ Loss: +0.6891 │ Free En. Mean: 0.6769 │ Free En. Var: 1.8411 │ Learning Rate: 0.00035
# Epoch 380/500 │ Loss: +0.6746 │ Free En. Mean: 0.6777 │ Free En. Var: 1.8890 │ Learning Rate: 0.00035
# Epoch 381/500 │ Loss: +0.6965 │ Free En. Mean: 0.6831 │ Free En. Var: 1.7962 │ Learning Rate: 0.00035
# Epoch 382/500 │ Loss: +0.6936 │ Free En. Mean: 0.7375 │ Free En. Var: 1.8801 │ Learning Rate: 0.00034
# Epoch 383/500 │ Loss: +0.6806 │ Free En. Mean: 0.6612 │ Free En. Var: 1.7515 │ Learning Rate: 0.00034
# Epoch 384/500 │ Loss: +0.6839 │ Free En. Mean: 0.7054 │ Free En. Var: 1.8646 │ Learning Rate: 0.00034
# Epoch 385/500 │ Loss: +0.6805 │ Free En. Mean: 0.6806 │ Free En. Var: 1.8193 │ Learning Rate: 0.00034
# Epoch 386/500 │ Loss: +0.6903 │ Free En. Mean: 0.7923 │ Free En. Var: 1.9120 │ Learning Rate: 0.00034
# Epoch 387/500 │ Loss: +0.6937 │ Free En. Mean: 0.7675 │ Free En. Var: 1.8847 │ Learning Rate: 0.00034
# Epoch 388/500 │ Loss: +0.6798 │ Free En. Mean: 0.7350 │ Free En. Var: 1.8628 │ Learning Rate: 0.00034
# Epoch 389/500 │ Loss: +0.6844 │ Free En. Mean: 0.6024 │ Free En. Var: 1.7184 │ Learning Rate: 0.00033
# Epoch 390/500 │ Loss: +0.6789 │ Free En. Mean: 0.6881 │ Free En. Var: 1.8032 │ Learning Rate: 0.00033
# Epoch 391/500 │ Loss: +0.6964 │ Free En. Mean: 0.7612 │ Free En. Var: 1.9480 │ Learning Rate: 0.00033
# Epoch 392/500 │ Loss: +0.6796 │ Free En. Mean: 0.6807 │ Free En. Var: 1.8462 │ Learning Rate: 0.00033
# Epoch 393/500 │ Loss: +0.6858 │ Free En. Mean: 0.5842 │ Free En. Var: 1.7565 │ Learning Rate: 0.00033
# Epoch 394/500 │ Loss: +0.6715 │ Free En. Mean: 0.6611 │ Free En. Var: 1.7855 │ Learning Rate: 0.00033
# Epoch 395/500 │ Loss: +0.6785 │ Free En. Mean: 0.6799 │ Free En. Var: 1.7924 │ Learning Rate: 0.00033
# Epoch 396/500 │ Loss: +0.6848 │ Free En. Mean: 0.7901 │ Free En. Var: 1.9369 │ Learning Rate: 0.00033
# Epoch 397/500 │ Loss: +0.6779 │ Free En. Mean: 0.7242 │ Free En. Var: 1.8954 │ Learning Rate: 0.00032
# Epoch 398/500 │ Loss: +0.6759 │ Free En. Mean: 0.6169 │ Free En. Var: 1.8470 │ Learning Rate: 0.00032
# Epoch 399/500 │ Loss: +0.6790 │ Free En. Mean: 0.6897 │ Free En. Var: 1.8645 │ Learning Rate: 0.00032
# Epoch 400/500 │ Loss: +0.6692 │ Free En. Mean: 0.6266 │ Free En. Var: 1.7433 │ Learning Rate: 0.00032
# Epoch 401/500 │ Loss: +0.6794 │ Free En. Mean: 0.6604 │ Free En. Var: 1.7626 │ Learning Rate: 0.00032
# Epoch 402/500 │ Loss: +0.6811 │ Free En. Mean: 0.6864 │ Free En. Var: 1.7612 │ Learning Rate: 0.00032
# Epoch 403/500 │ Loss: +0.6824 │ Free En. Mean: 0.6529 │ Free En. Var: 1.8371 │ Learning Rate: 0.00032
# Epoch 404/500 │ Loss: +0.6896 │ Free En. Mean: 0.7120 │ Free En. Var: 1.7544 │ Learning Rate: 0.00032
# Epoch 405/500 │ Loss: +0.6720 │ Free En. Mean: 0.6084 │ Free En. Var: 1.7880 │ Learning Rate: 0.00031
# Epoch 406/500 │ Loss: +0.6839 │ Free En. Mean: 0.6434 │ Free En. Var: 1.7980 │ Learning Rate: 0.00031
# Epoch 407/500 │ Loss: +0.6798 │ Free En. Mean: 0.6653 │ Free En. Var: 1.7460 │ Learning Rate: 0.00031
# Epoch 408/500 │ Loss: +0.6828 │ Free En. Mean: 0.6190 │ Free En. Var: 1.8282 │ Learning Rate: 0.00031
# Epoch 409/500 │ Loss: +0.6721 │ Free En. Mean: 0.7788 │ Free En. Var: 1.9335 │ Learning Rate: 0.00031
# Epoch 410/500 │ Loss: +0.6933 │ Free En. Mean: 0.6384 │ Free En. Var: 1.7785 │ Learning Rate: 0.00031
# Epoch 411/500 │ Loss: +0.6797 │ Free En. Mean: 0.6393 │ Free En. Var: 1.7802 │ Learning Rate: 0.00031
# Epoch 412/500 │ Loss: +0.6828 │ Free En. Mean: 0.6161 │ Free En. Var: 1.7814 │ Learning Rate: 0.00031
# Epoch 413/500 │ Loss: +0.6800 │ Free En. Mean: 0.6403 │ Free En. Var: 1.7725 │ Learning Rate: 0.00030
# Epoch 414/500 │ Loss: +0.6817 │ Free En. Mean: 0.7870 │ Free En. Var: 1.9085 │ Learning Rate: 0.00030
# Epoch 415/500 │ Loss: +0.6863 │ Free En. Mean: 0.6678 │ Free En. Var: 1.8797 │ Learning Rate: 0.00030
# Epoch 416/500 │ Loss: +0.6841 │ Free En. Mean: 0.6649 │ Free En. Var: 1.7851 │ Learning Rate: 0.00030
# Epoch 417/500 │ Loss: +0.6713 │ Free En. Mean: 0.6214 │ Free En. Var: 1.8439 │ Learning Rate: 0.00030
# Epoch 418/500 │ Loss: +0.6893 │ Free En. Mean: 0.7568 │ Free En. Var: 1.9379 │ Learning Rate: 0.00030
# Epoch 419/500 │ Loss: +0.6831 │ Free En. Mean: 0.6157 │ Free En. Var: 1.7752 │ Learning Rate: 0.00030
# Epoch 420/500 │ Loss: +0.6784 │ Free En. Mean: 0.7171 │ Free En. Var: 1.9127 │ Learning Rate: 0.00030
# Epoch 421/500 │ Loss: +0.6799 │ Free En. Mean: 0.6877 │ Free En. Var: 1.8745 │ Learning Rate: 0.00030
# Epoch 422/500 │ Loss: +0.6691 │ Free En. Mean: 0.6126 │ Free En. Var: 1.8657 │ Learning Rate: 0.00029
# Epoch 423/500 │ Loss: +0.6780 │ Free En. Mean: 0.6829 │ Free En. Var: 1.8117 │ Learning Rate: 0.00029
# Epoch 424/500 │ Loss: +0.6745 │ Free En. Mean: 0.6641 │ Free En. Var: 1.7661 │ Learning Rate: 0.00029
# Epoch 425/500 │ Loss: +0.6757 │ Free En. Mean: 0.6289 │ Free En. Var: 1.7761 │ Learning Rate: 0.00029
# Epoch 426/500 │ Loss: +0.6779 │ Free En. Mean: 0.6868 │ Free En. Var: 1.8749 │ Learning Rate: 0.00029
# Epoch 427/500 │ Loss: +0.6890 │ Free En. Mean: 0.6612 │ Free En. Var: 1.8699 │ Learning Rate: 0.00029
# Epoch 428/500 │ Loss: +0.6757 │ Free En. Mean: 0.6728 │ Free En. Var: 1.8477 │ Learning Rate: 0.00029
# Epoch 429/500 │ Loss: +0.6848 │ Free En. Mean: 0.6929 │ Free En. Var: 1.7898 │ Learning Rate: 0.00029
# Epoch 430/500 │ Loss: +0.6786 │ Free En. Mean: 0.7590 │ Free En. Var: 1.8707 │ Learning Rate: 0.00029
# Epoch 431/500 │ Loss: +0.6795 │ Free En. Mean: 0.6750 │ Free En. Var: 1.8573 │ Learning Rate: 0.00028
# Epoch 432/500 │ Loss: +0.6804 │ Free En. Mean: 0.7956 │ Free En. Var: 1.9795 │ Learning Rate: 0.00028
# Epoch 433/500 │ Loss: +0.6793 │ Free En. Mean: 0.6564 │ Free En. Var: 1.8557 │ Learning Rate: 0.00028
# Epoch 434/500 │ Loss: +0.6758 │ Free En. Mean: 0.6256 │ Free En. Var: 1.8684 │ Learning Rate: 0.00028
# Epoch 435/500 │ Loss: +0.6824 │ Free En. Mean: 0.6945 │ Free En. Var: 1.8650 │ Learning Rate: 0.00028
# Epoch 436/500 │ Loss: +0.6736 │ Free En. Mean: 0.5491 │ Free En. Var: 1.7778 │ Learning Rate: 0.00028
# Epoch 437/500 │ Loss: +0.6765 │ Free En. Mean: 0.7131 │ Free En. Var: 1.8638 │ Learning Rate: 0.00028
# Epoch 438/500 │ Loss: +0.6750 │ Free En. Mean: 0.6845 │ Free En. Var: 1.7653 │ Learning Rate: 0.00028
# Epoch 439/500 │ Loss: +0.6817 │ Free En. Mean: 0.6634 │ Free En. Var: 1.8604 │ Learning Rate: 0.00028
# Epoch 440/500 │ Loss: +0.6861 │ Free En. Mean: 0.6565 │ Free En. Var: 1.8181 │ Learning Rate: 0.00027
# Epoch 441/500 │ Loss: +0.6617 │ Free En. Mean: 0.6273 │ Free En. Var: 1.9027 │ Learning Rate: 0.00027
# Epoch 442/500 │ Loss: +0.6868 │ Free En. Mean: 0.7398 │ Free En. Var: 1.8911 │ Learning Rate: 0.00027
# Epoch 443/500 │ Loss: +0.6688 │ Free En. Mean: 0.6413 │ Free En. Var: 1.8216 │ Learning Rate: 0.00027
# Epoch 444/500 │ Loss: +0.6881 │ Free En. Mean: 0.7419 │ Free En. Var: 1.9066 │ Learning Rate: 0.00027
# Epoch 445/500 │ Loss: +0.6703 │ Free En. Mean: 0.6333 │ Free En. Var: 1.8105 │ Learning Rate: 0.00027
# Epoch 446/500 │ Loss: +0.6868 │ Free En. Mean: 0.6922 │ Free En. Var: 1.8438 │ Learning Rate: 0.00027
# Epoch 447/500 │ Loss: +0.6797 │ Free En. Mean: 0.6875 │ Free En. Var: 2.0135 │ Learning Rate: 0.00027
# Epoch 448/500 │ Loss: +0.6715 │ Free En. Mean: 0.6772 │ Free En. Var: 1.8243 │ Learning Rate: 0.00027
# Epoch 449/500 │ Loss: +0.6709 │ Free En. Mean: 0.7096 │ Free En. Var: 1.8388 │ Learning Rate: 0.00027
# Epoch 450/500 │ Loss: +0.6730 │ Free En. Mean: 0.6252 │ Free En. Var: 1.7958 │ Learning Rate: 0.00026
# Epoch 451/500 │ Loss: +0.6797 │ Free En. Mean: 0.6800 │ Free En. Var: 1.8617 │ Learning Rate: 0.00026
# Epoch 452/500 │ Loss: +0.6805 │ Free En. Mean: 0.6967 │ Free En. Var: 1.8625 │ Learning Rate: 0.00026
# Epoch 453/500 │ Loss: +0.6833 │ Free En. Mean: 0.6998 │ Free En. Var: 1.8280 │ Learning Rate: 0.00026
# Epoch 454/500 │ Loss: +0.6732 │ Free En. Mean: 0.7062 │ Free En. Var: 1.8118 │ Learning Rate: 0.00026
# Epoch 455/500 │ Loss: +0.6845 │ Free En. Mean: 0.6446 │ Free En. Var: 1.8414 │ Learning Rate: 0.00026
# Epoch 456/500 │ Loss: +0.6699 │ Free En. Mean: 0.6942 │ Free En. Var: 1.8325 │ Learning Rate: 0.00026
# Epoch 457/500 │ Loss: +0.6832 │ Free En. Mean: 0.7140 │ Free En. Var: 1.8695 │ Learning Rate: 0.00026
# Epoch 458/500 │ Loss: +0.6783 │ Free En. Mean: 0.6308 │ Free En. Var: 1.8184 │ Learning Rate: 0.00026
# Epoch 459/500 │ Loss: +0.6785 │ Free En. Mean: 0.6606 │ Free En. Var: 1.9589 │ Learning Rate: 0.00026
# Epoch 460/500 │ Loss: +0.6758 │ Free En. Mean: 0.7142 │ Free En. Var: 1.8689 │ Learning Rate: 0.00025
# Epoch 461/500 │ Loss: +0.6729 │ Free En. Mean: 0.6201 │ Free En. Var: 1.7704 │ Learning Rate: 0.00025
# Epoch 462/500 │ Loss: +0.6814 │ Free En. Mean: 0.5821 │ Free En. Var: 1.7663 │ Learning Rate: 0.00025
# Epoch 463/500 │ Loss: +0.6789 │ Free En. Mean: 0.6936 │ Free En. Var: 1.8674 │ Learning Rate: 0.00025
# Epoch 464/500 │ Loss: +0.6775 │ Free En. Mean: 0.6157 │ Free En. Var: 1.9172 │ Learning Rate: 0.00025
# Epoch 465/500 │ Loss: +0.6764 │ Free En. Mean: 0.6455 │ Free En. Var: 1.8056 │ Learning Rate: 0.00025
# Epoch 466/500 │ Loss: +0.6873 │ Free En. Mean: 0.7332 │ Free En. Var: 1.8499 │ Learning Rate: 0.00025
# Epoch 467/500 │ Loss: +0.6805 │ Free En. Mean: 0.7197 │ Free En. Var: 1.8379 │ Learning Rate: 0.00025
# Epoch 468/500 │ Loss: +0.6758 │ Free En. Mean: 0.6036 │ Free En. Var: 1.8426 │ Learning Rate: 0.00025
# Epoch 469/500 │ Loss: +0.6737 │ Free En. Mean: 0.6544 │ Free En. Var: 1.8410 │ Learning Rate: 0.00025
# Epoch 470/500 │ Loss: +0.6817 │ Free En. Mean: 0.7093 │ Free En. Var: 1.8553 │ Learning Rate: 0.00024
# Epoch 471/500 │ Loss: +0.6710 │ Free En. Mean: 0.6769 │ Free En. Var: 1.8473 │ Learning Rate: 0.00024
# Epoch 472/500 │ Loss: +0.6848 │ Free En. Mean: 0.6700 │ Free En. Var: 1.7225 │ Learning Rate: 0.00024
# Epoch 473/500 │ Loss: +0.6799 │ Free En. Mean: 0.7025 │ Free En. Var: 1.8539 │ Learning Rate: 0.00024
# Epoch 474/500 │ Loss: +0.6726 │ Free En. Mean: 0.6306 │ Free En. Var: 1.7824 │ Learning Rate: 0.00024
# Epoch 475/500 │ Loss: +0.6807 │ Free En. Mean: 0.6880 │ Free En. Var: 1.8545 │ Learning Rate: 0.00024
# Epoch 476/500 │ Loss: +0.6722 │ Free En. Mean: 0.6699 │ Free En. Var: 1.8690 │ Learning Rate: 0.00024
# Epoch 477/500 │ Loss: +0.6691 │ Free En. Mean: 0.5702 │ Free En. Var: 1.7856 │ Learning Rate: 0.00024
# Epoch 478/500 │ Loss: +0.6845 │ Free En. Mean: 0.6374 │ Free En. Var: 1.8137 │ Learning Rate: 0.00024
# Epoch 479/500 │ Loss: +0.6762 │ Free En. Mean: 0.8155 │ Free En. Var: 1.8931 │ Learning Rate: 0.00024
# Epoch 480/500 │ Loss: +0.6747 │ Free En. Mean: 0.7065 │ Free En. Var: 1.7867 │ Learning Rate: 0.00024
# Epoch 481/500 │ Loss: +0.6798 │ Free En. Mean: 0.6766 │ Free En. Var: 1.8188 │ Learning Rate: 0.00024
# Epoch 482/500 │ Loss: +0.6713 │ Free En. Mean: 0.6240 │ Free En. Var: 1.8454 │ Learning Rate: 0.00023
# Epoch 483/500 │ Loss: +0.6706 │ Free En. Mean: 0.5290 │ Free En. Var: 1.7456 │ Learning Rate: 0.00023
# Epoch 484/500 │ Loss: +0.6692 │ Free En. Mean: 0.6339 │ Free En. Var: 1.8926 │ Learning Rate: 0.00023
# Epoch 485/500 │ Loss: +0.6760 │ Free En. Mean: 0.7430 │ Free En. Var: 1.9186 │ Learning Rate: 0.00023
# Epoch 486/500 │ Loss: +0.6654 │ Free En. Mean: 0.7726 │ Free En. Var: 1.9223 │ Learning Rate: 0.00023
# Epoch 487/500 │ Loss: +0.6676 │ Free En. Mean: 0.6033 │ Free En. Var: 1.7968 │ Learning Rate: 0.00023
# Epoch 488/500 │ Loss: +0.6815 │ Free En. Mean: 0.6245 │ Free En. Var: 1.8343 │ Learning Rate: 0.00023
# Epoch 489/500 │ Loss: +0.6718 │ Free En. Mean: 0.7048 │ Free En. Var: 1.9025 │ Learning Rate: 0.00023
# Epoch 490/500 │ Loss: +0.6797 │ Free En. Mean: 0.7178 │ Free En. Var: 1.8954 │ Learning Rate: 0.00023
# Epoch 491/500 │ Loss: +0.6780 │ Free En. Mean: 0.6524 │ Free En. Var: 1.8627 │ Learning Rate: 0.00023
# Epoch 492/500 │ Loss: +0.6727 │ Free En. Mean: 0.7366 │ Free En. Var: 1.8274 │ Learning Rate: 0.00023
# Epoch 493/500 │ Loss: +0.6770 │ Free En. Mean: 0.6199 │ Free En. Var: 1.7695 │ Learning Rate: 0.00023
# Epoch 494/500 │ Loss: +0.6659 │ Free En. Mean: 0.7144 │ Free En. Var: 1.9571 │ Learning Rate: 0.00022
# Epoch 495/500 │ Loss: +0.6822 │ Free En. Mean: 0.6212 │ Free En. Var: 1.8395 │ Learning Rate: 0.00022
# Epoch 496/500 │ Loss: +0.6702 │ Free En. Mean: 0.6932 │ Free En. Var: 1.7324 │ Learning Rate: 0.00022
# Epoch 497/500 │ Loss: +0.6798 │ Free En. Mean: 0.6644 │ Free En. Var: 1.8768 │ Learning Rate: 0.00022
# Epoch 498/500 │ Loss: +0.6751 │ Free En. Mean: 0.6195 │ Free En. Var: 1.6784 │ Learning Rate: 0.00022
# Epoch 499/500 │ Loss: +0.6887 │ Free En. Mean: 0.6678 │ Free En. Var: 1.8513 │ Learning Rate: 0.00022
# Epoch 500/500 │ Loss: +0.6693 │ Free En. Mean: 0.5618 │ Free En. Var: 1.7911 │ Learning Rate: 0.00022

# %%
epochs = list(metrics.keys())

loss_vals = [metrics[e]['loss'] for e in epochs]
free_model_mean_vals = [metrics[e]['free_energy_mean'] for e in epochs]
free_model_var_vals = [metrics[e]['free_energy_var'] for e in epochs]
lr_vals = [metrics[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots(figsize=(11, 4))

ax1.plot(epochs, lr_vals, label="Learning Rate", color="tab:red")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Learning Rate", color="tab:red")
ax1.tick_params(axis="y", labelcolor="tab:red")

ax2 = ax1.twinx()
ax2.spines["right"].set_position(("axes", 1.00))
ax2.plot(epochs, loss_vals, label="Amplitude CD Loss", color="tab:blue")
ax2.set_ylabel("Phase Loss", color="tab:blue")
ax2.tick_params(axis="y", labelcolor="tab:blue")

ax3 = ax1.twinx()
ax3.spines["right"].set_position(("axes", 1.1))
ax3.plot(epochs, free_model_var_vals, label="Free Energy Model Var", color="tab:green")
ax3.set_ylabel("Free Energy Model Var", color="tab:green")
ax3.tick_params(axis="y", labelcolor="tab:green")

ax4 = ax1.twinx()
ax4.spines["right"].set_position(("axes", 1.2))
ax4.plot(epochs, free_model_mean_vals, label="Free Energy Model Mean", color="tab:orange")
ax4.set_ylabel("Free Energy Model Mean", color="tab:orange")
ax4.tick_params(axis="y", labelcolor="tab:orange")

plt.tight_layout()
plt.show()

# %%
# a quick test is to test whether the conditioner can condition on the Z basis

T_high = 2.0
T_low = 0.01
sampling_steps = 5_000
sigmoid_schedule_fn = get_sigmoid_curve(high=T_high*2, low=T_low, steps=sampling_steps, falloff=0.0013, center_step=0)
sigmoid_schedule = jnp.array([sigmoid_schedule_fn(i) for i in range(sampling_steps)], dtype=jnp.float32)

# construct a batch of basis bits in Z direction
num_samples = 1_000
basis_bits = jnp.ones((num_samples, num_visible, 2), dtype=jnp.float32)

all_vars = { "params": state.params, "rbm": rbm_vars }

key_sample = jax.random.PRNGKey(42)
samples, key_sample = model.apply(all_vars, basis_bits, sigmoid_schedule, key_sample, method=ConditionalRBM.generate)

sampled_freq = samples.mean(axis=0)
sampled_freq
# Out:
# Array([0.351     , 0.33600003, 0.312     , 0.33800003, 0.35300002,
#        0.48900002, 0.33      , 0.291     ], dtype=float32)
