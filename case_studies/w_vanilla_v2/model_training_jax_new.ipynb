# %%
import os
import numpy as np

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import flax.linen as nn
import optax
from flax.training import train_state

import functools

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches

data_dir = "./data"
device = jax.devices('cpu')[0]

print(f"Data resides in        : {data_dir}")
print(f"Training model on      : {str(device)}")
# Out:
# Data resides in        : ./data
# Training model on      : TFRT_CPU_0

# %%
def z_meas_to_binary(line: str) -> np.ndarray:
    binary_array = [c == "z" for c in line.strip()]
    return np.array(binary_array, dtype=np.float32).reshape(-1)

data_file = os.path.join(data_dir, "w_vanilla_20_50000.txt")

with open(data_file) as f:
    data = np.stack([z_meas_to_binary(l) for l in f])

print(f"Loaded {len(data)} samples, each of length {data.shape[1]} into numpy array of type {data.dtype}.")

num_train_samples = 10_000
rng = PRNGKey(0)

data_subset = jax.random.choice(rng, data, (num_train_samples,), replace=False)

print(f"Subset shape: {data_subset.shape}")
# Out:
# Loaded 50000 samples, each of length 20 into numpy array of type float32.
# Subset shape: (10000, 20)

# %%
cols = 10
rows = data_subset.shape[0] // cols
panel_width = data_subset.shape[1]
spacer = 4
left_padding = 10
right_padding = 10

canvas_width = (left_padding + cols * panel_width + (cols - 1) * spacer + right_padding)

bright_red = "darkred"
dark_red = "#ffcccc"
flip_red_cmap = ListedColormap([bright_red, dark_red])
flip_red_cmap.set_bad("white")

canvas = np.full((rows, canvas_width), np.nan, dtype=np.float32)
for i in range(cols):
    start_x = left_padding + i * (panel_width + spacer)
    block = data_subset[i * rows:(i + 1) * rows, :]
    canvas[:, start_x:start_x + panel_width] = block

plt.figure(figsize=(12, 6))
img = plt.imshow(canvas, cmap=flip_red_cmap, interpolation='nearest', aspect='auto')
plt.axis('off')

dark_patch = mpatches.Patch(color=dark_red, label="1 (+Z)")
bright_patch = mpatches.Patch(color=bright_red, label="0 (−Z)")
plt.legend(
    handles=[dark_patch, bright_patch],
    loc="center right",
    bbox_to_anchor=(1.1, 0.5),
    frameon=False
)

plt.tight_layout()
plt.show()

# %%
# get rel frequency of up-spin on each site
rel_freq = data_subset.mean(0)
rel_freq
# Out:
# Array([0.0504, 0.0503, 0.0498, 0.0494, 0.0484, 0.0529, 0.0545, 0.0531,
#        0.0493, 0.0494, 0.0502, 0.0495, 0.0507, 0.0465, 0.0496, 0.0474,
#        0.0496, 0.0468, 0.0467, 0.0555], dtype=float32)

# %%
visible_units = 20

fig, ax = plt.subplots(figsize=(8,4))
sites = np.arange(1, visible_units+1)
ax.bar(sites, rel_freq, width=0.8, edgecolor='black', alpha=0.7)
ax.axhline(1/visible_units, color='red', linestyle='--', label=f'Expected = {1/visible_units:.3f}')

ax.set_xlabel('Spin‐site index')
ax.set_ylabel('Relative frequency of up‐spin')
ax.set_title('Training Data: Up‐Spin Occurrence per Site')
ax.set_xticks(sites)
ax.set_ylim(0, rel_freq.max()*1.2)

ax.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
class DataLoader:
    def __init__(self, dataset, batch_size=128, shuffle=True, drop_last=False):
        self.x         = dataset
        self.bs        = batch_size
        self.shuffle   = shuffle
        self.drop_last = drop_last

        n_samples = len(self.x)
        self.idx_slices = [
            (i, i + batch_size)
            for i in range(0, n_samples, batch_size)
            if not drop_last or i + batch_size <= n_samples
        ]

    def __iter__(self):
        order = np.arange(len(self.x))
        if self.shuffle:
            np.random.shuffle(order)
        for s, e in self.idx_slices:
            yield self.x[order[s:e]]

    def __len__(self):
        return len(self.idx_slices)

# %%
class RBM(nn.Module):
    n_visible: int
    n_hidden: int
    k: int = 1

    @nn.compact
    def __call__(self, data_batch: jnp.ndarray, v_persistent: jnp.ndarray, rng: PRNGKey) -> (jnp.ndarray, jnp.ndarray):
        # in flax, __call__ is the main computation to be differentiated.

        # initialize parameters in @nn.compact style:
        W = self.param("W", nn.initializers.normal(0.01), (self.n_visible, self.n_hidden))
        b = self.param("b", nn.initializers.zeros,        (self.n_visible,))
        c = self.param("c", nn.initializers.zeros,        (self.n_hidden,))
        params = {"W": W, "b": b, "c": c}

        # gibbs sampling only refines the fantasy particles, we are actually not interested in the gradients
        v_k, key = self._gibbs_sample(params, v_persistent, rng, k=self.k)
        v_k = jax.lax.stop_gradient(v_k)

        # we are interested in the gradients of the free energy w.r.t. the parameters
        free_energy_data  = self._free_energy(params, data_batch)
        free_energy_model = self._free_energy(params, v_k)

        pcd_loss = jnp.mean(free_energy_data) - jnp.mean(free_energy_model)
        # since this is a pcd loss function, we also return the updated fantasy particles. and we also pass through the key
        # since JAX’s tree utilities flatten nested tuples we need to wrap the auxiliary variables in a container
        aux_vars = {"v_persistent": v_k, "key": key}

        return pcd_loss, aux_vars

    @staticmethod
    def _free_energy(params, v):
        W, b, c = params["W"], params["b"], params["c"]

        visible_term = jnp.dot(v, b)
        hidden_term  = jnp.sum(jax.nn.softplus(v @ W + c), axis=-1)
        free_energy = -visible_term - hidden_term
        return free_energy

    @staticmethod
    def _gibbs_step(i, state, params, T=1.0):
        v, key = state
        W, b, c = params["W"], params["b"], params["c"]

        # splitting generates different random numbers for each step, one of them is passed on
        key, h_key, v_key = jax.random.split(key, 3)

        h_logits = (v @ W + c) / T
        h_probs = jax.nn.sigmoid(h_logits)
        h = jax.random.bernoulli(h_key, h_probs).astype(jnp.float32)

        v_logits = (h @ W.T + b) / T
        v_probs = jax.nn.sigmoid(v_logits)
        v = jax.random.bernoulli(v_key, v_probs).astype(jnp.float32)
        return v, key

    @staticmethod
    def _gibbs_sample(params, v_init, rng, k=1, T=1.0):
        # the fori_loop enables JIT compilation of loops. It basically unrolls the loop over the fixed length k.

        body_fun = lambda i, state: RBM._gibbs_step(i, state, params, T)
        v_final, key = jax.lax.fori_loop(0, k, body_fun, (v_init, rng))
        return v_final, key

    @staticmethod
    def _annealing_step(i, state, params, T_schedule):
        v, rng = state
        T = T_schedule[i]
        # Perform one Gibbs step using the current temperature T.
        # Note: _gibbs_sample already handles k=1 and T
        v_next, rng_next = RBM._gibbs_sample(params, v, rng, k=1, T=T)
        return (v_next, rng_next)

    # the nowrap attribute basically tells JAX to not do the magic wrapping, which injects the params argument
    @nn.nowrap
    def generate(self, params: dict, n_samples: int, T_schedule: jnp.ndarray, rng: PRNGKey) -> jnp.ndarray:

        # get the initial state and perform initial key splitting
        rng, init_key = jax.random.split(rng)
        v = jax.random.bernoulli(init_key, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)
        init_state = (v, rng)

        body_fun = lambda i, state: RBM._gibbs_step(i, state, params, T_schedule[i])

        # the fori_loop is still required, since this function will also be JIT-compiled
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), body_fun, init_state)
        return v_final

# %%
class RBMTrainState(train_state.TrainState):
    """
    A value object bundling parameters and optimizer state for training.
    It has a few pre-defined fields to be used in the training loop.
    Since it is immutable, the training function needs to return a new instance after each update step.
    """
    pass


@functools.partial(jax.jit)
def train_step(state: RBMTrainState, data_batch: jnp.ndarray, v_persistent: jnp.ndarray, key: PRNGKey):

    # only the 'params' argument remains a variable to be differentiated
    pcd_loss_fn = lambda params: state.apply_fn({'params': params}, data_batch, v_persistent, key)

    # since our pc_loss_fn also returns the updated fantasy particles, we need to use has_aux=True
    value_and_grad_fn = jax.value_and_grad(pcd_loss_fn, has_aux=True)
    (pcd_loss, aux_vars), pdc_loss_grads = value_and_grad_fn(state.params)

    # apply the gradients to the state, this actually updates the optimizer state
    new_state = state.apply_gradients(grads=pdc_loss_grads)
    v_persistent = aux_vars["v_persistent"]
    key = aux_vars["key"]

    return new_state, pcd_loss, v_persistent, key


def train_rbm(state: RBMTrainState, train_loader, num_epochs: int, rng: PRNGKey, pcd_reset: int = 5, scheduler=None):
    metrics = {}

    for epoch in range(num_epochs):
        total_loss = 0.0
        batch_count = 0

        for batch_idx, data in enumerate(train_loader):

            if batch_idx % pcd_reset == 0:
                rng, subkey = jax.random.split(rng)   # rng is overwritten with new one to generate new sample
                v_persistent = jax.random.bernoulli(subkey, p=0.5, shape=data.shape).astype(jnp.float32)

            state, loss, v_persistent, rng = train_step(state, data, v_persistent, rng)
            total_loss += loss
            batch_count += 1

        avg_loss = total_loss / len(train_loader)
        metrics[epoch] = {"free_energy_loss": float(avg_loss)}
        print(f"Epoch [{epoch+1}/{num_epochs}] - Free Energy Loss: {avg_loss:.4f}")

    return state, metrics, rng

# %%
# ACTUAL TRAINING
batch_size    = 50
visible_units = 20
hidden_units  = 20
k_steps       = 1
lr            = 1e-2
num_epochs    = 1000
pcd_reset     = 50


rng = PRNGKey(42)

# instantiate the optimizer and the RBM
train_loader = DataLoader(data_subset, batch_size=batch_size, shuffle=True)

optimizer = optax.adam(learning_rate=lr)
rbm = RBM(n_visible=visible_units, n_hidden=hidden_units, k=k_steps)

# initialize RBM parameters and create the training state
dummy_batch = data_subset[:batch_size]
rng, subkey = jax.random.split(rng)
v_persistent = jax.random.bernoulli(subkey, p=0.5, shape=dummy_batch.shape).astype(jnp.float32)
params = rbm.init(rng, dummy_batch, v_persistent, rng)['params']

state = RBMTrainState.create(apply_fn=rbm.apply, params=params, tx=optimizer)

state, metrics, rng = train_rbm(state, train_loader, num_epochs, rng, pcd_reset)
# Out:
# Epoch [1/1000] - Free Energy Loss: -0.7578
# Epoch [2/1000] - Free Energy Loss: -0.1502
# Epoch [3/1000] - Free Energy Loss: -0.0716
# Epoch [4/1000] - Free Energy Loss: -0.0302
# Epoch [5/1000] - Free Energy Loss: -0.0164
# Epoch [6/1000] - Free Energy Loss: 0.0084
# Epoch [7/1000] - Free Energy Loss: 0.0190
# Epoch [8/1000] - Free Energy Loss: 0.0206
# Epoch [9/1000] - Free Energy Loss: 0.0421
# Epoch [10/1000] - Free Energy Loss: 0.0293
# Epoch [11/1000] - Free Energy Loss: 0.0424
# Epoch [12/1000] - Free Energy Loss: 0.0457
# Epoch [13/1000] - Free Energy Loss: 0.0433
# Epoch [14/1000] - Free Energy Loss: 0.0458
# Epoch [15/1000] - Free Energy Loss: 0.0508
# Epoch [16/1000] - Free Energy Loss: 0.0563
# Epoch [17/1000] - Free Energy Loss: 0.0464
# Epoch [18/1000] - Free Energy Loss: 0.0527
# Epoch [19/1000] - Free Energy Loss: 0.0496
# Epoch [20/1000] - Free Energy Loss: 0.0600
# Epoch [21/1000] - Free Energy Loss: 0.0564
# Epoch [22/1000] - Free Energy Loss: 0.0378
# Epoch [23/1000] - Free Energy Loss: 0.0510
# Epoch [24/1000] - Free Energy Loss: 0.0473
# Epoch [25/1000] - Free Energy Loss: 0.0374
# Epoch [26/1000] - Free Energy Loss: 0.0384
# Epoch [27/1000] - Free Energy Loss: 0.0388
# Epoch [28/1000] - Free Energy Loss: 0.0313
# Epoch [29/1000] - Free Energy Loss: 0.0533
# Epoch [30/1000] - Free Energy Loss: 0.0360
# Epoch [31/1000] - Free Energy Loss: 0.0280
# Epoch [32/1000] - Free Energy Loss: 0.0447
# Epoch [33/1000] - Free Energy Loss: 0.0328
# Epoch [34/1000] - Free Energy Loss: 0.0364
# Epoch [35/1000] - Free Energy Loss: 0.0185
# Epoch [36/1000] - Free Energy Loss: 0.0406
# Epoch [37/1000] - Free Energy Loss: 0.0317
# Epoch [38/1000] - Free Energy Loss: 0.0266
# Epoch [39/1000] - Free Energy Loss: 0.0315
# Epoch [40/1000] - Free Energy Loss: 0.0332
# Epoch [41/1000] - Free Energy Loss: 0.0311
# Epoch [42/1000] - Free Energy Loss: 0.0263
# Epoch [43/1000] - Free Energy Loss: 0.0357
# Epoch [44/1000] - Free Energy Loss: 0.0017
# Epoch [45/1000] - Free Energy Loss: 0.0411
# Epoch [46/1000] - Free Energy Loss: 0.0258
# Epoch [47/1000] - Free Energy Loss: 0.0344
# Epoch [48/1000] - Free Energy Loss: 0.0274
# Epoch [49/1000] - Free Energy Loss: 0.0204
# Epoch [50/1000] - Free Energy Loss: 0.0307
# Epoch [51/1000] - Free Energy Loss: 0.0348
# Epoch [52/1000] - Free Energy Loss: 0.0373
# Epoch [53/1000] - Free Energy Loss: 0.0072
# Epoch [54/1000] - Free Energy Loss: 0.0503
# Epoch [55/1000] - Free Energy Loss: 0.0288
# Epoch [56/1000] - Free Energy Loss: 0.0278
# Epoch [57/1000] - Free Energy Loss: 0.0310
# Epoch [58/1000] - Free Energy Loss: 0.0331
# Epoch [59/1000] - Free Energy Loss: 0.0146
# Epoch [60/1000] - Free Energy Loss: 0.0417
# Epoch [61/1000] - Free Energy Loss: 0.0252
# Epoch [62/1000] - Free Energy Loss: 0.0274
# Epoch [63/1000] - Free Energy Loss: 0.0299
# Epoch [64/1000] - Free Energy Loss: 0.0168
# Epoch [65/1000] - Free Energy Loss: 0.0284
# Epoch [66/1000] - Free Energy Loss: 0.0391
# Epoch [67/1000] - Free Energy Loss: 0.0204
# Epoch [68/1000] - Free Energy Loss: 0.0284
# Epoch [69/1000] - Free Energy Loss: 0.0335
# Epoch [70/1000] - Free Energy Loss: 0.0302
# Epoch [71/1000] - Free Energy Loss: 0.0293
# Epoch [72/1000] - Free Energy Loss: 0.0297
# Epoch [73/1000] - Free Energy Loss: 0.0281
# Epoch [74/1000] - Free Energy Loss: 0.0323
# Epoch [75/1000] - Free Energy Loss: 0.0205
# Epoch [76/1000] - Free Energy Loss: 0.0437
# Epoch [77/1000] - Free Energy Loss: 0.0185
# Epoch [78/1000] - Free Energy Loss: 0.0388
# Epoch [79/1000] - Free Energy Loss: 0.0351
# Epoch [80/1000] - Free Energy Loss: 0.0317
# Epoch [81/1000] - Free Energy Loss: 0.0174
# Epoch [82/1000] - Free Energy Loss: 0.0299
# Epoch [83/1000] - Free Energy Loss: 0.0117
# Epoch [84/1000] - Free Energy Loss: 0.0452
# Epoch [85/1000] - Free Energy Loss: 0.0367
# Epoch [86/1000] - Free Energy Loss: 0.0370
# Epoch [87/1000] - Free Energy Loss: 0.0174
# Epoch [88/1000] - Free Energy Loss: 0.0286
# Epoch [89/1000] - Free Energy Loss: 0.0260
# Epoch [90/1000] - Free Energy Loss: 0.0392
# Epoch [91/1000] - Free Energy Loss: 0.0341
# Epoch [92/1000] - Free Energy Loss: 0.0112
# Epoch [93/1000] - Free Energy Loss: 0.0425
# Epoch [94/1000] - Free Energy Loss: 0.0202
# Epoch [95/1000] - Free Energy Loss: 0.0441
# Epoch [96/1000] - Free Energy Loss: 0.0237
# Epoch [97/1000] - Free Energy Loss: 0.0387
# Epoch [98/1000] - Free Energy Loss: 0.0204
# Epoch [99/1000] - Free Energy Loss: 0.0285
# Epoch [100/1000] - Free Energy Loss: 0.0274
# Epoch [101/1000] - Free Energy Loss: 0.0318
# Epoch [102/1000] - Free Energy Loss: 0.0419
# Epoch [103/1000] - Free Energy Loss: 0.0172
# Epoch [104/1000] - Free Energy Loss: 0.0251
# Epoch [105/1000] - Free Energy Loss: 0.0339
# Epoch [106/1000] - Free Energy Loss: 0.0178
# Epoch [107/1000] - Free Energy Loss: 0.0482
# Epoch [108/1000] - Free Energy Loss: 0.0155
# Epoch [109/1000] - Free Energy Loss: 0.0257
# Epoch [110/1000] - Free Energy Loss: 0.0405
# Epoch [111/1000] - Free Energy Loss: 0.0402
# Epoch [112/1000] - Free Energy Loss: 0.0141
# Epoch [113/1000] - Free Energy Loss: 0.0343
# Epoch [114/1000] - Free Energy Loss: 0.0237
# Epoch [115/1000] - Free Energy Loss: 0.0366
# Epoch [116/1000] - Free Energy Loss: 0.0253
# Epoch [117/1000] - Free Energy Loss: 0.0341
# Epoch [118/1000] - Free Energy Loss: 0.0443
# Epoch [119/1000] - Free Energy Loss: 0.0006
# Epoch [120/1000] - Free Energy Loss: 0.0496
# Epoch [121/1000] - Free Energy Loss: 0.0401
# Epoch [122/1000] - Free Energy Loss: 0.0161
# Epoch [123/1000] - Free Energy Loss: 0.0418
# Epoch [124/1000] - Free Energy Loss: 0.0299
# Epoch [125/1000] - Free Energy Loss: 0.0221
# Epoch [126/1000] - Free Energy Loss: 0.0294
# Epoch [127/1000] - Free Energy Loss: 0.0419
# Epoch [128/1000] - Free Energy Loss: 0.0168
# Epoch [129/1000] - Free Energy Loss: 0.0316
# Epoch [130/1000] - Free Energy Loss: 0.0283
# Epoch [131/1000] - Free Energy Loss: 0.0362
# Epoch [132/1000] - Free Energy Loss: 0.0358
# Epoch [133/1000] - Free Energy Loss: 0.0204
# Epoch [134/1000] - Free Energy Loss: 0.0314
# Epoch [135/1000] - Free Energy Loss: 0.0377
# Epoch [136/1000] - Free Energy Loss: 0.0222
# Epoch [137/1000] - Free Energy Loss: 0.0093
# Epoch [138/1000] - Free Energy Loss: 0.0173
# Epoch [139/1000] - Free Energy Loss: 0.0522
# Epoch [140/1000] - Free Energy Loss: 0.0125
# Epoch [141/1000] - Free Energy Loss: 0.0267
# Epoch [142/1000] - Free Energy Loss: 0.0356
# Epoch [143/1000] - Free Energy Loss: 0.0458
# Epoch [144/1000] - Free Energy Loss: 0.0110
# Epoch [145/1000] - Free Energy Loss: 0.0428
# Epoch [146/1000] - Free Energy Loss: 0.0560
# Epoch [147/1000] - Free Energy Loss: 0.0190
# Epoch [148/1000] - Free Energy Loss: 0.0232
# Epoch [149/1000] - Free Energy Loss: 0.0240
# Epoch [150/1000] - Free Energy Loss: 0.0194
# Epoch [151/1000] - Free Energy Loss: 0.0580
# Epoch [152/1000] - Free Energy Loss: 0.0777
# Epoch [153/1000] - Free Energy Loss: 0.0654
# Epoch [154/1000] - Free Energy Loss: 0.0404
# Epoch [155/1000] - Free Energy Loss: 0.0546
# Epoch [156/1000] - Free Energy Loss: 0.0234
# Epoch [157/1000] - Free Energy Loss: 0.0570
# Epoch [158/1000] - Free Energy Loss: 0.0245
# Epoch [159/1000] - Free Energy Loss: 0.0242
# Epoch [160/1000] - Free Energy Loss: 0.0383
# Epoch [161/1000] - Free Energy Loss: 0.0351
# Epoch [162/1000] - Free Energy Loss: 0.0607
# Epoch [163/1000] - Free Energy Loss: 0.0577
# Epoch [164/1000] - Free Energy Loss: 0.0785
# Epoch [165/1000] - Free Energy Loss: 0.0267
# Epoch [166/1000] - Free Energy Loss: 0.0422
# Epoch [167/1000] - Free Energy Loss: 0.1630
# Epoch [168/1000] - Free Energy Loss: 0.0157
# Epoch [169/1000] - Free Energy Loss: 0.0266
# Epoch [170/1000] - Free Energy Loss: 0.0559
# Epoch [171/1000] - Free Energy Loss: 0.0437
# Epoch [172/1000] - Free Energy Loss: 0.0630
# Epoch [173/1000] - Free Energy Loss: 0.0588
# Epoch [174/1000] - Free Energy Loss: 0.0875
# Epoch [175/1000] - Free Energy Loss: 0.0855
# Epoch [176/1000] - Free Energy Loss: 0.1474
# Epoch [177/1000] - Free Energy Loss: 0.1485
# Epoch [178/1000] - Free Energy Loss: 0.1121
# Epoch [179/1000] - Free Energy Loss: 0.0904
# Epoch [180/1000] - Free Energy Loss: 0.1383
# Epoch [181/1000] - Free Energy Loss: 0.1368
# Epoch [182/1000] - Free Energy Loss: 0.0616
# Epoch [183/1000] - Free Energy Loss: 0.0900
# Epoch [184/1000] - Free Energy Loss: 0.0820
# Epoch [185/1000] - Free Energy Loss: 0.0608
# Epoch [186/1000] - Free Energy Loss: 0.0863
# Epoch [187/1000] - Free Energy Loss: 0.0317
# Epoch [188/1000] - Free Energy Loss: 0.0668
# Epoch [189/1000] - Free Energy Loss: 0.0469
# Epoch [190/1000] - Free Energy Loss: 0.0424
# Epoch [191/1000] - Free Energy Loss: 0.0224
# Epoch [192/1000] - Free Energy Loss: 0.0887
# Epoch [193/1000] - Free Energy Loss: -0.0002
# Epoch [194/1000] - Free Energy Loss: 0.0181
# Epoch [195/1000] - Free Energy Loss: 0.0370
# Epoch [196/1000] - Free Energy Loss: 0.0264
# Epoch [197/1000] - Free Energy Loss: 0.0399
# Epoch [198/1000] - Free Energy Loss: 0.0066
# Epoch [199/1000] - Free Energy Loss: 0.0956
# Epoch [200/1000] - Free Energy Loss: -0.0329
# Epoch [201/1000] - Free Energy Loss: 0.0639
# Epoch [202/1000] - Free Energy Loss: 0.0791
# Epoch [203/1000] - Free Energy Loss: -0.0174
# Epoch [204/1000] - Free Energy Loss: -0.0449
# Epoch [205/1000] - Free Energy Loss: 0.0032
# Epoch [206/1000] - Free Energy Loss: -0.0474
# Epoch [207/1000] - Free Energy Loss: 0.0296
# Epoch [208/1000] - Free Energy Loss: -0.1171
# Epoch [209/1000] - Free Energy Loss: -0.0273
# Epoch [210/1000] - Free Energy Loss: 0.0889
# Epoch [211/1000] - Free Energy Loss: 0.0375
# Epoch [212/1000] - Free Energy Loss: 0.0183
# Epoch [213/1000] - Free Energy Loss: -0.0265
# Epoch [214/1000] - Free Energy Loss: -0.0882
# Epoch [215/1000] - Free Energy Loss: 0.0705
# Epoch [216/1000] - Free Energy Loss: -0.0568
# Epoch [217/1000] - Free Energy Loss: 0.0519
# Epoch [218/1000] - Free Energy Loss: -0.0615
# Epoch [219/1000] - Free Energy Loss: -0.0560
# Epoch [220/1000] - Free Energy Loss: 0.0184
# Epoch [221/1000] - Free Energy Loss: -0.0316
# Epoch [222/1000] - Free Energy Loss: -0.0203
# Epoch [223/1000] - Free Energy Loss: -0.0295
# Epoch [224/1000] - Free Energy Loss: -0.0718
# Epoch [225/1000] - Free Energy Loss: -0.0044
# Epoch [226/1000] - Free Energy Loss: -0.0513
# Epoch [227/1000] - Free Energy Loss: -0.0587
# Epoch [228/1000] - Free Energy Loss: -0.0323
# Epoch [229/1000] - Free Energy Loss: -0.0543
# Epoch [230/1000] - Free Energy Loss: 0.0493
# Epoch [231/1000] - Free Energy Loss: -0.0874
# Epoch [232/1000] - Free Energy Loss: -0.0313
# Epoch [233/1000] - Free Energy Loss: -0.0732
# Epoch [234/1000] - Free Energy Loss: -0.0085
# Epoch [235/1000] - Free Energy Loss: -0.1673
# Epoch [236/1000] - Free Energy Loss: -0.0532
# Epoch [237/1000] - Free Energy Loss: -0.0408
# Epoch [238/1000] - Free Energy Loss: -0.0539
# Epoch [239/1000] - Free Energy Loss: -0.1373
# Epoch [240/1000] - Free Energy Loss: -0.1256
# Epoch [241/1000] - Free Energy Loss: -0.2152
# Epoch [242/1000] - Free Energy Loss: -0.2375
# Epoch [243/1000] - Free Energy Loss: -0.0536
# Epoch [244/1000] - Free Energy Loss: -0.1914
# Epoch [245/1000] - Free Energy Loss: -0.1999
# Epoch [246/1000] - Free Energy Loss: -0.2075
# Epoch [247/1000] - Free Energy Loss: -0.1234
# Epoch [248/1000] - Free Energy Loss: -0.2012
# Epoch [249/1000] - Free Energy Loss: -0.0733
# Epoch [250/1000] - Free Energy Loss: -0.0866
# Epoch [251/1000] - Free Energy Loss: -0.0707
# Epoch [252/1000] - Free Energy Loss: -0.0974
# Epoch [253/1000] - Free Energy Loss: -0.0719
# Epoch [254/1000] - Free Energy Loss: -0.2639
# Epoch [255/1000] - Free Energy Loss: -0.0606
# Epoch [256/1000] - Free Energy Loss: 0.0252
# Epoch [257/1000] - Free Energy Loss: -0.1265
# Epoch [258/1000] - Free Energy Loss: -0.1695
# Epoch [259/1000] - Free Energy Loss: -0.0989
# Epoch [260/1000] - Free Energy Loss: -0.1965
# Epoch [261/1000] - Free Energy Loss: -0.1769
# Epoch [262/1000] - Free Energy Loss: 0.0999
# Epoch [263/1000] - Free Energy Loss: -0.1853
# Epoch [264/1000] - Free Energy Loss: -0.1965
# Epoch [265/1000] - Free Energy Loss: -0.0464
# Epoch [266/1000] - Free Energy Loss: -0.2883
# Epoch [267/1000] - Free Energy Loss: 0.0101
# Epoch [268/1000] - Free Energy Loss: -0.1725
# Epoch [269/1000] - Free Energy Loss: -0.2332
# Epoch [270/1000] - Free Energy Loss: -0.3964
# Epoch [271/1000] - Free Energy Loss: 0.1970
# Epoch [272/1000] - Free Energy Loss: -0.3704
# Epoch [273/1000] - Free Energy Loss: -0.1956
# Epoch [274/1000] - Free Energy Loss: -0.1191
# Epoch [275/1000] - Free Energy Loss: -0.2332
# Epoch [276/1000] - Free Energy Loss: -0.1735
# Epoch [277/1000] - Free Energy Loss: -0.2325
# Epoch [278/1000] - Free Energy Loss: -0.1176
# Epoch [279/1000] - Free Energy Loss: -0.2222
# Epoch [280/1000] - Free Energy Loss: -0.2684
# Epoch [281/1000] - Free Energy Loss: -0.0889
# Epoch [282/1000] - Free Energy Loss: -0.1395
# Epoch [283/1000] - Free Energy Loss: -0.2300
# Epoch [284/1000] - Free Energy Loss: -0.2423
# Epoch [285/1000] - Free Energy Loss: -0.1093
# Epoch [286/1000] - Free Energy Loss: -0.1032
# Epoch [287/1000] - Free Energy Loss: -0.2747
# Epoch [288/1000] - Free Energy Loss: -0.0819
# Epoch [289/1000] - Free Energy Loss: -0.0494
# Epoch [290/1000] - Free Energy Loss: -0.3476
# Epoch [291/1000] - Free Energy Loss: -0.0395
# Epoch [292/1000] - Free Energy Loss: -0.2670
# Epoch [293/1000] - Free Energy Loss: -0.0867
# Epoch [294/1000] - Free Energy Loss: -0.2057
# Epoch [295/1000] - Free Energy Loss: -0.0833
# Epoch [296/1000] - Free Energy Loss: 0.0662
# Epoch [297/1000] - Free Energy Loss: -0.2421
# Epoch [298/1000] - Free Energy Loss: -0.5403
# Epoch [299/1000] - Free Energy Loss: 0.1526
# Epoch [300/1000] - Free Energy Loss: -0.1532
# Epoch [301/1000] - Free Energy Loss: -0.2103
# Epoch [302/1000] - Free Energy Loss: -0.0066
# Epoch [303/1000] - Free Energy Loss: 0.0223
# Epoch [304/1000] - Free Energy Loss: -0.2290
# Epoch [305/1000] - Free Energy Loss: -0.1681
# Epoch [306/1000] - Free Energy Loss: -0.2616
# Epoch [307/1000] - Free Energy Loss: 0.1823
# Epoch [308/1000] - Free Energy Loss: -0.3326
# Epoch [309/1000] - Free Energy Loss: -0.3102
# Epoch [310/1000] - Free Energy Loss: 0.2230
# Epoch [311/1000] - Free Energy Loss: -0.2245
# Epoch [312/1000] - Free Energy Loss: -0.1054
# Epoch [313/1000] - Free Energy Loss: 0.0238
# Epoch [314/1000] - Free Energy Loss: -0.4253
# Epoch [315/1000] - Free Energy Loss: -0.1479
# Epoch [316/1000] - Free Energy Loss: 0.2475
# Epoch [317/1000] - Free Energy Loss: -0.4115
# Epoch [318/1000] - Free Energy Loss: 0.0145
# Epoch [319/1000] - Free Energy Loss: -0.2189
# Epoch [320/1000] - Free Energy Loss: 0.0075
# Epoch [321/1000] - Free Energy Loss: -0.0944
# Epoch [322/1000] - Free Energy Loss: -0.3142
# Epoch [323/1000] - Free Energy Loss: -0.3031
# Epoch [324/1000] - Free Energy Loss: 0.1205
# Epoch [325/1000] - Free Energy Loss: -0.0451
# Epoch [326/1000] - Free Energy Loss: -0.3498
# Epoch [327/1000] - Free Energy Loss: 0.1305
# Epoch [328/1000] - Free Energy Loss: -0.0539
# Epoch [329/1000] - Free Energy Loss: -0.3548
# Epoch [330/1000] - Free Energy Loss: -0.0870
# Epoch [331/1000] - Free Energy Loss: -0.2425
# Epoch [332/1000] - Free Energy Loss: 0.0092
# Epoch [333/1000] - Free Energy Loss: -0.0588
# Epoch [334/1000] - Free Energy Loss: -0.0694
# Epoch [335/1000] - Free Energy Loss: -0.2331
# Epoch [336/1000] - Free Energy Loss: -0.1428
# Epoch [337/1000] - Free Energy Loss: 0.0439
# Epoch [338/1000] - Free Energy Loss: -0.4115
# Epoch [339/1000] - Free Energy Loss: 0.0188
# Epoch [340/1000] - Free Energy Loss: 0.0167
# Epoch [341/1000] - Free Energy Loss: -0.0812
# Epoch [342/1000] - Free Energy Loss: -0.1548
# Epoch [343/1000] - Free Energy Loss: 0.2022
# Epoch [344/1000] - Free Energy Loss: -0.5713
# Epoch [345/1000] - Free Energy Loss: 0.0891
# Epoch [346/1000] - Free Energy Loss: -0.2712
# Epoch [347/1000] - Free Energy Loss: -0.1470
# Epoch [348/1000] - Free Energy Loss: 0.1500
# Epoch [349/1000] - Free Energy Loss: -0.2047
# Epoch [350/1000] - Free Energy Loss: -0.1803
# Epoch [351/1000] - Free Energy Loss: -0.1914
# Epoch [352/1000] - Free Energy Loss: -0.1057
# Epoch [353/1000] - Free Energy Loss: 0.1126
# Epoch [354/1000] - Free Energy Loss: -0.4615
# Epoch [355/1000] - Free Energy Loss: -0.0048
# Epoch [356/1000] - Free Energy Loss: -0.0241
# Epoch [357/1000] - Free Energy Loss: -0.1397
# Epoch [358/1000] - Free Energy Loss: -0.1508
# Epoch [359/1000] - Free Energy Loss: 0.0463
# Epoch [360/1000] - Free Energy Loss: -0.3914
# Epoch [361/1000] - Free Energy Loss: 0.0350
# Epoch [362/1000] - Free Energy Loss: -0.1765
# Epoch [363/1000] - Free Energy Loss: -0.0590
# Epoch [364/1000] - Free Energy Loss: 0.1056
# Epoch [365/1000] - Free Energy Loss: -0.2051
# Epoch [366/1000] - Free Energy Loss: -0.3777
# Epoch [367/1000] - Free Energy Loss: 0.0761
# Epoch [368/1000] - Free Energy Loss: -0.3613
# Epoch [369/1000] - Free Energy Loss: -0.0419
# Epoch [370/1000] - Free Energy Loss: -0.1037
# Epoch [371/1000] - Free Energy Loss: 0.0605
# Epoch [372/1000] - Free Energy Loss: 0.0808
# Epoch [373/1000] - Free Energy Loss: -0.3187
# Epoch [374/1000] - Free Energy Loss: -0.3811
# Epoch [375/1000] - Free Energy Loss: -0.2850
# Epoch [376/1000] - Free Energy Loss: -0.1232
# Epoch [377/1000] - Free Energy Loss: 0.3606
# Epoch [378/1000] - Free Energy Loss: -0.3677
# Epoch [379/1000] - Free Energy Loss: -0.2858
# Epoch [380/1000] - Free Energy Loss: 0.0081
# Epoch [381/1000] - Free Energy Loss: -0.0776
# Epoch [382/1000] - Free Energy Loss: -0.0951
# Epoch [383/1000] - Free Energy Loss: -0.4675
# Epoch [384/1000] - Free Energy Loss: -0.1851
# Epoch [385/1000] - Free Energy Loss: -0.0685
# Epoch [386/1000] - Free Energy Loss: 0.2678
# Epoch [387/1000] - Free Energy Loss: -0.3906
# Epoch [388/1000] - Free Energy Loss: 0.0295
# Epoch [389/1000] - Free Energy Loss: -0.1823
# Epoch [390/1000] - Free Energy Loss: -0.2321
# Epoch [391/1000] - Free Energy Loss: -0.0314
# Epoch [392/1000] - Free Energy Loss: -0.2593
# Epoch [393/1000] - Free Energy Loss: -0.0379
# Epoch [394/1000] - Free Energy Loss: -0.0228
# Epoch [395/1000] - Free Energy Loss: -0.0868
# Epoch [396/1000] - Free Energy Loss: 0.0126
# Epoch [397/1000] - Free Energy Loss: -0.2935
# Epoch [398/1000] - Free Energy Loss: -0.2870
# Epoch [399/1000] - Free Energy Loss: -0.1870
# Epoch [400/1000] - Free Energy Loss: -0.1302
# Epoch [401/1000] - Free Energy Loss: -0.0774
# Epoch [402/1000] - Free Energy Loss: -0.3555
# Epoch [403/1000] - Free Energy Loss: -0.0086
# Epoch [404/1000] - Free Energy Loss: -0.0901
# Epoch [405/1000] - Free Energy Loss: -0.2976
# Epoch [406/1000] - Free Energy Loss: 0.2069
# Epoch [407/1000] - Free Energy Loss: -0.3011
# Epoch [408/1000] - Free Energy Loss: 0.1069
# Epoch [409/1000] - Free Energy Loss: -0.4357
# Epoch [410/1000] - Free Energy Loss: 0.0288
# Epoch [411/1000] - Free Energy Loss: -0.4139
# Epoch [412/1000] - Free Energy Loss: -0.0706
# Epoch [413/1000] - Free Energy Loss: 0.0027
# Epoch [414/1000] - Free Energy Loss: -0.6593
# Epoch [415/1000] - Free Energy Loss: 0.1609
# Epoch [416/1000] - Free Energy Loss: -0.2790
# Epoch [417/1000] - Free Energy Loss: -0.2256
# Epoch [418/1000] - Free Energy Loss: -0.1002
# Epoch [419/1000] - Free Energy Loss: -0.1906
# Epoch [420/1000] - Free Energy Loss: -0.2272
# Epoch [421/1000] - Free Energy Loss: -0.0368
# Epoch [422/1000] - Free Energy Loss: 0.0441
# Epoch [423/1000] - Free Energy Loss: -0.3906
# Epoch [424/1000] - Free Energy Loss: 0.0798
# Epoch [425/1000] - Free Energy Loss: -0.8592
# Epoch [426/1000] - Free Energy Loss: 0.3434
# Epoch [427/1000] - Free Energy Loss: -0.3526
# Epoch [428/1000] - Free Energy Loss: -0.0520
# Epoch [429/1000] - Free Energy Loss: -0.0469
# Epoch [430/1000] - Free Energy Loss: -0.4176
# Epoch [431/1000] - Free Energy Loss: -0.2460
# Epoch [432/1000] - Free Energy Loss: -0.1080
# Epoch [433/1000] - Free Energy Loss: -0.1040
# Epoch [434/1000] - Free Energy Loss: -0.0352
# Epoch [435/1000] - Free Energy Loss: -0.4016
# Epoch [436/1000] - Free Energy Loss: -0.0225
# Epoch [437/1000] - Free Energy Loss: -0.0816
# Epoch [438/1000] - Free Energy Loss: -0.0951
# Epoch [439/1000] - Free Energy Loss: -0.4970
# Epoch [440/1000] - Free Energy Loss: -0.0794
# Epoch [441/1000] - Free Energy Loss: -0.3587
# Epoch [442/1000] - Free Energy Loss: -0.2709
# Epoch [443/1000] - Free Energy Loss: -0.0334
# Epoch [444/1000] - Free Energy Loss: -0.3460
# Epoch [445/1000] - Free Energy Loss: -0.2896
# Epoch [446/1000] - Free Energy Loss: -0.1144
# Epoch [447/1000] - Free Energy Loss: -0.3104
# Epoch [448/1000] - Free Energy Loss: 0.0463
# Epoch [449/1000] - Free Energy Loss: -0.2398
# Epoch [450/1000] - Free Energy Loss: -0.2269
# Epoch [451/1000] - Free Energy Loss: -0.3666
# Epoch [452/1000] - Free Energy Loss: -0.0865
# Epoch [453/1000] - Free Energy Loss: -0.2748
# Epoch [454/1000] - Free Energy Loss: 0.1238
# Epoch [455/1000] - Free Energy Loss: -0.3892
# Epoch [456/1000] - Free Energy Loss: 0.1167
# Epoch [457/1000] - Free Energy Loss: -0.5519
# Epoch [458/1000] - Free Energy Loss: -0.4056
# Epoch [459/1000] - Free Energy Loss: 0.1372
# Epoch [460/1000] - Free Energy Loss: -0.1818
# Epoch [461/1000] - Free Energy Loss: -0.3687
# Epoch [462/1000] - Free Energy Loss: -0.4416
# Epoch [463/1000] - Free Energy Loss: -0.0350
# Epoch [464/1000] - Free Energy Loss: -0.3367
# Epoch [465/1000] - Free Energy Loss: 0.1891
# Epoch [466/1000] - Free Energy Loss: -0.4962
# Epoch [467/1000] - Free Energy Loss: -0.1454
# Epoch [468/1000] - Free Energy Loss: -0.1791
# Epoch [469/1000] - Free Energy Loss: -0.3216
# Epoch [470/1000] - Free Energy Loss: -0.0055
# Epoch [471/1000] - Free Energy Loss: -0.1728
# Epoch [472/1000] - Free Energy Loss: -0.6181
# Epoch [473/1000] - Free Energy Loss: -0.3010
# Epoch [474/1000] - Free Energy Loss: 0.0962
# Epoch [475/1000] - Free Energy Loss: -0.1708
# Epoch [476/1000] - Free Energy Loss: -0.3926
# Epoch [477/1000] - Free Energy Loss: -0.4121
# Epoch [478/1000] - Free Energy Loss: -0.3319
# Epoch [479/1000] - Free Energy Loss: -0.1900
# Epoch [480/1000] - Free Energy Loss: -0.2647
# Epoch [481/1000] - Free Energy Loss: 0.1915
# Epoch [482/1000] - Free Energy Loss: -0.4283
# Epoch [483/1000] - Free Energy Loss: -0.3394
# Epoch [484/1000] - Free Energy Loss: -0.2847
# Epoch [485/1000] - Free Energy Loss: -0.0079
# Epoch [486/1000] - Free Energy Loss: -0.3737
# Epoch [487/1000] - Free Energy Loss: -0.3958
# Epoch [488/1000] - Free Energy Loss: -0.3661
# Epoch [489/1000] - Free Energy Loss: -0.0338
# Epoch [490/1000] - Free Energy Loss: -0.3073
# Epoch [491/1000] - Free Energy Loss: -0.0878
# Epoch [492/1000] - Free Energy Loss: -0.5818
# Epoch [493/1000] - Free Energy Loss: -0.2923
# Epoch [494/1000] - Free Energy Loss: -0.0607
# Epoch [495/1000] - Free Energy Loss: -0.4365
# Epoch [496/1000] - Free Energy Loss: -0.1923
# Epoch [497/1000] - Free Energy Loss: 0.0156
# Epoch [498/1000] - Free Energy Loss: -0.5548
# Epoch [499/1000] - Free Energy Loss: -0.5010
# Epoch [500/1000] - Free Energy Loss: -0.1217
# Epoch [501/1000] - Free Energy Loss: -0.0166
# Epoch [502/1000] - Free Energy Loss: -0.1812
# Epoch [503/1000] - Free Energy Loss: -0.3019
# Epoch [504/1000] - Free Energy Loss: -0.3658
# Epoch [505/1000] - Free Energy Loss: -0.3089
# Epoch [506/1000] - Free Energy Loss: -0.0638
# Epoch [507/1000] - Free Energy Loss: -0.4132
# Epoch [508/1000] - Free Energy Loss: -0.4574
# Epoch [509/1000] - Free Energy Loss: -0.1606
# Epoch [510/1000] - Free Energy Loss: -0.1582
# Epoch [511/1000] - Free Energy Loss: -0.6174
# Epoch [512/1000] - Free Energy Loss: -0.1110
# Epoch [513/1000] - Free Energy Loss: -0.1379
# Epoch [514/1000] - Free Energy Loss: -0.4329
# Epoch [515/1000] - Free Energy Loss: -0.4586
# Epoch [516/1000] - Free Energy Loss: -0.0126
# Epoch [517/1000] - Free Energy Loss: -0.4831
# Epoch [518/1000] - Free Energy Loss: -0.4236
# Epoch [519/1000] - Free Energy Loss: -0.0968
# Epoch [520/1000] - Free Energy Loss: -0.3797
# Epoch [521/1000] - Free Energy Loss: -0.2712
# Epoch [522/1000] - Free Energy Loss: -0.0563
# Epoch [523/1000] - Free Energy Loss: -0.2930
# Epoch [524/1000] - Free Energy Loss: -0.2873
# Epoch [525/1000] - Free Energy Loss: -0.4520
# Epoch [526/1000] - Free Energy Loss: -0.1468
# Epoch [527/1000] - Free Energy Loss: -0.3427
# Epoch [528/1000] - Free Energy Loss: -0.4799
# Epoch [529/1000] - Free Energy Loss: -0.2501
# Epoch [530/1000] - Free Energy Loss: -0.3128
# Epoch [531/1000] - Free Energy Loss: -0.2927
# Epoch [532/1000] - Free Energy Loss: -0.1731
# Epoch [533/1000] - Free Energy Loss: -0.4770
# Epoch [534/1000] - Free Energy Loss: -0.2196
# Epoch [535/1000] - Free Energy Loss: -0.3385
# Epoch [536/1000] - Free Energy Loss: -0.3647
# Epoch [537/1000] - Free Energy Loss: -0.4546
# Epoch [538/1000] - Free Energy Loss: -0.5406
# Epoch [539/1000] - Free Energy Loss: 0.2109
# Epoch [540/1000] - Free Energy Loss: -0.4863
# Epoch [541/1000] - Free Energy Loss: -0.1750
# Epoch [542/1000] - Free Energy Loss: -0.4039
# Epoch [543/1000] - Free Energy Loss: -0.3062
# Epoch [544/1000] - Free Energy Loss: -0.4823
# Epoch [545/1000] - Free Energy Loss: -0.4307
# Epoch [546/1000] - Free Energy Loss: -0.0838
# Epoch [547/1000] - Free Energy Loss: -0.3883
# Epoch [548/1000] - Free Energy Loss: -0.1917
# Epoch [549/1000] - Free Energy Loss: -0.2847
# Epoch [550/1000] - Free Energy Loss: -0.6308
# Epoch [551/1000] - Free Energy Loss: -0.1076
# Epoch [552/1000] - Free Energy Loss: -0.3088
# Epoch [553/1000] - Free Energy Loss: -0.4758
# Epoch [554/1000] - Free Energy Loss: -0.3873
# Epoch [555/1000] - Free Energy Loss: -0.1742
# Epoch [556/1000] - Free Energy Loss: -0.2743
# Epoch [557/1000] - Free Energy Loss: -0.4866
# Epoch [558/1000] - Free Energy Loss: -0.3239
# Epoch [559/1000] - Free Energy Loss: -0.4973
# Epoch [560/1000] - Free Energy Loss: 0.0707
# Epoch [561/1000] - Free Energy Loss: -0.6709
# Epoch [562/1000] - Free Energy Loss: -0.2961
# Epoch [563/1000] - Free Energy Loss: -0.2509
# Epoch [564/1000] - Free Energy Loss: -0.5449
# Epoch [565/1000] - Free Energy Loss: -0.4171
# Epoch [566/1000] - Free Energy Loss: -0.1509
# Epoch [567/1000] - Free Energy Loss: -0.4907
# Epoch [568/1000] - Free Energy Loss: -0.2408
# Epoch [569/1000] - Free Energy Loss: -0.2706
# Epoch [570/1000] - Free Energy Loss: -0.3356
# Epoch [571/1000] - Free Energy Loss: -0.5980
# Epoch [572/1000] - Free Energy Loss: -0.2873
# Epoch [573/1000] - Free Energy Loss: -0.4721
# Epoch [574/1000] - Free Energy Loss: -0.5066
# Epoch [575/1000] - Free Energy Loss: -0.4627
# Epoch [576/1000] - Free Energy Loss: -0.3627
# Epoch [577/1000] - Free Energy Loss: -0.6844
# Epoch [578/1000] - Free Energy Loss: 0.1871
# Epoch [579/1000] - Free Energy Loss: -0.4324
# Epoch [580/1000] - Free Energy Loss: -0.5497
# Epoch [581/1000] - Free Energy Loss: -0.4561
# Epoch [582/1000] - Free Energy Loss: -0.0652
# Epoch [583/1000] - Free Energy Loss: -0.5214
# Epoch [584/1000] - Free Energy Loss: -0.4435
# Epoch [585/1000] - Free Energy Loss: -0.2930
# Epoch [586/1000] - Free Energy Loss: -0.5226
# Epoch [587/1000] - Free Energy Loss: -0.4153
# Epoch [588/1000] - Free Energy Loss: -0.4181
# Epoch [589/1000] - Free Energy Loss: -0.4575
# Epoch [590/1000] - Free Energy Loss: -0.4745
# Epoch [591/1000] - Free Energy Loss: -0.3633
# Epoch [592/1000] - Free Energy Loss: -0.3198
# Epoch [593/1000] - Free Energy Loss: -0.3988
# Epoch [594/1000] - Free Energy Loss: -0.4088
# Epoch [595/1000] - Free Energy Loss: -0.6605
# Epoch [596/1000] - Free Energy Loss: -0.2066
# Epoch [597/1000] - Free Energy Loss: -0.5104
# Epoch [598/1000] - Free Energy Loss: -0.5051
# Epoch [599/1000] - Free Energy Loss: -0.4996
# Epoch [600/1000] - Free Energy Loss: -0.4425
# Epoch [601/1000] - Free Energy Loss: -0.5315
# Epoch [602/1000] - Free Energy Loss: -0.3029
# Epoch [603/1000] - Free Energy Loss: -0.3299
# Epoch [604/1000] - Free Energy Loss: -0.2347
# Epoch [605/1000] - Free Energy Loss: -0.5860
# Epoch [606/1000] - Free Energy Loss: -0.4246
# Epoch [607/1000] - Free Energy Loss: -0.4864
# Epoch [608/1000] - Free Energy Loss: -0.3995
# Epoch [609/1000] - Free Energy Loss: -0.4059
# Epoch [610/1000] - Free Energy Loss: -0.1507
# Epoch [611/1000] - Free Energy Loss: -0.5926
# Epoch [612/1000] - Free Energy Loss: -0.6558
# Epoch [613/1000] - Free Energy Loss: -0.1781
# Epoch [614/1000] - Free Energy Loss: -0.6947
# Epoch [615/1000] - Free Energy Loss: -0.4388
# Epoch [616/1000] - Free Energy Loss: -0.3819
# Epoch [617/1000] - Free Energy Loss: -0.4123
# Epoch [618/1000] - Free Energy Loss: -0.4621
# Epoch [619/1000] - Free Energy Loss: -0.4766
# Epoch [620/1000] - Free Energy Loss: -0.5152
# Epoch [621/1000] - Free Energy Loss: -0.4215
# Epoch [622/1000] - Free Energy Loss: -0.4885
# Epoch [623/1000] - Free Energy Loss: -0.7140
# Epoch [624/1000] - Free Energy Loss: -0.1825
# Epoch [625/1000] - Free Energy Loss: -0.6256
# Epoch [626/1000] - Free Energy Loss: -0.3622
# Epoch [627/1000] - Free Energy Loss: -0.7277
# Epoch [628/1000] - Free Energy Loss: -0.6566
# Epoch [629/1000] - Free Energy Loss: -0.3315
# Epoch [630/1000] - Free Energy Loss: -0.5577
# Epoch [631/1000] - Free Energy Loss: -0.3892
# Epoch [632/1000] - Free Energy Loss: -0.3276
# Epoch [633/1000] - Free Energy Loss: -0.2289
# Epoch [634/1000] - Free Energy Loss: -0.9604
# Epoch [635/1000] - Free Energy Loss: -0.2336
# Epoch [636/1000] - Free Energy Loss: -0.4680
# Epoch [637/1000] - Free Energy Loss: -0.5668
# Epoch [638/1000] - Free Energy Loss: -0.4929
# Epoch [639/1000] - Free Energy Loss: -0.6295
# Epoch [640/1000] - Free Energy Loss: -0.4358
# Epoch [641/1000] - Free Energy Loss: -0.2782
# Epoch [642/1000] - Free Energy Loss: -0.3508
# Epoch [643/1000] - Free Energy Loss: -0.8348
# Epoch [644/1000] - Free Energy Loss: -0.1418
# Epoch [645/1000] - Free Energy Loss: -0.5804
# Epoch [646/1000] - Free Energy Loss: -0.7382
# Epoch [647/1000] - Free Energy Loss: -0.2599
# Epoch [648/1000] - Free Energy Loss: -0.3576
# Epoch [649/1000] - Free Energy Loss: -0.7663
# Epoch [650/1000] - Free Energy Loss: -0.2558
# Epoch [651/1000] - Free Energy Loss: -0.6578
# Epoch [652/1000] - Free Energy Loss: -0.5534
# Epoch [653/1000] - Free Energy Loss: -0.5059
# Epoch [654/1000] - Free Energy Loss: -0.3702
# Epoch [655/1000] - Free Energy Loss: -0.6213
# Epoch [656/1000] - Free Energy Loss: -0.4917
# Epoch [657/1000] - Free Energy Loss: -0.7301
# Epoch [658/1000] - Free Energy Loss: -0.3218
# Epoch [659/1000] - Free Energy Loss: -0.6947
# Epoch [660/1000] - Free Energy Loss: -0.4192
# Epoch [661/1000] - Free Energy Loss: -0.7374
# Epoch [662/1000] - Free Energy Loss: -0.5744
# Epoch [663/1000] - Free Energy Loss: -0.4730
# Epoch [664/1000] - Free Energy Loss: -0.7376
# Epoch [665/1000] - Free Energy Loss: -0.5071
# Epoch [666/1000] - Free Energy Loss: -0.5467
# Epoch [667/1000] - Free Energy Loss: -0.4595
# Epoch [668/1000] - Free Energy Loss: -0.5248
# Epoch [669/1000] - Free Energy Loss: -0.3651
# Epoch [670/1000] - Free Energy Loss: -0.5468
# Epoch [671/1000] - Free Energy Loss: -0.5442
# Epoch [672/1000] - Free Energy Loss: -0.5835
# Epoch [673/1000] - Free Energy Loss: -0.7984
# Epoch [674/1000] - Free Energy Loss: -0.2499
# Epoch [675/1000] - Free Energy Loss: -0.7093
# Epoch [676/1000] - Free Energy Loss: -0.3547
# Epoch [677/1000] - Free Energy Loss: -0.6516
# Epoch [678/1000] - Free Energy Loss: -0.5037
# Epoch [679/1000] - Free Energy Loss: -0.6178
# Epoch [680/1000] - Free Energy Loss: -0.4821
# Epoch [681/1000] - Free Energy Loss: -0.4966
# Epoch [682/1000] - Free Energy Loss: -0.6515
# Epoch [683/1000] - Free Energy Loss: -0.7394
# Epoch [684/1000] - Free Energy Loss: -0.5721
# Epoch [685/1000] - Free Energy Loss: -0.4966
# Epoch [686/1000] - Free Energy Loss: -0.6388
# Epoch [687/1000] - Free Energy Loss: -0.8016
# Epoch [688/1000] - Free Energy Loss: -0.6250
# Epoch [689/1000] - Free Energy Loss: -0.6091
# Epoch [690/1000] - Free Energy Loss: -0.5289
# Epoch [691/1000] - Free Energy Loss: -0.6731
# Epoch [692/1000] - Free Energy Loss: -0.4005
# Epoch [693/1000] - Free Energy Loss: -0.4836
# Epoch [694/1000] - Free Energy Loss: -0.6315
# Epoch [695/1000] - Free Energy Loss: -0.8216
# Epoch [696/1000] - Free Energy Loss: -0.5129
# Epoch [697/1000] - Free Energy Loss: -0.5851
# Epoch [698/1000] - Free Energy Loss: -0.7514
# Epoch [699/1000] - Free Energy Loss: -0.5446
# Epoch [700/1000] - Free Energy Loss: -0.3897
# Epoch [701/1000] - Free Energy Loss: -0.8899
# Epoch [702/1000] - Free Energy Loss: -0.5852
# Epoch [703/1000] - Free Energy Loss: -0.9865
# Epoch [704/1000] - Free Energy Loss: -0.0743
# Epoch [705/1000] - Free Energy Loss: -0.9254
# Epoch [706/1000] - Free Energy Loss: -0.4436
# Epoch [707/1000] - Free Energy Loss: -0.6490
# Epoch [708/1000] - Free Energy Loss: -0.4644
# Epoch [709/1000] - Free Energy Loss: -0.7484
# Epoch [710/1000] - Free Energy Loss: -0.6139
# Epoch [711/1000] - Free Energy Loss: -0.6947
# Epoch [712/1000] - Free Energy Loss: -0.5886
# Epoch [713/1000] - Free Energy Loss: -0.9062
# Epoch [714/1000] - Free Energy Loss: -0.5468
# Epoch [715/1000] - Free Energy Loss: -0.6576
# Epoch [716/1000] - Free Energy Loss: -0.6311
# Epoch [717/1000] - Free Energy Loss: -0.7412
# Epoch [718/1000] - Free Energy Loss: -0.6399
# Epoch [719/1000] - Free Energy Loss: -0.6403
# Epoch [720/1000] - Free Energy Loss: -0.8444
# Epoch [721/1000] - Free Energy Loss: -0.2886
# Epoch [722/1000] - Free Energy Loss: -0.7926
# Epoch [723/1000] - Free Energy Loss: -0.6665
# Epoch [724/1000] - Free Energy Loss: -0.5943
# Epoch [725/1000] - Free Energy Loss: -0.6112
# Epoch [726/1000] - Free Energy Loss: -0.5820
# Epoch [727/1000] - Free Energy Loss: -0.9128
# Epoch [728/1000] - Free Energy Loss: -0.8254
# Epoch [729/1000] - Free Energy Loss: -0.2514
# Epoch [730/1000] - Free Energy Loss: -0.8059
# Epoch [731/1000] - Free Energy Loss: -0.7527
# Epoch [732/1000] - Free Energy Loss: -0.4568
# Epoch [733/1000] - Free Energy Loss: -0.8735
# Epoch [734/1000] - Free Energy Loss: -0.8448
# Epoch [735/1000] - Free Energy Loss: -0.5087
# Epoch [736/1000] - Free Energy Loss: -0.5809
# Epoch [737/1000] - Free Energy Loss: -0.8146
# Epoch [738/1000] - Free Energy Loss: -0.7871
# Epoch [739/1000] - Free Energy Loss: -0.5634
# Epoch [740/1000] - Free Energy Loss: -0.4999
# Epoch [741/1000] - Free Energy Loss: -0.8589
# Epoch [742/1000] - Free Energy Loss: -0.6060
# Epoch [743/1000] - Free Energy Loss: -0.6771
# Epoch [744/1000] - Free Energy Loss: -0.7283
# Epoch [745/1000] - Free Energy Loss: -0.8603
# Epoch [746/1000] - Free Energy Loss: -0.5393
# Epoch [747/1000] - Free Energy Loss: -0.6146
# Epoch [748/1000] - Free Energy Loss: -1.0406
# Epoch [749/1000] - Free Energy Loss: -0.8149
# Epoch [750/1000] - Free Energy Loss: -0.7340
# Epoch [751/1000] - Free Energy Loss: -0.7395
# Epoch [752/1000] - Free Energy Loss: -0.6961
# Epoch [753/1000] - Free Energy Loss: -0.6802
# Epoch [754/1000] - Free Energy Loss: -0.5221
# Epoch [755/1000] - Free Energy Loss: -0.9220
# Epoch [756/1000] - Free Energy Loss: -1.0318
# Epoch [757/1000] - Free Energy Loss: -0.6364
# Epoch [758/1000] - Free Energy Loss: -0.7800
# Epoch [759/1000] - Free Energy Loss: -0.5693
# Epoch [760/1000] - Free Energy Loss: -1.0767
# Epoch [761/1000] - Free Energy Loss: -0.5204
# Epoch [762/1000] - Free Energy Loss: -0.7893
# Epoch [763/1000] - Free Energy Loss: -0.5826
# Epoch [764/1000] - Free Energy Loss: -1.0052
# Epoch [765/1000] - Free Energy Loss: -0.6053
# Epoch [766/1000] - Free Energy Loss: -0.4590
# Epoch [767/1000] - Free Energy Loss: -0.8707
# Epoch [768/1000] - Free Energy Loss: -0.7813
# Epoch [769/1000] - Free Energy Loss: -0.6454
# Epoch [770/1000] - Free Energy Loss: -0.7784
# Epoch [771/1000] - Free Energy Loss: -0.9297
# Epoch [772/1000] - Free Energy Loss: -0.7144
# Epoch [773/1000] - Free Energy Loss: -0.6124
# Epoch [774/1000] - Free Energy Loss: -0.9821
# Epoch [775/1000] - Free Energy Loss: -0.3766
# Epoch [776/1000] - Free Energy Loss: -0.9376
# Epoch [777/1000] - Free Energy Loss: -0.9731
# Epoch [778/1000] - Free Energy Loss: -0.7978
# Epoch [779/1000] - Free Energy Loss: -0.8271
# Epoch [780/1000] - Free Energy Loss: -0.5983
# Epoch [781/1000] - Free Energy Loss: -0.8695
# Epoch [782/1000] - Free Energy Loss: -0.8504
# Epoch [783/1000] - Free Energy Loss: -0.9481
# Epoch [784/1000] - Free Energy Loss: -0.8132
# Epoch [785/1000] - Free Energy Loss: -0.9538
# Epoch [786/1000] - Free Energy Loss: -0.6089
# Epoch [787/1000] - Free Energy Loss: -0.9112
# Epoch [788/1000] - Free Energy Loss: -0.8542
# Epoch [789/1000] - Free Energy Loss: -0.4900
# Epoch [790/1000] - Free Energy Loss: -0.6632
# Epoch [791/1000] - Free Energy Loss: -0.7169
# Epoch [792/1000] - Free Energy Loss: -0.8630
# Epoch [793/1000] - Free Energy Loss: -0.7034
# Epoch [794/1000] - Free Energy Loss: -0.8314
# Epoch [795/1000] - Free Energy Loss: -0.7893
# Epoch [796/1000] - Free Energy Loss: -0.8615
# Epoch [797/1000] - Free Energy Loss: -0.6101
# Epoch [798/1000] - Free Energy Loss: -0.7954
# Epoch [799/1000] - Free Energy Loss: -0.6648
# Epoch [800/1000] - Free Energy Loss: -0.7694
# Epoch [801/1000] - Free Energy Loss: -0.6302
# Epoch [802/1000] - Free Energy Loss: -1.0486
# Epoch [803/1000] - Free Energy Loss: -0.9042
# Epoch [804/1000] - Free Energy Loss: -0.6010
# Epoch [805/1000] - Free Energy Loss: -0.9232
# Epoch [806/1000] - Free Energy Loss: -0.9636
# Epoch [807/1000] - Free Energy Loss: -0.5982
# Epoch [808/1000] - Free Energy Loss: -0.8719
# Epoch [809/1000] - Free Energy Loss: -0.8468
# Epoch [810/1000] - Free Energy Loss: -0.9138
# Epoch [811/1000] - Free Energy Loss: -1.0928
# Epoch [812/1000] - Free Energy Loss: -0.6502
# Epoch [813/1000] - Free Energy Loss: -0.7842
# Epoch [814/1000] - Free Energy Loss: -0.8660
# Epoch [815/1000] - Free Energy Loss: -0.7493
# Epoch [816/1000] - Free Energy Loss: -0.9967
# Epoch [817/1000] - Free Energy Loss: -0.9003
# Epoch [818/1000] - Free Energy Loss: -0.8882
# Epoch [819/1000] - Free Energy Loss: -0.8093
# Epoch [820/1000] - Free Energy Loss: -0.6698
# Epoch [821/1000] - Free Energy Loss: -0.9391
# Epoch [822/1000] - Free Energy Loss: -0.9589
# Epoch [823/1000] - Free Energy Loss: -0.6483
# Epoch [824/1000] - Free Energy Loss: -1.0522
# Epoch [825/1000] - Free Energy Loss: -0.7505
# Epoch [826/1000] - Free Energy Loss: -0.7989
# Epoch [827/1000] - Free Energy Loss: -0.9985
# Epoch [828/1000] - Free Energy Loss: -0.6269
# Epoch [829/1000] - Free Energy Loss: -0.7309
# Epoch [830/1000] - Free Energy Loss: -0.8079
# Epoch [831/1000] - Free Energy Loss: -0.7097
# Epoch [832/1000] - Free Energy Loss: -0.8268
# Epoch [833/1000] - Free Energy Loss: -1.0335
# Epoch [834/1000] - Free Energy Loss: -1.0567
# Epoch [835/1000] - Free Energy Loss: -0.7151
# Epoch [836/1000] - Free Energy Loss: -1.0190
# Epoch [837/1000] - Free Energy Loss: -1.1411
# Epoch [838/1000] - Free Energy Loss: -0.6551
# Epoch [839/1000] - Free Energy Loss: -0.7435
# Epoch [840/1000] - Free Energy Loss: -0.8400
# Epoch [841/1000] - Free Energy Loss: -0.6203
# Epoch [842/1000] - Free Energy Loss: -0.9668
# Epoch [843/1000] - Free Energy Loss: -0.9671
# Epoch [844/1000] - Free Energy Loss: -1.1015
# Epoch [845/1000] - Free Energy Loss: -0.9474
# Epoch [846/1000] - Free Energy Loss: -0.8012
# Epoch [847/1000] - Free Energy Loss: -1.0557
# Epoch [848/1000] - Free Energy Loss: -0.8586
# Epoch [849/1000] - Free Energy Loss: -0.8726
# Epoch [850/1000] - Free Energy Loss: -0.7722
# Epoch [851/1000] - Free Energy Loss: -1.0919
# Epoch [852/1000] - Free Energy Loss: -0.9390
# Epoch [853/1000] - Free Energy Loss: -0.9858
# Epoch [854/1000] - Free Energy Loss: -0.6713
# Epoch [855/1000] - Free Energy Loss: -0.9343
# Epoch [856/1000] - Free Energy Loss: -1.0318
# Epoch [857/1000] - Free Energy Loss: -0.6663
# Epoch [858/1000] - Free Energy Loss: -0.8895
# Epoch [859/1000] - Free Energy Loss: -0.9136
# Epoch [860/1000] - Free Energy Loss: -1.0548
# Epoch [861/1000] - Free Energy Loss: -0.6940
# Epoch [862/1000] - Free Energy Loss: -0.9592
# Epoch [863/1000] - Free Energy Loss: -1.0563
# Epoch [864/1000] - Free Energy Loss: -0.9605
# Epoch [865/1000] - Free Energy Loss: -0.7736
# Epoch [866/1000] - Free Energy Loss: -0.8621
# Epoch [867/1000] - Free Energy Loss: -0.9372
# Epoch [868/1000] - Free Energy Loss: -0.9406
# Epoch [869/1000] - Free Energy Loss: -1.1164
# Epoch [870/1000] - Free Energy Loss: -1.2010
# Epoch [871/1000] - Free Energy Loss: -0.9517
# Epoch [872/1000] - Free Energy Loss: -1.1277
# Epoch [873/1000] - Free Energy Loss: -0.9397
# Epoch [874/1000] - Free Energy Loss: -1.1386
# Epoch [875/1000] - Free Energy Loss: -0.9584
# Epoch [876/1000] - Free Energy Loss: -0.8783
# Epoch [877/1000] - Free Energy Loss: -1.0204
# Epoch [878/1000] - Free Energy Loss: -1.0702
# Epoch [879/1000] - Free Energy Loss: -1.3017
# Epoch [880/1000] - Free Energy Loss: -0.7452
# Epoch [881/1000] - Free Energy Loss: -1.0825
# Epoch [882/1000] - Free Energy Loss: -0.9161
# Epoch [883/1000] - Free Energy Loss: -1.1507
# Epoch [884/1000] - Free Energy Loss: -0.9674
# Epoch [885/1000] - Free Energy Loss: -0.9628
# Epoch [886/1000] - Free Energy Loss: -0.8117
# Epoch [887/1000] - Free Energy Loss: -1.0018
# Epoch [888/1000] - Free Energy Loss: -1.0589
# Epoch [889/1000] - Free Energy Loss: -0.9951
# Epoch [890/1000] - Free Energy Loss: -0.9353
# Epoch [891/1000] - Free Energy Loss: -1.0553
# Epoch [892/1000] - Free Energy Loss: -1.0953
# Epoch [893/1000] - Free Energy Loss: -1.0576
# Epoch [894/1000] - Free Energy Loss: -0.7160
# Epoch [895/1000] - Free Energy Loss: -1.2025
# Epoch [896/1000] - Free Energy Loss: -1.0481
# Epoch [897/1000] - Free Energy Loss: -1.0276
# Epoch [898/1000] - Free Energy Loss: -0.7780
# Epoch [899/1000] - Free Energy Loss: -0.8861
# Epoch [900/1000] - Free Energy Loss: -0.9300
# Epoch [901/1000] - Free Energy Loss: -1.0496
# Epoch [902/1000] - Free Energy Loss: -0.8986
# Epoch [903/1000] - Free Energy Loss: -1.3031
# Epoch [904/1000] - Free Energy Loss: -0.9246
# Epoch [905/1000] - Free Energy Loss: -1.0389
# Epoch [906/1000] - Free Energy Loss: -1.1255
# Epoch [907/1000] - Free Energy Loss: -1.1180
# Epoch [908/1000] - Free Energy Loss: -1.0296
# Epoch [909/1000] - Free Energy Loss: -1.0735
# Epoch [910/1000] - Free Energy Loss: -1.0483
# Epoch [911/1000] - Free Energy Loss: -0.8384
# Epoch [912/1000] - Free Energy Loss: -1.1336
# Epoch [913/1000] - Free Energy Loss: -0.8674
# Epoch [914/1000] - Free Energy Loss: -1.0011
# Epoch [915/1000] - Free Energy Loss: -0.8929
# Epoch [916/1000] - Free Energy Loss: -0.8051
# Epoch [917/1000] - Free Energy Loss: -1.2636
# Epoch [918/1000] - Free Energy Loss: -1.0418
# Epoch [919/1000] - Free Energy Loss: -1.1209
# Epoch [920/1000] - Free Energy Loss: -1.3239
# Epoch [921/1000] - Free Energy Loss: -1.0127
# Epoch [922/1000] - Free Energy Loss: -0.8134
# Epoch [923/1000] - Free Energy Loss: -1.2984
# Epoch [924/1000] - Free Energy Loss: -0.8922
# Epoch [925/1000] - Free Energy Loss: -1.0274
# Epoch [926/1000] - Free Energy Loss: -1.1106
# Epoch [927/1000] - Free Energy Loss: -0.7407
# Epoch [928/1000] - Free Energy Loss: -1.1018
# Epoch [929/1000] - Free Energy Loss: -1.2546
# Epoch [930/1000] - Free Energy Loss: -0.8905
# Epoch [931/1000] - Free Energy Loss: -1.4354
# Epoch [932/1000] - Free Energy Loss: -1.0626
# Epoch [933/1000] - Free Energy Loss: -1.2453
# Epoch [934/1000] - Free Energy Loss: -1.4651
# Epoch [935/1000] - Free Energy Loss: -0.8060
# Epoch [936/1000] - Free Energy Loss: -1.1191
# Epoch [937/1000] - Free Energy Loss: -1.2150
# Epoch [938/1000] - Free Energy Loss: -0.7987
# Epoch [939/1000] - Free Energy Loss: -1.0797
# Epoch [940/1000] - Free Energy Loss: -1.2162
# Epoch [941/1000] - Free Energy Loss: -1.2436
# Epoch [942/1000] - Free Energy Loss: -1.0964
# Epoch [943/1000] - Free Energy Loss: -1.0522
# Epoch [944/1000] - Free Energy Loss: -1.1259
# Epoch [945/1000] - Free Energy Loss: -1.0008
# Epoch [946/1000] - Free Energy Loss: -1.1281
# Epoch [947/1000] - Free Energy Loss: -1.0818
# Epoch [948/1000] - Free Energy Loss: -1.2111
# Epoch [949/1000] - Free Energy Loss: -1.0723
# Epoch [950/1000] - Free Energy Loss: -1.2479
# Epoch [951/1000] - Free Energy Loss: -1.2517
# Epoch [952/1000] - Free Energy Loss: -1.2112
# Epoch [953/1000] - Free Energy Loss: -1.0108
# Epoch [954/1000] - Free Energy Loss: -1.2919
# Epoch [955/1000] - Free Energy Loss: -1.0967
# Epoch [956/1000] - Free Energy Loss: -0.8915
# Epoch [957/1000] - Free Energy Loss: -1.4380
# Epoch [958/1000] - Free Energy Loss: -0.9409
# Epoch [959/1000] - Free Energy Loss: -1.0449
# Epoch [960/1000] - Free Energy Loss: -0.9532
# Epoch [961/1000] - Free Energy Loss: -0.8563
# Epoch [962/1000] - Free Energy Loss: -1.2920
# Epoch [963/1000] - Free Energy Loss: -1.0133
# Epoch [964/1000] - Free Energy Loss: -1.0917
# Epoch [965/1000] - Free Energy Loss: -1.3803
# Epoch [966/1000] - Free Energy Loss: -1.0441
# Epoch [967/1000] - Free Energy Loss: -1.5217
# Epoch [968/1000] - Free Energy Loss: -1.3627
# Epoch [969/1000] - Free Energy Loss: -0.9612
# Epoch [970/1000] - Free Energy Loss: -0.9884
# Epoch [971/1000] - Free Energy Loss: -0.9323
# Epoch [972/1000] - Free Energy Loss: -1.3243
# Epoch [973/1000] - Free Energy Loss: -1.2947
# Epoch [974/1000] - Free Energy Loss: -1.0472
# Epoch [975/1000] - Free Energy Loss: -1.2621
# Epoch [976/1000] - Free Energy Loss: -1.2540
# Epoch [977/1000] - Free Energy Loss: -1.3119
# Epoch [978/1000] - Free Energy Loss: -1.2927
# Epoch [979/1000] - Free Energy Loss: -1.3234
# Epoch [980/1000] - Free Energy Loss: -0.7517
# Epoch [981/1000] - Free Energy Loss: -1.1310
# Epoch [982/1000] - Free Energy Loss: -1.5391
# Epoch [983/1000] - Free Energy Loss: -1.3450
# Epoch [984/1000] - Free Energy Loss: -1.1950
# Epoch [985/1000] - Free Energy Loss: -1.5413
# Epoch [986/1000] - Free Energy Loss: -1.0790
# Epoch [987/1000] - Free Energy Loss: -1.4252
# Epoch [988/1000] - Free Energy Loss: -1.0465
# Epoch [989/1000] - Free Energy Loss: -1.4261
# Epoch [990/1000] - Free Energy Loss: -1.3668
# Epoch [991/1000] - Free Energy Loss: -1.2958
# Epoch [992/1000] - Free Energy Loss: -1.1494
# Epoch [993/1000] - Free Energy Loss: -1.1346
# Epoch [994/1000] - Free Energy Loss: -1.3321
# Epoch [995/1000] - Free Energy Loss: -1.3393
# Epoch [996/1000] - Free Energy Loss: -1.1944
# Epoch [997/1000] - Free Energy Loss: -0.9586
# Epoch [998/1000] - Free Energy Loss: -1.1907
# Epoch [999/1000] - Free Energy Loss: -1.0425
# Epoch [1000/1000] - Free Energy Loss: -1.3348

# %%
plt.plot([metrics[epoch]['free_energy_loss'] for epoch in metrics])
plt.xlabel("Epoch")
plt.ylabel("Free Energy Loss")
# Out:
# Text(0, 0.5, 'Free Energy Loss')

# %%
samples = rbm.generate(state.params,
                       n_samples=10_000,
                       T_schedule=jnp.ones(200) * 1.2,
                       rng=rng)

rel_freq = samples.mean(0)
rel_freq
# Out:
# Array([0.0442    , 0.0477    , 0.0613    , 0.0257    , 0.0629    ,
#        0.0395    , 0.0994    , 0.0627    , 0.0672    , 0.0444    ,
#        0.08679999, 0.0393    , 0.0438    , 0.0462    , 0.0581    ,
#        0.0245    , 0.0377    , 0.0415    , 0.0395    , 0.0276    ],      dtype=float32)

# %%
rel_freq.sum()
# Out:
# Array(0.9999999, dtype=float32)

# %%
spin_counts = samples.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(22), align='left', edgecolor='black')
plt.xticks(range(21))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
sites = np.arange(1, visible_units+1)
ax.bar(sites, rel_freq, width=0.8, edgecolor='black', alpha=0.7)
ax.axhline(1/visible_units, color='red', linestyle='--', label=f'Expected = {1/visible_units:.3f}')

ax.set_xlabel('Spin‐site index')
ax.set_ylabel('Relative frequency of up‐spin')
ax.set_title('Training Data: Up‐Spin Occurrence per Site')
ax.set_xticks(sites)
ax.set_ylim(0, rel_freq.max()*1.2)

ax.legend(loc='upper right')
plt.tight_layout()
plt.show()
