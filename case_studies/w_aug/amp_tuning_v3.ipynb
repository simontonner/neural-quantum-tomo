# %%
import re
from pathlib import Path

import numpy as np

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import optax
from flax.training.train_state import TrainState
from flax import linen as nn

import matplotlib.pyplot as plt

from typing import Optional, Tuple, Dict, Any, Sequence


data_dir = "./data"
print(f"Data resides in        : {data_dir}")
# Out:
# Data resides in        : ./data

# %%
class MultiBasisDataLoader:
    def __init__(self, data_dict: dict[str, jnp.ndarray],
                 batch_size: int = 128,
                 shuffle: bool = True,
                 drop_last: bool = False,
                 seed: int = 0):
        lengths = [len(v) for v in data_dict.values()]
        if len(set(lengths)) != 1:
            raise ValueError(f"All arrays must have the same length, got: {lengths}")

        self.data = data_dict
        self.n = lengths[0]
        self.bs = batch_size
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.rng = np.random.default_rng(seed)

        self.idx_slices = [
            (i, i + batch_size)
            for i in range(0, self.n, batch_size)
            if not drop_last or i + batch_size <= self.n
        ]

    def __iter__(self):
        self.order = np.arange(self.n)
        if self.shuffle:
            self.rng.shuffle(self.order)
        self.slice_idx = 0
        return self

    def __next__(self):
        if self.slice_idx >= len(self.idx_slices):
            raise StopIteration
        s, e = self.idx_slices[self.slice_idx]
        self.slice_idx += 1
        return {k: v[self.order[s:e]] for k, v in self.data.items()}


def load_measurements(folder: str, file_pattern: str = "w_*.txt") -> dict[str, jnp.ndarray]:
    out: dict[str, jnp.ndarray] = {}

    for fp in Path(folder).glob(file_pattern):
        basis = fp.stem.split("_")[2]

        bitstrings = []
        with fp.open() as f:
            for line in f:
                bitstring = np.fromiter((c.islower() for c in line.strip()), dtype=np.float32)
                bitstrings.append(bitstring)

        arr = jnp.asarray(np.stack(bitstrings))
        if basis in out:
            out[basis] = jnp.concatenate([out[basis], arr], axis=0)
        else:
            out[basis] = arr

    return out

# %%
data_dict = load_measurements("data/", "w_*.txt")

keys_amp = [k for k in data_dict if re.fullmatch(r"^Z+$", k)]
keys_pha = [k for k in data_dict if re.fullmatch(r"^(?!Z+$).*", k)]
dict_amp = {k: data_dict[k] for k in keys_amp}
dict_pha = {k: data_dict[k] for k in keys_pha}

loader_amp = MultiBasisDataLoader(dict_amp, batch_size=128)
loader_pha = MultiBasisDataLoader(dict_pha, batch_size=128)

# %%
import jax
import jax.numpy as jnp
from flax import linen as nn
from typing import Tuple
from jax.random import PRNGKey


class PcdRBM(nn.Module):
    n_visible: int
    n_hidden: int
    k: int = 1
    T: float = 1.0

    def setup(self):
        self.W = self.param("W", nn.initializers.normal(0.01), (self.n_visible, self.n_hidden))
        self.b = self.param("b", nn.initializers.zeros, (self.n_visible,))
        self.c = self.param("c", nn.initializers.zeros, (self.n_hidden,))

    def __call__(self, data_batch: jnp.ndarray, key: PRNGKey, v_chain: jnp.ndarray) -> Tuple[jnp.ndarray, jnp.ndarray, PRNGKey]:
        # Gibbs sampling
        body_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=self.T)
        model_batch, key = jax.lax.fori_loop(0, self.k, body_fn, (v_chain, key))
        model_batch = jax.lax.stop_gradient(model_batch)

        # Free energy loss
        free_energy_data = self._free_energy(data_batch)
        free_energy_model = self._free_energy(model_batch)
        loss = jnp.mean(free_energy_data) - jnp.mean(free_energy_model)

        return loss, model_batch, key

    def _free_energy(self, v_batch: jnp.ndarray) -> jnp.ndarray:
        visible_term = jnp.dot(v_batch, self.b)
        hidden_term = jnp.sum(jax.nn.softplus(v_batch @ self.W + self.c), axis=-1)
        return -visible_term - hidden_term

    @staticmethod
    def _gibbs_step(state: Tuple[jnp.ndarray, PRNGKey], W, b, c, T=1.0) -> Tuple[jnp.ndarray, PRNGKey]:
        v_batch, key = state
        key, h_key, v_key = jax.random.split(key, 3)

        h_probs = jax.nn.sigmoid((v_batch @ W + c) / T)
        h = jax.random.bernoulli(h_key, h_probs).astype(jnp.float32)

        v_probs = jax.nn.sigmoid((h @ W.T + b) / T)
        v = jax.random.bernoulli(v_key, v_probs).astype(jnp.float32)

        return v, key

    @nn.nowrap
    def generate(self, n_samples: int, T_schedule: jnp.ndarray, rng: PRNGKey) -> jnp.ndarray:
        rng, init_key = jax.random.split(rng)
        v = jax.random.bernoulli(init_key, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)
        state = (v, rng)

        anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, state)

        return v_final

# %%
from flax.training.train_state import TrainState
from typing import Dict, Tuple
import jax
import jax.numpy as jnp
from jax.random import PRNGKey


def train_step_amp(
        state: TrainState,
        batch_dict: Dict[str, jnp.ndarray],
        rng: PRNGKey,
        v_chain: jnp.ndarray
) -> Tuple[TrainState, float, jnp.ndarray, PRNGKey]:
    if len(batch_dict) != 1:
        raise ValueError("Batch dictionary must contain exactly one entry.")

    (basis, batch), = batch_dict.items()
    if set(basis) != {'Z'}:
        raise ValueError(f"Batch key must consist only of 'Z', got: {basis}")

    rng, subkey = jax.random.split(rng)

    def loss_fn(params):
        loss, new_chain, new_key = state.apply_fn(
            {"params": params},
            batch,
            subkey,
            v_chain
        )
        return loss, (new_chain, new_key)

    (loss, (new_v_chain, new_key)), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    new_state = state.apply_gradients(grads=grads)

    return new_state, float(loss), new_v_chain, new_key





def train_amp_rbm(
        state: TrainState,
        loader,
        v_chain: jnp.ndarray,
        num_epochs: int,
        rng: PRNGKey
) -> Tuple[TrainState, jnp.ndarray, Dict[int, float], PRNGKey]:

    metrics = {}

    for epoch in range(num_epochs):
        tot_loss = 0.0
        batches = 0

        for batch_dict in loader:
            state, loss, v_chain, rng = train_step_amp(state, batch_dict, rng, v_chain)
            tot_loss += loss
            batches += 1

        avg_loss = tot_loss / batches
        metrics[epoch] = {"loss_amp": avg_loss}
        print(f"Epoch {epoch+1}/{num_epochs} │ Loss: {avg_loss:.4f}")

    return state, v_chain, metrics, rng

# %%
import optax

# ---- hyperparameters ----
batch_size    = 128
visible_units = 10
hidden_units  = 30
k_steps       = 10
lr            = 1e-2
num_epochs    = 50
chains        = 128

# Random seed setup
random_seed = PRNGKey(42)
key1, key2, key3 = jax.random.split(random_seed, 3)

# Model instantiation
model_amp = PcdRBM(
    n_visible=visible_units,
    n_hidden=hidden_units,
    k=k_steps
)

# Initialize parameters
dummy_batch = jnp.zeros((batch_size, visible_units), dtype=jnp.float32)
dummy_chain = jnp.zeros((chains, visible_units), dtype=jnp.float32)
variables_amp = model_amp.init(key1, dummy_batch, key3, dummy_chain)

# Optimizer
optimizer_amp = optax.adam(learning_rate=lr)

# State
state_amp = TrainState.create(
    apply_fn=model_amp.apply,
    params=variables_amp["params"],
    tx=optimizer_amp
)

# Initialize persistent chain
v_chain = jax.random.bernoulli(key2, p=0.5, shape=(chains, visible_units)).astype(jnp.float32)

# %%
state_amp, v_chain, metrics, rng = train_amp_rbm(
    state_amp,
    loader_amp,
    v_chain,
    num_epochs,
    key3
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 state_amp, v_chain, metrics, rng = train_amp_rbm(
#       2     state_amp,
#       3     loader_amp,
#       4     v_chain,
#       5     num_epochs,
#       6     key3
#       7 )
#
# Cell In[24], line 56, in train_amp_rbm(state, loader, v_chain, num_epochs, rng)
#      53 batches = 0
#      55 for batch_dict in loader:
# ---> 56     state, loss, v_chain, rng = train_step_amp(state, batch_dict, rng, v_chain)
#      57     tot_loss += loss
#      58     batches += 1
#
# Cell In[24], line 32, in train_step_amp(state, batch_dict, rng, v_chain)
#      24     loss, new_chain, new_key = state.apply_fn(
#      25         {"params": params},
#      26         batch,
#      27         subkey,
#      28         v_chain
#      29     )
#      30     return loss, (new_chain, new_key)
# ---> 32 (loss, (new_v_chain, new_key)), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
#      33 new_state = state.apply_gradients(grads=grads)
#      35 return new_state, float(loss), new_v_chain, new_key
#
#     [... skipping hidden 1 frame]
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/api.py:693, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     691   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     692 else:
# --> 693   ans, vjp_py, aux = _vjp(
#     694       f_partial, *dyn_args, has_aux=True)
#     695 _check_scalar(ans)
#     696 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/api.py:2180, in _vjp(fun, has_aux, *primals)
#    2178 else:
#    2179   flat_fun, out_aux_trees = flatten_fun_nokwargs2(fun, in_tree)
# -> 2180   out_primals, vjp, aux = ad.vjp(flat_fun, primals_flat, has_aux=True)
#    2181   out_tree, aux_tree = out_aux_trees()
#    2182 out_primal_avals = map(shaped_abstractify, out_primals)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/interpreters/ad.py:145, in vjp(traceable, primals, has_aux)
#     143   out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     144 else:
# --> 145   out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#     147 def unbound_vjp(pvals, jaxpr, consts, *cts):
#     148   cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/interpreters/ad.py:132, in linearize(traceable, *primals, **kwargs)
#     130 _, in_tree = tree_flatten(((primals, primals), {}))
#     131 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 132 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     133 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     134 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:777, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     775 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     776   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 777   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     778   assert not env
#     779   del main, fun, env
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# Cell In[24], line 24, in train_step_amp.<locals>.loss_fn(params)
#      23 def loss_fn(params):
# ---> 24     loss, new_chain, new_key = state.apply_fn(
#      25         {"params": params},
#      26         batch,
#      27         subkey,
#      28         v_chain
#      29     )
#      30     return loss, (new_chain, new_key)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/flax/linen/module.py:2252, in Module.apply(self, variables, rngs, method, mutable, capture_intermediates, *args, **kwargs)
#    2250   method = self.__call__
#    2251 method = _get_unbound_fn(method)
# -> 2252 return apply(
#    2253   method,
#    2254   self,
#    2255   mutable=mutable,
#    2256   capture_intermediates=capture_intermediates,
#    2257 )(variables, *args, **kwargs, rngs=rngs)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/flax/core/scope.py:1101, in apply.<locals>.wrapper(variables, rngs, *args, **kwargs)
#    1096   raise errors.ApplyScopeInvalidVariablesStructureError(variables)
#    1098 with bind(
#    1099   variables, rngs=rngs, mutable=mutable, flags=flags
#    1100 ).temporary() as root:
# -> 1101   y = fn(root, *args, **kwargs)
#    1102 if mutable is not False:
#    1103   return y, root.mutable_variables()
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/flax/linen/module.py:3032, in apply.<locals>.scope_fn(scope, *args, **kwargs)
#    3030 _context.capture_stack.append(capture_intermediates)
#    3031 try:
# -> 3032   return fn(module.clone(parent=scope, _deep_clone=True), *args, **kwargs)
#    3033 finally:
#    3034   _context.capture_stack.pop()
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/flax/linen/module.py:701, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     699 if args and isinstance(args[0], Module):
#     700   self, args = args[0], args[1:]
# --> 701   return self._call_wrapped_method(fun, args, kwargs)
#     702 else:
#     703   return fun(*args, **kwargs)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/flax/linen/module.py:1233, in Module._call_wrapped_method(self, fun, args, kwargs)
#    1231 if _use_named_call:
#    1232   with jax.named_scope(_derive_profiling_name(self, fun)):
# -> 1233     y = run_fun(self, *args, **kwargs)
#    1234 else:
#    1235   y = run_fun(self, *args, **kwargs)
#
# Cell In[23], line 22, in PcdRBM.__call__(self, data_batch, key, v_chain)
#      19 def __call__(self, data_batch: jnp.ndarray, key: PRNGKey, v_chain: jnp.ndarray) -> Tuple[jnp.ndarray, jnp.ndarray, PRNGKey]:
#      20     # Gibbs sampling
#      21     body_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=self.T)
# ---> 22     model_batch, key = jax.lax.fori_loop(0, self.k, body_fn, (v_chain, key))
#      23     model_batch = jax.lax.stop_gradient(model_batch)
#      25     # Free energy loss
#
#     [... skipping hidden 1 frame]
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:2061, in fori_loop(lower, upper, body_fun, init_val, unroll)
#    2057   if config.disable_jit.value and length == 0:
#    2058     # non-jit implementation of scan does not support length=0
#    2059     return init_val
# -> 2061   (_, result), _ = scan(
#    2062       _fori_scan_body_fun(body_fun),
#    2063       (lower_, init_val),
#    2064       None,
#    2065       length=length,
#    2066       unroll=unroll,
#    2067   )
#    2068   return result
#    2069 if unroll is not None:
#
#     [... skipping hidden 1 frame]
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:304, in scan(f, init, xs, length, reverse, unroll, _split_transpose)
#     302   in_flat = [*in_state, *in_carry, *in_ext]
#     303   num_carry += len(attrs_tracked)
# --> 304 out = scan_p.bind(*consts, *in_flat,
#     305                   reverse=reverse, length=length, jaxpr=jaxpr,
#     306                   num_consts=len(consts), num_carry=num_carry,
#     307                   linear=(False,) * (len(consts) + len(in_flat)),
#     308                   unroll=unroll,
#     309                   _split_transpose=_split_transpose)
#     310 if attrs_tracked:
#     311   out_state, out = split_list(out, [len(attrs_tracked)])
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1217, in scan_bind(*args, **params)
#    1215   _scan_typecheck(True, *in_atoms, **params)
#    1216   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1217 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/interpreters/ad.py:315, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     313   msg = f"Differentiation rule for '{primitive}' not implemented"
#     314   raise NotImplementedError(msg)
# --> 315 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     316 if primitive.multiple_results:
#     317   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:521, in _scan_jvp(primals, tangents, reverse, length, jaxpr, num_consts, num_carry, linear, unroll, _split_transpose)
#     516 consts_linear, init_linear, xs_linear = split_list(linear, [num_consts, num_carry])
#     517 jaxpr_jvp_linear = tuple(consts_linear + [True] * len(consts_dot)
#     518                          + init_linear + [True] * len(init_dot)
#     519                          + xs_linear + [True] * len(xs_dot))
# --> 521 out_flat = scan_p.bind(
#     522     *(consts + consts_dot + init + init_dot + xs + xs_dot),
#     523     reverse=reverse, length=length, jaxpr=jaxpr_jvp_rearranged,
#     524     num_consts=num_consts + len(consts_dot),
#     525     num_carry=num_carry + len(init_dot),
#     526     linear=jaxpr_jvp_linear, unroll=unroll,
#     527     _split_transpose=_split_transpose)
#     529 carry, carry_dot, ys, ys_dot = split_list(out_flat, [num_carry, len(init_dot), num_ys])
#     530 primals_out = carry + ys
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1217, in scan_bind(*args, **params)
#    1215   _scan_typecheck(True, *in_atoms, **params)
#    1216   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1217 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:214, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     212 def process_primitive(self, primitive, tracers, params):
#     213   if primitive in custom_partial_eval_rules:
# --> 214     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     215   else:
#     216     return self.default_process_primitive(primitive, tracers, params)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:632, in _scan_partial_eval(trace, reverse, length, num_consts, num_carry, jaxpr, linear, unroll, _split_transpose, *tracers)
#     630 else:
#     631   linear_known = [False] * len(known_inputs)  # conservative!
# --> 632   out_known = scan_p.bind(
#     633       *known_inputs, reverse=reverse, length=length, jaxpr=jaxpr_known,
#     634       num_consts=len(jaxpr_known_consts), num_carry=num_carry - sum(carry_uk),
#     635       linear=tuple(linear_known), unroll=unroll,
#     636       _split_transpose=_split_transpose)
#     637   del linear_known
#     638 # Complete the known output by filling in forwarded values using fwds_known.
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1217, in scan_bind(*args, **params)
#    1215   _scan_typecheck(True, *in_atoms, **params)
#    1216   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1217 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/core.py:921, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     919   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     920 else:
# --> 921   return primitive.impl(*tracers, **params)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/dispatch.py:87, in apply_primitive(prim, *args, **params)
#      85 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86 try:
# ---> 87   outs = fun(*args)
#      88 finally:
#      89   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/pjit.py:327, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     325 @api_boundary
#     326 def cache_miss(*args, **kwargs):
# --> 327   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     328       jit_info, *args, **kwargs)
#     329   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     330   pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/pjit.py:185, in _python_pjit_helper(jit_info, *args, **kwargs)
#     182   args_flat = [*init_states, *args_flat]
#     184 try:
# --> 185   out_flat = pjit_p.bind(*args_flat, **params)
#     186 except pxla.DeviceAssignmentMismatchError as e:
#     187   fails, = e.args
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/core.py:921, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     919   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     920 else:
# --> 921   return primitive.impl(*tracers, **params)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/pjit.py:1635, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1632 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1633 has_explicit_sharding = _pjit_explicit_sharding(
#    1634     in_shardings, out_shardings, None, None)
# -> 1635 return xc._xla.pjit(
#    1636     name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1637     tree_util.dispatch_registry,
#    1638     lambda x, sharding: pxla.shard_args([sharding], [x])[0],
#    1639     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/pjit.py:1614, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1613 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1614   out_flat, compiled = _pjit_call_impl_python(
#    1615       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1616       out_shardings=out_shardings, in_layouts=in_layouts,
#    1617       out_layouts=out_layouts, resource_env=resource_env,
#    1618       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1619       inline=inline)
#    1620   pgle_profiler = _read_pgle_profiler(jaxpr)
#    1621   fastpath_data = _get_fastpath_data(
#    1622       compiled, tree_structure(out_flat), args, out_flat, [], jaxpr.effects,
#    1623       jaxpr.consts, None, pgle_profiler)
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/pjit.py:1536, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1531     compile_options = {'fdo_profile': fdo_profile}
#    1533 # TODO(patrios): Do not pass mutable profile session through cached lowering
#    1534 # chain. Instead we need to move profilers dictionary to pxla module and use
#    1535 # module as key. Right now we can't do that since there is no way to evict _pjit_lower_cached cache for in PGLE mode.
# -> 1536 compiled = _resolve_and_lower(
#    1537     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1538     out_shardings=out_shardings, in_layouts=in_layouts,
#    1539     out_layouts=out_layouts, resource_env=resource_env,
#    1540     donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1541     inline=inline, lowering_platforms=None,
#    1542     lowering_parameters=mlir.LoweringParameters(),
#    1543     pgle_profiler=pgle_profiler
#    1544 ).compile(compile_options)
#    1546 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1547 # This check is expensive so only do it if enable_checks is on.
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2496, in MeshComputation.compile(self, compiler_options)
#    2494 def compile(self, compiler_options=None) -> MeshExecutable:
#    2495   if self._executable is None or compiler_options is not None:
# -> 2496     executable = UnloadedMeshExecutable.from_hlo(
#    2497         self._name, self._hlo, **self.compile_args,
#    2498         compiler_options=compiler_options)
#    2499     if compiler_options is None:
#    2500       self._executable = executable
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2995, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2992       mesh = i.mesh  # type: ignore
#    2993       break
# -> 2995 xla_executable = _cached_compilation(
#    2996     hlo, name, mesh, spmd_lowering,
#    2997     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    2998     allow_prop_to_outputs, tuple(host_callbacks), backend, da, pmap_nreps,
#    2999     compiler_options_keys, compiler_options_values, pgle_profiler)
#    3001 if auto_spmd_lowering:
#    3002   assert mesh is not None
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2810, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_keys, compiler_options_values, pgle_profiler)
#    2802 compile_options = create_compile_options(
#    2803     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2804     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2805     dev, pmap_nreps, compiler_options)
#    2807 with dispatch.log_elapsed_time(
#    2808     "Finished XLA compilation of {fun_name} in {elapsed_time} sec",
#    2809     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2810   xla_executable = compiler.compile_or_get_cached(
#    2811       backend, computation, dev, compile_options, host_callbacks,
#    2812       pgle_profiler)
#    2813 return xla_executable
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/compiler.py:378, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, pgle_profiler)
#     367   return _compile_and_write_autotune_config(
#     368       backend,
#     369       computation,
#    (...)
#     375       min_device_process_id
#     376   )
#     377 else:
# --> 378   return _compile_and_write_cache(
#     379       backend,
#     380       computation,
#     381       compile_options,
#     382       host_callbacks,
#     383       module_name,
#     384       cache_key,
#     385   )
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/compiler.py:608, in _compile_and_write_cache(backend, computation, compile_options, host_callbacks, module_name, cache_key)
#     599 def _compile_and_write_cache(
#     600     backend: xc.Client,
#     601     computation: ir.Module,
#    (...)
#     605     cache_key: str,
#     606 ) -> xc.LoadedExecutable:
#     607   start_time = time.monotonic()
# --> 608   executable = backend_compile(
#     609       backend, computation, compile_options, host_callbacks
#     610   )
#     611   compile_time = time.monotonic() - start_time
#     612   _cache_write(
#     613       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     614   )
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/jax/_src/compiler.py:238, in backend_compile(backend, module, options, host_callbacks)
#     233   return backend.compile(built_c, compile_options=options,
#     234                          host_callbacks=host_callbacks)
#     235 # Some backends don't have `host_callbacks` option yet
#     236 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     237 # to take in `host_callbacks`
# --> 238 return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %%
plt.plot([metrics[epoch]['loss_amp'] for epoch in metrics])
plt.xlabel("Epoch")
plt.ylabel("Free Energy Loss")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.plot([metrics[epoch]['loss_amp'] for epoch in metrics])
#       2 plt.xlabel("Epoch")
#       3 plt.ylabel("Free Energy Loss")
#
# NameError: name 'metrics' is not defined

# %%
samples = model_amp.apply(
    {"params": state_amp.params, "pcd_state": state_amp.pcd_state},
    n_samples=10_000,
    T_schedule=jnp.ones(300) * 1.2,
    rng=rng,
    method=PcdRBM.generate,
    rngs={"pcd_init": rng}  # this is the fix
)

rel_freq = samples.mean(0)
rel_freq
# Out:
# ---------------------------------------------------------------------------
# JaxTransformError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 samples = model_amp.apply(
#       2     {"params": state_amp.params, "pcd_state": state_amp.pcd_state},
#       3     n_samples=10_000,
#       4     T_schedule=jnp.ones(300) * 1.2,
#       5     rng=rng,
#       6     method=PcdRBM.generate,
#       7     rngs={"pcd_init": rng}  # this is the fix
#       8 )
#      10 rel_freq = samples.mean(0)
#      11 rel_freq
#
#     [... skipping hidden 4 frame]
#
# Cell In[24], line 66, in PcdRBM.generate(self, n_samples, T_schedule, rng)
#      63 state = (v, rng)
#      65 anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
# ---> 66 v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, state)
#      68 return v_final
#
#     [... skipping hidden 12 frame]
#
# Cell In[24], line 65, in PcdRBM.generate.<locals>.<lambda>(i, s)
#      62 v = jax.random.bernoulli(init_key, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)
#      63 state = (v, rng)
# ---> 65 anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
#      66 v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, state)
#      68 return v_final
#
#     [... skipping hidden 4 frame]
#
# Cell In[24], line 21, in PcdRBM.setup(self)
#      18 self.c = self.param("c", nn.initializers.zeros, (self.n_hidden,))
#      20 init_fn = lambda key: self.init_chain(key, (self.n_chains, self.n_visible))
# ---> 21 self.v_chain = self.variable("pcd_state", "v_chain", init_fn, self.make_rng("pcd_init"))
#
#     [... skipping hidden 3 frame]
#
# File ~/miniforge3/envs/dlnn2/lib/python3.9/site-packages/flax/core/tracers.py:37, in check_trace_level(base_level)
#      35 level = trace_level(current_trace())
#      36 if level != base_level:
# ---> 37   raise errors.JaxTransformError()
#
# JaxTransformError: Jax transforms and Flax models cannot be mixed. (https://flax.readthedocs.io/en/latest/api_reference/flax.errors.html#flax.errors.JaxTransformError)

# %%
spin_counts = samples.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(22), align='left', edgecolor='black')
plt.xticks(range(21))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
# compare with actual frequencies from first
empirical_freq = jnp.zeros(visible_units)
num_total = 0

for batch in loader_amp:
    for arr in batch.values():
        empirical_freq += jnp.sum(arr, axis=0)
        num_total += arr.shape[0]

empirical_freq = empirical_freq / num_total
empirical_freq
# Out:
# Array([0.0959375 , 0.09953125, 0.09640625, 0.0984375 , 0.09984375,
#        0.10265625, 0.09671875, 0.101875  , 0.109375  , 0.09921875],      dtype=float32)

# %%
# Plotting comparison
plt.figure(figsize=(10, 5))
x = np.arange(visible_units)
width = 0.35

plt.bar(x - width/2, empirical_freq, width, label="Empirical", alpha=0.7)
plt.bar(x + width/2, rel_freq, width, label="Sampled", alpha=0.7)
plt.axhline(1 / visible_units, linestyle='--', color='gray', label=f'1/{visible_units} reference')
plt.xlabel("Visible Unit Index")
plt.ylabel("Mean Activation Probability")
plt.title("Comparison: Empirical vs Sampled Frequencies")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
