# %%
import re
from pathlib import Path

import numpy as np

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import optax
from flax.training.train_state import TrainState
from flax import linen as nn

import matplotlib.pyplot as plt

from flax import struct
from flax.training.train_state import TrainState
from flax.core import FrozenDict
from typing import Any, Dict, Tuple

import jax, jax.numpy as jnp
from jax.random import PRNGKey
from flax import linen as nn
from typing import Tuple


from typing import Optional, Tuple, Dict, Any, Sequence

from optax import linear_schedule

data_dir = "./data"
print(f"Data resides in        : {data_dir}")
# Out:
# Data resides in        : ./data

# %%
class MultiBasisDataLoader:
    def __init__(self, data_dict: dict[str, jnp.ndarray],
                 batch_size: int = 128,
                 shuffle: bool = True,
                 drop_last: bool = False,
                 seed: int = 0):
        lengths = [len(v) for v in data_dict.values()]
        if len(set(lengths)) != 1:
            raise ValueError(f"All arrays must have the same length, got: {lengths}")

        self.data = data_dict
        self.n = lengths[0]
        self.bs = batch_size
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.rng = np.random.default_rng(seed)

        self.idx_slices = [
            (i, i + batch_size)
            for i in range(0, self.n, batch_size)
            if not drop_last or i + batch_size <= self.n
        ]

    def __iter__(self):
        self.order = np.arange(self.n)
        if self.shuffle:
            self.rng.shuffle(self.order)
        self.slice_idx = 0
        return self

    def __next__(self):
        if self.slice_idx >= len(self.idx_slices):
            raise StopIteration
        s, e = self.idx_slices[self.slice_idx]
        self.slice_idx += 1
        return {k: v[self.order[s:e]] for k, v in self.data.items()}

    def __len__(self):
        return len(self.idx_slices)


def load_measurements(folder: str, file_pattern: str = "w_*.txt") -> dict[str, jnp.ndarray]:
    out: dict[str, jnp.ndarray] = {}

    for fp in Path(folder).glob(file_pattern):
        basis = fp.stem.split("_")[2]

        bitstrings = []
        with fp.open() as f:
            for line in f:
                bitstring = np.fromiter((c.islower() for c in line.strip()), dtype=np.float32)
                bitstrings.append(bitstring)

        arr = jnp.asarray(np.stack(bitstrings))
        if basis in out:
            out[basis] = jnp.concatenate([out[basis], arr], axis=0)
        else:
            out[basis] = arr

    return out

# %%
data_dict = load_measurements("data/", "w_*.txt")

keys_amp = [k for k in data_dict if re.fullmatch(r"^Z+$", k)]
keys_pha = [k for k in data_dict if re.fullmatch(r"^(?!Z+$).*", k)]
dict_amp = {k: data_dict[k] for k in keys_amp}
dict_pha = {k: data_dict[k] for k in keys_pha}

# %%
empirical_freq_amp = jnp.zeros(next(iter(dict_amp.values())).shape[1])
num_total = 0

for arr in dict_amp.values():
    empirical_freq_amp += jnp.sum(arr, axis=0)
    num_total += arr.shape[0]

empirical_freq_amp = empirical_freq_amp / num_total

# %%
class RBM(nn.Module):
    n_visible: int
    n_hidden: int
    k: int = 1          # bound to class instance to make whole gibbs chain compilable
    T: float = 1.0      # bound to class instance to make single gibbs step compilable

    def setup(self):
        self.W = self.param("W", nn.initializers.normal(0.01), (self.n_visible, self.n_hidden))
        self.b = self.param("b", nn.initializers.zeros, (self.n_visible,))
        self.c = self.param("c", nn.initializers.zeros, (self.n_hidden,))

    def __call__(self, data: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W, self.b, self.c, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (aux_vars["gibbs_chain"], aux_vars["key"]))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain) # cut off gradients after Gibbs sampling

        loss = jnp.mean(self._free_energy(data)) - jnp.mean(self._free_energy(gibbs_chain))
        return loss, {"gibbs_chain": gibbs_chain, "key": key}

    def _free_energy(self, v):
        return -(v @ self.b) - jnp.sum(jax.nn.softplus(v @ self.W + self.c), -1)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c)/T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b)/T)).astype(jnp.float32)
        return v, key

    @nn.nowrap
    def generate(self, n_samples: int, T_schedule: jnp.ndarray, key: PRNGKey) -> jnp.ndarray:
        key, key_init = jax.random.split(key, 2)
        v = jax.random.bernoulli(key_init, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)

        anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, (v, key))
        return v_final

# %%
@jax.jit
def train_step_amp(
        state: TrainState,
        batch_dict: Dict[str, jnp.ndarray],
        gibbs_chain: jnp.ndarray,
        key: PRNGKey,
        p_reset: float) -> Tuple[TrainState, jnp.ndarray, jnp.ndarray, PRNGKey]:

    if len(batch_dict) != 1:
        raise ValueError("Batch dictionary must contain exactly one entry.")

    (basis_key, batch), = batch_dict.items()
    if set(basis_key) != {'Z'}:
        raise ValueError(f"Batch key must consist only of 'Z', got: {basis_key}")

    key, reset_key = jax.random.split(key)

    def maybe_reset(chain, data_batch, key, p_reset):
        # Reset entire rows, not individual bits
        reset_mask = jax.random.bernoulli(key, p=p_reset, shape=(chain.shape[0], 1))
        return jnp.where(reset_mask, data_batch, chain)

    reset_chain = maybe_reset(gibbs_chain, batch, reset_key, p_reset)

    aux_vars = {"gibbs_chain": reset_chain, "key": key}
    loss_fn = lambda params: state.apply_fn({'params': params}, batch, aux_vars)
    value_and_grad_fn = jax.value_and_grad(loss_fn, has_aux=True)

    (loss, aux_vars), grads = value_and_grad_fn(state.params)
    state = state.apply_gradients(grads=grads)

    return state, loss, aux_vars["gibbs_chain"], aux_vars["key"]



def train_amp_rbm(
        state: TrainState,
        loader: MultiBasisDataLoader,
        gibbs_chain: jnp.ndarray,
        num_epochs: int,
        key: PRNGKey,
        p_min: float = 0.02,
        p_max: float = 0.30,
        reset_gain: float = 0.5,
        ema_alpha: float = 0.9) -> Tuple[TrainState, Dict[int, float]]:

    metrics = {}

    def estimate_entropy(chain: jnp.ndarray) -> float:
        # Bitwise marginal entropy
        probs = jnp.mean(chain, axis=0)
        entropies = -probs * jnp.log(probs + 1e-8) - (1 - probs) * jnp.log(1 - probs + 1e-8)
        return jnp.sum(entropies)

    def count_unique_modes(chain: jnp.ndarray) -> int:
        # Convert binary vectors to packed byte-wise integers
        int_repr = jnp.packbits(chain.astype(jnp.uint8), axis=-1, bitorder='little')
        # Count unique rows = unique binary patterns
        return jnp.unique(int_repr, axis=0).shape[0]

    # For entropy reset logic
    H_target = jnp.log(2.0) * gibbs_chain.shape[-1]  # maximum entropy for uniform binary bits
    H_ema = H_target

    for epoch in range(num_epochs):
        tot_loss = 0.0
        tot_entropy = 0.0
        tot_mode_count = 0.0
        batches = 0

        for batch_dict in loader:
            H_chain = estimate_entropy(gibbs_chain)
            n_modes = count_unique_modes(gibbs_chain)

            H_ema = float(ema_alpha * H_ema + (1 - ema_alpha) * H_chain)
            p_reset = jnp.clip(reset_gain * (H_target - H_ema), a_min=p_min, a_max=p_max)

            state, loss, gibbs_chain, key = train_step_amp(
                state, batch_dict, gibbs_chain, key, float(p_reset)
            )

            tot_entropy += float(H_chain)
            tot_loss += float(loss)
            tot_mode_count += float(n_modes)
            batches += 1

        avg_loss = tot_loss / batches
        avg_entropy = tot_entropy / batches
        avg_mode_count = tot_mode_count / batches

        lr = float(lr_schedule(state.opt_state[0].count))
        metrics[epoch] = {
            "loss_amp": avg_loss,
            "H_chain": avg_entropy,
            "mode_count": avg_mode_count,
            "lr": lr,
        }

        print(f"Epoch {epoch+1}/{num_epochs} │ Loss: {avg_loss:.4f} │ H_chain: {avg_entropy:.2f} │ Modes: {avg_mode_count:.0f} │ LR: {lr:.5f}")

    return state, metrics

# %%
# ---- hyperparameters ----
batch_size      = 64        #                                               DONE
visible_units   = 10        #                                               DONE
hidden_units    = 16        # totally sufficient to capture all modes       DONE
k_steps         = 300       # more k-steps mean less variance in the loss
init_lr         = 1e-2
final_lr        = init_lr * 0.1
num_epochs      = 500
chains          = batch_size


key_seed = PRNGKey(42)
key, key_params, key_chains, key_dummy = jax.random.split(key_seed, 4)

model_amp = RBM(visible_units, hidden_units, k=k_steps)
batch_dummy = jnp.zeros((batch_size, visible_units), dtype=jnp.float32)
aux_vars_dummy = {"gibbs_chain": jnp.zeros((batch_size, visible_units), dtype=jnp.float32), "key": key_dummy}
variables_amp = model_amp.init({"params": key_params}, batch_dummy, aux_vars_dummy)

loader_amp = MultiBasisDataLoader(dict_amp, batch_size=batch_size)

def sigmoid_schedule(init_lr, final_lr, decay_steps, a=0.01, center_step=None):
    if center_step is None:
        center_step = decay_steps / 2
    schedule = lambda step: final_lr + (init_lr - final_lr) / (1 + jnp.exp(a * (jnp.minimum(step, decay_steps) - center_step)))
    return schedule

schedule_steps = num_epochs * len(loader_amp)
lr_schedule = sigmoid_schedule(init_lr=init_lr, final_lr=final_lr, decay_steps=schedule_steps, a=0.001, center_step=schedule_steps * 0.5)

# Use it in the optimizer
optimizer_amp = optax.adam(learning_rate=lr_schedule)

state_amp = TrainState.create(apply_fn=model_amp.apply, params=variables_amp["params"], tx=optimizer_amp)
gibbs_chain = jax.random.bernoulli(key_chains, p=0.5, shape=(chains, visible_units)).astype(jnp.float32)

# %time state_amp, metrics_amp = train_amp_rbm(state_amp, loader_amp, gibbs_chain, num_epochs, key=key, p_min=0.00, p_max=1, reset_gain=0.5)
# Out:
# Epoch 1/500 │ Loss: -0.3387 │ H_chain: 3.97 │ Modes: 34 │ LR: 0.01000
# Epoch 2/500 │ Loss: -0.0632 │ H_chain: 3.33 │ Modes: 27 │ LR: 0.01000
# Epoch 3/500 │ Loss: -0.0508 │ H_chain: 3.29 │ Modes: 27 │ LR: 0.01000
# Epoch 4/500 │ Loss: -0.0382 │ H_chain: 3.27 │ Modes: 26 │ LR: 0.01000
# Epoch 5/500 │ Loss: -0.0160 │ H_chain: 3.23 │ Modes: 26 │ LR: 0.01000
# Epoch 6/500 │ Loss: -0.0269 │ H_chain: 3.24 │ Modes: 26 │ LR: 0.01000
# Epoch 7/500 │ Loss: -0.0027 │ H_chain: 3.22 │ Modes: 26 │ LR: 0.01000
# Epoch 8/500 │ Loss: 0.0092 │ H_chain: 3.19 │ Modes: 26 │ LR: 0.01000
# Epoch 9/500 │ Loss: -0.0026 │ H_chain: 3.20 │ Modes: 26 │ LR: 0.01000
# Epoch 10/500 │ Loss: 0.0309 │ H_chain: 3.18 │ Modes: 26 │ LR: 0.01000
# Epoch 11/500 │ Loss: 0.0063 │ H_chain: 3.19 │ Modes: 26 │ LR: 0.01000
# Epoch 12/500 │ Loss: 0.0255 │ H_chain: 3.19 │ Modes: 26 │ LR: 0.01000
# Epoch 13/500 │ Loss: 0.0167 │ H_chain: 3.18 │ Modes: 25 │ LR: 0.01000
# Epoch 14/500 │ Loss: 0.0280 │ H_chain: 3.18 │ Modes: 26 │ LR: 0.01000
# Epoch 15/500 │ Loss: 0.0082 │ H_chain: 3.19 │ Modes: 26 │ LR: 0.01000
# Epoch 16/500 │ Loss: 0.0239 │ H_chain: 3.18 │ Modes: 26 │ LR: 0.01000
# Epoch 17/500 │ Loss: 0.0305 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 18/500 │ Loss: 0.0120 │ H_chain: 3.18 │ Modes: 26 │ LR: 0.01000
# Epoch 19/500 │ Loss: 0.0397 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 20/500 │ Loss: 0.0158 │ H_chain: 3.18 │ Modes: 25 │ LR: 0.01000
# Epoch 21/500 │ Loss: 0.0152 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 22/500 │ Loss: 0.0119 │ H_chain: 3.19 │ Modes: 26 │ LR: 0.01000
# Epoch 23/500 │ Loss: 0.0365 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 24/500 │ Loss: 0.0234 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 25/500 │ Loss: 0.0208 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 26/500 │ Loss: 0.0371 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 27/500 │ Loss: 0.0239 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 28/500 │ Loss: 0.0112 │ H_chain: 3.18 │ Modes: 25 │ LR: 0.01000
# Epoch 29/500 │ Loss: 0.0334 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 30/500 │ Loss: 0.0295 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 31/500 │ Loss: 0.0277 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 32/500 │ Loss: 0.0188 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 33/500 │ Loss: 0.0337 │ H_chain: 3.16 │ Modes: 26 │ LR: 0.01000
# Epoch 34/500 │ Loss: 0.0283 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 35/500 │ Loss: 0.0141 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 36/500 │ Loss: 0.0271 │ H_chain: 3.16 │ Modes: 26 │ LR: 0.01000
# Epoch 37/500 │ Loss: 0.0427 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 38/500 │ Loss: 0.0159 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 39/500 │ Loss: 0.0247 │ H_chain: 3.18 │ Modes: 26 │ LR: 0.01000
# Epoch 40/500 │ Loss: 0.0394 │ H_chain: 3.16 │ Modes: 26 │ LR: 0.01000
# Epoch 41/500 │ Loss: 0.0155 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 42/500 │ Loss: 0.0135 │ H_chain: 3.18 │ Modes: 25 │ LR: 0.01000
# Epoch 43/500 │ Loss: 0.0098 │ H_chain: 3.19 │ Modes: 26 │ LR: 0.01000
# Epoch 44/500 │ Loss: 0.0410 │ H_chain: 3.16 │ Modes: 26 │ LR: 0.01000
# Epoch 45/500 │ Loss: 0.0135 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 46/500 │ Loss: 0.0151 │ H_chain: 3.18 │ Modes: 26 │ LR: 0.01000
# Epoch 47/500 │ Loss: 0.0306 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 48/500 │ Loss: 0.0015 │ H_chain: 3.19 │ Modes: 26 │ LR: 0.01000
# Epoch 49/500 │ Loss: 0.0218 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 50/500 │ Loss: 0.0013 │ H_chain: 3.18 │ Modes: 25 │ LR: 0.01000
# Epoch 51/500 │ Loss: 0.0272 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 52/500 │ Loss: 0.0202 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 53/500 │ Loss: -0.0107 │ H_chain: 3.19 │ Modes: 26 │ LR: 0.01000
# Epoch 54/500 │ Loss: 0.0311 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 55/500 │ Loss: 0.0138 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 56/500 │ Loss: 0.0244 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 57/500 │ Loss: 0.0163 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 58/500 │ Loss: 0.0154 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 59/500 │ Loss: -0.0010 │ H_chain: 3.19 │ Modes: 26 │ LR: 0.01000
# Epoch 60/500 │ Loss: 0.0221 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 61/500 │ Loss: 0.0073 │ H_chain: 3.18 │ Modes: 25 │ LR: 0.01000
# Epoch 62/500 │ Loss: 0.0174 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 63/500 │ Loss: 0.0016 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 64/500 │ Loss: 0.0181 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 65/500 │ Loss: 0.0034 │ H_chain: 3.18 │ Modes: 25 │ LR: 0.01000
# Epoch 66/500 │ Loss: 0.0219 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 67/500 │ Loss: 0.0164 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 68/500 │ Loss: 0.0008 │ H_chain: 3.18 │ Modes: 26 │ LR: 0.01000
# Epoch 69/500 │ Loss: 0.0290 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 70/500 │ Loss: 0.0172 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 71/500 │ Loss: -0.0109 │ H_chain: 3.18 │ Modes: 25 │ LR: 0.01000
# Epoch 72/500 │ Loss: 0.0283 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 73/500 │ Loss: 0.0106 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 74/500 │ Loss: -0.0057 │ H_chain: 3.18 │ Modes: 26 │ LR: 0.01000
# Epoch 75/500 │ Loss: 0.0115 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 76/500 │ Loss: 0.0165 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 77/500 │ Loss: 0.0115 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 78/500 │ Loss: 0.0169 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 79/500 │ Loss: -0.0028 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 80/500 │ Loss: 0.0163 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 81/500 │ Loss: 0.0102 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 82/500 │ Loss: 0.0401 │ H_chain: 3.14 │ Modes: 25 │ LR: 0.01000
# Epoch 83/500 │ Loss: -0.0057 │ H_chain: 3.18 │ Modes: 26 │ LR: 0.01000
# Epoch 84/500 │ Loss: 0.0041 │ H_chain: 3.17 │ Modes: 26 │ LR: 0.01000
# Epoch 85/500 │ Loss: 0.0246 │ H_chain: 3.14 │ Modes: 25 │ LR: 0.01000
# Epoch 86/500 │ Loss: 0.0021 │ H_chain: 3.18 │ Modes: 26 │ LR: 0.01000
# Epoch 87/500 │ Loss: 0.0246 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 88/500 │ Loss: 0.0166 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 89/500 │ Loss: -0.0142 │ H_chain: 3.19 │ Modes: 26 │ LR: 0.01000
# Epoch 90/500 │ Loss: 0.0248 │ H_chain: 3.14 │ Modes: 25 │ LR: 0.01000
# Epoch 91/500 │ Loss: 0.0131 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 92/500 │ Loss: -0.0144 │ H_chain: 3.18 │ Modes: 25 │ LR: 0.01000
# Epoch 93/500 │ Loss: -0.0191 │ H_chain: 3.17 │ Modes: 25 │ LR: 0.01000
# Epoch 94/500 │ Loss: 0.0038 │ H_chain: 3.15 │ Modes: 25 │ LR: 0.01000
# Epoch 95/500 │ Loss: -0.0301 │ H_chain: 3.18 │ Modes: 25 │ LR: 0.01000
# Epoch 96/500 │ Loss: -0.0154 │ H_chain: 3.16 │ Modes: 25 │ LR: 0.01000
# Epoch 97/500 │ Loss: -0.0494 │ H_chain: 3.19 │ Modes: 25 │ LR: 0.01000
# Epoch 98/500 │ Loss: -0.0303 │ H_chain: 3.16 │ Modes: 24 │ LR: 0.01000
# Epoch 99/500 │ Loss: -0.0361 │ H_chain: 3.17 │ Modes: 24 │ LR: 0.01000
# Epoch 100/500 │ Loss: -0.0450 │ H_chain: 3.17 │ Modes: 24 │ LR: 0.01000
# Epoch 101/500 │ Loss: -0.0564 │ H_chain: 3.17 │ Modes: 24 │ LR: 0.01000
# Epoch 102/500 │ Loss: -0.0652 │ H_chain: 3.17 │ Modes: 24 │ LR: 0.01000
# Epoch 103/500 │ Loss: -0.0807 │ H_chain: 3.18 │ Modes: 23 │ LR: 0.01000
# Epoch 104/500 │ Loss: -0.0623 │ H_chain: 3.15 │ Modes: 23 │ LR: 0.01000
# Epoch 105/500 │ Loss: -0.0798 │ H_chain: 3.16 │ Modes: 23 │ LR: 0.01000
# Epoch 106/500 │ Loss: -0.1195 │ H_chain: 3.18 │ Modes: 22 │ LR: 0.01000
# Epoch 107/500 │ Loss: -0.1287 │ H_chain: 3.18 │ Modes: 22 │ LR: 0.01000
# Epoch 108/500 │ Loss: -0.1413 │ H_chain: 3.16 │ Modes: 21 │ LR: 0.01000
# Epoch 109/500 │ Loss: -0.1845 │ H_chain: 3.19 │ Modes: 21 │ LR: 0.01000
# Epoch 110/500 │ Loss: -0.1831 │ H_chain: 3.19 │ Modes: 20 │ LR: 0.01000
# Epoch 111/500 │ Loss: -0.1746 │ H_chain: 3.16 │ Modes: 19 │ LR: 0.01000
# Epoch 112/500 │ Loss: -0.2214 │ H_chain: 3.20 │ Modes: 19 │ LR: 0.01000
# Epoch 113/500 │ Loss: -0.2179 │ H_chain: 3.15 │ Modes: 18 │ LR: 0.01000
# Epoch 114/500 │ Loss: -0.2386 │ H_chain: 3.18 │ Modes: 18 │ LR: 0.01000
# Epoch 115/500 │ Loss: -0.2440 │ H_chain: 3.18 │ Modes: 17 │ LR: 0.01000
# Epoch 116/500 │ Loss: -0.2612 │ H_chain: 3.16 │ Modes: 17 │ LR: 0.01000
# Epoch 117/500 │ Loss: -0.2669 │ H_chain: 3.18 │ Modes: 16 │ LR: 0.01000
# Epoch 118/500 │ Loss: -0.2749 │ H_chain: 3.18 │ Modes: 16 │ LR: 0.01000
# Epoch 119/500 │ Loss: -0.2625 │ H_chain: 3.16 │ Modes: 16 │ LR: 0.01000
# Epoch 120/500 │ Loss: -0.2662 │ H_chain: 3.16 │ Modes: 15 │ LR: 0.01000
# Epoch 121/500 │ Loss: -0.2283 │ H_chain: 3.15 │ Modes: 14 │ LR: 0.01000
# Epoch 122/500 │ Loss: -0.2406 │ H_chain: 3.17 │ Modes: 14 │ LR: 0.01000
# Epoch 123/500 │ Loss: -0.2203 │ H_chain: 3.16 │ Modes: 14 │ LR: 0.01000
# Epoch 124/500 │ Loss: -0.2104 │ H_chain: 3.15 │ Modes: 14 │ LR: 0.01000
# Epoch 125/500 │ Loss: -0.1898 │ H_chain: 3.15 │ Modes: 13 │ LR: 0.01000
# Epoch 126/500 │ Loss: -0.1922 │ H_chain: 3.18 │ Modes: 13 │ LR: 0.01000
# Epoch 127/500 │ Loss: -0.1800 │ H_chain: 3.14 │ Modes: 13 │ LR: 0.01000
# Epoch 128/500 │ Loss: -0.1691 │ H_chain: 3.16 │ Modes: 13 │ LR: 0.01000
# Epoch 129/500 │ Loss: -0.1521 │ H_chain: 3.16 │ Modes: 13 │ LR: 0.01000
# Epoch 130/500 │ Loss: -0.1665 │ H_chain: 3.14 │ Modes: 13 │ LR: 0.01000
# Epoch 131/500 │ Loss: -0.1433 │ H_chain: 3.16 │ Modes: 12 │ LR: 0.01000
# Epoch 132/500 │ Loss: -0.1412 │ H_chain: 3.15 │ Modes: 12 │ LR: 0.01000
# Epoch 133/500 │ Loss: -0.1487 │ H_chain: 3.17 │ Modes: 12 │ LR: 0.01000
# Epoch 134/500 │ Loss: -0.1372 │ H_chain: 3.16 │ Modes: 12 │ LR: 0.01000
# Epoch 135/500 │ Loss: -0.1351 │ H_chain: 3.16 │ Modes: 12 │ LR: 0.01000
# Epoch 136/500 │ Loss: -0.1276 │ H_chain: 3.17 │ Modes: 12 │ LR: 0.01000
# Epoch 137/500 │ Loss: -0.1070 │ H_chain: 3.15 │ Modes: 12 │ LR: 0.01000
# Epoch 138/500 │ Loss: -0.0937 │ H_chain: 3.16 │ Modes: 12 │ LR: 0.01000
# Epoch 139/500 │ Loss: -0.1006 │ H_chain: 3.16 │ Modes: 12 │ LR: 0.01000
# Epoch 140/500 │ Loss: -0.1137 │ H_chain: 3.17 │ Modes: 12 │ LR: 0.01000
# Epoch 141/500 │ Loss: -0.1084 │ H_chain: 3.16 │ Modes: 12 │ LR: 0.01000
# Epoch 142/500 │ Loss: -0.1082 │ H_chain: 3.17 │ Modes: 12 │ LR: 0.01000
# Epoch 143/500 │ Loss: -0.0712 │ H_chain: 3.15 │ Modes: 11 │ LR: 0.01000
# Epoch 144/500 │ Loss: -0.0873 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 145/500 │ Loss: -0.0816 │ H_chain: 3.16 │ Modes: 12 │ LR: 0.01000
# Epoch 146/500 │ Loss: -0.0864 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.01000
# Epoch 147/500 │ Loss: -0.0829 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 148/500 │ Loss: -0.0760 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 149/500 │ Loss: -0.0699 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 150/500 │ Loss: -0.0804 │ H_chain: 3.15 │ Modes: 11 │ LR: 0.01000
# Epoch 151/500 │ Loss: -0.0905 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.01000
# Epoch 152/500 │ Loss: -0.0674 │ H_chain: 3.15 │ Modes: 11 │ LR: 0.01000
# Epoch 153/500 │ Loss: -0.0730 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 154/500 │ Loss: -0.0694 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 155/500 │ Loss: -0.0585 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 156/500 │ Loss: -0.0536 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 157/500 │ Loss: -0.0706 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.01000
# Epoch 158/500 │ Loss: -0.0627 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.01000
# Epoch 159/500 │ Loss: -0.0529 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 160/500 │ Loss: -0.0486 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 161/500 │ Loss: -0.0427 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 162/500 │ Loss: -0.0480 │ H_chain: 3.15 │ Modes: 11 │ LR: 0.01000
# Epoch 163/500 │ Loss: -0.0488 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.01000
# Epoch 164/500 │ Loss: -0.0422 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 165/500 │ Loss: -0.0520 │ H_chain: 3.15 │ Modes: 11 │ LR: 0.01000
# Epoch 166/500 │ Loss: -0.0443 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 167/500 │ Loss: -0.0333 │ H_chain: 3.15 │ Modes: 11 │ LR: 0.01000
# Epoch 168/500 │ Loss: -0.0492 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.01000
# Epoch 169/500 │ Loss: -0.0346 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 170/500 │ Loss: -0.0325 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 171/500 │ Loss: -0.0529 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 172/500 │ Loss: -0.0398 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 173/500 │ Loss: -0.0381 │ H_chain: 3.15 │ Modes: 11 │ LR: 0.01000
# Epoch 174/500 │ Loss: -0.0270 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 175/500 │ Loss: -0.0359 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.01000
# Epoch 176/500 │ Loss: -0.0305 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.00999
# Epoch 177/500 │ Loss: -0.0372 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.00999
# Epoch 178/500 │ Loss: -0.0378 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.00999
# Epoch 179/500 │ Loss: -0.0470 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.00999
# Epoch 180/500 │ Loss: -0.0295 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.00999
# Epoch 181/500 │ Loss: -0.0424 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.00999
# Epoch 182/500 │ Loss: -0.0374 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.00999
# Epoch 183/500 │ Loss: -0.0357 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.00999
# Epoch 184/500 │ Loss: -0.0174 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00999
# Epoch 185/500 │ Loss: -0.0160 │ H_chain: 3.15 │ Modes: 10 │ LR: 0.00999
# Epoch 186/500 │ Loss: -0.0307 │ H_chain: 3.15 │ Modes: 11 │ LR: 0.00999
# Epoch 187/500 │ Loss: -0.0270 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.00998
# Epoch 188/500 │ Loss: -0.0329 │ H_chain: 3.17 │ Modes: 11 │ LR: 0.00998
# Epoch 189/500 │ Loss: -0.0180 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00998
# Epoch 190/500 │ Loss: -0.0204 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00998
# Epoch 191/500 │ Loss: -0.0272 │ H_chain: 3.16 │ Modes: 11 │ LR: 0.00998
# Epoch 192/500 │ Loss: -0.0141 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00997
# Epoch 193/500 │ Loss: -0.0082 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00997
# Epoch 194/500 │ Loss: -0.0212 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00997
# Epoch 195/500 │ Loss: -0.0163 │ H_chain: 3.15 │ Modes: 10 │ LR: 0.00996
# Epoch 196/500 │ Loss: -0.0259 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00996
# Epoch 197/500 │ Loss: -0.0241 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00996
# Epoch 198/500 │ Loss: -0.0272 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00995
# Epoch 199/500 │ Loss: -0.0251 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00995
# Epoch 200/500 │ Loss: -0.0181 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00994
# Epoch 201/500 │ Loss: -0.0284 │ H_chain: 3.18 │ Modes: 10 │ LR: 0.00993
# Epoch 202/500 │ Loss: -0.0187 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00993
# Epoch 203/500 │ Loss: -0.0200 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00992
# Epoch 204/500 │ Loss: -0.0203 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00991
# Epoch 205/500 │ Loss: -0.0290 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00990
# Epoch 206/500 │ Loss: -0.0154 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00989
# Epoch 207/500 │ Loss: -0.0175 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00988
# Epoch 208/500 │ Loss: -0.0117 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00987
# Epoch 209/500 │ Loss: -0.0247 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00985
# Epoch 210/500 │ Loss: -0.0096 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00984
# Epoch 211/500 │ Loss: -0.0147 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00982
# Epoch 212/500 │ Loss: -0.0058 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00980
# Epoch 213/500 │ Loss: -0.0106 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00978
# Epoch 214/500 │ Loss: -0.0192 │ H_chain: 3.15 │ Modes: 10 │ LR: 0.00976
# Epoch 215/500 │ Loss: -0.0117 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00974
# Epoch 216/500 │ Loss: -0.0229 │ H_chain: 3.18 │ Modes: 10 │ LR: 0.00971
# Epoch 217/500 │ Loss: -0.0147 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00968
# Epoch 218/500 │ Loss: -0.0088 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00965
# Epoch 219/500 │ Loss: -0.0188 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00961
# Epoch 220/500 │ Loss: -0.0192 │ H_chain: 3.18 │ Modes: 10 │ LR: 0.00957
# Epoch 221/500 │ Loss: -0.0080 │ H_chain: 3.16 │ Modes: 10 │ LR: 0.00953
# Epoch 222/500 │ Loss: -0.0168 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.
│ H_chain: 3.17 │ Modes: 10 │ LR: 0.00100
# Epoch 500/500 │ Loss: -0.0179 │ H_chain: 3.17 │ Modes: 10 │ LR: 0.00100
# CPU times: user 3min 37s, sys: 1.32 s, total: 3min 39s
# Wall time: 3min 40s

# %%
import matplotlib.pyplot as plt

epochs = list(metrics_amp.keys())
loss_vals = [metrics_amp[e]['loss_amp'] for e in epochs]
entropy_vals = [metrics_amp[e]['H_chain'] for e in epochs]
mode_vals = [metrics_amp[e]['mode_count'] for e in epochs]
lr_vals = [metrics_amp[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots()

# Left y-axis: CD loss
ax1.plot(epochs, loss_vals, label="Amplitude CD Loss", color="tab:blue")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Amplitude CD Loss", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

# Right y-axis: Entropy
ax2 = ax1.twinx()
ax2.plot(epochs, entropy_vals, label="Chain Entropy", color="tab:orange")
ax2.set_ylabel("Chain Entropy", color="tab:orange")
ax2.tick_params(axis="y", labelcolor="tab:orange")

# Third axis: Mode count (offset further right)
ax3 = ax1.twinx()
ax3.spines["right"].set_position(("axes", 1.2))
ax3.plot(epochs, mode_vals, label="Estimated Mode Count", color="tab:green")
ax3.set_ylabel("Mode Count", color="tab:green")
ax3.tick_params(axis="y", labelcolor="tab:green")

# Fourth axis: Learning rate (even further right)
ax4 = ax1.twinx()
ax4.spines["right"].set_position(("axes", 1.4))
ax4.plot(epochs, lr_vals, label="Learning Rate", color="tab:red")
ax4.set_ylabel("Learning Rate", color="tab:red")
ax4.tick_params(axis="y", labelcolor="tab:red")

plt.title("CD Loss vs. Entropy vs. Mode Count vs. Learning Rate")
plt.show()

# %%
def get_cosine_schedule(T_high, T_low, n_steps):
    steps = jnp.arange(n_steps, dtype=jnp.float32)
    cos = 0.5 * (1 + jnp.cos(jnp.pi * steps / (n_steps - 1)))
    return T_low + (T_high - T_low) * cos

def get_exponential_schedule(T_high, T_low, n_steps):
    steps = jnp.arange(n_steps, dtype=jnp.float32)
    exp = jnp.exp(-steps / (n_steps / 10))  # decay factor
    return T_low + (T_high - T_low) * exp

cosine_schedule = get_cosine_schedule(2.0, 0.1, 500)
exponential_schedule = get_exponential_schedule(2.0, 0.01, 500)
constant_schedule = jnp.ones(500) * 1.2


key_sample = PRNGKey(12345)

samples_amp = model_amp.apply(
    {"params": state_amp.params},
    n_samples=10_000,
    T_schedule=exponential_schedule,
    key=key_sample,
    method=RBM.generate
)

sampled_freq_amp = samples_amp.mean(0)
sampled_freq_amp
# Out:
# Array([0.11009999, 0.1542    , 0.1191    , 0.1039    , 0.0994    ,
#        0.07889999, 0.0695    , 0.0641    , 0.1125    , 0.0883    ],      dtype=float32)

# %%
spin_counts = samples_amp.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(12), align='left', edgecolor='black')
plt.xticks(range(11))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
# Plotting comparison
plt.figure(figsize=(10, 5))
x = np.arange(visible_units)
width = 0.35

plt.bar(x - width/2, empirical_freq_amp, width, label="Empirical", alpha=0.7)
plt.bar(x + width/2, sampled_freq_amp, width, label="Sampled", alpha=0.7)
plt.axhline(1 / visible_units, linestyle='--', color='gray', label=f'1/{visible_units} reference')
plt.xlabel("Visible Unit Index")
plt.ylabel("Mean Activation Frequency")
plt.title("Comparison: Empirical vs Sampled Frequencies")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
