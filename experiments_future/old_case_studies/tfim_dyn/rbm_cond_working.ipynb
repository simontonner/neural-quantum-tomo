# %%
# %reload_ext autoreload
# %autoreload 2

from lib.data_loading import load_measurements, MixedDataLoader

####

from pathlib import Path
from typing import Tuple, Dict, Any, Callable

import jax
import jax.lax
import jax.numpy as jnp
from jax.random import PRNGKey
import optax
from flax.training.train_state import TrainState
from flax import linen as nn

import matplotlib.pyplot as plt

data_dir = Path("data")
model_dir = "./models"

print(f"Data resides in                         : {data_dir}")
# Out:
# Data resides in                         : data

# %%
class ConditionalRBM(nn.Module):
    num_visible: int
    num_hidden: int
    conditioner_width: int = 64
    k: int = 1
    T: float = 1.0

    def setup(self):
        self.W = self.param("W", nn.initializers.normal(0.01), (self.num_visible, self.num_hidden))
        self.b = self.param("b", nn.initializers.zeros, (self.num_visible,))
        self.c = self.param("c", nn.initializers.zeros, (self.num_hidden,))

    @nn.compact
    def conditioner(self, field: jnp.ndarray) -> Tuple[jnp.ndarray, jnp.ndarray, jnp.ndarray, jnp.ndarray]:
        # field shape: (B,) or (B, 1)
        x = field[:, None] if field.ndim == 1 else field       # ensure shape (B, 1)
        x = nn.Dense(self.conditioner_width)(x)                # (B, conditioner_width)
        x = nn.tanh(x)
        x = nn.Dense(2 * (self.num_visible + self.num_hidden))(x)  # (B, 2*(N+H))
        split_indices = [self.num_visible, 2 * self.num_visible, 2 * self.num_visible + self.num_hidden]
        gamma_b, beta_b, gamma_c, beta_c = jnp.split(x, split_indices, axis=-1)
        return gamma_b, beta_b, gamma_c, beta_c

    @nn.nowrap
    def forward_conditioner(self, field: jnp.ndarray) -> Tuple[jnp.ndarray, jnp.ndarray, jnp.ndarray, jnp.ndarray]:
        return self.conditioner(field)

    @staticmethod
    def _free_energy(v, W, b, c) -> jnp.ndarray:
        return -(v @ b) - jnp.sum(jax.nn.softplus(v @ W + c), -1)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c) / T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b) / T)).astype(jnp.float32)
        return v, key

    def __call__(self, batch: Tuple[jnp.ndarray, jnp.ndarray], aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        measurement, field = batch  # (B, N), (B,)
        gamma_b, beta_b, gamma_c, beta_c = self.conditioner(field)  # all shape (B, N/H)

        b_mod = (1 + gamma_b) * self.b + beta_b  # (B, N)
        c_mod = (1 + gamma_c) * self.c + beta_c  # (B, H)

        key, key_init = jax.random.split(aux_vars["key"])
        gibbs_chain = jax.random.bernoulli(key_init, 0.5, shape=measurement.shape).astype(jnp.float32)

        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W, b_mod, c_mod, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (gibbs_chain, key))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain)

        free_energy_data  = jax.vmap(self._free_energy, in_axes=(0, None, 0, 0))(measurement, self.W, b_mod, c_mod)
        free_energy_model = jax.vmap(self._free_energy, in_axes=(0, None, 0, 0))(gibbs_chain, self.W, b_mod, c_mod)

        free_energy_delta = free_energy_data - free_energy_model
        free_energy_mean = jnp.mean(free_energy_delta)
        free_energy_std  = jnp.std(free_energy_delta)

        l2_regularization = (
                jnp.sum((self.b[None, :] - b_mod) ** 2) +
                jnp.sum((self.c[None, :] - c_mod) ** 2)
        )

        loss = free_energy_mean + aux_vars["l2_strength"] * l2_regularization

        aux_vars_out = {
            "key": key,
            "free_energy_mean": free_energy_mean,
            "free_energy_std": free_energy_std,
        }

        return loss, aux_vars_out

    @nn.nowrap
    def free_energy(self, v: jnp.ndarray) -> jnp.ndarray:
        return self._free_energy(v)

    @nn.nowrap
    def generate(self, field: jnp.ndarray, T_schedule: jnp.ndarray, key: PRNGKey) -> Tuple[jnp.ndarray, PRNGKey]:
        gamma_b, beta_b, gamma_c, beta_c = self.conditioner(field)

        b_mod = (1 + gamma_b) * self.b + beta_b
        c_mod = (1 + gamma_c) * self.c + beta_c

        batch_size = field.shape[0]
        key, key_init = jax.random.split(key, 2)

        gibbs_chain = jax.random.bernoulli(key_init, 0.5, shape=(batch_size, self.num_visible)).astype(jnp.float32)
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W, b_mod, c_mod, T_schedule[i])
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (gibbs_chain, key))

        return gibbs_chain, key

# %%
@jax.jit
def train_step(
        state: TrainState,
        batch: Tuple[jnp.ndarray, jnp.ndarray],
        aux_vars: Dict[str, Any]) -> Tuple[TrainState, jnp.ndarray, Dict[str, Any]]:

    loss_fn = lambda params: state.apply_fn({'params': params}, batch, aux_vars)
    (loss, aux_vars), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    state = state.apply_gradients(grads=grads)
    return state, loss, aux_vars


def train(
        state: TrainState,
        loader: MixedDataLoader,
        num_epochs: int,
        key: PRNGKey,
        l2_strength: float,
        lr_schedule_fn: Callable[[int], float]) -> Tuple[TrainState, Dict[int, float]]:

    metrics: Dict[int, Any] = {}
    gibbs_chain = None

    for epoch in range(num_epochs):
        tot_loss = 0.0

        for batch_bits, batch_field in loader:
            if gibbs_chain is None:
                gibbs_chain = jax.random.bernoulli(key, 0.5, shape=batch_bits.shape).astype(jnp.float32)

            key, subkey = jax.random.split(key)
            aux_vars = {
                "key": subkey,
                "l2_strength": l2_strength,
            }

            batch = (batch_bits, batch_field)

            state, loss, aux_vars = train_step(state, batch, aux_vars)
            key = aux_vars["key"]
            free_energy_mean = aux_vars["free_energy_mean"]
            free_energy_std = aux_vars["free_energy_std"]

            tot_loss += float(loss)

        avg_loss = tot_loss / len(loader)
        lr = lr_schedule_fn(state.step)

        metrics[epoch] = dict(
            loss=avg_loss,
            free_energy_mean=free_energy_mean,
            free_energy_var=free_energy_std,
            lr=lr
        )

        print(f"Epoch {epoch+1}/{num_epochs} │ "
              f"Loss: {avg_loss:+.4f} │ "
              f"Free En. Mean: {free_energy_mean:.4f} │ "
              f"Free En. STD: {free_energy_std:.4f} │ "
              f"Learning Rate: {lr:.5f}")

    return state, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2

    curve_fn = lambda step: low + (high - low) / (1 + jnp.exp(falloff * (jnp.minimum(step, steps) - center_step)))
    return curve_fn

# %%
file_names = [
    "tfim_h1.00_3x3_10000.txt",
    "tfim_h2.00_3x3_10000.txt",
    "tfim_h2.80_3x3_10000.txt",
    "tfim_h3.00_3x3_10000.txt",
    "tfim_h3.30_3x3_10000.txt",
    "tfim_h3.60_3x3_10000.txt",
    "tfim_h4.00_3x3_10000.txt",
    "tfim_h5.00_3x3_10000.txt",
    "tfim_h6.00_3x3_10000.txt",
    "tfim_h7.00_3x3_10000.txt",
]

bits_list = []
fields_list = []
for fn in file_names:
    bits, field = load_measurements(data_dir / fn)
    bits_list.append(bits)   # (N, num_qubits)
    fields_list.append(field) # (N,)

bits  = jnp.concatenate(bits_list,  axis=0)  # (2*N, num_qubits)
fields = jnp.concatenate(fields_list, axis=0)
# Out:
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 14544.24it/s]
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 18806.65it/s]
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 19739.67it/s]
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 18050.67it/s]
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 19748.68it/s]
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 17848.91it/s]
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 19555.47it/s]
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 18127.47it/s]
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 19156.91it/s]
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 19301.03it/s]

# %%
batch_size        = 1024
num_visible       = 9
num_hidden        = 9
conditioner_width = 32
num_epochs        = 100
k_steps           = 100
init_lr           = 1e-2
final_lr          = init_lr * 0.1
l2_strength       = 0.0

key = jax.random.PRNGKey(0)
key, key_params, key_dummy = jax.random.split(key, 3)

model = ConditionalRBM(
    num_visible=num_visible,
    num_hidden=num_hidden,
    conditioner_width=conditioner_width,
    k=k_steps
)

# DUMMY DATA for model init
bits_dummy   = jnp.zeros((batch_size, num_visible), dtype=jnp.float32)
fields_dummy = jnp.zeros((batch_size,), dtype=jnp.float32)
batch_dummy  = (bits_dummy, fields_dummy)
aux_vars_dummy = { "key": key_dummy, "l2_strength": l2_strength }

variables = model.init({"params": key_params}, batch_dummy, aux_vars_dummy)

# Construct loader
loader = MixedDataLoader(bits=bits, field=fields, batch_size=batch_size)

# Learning rate schedule
schedule_steps = num_epochs * len(loader)
lr_schedule_fn = get_sigmoid_curve(high=init_lr, low=final_lr, steps=schedule_steps, falloff=0.0005)
optim = optax.adam(lr_schedule_fn)

# Wrap in training state
state = TrainState.create(apply_fn=model.apply, params=variables["params"], tx=optim)

# Kick off training!
state, metrics = train(state, loader, num_epochs, key, l2_strength, lr_schedule_fn)
# Out:
# Epoch 1/100 │ Loss: +0.0005 │ Free En. Mean: -0.4107 │ Free En. STD: 0.8645 │ Learning Rate: 0.00925
# Epoch 2/100 │ Loss: -0.2084 │ Free En. Mean: -0.1809 │ Free En. STD: 2.0522 │ Learning Rate: 0.00922
# Epoch 3/100 │ Loss: -0.1044 │ Free En. Mean: -0.1274 │ Free En. STD: 1.7960 │ Learning Rate: 0.00918
# Epoch 4/100 │ Loss: -0.0457 │ Free En. Mean: -0.1102 │ Free En. STD: 1.9707 │ Learning Rate: 0.00914
# Epoch 5/100 │ Loss: -0.0234 │ Free En. Mean: -0.1537 │ Free En. STD: 1.9389 │ Learning Rate: 0.00911
# Epoch 6/100 │ Loss: -0.0149 │ Free En. Mean: -0.0464 │ Free En. STD: 1.9924 │ Learning Rate: 0.00907
# Epoch 7/100 │ Loss: -0.0050 │ Free En. Mean: -0.1156 │ Free En. STD: 1.9117 │ Learning Rate: 0.00902
# Epoch 8/100 │ Loss: -0.0018 │ Free En. Mean: -0.0134 │ Free En. STD: 2.0350 │ Learning Rate: 0.00898
# Epoch 9/100 │ Loss: +0.0052 │ Free En. Mean: 0.0345 │ Free En. STD: 1.8658 │ Learning Rate: 0.00894
# Epoch 10/100 │ Loss: -0.0005 │ Free En. Mean: 0.0008 │ Free En. STD: 1.8535 │ Learning Rate: 0.00889
# Epoch 11/100 │ Loss: +0.0041 │ Free En. Mean: -0.0332 │ Free En. STD: 1.8247 │ Learning Rate: 0.00884
# Epoch 12/100 │ Loss: +0.0057 │ Free En. Mean: 0.0348 │ Free En. STD: 1.8415 │ Learning Rate: 0.00879
# Epoch 13/100 │ Loss: +0.0174 │ Free En. Mean: 0.0624 │ Free En. STD: 1.9954 │ Learning Rate: 0.00874
# Epoch 14/100 │ Loss: +0.0061 │ Free En. Mean: 0.0977 │ Free En. STD: 1.9881 │ Learning Rate: 0.00868
# Epoch 15/100 │ Loss: +0.0161 │ Free En. Mean: 0.0575 │ Free En. STD: 2.0157 │ Learning Rate: 0.00863
# Epoch 16/100 │ Loss: +0.0121 │ Free En. Mean: 0.0239 │ Free En. STD: 1.8505 │ Learning Rate: 0.00857
# Epoch 17/100 │ Loss: +0.0126 │ Free En. Mean: 0.0732 │ Free En. STD: 1.8254 │ Learning Rate: 0.00851
# Epoch 18/100 │ Loss: +0.0112 │ Free En. Mean: -0.0912 │ Free En. STD: 1.9987 │ Learning Rate: 0.00845
# Epoch 19/100 │ Loss: +0.0209 │ Free En. Mean: 0.0168 │ Free En. STD: 1.8822 │ Learning Rate: 0.00838
# Epoch 20/100 │ Loss: +0.0219 │ Free En. Mean: 0.2292 │ Free En. STD: 2.1307 │ Learning Rate: 0.00832
# Epoch 21/100 │ Loss: +0.0153 │ Free En. Mean: 0.1306 │ Free En. STD: 1.9794 │ Learning Rate: 0.00825
# Epoch 22/100 │ Loss: +0.0185 │ Free En. Mean: 0.0569 │ Free En. STD: 1.9678 │ Learning Rate: 0.00818
# Epoch 23/100 │ Loss: +0.0197 │ Free En. Mean: 0.0360 │ Free En. STD: 1.9420 │ Learning Rate: 0.00811
# Epoch 24/100 │ Loss: +0.0106 │ Free En. Mean: -0.0069 │ Free En. STD: 1.9057 │ Learning Rate: 0.00803
# Epoch 25/100 │ Loss: +0.0134 │ Free En. Mean: -0.1106 │ Free En. STD: 1.7990 │ Learning Rate: 0.00796
# Epoch 26/100 │ Loss: +0.0206 │ Free En. Mean: 0.0611 │ Free En. STD: 1.7659 │ Learning Rate: 0.00788
# Epoch 27/100 │ Loss: +0.0152 │ Free En. Mean: 0.1071 │ Free En. STD: 2.0446 │ Learning Rate: 0.00780
# Epoch 28/100 │ Loss: +0.0155 │ Free En. Mean: -0.0214 │ Free En. STD: 1.7465 │ Learning Rate: 0.00772
# Epoch 29/100 │ Loss: +0.0157 │ Free En. Mean: 0.2159 │ Free En. STD: 1.9305 │ Learning Rate: 0.00763
# Epoch 30/100 │ Loss: +0.0095 │ Free En. Mean: -0.1295 │ Free En. STD: 1.7639 │ Learning Rate: 0.00754
# Epoch 31/100 │ Loss: +0.0177 │ Free En. Mean: 0.1482 │ Free En. STD: 2.0288 │ Learning Rate: 0.00746
# Epoch 32/100 │ Loss: +0.0165 │ Free En. Mean: 0.0352 │ Free En. STD: 1.9443 │ Learning Rate: 0.00737
# Epoch 33/100 │ Loss: +0.0141 │ Free En. Mean: 0.0937 │ Free En. STD: 1.9413 │ Learning Rate: 0.00727
# Epoch 34/100 │ Loss: +0.0164 │ Free En. Mean: -0.0055 │ Free En. STD: 1.9237 │ Learning Rate: 0.00718
# Epoch 35/100 │ Loss: +0.0173 │ Free En. Mean: 0.0482 │ Free En. STD: 1.9240 │ Learning Rate: 0.00708
# Epoch 36/100 │ Loss: +0.0181 │ Free En. Mean: 0.0942 │ Free En. STD: 1.9730 │ Learning Rate: 0.00699
# Epoch 37/100 │ Loss: +0.0138 │ Free En. Mean: 0.0716 │ Free En. STD: 1.9142 │ Learning Rate: 0.00689
# Epoch 38/100 │ Loss: +0.0134 │ Free En. Mean: -0.0279 │ Free En. STD: 1.8358 │ Learning Rate: 0.00679
# Epoch 39/100 │ Loss: +0.0130 │ Free En. Mean: 0.0376 │ Free En. STD: 1.9386 │ Learning Rate: 0.00668
# Epoch 40/100 │ Loss: +0.0108 │ Free En. Mean: -0.0316 │ Free En. STD: 1.8610 │ Learning Rate: 0.00658
# Epoch 41/100 │ Loss: +0.0210 │ Free En. Mean: -0.0237 │ Free En. STD: 1.8162 │ Learning Rate: 0.00648
# Epoch 42/100 │ Loss: +0.0110 │ Free En. Mean: -0.0711 │ Free En. STD: 1.8671 │ Learning Rate: 0.00637
# Epoch 43/100 │ Loss: +0.0169 │ Free En. Mean: -0.0443 │ Free En. STD: 1.8329 │ Learning Rate: 0.00626
# Epoch 44/100 │ Loss: +0.0113 │ Free En. Mean: -0.0150 │ Free En. STD: 1.9513 │ Learning Rate: 0.00616
# Epoch 45/100 │ Loss: +0.0145 │ Free En. Mean: 0.0375 │ Free En. STD: 1.9810 │ Learning Rate: 0.00605
# Epoch 46/100 │ Loss: +0.0198 │ Free En. Mean: -0.0602 │ Free En. STD: 1.9428 │ Learning Rate: 0.00594
# Epoch 47/100 │ Loss: +0.0096 │ Free En. Mean: 0.0222 │ Free En. STD: 1.8542 │ Learning Rate: 0.00583
# Epoch 48/100 │ Loss: +0.0155 │ Free En. Mean: 0.1475 │ Free En. STD: 1.8687 │ Learning Rate: 0.00572
# Epoch 49/100 │ Loss: +0.0108 │ Free En. Mean: 0.0148 │ Free En. STD: 1.8151 │ Learning Rate: 0.00561
# Epoch 50/100 │ Loss: +0.0171 │ Free En. Mean: 0.0633 │ Free En. STD: 1.7865 │ Learning Rate: 0.00550
# Epoch 51/100 │ Loss: +0.0086 │ Free En. Mean: 0.0379 │ Free En. STD: 1.8772 │ Learning Rate: 0.00539
# Epoch 52/100 │ Loss: +0.0072 │ Free En. Mean: 0.0643 │ Free En. STD: 1.7668 │ Learning Rate: 0.00528
# Epoch 53/100 │ Loss: +0.0088 │ Free En. Mean: 0.1664 │ Free En. STD: 1.8335 │ Learning Rate: 0.00517
# Epoch 54/100 │ Loss: +0.0091 │ Free En. Mean: -0.0799 │ Free En. STD: 1.7734 │ Learning Rate: 0.00506
# Epoch 55/100 │ Loss: +0.0063 │ Free En. Mean: -0.0150 │ Free En. STD: 1.9915 │ Learning Rate: 0.00495
# Epoch 56/100 │ Loss: +0.0056 │ Free En. Mean: 0.0749 │ Free En. STD: 2.0193 │ Learning Rate: 0.00484
# Epoch 57/100 │ Loss: +0.0098 │ Free En. Mean: -0.0023 │ Free En. STD: 1.9306 │ Learning Rate: 0.00474
# Epoch 58/100 │ Loss: +0.0086 │ Free En. Mean: -0.0333 │ Free En. STD: 1.7142 │ Learning Rate: 0.00463
# Epoch 59/100 │ Loss: +0.0027 │ Free En. Mean: 0.0479 │ Free En. STD: 1.8380 │ Learning Rate: 0.00452
# Epoch 60/100 │ Loss: +0.0032 │ Free En. Mean: -0.0195 │ Free En. STD: 1.8601 │ Learning Rate: 0.00442
# Epoch 61/100 │ Loss: +0.0153 │ Free En. Mean: 0.1287 │ Free En. STD: 1.8734 │ Learning Rate: 0.00432
# Epoch 62/100 │ Loss: +0.0097 │ Free En. Mean: -0.0069 │ Free En. STD: 1.9941 │ Learning Rate: 0.00421
# Epoch 63/100 │ Loss: +0.0059 │ Free En. Mean: -0.0469 │ Free En. STD: 1.8986 │ Learning Rate: 0.00411
# Epoch 64/100 │ Loss: +0.0006 │ Free En. Mean: -0.1577 │ Free En. STD: 1.8745 │ Learning Rate: 0.00401
# Epoch 65/100 │ Loss: +0.0051 │ Free En. Mean: 0.1076 │ Free En. STD: 1.7516 │ Learning Rate: 0.00392
# Epoch 66/100 │ Loss: +0.0070 │ Free En. Mean: 0.0071 │ Free En. STD: 2.0360 │ Learning Rate: 0.00382
# Epoch 67/100 │ Loss: +0.0083 │ Free En. Mean: -0.0003 │ Free En. STD: 1.9389 │ Learning Rate: 0.00373
# Epoch 68/100 │ Loss: +0.0009 │ Free En. Mean: 0.1295 │ Free En. STD: 2.0701 │ Learning Rate: 0.00363
# Epoch 69/100 │ Loss: +0.0081 │ Free En. Mean: -0.0044 │ Free En. STD: 1.8569 │ Learning Rate: 0.00354
# Epoch 70/100 │ Loss: +0.0089 │ Free En. Mean: 0.0023 │ Free En. STD: 1.8103 │ Learning Rate: 0.00346
# Epoch 71/100 │ Loss: +0.0047 │ Free En. Mean: 0.0617 │ Free En. STD: 1.8603 │ Learning Rate: 0.00337
# Epoch 72/100 │ Loss: +0.0067 │ Free En. Mean: -0.0327 │ Free En. STD: 1.7796 │ Learning Rate: 0.00328
# Epoch 73/100 │ Loss: +0.0016 │ Free En. Mean: 0.0175 │ Free En. STD: 1.8958 │ Learning Rate: 0.00320
# Epoch 74/100 │ Loss: +0.0075 │ Free En. Mean: 0.0909 │ Free En. STD: 1.9479 │ Learning Rate: 0.00312
# Epoch 75/100 │ Loss: +0.0062 │ Free En. Mean: -0.0562 │ Free En. STD: 1.8658 │ Learning Rate: 0.00304
# Epoch 76/100 │ Loss: +0.0030 │ Free En. Mean: -0.0323 │ Free En. STD: 1.8485 │ Learning Rate: 0.00297
# Epoch 77/100 │ Loss: +0.0089 │ Free En. Mean: -0.0068 │ Free En. STD: 1.7852 │ Learning Rate: 0.00289
# Epoch 78/100 │ Loss: +0.0042 │ Free En. Mean: -0.1335 │ Free En. STD: 1.7452 │ Learning Rate: 0.00282
# Epoch 79/100 │ Loss: +0.0064 │ Free En. Mean: 0.0495 │ Free En. STD: 1.7180 │ Learning Rate: 0.00275
# Epoch 80/100 │ Loss: +0.0030 │ Free En. Mean: -0.0563 │ Free En. STD: 1.7867 │ Learning Rate: 0.00268
# Epoch 81/100 │ Loss: +0.0021 │ Free En. Mean: -0.0746 │ Free En. STD: 1.9239 │ Learning Rate: 0.00262
# Epoch 82/100 │ Loss: +0.0054 │ Free En. Mean: -0.0229 │ Free En. STD: 1.7650 │ Learning Rate: 0.00255
# Epoch 83/100 │ Loss: +0.0069 │ Free En. Mean: 0.1399 │ Free En. STD: 2.0377 │ Learning Rate: 0.00249
# Epoch 84/100 │ Loss: -0.0007 │ Free En. Mean: -0.0070 │ Free En. STD: 1.9521 │ Learning Rate: 0.00243
# Epoch 85/100 │ Loss: +0.0030 │ Free En. Mean: -0.0365 │ Free En. STD: 1.8370 │ Learning Rate: 0.00237
# Epoch 86/100 │ Loss: +0.0037 │ Free En. Mean: -0.0150 │ Free En. STD: 1.7288 │ Learning Rate: 0.00232
# Epoch 87/100 │ Loss: +0.0005 │ Free En. Mean: -0.0446 │ Free En. STD: 1.9017 │ Learning Rate: 0.00226
# Epoch 88/100 │ Loss: +0.0030 │ Free En. Mean: 0.0333 │ Free En. STD: 1.7320 │ Learning Rate: 0.00221
# Epoch 89/100 │ Loss: +0.0046 │ Free En. Mean: -0.0846 │ Free En. STD: 1.8947 │ Learning Rate: 0.00216
# Epoch 90/100 │ Loss: +0.0047 │ Free En. Mean: 0.1477 │ Free En. STD: 2.0349 │ Learning Rate: 0.00211
# Epoch 91/100 │ Loss: -0.0001 │ Free En. Mean: -0.0405 │ Free En. STD: 1.8384 │ Learning Rate: 0.00206
# Epoch 92/100 │ Loss: +0.0048 │ Free En. Mean: -0.0054 │ Free En. STD: 1.9315 │ Learning Rate: 0.00202
# Epoch 93/100 │ Loss: +0.0018 │ Free En. Mean: -0.0737 │ Free En. STD: 1.9503 │ Learning Rate: 0.00198
# Epoch 94/100 │ Loss: +0.0082 │ Free En. Mean: -0.0066 │ Free En. STD: 1.7581 │ Learning Rate: 0.00193
# Epoch 95/100 │ Loss: +0.0014 │ Free En. Mean: -0.0504 │ Free En. STD: 1.7704 │ Learning Rate: 0.00189
# Epoch 96/100 │ Loss: +0.0011 │ Free En. Mean: 0.0253 │ Free En. STD: 1.9085 │ Learning Rate: 0.00186
# Epoch 97/100 │ Loss: +0.0040 │ Free En. Mean: -0.0662 │ Free En. STD: 1.8260 │ Learning Rate: 0.00182
# Epoch 98/100 │ Loss: +0.0047 │ Free En. Mean: 0.0504 │ Free En. STD: 1.8801 │ Learning Rate: 0.00178
# Epoch 99/100 │ Loss: +0.0002 │ Free En. Mean: -0.1119 │ Free En. STD: 1.9011 │ Learning Rate: 0.00175
# Epoch 100/100 │ Loss: -0.0018 │ Free En. Mean: -0.1148 │ Free En. STD: 1.8574 │ Learning Rate: 0.00171

# %%
epochs = list(metrics.keys())

loss_vals = [metrics[e]['loss'] for e in epochs]
free_model_mean_vals = [metrics[e]['free_energy_mean'] for e in epochs]
free_model_var_vals = [metrics[e]['free_energy_var'] for e in epochs]
lr_vals = [metrics[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots(figsize=(11, 4))

ax1.plot(epochs, lr_vals, label="Learning Rate", color="tab:red")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Learning Rate", color="tab:red")
ax1.tick_params(axis="y", labelcolor="tab:red")

ax2 = ax1.twinx()
ax2.spines["right"].set_position(("axes", 1.00))
ax2.plot(epochs, loss_vals, label="Amplitude CD Loss", color="tab:blue")
ax2.set_ylabel("Loss", color="tab:blue")
ax2.tick_params(axis="y", labelcolor="tab:blue")

ax3 = ax1.twinx()
ax3.spines["right"].set_position(("axes", 1.1))
ax3.plot(epochs, free_model_var_vals, label="Free Energy Model Var", color="tab:green")
ax3.set_ylabel("Free Energy Model Var", color="tab:green")
ax3.tick_params(axis="y", labelcolor="tab:green")

ax4 = ax1.twinx()
ax4.spines["right"].set_position(("axes", 1.2))
ax4.plot(epochs, free_model_mean_vals, label="Free Energy Model Mean", color="tab:orange")
ax4.set_ylabel("Free Energy Model Mean", color="tab:orange")
ax4.tick_params(axis="y", labelcolor="tab:orange")

plt.tight_layout()
plt.show()

# %%
from jax.random import PRNGKey

# Sampling config
sampling_steps = 1000
T_schedule = jnp.full((sampling_steps,), 1.0, dtype=jnp.float32)

# Set the magnetic field to 2.8
num_samples = 10_000
# [1.0, 2.0, 2.8, 3.0, 3.3, 3.6, 4.0, 5.0, 6.0, 7.0]

field_value = 2.0
field = jnp.full((num_samples,), field_value, dtype=jnp.float32)

# Sampling key
key_sample = PRNGKey(1234)

# Generate samples using the trained model
samples, key_sample = model.apply(
    {"params": state.params},
    field,
    T_schedule,
    key_sample,
    method=ConditionalRBM.generate
)

# Analyze frequency of 1s per spin
sampled_freq = samples.mean(axis=0)
print(sampled_freq)
# Out:
# [0.53709996 0.5406     0.5399     0.5432     0.5369     0.5414
#  0.53709996 0.5365     0.54719996]

# %%
def magnetization_z(samples: jnp.ndarray) -> jnp.ndarray: # (num_samples, num_qubits)
    # making sure it is not unsigned when changing to -1 and +1 domain
    samples = samples.astype(jnp.float32)  # ensure float for division
    spins = 1 - 2 * samples  # map 0 -> +1, 1 -> -1
    sample_magnetisations = jnp.abs(spins.mean(axis=1)) # the .abs gives us the spontaneous magnetization
    total_magnetisation = sample_magnetisations.mean()
    return total_magnetisation  # mean over samples, gives us the global magnetization

mag_z = magnetization_z(samples)
mag_z
# Out:
# Array(0.808689, dtype=float32)

# %%
import flax

def amplitude_ratio_flip(
        model: ConditionalRBM,
        params: flax.core.FrozenDict,
        sample: jnp.ndarray,         # shape (batch_size, num_visible)
        flip_idx: int
) -> jnp.ndarray:
    # flip that one bit
    sample_flipped = sample.at[:, flip_idx].set(1 - sample[:, flip_idx])

    # compute F(v) and F(v') via apply+method
    F_ref  = model.apply({"params": params}, sample,        method=ConditionalRBM.free_energy)
    F_flip = model.apply({"params": params}, sample_flipped, method=ConditionalRBM.free_energy)

    # amplitude ratio = exp[(F(v) - F(v'))/2]
    return jnp.exp((F_ref - F_flip) / 2)


def magnetization_x(
        model: ConditionalRBM,
        params: flax.core.FrozenDict,
        samples: jnp.ndarray          # shape (batch_size, num_visible)
) -> jnp.ndarray:
    # for each qubit index i, get a vector of ratios shape (batch,)
    flip_fn = lambda i: amplitude_ratio_flip(model, params, samples, i)
    # vmap over the spin index axis → (num_visible, batch_size)
    qubit_ratios = jax.vmap(flip_fn)(jnp.arange(samples.shape[1]))
    # average over qubits *and* batch:
    return qubit_ratios.mean()


mag_x = magnetization_x(model, state.params, samples)
mag_x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 33
#      29     # average over qubits *and* batch:
#      30     return qubit_ratios.mean()
# ---> 33 mag_x = magnetization_x(model, state.params, samples)
#      34 mag_x
#
# Cell In[13], line 28, in magnetization_x(model, params, samples)
#      26 flip_fn = lambda i: amplitude_ratio_flip(model, params, samples, i)
#      27 # vmap over the spin index axis → (num_visible, batch_size)
# ---> 28 qubit_ratios = jax.vmap(flip_fn)(jnp.arange(samples.shape[1]))
#      29 # average over qubits *and* batch:
#      30 return qubit_ratios.mean()
#
#     [... skipping hidden 3 frame]
#
# Cell In[13], line 26, in magnetization_x.<locals>.<lambda>(i)
#      20 def magnetization_x(
#      21         model: ConditionalRBM,
#      22         params: flax.core.FrozenDict,
#      23         samples: jnp.ndarray          # shape (batch_size, num_visible)
#      24 ) -> jnp.ndarray:
#      25     # for each qubit index i, get a vector of ratios shape (batch,)
# ---> 26     flip_fn = lambda i: amplitude_ratio_flip(model, params, samples, i)
#      27     # vmap over the spin index axis → (num_visible, batch_size)
#      28     qubit_ratios = jax.vmap(flip_fn)(jnp.arange(samples.shape[1]))
#
# Cell In[13], line 13, in amplitude_ratio_flip(model, params, sample, flip_idx)
#      10 sample_flipped = sample.at[:, flip_idx].set(1 - sample[:, flip_idx])
#      12 # compute F(v) and F(v') via apply+method
# ---> 13 F_ref  = model.apply({"params": params}, sample,        method=ConditionalRBM.free_energy)
#      14 F_flip = model.apply({"params": params}, sample_flipped, method=ConditionalRBM.free_energy)
#      16 # amplitude ratio = exp[(F(v) - F(v'))/2]
#
#     [... skipping hidden 4 frame]
#
# Cell In[2], line 78, in ConditionalRBM.free_energy(self, v)
#      76 @nn.nowrap
#      77 def free_energy(self, v: jnp.ndarray) -> jnp.ndarray:
# ---> 78     return self._free_energy(v)
#
# TypeError: _free_energy() missing 3 required positional arguments: 'W', 'b', and 'c'
