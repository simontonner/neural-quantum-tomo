# %%
# %reload_ext autoreload
# %autoreload 2

from lib.data_loading import load_measurements, MixedDataLoader

####

from pathlib import Path
from typing import Tuple, Dict, Any, Callable
from itertools import combinations
from datetime import datetime

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import optax
from flax.training.train_state import TrainState
from flax.training import checkpoints
from flax import linen as nn

import matplotlib.pyplot as plt


data_dir = "data"
model_dir = Path("./models")
model_dir.mkdir(parents=True, exist_ok=True)

print(f"Data resides in        : {data_dir}")
print(f"Model will be saved to : {model_dir}")
# Out:
# Data resides in        : data
# Model will be saved to : models

# %%
class RBM(nn.Module):
    num_visible: int
    num_hidden: int
    k: int = 1
    T: float = 1.0

    def setup(self):
        self.W = self.param("W", nn.initializers.normal(0.01), (self.num_visible, self.num_hidden))
        self.b = self.param("b", nn.initializers.zeros, (self.num_visible,))
        self.c = self.param("c", nn.initializers.zeros, (self.num_hidden,))

    def __call__(self, data: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[jnp.ndarray, Dict[str, Any]]:
        gibbs_step_fn = lambda i, s: self._gibbs_step(s, self.W, self.b, self.c, self.T)
        gibbs_chain, key = jax.lax.fori_loop(0, self.k, gibbs_step_fn, (aux_vars["gibbs_chain"], aux_vars["key"]))
        gibbs_chain = jax.lax.stop_gradient(gibbs_chain)

        free_energy_data = jnp.mean(self._free_energy(data))
        free_energy_model = jnp.mean(self._free_energy(gibbs_chain))

        regularization = aux_vars["l2_strength"] * (jnp.sum(self.W**2) + jnp.sum(self.b**2) + jnp.sum(self.c**2))
        loss = free_energy_data - free_energy_model + regularization

        aux_vars = {
            "gibbs_chain": gibbs_chain,
            "key": key,
            "free_energy_data": free_energy_data,
            "free_energy_model": free_energy_model,
        }

        return loss, aux_vars

    def _free_energy(self, v):
        return -(v @ self.b) - jnp.sum(jax.nn.softplus(v @ self.W + self.c), -1)

    @staticmethod
    def _gibbs_step(state, W, b, c, T):
        v, key = state
        key, h_key, v_key = jax.random.split(key, 3)
        h = jax.random.bernoulli(h_key, jax.nn.sigmoid((v @ W + c)/T)).astype(jnp.float32)
        v = jax.random.bernoulli(v_key, jax.nn.sigmoid((h @ W.T + b)/T)).astype(jnp.float32)
        return v, key

    @nn.nowrap
    def generate(self, num_samples: int, T_schedule: jnp.ndarray, key: PRNGKey) -> jnp.ndarray:
        key, key_init = jax.random.split(key, 2)
        v = jax.random.bernoulli(key_init, p=0.5, shape=(num_samples, self.num_visible)).astype(jnp.float32)

        anneal_fn = lambda i, s: self._gibbs_step(s, W=self.W, b=self.b, c=self.c, T=T_schedule[i])
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), anneal_fn, (v, key))
        return v_final

# %%
@jax.jit
def train_step(state: TrainState, batch: jnp.ndarray, aux_vars: Dict[str, Any]) -> Tuple[TrainState, jnp.ndarray, Dict[str, Any]]:

    key, key_reset = jax.random.split(aux_vars["key"])
    aux_vars["key"] = key

    # reset gibbs_chain[i] with batch[i] given reset probability as chain_reset_frac
    reset_mask = jax.random.bernoulli(key_reset, p=aux_vars["chain_reset_frac"], shape=(batch.shape[0], 1))
    aux_vars["gibbs_chain"] = jnp.where(reset_mask, batch, aux_vars["gibbs_chain"])

    loss_fn = lambda params: state.apply_fn({'params': params}, batch, aux_vars)
    (loss, aux_vars), grads = jax.value_and_grad(loss_fn, has_aux=True)(state.params)
    state = state.apply_gradients(grads=grads)

    return state, loss, aux_vars


def count_modes(chain: jnp.ndarray) -> int:
    chain = chain.astype(jnp.uint32)
    powers = 2 ** jnp.arange(chain.shape[-1], dtype=jnp.uint32)
    ints = jnp.dot(chain, powers)

    hist = jnp.bincount(ints, length=1 << chain.shape[-1])
    return int(jnp.sum(hist > 0))


def train(
        state: TrainState,
        loader: MixedDataLoader,
        num_epochs: int,
        key: PRNGKey,
        chain_reset_frac: float,
        l2_strength: float,
        lr_schedule_fn: Callable[[int], float]) -> Tuple[TrainState, Dict[int, float]]:

    metrics: Dict[int, Any] = {}
    gibbs_chain = None

    for epoch in range(num_epochs):
        tot_loss = 0.0

        for i, batch in enumerate(loader):
            measurements = batch[:, :, 0].astype(jnp.float32)

            if gibbs_chain is None:
                gibbs_chain = measurements

            key, subkey = jax.random.split(key)
            aux_vars = {
                "gibbs_chain": gibbs_chain,
                "key": subkey,
                "chain_reset_frac": chain_reset_frac,
                "l2_strength": l2_strength,
            }

            state, loss, aux_vars = train_step(state, measurements, aux_vars)
            gibbs_chain = aux_vars["gibbs_chain"]
            key = aux_vars["key"]
            free_energy_model = aux_vars["free_energy_model"]
            free_energy_data  = aux_vars["free_energy_data"]

            tot_loss += float(loss)

        avg_loss = tot_loss / len(loader)
        modes = count_modes(gibbs_chain)
        lr = lr_schedule_fn(state.step)

        metrics[epoch] = dict(
            loss=avg_loss,
            modes=modes,
            free_energy_model=free_energy_model,
            free_energy_data=free_energy_data,
            lr=lr
        )

        print(f"Epoch {epoch+1}/{num_epochs} │ "
              f"Loss: {avg_loss:+.4f} │ "
              f"Modes: {modes} │ "
              f"Free En. Model: {free_energy_model:.4f} │ "
              f"Free En. Data: {free_energy_data:.4f} │ "
              f"Learning Rate: {lr:.5f}")

    return state, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2

    curve_fn = lambda step: low + (high - low) / (1 + jnp.exp(falloff * (jnp.minimum(step, steps) - center_step)))
    return curve_fn

# %%
file_path = Path("data/w_aug_ZZZZZZZZ_10000.txt")
data = load_measurements(file_path)

measurements = data[:, :, 0]
empirical_freq = measurements.mean(axis=0)
empirical_freq
# Out:
# Parsing measurements: 100%|██████████| 10000/10000 [00:00<00:00, 21730.15it/s]
# Array([0.12529999, 0.1228    , 0.1222    , 0.1248    , 0.1337    ,
#        0.1295    , 0.1199    , 0.1218    ], dtype=float32)

# %%
batch_size   = 1024             # larger requires more epochs for the model to go down in its modes
num_visible  = 8
hidden_units = 16               # interesting, lower gives evener frequencies, although the modes go not down to 1
k_steps      = 50               # more steps required if small batch size
num_epochs   = 2000             # longer since large batch size
init_lr      = 1e-2             # large drives modes down fast but learns nothing, to small and we dont get any one hots
final_lr     = init_lr * 0.1
chain_reset_frac = 0.1
l2_strength  = 1e-4

# we chose 16 in the hope that our conditioner has more to work with

# runs also very nicely if l2 norm is turned off completely but the free energies get large

key_seed = PRNGKey(42)
key, key_params, key_dummy = jax.random.split(key_seed, 3)

model = RBM(num_visible=num_visible, num_hidden=hidden_units, k=k_steps)
batch_dummy = jnp.zeros((batch_size, num_visible), dtype=jnp.float32)
aux_vars_dummy = {"gibbs_chain": jnp.zeros((batch_size, num_visible), dtype=jnp.float32), "key": key_dummy, "l2_strength": l2_strength}
variables = model.init({"params": key_params}, batch_dummy, aux_vars_dummy)

loader = MixedDataLoader(data, batch_size=batch_size, drop_last=True) # we need the last batch to match the chain dimension

schedule_steps = num_epochs * len(loader)
lr_schedule_fn = get_sigmoid_curve(high=init_lr, low=final_lr, steps=schedule_steps, falloff=0.0005)
optimizer = optax.adam(lr_schedule_fn)

state = TrainState.create(apply_fn=model.apply, params=variables['params'], tx=optimizer)

state, metrics = train(state, loader, num_epochs, key, chain_reset_frac, l2_strength, lr_schedule_fn)
# Out:
# Epoch 1/2000 │ Loss: -0.7219 │ Modes: 221 │ Free En. Model: -9.7143 │ Free En. Data: -10.8859 │ Learning Rate: 0.00990
# Epoch 2/2000 │ Loss: -1.1101 │ Modes: 150 │ Free En. Model: -10.0357 │ Free En. Data: -10.9643 │ Learning Rate: 0.00990
# Epoch 3/2000 │ Loss: -0.5710 │ Modes: 108 │ Free En. Model: -10.9379 │ Free En. Data: -11.2069 │ Learning Rate: 0.00990
# Epoch 4/2000 │ Loss: +0.0526 │ Modes: 90 │ Free En. Model: -11.7065 │ Free En. Data: -11.4373 │ Learning Rate: 0.00990
# Epoch 5/2000 │ Loss: +0.3278 │ Modes: 84 │ Free En. Model: -11.8732 │ Free En. Data: -11.5332 │ Learning Rate: 0.00990
# Epoch 6/2000 │ Loss: +0.2474 │ Modes: 83 │ Free En. Model: -11.9091 │ Free En. Data: -11.5419 │ Learning Rate: 0.00990
# Epoch 7/2000 │ Loss: +0.0508 │ Modes: 93 │ Free En. Model: -11.6256 │ Free En. Data: -11.5735 │ Learning Rate: 0.00990
# Epoch 8/2000 │ Loss: -0.0706 │ Modes: 106 │ Free En. Model: -11.5648 │ Free En. Data: -11.6896 │ Learning Rate: 0.00990
# Epoch 9/2000 │ Loss: -0.1234 │ Modes: 94 │ Free En. Model: -11.7185 │ Free En. Data: -11.8793 │ Learning Rate: 0.00990
# Epoch 10/2000 │ Loss: -0.1177 │ Modes: 97 │ Free En. Model: -12.0711 │ Free En. Data: -12.1215 │ Learning Rate: 0.00990
# Epoch 11/2000 │ Loss: -0.0876 │ Modes: 100 │ Free En. Model: -12.3048 │ Free En. Data: -12.3717 │ Learning Rate: 0.00990
# Epoch 12/2000 │ Loss: -0.0156 │ Modes: 100 │ Free En. Model: -12.5343 │ Free En. Data: -12.6053 │ Learning Rate: 0.00990
# Epoch 13/2000 │ Loss: -0.0805 │ Modes: 99 │ Free En. Model: -12.7937 │ Free En. Data: -12.8403 │ Learning Rate: 0.00990
# Epoch 14/2000 │ Loss: -0.0420 │ Modes: 92 │ Free En. Model: -13.1299 │ Free En. Data: -13.0906 │ Learning Rate: 0.00989
# Epoch 15/2000 │ Loss: -0.0570 │ Modes: 100 │ Free En. Model: -13.2653 │ Free En. Data: -13.3182 │ Learning Rate: 0.00989
# Epoch 16/2000 │ Loss: -0.1075 │ Modes: 99 │ Free En. Model: -13.3983 │ Free En. Data: -13.5670 │ Learning Rate: 0.00989
# Epoch 17/2000 │ Loss: -0.0674 │ Modes: 93 │ Free En. Model: -13.8079 │ Free En. Data: -13.8337 │ Learning Rate: 0.00989
# Epoch 18/2000 │ Loss: -0.0064 │ Modes: 93 │ Free En. Model: -14.0825 │ Free En. Data: -14.0737 │ Learning Rate: 0.00989
# Epoch 19/2000 │ Loss: -0.0521 │ Modes: 94 │ Free En. Model: -14.2175 │ Free En. Data: -14.3037 │ Learning Rate: 0.00989
# Epoch 20/2000 │ Loss: -0.1076 │ Modes: 93 │ Free En. Model: -14.4914 │ Free En. Data: -14.5501 │ Learning Rate: 0.00989
# Epoch 21/2000 │ Loss: -0.0425 │ Modes: 91 │ Free En. Model: -14.8223 │ Free En. Data: -14.8105 │ Learning Rate: 0.00989
# Epoch 22/2000 │ Loss: -0.0596 │ Modes: 89 │ Free En. Model: -15.0983 │ Free En. Data: -15.0583 │ Learning Rate: 0.00989
# Epoch 23/2000 │ Loss: -0.0683 │ Modes: 95 │ Free En. Model: -15.1299 │ Free En. Data: -15.3093 │ Learning Rate: 0.00989
# Epoch 24/2000 │ Loss: -0.0345 │ Modes: 92 │ Free En. Model: -15.5351 │ Free En. Data: -15.5502 │ Learning Rate: 0.00989
# Epoch 25/2000 │ Loss: -0.0531 │ Modes: 89 │ Free En. Model: -15.7685 │ Free En. Data: -15.7930 │ Learning Rate: 0.00989
# Epoch 26/2000 │ Loss: -0.0593 │ Modes: 91 │ Free En. Model: -16.0020 │ Free En. Data: -16.0287 │ Learning Rate: 0.00989
# Epoch 27/2000 │ Loss: -0.0347 │ Modes: 93 │ Free En. Model: -16.1752 │ Free En. Data: -16.2576 │ Learning Rate: 0.00989
# Epoch 28/2000 │ Loss: -0.0493 │ Modes: 91 │ Free En. Model: -16.4988 │ Free En. Data: -16.4894 │ Learning Rate: 0.00989
# Epoch 29/2000 │ Loss: -0.0677 │ Modes: 97 │ Free En. Model: -16.6577 │ Free En. Data: -16.7211 │ Learning Rate: 0.00989
# Epoch 30/2000 │ Loss: -0.0615 │ Modes: 94 │ Free En. Model: -16.9026 │ Free En. Data: -16.9587 │ Learning Rate: 0.00989
# Epoch 31/2000 │ Loss: -0.0359 │ Modes: 96 │ Free En. Model: -17.0946 │ Free En. Data: -17.1808 │ Learning Rate: 0.00989
# Epoch 32/2000 │ Loss: -0.0223 │ Modes: 93 │ Free En. Model: -17.3617 │ Free En. Data: -17.3996 │ Learning Rate: 0.00989
# Epoch 33/2000 │ Loss: -0.0238 │ Modes: 89 │ Free En. Model: -17.5260 │ Free En. Data: -17.6093 │ Learning Rate: 0.00989
# Epoch 34/2000 │ Loss: -0.1044 │ Modes: 91 │ Free En. Model: -17.8154 │ Free En. Data: -17.8262 │ Learning Rate: 0.00988
# Epoch 35/2000 │ Loss: -0.0310 │ Modes: 103 │ Free En. Model: -17.9120 │ Free En. Data: -18.0361 │ Learning Rate: 0.00988
# Epoch 36/2000 │ Loss: -0.0052 │ Modes: 88 │ Free En. Model: -18.2636 │ Free En. Data: -18.2496 │ Learning Rate: 0.00988
# Epoch 37/2000 │ Loss: -0.0630 │ Modes: 94 │ Free En. Model: -18.3748 │ Free En. Data: -18.4504 │ Learning Rate: 0.00988
# Epoch 38/2000 │ Loss: -0.0391 │ Modes: 93 │ Free En. Model: -18.6490 │ Free En. Data: -18.6530 │ Learning Rate: 0.00988
# Epoch 39/2000 │ Loss: -0.0357 │ Modes: 90 │ Free En. Model: -18.8255 │ Free En. Data: -18.8520 │ Learning Rate: 0.00988
# Epoch 40/2000 │ Loss: -0.0408 │ Modes: 91 │ Free En. Model: -18.9894 │ Free En. Data: -19.0493 │ Learning Rate: 0.00988
# Epoch 41/2000 │ Loss: -0.0109 │ Modes: 90 │ Free En. Model: -19.1923 │ Free En. Data: -19.2424 │ Learning Rate: 0.00988
# Epoch 42/2000 │ Loss: -0.0560 │ Modes: 89 │ Free En. Model: -19.3289 │ Free En. Data: -19.4275 │ Learning Rate: 0.00988
# Epoch 43/2000 │ Loss: -0.0341 │ Modes: 88 │ Free En. Model: -19.5626 │ Free En. Data: -19.6119 │ Learning Rate: 0.00988
# Epoch 44/2000 │ Loss: -0.0404 │ Modes: 86 │ Free En. Model: -19.7448 │ Free En. Data: -19.7769 │ Learning Rate: 0.00988
# Epoch 45/2000 │ Loss: -0.0167 │ Modes: 79 │ Free En. Model: -20.0144 │ Free En. Data: -19.9530 │ Learning Rate: 0.00988
# Epoch 46/2000 │ Loss: -0.0330 │ Modes: 92 │ Free En. Model: -20.1260 │ Free En. Data: -20.1232 │ Learning Rate: 0.00988
# Epoch 47/2000 │ Loss: -0.0336 │ Modes: 88 │ Free En. Model: -20.2341 │ Free En. Data: -20.2905 │ Learning Rate: 0.00988
# Epoch 48/2000 │ Loss: -0.0686 │ Modes: 91 │ Free En. Model: -20.3362 │ Free En. Data: -20.4566 │ Learning Rate: 0.00988
# Epoch 49/2000 │ Loss: +0.0185 │ Modes: 92 │ Free En. Model: -20.6195 │ Free En. Data: -20.6236 │ Learning Rate: 0.00988
# Epoch 50/2000 │ Loss: -0.0320 │ Modes: 91 │ Free En. Model: -20.6798 │ Free En. Data: -20.7929 │ Learning Rate: 0.00988
# Epoch 51/2000 │ Loss: -0.0483 │ Modes: 89 │ Free En. Model: -20.9389 │ Free En. Data: -20.9407 │ Learning Rate: 0.00988
# Epoch 52/2000 │ Loss: -0.0367 │ Modes: 88 │ Free En. Model: -21.0824 │ Free En. Data: -21.0899 │ Learning Rate: 0.00988
# Epoch 53/2000 │ Loss: +0.0182 │ Modes: 90 │ Free En. Model: -21.2436 │ Free En. Data: -21.2377 │ Learning Rate: 0.00987
# Epoch 54/2000 │ Loss: -0.0426 │ Modes: 84 │ Free En. Model: -21.4184 │ Free En. Data: -21.3883 │ Learning Rate: 0.00987
# Epoch 55/2000 │ Loss: -0.0534 │ Modes: 86 │ Free En. Model: -21.5117 │ Free En. Data: -21.5273 │ Learning Rate: 0.00987
# Epoch 56/2000 │ Loss: -0.0168 │ Modes: 92 │ Free En. Model: -21.6890 │ Free En. Data: -21.6680 │ Learning Rate: 0.00987
# Epoch 57/2000 │ Loss: -0.0176 │ Modes: 82 │ Free En. Model: -21.8298 │ Free En. Data: -21.8008 │ Learning Rate: 0.00987
# Epoch 58/2000 │ Loss: -0.0336 │ Modes: 92 │ Free En. Model: -21.8494 │ Free En. Data: -21.9518 │ Learning Rate: 0.00987
# Epoch 59/2000 │ Loss: -0.0353 │ Modes: 86 │ Free En. Model: -22.0396 │ Free En. Data: -22.0806 │ Learning Rate: 0.00987
# Epoch 60/2000 │ Loss: -0.0103 │ Modes: 82 │ Free En. Model: -22.1692 │ Free En. Data: -22.2221 │ Learning Rate: 0.00987
# Epoch 61/2000 │ Loss: -0.0373 │ Modes: 82 │ Free En. Model: -22.3940 │ Free En. Data: -22.3488 │ Learning Rate: 0.00987
# Epoch 62/2000 │ Loss: -0.0221 │ Modes: 91 │ Free En. Model: -22.4322 │ Free En. Data: -22.4768 │ Learning Rate: 0.00987
# Epoch 63/2000 │ Loss: -0.0374 │ Modes: 79 │ Free En. Model: -22.6692 │ Free En. Data: -22.5833 │ Learning Rate: 0.00987
# Epoch 64/2000 │ Loss: +0.0189 │ Modes: 94 │ Free En. Model: -22.6765 │ Free En. Data: -22.7205 │ Learning Rate: 0.00987
# Epoch 65/2000 │ Loss: -0.0562 │ Modes: 91 │ Free En. Model: -22.7887 │ Free En. Data: -22.8298 │ Learning Rate: 0.00987
# Epoch 66/2000 │ Loss: +0.0087 │ Modes: 80 │ Free En. Model: -22.9014 │ Free En. Data: -22.9452 │ Learning Rate: 0.00987
# Epoch 67/2000 │ Loss: -0.0435 │ Modes: 94 │ Free En. Model: -22.9259 │ Free En. Data: -23.0573 │ Learning Rate: 0.00987
# Epoch 68/2000 │ Loss: +0.0012 │ Modes: 90 │ Free En. Model: -23.0617 │ Free En. Data: -23.1687 │ Learning Rate: 0.00987
# Epoch 69/2000 │ Loss: -0.0262 │ Modes: 83 │ Free En. Model: -23.2357 │ Free En. Data: -23.2748 │ Learning Rate: 0.00987
# Epoch 70/2000 │ Loss: -0.0511 │ Modes: 81 │ Free En. Model: -23.3057 │ Free En. Data: -23.3676 │ Learning Rate: 0.00987
# Epoch 71/2000 │ Loss: +0.0039 │ Modes: 79 │ Free En. Model: -23.4914 │ Free En. Data: -23.4701 │ Learning Rate: 0.00986
# Epoch 72/2000 │ Loss: -0.0215 │ Modes: 88 │ Free En. Model: -23.4904 │ Free En. Data: -23.5821 │ Learning Rate: 0.00986
# Epoch 73/2000 │ Loss: -0.0150 │ Modes: 85 │ Free En. Model: -23.7079 │ Free En. Data: -23.6778 │ Learning Rate: 0.00986
# Epoch 74/2000 │ Loss: -0.0099 │ Modes: 94 │ Free En. Model: -23.6184 │ Free En. Data: -23.7969 │ Learning Rate: 0.00986
# Epoch 75/2000 │ Loss: -0.0537 │ Modes: 83 │ Free En. Model: -23.8812 │ Free En. Data: -23.8592 │ Learning Rate: 0.00986
# Epoch 76/2000 │ Loss: +0.0298 │ Modes: 92 │ Free En. Model: -23.8529 │ Free En. Data: -23.9567 │ Learning Rate: 0.00986
# Epoch 77/2000 │ Loss: -0.0521 │ Modes: 74 │ Free En. Model: -24.2089 │ Free En. Data: -24.0267 │ Learning Rate: 0.00986
# Epoch 78/2000 │ Loss: +0.0036 │ Modes: 91 │ Free En. Model: -24.0693 │ Free En. Data: -24.1172 │ Learning Rate: 0.00986
# Epoch 79/2000 │ Loss: -0.0239 │ Modes: 85 │ Free En. Model: -24.2134 │ Free En. Data: -24.1980 │ Learning Rate: 0.00986
# Epoch 80/2000 │ Loss: -0.0292 │ Modes: 83 │ Free En. Model: -24.3442 │ Free En. Data: -24.2648 │ Learning Rate: 0.00986
# Epoch 81/2000 │ Loss: +0.0123 │ Modes: 80 │ Free En. Model: -24.3937 │ Free En. Data: -24.3622 │ Learning Rate: 0.00986
# Epoch 82/2000 │ Loss: -0.0233 │ Modes: 72 │ Free En. Model: -24.5155 │ Free En. Data: -24.4495 │ Learning Rate: 0.00986
# Epoch 83/2000 │ Loss: -0.0191 │ Modes: 77 │ Free En. Model: -24.6033 │ Free En. Data: -24.5062 │ Learning Rate: 0.00986
# Epoch 84/2000 │ Loss: -0.0222 │ Modes: 80 │ Free En. Model: -24.6053 │ Free En. Data: -24.5931 │ Learning Rate: 0.00986
# Epoch 85/2000 │ Loss: -0.0294 │ Modes: 86 │ Free En. Model: -24.5106 │ Free En. Data: -24.6616 │ Learning Rate: 0.00986
# Epoch 86/2000 │ Loss: +0.0060 │ Modes: 83 │ Free En. Model: -24.7539 │ Free En. Data: -24.7201 │ Learning Rate: 0.00986
# Epoch 87/2000 │ Loss: -0.0157 │ Modes: 84 │ Free En. Model: -24.7263 │ Free En. Data: -24.7970 │ Learning Rate: 0.00985
# Epoch 88/2000 │ Loss: -0.0111 │ Modes: 81 │ Free En. Model: -24.8621 │ Free En. Data: -24.8459 │ Learning Rate: 0.00985
# Epoch 89/2000 │ Loss: -0.0053 │ Modes: 91 │ Free En. Model: -24.8488 │ Free En. Data: -24.9317 │ Learning Rate: 0.00985
# Epoch 90/2000 │ Loss: -0.0581 │ Modes: 80 │ Free En. Model: -24.8560 │ Free En. Data: -24.9702 │ Learning Rate: 0.00985
# Epoch 91/2000 │ Loss: +0.0266 │ Modes: 87 │ Free En. Model: -25.0245 │ Free En. Data: -25.0108 │ Learning Rate: 0.00985
# Epoch 92/2000 │ Loss: -0.0121 │ Modes: 88 │ Free En. Model: -25.0793 │ Free En. Data: -25.0794 │ Learning Rate: 0.00985
# Epoch 93/2000 │ Loss: -0.0268 │ Modes: 84 │ Free En. Model: -25.1584 │ Free En. Data: -25.1140 │ Learning Rate: 0.00985
# Epoch 94/2000 │ Loss: +0.0058 │ Modes: 91 │ Free En. Model: -25.0466 │ Free En. Data: -25.1704 │ Learning Rate: 0.00985
# Epoch 95/2000 │ Loss: -0.0191 │ Modes: 83 │ Free En. Model: -25.2038 │ Free En. Data: -25.2347 │ Learning Rate: 0.00985
# Epoch 96/2000 │ Loss: -0.0120 │ Modes: 82 │ Free En. Model: -25.2752 │ Free En. Data: -25.2613 │ Learning Rate: 0.00985
# Epoch 97/2000 │ Loss: -0.0183 │ Modes: 86 │ Free En. Model: -25.3171 │ Free En. Data: -25.3211 │ Learning Rate: 0.00985
# Epoch 98/2000 │ Loss: -0.0069 │ Modes: 82 │ Free En. Model: -25.4364 │ Free En. Data: -25.3599 │ Learning Rate: 0.00985
# Epoch 99/2000 │ Loss: -0.0156 │ Modes: 88 │ Free En. Model: -25.4281 │ Free En. Data: -25.3884 │ Learning Rate: 0.00985
# Epoch 100/2000 │ Loss: -0.0296 │ Modes: 89 │ Free En. Model: -25.3064 │ Free En. Data: -25.4383 │ Learning Rate: 0.00985
# Epoch 101/2000 │ Loss: -0.0051 │ Modes: 85 │ Free En. Model: -25.5252 │ Free En. Data: -25.4623 │ Learning Rate: 0.00985
# Epoch 102/2000 │ Loss: +0.0131 │ Modes: 78 │ Free En. Model: -25.5235 │ Free En. Data: -25.5077 │ Learning Rate: 0.00984
# Epoch 103/2000 │ Loss: -0.0240 │ Modes: 84 │ Free En. Model: -25.5048 │ Free En. Data: -25.5602 │ Learning Rate: 0.00984
# Epoch 104/2000 │ Loss: -0.0067 │ Modes: 77 │ Free En. Model: -25.6501 │ Free En. Data: -25.5828 │ Learning Rate: 0.00984
# Epoch 105/2000 │ Loss: -0.0185 │ Modes: 81 │ Free En. Model: -25.6184 │ Free En. Data: -25.6105 │ Learning Rate: 0.00984
# Epoch 106/2000 │ Loss: +0.0121 │ Modes: 82 │ Free En. Model: -25.6039 │ Free En. Data: -25.6530 │ Learning Rate: 0.00984
# Epoch 107/2000 │ Loss: -0.0370 │ Modes: 81 │ Free En. Model: -25.6543 │ Free En. Data: -25.6442 │ Learning Rate: 0.00984
# Epoch 108/2000 │ Loss: +0.0407 │ Modes: 88 │ Free En. Model: -25.6851 │ Free En. Data: -25.7052 │ Learning Rate: 0.00984
# Epoch 109/2000 │ Loss: -0.0911 │ Modes: 83 │ Free En. Model: -25.6334 │ Free En. Data: -25.7014 │ Learning Rate: 0.00984
# Epoch 110/2000 │ Loss: +0.0640 │ Modes: 88 │ Free En. Model: -25.7451 │ Free En. Data: -25.7189 │ Learning Rate: 0.00984
# Epoch 111/2000 │ Loss: -0.0463 │ Modes: 85 │ Free En. Model: -25.6398 │ Free En. Data: -25.7696 │ Learning Rate: 0.00984
# Epoch 112/2000 │ Loss: -0.0056 │ Modes: 81 │ Free En. Model: -25.8444 │ Free En. Data: -25.7688 │ Learning Rate: 0.00984
# Epoch 113/2000 │ Loss: -0.0027 │ Modes: 86 │ Free En. Model: -25.7943 │ Free En. Data: -25.8044 │ Learning Rate: 0.00984
# Epoch 114/2000 │ Loss: -0.0246 │ Modes: 83 │ Free En. Model: -25.8845 │ Free En. Data: -25.8204 │ Learning Rate: 0.00984
# Epoch 115/2000 │ Loss: -0.0104 │ Modes: 85 │ Free En. Model: -25.7899 │ Free En. Data: -25.8379 │ Learning Rate: 0.00984
# Epoch 116/2000 │ Loss: +0.0216 │ Modes: 84 │ Free En. Model: -25.8606 │ Free En. Data: -25.8509 │ Learning Rate: 0.00983
# Epoch 117/2000 │ Loss: -0.0485 │ Modes: 85 │ Free En. Model: -25.8097 │ Free En. Data: -25.8806 │ Learning Rate: 0.00983
# Epoch 118/2000 │ Loss: -0.0130 │ Modes: 86 │ Free En. Model: -25.7916 │ Free En. Data: -25.8677 │ Learning Rate: 0.00983
# Epoch 119/2000 │ Loss: +0.0428 │ Modes: 89 │ Free En. Model: -25.8940 │ Free En. Data: -25.9084 │ Learning Rate: 0.00983
# Epoch 120/2000 │ Loss: -0.0648 │ Modes: 92 │ Free En. Model: -25.8208 │ Free En. Data: -25.9225 │ Learning Rate: 0.00983
# Epoch 121/2000 │ Loss: +0.0175 │ Modes: 80 │ Free En. Model: -25.9988 │ Free En. Data: -25.8984 │ Learning Rate: 0.00983
# Epoch 122/2000 │ Loss: +0.0031 │ Modes: 82 │ Free En. Model: -25.9804 │ Free En. Data: -25.9502 │ Learning Rate: 0.00983
# Epoch 123/2000 │ Loss: -0.0311 │ Modes: 82 │ Free En. Model: -25.9221 │ Free En. Data: -25.9545 │ Learning Rate: 0.00983
# Epoch 124/2000 │ Loss: -0.0249 │ Modes: 90 │ Free En. Model: -25.8242 │ Free En. Data: -25.9350 │ Learning Rate: 0.00983
# Epoch 125/2000 │ Loss: +0.0190 │ Modes: 79 │ Free En. Model: -25.9827 │ Free En. Data: -25.9533 │ Learning Rate: 0.00983
# Epoch 126/2000 │ Loss: -0.0352 │ Modes: 89 │ Free En. Model: -25.8623 │ Free En. Data: -25.9446 │ Learning Rate: 0.00983
# Epoch 127/2000 │ Loss: -0.0075 │ Modes: 84 │ Free En. Model: -25.9367 │ Free En. Data: -25.9323 │ Learning Rate: 0.00983
# Epoch 128/2000 │ Loss: +0.0229 │ Modes: 94 │ Free En. Model: -25.8956 │ Free En. Data: -25.9574 │ Learning Rate: 0.00983
# Epoch 129/2000 │ Loss: -0.0488 │ Modes: 82 │ Free En. Model: -25.9641 │ Free En. Data: -25.9433 │ Learning Rate: 0.00982
# Epoch 130/2000 │ Loss: +0.0420 │ Modes: 81 │ Free En. Model: -25.9626 │ Free En. Data: -25.9668 │ Learning Rate: 0.00982
# Epoch 131/2000 │ Loss: -0.0573 │ Modes: 83 │ Free En. Model: -25.8837 │ Free En. Data: -25.9638 │ Learning Rate: 0.00982
# Epoch 132/2000 │ Loss: +0.0007 │ Modes: 90 │ Free En. Model: -25.9310 │ Free En. Data: -25.9282 │ Learning Rate: 0.00982
# Epoch 133/2000 │ Loss: +0.0024 │ Modes: 87 │ Free En. Model: -25.9249 │ Free En. Data: -25.9409 │ Learning Rate: 0.00982
# Epoch 134/2000 │ Loss: -0.0135 │ Modes: 77 │ Free En. Model: -25.9049 │ Free En. Data: -25.9377 │ Learning Rate: 0.00982
# Epoch 135/2000 │ Loss: +0.0125 │ Modes: 84 │ Free En. Model: -25.9409 │ Free En. Data: -25.9251 │ Learning Rate: 0.00982
# Epoch 136/2000 │ Loss: -0.0160 │ Modes: 85 │ Free En. Model: -26.0228 │ Free En. Data: -25.9003 │ Learning Rate: 0.00982
# Epoch 137/2000 │ Loss: -0.0203 │ Modes: 91 │ Free En. Model: -25.8554 │ Free En. Data: -25.8888 │ Learning Rate: 0.00982
# Epoch 138/2000 │ Loss: +0.0229 │ Modes: 90 │ Free En. Model: -25.8678 │ Free En. Data: -25.8831 │ Learning Rate: 0.00982
# Epoch 139/2000 │ Loss: -0.0421 │ Modes: 75 │ Free En. Model: -25.9678 │ Free En. Data: -25.8679 │ Learning Rate: 0.00982
# Epoch 140/2000 │ Loss: +0.0083 │ Modes: 85 │ Free En. Model: -25.9003 │ Free En. Data: -25.8415 │ Learning Rate: 0.00982
# Epoch 141/2000 │ Loss: -0.0008 │ Modes: 90 │ Free En. Model: -25.7784 │ Free En. Data: -25.8541 │ Learning Rate: 0.00982
# Epoch 142/2000 │ Loss: -0.0186 │ Modes: 82 │ Free En. Model: -25.8478 │ Free En. Data: -25.8183 │ Learning Rate: 0.00981
# Epoch 143/2000 │ Loss: -0.0153 │ Modes: 83 │ Free En. Model: -25.7476 │ Free En. Data: -25.7781 │ Learning Rate: 0.00981
# Epoch 144/2000 │ Loss: +0.0135 │ Modes: 98 │ Free En. Model: -25.6747 │ Free En. Data: -25.7774 │ Learning Rate: 0.00981
# Epoch 145/2000 │ Loss: -0.0192 │ Modes: 82 │ Free En. Model: -25.7397 │ Free En. Data: -25.7204 │ Learning Rate: 0.00981
# Epoch 146/2000 │ Loss: +0.0017 │ Modes: 88 │ Free En. Model: -25.6495 │ Free En. Data: -25.6995 │ Learning Rate: 0.00981
# Epoch 147/2000 │ Loss: -0.0115 │ Modes: 83 │ Free En. Model: -25.6381 │ Free En. Data: -25.6733 │ Learning Rate: 0.00981
# Epoch 148/2000 │ Loss: +0.0028 │ Modes: 82 │ Free En. Model: -25.6709 │ Free En. Data: -25.6342 │ Learning Rate: 0.00981
# Epoch 149/2000 │ Loss: -0.0252 │ Modes: 86 │ Free En. Model: -25.6271 │ Free En. Data: -25.6111 │ Learning Rate: 0.00981
# Epoch 150/2000 │ Loss: -0.0028 │ Modes: 88 │ Free En. Model: -25.6126 │ Free En. Data: -25.5990 │ Learning Rate: 0.00981
# Epoch 151/2000 │ Loss: -0.0144 │ Modes: 82 │ Free En. Model: -25.7072 │ Free En. Data: -25.5647 │ Learning Rate: 0.00981
# Epoch 152/2000 │ Loss: -0.0003 │ Modes: 81 │ Free En. Model: -25.6197 │ Free En. Data: -25.5521 │ Learning Rate: 0.00981
# Epoch 153/2000 │ Loss: -0.0160 │ Modes: 95 │ Free En. Model: -25.4850 │ Free En. Data: -25.5224 │ Learning Rate: 0.00981
# Epoch 154/2000 │ Loss: +0.0009 │ Modes: 93 │ Free En. Model: -25.4781 │ Free En. Data: -25.5296 │ Learning Rate: 0.00980
# Epoch 155/2000 │ Loss: -0.0143 │ Modes: 87 │ Free En. Model: -25.4850 │ Free En. Data: -25.4964 │ Learning Rate: 0.00980
# Epoch 156/2000 │ Loss: -0.0169 │ Modes: 80 │ Free En. Model: -25.4641 │ Free En. Data: -25.4646 │ Learning Rate: 0.00980
# Epoch 157/2000 │ Loss: +0.0009 │ Modes: 79 │ Free En. Model: -25.5183 │ Free En. Data: -25.4211 │ Learning Rate: 0.00980
# Epoch 158/2000 │ Loss: +0.0025 │ Modes: 84 │ Free En. Model: -25.3623 │ Free En. Data: -25.4011 │ Learning Rate: 0.00980
# Epoch 159/2000 │ Loss: -0.0339 │ Modes: 87 │ Free En. Model: -25.3698 │ Free En. Data: -25.3811 │ Learning Rate: 0.00980
# Epoch 160/2000 │ Loss: +0.0113 │ Modes: 76 │ Free En. Model: -25.4809 │ Free En. Data: -25.3238 │ Learning Rate: 0.00980
# Epoch 161/2000 │ Loss: +0.0139 │ Modes: 88 │ Free En. Model: -25.2707 │ Free En. Data: -25.2979 │ Learning Rate: 0.00980
# Epoch 162/2000 │ Loss: -0.0417 │ Modes: 96 │ Free En. Model: -25.1426 │ Free En. Data: -25.2272 │ Learning Rate: 0.00980
# Epoch 163/2000 │ Loss: +0.0153 │ Modes: 79 │ Free En. Model: -25.2373 │ Free En. Data: -25.1734 │ Learning Rate: 0.00980
# Epoch 164/2000 │ Loss: -0.0088 │ Modes: 87 │ Free En. Model: -25.1020 │ Free En. Data: -25.1231 │ Learning Rate: 0.00980
# Epoch 165/2000 │ Loss: +0.0076 │ Modes: 87 │ Free En. Model: -25.0751 │ Free En. Data: -25.0943 │ Learning Rate: 0.00979
# Epoch 166/2000 │ Loss: -0.0261 │ Modes: 83 │ Free En. Model: -25.0593 │ Free En. Data: -25.0776 │ Learning Rate: 0.00979
# Epoch 167/2000 │ Loss: -0.0269 │ Modes: 82 │ Free En. Model: -24.9995 │ Free En. Data: -25.0044 │ Learning Rate: 0.00979
# Epoch 168/2000 │ Loss: +0.0324 │ Modes: 82 │ Free En. Model: -25.0457 │ Free En. Data: -24.9840 │ Learning Rate: 0.00979
# Epoch 169/2000 │ Loss: -0.0285 │ Modes: 87 │ Free En. Model: -24.9278 │ Free En. Data: -24.9577 │ Learning Rate: 0.00979
# Epoch 170/2000 │ Loss: -0.0145 │ Modes: 91 │ Free En. Model: -24.8818 │ Free En. Data: -24.8973 │ Learning Rate: 0.00979
# Epoch 171/2000 │ Loss: -0.0000 │ Modes: 89 │ Free En. Model: -24.7609 │ Free En. Data: -24.8671 │ Learning Rate: 0.00979
# Epoch 172/2000 │ Loss: -0.0167 │ Modes: 90 │ Free En. Model: -24.7679 │ Free En. Data: -24.8012 │ Learning Rate: 0.00979
# Epoch 173/2000 │ Loss: -0.0062 │ Modes: 93 │ Free En. Model: -24.7732 │ Free En. Data: -24.7638 │ Learning Rate: 0.00979
# Epoch 174/2000 │ Loss: +0.0114 │ Modes: 78 │ Free En. Model: -24.8074 │ Free En. Data: -24.7103 │ Learning Rate: 0.00979
# Epoch 175/2000 │ Loss: -0.0168 │ Modes: 97 │ Free En. Model: -24.5221 │ Free En. Data: -24.6571 │ Learning Rate: 0.00979
# Epoch 176/2000 │ Loss: -0.0171 │ Modes: 86 │ Free En. Model: -24.5744 │ Free En. Data: -24.5810 │ Learning Rate: 0.00978
# Epoch 177/2000 │ Loss: +0.0360 │ Modes: 86 │ Free En. Model: -24.6286 │ Free En. Data: -24.5248 │ Learning Rate: 0.00978
# Epoch 178/2000 │ Loss: -0.0469 │ Modes: 81 │ Free En. Model: -24.4825 │ Free En. Data: -24.4949 │ Learning Rate: 0.00978
# Epoch 179/2000 │ Loss: -0.0128 │ Modes: 81 │ Free En. Model: -24.4356 │ Free En. Data: -24.4099 │ Learning Rate: 0.00978
# Epoch 180/2000 │ Loss: +0.0269 │ Modes: 80 │ Free En. Model: -24.2951 │ Free En. Data: -24.3805 │ Learning Rate: 0.00978
# Epoch 181/2000 │ Loss: -0.0368 │ Modes: 81 │ Free En. Model: -24.3060 │ Free En. Data: -24.2945 │ Learning Rate: 0.00978
# Epoch 182/2000 │ Loss: +0.0009 │ Modes: 83 │ Free En. Model: -24.2634 │ Free En. Data: -24.2332 │ Learning Rate: 0.00978
# Epoch 183/2000 │ Loss: -0.0017 │ Modes: 87 │ Free En. Model: -24.0954 │ Free En. Data: -24.1996 │ Learning Rate: 0.00978
# Epoch 184/2000 │ Loss: -0.0132 │ Modes: 88 │ Free En. Model: -24.1112 │ Free En. Data: -24.1236 │ Learning Rate: 0.00978
# Epoch 185/2000 │ Loss: +0.0171 │ Modes: 85 │ Free En. Model: -24.0822 │ Free En. Data: -24.0709 │ Learning Rate: 0.00978
# Epoch 186/2000 │ Loss: -0.0390 │ Modes: 90 │ Free En. Model: -23.8861 │ Free En. Data: -24.0137 │ Learning Rate: 0.00977
# Epoch 187/2000 │ Loss: +0.0239 │ Modes: 87 │ Free En. Model: -23.9822 │ Free En. Data: -23.9358 │ Learning Rate: 0.00977
# Epoch 188/2000 │ Loss: -0.0316 │ Modes: 86 │ Free En. Model: -23.8781 │ Free En. Data: -23.8941 │ Learning Rate: 0.00977
# Epoch 189/2000 │ Loss: +0.0005 │ Modes: 84 │ Free En. Model: -23.8623 │ Free En. Data: -23.8139 │ Learning Rate: 0.00977
# Epoch 190/2000 │ Loss: +0.0163 │ Modes: 93 │ Free En. Model: -23.6752 │ Free En. Data: -23.7801 │ Learning Rate: 0.00977
# Epoch 191/2000 │ Loss: -0.0393 │ Modes: 84 │ Free En. Model: -23.6958 │ Free En. Data: -23.6753 │ Learning Rate: 0.00977
# Epoch 192/2000 │ Loss: -0.0036 │ Modes: 85 │ Free En. Model: -23.6348 │ Free En. Data: -23.6270 │ Learning Rate: 0.00977
# Epoch 193/2000 │ Loss: +0.0184 │ Modes: 80 │ Free En. Model: -23.6078 │ Free En. Data: -23.5612 │ Learning Rate: 0.00977
# Epoch 194/2000 │ Loss: -0.0263 │ Modes: 77 │ Free En. Model: -23.4902 │ Free En. Data: -23.5031 │ Learning Rate: 0.00977
# Epoch 195/2000 │ Loss: +0.0042 │ Modes: 79 │ Free En. Model: -23.4392 │ Free En. Data: -23.4310 │ Learning Rate: 0.00977
# Epoch 196/2000 │ Loss: -0.0164 │ Modes: 95 │ Free En. Model: -23.2896 │ Free En. Data: -23.3664 │ Learning Rate: 0.00976
# Epoch 197/2000 │ Loss: -0.0007 │ Modes: 92 │ Free En. Model: -23.2725 │ Free En. Data: -23.3136 │ Learning Rate: 0.00976
# Epoch 198/2000 │ Loss: -0.0221 │ Modes: 72 │ Free En. Model: -23.2952 │ Free En. Data: -23.2226 │ Learning Rate: 0.00976
# Epoch 199/2000 │ Loss: +0.0096 │ Modes: 99 │ Free En. Model: -23.0131 │ Free En. Data: -23.1754 │ Learning Rate: 0.00976
# Epoch 200/2000 │ Loss: -0.0356 │ Modes: 89 │ Free En. Model: -23.0906 │ Free En. Data: -23.0789 │ Learning Rate: 0.00976
# Epoch 201/2000 │ Loss: +0.0313 │ Modes: 78 │ Free En. Model: -23.0301 │ Free En. Data: -23.0073 │ Learning Rate: 0.00976
# Epoch 202/2000 │ Loss: -0.0281 │ Modes: 91 │ Free En. Model: -22.9542 │ Free En. Data: -22.9363 │ Learning Rate: 0.00976
# Epoch 203/2000 │ Loss: -0.0027 │ Modes: 79 │ Free En. Model: -22.8708 │ Free En. Data: -22.8550 │ Learning Rate: 0.00976
# Epoch 204/2000 │ Loss: -0.0023 │ Modes: 82 │ Free En. Model: -22.7216 │ Free En. Data: -22.7916 │ Learning Rate: 0.00976
# Epoch 205/2000 │ Loss: -0.0064 │ Modes: 85 │ Free En. Model: -22.7601 │ Free En. Data: -22.7261 │ Learning Rate: 0.00976
# Epoch 206/2000 │ Loss: -0.0128 │ Modes: 83 │ Free En. Model: -22.6084 │ Free En. Data: -22.6531 │ Learning Rate: 0.00975
# Epoch 207/2000 │ Loss: -0.0143 │ Modes: 91 │ Free En. Model: -22.6811 │ Free En. Data: -22.5620 │ Learning Rate: 0.00975
# Epoch 208/2000 │ Loss: -0.0169 │ Modes: 84 │ Free En. Model: -22.4169 │ Free En. Data: -22.5178 │ Learning Rate: 0.00975
# Epoch 209/2000 │ Loss: +0.0217 │ Modes: 78 │ Free En. Model: -22.5729 │ Free En. Data: -22.4196 │ Learning Rate: 0.00975
# Epoch 210/2000 │ Loss: -0.0095 │ Modes: 86 │ Free En. Model: -22.4295 │ Free En. Data: -22.3792 │ Learning Rate: 0.00975
# Epoch 211/2000 │ Loss: -0.0420 │ Modes: 79 │ Free En. Model: -22.3229 │ Free En. Data: -22.2634 │ Learning Rate: 0.00975
# Epoch 212/2000 │ Loss: +0.0197 │ Modes: 87 │ Free En. Model: -22.1657 │ Free En. Data: -22.2061 │ Learning Rate: 0.00975
# Epoch 213/2000 │ Loss: -0.0151 │ Modes: 88 │ Free En. Model: -22.1428 │ Free En. Data: -22.1442 │ Learning Rate: 0.00975
# Epoch 214/2000 │ Loss: -0.0220 │ Modes: 86 │ Free En. Model: -22.0444 │ Free En. Data: -22.0681 │ Learning Rate: 0.00975
# Epoch 215/2000 │ Loss: +0.0118 │ Modes: 80 │ Free En. Model: -22.0733 │ Free En. Data: -21.9789 │ Learning Rate: 0.00974
# Epoch 216/2000 │ Loss: -0.0027 │ Modes: 85 │ Free En. Model: -21.8652 │ Free En. Data: -21.9286 │ Learning Rate: 0.00974
# Epoch 217/2000 │ Loss: -0.0309 │ Modes: 90 │ Free En. Model: -21.7523 │ Free En. Data: -21.8259 │ Learning Rate: 0.00974
# Epoch 218/2000 │ Loss: -0.0032 │ Modes: 88 │ Free En. Model: -21.7412 │ Free En. Data: -21.7561 │ Learning Rate: 0.00974
# Epoch 219/2000 │ Loss: +0.0013 │ Modes: 87 │ Free En. Model: -21.6389 │ Free En. Data: -21.6631 │ Learning Rate: 0.00974
# Epoch 220/2000 │ Loss: -0.0368 │ Modes: 89 │ Free En. Model: -21.4728 │ Free En. Data: -21.5758 │ Learning Rate: 0.00974
# Epoch 221/2000 │ Loss: +0.0318 │ Modes: 85 │ Free En. Model: -21.5570 │ Free En. Data: -21.4941 │ Learning Rate: 0.00974
# Epoch 222/2000 │ Loss: -0.0332 │ Modes: 85 │ Free En. Model: -21.4122 │ Free En. Data: -21.4034 │ Learning Rate: 0.00974
# Epoch 223/2000 │ Loss: +0.0092 │ Modes: 88 │ Free En. Model: -21.2813 │ Free En. Data: -21.2975 │ Learning Rate: 0.00974
# Epoch 224/2000 │ Loss: -0.0185 │ Modes: 86 │ Free En. Model: -21.1797 │ Free En. Data: -21.2333 │ Learning Rate: 0.00973
# Epoch 225/2000 │ Loss: +0.0100 │ Modes: 87 │ Free En. Model: -21.1106 │ Free En. Data: -21.1473 │ Learning Rate: 0.00973
# Epoch 226/2000 │ Loss: -0.0312 │ Modes: 89 │ Free En. Model: -20.9902 │ Free En. Data: -21.0685 │ Learning Rate: 0.00973
# Epoch 227/2000 │ Loss: -0.0230 │ Modes: 83 │ Free En. Model: -21.0354 │ Free En. Data: -20.9686 │ Learning Rate: 0.00973
# Epoch 228/2000 │ Loss: +0.0469 │ Modes: 86 │ Free En. Model: -20.8834 │ Free En. Data: -20.8999 │ Learning Rate: 0.00973
# Epoch 229/2000 │ Loss: -0.0464 │ Modes: 99 │ Free En. Model: -20.7661 │ Free En. Data: -20.8260 │ Learning Rate: 0.00973
# Epoch 230/2000 │ Loss: -0.0101 │ Modes: 90 │ Free En. Model: -20.6900 │ Free En. Data: -20.7220 │ Learning Rate: 0.00973
# Epoch 231/2000 │ Loss: +0.0133 │ Modes: 87 │ Free En. Model: -20.6438 │ Free En. Data: -20.6432 │ Learning Rate: 0.00973
# Epoch 232/2000 │ Loss: -0.0451 │ Modes: 84 │ Free En. Model: -20.5336 │ Free En. Data: -20.5326 │ Learning Rate: 0.00972
# Epoch 233/2000 │ Loss: +0.0116 │ Modes: 87 │ Free En. Model: -20.3861 │ Free En. Data: -20.4408 │ Learning Rate: 0.00972
# Epoch 234/2000 │ Loss: -0.0077 │ Modes: 85 │ Free En. Model: -20.3278 │ Free En. Data: -20.3563 │ Learning Rate: 0.00972
# Epoch 235/2000 │ Loss: +0.0031 │ Modes: 79 │ Free En. Model: -20.2559 │ Free En. Data: -20.2474 │ Learning Rate: 0.00972
# Epoch 236/2000 │ Loss: -0.0271 │ Modes: 79 │ Free En. Model: -20.1868 │ Free En. Data: -20.1605 │ Learning Rate: 0.00972
# Epoch 237/2000 │ Loss: -0.0122 │ Modes: 87 │ Free En. Model: -19.9239 │ Free En. Data: -20.0591 │ Learning Rate: 0.00972
# Epoch 238/2000 │ Loss: +0.0093 │ Modes: 94 │ Free En. Model: -19.8068 │ Free En. Data: -19.9856 │ Learning Rate: 0.00972
# Epoch 239/2000 │ Loss: -0.0132 │ Modes: 81 │ Free En. Model: -19.9818 │ Free En. Data: -19.8857 │ Learning Rate: 0.00972
# Epoch 240/2000 │ Loss: -0.0026 │ Modes: 87 │ Free En. Model: -19.7659 │ Free En. Data: -19.8151 │ Learning Rate: 0.00971
# Epoch 241/2000 │ Loss: -0.0325 │ Modes: 87 │ Free En. Model: -19.6689 │ Free En. Data: -19.7161 │ Learning Rate: 0.00971
# Epoch 242/2000 │ Loss: +0.0100 │ Modes: 86 │ Free En. Model: -19.6815 │ Free En. Data: -19.6185 │ Learning Rate: 0.00971
# Epoch 243/2000 │ Loss: -0.0187 │ Modes: 79 │ Free En. Model: -19.5590 │ Free En. Data: -19.5191 │ Learning Rate: 0.00971
# Epoch 244/2000 │ Loss: -0.0130 │ Modes: 84 │ Free En. Model: -19.4301 │ Free En. Data: -19.4361 │ Learning Rate: 0.00971
# Epoch 245/2000 │ Loss: -0.0207 │ Modes: 82 │ Free En. Model: -19.3744 │ Free En. Data: -19.3497 │ Learning Rate: 0.00971
# Epoch 246/2000 │ Loss: +0.0004 │ Modes: 84 │ Free En. Model: -19.2473 │ Free En. Data: -19.2669 │ Learning Rate: 0.00971
# Epoch 247/2000 │ Loss: -0.0192 │ Modes: 78 │ Free En. Model: -19.2001 │ Free En. Data: -19.1759 │ Learning Rate: 0.00971
# Epoch 248/2000 │ Loss: +0.0006 │ Modes: 86 │ Free En. Model: -19.0633 │ Free En. Data: -19.0957 │ Learning Rate: 0.00970
# Epoch 249/2000 │ Loss: -0.0174 │ Modes: 79 │ Free En. Model: -19.0320 │ Free En. Data: -18.9969 │ Learning Rate: 0.00970
# Epoch 250/2000 │ Loss: -0.0018 │ Modes: 85 │ Free En. Model: -18.9225 │ Free En. Data: -18.9175 │ Learning Rate: 0.00970
# Epoch 251/2000 │ Loss: -0.0325 │ Modes: 81 │ Free En. Model: -18.8001 │ Free En. Data: -18.8049 │ Learning Rate: 0.00970
# Epoch 252/2000 │ Loss: +0.0060 │ Modes: 82 │ Free En. Model: -18.7079 │ Free En. Data: -18.7236 │ Learning Rate: 0.00970
# Epoch 253/2000 │ Loss: -0.0276 │ Modes: 78 │ Free En. Model: -18.5989 │ Free En. Data: -18.6072 │ Learning Rate: 0.00970
# Epoch 254/2000 │ Loss: +0.0219 │ Modes: 81 │ Free En. Model: -18.5538 │ Free En. Data: -18.5226 │ Learning Rate: 0.00970
# Epoch 255/2000 │ Loss: -0.0213 │ Modes: 76 │ Free En. Model: -18.5044 │ Free En. Data: -18.4212 │ Learning Rate: 0.00970
# Epoch 256/2000 │ Loss: -0.0147 │ Modes: 74 │ Free En. Model: -18.3648 │ Free En. Data: -18.3177 │ Learning Rate: 0.00969
# Epoch 257/2000 │ Loss: +0.0020 │ Modes: 92 │ Free En. Model: -18.1925 │ Free En. Data: -18.1971 │ Learning Rate: 0.00969
# Epoch 258/2000 │ Loss: -0.0358 │ Modes: 83 │ Free En. Model: -18.0308 │ Free En. Data: -18.0666 │ Learning Rate: 0.00969
# Epoch 259/2000 │ Loss: +0.0135 │ Modes: 80 │ Free En. Model: -18.0180 │ Free En. Data: -17.9419 │ Learning Rate: 0.00969
# Epoch 260/2000 │ Loss: -0.0449 │ Modes: 85 │ Free En. Model: -17.8827 │ Free En. Data: -17.8434 │ Learning Rate: 0.00969
# Epoch 261/2000 │ Loss: +0.0134 │ Modes: 86 │ Free En. Model: -17.7141 │ Free En. Data: -17.7453 │ Learning Rate: 0.00969
# Epoch 262/2000 │ Loss: -0.0310 │ Modes: 76 │ Free En. Model: -17.6654 │ Free En. Data: -17.6476 │ Learning Rate: 0.00969
# Epoch 263/2000 │ Loss: +0.0175 │ Modes: 90 │ Free En. Model: -17.5005 │ Free En. Data: -17.5598 │ Learning Rate: 0.00968
# Epoch 264/2000 │ Loss: -0.0456 │ Modes: 81 │ Free En. Model: -17.5521 │ Free En. Data: -17.4315 │ Learning Rate: 0.00968
# Epoch 265/2000 │ Loss: +0.0062 │ Modes: 82 │ Free En. Model: -17.3600 │ Free En. Data: -17.3221 │ Learning Rate: 0.00968
# Epoch 266/2000 │ Loss: -0.0114 │ Modes: 85 │ Free En. Model: -17.1884 │ Free En. Data: -17.2544 │ Learning Rate: 0.00968
# Epoch 267/2000 │ Loss: -0.0208 │ Modes: 78 │ Free En. Model: -17.1501 │ Free En. Data: -17.1228 │ Learning Rate: 0.00968
# Epoch 268/2000 │ Loss: +0.0055 │ Modes: 78 │ Free En. Model: -17.0654 │ Free En. Data: -17.0290 │ Learning Rate: 0.00968
# Epoch 269/2000 │ Loss: -0.0542 │ Modes: 87 │ Free En. Model: -16.9205 │ Free En. Data: -16.8972 │ Learning Rate: 0.00968
# Epoch 270/2000 │ Loss: +0.0354 │ Modes: 78 │ Free En. Model: -16.7313 │ Free En. Data: -16.7777 │ Learning Rate: 0.00968
# Epoch 271/2000 │ Loss: -0.0451 │ Modes: 85 │ Free En. Model: -16.6569 │ Free En. Data: -16.6726 │ Learning Rate: 0.00967
# Epoch 272/2000 │ Loss: -0.0080 │ Modes: 93 │ Free En. Model: -16.4880 │ Free En. Data: -16.5742 │ Learning Rate: 0.00967
# Epoch 273/2000 │ Loss: -0.0159 │ Modes: 88 │ Free En. Model: -16.4416 │ Free En. Data: -16.4532 │ Learning Rate: 0.00967
# Epoch 274/2000 │ Loss: +0.0012 │ Modes: 93 │ Free En. Model: -16.2444 │ Free En. Data: -16.3526 │ Learning Rate: 0.00967
# Epoch 275/2000 │ Loss: -0.0239 │ Modes: 89 │ Free En. Model: -16.1607 │ Free En. Data: -16.2090 │ Learning Rate: 0.00967
# Epoch 276/2000 │ Loss: -0.0109 │ Modes: 84 │ Free En. Model: -15.9760 │ Free En. Data: -16.0985 │ Learning Rate: 0.00967
# Epoch 277/2000 │ Loss: -0.0232 │ Modes: 80 │ Free En. Model: -15.9257 │ Free En. Data: -15.9838 │ Learning Rate: 0.00967
# Epoch 278/2000 │ Loss: -0.0223 │ Modes: 82 │ Free En. Model: -15.7811 │ Free En. Data: -15.8671 │ Learning Rate: 0.00966
# Epoch 279/2000 │ Loss: -0.0060 │ Modes: 85 │ Free En. Model: -15.7395 │ Free En. Data: -15.7718 │ Learning Rate: 0.00966
# Epoch 280/2000 │ Loss: -0.0105 │ Modes: 95 │ Free En. Model: -15.5768 │ Free En. Data: -15.6893 │ Learning Rate: 0.00966
# Epoch 281/2000 │ Loss: -0.0177 │ Modes: 87 │ Free En. Model: -15.5152 │ Free En. Data: -15.5885 │ Learning Rate: 0.00966
# Epoch 282/2000 │ Loss: -0.0265 │ Modes: 78 │ Free En. Model: -15.4826 │ Free En. Data: -15.4732 │ Learning Rate: 0.00966
# Epoch 283/2000 │ Loss: -0.0379 │ Modes: 85 │ Free En. Model: -15.2230 │ Free En. Data: -15.3655 │ Learning Rate: 0.00966
# Epoch 284/2000 │ Loss: +0.0156 │ Modes: 77 │ Free En. Model: -15.3744 │ Free En. Data: -15.2488 │ Learning Rate: 0.00965
# Epoch 285/2000 │ Loss: +0.0211 │ Modes: 81 │ Free En. Model: -15.2165 │ Free En. Data: -15.1590 │ Learning Rate: 0.00965
# Epoch 286/2000 │ Loss: -0.0825 │ Modes: 86 │ Free En. Model: -14.9556 │ Free En. Data: -15.0485 │ Learning Rate: 0.00965
# Epoch 287/2000 │ Loss: +0.0098 │ Modes: 80 │ Free En. Model: -15.0520 │ Free En. Data: -14.9002 │ Learning Rate: 0.00965
# Epoch 288/2000 │ Loss: -0.0134 │ Modes: 85 │ Free En. Model: -14.6875 │ Free En. Data: -14.7864 │ Learning Rate: 0.00965
# Epoch 289/2000 │ Loss: -0.0330 │ Modes: 76 │ Free En. Model: -14.6820 │ Free En. Data: -14.6707 │ Learning Rate: 0.00965
# Epoch 290/2000 │ Loss: +0.0017 │ Modes: 81 │ Free En. Model: -14.5304 │ Free En. Data: -14.5966 │ Learning Rate: 0.00965
# Epoch 291/2000 │ Loss: -0.0491 │ Modes: 85 │ Free En. Model: -14.4532 │ Free En. Data: -14.4598 │ Learning Rate: 0.00964
# Epoch 292/2000 │ Loss: -0.0039 │ Modes: 89 │ Free En. Model: -14.3869 │ Free En. Data: -14.3518 │ Learning Rate: 0.00964
# Epoch 293/2000 │ Loss: -0.0366 │ Modes: 85 │ Free En. Model: -14.1490 │ Free En. Data: -14.2524 │ Learning Rate: 0.00964
# Epoch 294/2000 │ Loss: -0.0254 │ Modes: 83 │ Free En. Model: -14.1665 │ Free En. Data: -14.1414 │ Learning Rate: 0.00964
# Epoch 295/2000 │ Loss: +0.0342 │ Modes: 74 │ Free En. Model: -14.1415 │ Free En. Data: -14.0516 │ Learning Rate: 0.00964
# Epoch 296/2000 │ Loss: -0.0543 │ Modes: 89 │ Free En. Model: -13.8920 │ Free En. Data: -13.9569 │ Learning Rate: 0.00964
# Epoch 297/2000 │ Loss: -0.0173 │ Modes: 78 │ Free En. Model: -13.8888 │ Free En. Data: -13.8415 │ Learning Rate: 0.00963
# Epoch 298/2000 │ Loss: -0.0521 │ Modes: 81 │ Free En. Model: -13.6456 │ Free En. Data: -13.7479 │ Learning Rate: 0.00963
# Epoch 299/2000 │ Loss: -0.0139 │ Modes: 85 │ Free En. Model: -13.6399 │ Free En. Data: -13.6510 │ Learning Rate: 0.00963
# Epoch 300/2000 │ Loss: -0.0138 │ Modes: 78 │ Free En. Model: -13.4545 │ Free En. Data: -13.5704 │ Learning Rate: 0.00963
# Epoch 301/2000 │ Loss: -0.0426 │ Modes: 92 │ Free En. Model: -13.3574 │ Free En. Data: -13.4624 │ Learning Rate: 0.00963
# Epoch 302/2000 │ Loss: -0.0136 │ Modes: 85 │ Free En. Model: -13.2962 │ Free En. Data: -13.3692 │ Learning Rate: 0.00963
# Epoch 303/2000 │ Loss: -0.0021 │ Modes: 82 │ Free En. Model: -13.2778 │ Free En. Data: -13.3136 │ Learning Rate: 0.00963
# Epoch 304/2000 │ Loss: -0.0848 │ Modes: 82 │ Free En. Model: -13.1765 │ Free En. Data: -13.2191 │ Learning Rate: 0.00962
# Epoch 305/2000 │ Loss: +0.0233 │ Modes: 79 │ Free En. Model: -13.1552 │ Free En. Data: -13.1426 │ Learning Rate: 0.00962
# Epoch 306/2000 │ Loss: -0.0384 │ Modes: 79 │ Free En. Model: -13.0119 │ Free En. Data: -13.0676 │ Learning Rate: 0.00962
# Epoch 307/2000 │ Loss: -0.0540 │ Modes: 82 │ Free En. Model: -12.9391 │ Free En. Data: -12.9778 │ Learning Rate: 0.00962
# Epoch 308/2000 │ Loss: +0.0049 │ Modes: 90 │ Free En. Model: -12.8240 │ Free En. Data: -12.8802 │ Learning Rate: 0.00962
# Epoch 309/2000 │ Loss: -0.0581 │ Modes: 84 │ Free En. Model: -12.6979 │ Free En. Data: -12.7977 │ Learning Rate: 0.00962
# Epoch 310/2000 │ Loss: -0.0341 │ Modes: 78 │ Free En. Model: -12.6895 │ Free En. Data: -12.7198 │ Learning Rate: 0.00961
# Epoch 311/2000 │ Loss: -0.0140 │ Modes: 77 │ Free En. Model: -12.6111 │ Free En. Data: -12.6477 │ Learning Rate: 0.00961
# Epoch 312/2000 │ Loss: -0.0336 │ Modes: 87 │ Free En. Model: -12.5313 │ Free En. Data: -12.5537 │ Learning Rate: 0.00961
# Epoch 313/2000 │ Loss: -0.0546 │ Modes: 88 │ Free En. Model: -12.3845 │ Free En. Data: -12.4955 │ Learning Rate: 0.00961
# Epoch 314/2000 │ Loss: -0.0212 │ Modes: 74 │ Free En. Model: -12.5242 │ Free En. Data: -12.4067 │ Learning Rate: 0.00961
# Epoch 315/2000 │ Loss: -0.0342 │ Modes: 79 │ Free En. Model: -12.3250 │ Free En. Data: -12.3427 │ Learning Rate: 0.00961
# Epoch 316/2000 │ Loss: -0.0437 │ Modes: 85 │ Free En. Model: -12.2924 │ Free En. Data: -12.2972 │ Learning Rate: 0.00960
# Epoch 317/2000 │ Loss: -0.0304 │ Modes: 80 │ Free En. Model: -12.1874 │ Free En. Data: -12.2038 │ Learning Rate: 0.00960
# Epoch 318/2000 │ Loss: -0.0464 │ Modes: 78 │ Free En. Model: -12.1795 │ Free En. Data: -12.1633 │ Learning Rate: 0.00960
# Epoch 319/2000 │ Loss: -0.0488 │ Modes: 81 │ Free En. Model: -12.0320 │ Free En. Data: -12.1003 │ Learning Rate: 0.00960
# Epoch 320/2000 │ Loss: -0.0433 │ Modes: 78 │ Free En. Model: -11.9379 │ Free En. Data: -12.0574 │ Learning Rate: 0.00960
# Epoch 321/2000 │ Loss: -0.0391 │ Modes: 83 │ Free En. Model: -11.9344 │ Free En. Data: -12.0160 │ Learning Rate: 0.00960
# Epoch 322/2000 │ Loss: -0.0495 │ Modes: 83 │ Free En. Model: -11.9107 │ Free En. Data: -11.9655 │ Learning Rate: 0.00959
# Epoch 323/2000 │ Loss: -0.0385 │ Modes: 78 │ Free En. Model: -11.9737 │ Free En. Data: -11.9429 │ Learning Rate: 0.00959
# Epoch 324/2000 │ Loss: -0.0732 │ Modes: 86 │ Free En. Model: -11.7902 │ Free En. Data: -11.8677 │ Learning Rate: 0.00959
# Epoch 325/2000 │ Loss: -0.0230 │ Modes: 75 │ Free En. Model: -11.7358 │ Free En. Data: -11.8153 │ Learning Rate: 0.00959
# Epoch 326/2000 │ Loss: -0.0614 │ Modes: 76 │ Free En. Model: -11.6729 │ Free En. Data: -11.8151 │ Learning Rate: 0.00959
# Epoch 327/2000 │ Loss: -0.0624 │ Modes: 85 │ Free En. Model: -11.6729 │ Free En. Data: -11.7430 │ Learning Rate: 0.00958
# Epoch 328/2000 │ Loss: -0.0634 │ Modes: 92 │ Free En. Model: -11.5634 │ Free En. Data: -11.7204 │ Learning Rate: 0.00958
# Epoch 329/2000 │ Loss: -0.0380 │ Modes: 81 │ Free En. Model: -11.6283 │ Free En. Data: -11.7093 │ Learning Rate: 0.00958
# Epoch 330/2000 │ Loss: -0.0972 │ Modes: 75 │ Free En. Model: -11.5897 │ Free En. Data: -11.6645 │ Learning Rate: 0.00958
# Epoch 331/2000 │ Loss: -0.0311 │ Modes: 72 │ Free En. Model: -11.6691 │ Free En. Data: -11.6705 │ Learning Rate: 0.00958
# Epoch 332/2000 │ Loss: -0.0809 │ Modes: 67 │ Free En. Model: -11.6676 │ Free En. Data: -11.6764 │ Learning Rate: 0.00958
# Epoch 333/2000 │ Loss: -0.0750 │ Modes: 86 │ Free En. Model: -11.4639 │ Free En. Data: -11.6389 │ Learning Rate: 0.00957
# Epoch 334/2000 │ Loss: -0.0571 │ Modes: 77 │ Free En. Model: -11.6191 │ Free En. Data: -11.6281 │ Learning Rate: 0.00957
# Epoch 335/2000 │ Loss: -0.0690 │ Modes: 73 │ Free En. Model: -11.5717 │ Free En. Data: -11.6472 │ Learning Rate: 0.00957
# Epoch 336/2000 │ Loss: -0.1045 │ Modes: 87 │ Free En. Model: -11.5059 │ Free En. Data: -11.6531 │ Learning Rate: 0.00957
# Epoch 337/2000 │ Loss: -0.0529 │ Modes: 77 │ Free En. Model: -11.5973 │ Free En. Data: -11.6367 │ Learning Rate: 0.00957
# Epoch 338/2000 │ Loss: -0.0989 │ Modes: 73 │ Free En. Model: -11.5471 │ Free En. Data: -11.6344 │ Learning Rate: 0.00956
# Epoch 339/2000 │ Loss: -0.0532 │ Modes: 76 │ Free En. Model: -11.6386 │ Free En. Data: -11.6595 │ Learning Rate: 0.00956
# Epoch 340/2000 │ Loss: -0.1167 │ Modes: 74 │ Free En. Model: -11.5202 │ Free En. Data: -11.6685 │ Learning Rate: 0.00956
# Epoch 341/2000 │ Loss: -0.0939 │ Modes: 81 │ Free En. Model: -11.5855 │ Free En. Data: -11.6947 │ Learning Rate: 0.00956
# Epoch 342/2000 │ Loss: -0.0879 │ Modes: 78 │ Free En. Model: -11.5797 │ Free En. Data: -11.6832 │ Learning Rate: 0.00956
# Epoch 343/2000 │ Loss: -0.0984 │ Modes: 75 │ Free En. Model: -11.5994 │ Free En. Data: -11.7221 │ Learning Rate: 0.00956
# Epoch 344/2000 │ Loss: -0.1034 │ Modes: 70 │ Free En. Model: -11.7446 │ Free En. Data: -11.7814 │ Learning Rate: 0.00955
# Epoch 345/2000 │ Loss: -0.0871 │ Modes: 74 │ Free En. Model: -11.6731 │ Free En. Data: -11.7716 │ Learning Rate: 0.00955
# Epoch 346/2000 │ Loss: -0.1334 │ Modes: 80 │ Free En. Model: -11.6027 │ Free En. Data: -11.8326 │ Learning Rate: 0.00955
# Epoch 347/2000 │ Loss: -0.1056 │ Modes: 79 │ Free En. Model: -11.7023 │ Free En. Data: -11.8622 │ Learning Rate: 0.00955
# Epoch 348/2000 │ Loss: -0.1292 │ Modes: 84 │ Free En. Model: -11.6911 │ Free En. Data: -11.9263 │ Learning Rate: 0.00955
# Epoch 349/2000 │ Loss: -0.1297 │ Modes: 70 │ Free En. Model: -11.8088 │ Free En. Data: -11.9193 │ Learning Rate: 0.00954
# Epoch 350/2000 │ Loss: -0.1019 │ Modes: 68 │ Free En. Model: -11.8972 │ Free En. Data: -11.9953 │ Learning Rate: 0.00954
# Epoch 351/2000 │ Loss: -0.1485 │ Modes: 72 │ Free En. Model: -11.8296 │ Free En. Data: -12.0539 │ Learning Rate: 0.00954
# Epoch 352/2000 │ Loss: -0.1563 │ Modes: 64 │ Free En. Model: -12.0069 │ Free En. Data: -12.1097 │ Learning Rate: 0.00954
# Epoch 353/2000 │ Loss: -0.1070 │ Modes: 74 │ Free En. Model: -12.0031 │ Free En. Data: -12.1349 │ Learning Rate: 0.00954
# Epoch 354/2000 │ Loss: -0.1553 │ Modes: 80 │ Free En. Model: -11.9194 │ Free En. Data: -12.2183 │ Learning Rate: 0.00953
# Epoch 355/2000 │ Loss: -0.1576 │ Modes: 69 │ Free En. Model: -12.1071 │ Free En. Data: -12.2676 │ Learning Rate: 0.00953
# Epoch 356/2000 │ Loss: -0.1559 │ Modes: 73 │ Free En. Model: -12.2114 │ Free En. Data: -12.3629 │ Learning Rate: 0.00953
# Epoch 357/2000 │ Loss: -0.1641 │ Modes: 70 │ Free En. Model: -12.2769 │ Free En. Data: -12.4018 │ Learning Rate: 0.00953
# Epoch 358/2000 │ Loss: -0.1917 │ Modes: 70 │ Free En. Model: -12.3023 │ Free En. Data: -12.4921 │ Learning Rate: 0.00953
# Epoch 359/2000 │ Loss: -0.1695 │ Modes: 73 │ Free En. Model: -12.4046 │ Free En. Data: -12.5928 │ Learning Rate: 0.00952
# Epoch 360/2000 │ Loss: -0.1823 │ Modes: 67 │ Free En. Model: -12.4489 │ Free En. Data: -12.6585 │ Learning Rate: 0.00952
# Epoch 361/2000 │ Loss: -0.1930 │ Modes: 72 │ Free En. Model: -12.4081 │ Free En. Data: -12.7353 │ Learning Rate: 0.00952
# Epoch 362/2000 │ Loss: -0.2042 │ Modes: 65 │ Free En. Model: -12.6166 │ Free En. Data: -12.8345 │ Learning Rate: 0.00952
# Epoch 363/2000 │ Loss: -0.2109 │ Modes: 65 │ Free En. Model: -12.6345 │ Free En. Data: -12.9036 │ Learning Rate: 0.00952
# Epoch 364/2000 │ Loss: -0.2008 │ Modes: 63 │ Free En. Model: -12.8424 │ Free En. Data: -13.0088 │ Learning Rate: 0.00951
# Epoch 365/2000 │ Loss: -0.2141 │ Modes: 63 │ Free En. Model: -12.8715 │ Free En. Data: -13.0869 │ Learning Rate: 0.00951
# Epoch 366/2000 │ Loss: -0.2328 │ Modes: 65 │ Free En. Model: -12.9588 │ Free En. Data: -13.2345 │ Learning Rate: 0.00951
# Epoch 367/2000 │ Loss: -0.2127 │ Modes: 64 │ Free En. Model: -13.0700 │ Free En. Data: -13.3082 │ Learning Rate: 0.00951
# Epoch 368/2000 │ Loss: -0.2361 │ Modes: 65 │ Free En. Model: -13.1067 │ Free En. Data: -13.4176 │ Learning Rate: 0.00951
# Epoch 369/2000 │ Loss: -0.2555 │ Modes: 62 │ Free En. Model: -13.2795 │ Free En. Data: -13.5372 │ Learning Rate: 0.00950
# Epoch 370/2000 │ Loss: -0.2586 │ Modes: 66 │ Free En. Model: -13.2826 │ Free En. Data: -13.6277 │ Learning Rate: 0.00950
# Epoch 371/2000 │ Loss: -0.2661 │ Modes: 64 │ Free En. Model: -13.4563 │ Free En. Data: -13.7726 │ Learning Rate: 0.00950
# Epoch 372/2000 │ Loss: -0.2694 │ Modes: 66 │ Free En. Model: -13.5757 │ Free En. Data: -13.8716 │ Learning Rate: 0.00950
# Epoch 373/2000 │ Loss: -0.2809 │ Modes: 55 │ Free En. Model: -13.6968 │ Free En. Data: -14.0065 │ Learning Rate: 0.00949
# Epoch 374/2000 │ Loss: -0.2694 │ Modes: 56 │ Free En. Model: -13.8984 │ Free En. Data: -14.1179 │ Learning Rate: 0.00949
# Epoch 375/2000 │ Loss: -0.2955 │ Modes: 61 │ Free En. Model: -13.9454 │ Free En. Data: -14.2605 │ Learning Rate: 0.00949
# Epoch 376/2000 │ Loss: -0.2931 │ Modes: 55 │ Free En. Model: -14.0619 │ Free En. Data: -14.3726 │ Learning Rate: 0.00949
# Epoch 377/2000 │ Loss: -0.3077 │ Modes: 62 │ Free En. Model: -14.1440 │ Free En. Data: -14.5165 │ Learning Rate: 0.00949
# Epoch 378/2000 │ Loss: -0.3088 │ Modes: 57 │ Free En. Model: -14.2894 │ Free En. Data: -14.6273 │ Learning Rate: 0.00948
# Epoch 379/2000 │ Loss: -0.3290 │ Modes: 50 │ Free En. Model: -14.4600 │ Free En. Data: -14.8110 │ Learning Rate: 0.00948
# Epoch 380/2000 │ Loss: -0.3146 │ Modes: 52 │ Free En. Model: -14.6199 │ Free En. Data: -14.9022 │ Learning Rate: 0.00948
# Epoch 381/2000 │ Loss: -0.3173 │ Modes: 58 │ Free En. Model: -14.6477 │ Free En. Data: -15.0563 │ Learning Rate: 0.00948
# Epoch 382/2000 │ Loss: -0.3292 │ Modes: 51 │ Free En. Model: -14.8321 │ Free En. Data: -15.1967 │ Learning Rate: 0.00947
# Epoch 383/2000 │ Loss: -0.3319 │ Modes: 48 │ Free En. Model: -14.9745 │ Free En. Data: -15.3191 │ Learning Rate: 0.00947
# Epoch 384/2000 │ Loss: -0.3261 │ Modes: 49 │ Free En. Model: -15.0881 │ Free En. Data: -15.4424 │ Learning Rate: 0.00947
# Epoch 385/2000 │ Loss: -0.3147 │ Modes: 54 │ Free En. Model: -15.2838 │ Free En. Data: -15.6055 │ Learning Rate: 0.00947
# Epoch 386/2000 │ Loss: -0.3748 │ Modes: 54 │ Free En. Model: -15.3132 │ Free En. Data: -15.7213 │ Learning Rate: 0.00947
# Epoch 387/2000 │ Loss: -0.3542 │ Modes: 52 │ Free En. Model: -15.4669 │ Free En. Data: -15.8710 │ Learning Rate: 0.00946
# Epoch 388/2000 │ Loss: -0.3419 │ Modes: 48 │ Free En. Model: -15.6108 │ Free En. Data: -16.0097 │ Learning Rate: 0.00946
# Epoch 389/2000 │ Loss: -0.3367 │ Modes: 49 │ Free En. Model: -15.8752 │ Free En. Data: -16.1789 │ Learning Rate: 0.00946
# Epoch 390/2000 │ Loss: -0.3827 │ Modes: 51 │ Free En. Model: -15.8284 │ Free En. Data: -16.3265 │ Learning Rate: 0.00946
# Epoch 391/2000 │ Loss: -0.3459 │ Modes: 48 │ Free En. Model: -16.0743 │ Free En. Data: -16.4687 │ Learning Rate: 0.00945
# Epoch 392/2000 │ Loss: -0.3401 │ Modes: 46 │ Free En. Model: -16.2321 │ Free En. Data: -16.6178 │ Learning Rate: 0.00945
# Epoch 393/2000 │ Loss: -0.3850 │ Modes: 51 │ Free En. Model: -16.3703 │ Free En. Data: -16.7472 │ Learning Rate: 0.00945
# Epoch 394/2000 │ Loss: -0.3824 │ Modes: 48 │ Free En. Model: -16.5320 │ Free En. Data: -16.9065 │ Learning Rate: 0.00945
# Epoch 395/2000 │ Loss: -0.3662 │ Modes: 47 │ Free En. Model: -16.6526 │ Free En. Data: -17.0538 │ Learning Rate: 0.00945
# Epoch 396/2000 │ Loss: -0.3348 │ Modes: 44 │ Free En. Model: -16.8520 │ Free En. Data: -17.2066 │ Learning Rate: 0.00944
# Epoch 397/2000 │ Loss: -0.3553 │ Modes: 47 │ Free En. Model: -16.9474 │ Free En. Data: -17.3586 │ Learning Rate: 0.00944
# ...
# Epoch 1870/2000 │ Loss: -0.0074 │ Modes: 24 │ Free En. Model: -23.8332 │ Free En. Data: -23.9946 │ Learning Rate: 0.00118
# Epoch 1871/2000 │ Loss: -0.0261 │ Modes: 22 │ Free En. Model: -23.8787 │ Free En. Data: -23.9911 │ Learning Rate: 0.00118
# Epoch 1872/2000 │ Loss: -0.0093 │ Modes: 17 │ Free En. Model: -23.9147 │ Free En. Data: -23.9927 │ Learning Rate: 0.00117
# Epoch 1873/2000 │ Loss: -0.0103 │ Modes: 24 │ Free En. Model: -23.8493 │ Free En. Data: -23.9872 │ Learning Rate: 0.00117
# Epoch 1874/2000 │ Loss: -0.0058 │ Modes: 21 │ Free En. Model: -23.8697 │ Free En. Data: -23.9859 │ Learning Rate: 0.00117
# Epoch 1875/2000 │ Loss: -0.0087 │ Modes: 24 │ Free En. Model: -23.8733 │ Free En. Data: -23.9830 │ Learning Rate: 0.00117
# Epoch 1876/2000 │ Loss: -0.0035 │ Modes: 28 │ Free En. Model: -23.8298 │ Free En. Data: -23.9850 │ Learning Rate: 0.00117
# Epoch 1877/2000 │ Loss: -0.0027 │ Modes: 23 │ Free En. Model: -23.8933 │ Free En. Data: -23.9880 │ Learning Rate: 0.00117
# Epoch 1878/2000 │ Loss: -0.0087 │ Modes: 18 │ Free En. Model: -23.9022 │ Free En. Data: -23.9864 │ Learning Rate: 0.00117
# Epoch 1879/2000 │ Loss: -0.0138 │ Modes: 25 │ Free En. Model: -23.8525 │ Free En. Data: -23.9820 │ Learning Rate: 0.00117
# Epoch 1880/2000 │ Loss: -0.0164 │ Modes: 24 │ Free En. Model: -23.8202 │ Free En. Data: -23.9796 │ Learning Rate: 0.00117
# Epoch 1881/2000 │ Loss: -0.0043 │ Modes: 22 │ Free En. Model: -23.8438 │ Free En. Data: -23.9754 │ Learning Rate: 0.00117
# Epoch 1882/2000 │ Loss: +0.0014 │ Modes: 18 │ Free En. Model: -23.8968 │ Free En. Data: -23.9750 │ Learning Rate: 0.00117
# Epoch 1883/2000 │ Loss: -0.0210 │ Modes: 25 │ Free En. Model: -23.8309 │ Free En. Data: -23.9758 │ Learning Rate: 0.00117
# Epoch 1884/2000 │ Loss: -0.0115 │ Modes: 24 │ Free En. Model: -23.8255 │ Free En. Data: -23.9728 │ Learning Rate: 0.00117
# Epoch 1885/2000 │ Loss: -0.0042 │ Modes: 24 │ Free En. Model: -23.8367 │ Free En. Data: -23.9665 │ Learning Rate: 0.00116
# Epoch 1886/2000 │ Loss: -0.0069 │ Modes: 23 │ Free En. Model: -23.8261 │ Free En. Data: -23.9674 │ Learning Rate: 0.00116
# Epoch 1887/2000 │ Loss: -0.0080 │ Modes: 20 │ Free En. Model: -23.8683 │ Free En. Data: -23.9683 │ Learning Rate: 0.00116
# Epoch 1888/2000 │ Loss: -0.0125 │ Modes: 23 │ Free En. Model: -23.8186 │ Free En. Data: -23.9720 │ Learning Rate: 0.00116
# Epoch 1889/2000 │ Loss: -0.0072 │ Modes: 23 │ Free En. Model: -23.8356 │ Free En. Data: -23.9689 │ Learning Rate: 0.00116
# Epoch 1890/2000 │ Loss: -0.0007 │ Modes: 24 │ Free En. Model: -23.8386 │ Free En. Data: -23.9645 │ Learning Rate: 0.00116
# Epoch 1891/2000 │ Loss: -0.0025 │ Modes: 23 │ Free En. Model: -23.8392 │ Free En. Data: -23.9615 │ Learning Rate: 0.00116
# Epoch 1892/2000 │ Loss: -0.0072 │ Modes: 21 │ Free En. Model: -23.8189 │ Free En. Data: -23.9624 │ Learning Rate: 0.00116
# Epoch 1893/2000 │ Loss: -0.0185 │ Modes: 26 │ Free En. Model: -23.8298 │ Free En. Data: -23.9629 │ Learning Rate: 0.00116
# Epoch 1894/2000 │ Loss: -0.0013 │ Modes: 26 │ Free En. Model: -23.8277 │ Free En. Data: -23.9627 │ Learning Rate: 0.00116
# Epoch 1895/2000 │ Loss: -0.0126 │ Modes: 23 │ Free En. Model: -23.8132 │ Free En. Data: -23.9555 │ Learning Rate: 0.00116
# Epoch 1896/2000 │ Loss: -0.0063 │ Modes: 20 │ Free En. Model: -23.8556 │ Free En. Data: -23.9515 │ Learning Rate: 0.00116
# Epoch 1897/2000 │ Loss: -0.0140 │ Modes: 20 │ Free En. Model: -23.8615 │ Free En. Data: -23.9542 │ Learning Rate: 0.00116
# Epoch 1898/2000 │ Loss: -0.0032 │ Modes: 22 │ Free En. Model: -23.8431 │ Free En. Data: -23.9548 │ Learning Rate: 0.00116
# Epoch 1899/2000 │ Loss: -0.0009 │ Modes: 23 │ Free En. Model: -23.8066 │ Free En. Data: -23.9518 │ Learning Rate: 0.00115
# Epoch 1900/2000 │ Loss: -0.0082 │ Modes: 23 │ Free En. Model: -23.8155 │ Free En. Data: -23.9532 │ Learning Rate: 0.00115
# Epoch 1901/2000 │ Loss: -0.0277 │ Modes: 22 │ Free En. Model: -23.8146 │ Free En. Data: -23.9526 │ Learning Rate: 0.00115
# Epoch 1902/2000 │ Loss: +0.0008 │ Modes: 20 │ Free En. Model: -23.8379 │ Free En. Data: -23.9477 │ Learning Rate: 0.00115
# Epoch 1903/2000 │ Loss: -0.0096 │ Modes: 23 │ Free En. Model: -23.8222 │ Free En. Data: -23.9495 │ Learning Rate: 0.00115
# Epoch 1904/2000 │ Loss: -0.0126 │ Modes: 23 │ Free En. Model: -23.8183 │ Free En. Data: -23.9507 │ Learning Rate: 0.00115
# Epoch 1905/2000 │ Loss: -0.0164 │ Modes: 19 │ Free En. Model: -23.8534 │ Free En. Data: -23.9538 │ Learning Rate: 0.00115
# Epoch 1906/2000 │ Loss: -0.0078 │ Modes: 23 │ Free En. Model: -23.8208 │ Free En. Data: -23.9531 │ Learning Rate: 0.00115
# Epoch 1907/2000 │ Loss: -0.0122 │ Modes: 22 │ Free En. Model: -23.8396 │ Free En. Data: -23.9565 │ Learning Rate: 0.00115
# Epoch 1908/2000 │ Loss: -0.0034 │ Modes: 23 │ Free En. Model: -23.8068 │ Free En. Data: -23.9561 │ Learning Rate: 0.00115
# Epoch 1909/2000 │ Loss: -0.0262 │ Modes: 23 │ Free En. Model: -23.8170 │ Free En. Data: -23.9544 │ Learning Rate: 0.00115
# Epoch 1910/2000 │ Loss: -0.0039 │ Modes: 24 │ Free En. Model: -23.8360 │ Free En. Data: -23.9547 │ Learning Rate: 0.00115
# Epoch 1911/2000 │ Loss: -0.0141 │ Modes: 22 │ Free En. Model: -23.8428 │ Free En. Data: -23.9550 │ Learning Rate: 0.00115
# Epoch 1912/2000 │ Loss: -0.0081 │ Modes: 22 │ Free En. Model: -23.8285 │ Free En. Data: -23.9527 │ Learning Rate: 0.00115
# Epoch 1913/2000 │ Loss: -0.0115 │ Modes: 27 │ Free En. Model: -23.8135 │ Free En. Data: -23.9525 │ Learning Rate: 0.00115
# Epoch 1914/2000 │ Loss: -0.0193 │ Modes: 26 │ Free En. Model: -23.7851 │ Free En. Data: -23.9529 │ Learning Rate: 0.00114
# Epoch 1915/2000 │ Loss: -0.0193 │ Modes: 22 │ Free En. Model: -23.8220 │ Free En. Data: -23.9533 │ Learning Rate: 0.00114
# Epoch 1916/2000 │ Loss: -0.0156 │ Modes: 20 │ Free En. Model: -23.8507 │ Free En. Data: -23.9546 │ Learning Rate: 0.00114
# Epoch 1917/2000 │ Loss: -0.0245 │ Modes: 20 │ Free En. Model: -23.8581 │ Free En. Data: -23.9549 │ Learning Rate: 0.00114
# Epoch 1918/2000 │ Loss: -0.0065 │ Modes: 27 │ Free En. Model: -23.8079 │ Free En. Data: -23.9568 │ Learning Rate: 0.00114
# Epoch 1919/2000 │ Loss: +0.0101 │ Modes: 20 │ Free En. Model: -23.8375 │ Free En. Data: -23.9577 │ Learning Rate: 0.00114
# Epoch 1920/2000 │ Loss: -0.0065 │ Modes: 21 │ Free En. Model: -23.8598 │ Free En. Data: -23.9526 │ Learning Rate: 0.00114
# Epoch 1921/2000 │ Loss: -0.0176 │ Modes: 20 │ Free En. Model: -23.8571 │ Free En. Data: -23.9533 │ Learning Rate: 0.00114
# Epoch 1922/2000 │ Loss: -0.0062 │ Modes: 22 │ Free En. Model: -23.8204 │ Free En. Data: -23.9562 │ Learning Rate: 0.00114
# Epoch 1923/2000 │ Loss: -0.0108 │ Modes: 15 │ Free En. Model: -23.8855 │ Free En. Data: -23.9556 │ Learning Rate: 0.00114
# Epoch 1924/2000 │ Loss: -0.0081 │ Modes: 23 │ Free En. Model: -23.8202 │ Free En. Data: -23.9530 │ Learning Rate: 0.00114
# Epoch 1925/2000 │ Loss: -0.0209 │ Modes: 24 │ Free En. Model: -23.8062 │ Free En. Data: -23.9471 │ Learning Rate: 0.00114
# Epoch 1926/2000 │ Loss: -0.0166 │ Modes: 22 │ Free En. Model: -23.8396 │ Free En. Data: -23.9447 │ Learning Rate: 0.00114
# Epoch 1927/2000 │ Loss: -0.0158 │ Modes: 22 │ Free En. Model: -23.8292 │ Free En. Data: -23.9474 │ Learning Rate: 0.00114
# Epoch 1928/2000 │ Loss: -0.0169 │ Modes: 21 │ Free En. Model: -23.8140 │ Free En. Data: -23.9491 │ Learning Rate: 0.00114
# Epoch 1929/2000 │ Loss: -0.0182 │ Modes: 22 │ Free En. Model: -23.8305 │ Free En. Data: -23.9459 │ Learning Rate: 0.00114
# Epoch 1930/2000 │ Loss: -0.0102 │ Modes: 22 │ Free En. Model: -23.8322 │ Free En. Data: -23.9489 │ Learning Rate: 0.00113
# Epoch 1931/2000 │ Loss: -0.0112 │ Modes: 23 │ Free En. Model: -23.8504 │ Free En. Data: -23.9534 │ Learning Rate: 0.00113
# Epoch 1932/2000 │ Loss: +0.0069 │ Modes: 16 │ Free En. Model: -23.8887 │ Free En. Data: -23.9503 │ Learning Rate: 0.00113
# Epoch 1933/2000 │ Loss: -0.0073 │ Modes: 20 │ Free En. Model: -23.8416 │ Free En. Data: -23.9465 │ Learning Rate: 0.00113
# Epoch 1934/2000 │ Loss: -0.0262 │ Modes: 24 │ Free En. Model: -23.8246 │ Free En. Data: -23.9484 │ Learning Rate: 0.00113
# Epoch 1935/2000 │ Loss: -0.0151 │ Modes: 23 │ Free En. Model: -23.8180 │ Free En. Data: -23.9508 │ Learning Rate: 0.00113
# Epoch 1936/2000 │ Loss: -0.0165 │ Modes: 17 │ Free En. Model: -23.8703 │ Free En. Data: -23.9533 │ Learning Rate: 0.00113
# Epoch 1937/2000 │ Loss: -0.0017 │ Modes: 21 │ Free En. Model: -23.8465 │ Free En. Data: -23.9531 │ Learning Rate: 0.00113
# Epoch 1938/2000 │ Loss: -0.0134 │ Modes: 20 │ Free En. Model: -23.8354 │ Free En. Data: -23.9490 │ Learning Rate: 0.00113
# Epoch 1939/2000 │ Loss: -0.0117 │ Modes: 26 │ Free En. Model: -23.7824 │ Free En. Data: -23.9398 │ Learning Rate: 0.00113
# Epoch 1940/2000 │ Loss: -0.0162 │ Modes: 26 │ Free En. Model: -23.7876 │ Free En. Data: -23.9401 │ Learning Rate: 0.00113
# Epoch 1941/2000 │ Loss: -0.0144 │ Modes: 21 │ Free En. Model: -23.8084 │ Free En. Data: -23.9408 │ Learning Rate: 0.00113
# Epoch 1942/2000 │ Loss: +0.0013 │ Modes: 20 │ Free En. Model: -23.8378 │ Free En. Data: -23.9350 │ Learning Rate: 0.00113
# Epoch 1943/2000 │ Loss: -0.0191 │ Modes: 20 │ Free En. Model: -23.8239 │ Free En. Data: -23.9433 │ Learning Rate: 0.00113
# Epoch 1944/2000 │ Loss: +0.0017 │ Modes: 18 │ Free En. Model: -23.8748 │ Free En. Data: -23.9461 │ Learning Rate: 0.00113
# Epoch 1945/2000 │ Loss: -0.0043 │ Modes: 20 │ Free En. Model: -23.8332 │ Free En. Data: -23.9445 │ Learning Rate: 0.00113
# Epoch 1946/2000 │ Loss: +0.0048 │ Modes: 24 │ Free En. Model: -23.8011 │ Free En. Data: -23.9362 │ Learning Rate: 0.00113
# Epoch 1947/2000 │ Loss: -0.0209 │ Modes: 20 │ Free En. Model: -23.8094 │ Free En. Data: -23.9324 │ Learning Rate: 0.00113
# Epoch 1948/2000 │ Loss: -0.0186 │ Modes: 28 │ Free En. Model: -23.7613 │ Free En. Data: -23.9309 │ Learning Rate: 0.00112
# Epoch 1949/2000 │ Loss: -0.0132 │ Modes: 20 │ Free En. Model: -23.8425 │ Free En. Data: -23.9352 │ Learning Rate: 0.00112
# Epoch 1950/2000 │ Loss: -0.0157 │ Modes: 23 │ Free En. Model: -23.8139 │ Free En. Data: -23.9334 │ Learning Rate: 0.00112
# Epoch 1951/2000 │ Loss: -0.0227 │ Modes: 24 │ Free En. Model: -23.8116 │ Free En. Data: -23.9349 │ Learning Rate: 0.00112
# Epoch 1952/2000 │ Loss: +0.0005 │ Modes: 18 │ Free En. Model: -23.8244 │ Free En. Data: -23.9334 │ Learning Rate: 0.00112
# Epoch 1953/2000 │ Loss: -0.0084 │ Modes: 20 │ Free En. Model: -23.8210 │ Free En. Data: -23.9405 │ Learning Rate: 0.00112
# Epoch 1954/2000 │ Loss: -0.0119 │ Modes: 21 │ Free En. Model: -23.8207 │ Free En. Data: -23.9417 │ Learning Rate: 0.00112
# Epoch 1955/2000 │ Loss: -0.0041 │ Modes: 21 │ Free En. Model: -23.8326 │ Free En. Data: -23.9406 │ Learning Rate: 0.00112
# Epoch 1956/2000 │ Loss: -0.0024 │ Modes: 22 │ Free En. Model: -23.8263 │ Free En. Data: -23.9347 │ Learning Rate: 0.00112
# Epoch 1957/2000 │ Loss: -0.0164 │ Modes: 23 │ Free En. Model: -23.7919 │ Free En. Data: -23.9262 │ Learning Rate: 0.00112
# Epoch 1958/2000 │ Loss: -0.0136 │ Modes: 20 │ Free En. Model: -23.8488 │ Free En. Data: -23.9259 │ Learning Rate: 0.00112
# Epoch 1959/2000 │ Loss: -0.0035 │ Modes: 22 │ Free En. Model: -23.8178 │ Free En. Data: -23.9257 │ Learning Rate: 0.00112
# Epoch 1960/2000 │ Loss: -0.0169 │ Modes: 16 │ Free En. Model: -23.8405 │ Free En. Data: -23.9279 │ Learning Rate: 0.00112
# Epoch 1961/2000 │ Loss: -0.0096 │ Modes: 20 │ Free En. Model: -23.8237 │ Free En. Data: -23.9259 │ Learning Rate: 0.00112
# Epoch 1962/2000 │ Loss: -0.0132 │ Modes: 28 │ Free En. Model: -23.7552 │ Free En. Data: -23.9271 │ Learning Rate: 0.00112
# Epoch 1963/2000 │ Loss: -0.0054 │ Modes: 20 │ Free En. Model: -23.8301 │ Free En. Data: -23.9250 │ Learning Rate: 0.00112
# Epoch 1964/2000 │ Loss: -0.0182 │ Modes: 18 │ Free En. Model: -23.8459 │ Free En. Data: -23.9273 │ Learning Rate: 0.00112
# Epoch 1965/2000 │ Loss: -0.0103 │ Modes: 22 │ Free En. Model: -23.8087 │ Free En. Data: -23.9250 │ Learning Rate: 0.00112
# Epoch 1966/2000 │ Loss: -0.0182 │ Modes: 18 │ Free En. Model: -23.8219 │ Free En. Data: -23.9249 │ Learning Rate: 0.00112
# Epoch 1967/2000 │ Loss: -0.0049 │ Modes: 21 │ Free En. Model: -23.8040 │ Free En. Data: -23.9220 │ Learning Rate: 0.00111
# Epoch 1968/2000 │ Loss: -0.0102 │ Modes: 20 │ Free En. Model: -23.8195 │ Free En. Data: -23.9260 │ Learning Rate: 0.00111
# Epoch 1969/2000 │ Loss: -0.0155 │ Modes: 23 │ Free En. Model: -23.7874 │ Free En. Data: -23.9235 │ Learning Rate: 0.00111
# Epoch 1970/2000 │ Loss: +0.0004 │ Modes: 21 │ Free En. Model: -23.8076 │ Free En. Data: -23.9139 │ Learning Rate: 0.00111
# Epoch 1971/2000 │ Loss: -0.0126 │ Modes: 21 │ Free En. Model: -23.8141 │ Free En. Data: -23.9152 │ Learning Rate: 0.00111
# Epoch 1972/2000 │ Loss: -0.0172 │ Modes: 18 │ Free En. Model: -23.8104 │ Free En. Data: -23.9239 │ Learning Rate: 0.00111
# Epoch 1973/2000 │ Loss: -0.0110 │ Modes: 21 │ Free En. Model: -23.8010 │ Free En. Data: -23.9259 │ Learning Rate: 0.00111
# Epoch 1974/2000 │ Loss: -0.0130 │ Modes: 22 │ Free En. Model: -23.7984 │ Free En. Data: -23.9216 │ Learning Rate: 0.00111
# Epoch 1975/2000 │ Loss: -0.0063 │ Modes: 25 │ Free En. Model: -23.7869 │ Free En. Data: -23.9179 │ Learning Rate: 0.00111
# Epoch 1976/2000 │ Loss: +0.0023 │ Modes: 23 │ Free En. Model: -23.8068 │ Free En. Data: -23.9205 │ Learning Rate: 0.00111
# Epoch 1977/2000 │ Loss: -0.0168 │ Modes: 26 │ Free En. Model: -23.7781 │ Free En. Data: -23.9225 │ Learning Rate: 0.00111
# Epoch 1978/2000 │ Loss: -0.0096 │ Modes: 25 │ Free En. Model: -23.8071 │ Free En. Data: -23.9247 │ Learning Rate: 0.00111
# Epoch 1979/2000 │ Loss: -0.0081 │ Modes: 20 │ Free En. Model: -23.7983 │ Free En. Data: -23.9232 │ Learning Rate: 0.00111
# Epoch 1980/2000 │ Loss: -0.0288 │ Modes: 26 │ Free En. Model: -23.7447 │ Free En. Data: -23.9213 │ Learning Rate: 0.00111
# Epoch 1981/2000 │ Loss: -0.0287 │ Modes: 27 │ Free En. Model: -23.7582 │ Free En. Data: -23.9269 │ Learning Rate: 0.00111
# Epoch 1982/2000 │ Loss: -0.0007 │ Modes: 22 │ Free En. Model: -23.8141 │ Free En. Data: -23.9283 │ Learning Rate: 0.00111
# Epoch 1983/2000 │ Loss: -0.0063 │ Modes: 25 │ Free En. Model: -23.7836 │ Free En. Data: -23.9245 │ Learning Rate: 0.00111
# Epoch 1984/2000 │ Loss: -0.0118 │ Modes: 26 │ Free En. Model: -23.7767 │ Free En. Data: -23.9214 │ Learning Rate: 0.00111
# Epoch 1985/2000 │ Loss: -0.0024 │ Modes: 23 │ Free En. Model: -23.7951 │ Free En. Data: -23.9197 │ Learning Rate: 0.00111
# Epoch 1986/2000 │ Loss: -0.0082 │ Modes: 24 │ Free En. Model: -23.8008 │ Free En. Data: -23.9168 │ Learning Rate: 0.00111
# Epoch 1987/2000 │ Loss: -0.0127 │ Modes: 23 │ Free En. Model: -23.7830 │ Free En. Data: -23.9193 │ Learning Rate: 0.00110
# Epoch 1988/2000 │ Loss: -0.0022 │ Modes: 23 │ Free En. Model: -23.7766 │ Free En. Data: -23.9217 │ Learning Rate: 0.00110
# Epoch 1989/2000 │ Loss: -0.0041 │ Modes: 20 │ Free En. Model: -23.8064 │ Free En. Data: -23.9217 │ Learning Rate: 0.00110
# Epoch 1990/2000 │ Loss: -0.0220 │ Modes: 20 │ Free En. Model: -23.7957 │ Free En. Data: -23.9187 │ Learning Rate: 0.00110
# Epoch 1991/2000 │ Loss: -0.0111 │ Modes: 20 │ Free En. Model: -23.8272 │ Free En. Data: -23.9149 │ Learning Rate: 0.00110
# Epoch 1992/2000 │ Loss: -0.0034 │ Modes: 21 │ Free En. Model: -23.8125 │ Free En. Data: -23.9116 │ Learning Rate: 0.00110
# Epoch 1993/2000 │ Loss: -0.0058 │ Modes: 19 │ Free En. Model: -23.8060 │ Free En. Data: -23.9164 │ Learning Rate: 0.00110
# Epoch 1994/2000 │ Loss: -0.0114 │ Modes: 21 │ Free En. Model: -23.8121 │ Free En. Data: -23.9185 │ Learning Rate: 0.00110
# Epoch 1995/2000 │ Loss: -0.0048 │ Modes: 22 │ Free En. Model: -23.7744 │ Free En. Data: -23.9179 │ Learning Rate: 0.00110
# Epoch 1996/2000 │ Loss: +0.0049 │ Modes: 20 │ Free En. Model: -23.8038 │ Free En. Data: -23.9118 │ Learning Rate: 0.00110
# Epoch 1997/2000 │ Loss: -0.0062 │ Modes: 25 │ Free En. Model: -23.7651 │ Free En. Data: -23.9081 │ Learning Rate: 0.00110
# Epoch 1998/2000 │ Loss: -0.0256 │ Modes: 21 │ Free En. Model: -23.7975 │ Free En. Data: -23.9106 │ Learning Rate: 0.00110
# Epoch 1999/2000 │ Loss: -0.0180 │ Modes: 25 │ Free En. Model: -23.7670 │ Free En. Data: -23.9155 │ Learning Rate: 0.00110
# Epoch 2000/2000 │ Loss: -0.0110 │ Modes: 23 │ Free En. Model: -23.7587 │ Free En. Data: -23.9107 │ Learning Rate: 0.00110

# %%
epochs = list(metrics.keys())

loss_vals = [metrics[e]['loss'] for e in epochs]
mode_vals = [metrics[e]['modes'] for e in epochs]
free_energy_model_vals = [metrics[e]['free_energy_model'] for e in epochs]
free_energy_data_vals = [metrics[e]['free_energy_data'] for e in epochs]
lr_vals = [metrics[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots(figsize=(11, 4))

ax1.set_xlabel("Epoch")

ax1.plot(epochs, lr_vals, color="tab:red")
ax1.set_ylabel("Learning Rate", color="tab:red")
ax1.tick_params(axis="y", labelcolor="tab:red")

ax2 = ax1.twinx()
ax2.plot(epochs, loss_vals, color="tab:blue")
ax2.set_ylabel("CD Loss", color="tab:blue")
ax2.tick_params(axis="y", labelcolor="tab:blue")
ax2.spines["right"].set_position(("axes", 1.0))

ax3 = ax1.twinx()
ax3.plot(epochs, free_energy_model_vals, color="tab:orange")
ax3.set_ylabel("Free Energy Model", color="tab:orange")
ax3.tick_params(axis="y", labelcolor="tab:orange")
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax1.twinx()
ax4.plot(epochs, mode_vals, color="tab:green")
ax4.set_ylabel("Mode Count", color="tab:green")
ax4.tick_params(axis="y", labelcolor="tab:green")
ax4.spines["right"].set_position(("axes", 1.2))

plt.title("Training curve for vanilla RBM")
plt.show()

# %%
# shifting the center step to 0 we can approximate an exponential schedule if we choose the high to be double of T_high
T_high = 2.0
T_low = 0.01
sampling_steps = 5_000
sigmoid_schedule_fn = get_sigmoid_curve(high=T_high*2, low=T_low, steps=sampling_steps, falloff=0.0013, center_step=0)
sigmoid_schedule = jnp.array([sigmoid_schedule_fn(i) for i in range(sampling_steps)], dtype=jnp.float32)

key_sample = PRNGKey(1234)

samples = model.apply(
    {"params": state.params},
    num_samples=10_000,
    T_schedule=sigmoid_schedule,
    key=key_sample,
    method=RBM.generate
)

sampled_freq = samples.mean(0)
sampled_freq
# Out:
# Array([0.1174    , 0.14039999, 0.11319999, 0.13069999, 0.12789999,
#        0.1109    , 0.1286    , 0.1309    ], dtype=float32)

# %%
spin_counts = samples.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(12), align='left', edgecolor='black')
plt.xticks(range(11))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
plt.figure(figsize=(10, 5))
x = jnp.arange(num_visible) + 1

width = 0.35

plt.bar(x - width/2, empirical_freq, width, label="Empirical", alpha=0.7)
plt.bar(x + width/2, sampled_freq, width, label="Sampled", alpha=0.7)

plt.axhline(1 / num_visible, linestyle='--', color='gray', label=f'1/{num_visible} reference')
plt.xlabel("Visible Unit Index")
plt.ylabel("Mean Activation Frequency")
plt.ylim(0, 0.15)
plt.title("Comparison: Empirical vs Sampled Frequencies")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# during phase training we will at most encounter k-hot vectors with k <= 3

def make_k_hot(n, k):
    return jnp.array([jnp.array([1 if i in idxs else 0 for i in range(n)]) for idxs in combinations(range(n), k)], dtype=jnp.float32)

k_hot_vectors = jnp.concatenate([make_k_hot(num_visible, k) for k in range(4)], axis=0)

fe_k_hot = model.apply({'params': state.params}, method=model._free_energy, v=k_hot_vectors)
fe_k_hot = jnp.squeeze(fe_k_hot)
min_fe_k_hot = jnp.min(fe_k_hot)
max_fe_k_hot = jnp.max(fe_k_hot)

print(f"min energy: {min_fe_k_hot:6f}, max energy: {max_fe_k_hot:6f}")
# Out:
# min energy: -23.963350, max energy: -10.025587

# %%
plt.show()
timestamp = datetime.now().strftime("%Y%m%d%H%M")
model_name = f"rbm_amp_{timestamp}"

checkpoints.save_checkpoint(
    ckpt_dir=str(model_dir.resolve()),
    target=state.params,
    step=0,
    prefix=model_name + "_",
    overwrite=True
)
# Out:
# '/Users/Tonni/Desktop/master-code/neural-quantum-tomo/case_studies/shadow_rbm_v2/models/rbm_amp_202506131953_0'
