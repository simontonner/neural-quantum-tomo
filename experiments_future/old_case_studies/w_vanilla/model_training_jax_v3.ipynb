# %%
import os
import numpy as np

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import flax.linen as nn
import optax
from flax.training import train_state

import functools

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches

data_dir = "./data"
device = jax.devices('cpu')[0]

print(f"Data resides in        : {data_dir}")
print(f"Training model on      : {str(device)}")
# Out:
# Data resides in        : ./data
# Training model on      : TFRT_CPU_0

# %%
def z_meas_to_binary(line: str) -> np.ndarray:
    binary_array = [c == "Z" for c in line.strip()]
    return np.array(binary_array, dtype=np.float32).reshape(-1)

data_file = os.path.join(data_dir, "w_vanilla_20_20000.txt")

with open(data_file) as f:
    data = np.stack([z_meas_to_binary(l) for l in f])

print(f"Loaded {len(data)} samples, each of length {data.shape[1]} into numpy array of type {data.dtype}.")

num_train_samples = 20_000
rng = PRNGKey(0)

data_subset = jax.random.choice(rng, data, (num_train_samples,), replace=False)

print(f"Subset shape: {data_subset.shape}")
# Out:
# Loaded 20000 samples, each of length 20 into numpy array of type float32.
# Subset shape: (20000, 20)

# %%
cols = 10
rows = data_subset.shape[0] // cols
panel_width = data_subset.shape[1]
spacer = 4
left_padding = 10
right_padding = 10

canvas_width = (left_padding + cols * panel_width + (cols - 1) * spacer + right_padding)

bright_red = "darkred"
dark_red = "#ffcccc"
flip_red_cmap = ListedColormap([bright_red, dark_red])
flip_red_cmap.set_bad("white")

canvas = np.full((rows, canvas_width), np.nan, dtype=np.float32)
for i in range(cols):
    start_x = left_padding + i * (panel_width + spacer)
    block = data_subset[i * rows:(i + 1) * rows, :]
    canvas[:, start_x:start_x + panel_width] = block

plt.figure(figsize=(12, 6))
img = plt.imshow(canvas, cmap=flip_red_cmap, interpolation='nearest', aspect='auto')
plt.axis('off')

dark_patch = mpatches.Patch(color=dark_red, label="1 (+Z)")
bright_patch = mpatches.Patch(color=bright_red, label="0 (−Z)")
plt.legend(
    handles=[dark_patch, bright_patch],
    loc="center right",
    bbox_to_anchor=(1.1, 0.5),
    frameon=False
)

plt.tight_layout()
plt.show()

# %%
# get rel frequency of up-spin on each site
rel_freq = data_subset.mean(0)
rel_freq
# Out:
# Array([0.04875, 0.0508 , 0.0493 , 0.0521 , 0.0491 , 0.04615, 0.04855,
#        0.0492 , 0.0504 , 0.0507 , 0.052  , 0.05445, 0.0466 , 0.0513 ,
#        0.0496 , 0.05005, 0.0507 , 0.0497 , 0.0495 , 0.05105],      dtype=float32)

# %%
visible_units = 20

fig, ax = plt.subplots(figsize=(8,4))
sites = np.arange(1, visible_units+1)
ax.bar(sites, rel_freq, width=0.8, edgecolor='black', alpha=0.7)
ax.axhline(1/visible_units, color='red', linestyle='--', label=f'Expected = {1/visible_units:.3f}')

ax.set_xlabel('Spin‐site index')
ax.set_ylabel('Relative frequency of up‐spin')
ax.set_title('Training Data: Up‐Spin Occurrence per Site')
ax.set_xticks(sites)
ax.set_ylim(0, rel_freq.max()*1.2)

ax.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
class DataLoader:
    def __init__(self, dataset, batch_size=128, shuffle=True, drop_last=False):
        self.x         = dataset
        self.bs        = batch_size
        self.shuffle   = shuffle
        self.drop_last = drop_last

        n_samples = len(self.x)
        self.idx_slices = [
            (i, i + batch_size)
            for i in range(0, n_samples, batch_size)
            if not drop_last or i + batch_size <= n_samples
        ]

    def __iter__(self):
        order = np.arange(len(self.x))
        if self.shuffle:
            np.random.shuffle(order)
        for s, e in self.idx_slices:
            yield self.x[order[s:e]]

    def __len__(self):
        return len(self.idx_slices)

# %%
class RBM(nn.Module):
    n_visible: int
    n_hidden: int
    k: int = 1

    @nn.compact
    def __call__(self, data_batch: jnp.ndarray, v_persistent: jnp.ndarray, rng: PRNGKey) -> (jnp.ndarray, jnp.ndarray):
        # in flax, __call__ is the main computation to be differentiated.

        # initialize parameters in @nn.compact style:
        W = self.param("W", nn.initializers.normal(0.01), (self.n_visible, self.n_hidden))
        b = self.param("b", nn.initializers.zeros,        (self.n_visible,))
        c = self.param("c", nn.initializers.zeros,        (self.n_hidden,))
        params = {"W": W, "b": b, "c": c}

        # gibbs sampling only refines the fantasy particles, we are actually not interested in the gradients
        v_k, key = self._gibbs_sample(params, v_persistent, rng, k=self.k)
        v_k = jax.lax.stop_gradient(v_k)

        # we are interested in the gradients of the free energy w.r.t. the parameters
        free_energy_data  = self._free_energy(params, data_batch)
        free_energy_model = self._free_energy(params, v_k)

        pcd_loss = jnp.mean(free_energy_data) - jnp.mean(free_energy_model)
        # since this is a pcd loss function, we also return the updated fantasy particles. and we also pass through the key
        # since JAX’s tree utilities flatten nested tuples we need to wrap the auxiliary variables in a container
        aux_vars = {"v_persistent": v_k, "key": key}

        return pcd_loss, aux_vars

    @staticmethod
    def _free_energy(params, v):
        W, b, c = params["W"], params["b"], params["c"]

        visible_term = jnp.dot(v, b)
        hidden_term  = jnp.sum(jax.nn.softplus(v @ W + c), axis=-1)
        free_energy = -visible_term - hidden_term
        return free_energy

    @staticmethod
    def _gibbs_step(i, state, params, T=1.0):
        v, key = state
        W, b, c = params["W"], params["b"], params["c"]

        # splitting generates different random numbers for each step, one of them is passed on
        key, h_key, v_key = jax.random.split(key, 3)

        h_logits = (v @ W + c) / T
        h_probs = jax.nn.sigmoid(h_logits)
        h = jax.random.bernoulli(h_key, h_probs).astype(jnp.float32)

        v_logits = (h @ W.T + b) / T
        v_probs = jax.nn.sigmoid(v_logits)
        v = jax.random.bernoulli(v_key, v_probs).astype(jnp.float32)
        return v, key

    @staticmethod
    def _gibbs_sample(params, v_init, rng, k=1, T=1.0):
        # the fori_loop enables JIT compilation of loops. It basically unrolls the loop over the fixed length k.

        body_fun = lambda i, state: RBM._gibbs_step(i, state, params, T)
        v_final, key = jax.lax.fori_loop(0, k, body_fun, (v_init, rng))
        return v_final, key

    @staticmethod
    def _annealing_step(i, state, params, T_schedule):
        v, rng = state
        T = T_schedule[i]
        # Perform one Gibbs step using the current temperature T.
        # Note: _gibbs_sample already handles k=1 and T
        v_next, rng_next = RBM._gibbs_sample(params, v, rng, k=1, T=T)
        return (v_next, rng_next)

    # the nowrap attribute basically tells JAX to not do the magic wrapping, which injects the params argument
    @nn.nowrap
    def generate(self, params: dict, n_samples: int, T_schedule: jnp.ndarray, rng: PRNGKey) -> jnp.ndarray:

        # get the initial state and perform initial key splitting
        rng, init_key = jax.random.split(rng)
        v = jax.random.bernoulli(init_key, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)
        init_state = (v, rng)

        body_fun = lambda i, state: RBM._gibbs_step(i, state, params, T_schedule[i])

        # the fori_loop is still required, since this function will also be JIT-compiled
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), body_fun, init_state)
        return v_final

# %%
class RBMTrainState(train_state.TrainState):
    """
    A value object bundling parameters and optimizer state for training.
    It has a few pre-defined fields to be used in the training loop.
    Since it is immutable, the training function needs to return a new instance after each update step.
    """
    pass


@functools.partial(jax.jit)
def train_step(state: RBMTrainState, data_batch: jnp.ndarray, v_persistent: jnp.ndarray, key: PRNGKey):

    # only the 'params' argument remains a variable to be differentiated
    pcd_loss_fn = lambda params: state.apply_fn({'params': params}, data_batch, v_persistent, key)

    # since our pc_loss_fn also returns the updated fantasy particles, we need to use has_aux=True
    value_and_grad_fn = jax.value_and_grad(pcd_loss_fn, has_aux=True)
    (pcd_loss, aux_vars), pdc_loss_grads = value_and_grad_fn(state.params)

    # apply the gradients to the state, this actually updates the optimizer state
    new_state = state.apply_gradients(grads=pdc_loss_grads)
    v_persistent = aux_vars["v_persistent"]
    key = aux_vars["key"]

    return new_state, pcd_loss, v_persistent, key


def train_rbm(state: RBMTrainState, train_loader, num_epochs: int, rng: PRNGKey, pcd_reset: int = 5, scheduler=None):
    metrics = {}

    for epoch in range(num_epochs):
        total_loss = 0.0
        batch_count = 0

        for batch_idx, data in enumerate(train_loader):

            if batch_idx % pcd_reset == 0:
                rng, subkey = jax.random.split(rng)   # rng is overwritten with new one to generate new sample
                v_persistent = jax.random.bernoulli(subkey, p=0.5, shape=data.shape).astype(jnp.float32)

            state, loss, v_persistent, rng = train_step(state, data, v_persistent, rng)
            total_loss += loss
            batch_count += 1

        avg_loss = total_loss / len(train_loader)
        metrics[epoch] = {"free_energy_loss": float(avg_loss)}
        print(f"Epoch [{epoch+1}/{num_epochs}] - Free Energy Loss: {avg_loss:.4f}")

    return state, metrics, rng

# %%
# ACTUAL TRAINING
batch_size    = 100
visible_units = 20
hidden_units  = 20
k_steps       = 1
lr            = 1e-2
num_epochs    = 1000
pcd_reset     = 50


rng = PRNGKey(42)

# instantiate the optimizer and the RBM
train_loader = DataLoader(data_subset, batch_size=batch_size, shuffle=True)

optimizer = optax.adam(learning_rate=lr)
rbm = RBM(n_visible=visible_units, n_hidden=hidden_units, k=k_steps)

# initialize RBM parameters and create the training state
dummy_batch = data_subset[:batch_size]
rng, subkey = jax.random.split(rng)
v_persistent = jax.random.bernoulli(subkey, p=0.5, shape=dummy_batch.shape).astype(jnp.float32)
params = rbm.init(rng, dummy_batch, v_persistent, rng)['params']

state = RBMTrainState.create(apply_fn=rbm.apply, params=params, tx=optimizer)

state, metrics, rng = train_rbm(state, train_loader, num_epochs, rng, pcd_reset)
# Out:
# Epoch [1/1000] - Free Energy Loss: -0.7552
# Epoch [2/1000] - Free Energy Loss: -0.1541
# Epoch [3/1000] - Free Energy Loss: -0.0928
# Epoch [4/1000] - Free Energy Loss: -0.0392
# Epoch [5/1000] - Free Energy Loss: -0.0258
# Epoch [6/1000] - Free Energy Loss: 0.0016
# Epoch [7/1000] - Free Energy Loss: -0.0064
# Epoch [8/1000] - Free Energy Loss: 0.0008
# Epoch [9/1000] - Free Energy Loss: 0.0141
# Epoch [10/1000] - Free Energy Loss: 0.0108
# Epoch [11/1000] - Free Energy Loss: 0.0347
# Epoch [12/1000] - Free Energy Loss: 0.0307
# Epoch [13/1000] - Free Energy Loss: 0.0137
# Epoch [14/1000] - Free Energy Loss: 0.0433
# Epoch [15/1000] - Free Energy Loss: 0.0258
# Epoch [16/1000] - Free Energy Loss: 0.0389
# Epoch [17/1000] - Free Energy Loss: 0.0338
# Epoch [18/1000] - Free Energy Loss: 0.0350
# Epoch [19/1000] - Free Energy Loss: 0.0285
# Epoch [20/1000] - Free Energy Loss: 0.0475
# Epoch [21/1000] - Free Energy Loss: 0.0313
# Epoch [22/1000] - Free Energy Loss: 0.0393
# Epoch [23/1000] - Free Energy Loss: 0.0482
# Epoch [24/1000] - Free Energy Loss: 0.0400
# Epoch [25/1000] - Free Energy Loss: 0.0337
# Epoch [26/1000] - Free Energy Loss: 0.0514
# Epoch [27/1000] - Free Energy Loss: 0.0388
# Epoch [28/1000] - Free Energy Loss: 0.0299
# Epoch [29/1000] - Free Energy Loss: 0.0350
# Epoch [30/1000] - Free Energy Loss: 0.0366
# Epoch [31/1000] - Free Energy Loss: 0.0352
# Epoch [32/1000] - Free Energy Loss: 0.0285
# Epoch [33/1000] - Free Energy Loss: 0.0351
# Epoch [34/1000] - Free Energy Loss: 0.0163
# Epoch [35/1000] - Free Energy Loss: 0.0368
# Epoch [36/1000] - Free Energy Loss: 0.0218
# Epoch [37/1000] - Free Energy Loss: 0.0312
# Epoch [38/1000] - Free Energy Loss: 0.0113
# Epoch [39/1000] - Free Energy Loss: 0.0268
# Epoch [40/1000] - Free Energy Loss: 0.0383
# Epoch [41/1000] - Free Energy Loss: 0.0307
# Epoch [42/1000] - Free Energy Loss: 0.0170
# Epoch [43/1000] - Free Energy Loss: 0.0348
# Epoch [44/1000] - Free Energy Loss: 0.0226
# Epoch [45/1000] - Free Energy Loss: 0.0205
# Epoch [46/1000] - Free Energy Loss: 0.0414
# Epoch [47/1000] - Free Energy Loss: 0.0069
# Epoch [48/1000] - Free Energy Loss: 0.0334
# Epoch [49/1000] - Free Energy Loss: 0.0187
# Epoch [50/1000] - Free Energy Loss: 0.0274
# Epoch [51/1000] - Free Energy Loss: 0.0295
# Epoch [52/1000] - Free Energy Loss: 0.0279
# Epoch [53/1000] - Free Energy Loss: 0.0191
# Epoch [54/1000] - Free Energy Loss: 0.0274
# Epoch [55/1000] - Free Energy Loss: 0.0238
# Epoch [56/1000] - Free Energy Loss: 0.0324
# Epoch [57/1000] - Free Energy Loss: 0.0203
# Epoch [58/1000] - Free Energy Loss: 0.0243
# Epoch [59/1000] - Free Energy Loss: 0.0230
# Epoch [60/1000] - Free Energy Loss: 0.0281
# Epoch [61/1000] - Free Energy Loss: 0.0222
# Epoch [62/1000] - Free Energy Loss: 0.0225
# Epoch [63/1000] - Free Energy Loss: 0.0247
# Epoch [64/1000] - Free Energy Loss: 0.0176
# Epoch [65/1000] - Free Energy Loss: 0.0288
# Epoch [66/1000] - Free Energy Loss: 0.0205
# Epoch [67/1000] - Free Energy Loss: 0.0317
# Epoch [68/1000] - Free Energy Loss: 0.0172
# Epoch [69/1000] - Free Energy Loss: 0.0187
# Epoch [70/1000] - Free Energy Loss: 0.0370
# Epoch [71/1000] - Free Energy Loss: 0.0222
# Epoch [72/1000] - Free Energy Loss: 0.0220
# Epoch [73/1000] - Free Energy Loss: 0.0220
# Epoch [74/1000] - Free Energy Loss: 0.0192
# Epoch [75/1000] - Free Energy Loss: 0.0299
# Epoch [76/1000] - Free Energy Loss: 0.0188
# Epoch [77/1000] - Free Energy Loss: 0.0144
# Epoch [78/1000] - Free Energy Loss: 0.0371
# Epoch [79/1000] - Free Energy Loss: 0.0162
# Epoch [80/1000] - Free Energy Loss: 0.0176
# Epoch [81/1000] - Free Energy Loss: 0.0330
# Epoch [82/1000] - Free Energy Loss: 0.0276
# Epoch [83/1000] - Free Energy Loss: 0.0263
# Epoch [84/1000] - Free Energy Loss: 0.0210
# Epoch [85/1000] - Free Energy Loss: 0.0159
# Epoch [86/1000] - Free Energy Loss: 0.0299
# Epoch [87/1000] - Free Energy Loss: 0.0227
# Epoch [88/1000] - Free Energy Loss: 0.0206
# Epoch [89/1000] - Free Energy Loss: 0.0279
# Epoch [90/1000] - Free Energy Loss: 0.0193
# Epoch [91/1000] - Free Energy Loss: 0.0205
# Epoch [92/1000] - Free Energy Loss: 0.0279
# Epoch [93/1000] - Free Energy Loss: 0.0250
# Epoch [94/1000] - Free Energy Loss: 0.0208
# Epoch [95/1000] - Free Energy Loss: 0.0271
# Epoch [96/1000] - Free Energy Loss: 0.0079
# Epoch [97/1000] - Free Energy Loss: 0.0327
# Epoch [98/1000] - Free Energy Loss: 0.0221
# Epoch [99/1000] - Free Energy Loss: 0.0253
# Epoch [100/1000] - Free Energy Loss: 0.0277
# Epoch [101/1000] - Free Energy Loss: 0.0196
# Epoch [102/1000] - Free Energy Loss: 0.0232
# Epoch [103/1000] - Free Energy Loss: 0.0305
# Epoch [104/1000] - Free Energy Loss: 0.0147
# Epoch [105/1000] - Free Energy Loss: 0.0285
# Epoch [106/1000] - Free Energy Loss: 0.0296
# Epoch [107/1000] - Free Energy Loss: 0.0238
# Epoch [108/1000] - Free Energy Loss: 0.0235
# Epoch [109/1000] - Free Energy Loss: 0.0212
# Epoch [110/1000] - Free Energy Loss: 0.0228
# Epoch [111/1000] - Free Energy Loss: 0.0348
# Epoch [112/1000] - Free Energy Loss: 0.0192
# Epoch [113/1000] - Free Energy Loss: 0.0257
# Epoch [114/1000] - Free Energy Loss: 0.0192
# Epoch [115/1000] - Free Energy Loss: 0.0200
# Epoch [116/1000] - Free Energy Loss: 0.0282
# Epoch [117/1000] - Free Energy Loss: 0.0240
# Epoch [118/1000] - Free Energy Loss: 0.0358
# Epoch [119/1000] - Free Energy Loss: 0.0193
# Epoch [120/1000] - Free Energy Loss: 0.0228
# Epoch [121/1000] - Free Energy Loss: 0.0224
# Epoch [122/1000] - Free Energy Loss: 0.0144
# Epoch [123/1000] - Free Energy Loss: 0.0276
# Epoch [124/1000] - Free Energy Loss: 0.0229
# Epoch [125/1000] - Free Energy Loss: 0.0235
# Epoch [126/1000] - Free Energy Loss: 0.0190
# Epoch [127/1000] - Free Energy Loss: 0.0019
# Epoch [128/1000] - Free Energy Loss: 0.0381
# Epoch [129/1000] - Free Energy Loss: 0.0326
# Epoch [130/1000] - Free Energy Loss: 0.0075
# Epoch [131/1000] - Free Energy Loss: 0.0327
# Epoch [132/1000] - Free Energy Loss: 0.0246
# Epoch [133/1000] - Free Energy Loss: 0.0220
# Epoch [134/1000] - Free Energy Loss: 0.0052
# Epoch [135/1000] - Free Energy Loss: 0.0275
# Epoch [136/1000] - Free Energy Loss: 0.0532
# Epoch [137/1000] - Free Energy Loss: 0.0159
# Epoch [138/1000] - Free Energy Loss: 0.0198
# Epoch [139/1000] - Free Energy Loss: 0.0489
# Epoch [140/1000] - Free Energy Loss: 0.0165
# Epoch [141/1000] - Free Energy Loss: 0.0650
# Epoch [142/1000] - Free Energy Loss: 0.0271
# Epoch [143/1000] - Free Energy Loss: 0.0439
# Epoch [144/1000] - Free Energy Loss: 0.0431
# Epoch [145/1000] - Free Energy Loss: 0.0739
# Epoch [146/1000] - Free Energy Loss: 0.0882
# Epoch [147/1000] - Free Energy Loss: 0.0922
# Epoch [148/1000] - Free Energy Loss: 0.0139
# Epoch [149/1000] - Free Energy Loss: 0.0850
# Epoch [150/1000] - Free Energy Loss: 0.1345
# Epoch [151/1000] - Free Energy Loss: 0.0790
# Epoch [152/1000] - Free Energy Loss: 0.0943
# Epoch [153/1000] - Free Energy Loss: 0.1132
# Epoch [154/1000] - Free Energy Loss: 0.0868
# Epoch [155/1000] - Free Energy Loss: 0.0819
# Epoch [156/1000] - Free Energy Loss: 0.0968
# Epoch [157/1000] - Free Energy Loss: 0.1089
# Epoch [158/1000] - Free Energy Loss: 0.0977
# Epoch [159/1000] - Free Energy Loss: 0.0830
# Epoch [160/1000] - Free Energy Loss: 0.0838
# Epoch [161/1000] - Free Energy Loss: 0.0414
# Epoch [162/1000] - Free Energy Loss: 0.0575
# Epoch [163/1000] - Free Energy Loss: 0.0646
# Epoch [164/1000] - Free Energy Loss: 0.0108
# Epoch [165/1000] - Free Energy Loss: 0.0886
# Epoch [166/1000] - Free Energy Loss: 0.0345
# Epoch [167/1000] - Free Energy Loss: 0.0523
# Epoch [168/1000] - Free Energy Loss: 0.0444
# Epoch [169/1000] - Free Energy Loss: 0.0395
# Epoch [170/1000] - Free Energy Loss: 0.0395
# Epoch [171/1000] - Free Energy Loss: 0.0348
# Epoch [172/1000] - Free Energy Loss: 0.0370
# Epoch [173/1000] - Free Energy Loss: 0.1217
# Epoch [174/1000] - Free Energy Loss: 0.0436
# Epoch [175/1000] - Free Energy Loss: 0.0607
# Epoch [176/1000] - Free Energy Loss: 0.0777
# Epoch [177/1000] - Free Energy Loss: 0.0539
# Epoch [178/1000] - Free Energy Loss: 0.0404
# Epoch [179/1000] - Free Energy Loss: 0.0893
# Epoch [180/1000] - Free Energy Loss: 0.0802
# Epoch [181/1000] - Free Energy Loss: -0.0135
# Epoch [182/1000] - Free Energy Loss: 0.0497
# Epoch [183/1000] - Free Energy Loss: 0.0691
# Epoch [184/1000] - Free Energy Loss: 0.0439
# Epoch [185/1000] - Free Energy Loss: -0.0025
# Epoch [186/1000] - Free Energy Loss: 0.1005
# Epoch [187/1000] - Free Energy Loss: 0.0024
# Epoch [188/1000] - Free Energy Loss: 0.0853
# Epoch [189/1000] - Free Energy Loss: 0.0018
# Epoch [190/1000] - Free Energy Loss: 0.0310
# Epoch [191/1000] - Free Energy Loss: -0.0321
# Epoch [192/1000] - Free Energy Loss: 0.0528
# Epoch [193/1000] - Free Energy Loss: 0.0275
# Epoch [194/1000] - Free Energy Loss: 0.0072
# Epoch [195/1000] - Free Energy Loss: 0.0572
# Epoch [196/1000] - Free Energy Loss: -0.0399
# Epoch [197/1000] - Free Energy Loss: -0.0077
# Epoch [198/1000] - Free Energy Loss: 0.0255
# Epoch [199/1000] - Free Energy Loss: -0.0220
# Epoch [200/1000] - Free Energy Loss: -0.0519
# Epoch [201/1000] - Free Energy Loss: 0.0076
# Epoch [202/1000] - Free Energy Loss: -0.0872
# Epoch [203/1000] - Free Energy Loss: -0.0264
# Epoch [204/1000] - Free Energy Loss: -0.0297
# Epoch [205/1000] - Free Energy Loss: -0.0273
# Epoch [206/1000] - Free Energy Loss: 0.0103
# Epoch [207/1000] - Free Energy Loss: -0.0698
# Epoch [208/1000] - Free Energy Loss: -0.0792
# Epoch [209/1000] - Free Energy Loss: -0.0739
# Epoch [210/1000] - Free Energy Loss: -0.0481
# Epoch [211/1000] - Free Energy Loss: -0.0582
# Epoch [212/1000] - Free Energy Loss: -0.1489
# Epoch [213/1000] - Free Energy Loss: -0.0306
# Epoch [214/1000] - Free Energy Loss: -0.1011
# Epoch [215/1000] - Free Energy Loss: 0.0269
# Epoch [216/1000] - Free Energy Loss: -0.1011
# Epoch [217/1000] - Free Energy Loss: 0.0067
# Epoch [218/1000] - Free Energy Loss: -0.0611
# Epoch [219/1000] - Free Energy Loss: -0.0749
# Epoch [220/1000] - Free Energy Loss: -0.0677
# Epoch [221/1000] - Free Energy Loss: -0.0670
# Epoch [222/1000] - Free Energy Loss: 0.0071
# Epoch [223/1000] - Free Energy Loss: -0.0534
# Epoch [224/1000] - Free Energy Loss: -0.1235
# Epoch [225/1000] - Free Energy Loss: -0.0368
# Epoch [226/1000] - Free Energy Loss: -0.1393
# Epoch [227/1000] - Free Energy Loss: -0.1209
# Epoch [228/1000] - Free Energy Loss: -0.0375
# Epoch [229/1000] - Free Energy Loss: -0.1487
# Epoch [230/1000] - Free Energy Loss: -0.0799
# Epoch [231/1000] - Free Energy Loss: -0.2544
# Epoch [232/1000] - Free Energy Loss: -0.1146
# Epoch [233/1000] - Free Energy Loss: -0.0999
# Epoch [234/1000] - Free Energy Loss: -0.1200
# Epoch [235/1000] - Free Energy Loss: -0.1020
# Epoch [236/1000] - Free Energy Loss: -0.2229
# Epoch [237/1000] - Free Energy Loss: -0.0722
# Epoch [238/1000] - Free Energy Loss: -0.0789
# Epoch [239/1000] - Free Energy Loss: -0.1056
# Epoch [240/1000] - Free Energy Loss: -0.2663
# Epoch [241/1000] - Free Energy Loss: 0.0546
# Epoch [242/1000] - Free Energy Loss: -0.1597
# Epoch [243/1000] - Free Energy Loss: -0.0274
# Epoch [244/1000] - Free Energy Loss: -0.0940
# Epoch [245/1000] - Free Energy Loss: -0.0192
# Epoch [246/1000] - Free Energy Loss: -0.1800
# Epoch [247/1000] - Free Energy Loss: -0.2428
# Epoch [248/1000] - Free Energy Loss: 0.0092
# Epoch [249/1000] - Free Energy Loss: -0.0980
# Epoch [250/1000] - Free Energy Loss: -0.0653
# Epoch [251/1000] - Free Energy Loss: -0.1695
# Epoch [252/1000] - Free Energy Loss: -0.0841
# Epoch [253/1000] - Free Energy Loss: -0.0867
# Epoch [254/1000] - Free Energy Loss: -0.0845
# Epoch [255/1000] - Free Energy Loss: -0.1524
# Epoch [256/1000] - Free Energy Loss: -0.2290
# Epoch [257/1000] - Free Energy Loss: -0.0854
# Epoch [258/1000] - Free Energy Loss: -0.1497
# Epoch [259/1000] - Free Energy Loss: -0.0581
# Epoch [260/1000] - Free Energy Loss: -0.2364
# Epoch [261/1000] - Free Energy Loss: -0.1887
# Epoch [262/1000] - Free Energy Loss: -0.1078
# Epoch [263/1000] - Free Energy Loss: -0.2901
# Epoch [264/1000] - Free Energy Loss: -0.1875
# Epoch [265/1000] - Free Energy Loss: -0.3341
# Epoch [266/1000] - Free Energy Loss: 0.0062
# Epoch [267/1000] - Free Energy Loss: -0.1231
# Epoch [268/1000] - Free Energy Loss: -0.2917
# Epoch [269/1000] - Free Energy Loss: -0.1530
# Epoch [270/1000] - Free Energy Loss: -0.1143
# Epoch [271/1000] - Free Energy Loss: -0.3171
# Epoch [272/1000] - Free Energy Loss: -0.1615
# Epoch [273/1000] - Free Energy Loss: -0.2511
# Epoch [274/1000] - Free Energy Loss: -0.0716
# Epoch [275/1000] - Free Energy Loss: -0.1296
# Epoch [276/1000] - Free Energy Loss: -0.2778
# Epoch [277/1000] - Free Energy Loss: -0.1046
# Epoch [278/1000] - Free Energy Loss: -0.2253
# Epoch [279/1000] - Free Energy Loss: -0.1113
# Epoch [280/1000] - Free Energy Loss: -0.1949
# Epoch [281/1000] - Free Energy Loss: 0.0138
# Epoch [282/1000] - Free Energy Loss: -0.2559
# Epoch [283/1000] - Free Energy Loss: -0.1645
# Epoch [284/1000] - Free Energy Loss: -0.2957
# Epoch [285/1000] - Free Energy Loss: -0.2468
# Epoch [286/1000] - Free Energy Loss: -0.0509
# Epoch [287/1000] - Free Energy Loss: -0.1846
# Epoch [288/1000] - Free Energy Loss: -0.1515
# Epoch [289/1000] - Free Energy Loss: -0.2519
# Epoch [290/1000] - Free Energy Loss: -0.0893
# Epoch [291/1000] - Free Energy Loss: -0.3476
# Epoch [292/1000] - Free Energy Loss: -0.0157
# Epoch [293/1000] - Free Energy Loss: -0.1937
# Epoch [294/1000] - Free Energy Loss: -0.1103
# Epoch [295/1000] - Free Energy Loss: -0.2325
# Epoch [296/1000] - Free Energy Loss: 0.1160
# Epoch [297/1000] - Free Energy Loss: -0.2142
# Epoch [298/1000] - Free Energy Loss: -0.2010
# Epoch [299/1000] - Free Energy Loss: -0.2034
# Epoch [300/1000] - Free Energy Loss: -0.1240
# Epoch [301/1000] - Free Energy Loss: -0.1879
# Epoch [302/1000] - Free Energy Loss: -0.1213
# Epoch [303/1000] - Free Energy Loss: -0.2178
# Epoch [304/1000] - Free Energy Loss: -0.0123
# Epoch [305/1000] - Free Energy Loss: -0.2703
# Epoch [306/1000] - Free Energy Loss: -0.3487
# Epoch [307/1000] - Free Energy Loss: 0.0770
# Epoch [308/1000] - Free Energy Loss: -0.3570
# Epoch [309/1000] - Free Energy Loss: -0.0003
# Epoch [310/1000] - Free Energy Loss: -0.2702
# Epoch [311/1000] - Free Energy Loss: -0.1070
# Epoch [312/1000] - Free Energy Loss: 0.0476
# Epoch [313/1000] - Free Energy Loss: -0.2863
# Epoch [314/1000] - Free Energy Loss: -0.1691
# Epoch [315/1000] - Free Energy Loss: 0.0808
# Epoch [316/1000] - Free Energy Loss: -0.4246
# Epoch [317/1000] - Free Energy Loss: -0.2287
# Epoch [318/1000] - Free Energy Loss: 0.0812
# Epoch [319/1000] - Free Energy Loss: -0.2004
# Epoch [320/1000] - Free Energy Loss: -0.1145
# Epoch [321/1000] - Free Energy Loss: -0.2009
# Epoch [322/1000] - Free Energy Loss: -0.0212
# Epoch [323/1000] - Free Energy Loss: -0.3834
# Epoch [324/1000] - Free Energy Loss: -0.0803
# Epoch [325/1000] - Free Energy Loss: -0.1847
# Epoch [326/1000] - Free Energy Loss: -0.1280
# Epoch [327/1000] - Free Energy Loss: -0.1825
# Epoch [328/1000] - Free Energy Loss: -0.2896
# Epoch [329/1000] - Free Energy Loss: -0.0372
# Epoch [330/1000] - Free Energy Loss: -0.2312
# Epoch [331/1000] - Free Energy Loss: -0.0582
# Epoch [332/1000] - Free Energy Loss: -0.1571
# Epoch [333/1000] - Free Energy Loss: -0.2800
# Epoch [334/1000] - Free Energy Loss: -0.2099
# Epoch [335/1000] - Free Energy Loss: 0.1033
# Epoch [336/1000] - Free Energy Loss: -0.3943
# Epoch [337/1000] - Free Energy Loss: -0.2599
# Epoch [338/1000] - Free Energy Loss: -0.1455
# Epoch [339/1000] - Free Energy Loss: 0.0545
# Epoch [340/1000] - Free Energy Loss: -0.3672
# Epoch [341/1000] - Free Energy Loss: -0.1944
# Epoch [342/1000] - Free Energy Loss: -0.1791
# Epoch [343/1000] - Free Energy Loss: -0.0700
# Epoch [344/1000] - Free Energy Loss: -0.2647
# Epoch [345/1000] - Free Energy Loss: -0.1785
# Epoch [346/1000] - Free Energy Loss: -0.2227
# Epoch [347/1000] - Free Energy Loss: -0.0522
# Epoch [348/1000] - Free Energy Loss: -0.2429
# Epoch [349/1000] - Free Energy Loss: -0.1949
# Epoch [350/1000] - Free Energy Loss: -0.0838
# Epoch [351/1000] - Free Energy Loss: -0.2931
# Epoch [352/1000] - Free Energy Loss: -0.2565
# Epoch [353/1000] - Free Energy Loss: 0.0433
# Epoch [354/1000] - Free Energy Loss: -0.3915
# Epoch [355/1000] - Free Energy Loss: -0.1106
# Epoch [356/1000] - Free Energy Loss: -0.2061
# Epoch [357/1000] - Free Energy Loss: -0.2337
# Epoch [358/1000] - Free Energy Loss: -0.3735
# Epoch [359/1000] - Free Energy Loss: 0.1724
# Epoch [360/1000] - Free Energy Loss: -0.4435
# Epoch [361/1000] - Free Energy Loss: -0.2847
# Epoch [362/1000] - Free Energy Loss: -0.1124
# Epoch [363/1000] - Free Energy Loss: -0.1672
# Epoch [364/1000] - Free Energy Loss: -0.1468
# Epoch [365/1000] - Free Energy Loss: -0.4400
# Epoch [366/1000] - Free Energy Loss: -0.1772
# Epoch [367/1000] - Free Energy Loss: -0.1709
# Epoch [368/1000] - Free Energy Loss: -0.1607
# Epoch [369/1000] - Free Energy Loss: -0.2442
# Epoch [370/1000] - Free Energy Loss: -0.1883
# Epoch [371/1000] - Free Energy Loss: -0.2931
# Epoch [372/1000] - Free Energy Loss: -0.1776
# Epoch [373/1000] - Free Energy Loss: -0.2456
# Epoch [374/1000] - Free Energy Loss: -0.2059
# Epoch [375/1000] - Free Energy Loss: -0.3160
# Epoch [376/1000] - Free Energy Loss: -0.0836
# Epoch [377/1000] - Free Energy Loss: -0.2188
# Epoch [378/1000] - Free Energy Loss: -0.2679
# Epoch [379/1000] - Free Energy Loss: -0.2398
# Epoch [380/1000] - Free Energy Loss: -0.2582
# Epoch [381/1000] - Free Energy Loss: -0.2049
# Epoch [382/1000] - Free Energy Loss: -0.3249
# Epoch [383/1000] - Free Energy Loss: -0.1546
# Epoch [384/1000] - Free Energy Loss: -0.2542
# Epoch [385/1000] - Free Energy Loss: -0.3099
# Epoch [386/1000] - Free Energy Loss: -0.2958
# Epoch [387/1000] - Free Energy Loss: -0.2037
# Epoch [388/1000] - Free Energy Loss: -0.3196
# Epoch [389/1000] - Free Energy Loss: -0.1467
# Epoch [390/1000] - Free Energy Loss: -0.1367
# Epoch [391/1000] - Free Energy Loss: -0.5379
# Epoch [392/1000] - Free Energy Loss: -0.0176
# Epoch [393/1000] - Free Energy Loss: -0.4415
# Epoch [394/1000] - Free Energy Loss: -0.3031
# Epoch [395/1000] - Free Energy Loss: -0.1796
# Epoch [396/1000] - Free Energy Loss: -0.4226
# Epoch [397/1000] - Free Energy Loss: -0.1186
# Epoch [398/1000] - Free Energy Loss: -0.3871
# Epoch [399/1000] - Free Energy Loss: -0.0005
# Epoch [400/1000] - Free Energy Loss: -0.2777
# Epoch [401/1000] - Free Energy Loss: -0.2217
# Epoch [402/1000] - Free Energy Loss: -0.4304
# Epoch [403/1000] - Free Energy Loss: -0.0220
# Epoch [404/1000] - Free Energy Loss: -0.5365
# Epoch [405/1000] - Free Energy Loss: -0.4877
# Epoch [406/1000] - Free Energy Loss: 0.0008
# Epoch [407/1000] - Free Energy Loss: -0.2367
# Epoch [408/1000] - Free Energy Loss: -0.4151
# Epoch [409/1000] - Free Energy Loss: -0.3156
# Epoch [410/1000] - Free Energy Loss: -0.0632
# Epoch [411/1000] - Free Energy Loss: -0.4534
# Epoch [412/1000] - Free Energy Loss: -0.3898
# Epoch [413/1000] - Free Energy Loss: -0.2819
# Epoch [414/1000] - Free Energy Loss: -0.3136
# Epoch [415/1000] - Free Energy Loss: -0.2774
# Epoch [416/1000] - Free Energy Loss: -0.3654
# Epoch [417/1000] - Free Energy Loss: -0.3406
# Epoch [418/1000] - Free Energy Loss: -0.2764
# Epoch [419/1000] - Free Energy Loss: -0.1166
# Epoch [420/1000] - Free Energy Loss: -0.3973
# Epoch [421/1000] - Free Energy Loss: -0.3486
# Epoch [422/1000] - Free Energy Loss: -0.4314
# Epoch [423/1000] - Free Energy Loss: -0.3737
# Epoch [424/1000] - Free Energy Loss: -0.1125
# Epoch [425/1000] - Free Energy Loss: -0.4707
# Epoch [426/1000] - Free Energy Loss: -0.5276
# Epoch [427/1000] - Free Energy Loss: -0.3717
# Epoch [428/1000] - Free Energy Loss: -0.1528
# Epoch [429/1000] - Free Energy Loss: -0.4636
# Epoch [430/1000] - Free Energy Loss: -0.1302
# Epoch [431/1000] - Free Energy Loss: -0.4206
# Epoch [432/1000] - Free Energy Loss: -0.1866
# Epoch [433/1000] - Free Energy Loss: -0.4944
# Epoch [434/1000] - Free Energy Loss: -0.2930
# Epoch [435/1000] - Free Energy Loss: -0.3234
# Epoch [436/1000] - Free Energy Loss: -0.3150
# Epoch [437/1000] - Free Energy Loss: -0.4646
# Epoch [438/1000] - Free Energy Loss: -0.3010
# Epoch [439/1000] - Free Energy Loss: -0.4743
# Epoch [440/1000] - Free Energy Loss: -0.2358
# Epoch [441/1000] - Free Energy Loss: -0.3854
# Epoch [442/1000] - Free Energy Loss: -0.5865
# Epoch [443/1000] - Free Energy Loss: -0.2816
# Epoch [444/1000] - Free Energy Loss: -0.2712
# Epoch [445/1000] - Free Energy Loss: -0.4468
# Epoch [446/1000] - Free Energy Loss: -0.3479
# Epoch [447/1000] - Free Energy Loss: -0.2924
# Epoch [448/1000] - Free Energy Loss: -0.4320
# Epoch [449/1000] - Free Energy Loss: -0.3938
# Epoch [450/1000] - Free Energy Loss: -0.0053
# Epoch [451/1000] - Free Energy Loss: -0.4475
# Epoch [452/1000] - Free Energy Loss: -0.7282
# Epoch [453/1000] - Free Energy Loss: -0.5221
# Epoch [454/1000] - Free Energy Loss: -0.2022
# Epoch [455/1000] - Free Energy Loss: -0.4432
# Epoch [456/1000] - Free Energy Loss: -0.3474
# Epoch [457/1000] - Free Energy Loss: -0.7445
# Epoch [458/1000] - Free Energy Loss: 0.0876
# Epoch [459/1000] - Free Energy Loss: -0.5880
# Epoch [460/1000] - Free Energy Loss: -0.3526
# Epoch [461/1000] - Free Energy Loss: -0.5336
# Epoch [462/1000] - Free Energy Loss: -0.4168
# Epoch [463/1000] - Free Energy Loss: -0.3580
# Epoch [464/1000] - Free Energy Loss: -0.4663
# Epoch [465/1000] - Free Energy Loss: -0.4036
# Epoch [466/1000] - Free Energy Loss: -0.3934
# Epoch [467/1000] - Free Energy Loss: -0.4593
# Epoch [468/1000] - Free Energy Loss: -0.3826
# Epoch [469/1000] - Free Energy Loss: -0.4807
# Epoch [470/1000] - Free Energy Loss: -0.5274
# Epoch [471/1000] - Free Energy Loss: -0.5113
# Epoch [472/1000] - Free Energy Loss: -0.3982
# Epoch [473/1000] - Free Energy Loss: -0.2632
# Epoch [474/1000] - Free Energy Loss: -0.6862
# Epoch [475/1000] - Free Energy Loss: -0.2756
# Epoch [476/1000] - Free Energy Loss: -0.3824
# Epoch [477/1000] - Free Energy Loss: -0.6625
# Epoch [478/1000] - Free Energy Loss: -0.4261
# Epoch [479/1000] - Free Energy Loss: -0.3658
# Epoch [480/1000] - Free Energy Loss: -0.5145
# Epoch [481/1000] - Free Energy Loss: -0.4918
# Epoch [482/1000] - Free Energy Loss: -0.4406
# Epoch [483/1000] - Free Energy Loss: -0.6089
# Epoch [484/1000] - Free Energy Loss: -0.5786
# Epoch [485/1000] - Free Energy Loss: -0.5235
# Epoch [486/1000] - Free Energy Loss: -0.5232
# Epoch [487/1000] - Free Energy Loss: -0.4327
# Epoch [488/1000] - Free Energy Loss: -0.5365
# Epoch [489/1000] - Free Energy Loss: -0.4940
# Epoch [490/1000] - Free Energy Loss: -0.5702
# Epoch [491/1000] - Free Energy Loss: -0.2725
# Epoch [492/1000] - Free Energy Loss: -0.4813
# Epoch [493/1000] - Free Energy Loss: -0.6467
# Epoch [494/1000] - Free Energy Loss: -0.6265
# Epoch [495/1000] - Free Energy Loss: -0.5486
# Epoch [496/1000] - Free Energy Loss: -0.4507
# Epoch [497/1000] - Free Energy Loss: -0.5709
# Epoch [498/1000] - Free Energy Loss: -0.4871
# Epoch [499/1000] - Free Energy Loss: -0.4154
# Epoch [500/1000] - Free Energy Loss: -0.5596
# Epoch [501/1000] - Free Energy Loss: -0.5764
# Epoch [502/1000] - Free Energy Loss: -0.5687
# Epoch [503/1000] - Free Energy Loss: -0.5023
# Epoch [504/1000] - Free Energy Loss: -0.4966
# Epoch [505/1000] - Free Energy Loss: -0.5369
# Epoch [506/1000] - Free Energy Loss: -0.5487
# Epoch [507/1000] - Free Energy Loss: -0.6738
# Epoch [508/1000] - Free Energy Loss: -0.5536
# Epoch [509/1000] - Free Energy Loss: -0.6766
# Epoch [510/1000] - Free Energy Loss: -0.3585
# Epoch [511/1000] - Free Energy Loss: -0.5269
# Epoch [512/1000] - Free Energy Loss: -0.3820
# Epoch [513/1000] - Free Energy Loss: -0.9571
# Epoch [514/1000] - Free Energy Loss: -0.4996
# Epoch [515/1000] - Free Energy Loss: -0.6036
# Epoch [516/1000] - Free Energy Loss: -0.4385
# Epoch [517/1000] - Free Energy Loss: -0.5818
# Epoch [518/1000] - Free Energy Loss: -0.7038
# Epoch [519/1000] - Free Energy Loss: -0.5010
# Epoch [520/1000] - Free Energy Loss: -0.6559
# Epoch [521/1000] - Free Energy Loss: -0.4724
# Epoch [522/1000] - Free Energy Loss: -0.7642
# Epoch [523/1000] - Free Energy Loss: -0.5196
# Epoch [524/1000] - Free Energy Loss: -0.5579
# Epoch [525/1000] - Free Energy Loss: -1.0341
# Epoch [526/1000] - Free Energy Loss: -0.3169
# Epoch [527/1000] - Free Energy Loss: -0.5376
# Epoch [528/1000] - Free Energy Loss: -0.7653
# Epoch [529/1000] - Free Energy Loss: -0.6891
# Epoch [530/1000] - Free Energy Loss: -0.4953
# Epoch [531/1000] - Free Energy Loss: -0.5472
# Epoch [532/1000] - Free Energy Loss: -0.4284
# Epoch [533/1000] - Free Energy Loss: -0.7971
# Epoch [534/1000] - Free Energy Loss: -0.4485
# Epoch [535/1000] - Free Energy Loss: -0.5723
# Epoch [536/1000] - Free Energy Loss: -0.8177
# Epoch [537/1000] - Free Energy Loss: -0.5085
# Epoch [538/1000] - Free Energy Loss: -0.7087
# Epoch [539/1000] - Free Energy Loss: -0.5167
# Epoch [540/1000] - Free Energy Loss: -0.7229
# Epoch [541/1000] - Free Energy Loss: -0.6792
# Epoch [542/1000] - Free Energy Loss: -0.7226
# Epoch [543/1000] - Free Energy Loss: -0.5357
# Epoch [544/1000] - Free Energy Loss: -0.6552
# Epoch [545/1000] - Free Energy Loss: -0.6412
# Epoch [546/1000] - Free Energy Loss: -0.6631
# Epoch [547/1000] - Free Energy Loss: -0.8293
# Epoch [548/1000] - Free Energy Loss: -0.5005
# Epoch [549/1000] - Free Energy Loss: -0.7194
# Epoch [550/1000] - Free Energy Loss: -0.6537
# Epoch [551/1000] - Free Energy Loss: -0.4610
# Epoch [552/1000] - Free Energy Loss: -0.8355
# Epoch [553/1000] - Free Energy Loss: -0.7342
# Epoch [554/1000] - Free Energy Loss: -0.6542
# Epoch [555/1000] - Free Energy Loss: -0.7409
# Epoch [556/1000] - Free Energy Loss: -0.5889
# Epoch [557/1000] - Free Energy Loss: -0.8086
# Epoch [558/1000] - Free Energy Loss: -0.5275
# Epoch [559/1000] - Free Energy Loss: -0.8665
# Epoch [560/1000] - Free Energy Loss: -0.8277
# Epoch [561/1000] - Free Energy Loss: -0.6684
# Epoch [562/1000] - Free Energy Loss: -0.5271
# Epoch [563/1000] - Free Energy Loss: -1.0391
# Epoch [564/1000] - Free Energy Loss: -0.6307
# Epoch [565/1000] - Free Energy Loss: -0.6273
# Epoch [566/1000] - Free Energy Loss: -0.8653
# Epoch [567/1000] - Free Energy Loss: -0.6548
# Epoch [568/1000] - Free Energy Loss: -0.6105
# Epoch [569/1000] - Free Energy Loss: -0.7878
# Epoch [570/1000] - Free Energy Loss: -0.8343
# Epoch [571/1000] - Free Energy Loss: -0.5875
# Epoch [572/1000] - Free Energy Loss: -0.6997
# Epoch [573/1000] - Free Energy Loss: -0.8186
# Epoch [574/1000] - Free Energy Loss: -0.7669
# Epoch [575/1000] - Free Energy Loss: -0.6607
# Epoch [576/1000] - Free Energy Loss: -0.8774
# Epoch [577/1000] - Free Energy Loss: -0.6455
# Epoch [578/1000] - Free Energy Loss: -0.7864
# Epoch [579/1000] - Free Energy Loss: -0.8336
# Epoch [580/1000] - Free Energy Loss: -0.8599
# Epoch [581/1000] - Free Energy Loss: -0.7861
# Epoch [582/1000] - Free Energy Loss: -0.6915
# Epoch [583/1000] - Free Energy Loss: -0.7169
# Epoch [584/1000] - Free Energy Loss: -0.7517
# Epoch [585/1000] - Free Energy Loss: -0.9595
# Epoch [586/1000] - Free Energy Loss: -0.7758
# Epoch [587/1000] - Free Energy Loss: -0.7111
# Epoch [588/1000] - Free Energy Loss: -0.6728
# Epoch [589/1000] - Free Energy Loss: -0.9874
# Epoch [590/1000] - Free Energy Loss: -0.7839
# Epoch [591/1000] - Free Energy Loss: -0.6739
# Epoch [592/1000] - Free Energy Loss: -0.7790
# Epoch [593/1000] - Free Energy Loss: -0.8262
# Epoch [594/1000] - Free Energy Loss: -0.7351
# Epoch [595/1000] - Free Energy Loss: -0.9817
# Epoch [596/1000] - Free Energy Loss: -0.5656
# Epoch [597/1000] - Free Energy Loss: -1.0510
# Epoch [598/1000] - Free Energy Loss: -0.7359
# Epoch [599/1000] - Free Energy Loss: -0.5421
# Epoch [600/1000] - Free Energy Loss: -1.0885
# Epoch [601/1000] - Free Energy Loss: -0.6485
# Epoch [602/1000] - Free Energy Loss: -0.9193
# Epoch [603/1000] - Free Energy Loss: -0.8691
# Epoch [604/1000] - Free Energy Loss: -0.9139
# Epoch [605/1000] - Free Energy Loss: -0.8721
# Epoch [606/1000] - Free Energy Loss: -0.9748
# Epoch [607/1000] - Free Energy Loss: -0.6311
# Epoch [608/1000] - Free Energy Loss: -0.8813
# Epoch [609/1000] - Free Energy Loss: -1.0156
# Epoch [610/1000] - Free Energy Loss: -0.7418
# Epoch [611/1000] - Free Energy Loss: -0.9472
# Epoch [612/1000] - Free Energy Loss: -0.9363
# Epoch [613/1000] - Free Energy Loss: -0.9128
# Epoch [614/1000] - Free Energy Loss: -0.6950
# Epoch [615/1000] - Free Energy Loss: -1.0712
# Epoch [616/1000] - Free Energy Loss: -1.0139
# Epoch [617/1000] - Free Energy Loss: -0.8198
# Epoch [618/1000] - Free Energy Loss: -0.7049
# Epoch [619/1000] - Free Energy Loss: -0.9409
# Epoch [620/1000] - Free Energy Loss: -0.8607
# Epoch [621/1000] - Free Energy Loss: -0.6845
# Epoch [622/1000] - Free Energy Loss: -0.9887
# Epoch [623/1000] - Free Energy Loss: -0.8496
# Epoch [624/1000] - Free Energy Loss: -1.0429
# Epoch [625/1000] - Free Energy Loss: -0.7449
# Epoch [626/1000] - Free Energy Loss: -0.9230
# Epoch [627/1000] - Free Energy Loss: -0.8458
# Epoch [628/1000] - Free Energy Loss: -1.0540
# Epoch [629/1000] - Free Energy Loss: -0.8908
# Epoch [630/1000] - Free Energy Loss: -0.8741
# Epoch [631/1000] - Free Energy Loss: -1.1827
# Epoch [632/1000] - Free Energy Loss: -0.8999
# Epoch [633/1000] - Free Energy Loss: -0.9284
# Epoch [634/1000] - Free Energy Loss: -0.8358
# Epoch [635/1000] - Free Energy Loss: -0.9596
# Epoch [636/1000] - Free Energy Loss: -0.9804
# Epoch [637/1000] - Free Energy Loss: -1.0652
# Epoch [638/1000] - Free Energy Loss: -0.7379
# Epoch [639/1000] - Free Energy Loss: -1.0513
# Epoch [640/1000] - Free Energy Loss: -0.9897
# Epoch [641/1000] - Free Energy Loss: -0.8145
# Epoch [642/1000] - Free Energy Loss: -0.9415
# Epoch [643/1000] - Free Energy Loss: -1.0907
# Epoch [644/1000] - Free Energy Loss: -0.9631
# Epoch [645/1000] - Free Energy Loss: -0.8707
# Epoch [646/1000] - Free Energy Loss: -1.1004
# Epoch [647/1000] - Free Energy Loss: -0.9094
# Epoch [648/1000] - Free Energy Loss: -1.0351
# Epoch [649/1000] - Free Energy Loss: -0.8990
# Epoch [650/1000] - Free Energy Loss: -0.6957
# Epoch [651/1000] - Free Energy Loss: -1.1456
# Epoch [652/1000] - Free Energy Loss: -0.9445
# Epoch [653/1000] - Free Energy Loss: -0.9982
# Epoch [654/1000] - Free Energy Loss: -1.1179
# Epoch [655/1000] - Free Energy Loss: -0.8962
# Epoch [656/1000] - Free Energy Loss: -0.9203
# Epoch [657/1000] - Free Energy Loss: -1.1359
# Epoch [658/1000] - Free Energy Loss: -1.0677
# Epoch [659/1000] - Free Energy Loss: -0.9679
# Epoch [660/1000] - Free Energy Loss: -1.0801
# Epoch [661/1000] - Free Energy Loss: -0.9440
# Epoch [662/1000] - Free Energy Loss: -0.8500
# Epoch [663/1000] - Free Energy Loss: -0.9481
# Epoch [664/1000] - Free Energy Loss: -1.5486
# Epoch [665/1000] - Free Energy Loss: -0.7024
# Epoch [666/1000] - Free Energy Loss: -1.0204
# Epoch [667/1000] - Free Energy Loss: -0.7611
# Epoch [668/1000] - Free Energy Loss: -1.0362
# Epoch [669/1000] - Free Energy Loss: -1.1975
# Epoch [670/1000] - Free Energy Loss: -0.9026
# Epoch [671/1000] - Free Energy Loss: -0.9467
# Epoch [672/1000] - Free Energy Loss: -1.3017
# Epoch [673/1000] - Free Energy Loss: -1.0459
# Epoch [674/1000] - Free Energy Loss: -1.0371
# Epoch [675/1000] - Free Energy Loss: -1.0949
# Epoch [676/1000] - Free Energy Loss: -1.1295
# Epoch [677/1000] - Free Energy Loss: -1.0088
# Epoch [678/1000] - Free Energy Loss: -0.9843
# Epoch [679/1000] - Free Energy Loss: -1.1865
# Epoch [680/1000] - Free Energy Loss: -1.0150
# Epoch [681/1000] - Free Energy Loss: -1.1255
# Epoch [682/1000] - Free Energy Loss: -1.2912
# Epoch [683/1000] - Free Energy Loss: -1.0491
# Epoch [684/1000] - Free Energy Loss: -1.1104
# Epoch [685/1000] - Free Energy Loss: -1.1686
# Epoch [686/1000] - Free Energy Loss: -1.2373
# Epoch [687/1000] - Free Energy Loss: -1.0811
# Epoch [688/1000] - Free Energy Loss: -1.1123
# Epoch [689/1000] - Free Energy Loss: -0.9873
# Epoch [690/1000] - Free Energy Loss: -1.1934
# Epoch [691/1000] - Free Energy Loss: -1.2088
# Epoch [692/1000] - Free Energy Loss: -1.1134
# Epoch [693/1000] - Free Energy Loss: -1.2249
# Epoch [694/1000] - Free Energy Loss: -0.9577
# Epoch [695/1000] - Free Energy Loss: -1.2648
# Epoch [696/1000] - Free Energy Loss: -1.2952
# Epoch [697/1000] - Free Energy Loss: -1.0755
# Epoch [698/1000] - Free Energy Loss: -1.2008
# Epoch [699/1000] - Free Energy Loss: -0.9496
# Epoch [700/1000] - Free Energy Loss: -1.3216
# Epoch [701/1000] - Free Energy Loss: -1.2351
# Epoch [702/1000] - Free Energy Loss: -0.9892
# Epoch [703/1000] - Free Energy Loss: -1.1313
# Epoch [704/1000] - Free Energy Loss: -1.4333
# Epoch [705/1000] - Free Energy Loss: -1.2463
# Epoch [706/1000] - Free Energy Loss: -1.1190
# Epoch [707/1000] - Free Energy Loss: -1.2818
# Epoch [708/1000] - Free Energy Loss: -1.1513
# Epoch [709/1000] - Free Energy Loss: -1.3968
# Epoch [710/1000] - Free Energy Loss: -1.1483
# Epoch [711/1000] - Free Energy Loss: -1.2640
# Epoch [712/1000] - Free Energy Loss: -1.1937
# Epoch [713/1000] - Free Energy Loss: -1.1682
# Epoch [714/1000] - Free Energy Loss: -1.1343
# Epoch [715/1000] - Free Energy Loss: -1.2066
# Epoch [716/1000] - Free Energy Loss: -1.1786
# Epoch [717/1000] - Free Energy Loss: -1.0560
# Epoch [718/1000] - Free Energy Loss: -1.4383
# Epoch [719/1000] - Free Energy Loss: -1.1090
# Epoch [720/1000] - Free Energy Loss: -1.1602
# Epoch [721/1000] - Free Energy Loss: -1.3114
# Epoch [722/1000] - Free Energy Loss: -1.1744
# Epoch [723/1000] - Free Energy Loss: -1.2125
# Epoch [724/1000] - Free Energy Loss: -1.2855
# Epoch [725/1000] - Free Energy Loss: -1.1413
# Epoch [726/1000] - Free Energy Loss: -1.1470
# Epoch [727/1000] - Free Energy Loss: -1.2528
# Epoch [728/1000] - Free Energy Loss: -1.2654
# Epoch [729/1000] - Free Energy Loss: -1.2903
# Epoch [730/1000] - Free Energy Loss: -1.0474
# Epoch [731/1000] - Free Energy Loss: -1.1862
# Epoch [732/1000] - Free Energy Loss: -1.3346
# Epoch [733/1000] - Free Energy Loss: -1.4162
# Epoch [734/1000] - Free Energy Loss: -1.2644
# Epoch [735/1000] - Free Energy Loss: -1.4157
# Epoch [736/1000] - Free Energy Loss: -1.3173
# Epoch [737/1000] - Free Energy Loss: -1.3113
# Epoch [738/1000] - Free Energy Loss: -1.2752
# Epoch [739/1000] - Free Energy Loss: -1.2532
# Epoch [740/1000] - Free Energy Loss: -1.2260
# Epoch [741/1000] - Free Energy Loss: -1.1298
# Epoch [742/1000] - Free Energy Loss: -1.7422
# Epoch [743/1000] - Free Energy Loss: -1.1707
# Epoch [744/1000] - Free Energy Loss: -1.0335
# Epoch [745/1000] - Free Energy Loss: -1.2958
# Epoch [746/1000] - Free Energy Loss: -1.3844
# Epoch [747/1000] - Free Energy Loss: -1.0090
# Epoch [748/1000] - Free Energy Loss: -1.4168
# Epoch [749/1000] - Free Energy Loss: -1.2768
# Epoch [750/1000] - Free Energy Loss: -1.2939
# Epoch [751/1000] - Free Energy Loss: -1.2125
# Epoch [752/1000] - Free Energy Loss: -1.3351
# Epoch [753/1000] - Free Energy Loss: -1.6140
# Epoch [754/1000] - Free Energy Loss: -0.9279
# Epoch [755/1000] - Free Energy Loss: -1.5124
# Epoch [756/1000] - Free Energy Loss: -1.2665
# Epoch [757/1000] - Free Energy Loss: -1.2391
# Epoch [758/1000] - Free Energy Loss: -1.4367
# Epoch [759/1000] - Free Energy Loss: -1.4249
# Epoch [760/1000] - Free Energy Loss: -1.4787
# Epoch [761/1000] - Free Energy Loss: -1.4161
# Epoch [762/1000] - Free Energy Loss: -1.2072
# Epoch [763/1000] - Free Energy Loss: -1.4951
# Epoch [764/1000] - Free Energy Loss: -1.2413
# Epoch [765/1000] - Free Energy Loss: -1.5057
# Epoch [766/1000] - Free Energy Loss: -0.9972
# Epoch [767/1000] - Free Energy Loss: -1.2680
# Epoch [768/1000] - Free Energy Loss: -1.7236
# Epoch [769/1000] - Free Energy Loss: -1.0358
# Epoch [770/1000] - Free Energy Loss: -1.6889
# Epoch [771/1000] - Free Energy Loss: -1.2194
# Epoch [772/1000] - Free Energy Loss: -1.3092
# Epoch [773/1000] - Free Energy Loss: -1.3917
# Epoch [774/1000] - Free Energy Loss: -1.2271
# Epoch [775/1000] - Free Energy Loss: -1.5398
# Epoch [776/1000] - Free Energy Loss: -1.2806
# Epoch [777/1000] - Free Energy Loss: -1.4618
# Epoch [778/1000] - Free Energy Loss: -1.2835
# Epoch [779/1000] - Free Energy Loss: -1.5492
# Epoch [780/1000] - Free Energy Loss: -1.2953
# Epoch [781/1000] - Free Energy Loss: -1.4589
# Epoch [782/1000] - Free Energy Loss: -1.3385
# Epoch [783/1000] - Free Energy Loss: -1.3758
# Epoch [784/1000] - Free Energy Loss: -1.2351
# Epoch [785/1000] - Free Energy Loss: -1.2726
# Epoch [786/1000] - Free Energy Loss: -1.4027
# Epoch [787/1000] - Free Energy Loss: -1.4366
# Epoch [788/1000] - Free Energy Loss: -1.4219
# Epoch [789/1000] - Free Energy Loss: -1.4734
# Epoch [790/1000] - Free Energy Loss: -1.4628
# Epoch [791/1000] - Free Energy Loss: -1.6091
# Epoch [792/1000] - Free Energy Loss: -1.6166
# Epoch [793/1000] - Free Energy Loss: -1.5484
# Epoch [794/1000] - Free Energy Loss: -1.4404
# Epoch [795/1000] - Free Energy Loss: -1.2644
# Epoch [796/1000] - Free Energy Loss: -1.6401
# Epoch [797/1000] - Free Energy Loss: -1.5150
# Epoch [798/1000] - Free Energy Loss: -1.6825
# Epoch [799/1000] - Free Energy Loss: -1.4750
# Epoch [800/1000] - Free Energy Loss: -1.4847
# Epoch [801/1000] - Free Energy Loss: -1.4056
# Epoch [802/1000] - Free Energy Loss: -1.4252
# Epoch [803/1000] - Free Energy Loss: -1.2891
# Epoch [804/1000] - Free Energy Loss: -1.5056
# Epoch [805/1000] - Free Energy Loss: -1.3637
# Epoch [806/1000] - Free Energy Loss: -1.4683
# Epoch [807/1000] - Free Energy Loss: -1.4001
# Epoch [808/1000] - Free Energy Loss: -1.1640
# Epoch [809/1000] - Free Energy Loss: -1.2788
# Epoch [810/1000] - Free Energy Loss: -1.6999
# Epoch [811/1000] - Free Energy Loss: -1.2067
# Epoch [812/1000] - Free Energy Loss: -1.9006
# Epoch [813/1000] - Free Energy Loss: -1.3860
# Epoch [814/1000] - Free Energy Loss: -1.7629
# Epoch [815/1000] - Free Energy Loss: -1.4551
# Epoch [816/1000] - Free Energy Loss: -1.5561
# Epoch [817/1000] - Free Energy Loss: -1.6583
# Epoch [818/1000] - Free Energy Loss: -1.4164
# Epoch [819/1000] - Free Energy Loss: -1.4935
# Epoch [820/1000] - Free Energy Loss: -1.4828
# Epoch [821/1000] - Free Energy Loss: -1.6831
# Epoch [822/1000] - Free Energy Loss: -1.5839
# Epoch [823/1000] - Free Energy Loss: -1.7163
# Epoch [824/1000] - Free Energy Loss: -1.5348
# Epoch [825/1000] - Free Energy Loss: -1.6423
# Epoch [826/1000] - Free Energy Loss: -1.4440
# Epoch [827/1000] - Free Energy Loss: -1.7093
# Epoch [828/1000] - Free Energy Loss: -1.3704
# Epoch [829/1000] - Free Energy Loss: -1.6179
# Epoch [830/1000] - Free Energy Loss: -1.7192
# Epoch [831/1000] - Free Energy Loss: -1.6220
# Epoch [832/1000] - Free Energy Loss: -1.5515
# Epoch [833/1000] - Free Energy Loss: -1.8265
# Epoch [834/1000] - Free Energy Loss: -1.4179
# Epoch [835/1000] - Free Energy Loss: -1.6980
# Epoch [836/1000] - Free Energy Loss: -1.8302
# Epoch [837/1000] - Free Energy Loss: -1.4526
# Epoch [838/1000] - Free Energy Loss: -1.5479
# Epoch [839/1000] - Free Energy Loss: -1.5250
# Epoch [840/1000] - Free Energy Loss: -1.6988
# Epoch [841/1000] - Free Energy Loss: -1.6175
# Epoch [842/1000] - Free Energy Loss: -1.5756
# Epoch [843/1000] - Free Energy Loss: -1.5673
# Epoch [844/1000] - Free Energy Loss: -1.4851
# Epoch [845/1000] - Free Energy Loss: -1.7219
# Epoch [846/1000] - Free Energy Loss: -1.6339
# Epoch [847/1000] - Free Energy Loss: -1.3880
# Epoch [848/1000] - Free Energy Loss: -1.6759
# Epoch [849/1000] - Free Energy Loss: -1.6531
# Epoch [850/1000] - Free Energy Loss: -1.6022
# Epoch [851/1000] - Free Energy Loss: -1.4275
# Epoch [852/1000] - Free Energy Loss: -1.7242
# Epoch [853/1000] - Free Energy Loss: -1.7066
# Epoch [854/1000] - Free Energy Loss: -1.5119
# Epoch [855/1000] - Free Energy Loss: -1.6366
# Epoch [856/1000] - Free Energy Loss: -1.7777
# Epoch [857/1000] - Free Energy Loss: -1.5639
# Epoch [858/1000] - Free Energy Loss: -1.6946
# Epoch [859/1000] - Free Energy Loss: -1.5105
# Epoch [860/1000] - Free Energy Loss: -1.7451
# Epoch [861/1000] - Free Energy Loss: -1.6741
# Epoch [862/1000] - Free Energy Loss: -1.6727
# Epoch [863/1000] - Free Energy Loss: -1.7234
# Epoch [864/1000] - Free Energy Loss: -1.7600
# Epoch [865/1000] - Free Energy Loss: -1.7841
# Epoch [866/1000] - Free Energy Loss: -1.6762
# Epoch [867/1000] - Free Energy Loss: -1.8967
# Epoch [868/1000] - Free Energy Loss: -2.0750
# Epoch [869/1000] - Free Energy Loss: -1.4822
# Epoch [870/1000] - Free Energy Loss: -1.7806
# Epoch [871/1000] - Free Energy Loss: -1.7629
# Epoch [872/1000] - Free Energy Loss: -1.6988
# Epoch [873/1000] - Free Energy Loss: -1.7150
# Epoch [874/1000] - Free Energy Loss: -1.6521
# Epoch [875/1000] - Free Energy Loss: -1.9495
# Epoch [876/1000] - Free Energy Loss: -1.6047
# Epoch [877/1000] - Free Energy Loss: -1.4336
# Epoch [878/1000] - Free Energy Loss: -1.7677
# Epoch [879/1000] - Free Energy Loss: -1.7553
# Epoch [880/1000] - Free Energy Loss: -1.6348
# Epoch [881/1000] - Free Energy Loss: -1.6588
# Epoch [882/1000] - Free Energy Loss: -1.8252
# Epoch [883/1000] - Free Energy Loss: -1.7649
# Epoch [884/1000] - Free Energy Loss: -1.7530
# Epoch [885/1000] - Free Energy Loss: -1.7366
# Epoch [886/1000] - Free Energy Loss: -1.6684
# Epoch [887/1000] - Free Energy Loss: -1.8432
# Epoch [888/1000] - Free Energy Loss: -1.6103
# Epoch [889/1000] - Free Energy Loss: -1.6511
# Epoch [890/1000] - Free Energy Loss: -1.6670
# Epoch [891/1000] - Free Energy Loss: -1.6525
# Epoch [892/1000] - Free Energy Loss: -1.7207
# Epoch [893/1000] - Free Energy Loss: -1.8518
# Epoch [894/1000] - Free Energy Loss: -1.9285
# Epoch [895/1000] - Free Energy Loss: -1.5868
# Epoch [896/1000] - Free Energy Loss: -2.0103
# Epoch [897/1000] - Free Energy Loss: -1.9154
# Epoch [898/1000] - Free Energy Loss: -1.6882
# Epoch [899/1000] - Free Energy Loss: -1.8484
# Epoch [900/1000] - Free Energy Loss: -1.8647
# Epoch [901/1000] - Free Energy Loss: -1.7630
# Epoch [902/1000] - Free Energy Loss: -1.7063
# Epoch [903/1000] - Free Energy Loss: -1.7995
# Epoch [904/1000] - Free Energy Loss: -1.8875
# Epoch [905/1000] - Free Energy Loss: -1.8030
# Epoch [906/1000] - Free Energy Loss: -2.0755
# Epoch [907/1000] - Free Energy Loss: -1.8849
# Epoch [908/1000] - Free Energy Loss: -1.7684
# Epoch [909/1000] - Free Energy Loss: -1.5354
# Epoch [910/1000] - Free Energy Loss: -1.9310
# Epoch [911/1000] - Free Energy Loss: -2.1324
# Epoch [912/1000] - Free Energy Loss: -1.8839
# Epoch [913/1000] - Free Energy Loss: -1.9878
# Epoch [914/1000] - Free Energy Loss: -1.6568
# Epoch [915/1000] - Free Energy Loss: -1.9248
# Epoch [916/1000] - Free Energy Loss: -1.5746
# Epoch [917/1000] - Free Energy Loss: -2.1016
# Epoch [918/1000] - Free Energy Loss: -1.8544
# Epoch [919/1000] - Free Energy Loss: -1.8164
# Epoch [920/1000] - Free Energy Loss: -1.7911
# Epoch [921/1000] - Free Energy Loss: -2.0779
# Epoch [922/1000] - Free Energy Loss: -1.7275
# Epoch [923/1000] - Free Energy Loss: -1.7238
# Epoch [924/1000] - Free Energy Loss: -1.8230
# Epoch [925/1000] - Free Energy Loss: -2.0364
# Epoch [926/1000] - Free Energy Loss: -1.9652
# Epoch [927/1000] - Free Energy Loss: -1.8207
# Epoch [928/1000] - Free Energy Loss: -1.8645
# Epoch [929/1000] - Free Energy Loss: -1.8953
# Epoch [930/1000] - Free Energy Loss: -2.1950
# Epoch [931/1000] - Free Energy Loss: -1.9224
# Epoch [932/1000] - Free Energy Loss: -1.8033
# Epoch [933/1000] - Free Energy Loss: -2.0510
# Epoch [934/1000] - Free Energy Loss: -1.7926
# Epoch [935/1000] - Free Energy Loss: -2.1116
# Epoch [936/1000] - Free Energy Loss: -1.7450
# Epoch [937/1000] - Free Energy Loss: -2.2135
# Epoch [938/1000] - Free Energy Loss: -1.8277
# Epoch [939/1000] - Free Energy Loss: -2.0007
# Epoch [940/1000] - Free Energy Loss: -1.7861
# Epoch [941/1000] - Free Energy Loss: -1.8678
# Epoch [942/1000] - Free Energy Loss: -1.9104
# Epoch [943/1000] - Free Energy Loss: -1.7407
# Epoch [944/1000] - Free Energy Loss: -2.1335
# Epoch [945/1000] - Free Energy Loss: -2.2198
# Epoch [946/1000] - Free Energy Loss: -1.8577
# Epoch [947/1000] - Free Energy Loss: -1.8583
# Epoch [948/1000] - Free Energy Loss: -1.9366
# Epoch [949/1000] - Free Energy Loss: -1.9914
# Epoch [950/1000] - Free Energy Loss: -1.9364
# Epoch [951/1000] - Free Energy Loss: -2.0293
# Epoch [952/1000] - Free Energy Loss: -2.0560
# Epoch [953/1000] - Free Energy Loss: -2.1457
# Epoch [954/1000] - Free Energy Loss: -1.8232
# Epoch [955/1000] - Free Energy Loss: -1.8220
# Epoch [956/1000] - Free Energy Loss: -1.7334
# Epoch [957/1000] - Free Energy Loss: -2.2051
# Epoch [958/1000] - Free Energy Loss: -2.0250
# Epoch [959/1000] - Free Energy Loss: -2.1040
# Epoch [960/1000] - Free Energy Loss: -2.1739
# Epoch [961/1000] - Free Energy Loss: -1.9491
# Epoch [962/1000] - Free Energy Loss: -1.9292
# Epoch [963/1000] - Free Energy Loss: -2.2767
# Epoch [964/1000] - Free Energy Loss: -2.0035
# Epoch [965/1000] - Free Energy Loss: -1.6738
# Epoch [966/1000] - Free Energy Loss: -2.2270
# Epoch [967/1000] - Free Energy Loss: -1.6492
# Epoch [968/1000] - Free Energy Loss: -1.9679
# Epoch [969/1000] - Free Energy Loss: -1.9524
# Epoch [970/1000] - Free Energy Loss: -1.9789
# Epoch [971/1000] - Free Energy Loss: -2.0629
# Epoch [972/1000] - Free Energy Loss: -2.1064
# Epoch [973/1000] - Free Energy Loss: -2.1361
# Epoch [974/1000] - Free Energy Loss: -1.9842
# Epoch [975/1000] - Free Energy Loss: -1.9900
# Epoch [976/1000] - Free Energy Loss: -1.9454
# Epoch [977/1000] - Free Energy Loss: -2.1233
# Epoch [978/1000] - Free Energy Loss: -1.8576
# Epoch [979/1000] - Free Energy Loss: -2.4637
# Epoch [980/1000] - Free Energy Loss: -1.9270
# Epoch [981/1000] - Free Energy Loss: -2.4007
# Epoch [982/1000] - Free Energy Loss: -2.2520
# Epoch [983/1000] - Free Energy Loss: -2.1796
# Epoch [984/1000] - Free Energy Loss: -2.1632
# Epoch [985/1000] - Free Energy Loss: -2.1591
# Epoch [986/1000] - Free Energy Loss: -1.8763
# Epoch [987/1000] - Free Energy Loss: -2.2090
# Epoch [988/1000] - Free Energy Loss: -2.2647
# Epoch [989/1000] - Free Energy Loss: -1.9765
# Epoch [990/1000] - Free Energy Loss: -2.0876
# Epoch [991/1000] - Free Energy Loss: -1.9380
# Epoch [992/1000] - Free Energy Loss: -2.0048
# Epoch [993/1000] - Free Energy Loss: -1.9347
# Epoch [994/1000] - Free Energy Loss: -2.0196
# Epoch [995/1000] - Free Energy Loss: -1.9518
# Epoch [996/1000] - Free Energy Loss: -1.8329
# Epoch [997/1000] - Free Energy Loss: -1.9465
# Epoch [998/1000] - Free Energy Loss: -2.2481
# Epoch [999/1000] - Free Energy Loss: -2.0159
# Epoch [1000/1000] - Free Energy Loss: -2.2425

# %%
plt.plot([metrics[epoch]['free_energy_loss'] for epoch in metrics])
plt.xlabel("Epoch")
plt.ylabel("Free Energy Loss")
# Out:
# Text(0, 0.5, 'Free Energy Loss')

# %%
samples = rbm.generate(state.params,
                       n_samples=10_000,
                       T_schedule=jnp.ones(200) * 1.2,
                       rng=rng)

rel_freq = samples.mean(0)
rel_freq
# Out:
# Array([0.0389, 0.0579, 0.0406, 0.0582, 0.0481, 0.0401, 0.0506, 0.0472,
#        0.0602, 0.0571, 0.0579, 0.0437, 0.0332, 0.0668, 0.0338, 0.0598,
#        0.0551, 0.0431, 0.055 , 0.0527], dtype=float32)

# %%
rel_freq.sum()
# Out:
# Array(1., dtype=float32)

# %%
spin_counts = samples.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(22), align='left', edgecolor='black')
plt.xticks(range(21))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
sites = np.arange(1, visible_units+1)
ax.bar(sites, rel_freq, width=0.8, edgecolor='black', alpha=0.7)
ax.axhline(1/visible_units, color='red', linestyle='--', label=f'Expected = {1/visible_units:.3f}')

ax.set_xlabel('Spin‐site index')
ax.set_ylabel('Relative frequency of up‐spin')
ax.set_title('Training Data: Up‐Spin Occurrence per Site')
ax.set_xticks(sites)
ax.set_ylim(0, rel_freq.max()*1.2)

ax.legend(loc='upper right')
plt.tight_layout()
plt.show()
