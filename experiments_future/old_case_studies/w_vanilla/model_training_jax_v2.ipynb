# %%
import os
import numpy as np

import jax
import jax.lax
from jax.random import PRNGKey
import jax.numpy as jnp
import flax.linen as nn
import optax
from flax.training import train_state

import functools

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches


data_dir = "./data"
device = jax.devices('cpu')[0]

print(f"Data resides in        : {data_dir}")
print(f"Training model on      : {str(device)}")
# Out:
# Data resides in        : ./data
# Training model on      : TFRT_CPU_0

# %%
def z_meas_to_binary(line: str) -> np.ndarray:
    binary_array = [c == "Z" for c in line.strip()]
    return np.array(binary_array, dtype=np.float32).reshape(-1)

data_file = os.path.join(data_dir, "w_vanilla_20_20000.txt")

with open(data_file) as f:
    data = np.stack([z_meas_to_binary(l) for l in f])

print(f"Loaded {len(data)} samples, each of length {data.shape[1]} into numpy array of type {data.dtype}.")

num_train_samples = 50
rng = PRNGKey(0)

data_subset = jax.random.choice(rng, data, (num_train_samples,), replace=False)

print(f"Subset shape: {data_subset.shape}")
# Out:
# Loaded 20000 samples, each of length 20 into numpy array of type float32.
# Subset shape: (50, 20)

# %%
cols = 10
rows = data_subset.shape[0] // cols
panel_width = data_subset.shape[1]
spacer = 4
left_padding = 10
right_padding = 10

canvas_width = (left_padding + cols * panel_width + (cols - 1) * spacer + right_padding)

bright_red = "darkred"
dark_red = "#ffcccc"
flip_red_cmap = ListedColormap([bright_red, dark_red])
flip_red_cmap.set_bad("white")

canvas = np.full((rows, canvas_width), np.nan, dtype=np.float32)
for i in range(cols):
    start_x = left_padding + i * (panel_width + spacer)
    block = data_subset[i * rows:(i + 1) * rows, :]
    canvas[:, start_x:start_x + panel_width] = block

plt.figure(figsize=(12, 6))
img = plt.imshow(canvas, cmap=flip_red_cmap, interpolation='nearest', aspect='auto')
plt.axis('off')

dark_patch = mpatches.Patch(color=dark_red, label="1 (+Z)")
bright_patch = mpatches.Patch(color=bright_red, label="0 (−Z)")
plt.legend(
    handles=[dark_patch, bright_patch],
    loc="center right",
    bbox_to_anchor=(1.1, 0.5),
    frameon=False
)

plt.tight_layout()
plt.show()

# %%
# get rel frequency of up-spin on each site
rel_freq = data_subset.mean(0)
rel_freq
# Out:
# Array([0.04      , 0.04      , 0.02      , 0.        , 0.04      ,
#        0.06      , 0.06      , 0.06      , 0.06      , 0.12      ,
#        0.04      , 0.04      , 0.04      , 0.        , 0.06      ,
#        0.04      , 0.08      , 0.04      , 0.09999999, 0.06      ],      dtype=float32)

# %%
rel_freq.sum()
# Out:
# Array(1., dtype=float32)

# %%
class DataLoader:
    def __init__(self, dataset, batch_size=128, shuffle=True, drop_last=False):
        self.x         = dataset
        self.bs        = batch_size
        self.shuffle   = shuffle
        self.drop_last = drop_last

        n_samples = len(self.x)
        self.idx_slices = [
            (i, i + batch_size)
            for i in range(0, n_samples, batch_size)
            if not drop_last or i + batch_size <= n_samples
        ]

    def __iter__(self):
        order = np.arange(len(self.x))
        if self.shuffle:
            np.random.shuffle(order)
        for s, e in self.idx_slices:
            yield self.x[order[s:e]]

    def __len__(self):
        return len(self.idx_slices)

# %%
class RBM(nn.Module):
    n_visible: int
    n_hidden: int
    k: int = 1

    @nn.compact
    def __call__(self, data_batch: jnp.ndarray, v_persistent: jnp.ndarray, rng: PRNGKey) -> (jnp.ndarray, jnp.ndarray):
        # in flax, __call__ is the main computation to be differentiated.

        # initialize parameters in @nn.compact style:
        W = self.param("W", nn.initializers.normal(0.01), (self.n_visible, self.n_hidden))
        b = self.param("b", nn.initializers.zeros,        (self.n_visible,))
        c = self.param("c", nn.initializers.zeros,        (self.n_hidden,))
        params = {"W": W, "b": b, "c": c}

        # gibbs sampling only refines the fantasy particles, we are actually not interested in the gradients
        v_k, key = self._gibbs_sample(params, v_persistent, rng, k=self.k)
        v_k = jax.lax.stop_gradient(v_k)

        # we are interested in the gradients of the free energy w.r.t. the parameters
        free_energy_data  = self._free_energy(params, data_batch)
        free_energy_model = self._free_energy(params, v_k)

        pcd_loss = jnp.mean(free_energy_data) - jnp.mean(free_energy_model)
        # since this is a pcd loss function, we also return the updated fantasy particles. and we also pass through the key
        # since JAX’s tree utilities flatten nested tuples we need to wrap the auxiliary variables in a container
        aux_vars = {"v_persistent": v_k, "key": key}

        return pcd_loss, aux_vars

    @staticmethod
    def _free_energy(params, v):
        W, b, c = params["W"], params["b"], params["c"]

        visible_term = jnp.dot(v, b)
        hidden_term  = jnp.sum(jax.nn.softplus(v @ W + c), axis=-1)
        free_energy = -visible_term - hidden_term
        return free_energy

    @staticmethod
    def _gibbs_step(i, state, params, T=1.0):
        v, key = state
        W, b, c = params["W"], params["b"], params["c"]

        # splitting generates different random numbers for each step, one of them is passed on
        key, h_key, v_key = jax.random.split(key, 3)

        h_logits = (v @ W + c) / T
        h_probs = jax.nn.sigmoid(h_logits)
        h = jax.random.bernoulli(h_key, h_probs).astype(jnp.float32)

        v_logits = (h @ W.T + b) / T
        v_probs = jax.nn.sigmoid(v_logits)
        v = jax.random.bernoulli(v_key, v_probs).astype(jnp.float32)
        return v, key

    @staticmethod
    def _gibbs_sample(params, v_init, rng, k=1, T=1.0):
        # the fori_loop enables JIT compilation of loops. It basically unrolls the loop over the fixed length k.

        body_fun = lambda i, state: RBM._gibbs_step(i, state, params, T)
        v_final, key = jax.lax.fori_loop(0, k, body_fun, (v_init, rng))
        return v_final, key

    @staticmethod
    def _annealing_step(i, state, params, T_schedule):
        v, rng = state
        T = T_schedule[i]
        # Perform one Gibbs step using the current temperature T.
        # Note: _gibbs_sample already handles k=1 and T
        v_next, rng_next = RBM._gibbs_sample(params, v, rng, k=1, T=T)
        return (v_next, rng_next)

    # the nowrap attribute basically tells JAX to not do the magic wrapping, which injects the params argument
    @nn.nowrap
    def generate(self, params: dict, n_samples: int, T_schedule: jnp.ndarray, rng: PRNGKey) -> jnp.ndarray:

        # get the initial state and perform initial key splitting
        rng, init_key = jax.random.split(rng)
        v = jax.random.bernoulli(init_key, p=0.5, shape=(n_samples, self.n_visible)).astype(jnp.float32)
        init_state = (v, rng)

        body_fun = lambda i, state: RBM._gibbs_step(i, state, params, T_schedule[i])

        # the fori_loop is still required, since this function will also be JIT-compiled
        v_final, _ = jax.lax.fori_loop(0, len(T_schedule), body_fun, init_state)
        return v_final

# %%
class RBMTrainState(train_state.TrainState):
    """
    A value object bundling parameters and optimizer state for training.
    It has a few pre-defined fields to be used in the training loop.
    Since it is immutable, the training function needs to return a new instance after each update step.
    """
    pass


@functools.partial(jax.jit)
def train_step(state: RBMTrainState, data_batch: jnp.ndarray, v_persistent: jnp.ndarray, key: PRNGKey):

    # only the 'params' argument remains a variable to be differentiated
    pcd_loss_fn = lambda params: state.apply_fn({'params': params}, data_batch, v_persistent, key)

    # since our pc_loss_fn also returns the updated fantasy particles, we need to use has_aux=True
    value_and_grad_fn = jax.value_and_grad(pcd_loss_fn, has_aux=True)
    (pcd_loss, aux_vars), pdc_loss_grads = value_and_grad_fn(state.params)

    # apply the gradients to the state, this actually updates the optimizer state
    new_state = state.apply_gradients(grads=pdc_loss_grads)
    v_persistent = aux_vars["v_persistent"]
    key = aux_vars["key"]

    return new_state, pcd_loss, v_persistent, key


def train_rbm(state: RBMTrainState, train_loader, num_epochs: int, rng: PRNGKey, pcd_reset: int = 5, scheduler=None):
    metrics = {}

    for epoch in range(num_epochs):
        total_loss = 0.0
        batch_count = 0

        for batch_idx, data in enumerate(train_loader):

            #print(f"{type(batch_idx)}, {type(pcd_reset)}")
            if batch_idx % pcd_reset == 0:
                rng, subkey = jax.random.split(rng)   # rng is overwritten with new one to generate new sample
                v_persistent = jax.random.bernoulli(subkey, p=0.5, shape=data.shape).astype(jnp.float32)

            state, loss, v_persistent, rng = train_step(state, data, v_persistent, rng)
            total_loss += loss
            batch_count += 1

        avg_loss = total_loss / len(train_loader)
        metrics[epoch] = {"free_energy_loss": float(avg_loss)}
        print(f"Epoch [{epoch+1}/{num_epochs}] - Free Energy Loss: {avg_loss:.4f}")

    return state, metrics, rng

# %%
# ACTUAL TRAINING
batch_size    = 5
visible_units = 20
hidden_units  = 20
k_steps       = 50
lr            = 1e-2
num_epochs    = 300
pcd_reset     = 2
lr_decay      = 0.95


rng = PRNGKey(42)

# instantiate the optimizer and the RBM
train_loader = DataLoader(data_subset, batch_size=batch_size, shuffle=True)

optimizer = optax.adam(learning_rate=lr)
rbm = RBM(n_visible=visible_units, n_hidden=hidden_units, k=k_steps)

# initialize RBM parameters and create the training state
dummy_batch = data_subset[:batch_size]
rng, subkey = jax.random.split(rng)
v_persistent = jax.random.bernoulli(subkey, p=0.5, shape=dummy_batch.shape).astype(jnp.float32)
params = rbm.init(rng, dummy_batch, v_persistent, rng)['params']

state = RBMTrainState.create(apply_fn=rbm.apply, params=params, tx=optimizer)

state, metrics, rng = train_rbm(state, train_loader, num_epochs, rng, pcd_reset)
# Out:
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [1/300] - Free Energy Loss: -2.5047
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [2/300] - Free Energy Loss: -4.2530
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [3/300] - Free Energy Loss: -4.0489
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [4/300] - Free Energy Loss: -2.8971
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [5/300] - Free Energy Loss: -1.8532
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [6/300] - Free Energy Loss: 0.3750
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [7/300] - Free Energy Loss: -0.4371
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [8/300] - Free Energy Loss: 0.0281
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [9/300] - Free Energy Loss: -0.7661
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [10/300] - Free Energy Loss: -0.4734
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [11/300] - Free Energy Loss: -0.9150
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [12/300] - Free Energy Loss: 0.1144
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [13/300] - Free Energy Loss: 0.7977
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [14/300] - Free Energy Loss: 0.4114
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [15/300] - Free Energy Loss: -0.8014
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [16/300] - Free Energy Loss: -0.0879
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [17/300] - Free Energy Loss: -0.3513
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [18/300] - Free Energy Loss: 0.3161
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [19/300] - Free Energy Loss: 0.0843
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [20/300] - Free Energy Loss: 0.1792
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [21/300] - Free Energy Loss: -0.5831
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [22/300] - Free Energy Loss: -0.0879
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [23/300] - Free Energy Loss: -0.0829
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [24/300] - Free Energy Loss: 0.1449
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [25/300] - Free Energy Loss: -0.1899
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [26/300] - Free Energy Loss: -0.6130
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [27/300] - Free Energy Loss: -0.0980
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [28/300] - Free Energy Loss: 0.4055
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [29/300] - Free Energy Loss: 0.4046
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [30/300] - Free Energy Loss: 0.6699
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [31/300] - Free Energy Loss: 0.4671
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [32/300] - Free Energy Loss: -0.1068
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [33/300] - Free Energy Loss: -0.6630
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [34/300] - Free Energy Loss: 0.1063
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [35/300] - Free Energy Loss: 0.0952
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [36/300] - Free Energy Loss: -0.0929
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [37/300] - Free Energy Loss: -0.3123
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [38/300] - Free Energy Loss: -0.3538
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [39/300] - Free Energy Loss: -0.0809
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [40/300] - Free Energy Loss: 0.7269
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [41/300] - Free Energy Loss: -0.0527
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [42/300] - Free Energy Loss: -0.1053
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [43/300] - Free Energy Loss: 0.0877
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [44/300] - Free Energy Loss: 0.0268
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [45/300] - Free Energy Loss: -0.1358
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [46/300] - Free Energy Loss: -0.1003
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [47/300] - Free Energy Loss: 0.7007
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [48/300] - Free Energy Loss: -1.0089
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [49/300] - Free Energy Loss: -0.3252
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [50/300] - Free Energy Loss: -0.3159
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [51/300] - Free Energy Loss: 0.3518
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [52/300] - Free Energy Loss: 0.6085
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [53/300] - Free Energy Loss: -0.3225
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [54/300] - Free Energy Loss: -0.0378
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [55/300] - Free Energy Loss: -0.2845
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [56/300] - Free Energy Loss: 0.1483
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [57/300] - Free Energy Loss: 0.8752
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [58/300] - Free Energy Loss: 0.5564
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [59/300] - Free Energy Loss: -0.7328
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [60/300] - Free Energy Loss: 0.1318
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [61/300] - Free Energy Loss: 0.1484
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [62/300] - Free Energy Loss: 0.0395
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [63/300] - Free Energy Loss: 0.4450
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [64/300] - Free Energy Loss: -0.1579
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [65/300] - Free Energy Loss: -0.4375
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [66/300] - Free Energy Loss: -0.1653
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [67/300] - Free Energy Loss: 0.3556
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [68/300] - Free Energy Loss: -0.1916
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [69/300] - Free Energy Loss: 0.5361
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [70/300] - Free Energy Loss: 0.2872
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [71/300] - Free Energy Loss: -0.0333
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [72/300] - Free Energy Loss: -0.7204
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [73/300] - Free Energy Loss: 0.1919
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [74/300] - Free Energy Loss: 0.2409
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [75/300] - Free Energy Loss: -0.2197
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [76/300] - Free Energy Loss: 0.1502
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [77/300] - Free Energy Loss: -0.3639
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [78/300] - Free Energy Loss: 0.5538
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [79/300] - Free Energy Loss: -0.5613
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [80/300] - Free Energy Loss: 0.0859
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [81/300] - Free Energy Loss: 0.7514
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [82/300] - Free Energy Loss: 0.1390
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [83/300] - Free Energy Loss: -0.5040
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [84/300] - Free Energy Loss: -0.1819
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [85/300] - Free Energy Loss: 0.1052
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [86/300] - Free Energy Loss: 0.1631
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [87/300] - Free Energy Loss: 0.3024
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [88/300] - Free Energy Loss: 0.0663
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [89/300] - Free Energy Loss: -0.4476
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [90/300] - Free Energy Loss: 0.6858
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [91/300] - Free Energy Loss: -0.1633
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [92/300] - Free Energy Loss: -0.5133
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [93/300] - Free Energy Loss: 0.1330
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [94/300] - Free Energy Loss: 0.9549
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [95/300] - Free Energy Loss: -0.4328
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [96/300] - Free Energy Loss: 0.4743
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [97/300] - Free Energy Loss: 0.2099
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [98/300] - Free Energy Loss: -0.2263
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [99/300] - Free Energy Loss: 0.1250
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [100/300] - Free Energy Loss: -0.0701
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [101/300] - Free Energy Loss: -0.0608
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [102/300] - Free Energy Loss: 0.0031
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [103/300] - Free Energy Loss: -0.1862
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [104/300] - Free Energy Loss: 0.6870
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [105/300] - Free Energy Loss: 0.8246
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [106/300] - Free Energy Loss: -0.6258
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [107/300] - Free Energy Loss: -0.3687
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [108/300] - Free Energy Loss: -0.3554
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [109/300] - Free Energy Loss: 0.0679
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [110/300] - Free Energy Loss: -0.0057
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [111/300] - Free Energy Loss: 0.2149
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [112/300] - Free Energy Loss: -0.4197
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [113/300] - Free Energy Loss: 0.5068
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [114/300] - Free Energy Loss: -0.3951
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [115/300] - Free Energy Loss: 0.3686
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [116/300] - Free Energy Loss: -0.2637
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [117/300] - Free Energy Loss: 0.8019
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [118/300] - Free Energy Loss: -0.3367
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [119/300] - Free Energy Loss: 0.0295
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [120/300] - Free Energy Loss: 0.0380
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [121/300] - Free Energy Loss: -0.1174
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [122/300] - Free Energy Loss: 0.6130
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [123/300] - Free Energy Loss: 0.4795
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [124/300] - Free Energy Loss: -0.6418
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [125/300] - Free Energy Loss: 0.2248
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [126/300] - Free Energy Loss: 0.6270
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [127/300] - Free Energy Loss: -0.1564
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [128/300] - Free Energy Loss: -0.5075
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [129/300] - Free Energy Loss: -0.3158
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [130/300] - Free Energy Loss: 0.4469
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [131/300] - Free Energy Loss: 0.4244
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [132/300] - Free Energy Loss: -0.0125
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [133/300] - Free Energy Loss: 0.6307
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [134/300] - Free Energy Loss: -0.0655
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [135/300] - Free Energy Loss: -0.1544
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [136/300] - Free Energy Loss: 0.6030
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [137/300] - Free Energy Loss: -0.3319
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [138/300] - Free Energy Loss: 0.2451
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [139/300] - Free Energy Loss: -0.3630
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [140/300] - Free Energy Loss: 0.3698
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [141/300] - Free Energy Loss: 0.4484
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [142/300] - Free Energy Loss: -0.2098
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [143/300] - Free Energy Loss: -0.7315
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [144/300] - Free Energy Loss: -0.2538
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# ...
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [253/300] - Free Energy Loss: -0.1364
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [254/300] - Free Energy Loss: -0.0352
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [255/300] - Free Energy Loss: -0.0438
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [256/300] - Free Energy Loss: -0.6109
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [257/300] - Free Energy Loss: -0.0177
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [258/300] - Free Energy Loss: -0.1271
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [259/300] - Free Energy Loss: 0.7910
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [260/300] - Free Energy Loss: 0.7412
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [261/300] - Free Energy Loss: -0.5389
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [262/300] - Free Energy Loss: -0.1523
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [263/300] - Free Energy Loss: -0.2076
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [264/300] - Free Energy Loss: 0.8214
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [265/300] - Free Energy Loss: 0.2623
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [266/300] - Free Energy Loss: -0.1378
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [267/300] - Free Energy Loss: -0.3904
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [268/300] - Free Energy Loss: 0.3797
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [269/300] - Free Energy Loss: 0.1270
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [270/300] - Free Energy Loss: -0.2967
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [271/300] - Free Energy Loss: 0.4752
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [272/300] - Free Energy Loss: 0.0856
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [273/300] - Free Energy Loss: -0.0617
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [274/300] - Free Energy Loss: 0.2483
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [275/300] - Free Energy Loss: 0.3891
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [276/300] - Free Energy Loss: -0.2340
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [277/300] - Free Energy Loss: 0.4205
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [278/300] - Free Energy Loss: -0.4812
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [279/300] - Free Energy Loss: 0.3230
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [280/300] - Free Energy Loss: 0.4129
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [281/300] - Free Energy Loss: -0.2155
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [282/300] - Free Energy Loss: -0.1335
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [283/300] - Free Energy Loss: -0.6294
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [284/300] - Free Energy Loss: 0.2451
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [285/300] - Free Energy Loss: 0.8442
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [286/300] - Free Energy Loss: 0.7409
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [287/300] - Free Energy Loss: 0.0964
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [288/300] - Free Energy Loss: -0.0432
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [289/300] - Free Energy Loss: 0.1713
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [290/300] - Free Energy Loss: 0.0131
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [291/300] - Free Energy Loss: 0.1891
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [292/300] - Free Energy Loss: 0.3157
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [293/300] - Free Energy Loss: 0.1166
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [294/300] - Free Energy Loss: -0.9212
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [295/300] - Free Energy Loss: -0.3479
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [296/300] - Free Energy Loss: 0.7219
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [297/300] - Free Energy Loss: 0.3524
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [298/300] - Free Energy Loss: -0.4023
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [299/300] - Free Energy Loss: 0.5198
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# <class 'int'>, <class 'int'>
# Epoch [300/300] - Free Energy Loss: 0.1105

# %%
plt.plot([metrics[epoch]['free_energy_loss'] for epoch in metrics])
plt.xlabel("Epoch")
plt.ylabel("Free Energy Loss")
# Out:
# Text(0, 0.5, 'Free Energy Loss')

# %%
samples = rbm.generate(state.params,
                       n_samples=10_000,
                       T_schedule=jnp.ones(200) * 1.2,
                       rng=rng)

rel_freq = samples.mean(0)
rel_freq
# Out:
# Array([0.0913    , 0.0693    , 0.0773    , 0.0005    , 0.0992    ,
#        0.12529999, 0.1287    , 0.10839999, 0.1098    , 0.11629999,
#        0.0876    , 0.0523    , 0.0738    , 0.0004    , 0.119     ,
#        0.0616    , 0.1309    , 0.0885    , 0.11719999, 0.074     ],      dtype=float32)

# %%
rel_freq.sum()
# Out:
# Array(1., dtype=float32)

# %%
spin_counts = samples.sum(axis=1)

plt.figure(figsize=(8, 4))
plt.hist(spin_counts, bins=range(22), align='left', edgecolor='black')
plt.xticks(range(21))
plt.xlabel("Number of spins up (1)")
plt.ylabel("Number of samples")
plt.title("Histogram of spin-up counts per sample")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
sites = np.arange(1, visible_units+1)
ax.bar(sites, rel_freq, width=0.8, edgecolor='black', alpha=0.7)
ax.axhline(1/visible_units, color='red', linestyle='--', label=f'Expected = {1/visible_units:.3f}')

ax.set_xlabel('Spin‐site index')
ax.set_ylabel('Relative frequency of up‐spin')
ax.set_title('Training Data: Up‐Spin Occurrence per Site')
ax.set_xticks(sites)
ax.set_ylim(0, rel_freq.max()*1.2)

ax.legend(loc='upper right')
plt.tight_layout()
plt.show()
