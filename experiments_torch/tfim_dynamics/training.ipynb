# %%
# CELL 1 — imports & setup

from pathlib import Path
from typing import Tuple, Dict, Any, Callable, Optional, List

import csv
import math

import torch
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
from tqdm import tqdm

data_dir = Path("./measurements")
print(f"Data resides in: {data_dir.resolve()}")
# Out:
# Data resides in: /Users/Tonni/Desktop/master-code/neural-quantum-tomo/experiments_torch/tfim_dynamics/measurements

# %%
# CELL 2 — unified MeasurementDataset & MeasurementLoader

from pathlib import Path
from typing import Dict, List, Tuple, Optional, Iterable

import torch
from tqdm import tqdm

IGNORE_HAM_KEYS = {"system", "nqubits", "seed"}
_VALID_BASIS_LETTERS = set("XYZ")


def _parse_kv_line(expected_prefix: str, line: str) -> Dict[str, str]:
    line = line.strip()
    if not line.startswith(expected_prefix):
        raise ValueError(f"Expected line to start with '{expected_prefix}', got: {line}")
    parts = [p.strip() for p in line.split("|")[1:]]
    kv: Dict[str, str] = {}
    for p in parts:
        if "=" in p:
            k, v = p.split("=", 1)
            kv[k.strip()] = v.strip()
    return kv


def _is_float(s: str) -> bool:
    try:
        float(s)
        return True
    except ValueError:
        return False


def _shot_to_bits_generic(s: str, nqubits: int) -> List[int]:
    """Map 0/1 or letters (upper=0, lower=1) -> bits."""
    if len(s) != nqubits:
        raise ValueError(f"Shot width {len(s)} != nqubits {nqubits}.")
    out: List[int] = []
    for c in s:
        if c in "01":
            out.append(int(c))
        elif c.isalpha():
            out.append(0 if c.isupper() else 1)
        else:
            raise ValueError(f"Bad char '{c}' in shot '{s}'.")
    return out


def _parse_mixed_shot(s: str, nqubits: int) -> Tuple[List[int], Tuple[str, ...]]:
    """
    For basis=mixed:
      - Each position: letter in {X,Y,Z} (any case).
      - Uppercase -> bit 0, lowercase -> bit 1.
      - Basis at each site = letter.upper().
    """
    if len(s) != nqubits:
        raise ValueError(f"Shot width {len(s)} != nqubits {nqubits}.")
    bits: List[int] = []
    bases: List[str] = []
    for c in s:
        if not c.isalpha():
            raise ValueError(f"basis=mixed expects letters only, got '{c}' in '{s}'.")
        b = c.upper()
        if b not in _VALID_BASIS_LETTERS:
            raise ValueError(f"Invalid basis letter '{c}' in '{s}' (only X,Y,Z allowed).")
        bit = 0 if c.isupper() else 1
        bits.append(bit)
        bases.append(b)
    return bits, tuple(bases)


class MeasurementDataset:
    """
    Unified dataset over one or more measurement files.

    Files:

      STATE | system=... | ... | nqubits=9 | ...
      MEASUREMENT | basis=computational|XZXZ|mixed | samples=... | ...
      <shots>

    Basis logic:

      - If any file has basis=mixed          -> mixed dataset.
      - Else if >1 distinct fixed basis      -> mixed dataset.
      - Else                                 -> homogeneous dataset
                                               with a single implicit_basis.

    Shots:

      - Always stored as:
          values: (N, nqubits) uint8

      - Bases:

          if mixed:
            bases[i] = Tuple[str,...] per sample.
          if homogeneous:
            implicit_basis = Tuple[str,...]
            (per-batch bases are materialized by the loader).

    System parameters:

      - From STATE: numeric keys, excl. IGNORE_HAM_KEYS.
      - All files must share same set of param keys.
      - params_dict[name]: (N,) float32.
      - system_param_keys: desired ordering (user-provided or all sorted).
      - system_params: (N, d) stacked accordingly.

    z_mask:

      - True where basis is all 'Z' (per-sample, using bases or implicit_basis).
    """

    def __init__(
            self,
            file_paths: Iterable[Path],
            system_param_keys: Optional[List[str]] = None,
    ):
        file_paths = [Path(p) for p in file_paths]
        if not file_paths:
            raise ValueError("No measurement files provided.")

        (
            self.num_qubits,
            file_infos,
            self.is_mixed,
            implicit_basis,
            ham_param_names,
        ) = self._inspect_files(file_paths)

        # Decide which system params to stack
        if system_param_keys is None:
            self.system_param_keys = sorted(ham_param_names)
        else:
            missing = [k for k in system_param_keys if k not in ham_param_names]
            if missing:
                raise KeyError(f"Requested system_param_keys not in headers: {missing}")
            self.system_param_keys = list(system_param_keys)

        values_list: List[List[int]] = []
        bases_list: List[Tuple[str, ...]] = [] if self.is_mixed else []
        params_accum: Dict[str, List[float]] = {k: [] for k in ham_param_names}

        # Second pass: parse shots
        for info in file_infos:
            path = info["path"]
            basis_mode = info["basis_mode"]      # "mixed" or fixed string like "ZZZZ", "XZXZ"
            ham_params = info["ham_params"]

            lines = [
                ln.strip()
                for ln in path.read_text().splitlines()
                if ln.strip()
            ]
            if not lines or not lines[0].startswith("STATE"):
                raise ValueError(f"{path}: first non-empty line must start with 'STATE'.")

            # find shot region
            shot_start_idx = 1
            if len(lines) > 1 and lines[1].startswith("MEASUREMENT"):
                shot_start_idx = 2
            shots = lines[shot_start_idx:]
            if not shots:
                raise ValueError(f"{path}: no shots found after headers.")

            if self.is_mixed:
                if basis_mode == "mixed":
                    # basis encoded per shot
                    for s in tqdm(shots, desc=f"Parsing {path.name} (mixed)", leave=False):
                        bits, bases = _parse_mixed_shot(s, self.num_qubits)
                        values_list.append(bits)
                        bases_list.append(bases)
                        for k in ham_param_names:
                            params_accum[k].append(ham_params[k])
                else:
                    # fixed basis for this file
                    basis_tuple = tuple(basis_mode)
                    for s in tqdm(shots, desc=f"Parsing {path.name} (fixed)", leave=False):
                        bits = _shot_to_bits_generic(s, self.num_qubits)
                        values_list.append(bits)
                        bases_list.append(basis_tuple)
                        for k in ham_param_names:
                            params_accum[k].append(ham_params[k])
            else:
                # homogeneous: only bits; basis is implicit for all shots
                for s in tqdm(shots, desc=f"Parsing {path.name}", leave=False):
                    bits = _shot_to_bits_generic(s, self.num_qubits)
                    values_list.append(bits)
                    for k in ham_param_names:
                        params_accum[k].append(ham_params[k])

        if not values_list:
            raise ValueError("No measurement shots parsed from provided files.")

        self.values = torch.tensor(values_list, dtype=torch.uint8)  # (N, nqubits)

        if self.is_mixed:
            self.bases: Optional[List[Tuple[str, ...]]] = bases_list
            self.implicit_basis: Optional[Tuple[str, ...]] = None
        else:
            self.bases = None
            self.implicit_basis = tuple(implicit_basis) if implicit_basis is not None else None

        # Per-parameter tensors
        self.params_dict: Dict[str, torch.Tensor] = {
            k: torch.tensor(vs, dtype=torch.float32)
            for k, vs in params_accum.items()
        }

        # Stacked system params
        if self.system_param_keys:
            self.system_params = torch.stack(
                [self.params_dict[k] for k in self.system_param_keys],
                dim=-1,
            )  # (N, d)
        else:
            self.system_params = None

        # z_mask: per-sample "all Z"
        N = self.values.shape[0]
        if self.is_mixed:
            self.z_mask = torch.tensor(
                [all(b == "Z" for b in row) for row in self.bases],
                dtype=torch.bool,
            )
        else:
            if self.implicit_basis is None:
                self.z_mask = torch.zeros(N, dtype=torch.bool)
            else:
                all_z = all(b == "Z" for b in self.implicit_basis)
                self.z_mask = torch.full((N,), bool(all_z), dtype=torch.bool)

    @staticmethod
    def _inspect_files(file_paths: List[Path]):
        nqubits_global: Optional[int] = None
        ham_param_names: Optional[List[str]] = None

        file_infos = []
        fixed_bases_seen = set()
        any_mixed = False

        for path in file_paths:
            lines = [
                ln.strip()
                for ln in path.read_text().splitlines()
                if ln.strip()
            ]
            if not lines or not lines[0].startswith("STATE"):
                raise ValueError(f"{path}: first non-empty line must start with 'STATE'.")

            state_kv = _parse_kv_line("STATE", lines[0])

            if "nqubits" not in state_kv:
                raise ValueError(f"{path}: STATE header missing 'nqubits'.")
            nqubits = int(state_kv["nqubits"])

            if nqubits_global is None:
                nqubits_global = nqubits
            elif nqubits_global != nqubits:
                raise ValueError(
                    f"Inconsistent nqubits across files: {nqubits_global} vs {nqubits} in {path}."
                )

            meas_kv: Dict[str, str] = {}
            if len(lines) > 1 and lines[1].startswith("MEASUREMENT"):
                meas_kv = _parse_kv_line("MEASUREMENT", lines[1])

            # numeric params from STATE
            ham_params = {
                k: float(v)
                for k, v in state_kv.items()
                if k not in IGNORE_HAM_KEYS and _is_float(v)
            }
            if not ham_params:
                raise ValueError(f"{path}: no numeric system parameters found in STATE header.")

            if ham_param_names is None:
                ham_param_names = sorted(ham_params.keys())
            else:
                if sorted(ham_params.keys()) != ham_param_names:
                    raise ValueError(
                        f"{path}: system parameter keys {sorted(ham_params.keys())} "
                        f"do not match initial set {ham_param_names}."
                    )

            # basis from MEASUREMENT
            basis_raw = meas_kv.get("basis", "computational").strip()
            if basis_raw.lower() == "mixed":
                basis_mode = "mixed"
                any_mixed = True
            elif basis_raw.lower() == "computational":
                basis_str = "Z" * nqubits
                basis_mode = basis_str
                fixed_bases_seen.add(basis_str)
            else:
                basis_str = basis_raw.upper()
                if len(basis_str) != nqubits:
                    raise ValueError(
                        f"{path}: basis='{basis_raw}' has wrong length (expected {nqubits})."
                    )
                if any(c not in _VALID_BASIS_LETTERS for c in basis_str):
                    raise ValueError(
                        f"{path}: invalid basis letters in '{basis_raw}' (only X,Y,Z allowed)."
                    )
                basis_mode = basis_str
                fixed_bases_seen.add(basis_str)

            file_infos.append(
                {
                    "path": path,
                    "basis_mode": basis_mode,
                    "ham_params": ham_params,
                }
            )

        if nqubits_global is None:
            raise ValueError("Could not infer nqubits from files.")
        if ham_param_names is None:
            raise ValueError("No Hamiltonian parameters found in any file.")

        # decide regime
        if any_mixed:
            is_mixed = True
            implicit_basis = None
        else:
            if len(fixed_bases_seen) == 0:
                implicit_basis = ("Z",) * nqubits_global
                is_mixed = False
            elif len(fixed_bases_seen) == 1:
                only = next(iter(fixed_bases_seen))
                implicit_basis = tuple(only)
                is_mixed = False
            else:
                is_mixed = True
                implicit_basis = None

        return nqubits_global, file_infos, is_mixed, implicit_basis, ham_param_names

    def __len__(self) -> int:
        return int(self.values.shape[0])


class MeasurementLoader:
    """
    Minibatch wrapper around MeasurementDataset.

    Iteration yields:
        batch_values        : (B, nqubits), uint8
        batch_bases         : list[Tuple[str,...]]  (always materialized)
        batch_system_params : (B, d) float32 or None
    """

    def __init__(
            self,
            dataset: MeasurementDataset,
            batch_size: int = 128,
            shuffle: bool = True,
            drop_last: bool = False,
            gen: Optional[torch.Generator] = None,
    ):
        if batch_size <= 0:
            raise ValueError("batch_size must be positive.")

        self.ds = dataset
        self.bs = int(batch_size)
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.gen = gen or torch.Generator().manual_seed(0)

        N = len(self.ds)
        self.slice_bounds = [
            (i, i + self.bs)
            for i in range(0, N, self.bs)
            if not self.drop_last or (i + self.bs) <= N
        ]

    def __len__(self) -> int:
        return len(self.slice_bounds)

    def __iter__(self):
        N = len(self.ds)
        if self.shuffle:
            self.order = torch.randperm(N, generator=self.gen)
        else:
            self.order = torch.arange(N)
        self._idx = 0
        return self

    def __next__(self):
        if self._idx >= len(self.slice_bounds):
            raise StopIteration

        start, end = self.slice_bounds[self._idx]
        self._idx += 1

        idxs = self.order[start:end]
        values = self.ds.values[idxs]

        # Always materialize bases
        if self.ds.bases is not None:
            bases = [self.ds.bases[int(i)] for i in idxs]
        else:
            if self.ds.implicit_basis is None:
                raise RuntimeError("Homogeneous dataset without implicit_basis; this should not happen.")
            bases = [self.ds.implicit_basis for _ in range(values.shape[0])]

        # Stacked system params (if present)
        if self.ds.system_params is not None:
            sys = self.ds.system_params[idxs]
        else:
            sys = None

        return values, bases, sys

# %%
# CELL 3 — model (ConditionalRBM) — expects batch = (values, bases, system_params)

class Conditioner(nn.Module):
    def __init__(self, num_visible: int, num_hidden: int, cond_dim: int, width: int):
        super().__init__()
        self.num_visible = num_visible
        self.num_hidden = num_hidden
        self.cond_dim = cond_dim

        self.fc1 = nn.Linear(cond_dim, width)
        self.fc2 = nn.Linear(width, 2 * (num_visible + num_hidden))

    def forward(self, cond: torch.Tensor):
        """
        cond: (B, cond_dim)
        """
        if cond.dim() == 1:
            cond = cond.view(-1, self.cond_dim)
        elif cond.dim() == 2 and cond.size(1) == self.cond_dim:
            pass
        else:
            raise ValueError(
                f"Conditioner: expected shape (B, {self.cond_dim}), got {tuple(cond.shape)}"
            )

        x = torch.tanh(self.fc1(cond))
        x = self.fc2(x)

        N, H = self.num_visible, self.num_hidden
        gamma_b, beta_b, gamma_c, beta_c = torch.split(x, [N, N, H, H], dim=-1)
        return gamma_b, beta_b, gamma_c, beta_c


class ConditionalRBM(nn.Module):
    """
    Conditional RBM with per-sample conditioning vector.

    Batch format from MeasurementLoader:
        values        : (B, N) uint8
        bases         : list[Tuple[str,...]]  (ignored here, but available)
        system_params : (B, cond_dim) float32

    We use system_params as input to the Conditioner.
    """

    def __init__(
            self,
            num_visible: int,
            num_hidden: int,
            cond_dim: int,
            conditioner_width: int = 64,
            k: int = 1,
            T: float = 1.0,
    ):
        super().__init__()
        self.num_visible = num_visible
        self.num_hidden = num_hidden
        self.cond_dim = cond_dim
        self.k = k
        self.T = T

        self.W = nn.Parameter(torch.empty(num_visible, num_hidden))
        self.b = nn.Parameter(torch.zeros(num_visible))
        self.c = nn.Parameter(torch.zeros(num_hidden))

        nn.init.normal_(self.W, mean=0.0, std=0.01)

        self.conditioner = Conditioner(
            num_visible=num_visible,
            num_hidden=num_hidden,
            cond_dim=cond_dim,
            width=conditioner_width,
        )

    @staticmethod
    def _free_energy(
            v: torch.Tensor,
            W: torch.Tensor,
            b: torch.Tensor,
            c: torch.Tensor,
    ) -> torch.Tensor:
        """
        v: (B,N)
        W: (N,H)
        b: (B,N) or (N,)
        c: (B,H) or (H,)
        """
        if b.dim() == 1:
            b = b.unsqueeze(0).expand_as(v)
        h_arg = v @ W
        if c.dim() == 1:
            c = c.unsqueeze(0).expand(h_arg.shape[0], -1)

        term1 = -(v * b).sum(dim=-1)
        term2 = F.softplus(h_arg + c).sum(dim=-1)
        return term1 - term2

    @staticmethod
    def _sample_bernoulli(probs: torch.Tensor, gen: torch.Generator) -> torch.Tensor:
        noise = torch.rand(
            probs.shape,
            generator=gen,
            device=probs.device,
            dtype=probs.dtype,
        )
        return (noise < probs).to(probs.dtype)

    def _gibbs_step_T(
            self,
            v: torch.Tensor,
            b_mod: torch.Tensor,
            c_mod: torch.Tensor,
            T: float,
            gen: torch.Generator,
    ):
        # Sample h | v
        logits_h = (v @ self.W + c_mod) / T
        p_h = torch.sigmoid(logits_h)
        h = self._sample_bernoulli(p_h, gen)

        # Sample v | h
        logits_v = (h @ self.W.t() + b_mod) / T
        p_v = torch.sigmoid(logits_v)
        v = self._sample_bernoulli(p_v, gen)
        return v

    def forward(
            self,
            batch: Tuple[torch.Tensor, List[Tuple[str, ...]], Optional[torch.Tensor]],
            aux_vars: Dict[str, Any],
    ):
        """
        batch:
            values        : (B, N), uint8
            bases         : list[Tuple[str,...]]  (ignored)
            system_params : (B, cond_dim), float32

        aux_vars:
            gen          : torch.Generator for Gibbs sampling
            l2_strength  : float, L2 penalty on deviation (b_mod, c_mod) from base (b, c)
        """
        values, bases, cond = batch  # bases currently unused

        if cond is None:
            raise ValueError("ConditionalRBM expects non-None system_params as conditioning vector.")

        gen: torch.Generator = aux_vars.get("gen", torch.Generator().manual_seed(0))
        l2_strength: float = float(aux_vars.get("l2_strength", 0.0))

        v_data = values.float()
        cond = cond.to(v_data.device, dtype=v_data.dtype)

        # Per-sample effective biases from conditioner
        gamma_b, beta_b, gamma_c, beta_c = self.conditioner(cond)
        b_mod = (1.0 + gamma_b) * self.b.unsqueeze(0) + beta_b
        c_mod = (1.0 + gamma_c) * self.c.unsqueeze(0) + beta_c

        # Negative phase: persistent or fresh chain; here fresh per batch
        v_model = (torch.rand(v_data.shape, generator=gen, device=v_data.device) < 0.5).float()
        for _ in range(self.k):
            v_model = self._gibbs_step_T(v_model, b_mod, c_mod, self.T, gen)
        v_model = v_model.detach()

        fe_data = self._free_energy(v_data, self.W, b_mod, c_mod)
        fe_model = self._free_energy(v_model, self.W, b_mod, c_mod)

        fe_delta = fe_data - fe_model
        fe_mean = fe_delta.mean()
        fe_std = fe_delta.std(unbiased=False)

        # Small regularizer: keep conditioner-modulated biases near base biases
        l2_regularization = (
                (self.b.unsqueeze(0) - b_mod).pow(2).sum()
                + (self.c.unsqueeze(0) - c_mod).pow(2).sum()
        )

        loss = fe_mean + l2_strength * l2_regularization

        aux_out = {
            "free_energy_mean": fe_mean.detach(),
            "free_energy_std": fe_std.detach(),
        }
        return loss, aux_out

    @torch.no_grad()
    def generate(
            self,
            cond: torch.Tensor,
            T_schedule: torch.Tensor,
            gen: torch.Generator,
    ) -> torch.Tensor:
        """
        Generate samples given conditioning vector(s).

        cond       : (B, cond_dim)
        T_schedule : scalar or (K,) schedule
        """
        if cond.dim() == 1:
            cond = cond.view(-1, self.cond_dim)
        cond = cond.to(next(self.parameters()).device, dtype=torch.float32)

        gamma_b, beta_b, gamma_c, beta_c = self.conditioner(cond)
        b_mod = (1.0 + gamma_b) * self.b.unsqueeze(0) + beta_b
        c_mod = (1.0 + gamma_c) * self.c.unsqueeze(0) + beta_c

        B = cond.shape[0]
        v = (torch.rand((B, self.num_visible), generator=gen, device=cond.device) < 0.5).float()

        if T_schedule.dim() == 0:
            T_schedule = T_schedule.view(1)

        for i in range(int(T_schedule.shape[0])):
            T_i = float(T_schedule[i].item())
            v = self._gibbs_step_T(v, b_mod, c_mod, T_i, gen)

        return v

# %%
# CELL 4 — training utilities for ConditionalRBM with MeasurementLoader

def train_step(
        model: nn.Module,
        optimizer: torch.optim.Optimizer,
        batch: Tuple[torch.Tensor, List[Tuple[str, ...]], Optional[torch.Tensor]],
        aux_vars: Dict[str, Any],
):
    optimizer.zero_grad(set_to_none=True)
    loss, aux = model(batch, aux_vars)
    loss.backward()
    optimizer.step()
    return loss.detach(), aux


def train(
        model: nn.Module,
        optimizer: torch.optim.Optimizer,
        loader,
        num_epochs: int,
        gen: torch.Generator,
        l2_strength: float,
        lr_schedule_fn: Callable[[int], float],
):
    metrics: Dict[int, Any] = {}
    global_step = 0

    for epoch in range(num_epochs):
        tot_loss = 0.0
        fe_mean_last = torch.tensor(0.0)
        fe_std_last = torch.tensor(0.0)

        for batch in loader:
            lr = float(lr_schedule_fn(global_step))
            for g in optimizer.param_groups:
                g["lr"] = lr

            aux_vars = {
                "gen": gen,
                "l2_strength": l2_strength,
            }
            loss, aux_out = train_step(model, optimizer, batch, aux_vars)

            tot_loss += float(loss)
            fe_mean_last = aux_out.get("free_energy_mean", torch.tensor(0.0))
            fe_std_last = aux_out.get("free_energy_std", torch.tensor(0.0))
            global_step += 1

        avg_loss = tot_loss / len(loader)
        lr_epoch = float(lr_schedule_fn(global_step))

        metrics[epoch] = dict(
            loss=avg_loss,
            free_energy_mean=float(fe_mean_last),
            free_energy_var=float(fe_std_last),
            lr=lr_epoch,
        )

        print(
            f"Epoch {epoch + 1}/{num_epochs} | "
            f"Loss: {avg_loss:+.4f} | "
            f"Free En. Mean: {float(fe_mean_last):.4f} | "
            f"Free En. STD: {float(fe_std_last):.4f} | "
            f"Learning Rate: {lr_epoch:.5f}"
        )

    return model, metrics


def get_sigmoid_curve(high, low, steps, falloff, center_step=None):
    if center_step is None:
        center_step = steps / 2.0

    def curve_fn(step: int) -> float:
        s = min(step, steps)
        return float(
            low + (high - low) / (1.0 + math.exp(falloff * (s - center_step)))
        )

    return curve_fn

# %%
# CELL 5 — build MeasurementDataset from TFIM files

file_names = [
    "tfim_3x3_h1.00_10000.txt",
    "tfim_3x3_h2.00_10000.txt",
    "tfim_3x3_h2.80_10000.txt",
    "tfim_3x3_h3.00_10000.txt",
    "tfim_3x3_h3.30_10000.txt",
    "tfim_3x3_h3.60_10000.txt",
    "tfim_3x3_h4.00_10000.txt",
    "tfim_3x3_h5.00_10000.txt",
    "tfim_3x3_h6.00_10000.txt",
    "tfim_3x3_h7.00_10000.txt",
]

file_paths = [data_dir / fn for fn in file_names]

# Condition on 'h' only
ds = MeasurementDataset(file_paths, system_param_keys=["h"])

print("=== DATASET SUMMARY ===")
print(f"N samples         : {len(ds)}")
print(f"num_qubits       : {ds.num_qubits}")
print(f"is_mixed         : {ds.is_mixed}")
print(f"implicit_basis   : {ds.implicit_basis}")
print(f"has bases list   : {ds.bases is not None}")
print(f"values shape     : {tuple(ds.values.shape)}")
print(f"system_param_keys: {ds.system_param_keys}")
print(f"system_params    : {None if ds.system_params is None else tuple(ds.system_params.shape)}")
print(f"z_mask true count: {int(ds.z_mask.sum())} / {len(ds)}")

# For this TFIM set we expect:
assert not ds.is_mixed
assert ds.implicit_basis == tuple("Z" * ds.num_qubits)
assert ds.bases is None
assert ds.system_params is not None and ds.system_params.shape[1] == 1

h_idx = ds.system_param_keys.index("h")
unique_h = torch.unique(ds.system_params[:, h_idx])
print("unique h values   :", [float(v) for v in unique_h])
# Out:
# === DATASET SUMMARY ===
# N samples         : 100000
# num_qubits       : 9
# is_mixed         : False
# implicit_basis   : ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z')
# has bases list   : False
# values shape     : (100000, 9)
# system_param_keys: ['h']
# system_params    : (100000, 1)
# z_mask true count: 100000 / 100000
# unique h values   : [1.0, 2.0, 2.799999952316284, 3.0, 3.299999952316284, 3.5999999046325684, 4.0, 5.0, 6.0, 7.0]

# %%
# CELL 6 — hyperparams, loader, model, training

batch_size        = 1024
num_visible       = ds.num_qubits
num_hidden        = 9
conditioner_width = 32
num_epochs        = 100
k_steps           = 100
init_lr           = 1e-2
final_lr          = init_lr * 0.1
l2_strength       = 0.0

# Conditioning dimension from dataset (here: 1 for 'h')
assert ds.system_params is not None, "Dataset must provide system_params for ConditionalRBM."
cond_dim = ds.system_params.shape[1]

gen = torch.Generator().manual_seed(0)

loader = MeasurementLoader(
    dataset=ds,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
    gen=gen,
)

model = ConditionalRBM(
    num_visible=num_visible,
    num_hidden=num_hidden,
    cond_dim=cond_dim,
    conditioner_width=conditioner_width,
    k=k_steps,
    T=1.0,
)

optimizer = torch.optim.Adam(model.parameters(), lr=init_lr)

schedule_steps = num_epochs * len(loader)
lr_schedule_fn = get_sigmoid_curve(
    high=init_lr,
    low=final_lr,
    steps=schedule_steps,
    falloff=0.0005,
)

model, metrics = train(
    model=model,
    optimizer=optimizer,
    loader=loader,
    num_epochs=num_epochs,
    gen=gen,
    l2_strength=l2_strength,
    lr_schedule_fn=lr_schedule_fn,
)
# Out:
# Epoch 1/100 | Loss: +0.0033 | Free En. Mean: -0.1837 | Free En. STD: 0.3656 | Learning Rate: 0.00925
# Epoch 2/100 | Loss: -0.2383 | Free En. Mean: -0.3217 | Free En. STD: 1.9984 | Learning Rate: 0.00922
# Epoch 3/100 | Loss: -0.0754 | Free En. Mean: -0.0709 | Free En. STD: 1.8802 | Learning Rate: 0.00918
# Epoch 4/100 | Loss: -0.0203 | Free En. Mean: 0.0662 | Free En. STD: 2.0179 | Learning Rate: 0.00914
# Epoch 5/100 | Loss: -0.0068 | Free En. Mean: -0.0511 | Free En. STD: 1.7480 | Learning Rate: 0.00911
# Epoch 6/100 | Loss: +0.0026 | Free En. Mean: 0.0387 | Free En. STD: 1.9043 | Learning Rate: 0.00907
# Epoch 7/100 | Loss: +0.0026 | Free En. Mean: -0.1098 | Free En. STD: 1.8821 | Learning Rate: 0.00902
# Epoch 8/100 | Loss: +0.0053 | Free En. Mean: -0.0074 | Free En. STD: 2.0555 | Learning Rate: 0.00898
# Epoch 9/100 | Loss: +0.0111 | Free En. Mean: 0.0635 | Free En. STD: 1.9686 | Learning Rate: 0.00894
# Epoch 10/100 | Loss: +0.0076 | Free En. Mean: -0.0297 | Free En. STD: 1.7798 | Learning Rate: 0.00889
# Epoch 11/100 | Loss: +0.0145 | Free En. Mean: 0.0282 | Free En. STD: 1.8345 | Learning Rate: 0.00884
# Epoch 12/100 | Loss: +0.0108 | Free En. Mean: -0.0115 | Free En. STD: 1.9679 | Learning Rate: 0.00879
# Epoch 13/100 | Loss: +0.0197 | Free En. Mean: -0.1227 | Free En. STD: 1.9311 | Learning Rate: 0.00874
# Epoch 14/100 | Loss: +0.0143 | Free En. Mean: -0.0571 | Free En. STD: 1.9110 | Learning Rate: 0.00868
# Epoch 15/100 | Loss: +0.0184 | Free En. Mean: 0.0017 | Free En. STD: 2.0371 | Learning Rate: 0.00863
# Epoch 16/100 | Loss: +0.0181 | Free En. Mean: -0.0106 | Free En. STD: 1.8933 | Learning Rate: 0.00857
# Epoch 17/100 | Loss: +0.0068 | Free En. Mean: -0.0995 | Free En. STD: 1.7434 | Learning Rate: 0.00851
# Epoch 18/100 | Loss: +0.0129 | Free En. Mean: 0.1341 | Free En. STD: 1.8183 | Learning Rate: 0.00845
# Epoch 19/100 | Loss: +0.0224 | Free En. Mean: 0.0910 | Free En. STD: 1.9038 | Learning Rate: 0.00838
# Epoch 20/100 | Loss: +0.0111 | Free En. Mean: -0.1473 | Free En. STD: 1.8285 | Learning Rate: 0.00832
# Epoch 21/100 | Loss: +0.0135 | Free En. Mean: -0.0393 | Free En. STD: 1.6966 | Learning Rate: 0.00825
# Epoch 22/100 | Loss: +0.0200 | Free En. Mean: 0.0491 | Free En. STD: 1.8531 | Learning Rate: 0.00818
# Epoch 23/100 | Loss: +0.0148 | Free En. Mean: -0.0629 | Free En. STD: 1.8196 | Learning Rate: 0.00811
# Epoch 24/100 | Loss: +0.0157 | Free En. Mean: 0.0304 | Free En. STD: 1.9335 | Learning Rate: 0.00803
# Epoch 25/100 | Loss: +0.0089 | Free En. Mean: -0.0150 | Free En. STD: 1.8997 | Learning Rate: 0.00796
# Epoch 26/100 | Loss: +0.0139 | Free En. Mean: 0.0223 | Free En. STD: 1.9376 | Learning Rate: 0.00788
# Epoch 27/100 | Loss: +0.0103 | Free En. Mean: 0.0008 | Free En. STD: 1.8345 | Learning Rate: 0.00780
# Epoch 28/100 | Loss: +0.0153 | Free En. Mean: 0.0145 | Free En. STD: 1.7503 | Learning Rate: 0.00772
# Epoch 29/100 | Loss: +0.0125 | Free En. Mean: 0.1057 | Free En. STD: 1.9539 | Learning Rate: 0.00763
# Epoch 30/100 | Loss: +0.0138 | Free En. Mean: 0.0119 | Free En. STD: 1.7843 | Learning Rate: 0.00754
# Epoch 31/100 | Loss: +0.0070 | Free En. Mean: 0.0951 | Free En. STD: 1.8495 | Learning Rate: 0.00746
# Epoch 32/100 | Loss: +0.0182 | Free En. Mean: 0.1795 | Free En. STD: 1.8012 | Learning Rate: 0.00737
# Epoch 33/100 | Loss: +0.0102 | Free En. Mean: -0.0185 | Free En. STD: 1.7684 | Learning Rate: 0.00727
# Epoch 34/100 | Loss: +0.0118 | Free En. Mean: 0.0102 | Free En. STD: 1.8380 | Learning Rate: 0.00718
# Epoch 35/100 | Loss: +0.0125 | Free En. Mean: -0.0613 | Free En. STD: 1.8365 | Learning Rate: 0.00708
# Epoch 36/100 | Loss: +0.0081 | Free En. Mean: 0.0541 | Free En. STD: 1.9540 | Learning Rate: 0.00699
# Epoch 37/100 | Loss: +0.0146 | Free En. Mean: -0.0918 | Free En. STD: 1.8063 | Learning Rate: 0.00689
# Epoch 38/100 | Loss: +0.0081 | Free En. Mean: 0.1036 | Free En. STD: 1.8987 | Learning Rate: 0.00679
# Epoch 39/100 | Loss: +0.0135 | Free En. Mean: -0.0605 | Free En. STD: 1.6771 | Learning Rate: 0.00668
# Epoch 40/100 | Loss: +0.0099 | Free En. Mean: -0.0126 | Free En. STD: 1.9760 | Learning Rate: 0.00658
# Epoch 41/100 | Loss: +0.0151 | Free En. Mean: 0.1374 | Free En. STD: 1.9511 | Learning Rate: 0.00648
# Epoch 42/100 | Loss: +0.0097 | Free En. Mean: 0.0069 | Free En. STD: 1.9453 | Learning Rate: 0.00637
# Epoch 43/100 | Loss: +0.0056 | Free En. Mean: 0.0075 | Free En. STD: 1.6950 | Learning Rate: 0.00626
# Epoch 44/100 | Loss: +0.0079 | Free En. Mean: -0.0116 | Free En. STD: 1.8446 | Learning Rate: 0.00616
# Epoch 45/100 | Loss: +0.0095 | Free En. Mean: 0.1268 | Free En. STD: 1.8770 | Learning Rate: 0.00605
# Epoch 46/100 | Loss: +0.0139 | Free En. Mean: -0.0432 | Free En. STD: 1.7695 | Learning Rate: 0.00594
# Epoch 47/100 | Loss: +0.0102 | Free En. Mean: -0.0075 | Free En. STD: 1.9176 | Learning Rate: 0.00583
# Epoch 48/100 | Loss: +0.0076 | Free En. Mean: 0.1623 | Free En. STD: 1.9502 | Learning Rate: 0.00572
# Epoch 49/100 | Loss: +0.0064 | Free En. Mean: 0.0539 | Free En. STD: 1.8707 | Learning Rate: 0.00561
# Epoch 50/100 | Loss: +0.0109 | Free En. Mean: 0.0469 | Free En. STD: 1.8262 | Learning Rate: 0.00550
# Epoch 51/100 | Loss: +0.0103 | Free En. Mean: -0.0619 | Free En. STD: 1.7840 | Learning Rate: 0.00539
# Epoch 52/100 | Loss: +0.0114 | Free En. Mean: -0.0490 | Free En. STD: 2.0467 | Learning Rate: 0.00528
# Epoch 53/100 | Loss: +0.0063 | Free En. Mean: 0.0096 | Free En. STD: 1.8590 | Learning Rate: 0.00517
# Epoch 54/100 | Loss: +0.0058 | Free En. Mean: 0.0044 | Free En. STD: 1.6754 | Learning Rate: 0.00506
# Epoch 55/100 | Loss: +0.0123 | Free En. Mean: 0.0353 | Free En. STD: 1.8443 | Learning Rate: 0.00495
# Epoch 56/100 | Loss: +0.0083 | Free En. Mean: -0.0134 | Free En. STD: 1.8982 | Learning Rate: 0.00484
# Epoch 57/100 | Loss: +0.0076 | Free En. Mean: 0.0020 | Free En. STD: 1.8523 | Learning Rate: 0.00474
# Epoch 58/100 | Loss: +0.0080 | Free En. Mean: -0.0611 | Free En. STD: 1.8859 | Learning Rate: 0.00463
# Epoch 59/100 | Loss: +0.0139 | Free En. Mean: 0.1104 | Free En. STD: 1.8441 | Learning Rate: 0.00452
# Epoch 60/100 | Loss: +0.0052 | Free En. Mean: 0.0378 | Free En. STD: 1.8461 | Learning Rate: 0.00442
# Epoch 61/100 | Loss: +0.0066 | Free En. Mean: 0.0463 | Free En. STD: 1.9015 | Learning Rate: 0.00432
# Epoch 62/100 | Loss: +0.0041 | Free En. Mean: -0.0298 | Free En. STD: 1.9512 | Learning Rate: 0.00421
# Epoch 63/100 | Loss: +0.0113 | Free En. Mean: 0.1784 | Free En. STD: 1.6548 | Learning Rate: 0.00411
# Epoch 64/100 | Loss: -0.0010 | Free En. Mean: 0.0212 | Free En. STD: 1.8955 | Learning Rate: 0.00401
# Epoch 65/100 | Loss: +0.0115 | Free En. Mean: -0.0470 | Free En. STD: 1.8273 | Learning Rate: 0.00392
# Epoch 66/100 | Loss: +0.0034 | Free En. Mean: -0.0267 | Free En. STD: 1.8829 | Learning Rate: 0.00382
# Epoch 67/100 | Loss: +0.0057 | Free En. Mean: -0.0241 | Free En. STD: 1.9448 | Learning Rate: 0.00373
# Epoch 68/100 | Loss: +0.0038 | Free En. Mean: 0.0272 | Free En. STD: 1.8505 | Learning Rate: 0.00363
# Epoch 69/100 | Loss: +0.0088 | Free En. Mean: 0.0221 | Free En. STD: 1.8507 | Learning Rate: 0.00354
# Epoch 70/100 | Loss: -0.0003 | Free En. Mean: 0.0502 | Free En. STD: 1.8670 | Learning Rate: 0.00346
# Epoch 71/100 | Loss: +0.0019 | Free En. Mean: -0.1316 | Free En. STD: 1.8755 | Learning Rate: 0.00337
# Epoch 72/100 | Loss: +0.0075 | Free En. Mean: 0.0542 | Free En. STD: 1.8199 | Learning Rate: 0.00328
# Epoch 73/100 | Loss: +0.0012 | Free En. Mean: -0.0324 | Free En. STD: 1.7504 | Learning Rate: 0.00320
# Epoch 74/100 | Loss: +0.0064 | Free En. Mean: 0.0079 | Free En. STD: 1.8778 | Learning Rate: 0.00312
# Epoch 75/100 | Loss: +0.0033 | Free En. Mean: 0.0867 | Free En. STD: 1.7987 | Learning Rate: 0.00304
# Epoch 76/100 | Loss: +0.0064 | Free En. Mean: -0.2185 | Free En. STD: 1.9034 | Learning Rate: 0.00297
# Epoch 77/100 | Loss: +0.0043 | Free En. Mean: 0.0435 | Free En. STD: 1.7884 | Learning Rate: 0.00289
# Epoch 78/100 | Loss: -0.0015 | Free En. Mean: -0.0538 | Free En. STD: 1.9106 | Learning Rate: 0.00282
# Epoch 79/100 | Loss: +0.0011 | Free En. Mean: -0.0356 | Free En. STD: 1.8973 | Learning Rate: 0.00275
# Epoch 80/100 | Loss: +0.0047 | Free En. Mean: 0.0568 | Free En. STD: 1.8393 | Learning Rate: 0.00268
# Epoch 81/100 | Loss: -0.0030 | Free En. Mean: -0.0338 | Free En. STD: 1.8903 | Learning Rate: 0.00262
# Epoch 82/100 | Loss: -0.0004 | Free En. Mean: -0.1741 | Free En. STD: 1.9008 | Learning Rate: 0.00255
# Epoch 83/100 | Loss: -0.0029 | Free En. Mean: -0.0482 | Free En. STD: 1.8224 | Learning Rate: 0.00249
# Epoch 84/100 | Loss: +0.0059 | Free En. Mean: 0.0227 | Free En. STD: 1.8223 | Learning Rate: 0.00243
# Epoch 85/100 | Loss: +0.0028 | Free En. Mean: -0.0353 | Free En. STD: 1.8975 | Learning Rate: 0.00237
# Epoch 86/100 | Loss: +0.0032 | Free En. Mean: 0.0443 | Free En. STD: 1.7774 | Learning Rate: 0.00232
# Epoch 87/100 | Loss: +0.0030 | Free En. Mean: -0.0197 | Free En. STD: 1.8987 | Learning Rate: 0.00226
# Epoch 88/100 | Loss: +0.0047 | Free En. Mean: 0.0695 | Free En. STD: 1.8808 | Learning Rate: 0.00221
# Epoch 89/100 | Loss: -0.0014 | Free En. Mean: 0.0344 | Free En. STD: 2.0372 | Learning Rate: 0.00216
# Epoch 90/100 | Loss: -0.0028 | Free En. Mean: 0.0023 | Free En. STD: 1.6729 | Learning Rate: 0.00211
# Epoch 91/100 | Loss: +0.0041 | Free En. Mean: 0.0334 | Free En. STD: 1.9307 | Learning Rate: 0.00206
# Epoch 92/100 | Loss: -0.0004 | Free En. Mean: 0.0733 | Free En. STD: 1.8255 | Learning Rate: 0.00202
# Epoch 93/100 | Loss: +0.0055 | Free En. Mean: -0.0533 | Free En. STD: 1.8682 | Learning Rate: 0.00198
# Epoch 94/100 | Loss: -0.0005 | Free En. Mean: 0.0311 | Free En. STD: 1.8341 | Learning Rate: 0.00193
# Epoch 95/100 | Loss: -0.0015 | Free En. Mean: -0.0193 | Free En. STD: 1.8219 | Learning Rate: 0.00189
# Epoch 96/100 | Loss: -0.0024 | Free En. Mean: 0.0162 | Free En. STD: 1.9563 | Learning Rate: 0.00186
# Epoch 97/100 | Loss: +0.0038 | Free En. Mean: 0.1084 | Free En. STD: 1.6793 | Learning Rate: 0.00182
# Epoch 98/100 | Loss: -0.0027 | Free En. Mean: 0.0018 | Free En. STD: 1.7013 | Learning Rate: 0.00178
# Epoch 99/100 | Loss: +0.0036 | Free En. Mean: 0.0293 | Free En. STD: 2.0070 | Learning Rate: 0.00175
# Epoch 100/100 | Loss: +0.0017 | Free En. Mean: 0.0053 | Free En. STD: 1.8673 | Learning Rate: 0.00171

# %%
# CELL 7 — plotting training diagnostics

epochs = list(metrics.keys())
loss_vals = [metrics[e]['loss'] for e in epochs]
free_model_mean_vals = [metrics[e]['free_energy_mean'] for e in epochs]
free_model_var_vals = [metrics[e]['free_energy_var'] for e in epochs]
lr_vals = [metrics[e]['lr'] for e in epochs]

fig, ax1 = plt.subplots(figsize=(11, 4))

ax1.plot(epochs, lr_vals, label="Learning Rate", color="tab:red")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Learning Rate", color="tab:red")
ax1.tick_params(axis="y", labelcolor="tab:red")

ax2 = ax1.twinx()
ax2.spines["right"].set_position(("axes", 1.00))
ax2.plot(epochs, loss_vals, label="Amplitude CD Loss", color="tab:blue")
ax2.set_ylabel("Loss", color="tab:blue")
ax2.tick_params(axis="y", labelcolor="tab:blue")

ax3 = ax1.twinx()
ax3.spines["right"].set_position(("axes", 1.1))
ax3.plot(epochs, free_model_var_vals, label="Free Energy Model Var", color="tab:green")
ax3.set_ylabel("Free Energy Model Var", color="tab:green")
ax3.tick_params(axis="y", labelcolor="tab:green")

ax4 = ax1.twinx()
ax4.spines["right"].set_position(("axes", 1.2))
ax4.plot(epochs, free_model_mean_vals, label="Free Energy Model Mean", color="tab:orange")
ax4.set_ylabel("Free Energy Model Mean", color="tab:orange")
ax4.tick_params(axis="y", labelcolor="tab:orange")

plt.tight_layout()
plt.show()

# %%
# CELL 8 — physics metrics: magnetizations + helpers (PyTorch, uses conditioning vector)

def magnetization_z_with_error(samples: torch.Tensor):
    """
    samples: (B,N) with entries in {0,1}
    returns mean |m_z| and SEM
    """
    samples = samples.float()
    spins = 1.0 - 2.0 * samples              # {0,1} -> {+1,-1}
    sample_mags = spins.mean(dim=1).abs()    # (B,)
    mean_mag = sample_mags.mean()
    sem_mag = sample_mags.std(unbiased=True) / math.sqrt(sample_mags.numel())
    return mean_mag, sem_mag


def _free_energy_batch(
        v_batch: torch.Tensor,
        W: torch.Tensor,
        b_batch: torch.Tensor,
        c_batch: torch.Tensor,
) -> torch.Tensor:
    """
    v_batch: (B,N), W: (N,H), b_batch: (B,N), c_batch: (B,H)
    returns: (B,)
    """
    vb_term = (v_batch * b_batch).sum(dim=-1)
    hidden_term = F.softplus(v_batch @ W + c_batch).sum(dim=-1)
    return -vb_term - hidden_term


@torch.no_grad()
def amplitude_ratio_flip(
        model: "ConditionalRBM",
        samples: torch.Tensor,
        cond: torch.Tensor,
        flip_idx: int,
) -> torch.Tensor:
    """
    exp(0.5*(F_ref - F_flip)) per sample, flipping bit at flip_idx

    samples: (B,N) in {0,1}
    cond   : (B, cond_dim) or (B,) if cond_dim == 1
    """
    samples = samples.float()
    B, N = samples.shape

    # Normalize cond shape
    if cond.dim() == 1 and model.cond_dim == 1:
        cond = cond.view(-1, 1)
    if cond.dim() != 2 or cond.shape[0] != B or cond.shape[1] != model.cond_dim:
        raise ValueError(
            f"amplitude_ratio_flip: expected cond shape (B,{model.cond_dim}), got {tuple(cond.shape)}"
        )

    cond = cond.to(samples.device, dtype=torch.float32)

    samples_flip = samples.clone()
    samples_flip[:, flip_idx] = 1.0 - samples_flip[:, flip_idx]

    gamma_b, beta_b, gamma_c, beta_c = model.conditioner(cond)
    b_mod = (1.0 + gamma_b) * model.b.unsqueeze(0) + beta_b
    c_mod = (1.0 + gamma_c) * model.c.unsqueeze(0) + beta_c
    W = model.W

    F_ref  = _free_energy_batch(samples,      W, b_mod, c_mod)
    F_flip = _free_energy_batch(samples_flip, W, b_mod, c_mod)

    return torch.exp(0.5 * (F_ref - F_flip))


@torch.no_grad()
def magnetization_x_with_error(
        model: "ConditionalRBM",
        samples: torch.Tensor,
        cond: torch.Tensor,
) -> Tuple[float, float]:
    """
    Estimates ⟨σ_x⟩ via single-site amplitude ratios.

    samples: (B,N) in {0,1}
    cond   : (B, cond_dim) or (B,) if cond_dim == 1
    """
    samples = samples.float()
    B, N = samples.shape

    # Normalize cond shape
    if cond.dim() == 1 and model.cond_dim == 1:
        cond = cond.view(-1, 1)
    if cond.dim() != 2 or cond.shape[0] != B or cond.shape[1] != model.cond_dim:
        raise ValueError(
            f"magnetization_x_with_error: expected cond shape (B,{model.cond_dim}), got {tuple(cond.shape)}"
        )

    ratios = []
    for i in range(N):
        ratios.append(amplitude_ratio_flip(model, samples, cond, i))

    all_ratios = torch.stack(ratios, dim=1)   # (B, N)
    per_sample_mx = all_ratios.mean(dim=1)    # (B,)

    mean = per_sample_mx.mean()
    sem = per_sample_mx.std(unbiased=True) / math.sqrt(per_sample_mx.numel())
    return float(mean), float(sem)

# %%
# CELL 9 — sampling helper (ConditionalRBM + single-parameter 'h')

@torch.no_grad()
def sample_from_model(
        model: ConditionalRBM,
        h: float,
        n: int,
        gen: torch.Generator,
):
    """
    Draw n samples at field h.

    Assumes model.cond_dim == 1 and that this dimension corresponds to 'h'.
    """
    if model.cond_dim != 1:
        raise ValueError("sample_from_model currently assumes cond_dim == 1 (single 'h').")

    cond = torch.full((n, 1), float(h), dtype=torch.float32)
    T_schedule = torch.full((int(model.k),), float(model.T), dtype=torch.float32)

    samples = model.generate(cond, T_schedule, gen)
    return samples.float(), cond

# %%
# CELL 10 — evaluation sweep & CSV export

support_h = [1.0, 2.0, 2.8, 3.0, 3.3, 3.6, 4.0, 5.0, 6.0, 7.0]
novel_h   = [1.5, 2.4, 2.6, 2.9, 3.1, 3.2, 3.4, 3.8, 4.5, 5.5, 6.5]

sweep = sorted(
    [(h, "support") for h in support_h]
    + [(h, "novel") for h in novel_h],
    key=lambda x: x[0],
)

csv_file = Path("magnetization.csv")
if not csv_file.exists() or csv_file.stat().st_size == 0:
    with csv_file.open("w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["h", "type", "mag_z", "mag_z_error", "mag_x", "mag_x_error"])

num_samples = 10_000
gen_eval = torch.Generator().manual_seed(1234)

for h, origin in sweep:
    samples, cond = sample_from_model(model, h, num_samples, gen_eval)

    mz, mz_e = magnetization_z_with_error(samples)
    mx, mx_e = magnetization_x_with_error(model, samples, cond)

    print(
        f"h={h:4.1f} [{origin:6}] "
        f"m_z={float(mz):.6f}±{float(mz_e):.6f}  "
        f"m_x={float(mx):.6f}±{float(mx_e):.6f}"
    )

    with csv_file.open("a", newline="") as f:
        writer = csv.writer(f)
        writer.writerow([
            f"{h:.6f}", origin,
            f"{float(mz):.6f}", f"{float(mz_e):.6f}",
            f"{float(mx):.6f}", f"{float(mx_e):.6f}",
        ])

print(f"\nAppended rows to {csv_file.resolve()}")
# Out:
# h= 1.0 [support] m_z=0.965356±0.000911  m_x=0.258965±0.003321
# h= 1.5 [novel ] m_z=0.946067±0.001233  m_x=0.313980±0.003491
# h= 2.0 [support] m_z=0.824245±0.002247  m_x=0.557660±0.003387
# h= 2.4 [novel ] m_z=0.707733±0.002823  m_x=0.703039±0.003204
# h= 2.6 [novel ] m_z=0.652755±0.002956  m_x=0.761507±0.003000
# h= 2.8 [support] m_z=0.587622±0.003016  m_x=0.823622±0.002707
# h= 2.9 [novel ] m_z=0.560578±0.003009  m_x=0.847340±0.002563
# h= 3.0 [support] m_z=0.537844±0.002994  m_x=0.865750±0.002422
# h= 3.1 [novel ] m_z=0.521933±0.002971  m_x=0.878888±0.002283
# h= 3.2 [novel ] m_z=0.499378±0.002920  m_x=0.896386±0.002137
# h= 3.3 [support] m_z=0.479200±0.002888  m_x=0.910385±0.002010
# h= 3.4 [novel ] m_z=0.467956±0.002854  m_x=0.918579±0.001908
# h= 3.6 [support] m_z=0.449133±0.002786  m_x=0.931166±0.001733
# h= 3.8 [novel ] m_z=0.431133±0.002745  m_x=0.941530±0.001605
# h= 4.0 [support] m_z=0.415711±0.002695  m_x=0.950187±0.001506
# h= 4.5 [novel ] m_z=0.390533±0.002587  m_x=0.963117±0.001265
# h= 5.0 [support] m_z=0.367622±0.002492  m_x=0.973457±0.001103
# h= 5.5 [novel ] m_z=0.353378±0.002438  m_x=0.978902±0.000992
# h= 6.0 [support] m_z=0.346156±0.002366  m_x=0.982378±0.000886
# h= 6.5 [novel ] m_z=0.337711±0.002343  m_x=0.984890±0.000817
# h= 7.0 [support] m_z=0.328800±0.002293  m_x=0.987219±0.000756
#
# Appended rows to /Users/Tonni/Desktop/master-code/neural-quantum-tomo/experiments_torch/tfim_dynamics/magnetization.csv
